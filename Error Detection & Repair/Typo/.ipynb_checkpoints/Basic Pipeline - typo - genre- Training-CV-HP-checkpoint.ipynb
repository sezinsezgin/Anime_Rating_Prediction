# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Keyboard(),50, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Keyboard().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Keyboard().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Keyboard method ---------------
#
# row: 1291 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy' changed to 'AAgiilnn,,cciioovveef,,DDrrqkaa,,FFaagh'
# row: 1172 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'AAnnnaattiiooj,,QttiinnCCmmddu,,GmyqTqccee'
# row: 351 col: 2 : 'Animation,Short' changed to 'Saatt,,Ahhett'
# row: 273 col: 2 : 'Action,Historical,Military,SuperPower' changed to 'Qxttiij,,aiiiccoMMiillraaf,,ieerrOrr'
# row: 954 col: 2 : 'Animation,Comedy' changed to 'AAnniikqiioob,,nd'
# row: 271 col: 2 : 'Hentai' changed to 'Bryaa'
# row: 964 col: 2 : 'Horror,Shounen' changed to 'HHirrtrrhhoobdm'
# row: 126 col: 2 : 'Drama,History,War' changed to 'DDmmHHttt,,aae'
# row: 1145 col: 2 : 'Animation,Comedy,Sci-Fi,Thriller' changed to 'jmmaattuoo,,FeexSSfk--Do,,Riikoee'
# row: 826 col: 2 : 'Animation' changed to 'mmgooom'
# row: 959 col: 2 : 'Animation,Comedy,Drama,Fantasy' changed to 'SnniispjoorsuDDaammq,,aass'
# row: 218 col: 2 : 'Animation,Action,Comedy,History,Romance,War' changed to 'AAiimmsiSfjXndd,,Giittrr,,RRoonbccee,,Ee'
# row: 159 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'AAnnkriip,,XoommeeyyDDaakaa,,itt'
# row: 777 col: 2 : 'Comedy,Parody,School,Seinen' changed to 'pkrPPqrridduvhhoo,,SSeeiinndnn'
# row: 903 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Sccop,,Sddbee,,immddyy,,SShhuunn'
# row: 1561 col: 2 : 'Hentai' changed to 'eenngk'
# row: 335 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'AAnniiaaynnxttiioonnGnngsayy,,GGnee--,,SSiiG'
# row: 1035 col: 2 : 'Animation,Short,Fantasy' changed to 'uksiinn,,hhooerys'
# row: 935 col: 2 : 'Fantasy,Music' changed to 'FFaajyy,,Niicc'
# row: 1333 col: 2 : 'Animation,Romance' changed to 'aattkoomFpnqnnr'
# row: 847 col: 2 : 'Hentai' changed to 'HHwjaaii'
# row: 511 col: 2 : 'Action,Sci-Fi,Thriller' changed to 'Sxykoo,,ii--fiiee'
# row: 1320 col: 2 : 'Action,Fantasy,Magic,Shounen' changed to 'QfriibCqnngqMMaahcc,,oouubj'
# row: 1129 col: 2 : 'Documentary' changed to 'Fooccmmaarryy'
# row: 13 col: 2 : 'Hentai' changed to 'Bwii'
# row: 700 col: 2 : 'Animation,Short' changed to 'AAnnmmaaguhhprrtt'
# row: 449 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'friioojoowdd,,PPoccee,,SShhluunneem'
# row: 1472 col: 2 : 'Drama' changed to 'DDkaa'
# row: 970 col: 2 : 'Action,Adventure,Comedy,Magic,Mecha,Sci-Fi' changed to 'AAccgiib,,fgeejee,,FoommrddyyKii,,Neehh,,SScc--ii'
# row: 782 col: 2 : 'Drama' changed to 'Ftaas'
# row: 162 col: 2 : 'Music' changed to 'Nzo'
# row: 1498 col: 2 : 'Comedy' changed to 'pkeeyy'
# row: 1224 col: 2 : 'Hentai' changed to 'Ywnntt'
# row: 938 col: 2 : 'Animation' changed to 'mtti'
# row: 1096 col: 2 : 'Biography,Drama' changed to 'iiggfojhrrsk'
# row: 402 col: 2 : 'Animation,Drama,Fantasy,Thriller' changed to 'jiinqriioo,,Ffaaaa,,aass,,kowrr'
# row: 219 col: 2 : 'Documentary,Short' changed to 'iikdnnaaoorrtt'
# row: 600 col: 2 : 'Adventure,Fantasy,Kids' changed to 'AAvveejttjeeFFsttaaLdd'
# row: 589 col: 2 : 'Animation,Action,Adventure,Comedy,Crime,Mystery' changed to 'Skaaoonn,,AAvttoijddvveennuudXkwt,,rrkmmee,,Nhdu'
# row: 953 col: 2 : 'Action,Adventure,Fantasy' changed to 'AAccttiip,,xrttyrCqssh'
# row: 685 col: 2 : 'Fantasy,Kids' changed to 'nnttaazKKess'
# row: 1178 col: 2 : 'Short,Music' changed to 'Whhoouussf'
# row: 665 col: 2 : 'Animation,Short' changed to 'kmmsmhhoo'
# row: 1121 col: 2 : 'Animation,Fantasy,Mystery' changed to 'iiksglnnss,,Kd'
# row: 668 col: 2 : 'Animation,Comedy' changed to 'AAmiikaagooboommeh'
# row: 767 col: 2 : 'Comedy' changed to 'CCoonwdd'
# row: 334 col: 2 : 'Animation' changed to 'Sbmmaakoonn'
# row: 1560 col: 2 : 'Comedy' changed to 'Xooneeu'
# row: 540 col: 2 : 'Drama' changed to 'rraak'
# row: 1263 col: 2 : 'Fantasy,Kids,Magic' changed to 'GaamzhKKiiaagg'
# row: 1100 col: 2 : 'Animation,Sci-Fi' changed to 'Qiinqlnn,,--FFu'
# row: 683 col: 2 : 'Comedy,Historical,Sci-Fi' changed to 'CCoommwh,,YkrtiiccsSSvuo'
# row: 514 col: 2 : 'Demons,Fantasy,Hentai,Supernatural' changed to 'Sklagsssyy,,Jeebyseeaagjeaak'
# row: 74 col: 2 : 'Short,Drama,Thriller' changed to 'yrrr,,DDtnTThhrrkkkrr'
# row: 761 col: 2 : 'Hentai,Yaoi' changed to 'eegs,,aa'
# row: 1488 col: 2 : 'Comedy,Sci-Fi' changed to 'CCooneeddu,,ccok'
# row: 1305 col: 2 : 'Animation,Action,Comedy,Sci-Fi' changed to 'kkqropnnSiinn,,Foommu,,SSvoFFo'
# row: 720 col: 2 : 'Adventure,Sports' changed to 'AAddeemyytwoe'
# row: 14 col: 2 : 'Animation,Adventure,Fantasy,Romance' changed to 'nnaagol,,AAgeeyuuee,,DysssyyElnnnd'
# row: 651 col: 2 : 'Animation' changed to 'Sqrklnn'
# row: 1134 col: 2 : 'Animation,Short,Fantasy' changed to 'knsiioo,,Ahhtt,,Rmttsh'
# row: 1520 col: 2 : 'Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'ddgwjgirree,,oommddyyWvcchh,,MMdZxiiR,,ppaax'
# row: 29 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'AAbiisiilj,,CC,,baawyyRRoonqbcc'
# row: 1207 col: 2 : 'Drama' changed to 'rrq'
# row: 549 col: 2 : 'Animation,Action,Comedy,Sci-Fi' changed to 'mqttoQfttooCCooddyyu--G'
# row: 795 col: 2 : 'Action,Animation,Sci-Fi' changed to 'SttiinniimmsttiioomZcckFFii'
# row: 945 col: 2 : 'Animation,Short,Action,Sci-Fi' changed to 'AAiinaauoob,,ootttAAfinnZccG'
# row: 1149 col: 2 : 'Drama,Military,Sci-Fi,Space' changed to 'rrnaa,,NllaaeyyZcck--u,,SSppaaccr'
# row: 570 col: 2 : 'Comedy,Military' changed to 'Vmmeiioiiysrryy'
# row: 481 col: 2 : 'Action,Comedy,Sci-Fi,SuperPower' changed to 'AAttuib,,CCnddyyiiRiiDuuppeewwd'
# row: 478 col: 2 : 'Music' changed to 'MMjiicc'
# row: 552 col: 2 : 'Kids' changed to 'ez'
# row: 553 col: 2 : 'Sports' changed to 'SSpprrss'
# row: 863 col: 2 : 'Animation,Short' changed to 'aagAhhler'
# row: 1253 col: 2 : 'Animation,Comedy,Drama' changed to 'nniimmsgiinn,,VkeeFtqmmq'
# row: 100 col: 2 : 'Drama,Historical,Sports' changed to 'eaa,,Jdikcco,,SSorryd'
# row: 539 col: 2 : 'Reality-TV' changed to 'RRllyyy'
# row: 1080 col: 2 : 'Animation' changed to 'biiaattkoo'
# row: 508 col: 2 : 'Comedy,Romance,School,Shoujo,SliceofLife' changed to 'oommeeeoonaanncceeSSccbpoSSpnooSSooocOd'
# row: 605 col: 2 : 'Animation,Adventure,Fantasy' changed to 'AAjaattnn,,sdnnrrd,,Csnnttaaz'
# row: 582 col: 2 : 'Comedy' changed to 'Vmmdx'
# row: 1245 col: 2 : 'Adventure,Comedy,Demons,Fantasy,Magic,Romance,Shounen,Supernatural' changed to 'QfbeennttuuVmmhDDwnoonn,,wh,,KshiiccRRpkaaeejpr,,owerrraa'
# row: 1293 col: 2 : 'Animation,Horror,Music,Thriller' changed to 'AAjommqyooonnHHtoot,,Nuuwuv,,TThhfllrr'
# row: 251 col: 2 : 'Hentai' changed to 'Brttii'
# row: 1113 col: 2 : 'Animation,Comedy,Drama' changed to 'AAjukttonnFoowyyeq'
# row: 1358 col: 2 : 'Adventure,Kids' changed to 'AAvvttwKKiid'
# row: 472 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'nniioob,,V,,rraa,,Fookaamccr'
# row: 610 col: 2 : 'Documentary' changed to 'DDoottrryy'
# row: 1300 col: 2 : 'Hentai,Yuri' changed to 'Yjttk,,uu'
# row: 1220 col: 2 : 'Animation' changed to 'Qjaattiinn'
# row: 656 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'AAmkmmqttooCCoosu,,eqnqEoommaajd'
# row: 770 col: 2 : 'Sci-Fi,Action,Animation' changed to 'AccGiiAAiip,,Qokaattoo'
# row: 989 col: 2 : 'Comedy' changed to 'CCoommryy'
# row: 247 col: 2 : 'Comedy,Drama,Shounen,Sports' changed to 'VooeeddtStqaa,,Ahhoob,,SSorr'
# row: 95 col: 2 : 'Animation,Action,Fantasy' changed to 'AAommykpnnQttiioojFFsnnaassyy'
# row: 494 col: 2 : 'Kids,SliceofLife' changed to 'ddzDllveeffKuff'
# row: 267 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Qdmyrrwgq,,dda'
# row: 469 col: 2 : 'Kids' changed to 'KKiidd'
# row: 912 col: 2 : 'Hentai' changed to 'Jnnaaii'
# row: 1195 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'AAnnqgiiib,,QfttiioomSddttrree,,ookt,,FFaannszhDxii--Dii'
# row: 496 col: 2 : 'Action,Sci-Fi,SuperPower' changed to 'QcciioomD--FFSSppdfPPoowwdrr'
# row: 1246 col: 2 : 'Comedy,Fantasy,Supernatural' changed to 'FmmeedduFFjttaaau,,SSjppjttuuk'
# row: 1397 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Qnnuaaii,,ikeeddtAcc--ii'
# row: 971 col: 2 : 'Animation,Comedy,Drama' changed to 'AAoaar,,kdddyyDDqmmaa'
# row: 891 col: 2 : 'Action,Comedy,Ecchi' changed to 'Qvttiilnnkrx,,ccfk'
# row: 585 col: 2 : 'Animation,Short' changed to 'urb,,tt'
# row: 529 col: 2 : 'Animation' changed to 'nnaaooonn'
# row: 124 col: 2 : 'Comedy,Samurai,School' changed to 'FoonddtZaammrriiZgooo'
# row: 876 col: 2 : 'Short,Romance' changed to 'Ahhoorrr,,Eoommaannccee'
# row: 391 col: 2 : 'Action,Ecchi,Fantasy' changed to 'SccttonnDg,,Gsnnyy'
# row: 1077 col: 2 : 'Animation' changed to 'AAkaattiilnn'
# row: 1000 col: 2 : 'Action,Adventure,Comedy,Fantasy,Mecha,Sci-Fi,Shounen' changed to 'l,,Qxvvmjrree,,CCmmee,,FFsnnttaauK,,ZccDbiinnrb'
# row: 1431 col: 2 : 'Comedy,SliceofLife' changed to 'CCookee,,lliiccoogLLr'
# row: 617 col: 2 : 'Action,Adventure,Horror,Mystery,Sci-Fi,War' changed to 'AAttiii,,vveemttuurrrootooNhssrehcck,,'
# row: 1530 col: 2 : 'Animation,Action,Sci-Fi' changed to 'nniiaattuooj,,ccttnnSSx--G'
# row: 807 col: 2 : 'Hentai' changed to 'Geebyii'
# row: 36 col: 2 : 'Animation,Comedy,Fantasy' changed to 'AAginnXooeyyaaaass'
# row: 1170 col: 2 : 'Hentai' changed to 'HHwbgaaii'
# row: 714 col: 2 : 'Comedy' changed to 'Feesyy'
# row: 1227 col: 2 : 'Fantasy' changed to 'Gaannq'
# row: 45 col: 2 : 'Comedy' changed to 'CCooryy'
# row: 914 col: 2 : 'Action,Fantasy,Supernatural' changed to 'Qxrkoonn,,RjttaasstSSuueerrbrrsll'
# row: 718 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Sddrttitoommwyy,,aaraassu,,KKiie'
# row: 595 col: 2 : 'Drama,Romance' changed to 'qmmq,,Tlkqr'
# row: 1301 col: 2 : 'Historical' changed to 'iisstteoccaall'
# row: 1243 col: 2 : 'Animation' changed to 'AAboqij'
# row: 293 col: 2 : 'Comedy,Fantasy' changed to 'VnyyCttaawyy'
# row: 988 col: 2 : 'Animation,Drama' changed to 'AAnnmmsriiljDDqs'
# row: 1369 col: 2 : 'Drama,SliceofLife' changed to 'Errqnq,,SSllkcceelffLLee'
# row: 793 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'iiiiittiioob,,vveenngrrw,,CCpddaakoyyGrqss'
# row: 412 col: 2 : 'Animation,Action,Adventure' changed to 'nnmmaagooj,,Qvxbeennttf'
# row: 390 col: 2 : 'Adventure' changed to 'Qddvvmw'
# row: 1453 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi,Thriller' changed to 'kmmttnn,,AAccttupb,,xdyuuqkllsnnqyy,,SScckFFiiTThhiieet'
# row: 121 col: 2 : 'Action,Comedy,Drama,MartialArts,SliceofLife,Sports' changed to 'ylmCCoo,,Xs,,rrttiiqAArrz,,llkxrffKiid,,irrw'
# row: 1464 col: 2 : 'Action' changed to 'fyoi'
# row: 1264 col: 2 : 'Comedy,Drama,Romance,School' changed to 'CCook,,EmmFknnrSSk'
# row: 199 col: 2 : 'Drama' changed to 'aamm'
# row: 1057 col: 2 : 'Animation,Action,Fantasy,Sci-Fi' changed to 'Snnuqttiioom,,Soobaamttzu,,WRii'
# row: 223 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'Qsyjfr,,aaaa,,SS--G'
# row: 834 col: 2 : 'Adventure,Kids' changed to 'AAsvveemttirrdd'
# row: 1093 col: 2 : 'Comedy,Drama,SliceofLife' changed to 'CCoommdfErrkaa,,DpffLLiiw'
# row: 374 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'AAttiiooQfvveeyuurr,,Nwccys,,SSvo--k'
# row: 205 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'AAmkaaiioo,,ccttoo,,Vddu,,snntttRRiaajccw'
# row: 1514 col: 2 : 'Comedy' changed to 'ieedd'
# row: 1468 col: 2 : 'Adventure,Kids' changed to 'vvdmuuteeMud'
# row: 46 col: 2 : 'Animation,Family,Drama' changed to 'nniiksttiii,,RqyyXeaamms'
# row: 1276 col: 2 : 'Animation,Action,Adventure,Comedy,Crime' changed to 'nnaann,,Qvttnn,,Qsvvrttuurrwmmddu,,eee'
# row: 1368 col: 2 : 'Action,Drama,Fantasy,Horror,Mystery,Sci-Fi' changed to 'onn,,Fqns,,qnnaah,,HHleKttteef,,fo--FFii'
# row: 567 col: 2 : 'Music' changed to 'w'
# row: 691 col: 2 : 'Drama,Kids' changed to 'DDeaanq,,Low'
# row: 616 col: 2 : 'Comedy' changed to 'Xddh'
# row: 599 col: 2 : 'Action,Adventure,Sci-Fi' changed to 'Qccttb,,AAddeejttrr,,xoFFk'
# row: 1003 col: 2 : 'Hentai' changed to 'HHwmttii'
# row: 977 col: 2 : 'Adventure,Fantasy,Kids,Magic' changed to 'AAxvvwnnttyrrr,,Gnnsayy,,Mddsv'
# row: 1026 col: 2 : 'Adventure,Comedy,Magic,Shounen,Supernatural' changed to 'AAsgrnngee,,paaccSSlimppdbrraao'
# row: 43 col: 2 : 'Romance,School,Shoujo' changed to 'pkb,,vpkDhhpkoo'
# row: 1400 col: 2 : 'Animation,Adventure,Comedy,Fantasy' changed to 'AAmnlbsyuurrw,,XoommFFaattz'
# row: 1284 col: 2 : 'Comedy,School,SliceofLife' changed to 'FmmrsyySSvDouxeeooffLLkw'
# row: 1378 col: 2 : 'SliceofLife,Supernatural' changed to 'llvcoffee,,Duuppfnnsgyeq'
# row: 135 col: 2 : 'Animation,Drama' changed to 'nnonsttooomtaa'
# row: 480 col: 2 : 'Hentai' changed to 'Gjaaii'
# row: 885 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Thriller' changed to 'Snniittpnn,,AAxgnnSgeennjrrw,,Gmmot,,aanngaaYbrriillllwe'
# row: 1346 col: 2 : 'Action,Fantasy,Mecha,Military,Shounen' changed to 'Qccttnnbttdyy,,MMjaa,,ooiittaath,,SSypuunneenn'
# row: 1023 col: 2 : 'Supernatural' changed to 'SSuupptnnaae'
# row: 828 col: 2 : 'Comedy,Drama,Police,Romance' changed to 'ookees,,aa,,oiix,,Tooee'
# row: 2 col: 2 : 'Comedy,Historical,Shounen' changed to 'CCooeeyy,,HHiidoofiiccoSShhijnneenn'
# row: 875 col: 2 : 'Action,Adventure,Demons,Game,Shounen' changed to 'AAvttum,,Ssvvb,,Frnlnn,,mmdSShhlmeenn'
# row: 139 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'oorxtlmmsnnccee,,WoooAhhpuuoo'
# row: 359 col: 2 : 'Action' changed to 'ccooonn'
# row: 191 col: 2 : 'Drama,Kids' changed to 'rrmmaaoddd'
# row: 407 col: 2 : 'Comedy,Seinen' changed to 'Fdd,,SSeeiiee'
# row: 598 col: 2 : 'Animation,Short' changed to 'AAmmaaim,,ig'
# row: 1104 col: 2 : 'Action,Drama,Mecha,Military,Sci-Fi' changed to 'Snn,,DDqmmaaMMxgqNullttaarrvo--FFo'
# row: 999 col: 2 : 'Comedy,Drama,Romance,Sci-Fi,SliceofLife' changed to 'CCooeeXfaammoommaajveeSSxR,,Wkkxooffiiffee'
# row: 623 col: 2 : 'Animation,Action,Sci-Fi' changed to 'AAbiinqgpnnSvoo,,SSccuCo'
# row: 1285 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'ejttrVmmeeddyy,,Dmttu,,Io'
# row: 434 col: 2 : 'Game,Shounen' changed to 'Heenneenn'
# row: 1111 col: 2 : 'Comedy,Kids,SliceofLife' changed to 'ldd,,ossllcceeKiiffd'
# row: 1235 col: 2 : 'Drama,Fantasy,Harem,Romance,Shoujo' changed to 'XaammFFaannqtrrmm,,oommaann,,Doojj'
# row: 1536 col: 2 : 'Comedy' changed to 'ieeyy'
# row: 1555 col: 2 : 'Animation,Adventure,Drama,Fantasy' changed to 'AAnnokkimddeegtee,,DDrrqmmsFFaabttaat'
# row: 1204 col: 2 : 'Animation,Sci-Fi' changed to 'Qnaann,,Zv--C'
# row: 1116 col: 2 : 'Adventure,Comedy,Kids' changed to 'ddeetttdCCkrxKKz'
# row: 1030 col: 2 : 'Comedy,School,Shounen,Supernatural' changed to 'mmsyyccypooo,,hhjrnn,,Duuppeennaattfk'
# row: 1024 col: 2 : 'Animation,Action,Adventure,Family,Mystery,Thriller' changed to 'Qbmmtt,,AAfttiipb,,xvvrnnttyw,,qiikyyKwfyyTTrroorrr'
# row: 593 col: 2 : 'Animation,Adventure' changed to 'Qb,,AAddgeennttjtee'
# row: 1595 col: 2 : 'Drama,Musical' changed to 'Stk,,MMwvaao'
# row: 1371 col: 2 : 'Comedy,Magic,Shoujo,SliceofLife' changed to 'CCikddt,,Ncc,,ZhhuuuiccrlffKiirr'
# row: 671 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'AAknaa,,ookeeyyXsaaWppoorrtt'
# row: 625 col: 2 : 'Animation' changed to 'Siikqttoom'
# row: 1548 col: 2 : 'Animation,Action,Drama' changed to 'AAnqkoonn,,QxrkoobEekaa'
# row: 62 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi' changed to 'AAjkriil,,Sccpj,,DDns,,RRoommbcc,,ZccoFFu'
# row: 1042 col: 2 : 'Animation' changed to 'nnnttkl'
# row: 647 col: 2 : 'Adventure,Fantasy,Horror,Magic,Supernatural' changed to 'AAddceebuufr,,DmaassHHooetifMMaahufyeerrnnaattuuqk'
# row: 1101 col: 2 : 'Hentai' changed to 'HHdbyqii'
# row: 887 col: 2 : 'Kids' changed to 'Mddss'
# row: 573 col: 2 : 'Comedy' changed to 'Fook'
# row: 31 col: 2 : 'Fantasy' changed to 'snnttsyy'
# row: 1004 col: 2 : 'Animation,Short,Action,Drama,Fantasy,Romance' changed to 'AAoaattigttScckl,,DDtqmms,,nnssh,,RRnbx'
# row: 1007 col: 2 : 'Comedy,Sci-Fi' changed to 'CCimmeeh,,Accu--k'
# row: 258 col: 2 : 'Comedy,Parody,Sci-Fi' changed to 'CCikeee,,aaddu,,WiiFFii'
# row: 551 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'Qkiii,,cc,,FookeetFFaannqdyy'
# row: 1180 col: 2 : 'Drama,Psychological,Seinen,Thriller' changed to 'EfqaaPPyyvooiicck,,SSeeiijeennYtullll'
# row: 130 col: 2 : 'Animation,Comedy,Drama' changed to 'AAiiaariii,,CCmmeehDDaammaa'
# row: 245 col: 2 : 'Action,Drama,Western' changed to 'viioo,,saawsstteerr'
# row: 809 col: 2 : 'Animation,Action,Drama,Fantasy' changed to 'Qmmmsiii,,SriinnfaaqFFqmrqah'
# row: 3 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'AAsceejyrreeoommeeddyytrdrryyOoollxSSd'
# row: 394 col: 2 : 'Hentai' changed to 'HHm'
# row: 1274 col: 2 : 'Action' changed to 'AAcciioonn'
# row: 259 col: 2 : 'Animation,Drama,History,Romance' changed to 'Qnnkmmaauooj,,eqns,,HHssgootElnnxd'
# row: 785 col: 2 : 'Hentai' changed to 'Jnnrk'
# row: 216 col: 2 : 'Adventure,Sci-Fi' changed to 'AAceennyrrd,,SSvii--ii'
# row: 871 col: 2 : 'Drama,Historical' changed to 'rraammaaHHssttirrk'
# row: 611 col: 2 : 'Comedy' changed to 'nwyy'
# row: 1140 col: 2 : 'Kids' changed to 'KKkddz'
# row: 1185 col: 2 : 'Animation,Comedy,Drama' changed to 'SnnonaattiiXoowdd,,Stn'
# row: 1383 col: 2 : 'Romance,School,Shoujo' changed to 'lkmxee,,SScchhpillSSjuui'
# row: 1143 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'ddvvmttdXinddlldoodogd'
# row: 843 col: 2 : 'Short,Family,Animation,Fantasy' changed to 'Aprr,,qno,,Smknsttulnn,,Gsttaad'
# row: 336 col: 2 : 'Kids,Music' changed to 'KKy'
# row: 275 col: 2 : 'Animation' changed to 'kyiilm'
# row: 1120 col: 2 : 'Comedy' changed to 'ookrfh'
# row: 960 col: 2 : 'Comedy,SliceofLife' changed to 'eeddyySSkvooffLLee'
# row: 470 col: 2 : 'Hentai' changed to 'Ywbttaak'
# row: 702 col: 2 : 'Animation,Short,Action,Adventure,Drama,Fantasy,Sci-Fi' changed to 'QnnommaaguoobAooSfynnQbbyuuteeDDaaqCjrqwyyZvoFFii'
# row: 694 col: 2 : 'Animation,Drama,Horror' changed to 'AAnnksiii,,rrssf'
# row: 799 col: 2 : 'Animation,Family,Sci-Fi' changed to 'iinnn,,Gqnokii--G'
# row: 18 col: 2 : 'Drama,Kids' changed to 'rraammqKKo'
# row: 1351 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'AAmmoooboommwddyykFFk'
# row: 183 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'VlmmwxRRimmbccocceeooffKrw'
# row: 1239 col: 2 : 'Documentary,Music' changed to 'DDooccuummmaarrt,,MMdo'
# row: 516 col: 2 : 'Action,Adventure,Animation,Sci-Fi,Thriller' changed to 'ttiioojAAxwjruutw,,AAbkqriiibDccuFFu,,Giillkeee'
# row: 272 col: 2 : 'Comedy,Romance,School,Seinen,SliceofLife' changed to 'mmeeElmmaamv,,ccoooollZeenneennDlliiccriff'
# row: 438 col: 2 : 'Drama,Mystery' changed to 'FaammKee'
# row: 487 col: 2 : 'Animation' changed to 'AAiikj'
# row: 1427 col: 2 : 'Animation,Drama,Sport' changed to 'nnummaariioo,,rraamm,,r'
# row: 242 col: 2 : 'Comedy,Talk-Show' changed to 'oommdt,,sllgoos'
# row: 1417 col: 2 : 'Family' changed to 'Gaammllu'
# row: 1315 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'AAnnukaattnnfulnn,,Qnnuurrw,,nnssh'
# row: 204 col: 2 : 'Adventure' changed to 'AAwyi'
# row: 842 col: 2 : 'Comedy,Drama,Romance,Shounen' changed to 'CCikrrskRRooaannxee,,iybnn'
# row: 93 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'QummaattkibyiioojSvvrnnuurrFFnnyaad'
# row: 524 col: 2 : 'Adventure,Mecha,Sci-Fi,Shounen' changed to 'ddmuurree,,rfq,,Dxuk,,SShhooiwj'
# row: 1571 col: 2 : 'Action,Adventure,Comedy,Drama,Romance,Sci-Fi' changed to 'Qttiinn,,AAddrnnttrrwCCooddFrrsnqRRpqnnveeWvuFF'
# row: 1502 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Sci-Fi' changed to 'muaariicckoo,,lmmhrrkRaajaassyy,,'
# row: 986 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Romance,Thriller' changed to 'AAkqui,,QccttunnCClkddd,,XrrsnaannttqzTlmmaarTTbrrkll'
# row: 705 col: 2 : 'Short,Comedy,Fantasy,Romance' changed to 'hh,,oowyy,,Daannrw,,ooknnw'
# row: 1287 col: 2 : 'Animation' changed to 'AAnnommttiiinn'
# row: 537 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Sci-Fi' changed to 'kkttiiooAAxeennuuee,,Xtaanq,,aakyyRaannrssyy,,SSf--FF'
# row: 783 col: 2 : 'Documentary,Comedy,History,War' changed to 'Svuueennsrru,,CClddu,,kzrrhWWaa'
# row: 1551 col: 2 : 'Comedy,Fantasy' changed to 'oommeeh,,aabt'
# row: 69 col: 2 : 'Fantasy,Magic,Shounen' changed to 'smyqzyy,,MMsiicc,,bijd'
# row: 559 col: 2 : 'Comedy,Fantasy,Kids,Supernatural,Vampire' changed to 'CCmmxtFFnnyaad,,KKxa,,DuuownnaagjrrGaammod'
# row: 430 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'SnnommaattjSvriiooFpmmdyy,,GnnttqtFpmmmccd'
# row: 386 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'AAttoovvr,,Raajyaayy,,SSy'
# row: 805 col: 2 : 'Animation,Action,Drama' changed to 'Siislb,,SxunnDDmmaa'
# row: 1132 col: 2 : 'Kids' changed to 'KKiiw'
# row: 499 col: 2 : 'Animation,Comedy' changed to 'AAmmsiipnn,,pneefyy'
# row: 1061 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'SmmmyjFieeft,,DrssFmmqxd'
# row: 225 col: 2 : 'Animation,Comedy' changed to 'Sbaagiiij,,CCleeddyy'
# row: 1497 col: 2 : 'Animation,Adventure,Fantasy' changed to 'AAnnqttinn,,vveettuurreeDsgwh'
# row: 388 col: 2 : 'Animation,Action,Crime,Mystery' changed to 'Qmiikroom,,AAfttoofiimmw,,Nhttrr'
# row: 309 col: 2 : 'Animation,Comedy,Romance' changed to 'AAnnqgiilCCoox,,RRinaabccd'
# row: 9 col: 2 : 'Action' changed to 'Qinn'
# row: 850 col: 2 : 'Comedy,School,Sports' changed to 'CCoonyy,,SShhiSSpptr'
# row: 1256 col: 2 : 'Hentai' changed to 'Ynnttk'
# row: 66 col: 2 : 'Animation,Adventure,Family,Sci-Fi' changed to 'mknaattiioosvveebw,,noll,,ccFFii'
# row: 608 col: 2 : 'Comedy,Sports' changed to 'Fkdyy,,pp'
# row: 1086 col: 2 : 'Comedy,Police' changed to 'CCpksOlliicc'
# row: 941 col: 2 : 'Hentai' changed to 'Yr'
# row: 742 col: 2 : 'Crime' changed to 'rriikee'
# row: 1357 col: 2 : 'Comedy,Ecchi' changed to 'Vooeeddt,,EEfccyo'
# row: 1413 col: 2 : 'Kids,Music' changed to 'KKiiddauuwkcc'
# row: 1444 col: 2 : 'Action,Mystery' changed to 'AAccttiioonn,,ssgee'
# row: 7 col: 2 : 'Adventure,Sci-Fi' changed to 'nnuueeSSii--k'
# row: 772 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'XooeeddyyEEbkfk,,lsnn'
# row: 397 col: 2 : 'Animation,Family,Adventure,Fantasy' changed to 'AAmmrinnDaammkllvveenngyrrw,,FFnnqssyy'
# row: 65 col: 2 : 'Animation,Short,Action,Fantasy' changed to 'nnaam,,Wyoorry,,Sccriioom,,qwyy'
# row: 1396 col: 2 : 'Action,Comedy,Mecha' changed to 'xyulnnkeyyKrccbaa'
# row: 1208 col: 2 : 'Drama,Seinen,SliceofLife' changed to 'EfmmqdodjZkiiccooffff'
# row: 1526 col: 2 : 'Historical,Romance,Shoujo,Supernatural' changed to 'Joaglrrkk,,Fnsd,,Zooyhooeemqttk'
# row: 285 col: 2 : 'Animation,Action,Music,Romance,Sci-Fi' changed to 'QjmmqttklmAAxm,,KissuccmmsAcc--ii'
# row: 948 col: 2 : 'Action,Kids' changed to 'ccopbJxa'
# row: 85 col: 2 : 'Comedy,Fantasy,Music' changed to 'CClkeedd,,nnaayy,,wii'
# row: 155 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'CCpeeccjii,,HHrkoonqjf'
# row: 23 col: 2 : 'Drama,Sports' changed to 'XrraaSSotttw'
# row: 1375 col: 2 : 'Action,Drama' changed to 'Qxyuoom,,DDrrq'
# row: 1535 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Siimmqkinniwdd,,SSccuFF'
# row: 823 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'AAxnn,,ddvvwjyuuee,,bttz,,SSgoouunnee'
# row: 489 col: 2 : 'Comedy' changed to 'Xpxt'
# row: 541 col: 2 : 'Comedy,Ecchi,Kids,School,Shounen,SliceofLife' changed to 'CCookeh,,RccfbLoeSSxoolnneennSSodffiigee'
# row: 966 col: 2 : 'Comedy' changed to 'CCikweyy'
# row: 940 col: 2 : 'Animation,Action,Horror,Mystery,Sci-Fi' changed to 'Siinkl,,AAcciiJltoo,,Kurrryy,,A--Dii'
# row: 814 col: 2 : 'Short,Drama,Sci-Fi' changed to 'hhoorrg,,EaaSSii--FF'
# row: 1321 col: 2 : 'Animation,Adventure,Comedy,Drama,Fantasy' changed to 'nniittiipnn,,QsjttuueeVpmmeefh,,FqRqbttssyy'
# row: 762 col: 2 : 'Comedy,Sports' changed to 'XpkrddDtttd'
# row: 257 col: 2 : 'Animation,Comedy' changed to 'unsttunn,,Xpkeedd'
# row: 37 col: 2 : 'Animation,Romance' changed to 'mkmmtt,,RRsm'
# row: 739 col: 2 : 'Drama' changed to 'Errsnq'
# row: 1506 col: 2 : 'Animation,Comedy,Music' changed to 'AAiinsoonn,,CCne,,MMuusscc'
# row: 1017 col: 2 : 'Animation,Drama' changed to 'Qnniimmsyoom,,DDrrskq'
# row: 1370 col: 2 : 'Comedy,Music' changed to 'CCimmeedduMMjx'
# row: 1210 col: 2 : 'Animation,Action,Horror,Romance' changed to 'Skaagiii,,AAvttpmHHirreiFmmaanncc'
# row: 1467 col: 2 : 'Adventure' changed to 'Qsruue'
# row: 564 col: 2 : 'Drama' changed to 'tsmm'
# row: 649 col: 2 : 'Animation' changed to 'Qbknqttiib'
# row: 211 col: 2 : 'Short,Mystery,Romance' changed to 'SSjiy,,eeyyRRksnnvd'
# row: 82 col: 2 : 'Animation,Action,Comedy' changed to 'miiksttooo,,Svttiioom,,Frfh'
# row: 1559 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'AAnniimmttoinn,,CCee,,rrmmq,,Foosnnv'
# row: 820 col: 2 : 'Animation,Action,Comedy,Crime,Drama' changed to 'AAnniimmsknnAAiioonnXimmsyy,,eiimmr,,DDrrkaa'
# row: 916 col: 2 : 'Action,Mecha,Sci-Fi' changed to 'ttul,,dvgsSSccu--FFo'
# row: 997 col: 2 : 'Adventure,Drama,Fantasy,Horror,Shounen,Supernatural,Vampire' changed to 'AAebdmttuutdDDrrskgsayy,,YfprrSSymdnnSSjgrraaoGniifr'
# row: 1460 col: 2 : 'Action,Adventure,Comedy,Fantasy,Magic' changed to 'ttiipAAddgwr,,mmeeddtaannyayy,,Naakf'
# row: 990 col: 2 : 'Music' changed to 'uu'
# row: 998 col: 2 : 'Animation,Short' changed to 'AAnniinaapnn,,lf'
# row: 1152 col: 2 : 'Drama,Music,SliceofLife' changed to 'DDn,,KjiifodooffOee'
# row: 465 col: 2 : 'Action,ShounenAi,Supernatural' changed to 'AAccttkiSShhljjnnAAii,,Wuuppdjyjrraa'
# row: 1458 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Qiimmaagiioonn,,CCookwddyyvCii'
# row: 967 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Smiittiioom,,VimmeeddtccFF'
# row: 313 col: 2 : 'Animation,Short' changed to 'iiaattiiley'
# row: 1312 col: 2 : 'Animation,Short' changed to 'Sjummaattoij,,SSyoorrtt'
# row: 906 col: 2 : 'Comedy,Fantasy,Romance' changed to 'CClneetysyy,,RRmmd'
# row: 1191 col: 2 : 'Comedy,Drama,Romance' changed to 'VimmeeddyyXrraammq,,paannf'
# row: 911 col: 2 : 'Adventure,Drama,Historical,Romance' changed to 'AAeeji,,SeqmmaaJussyootaaoTlmmjcc'
# row: 40 col: 2 : 'Action,Adventure,Mecha' changed to 'fttu,,AAeettd,,Nwbs'
# row: 458 col: 2 : 'Comedy,Crime,Drama' changed to 'immeeddFiiee,,rrkq'
# row: 1277 col: 2 : 'Animation,Action,Crime,Sci-Fi' changed to 'AAmkaattoccoob,,eoSSiiRii'
# row: 436 col: 2 : 'Biography,Drama,Music' changed to 'Hiiggfobyy,,DDfqmmsNjcc'
# row: 1434 col: 2 : 'Drama' changed to 'Etkaa'
# row: 902 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi,Thriller' changed to 'QbiiaattlnnAAttiiDDmmaasnnccrSScc--CiiRtollde'
# row: 77 col: 2 : 'Animation,Action,Comedy,Drama' changed to 'nniimmaattpbttj,,CClkwddtDDrraamms'
# row: 387 col: 2 : 'Animation,Short,Sci-Fi' changed to 'iimmp,,AiuDii'
# row: 1115 col: 2 : 'Action,Animation,Sci-Fi' changed to 'AAttii,,AAiiaaulnn,,k'
# row: 1507 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'ddnntty,,pneeddhFFaasssu'
# row: 59 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'AAbkaattoonn,,ccij,,AAddgjgj,,SSccu'
# row: 865 col: 2 : 'Animation,Short,Comedy' changed to 'miiniSSettCCoondd'
# row: 983 col: 2 : 'Drama,Romance' changed to 'eaa,,kaajxd'
# row: 640 col: 2 : 'Adventure,Fantasy,Historical' changed to 'vvryd,,aattaassuYozttoofuccaao'
# row: 157 col: 2 : 'Fantasy,Magic' changed to 'FFaabttaasshMMaaggii'
# row: 147 col: 2 : 'Comedy' changed to 'CClkeeyy'
# row: 341 col: 2 : 'Action,Animation,Sci-Fi' changed to 'vttooAAbiikr,,A--FFk'
# row: 851 col: 2 : 'Animation,Comedy,Fantasy' changed to 'AAiikaattulVndeyy,,syss'
# row: 410 col: 2 : 'Hentai' changed to 'HHeettqk'
# row: 1373 col: 2 : 'Animation,Adventure,Comedy,Family' changed to 'AAnnknsttiioom,,AAddgdmit,,FieesyyDaakot'
# row: 969 col: 2 : 'Action,Sci-Fi,Animation,Fantasy,Adventure,Drama' changed to 'AAccttiiib,,SScc--ii,,jnqttkooGbaahSgwmrer,,fqks'
# row: 1199 col: 2 : 'Short' changed to 'hhrr'
# row: 1325 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Magic' changed to 'QddvveeruueeeXlmmeefyysnnraawKKiiddsssvkcc'
# row: 1329 col: 2 : 'Horror,Sci-Fi' changed to 'HHoorrrr,,SS--FFu'
# row: 1565 col: 2 : 'Hentai,School' changed to 'eett,,Alooll'
# row: 230 col: 2 : 'Kids' changed to 'KKdd'
# row: 1461 col: 2 : 'Comedy,School,Shounen,Sports' changed to 'mmwdduWl,,SShhooyeennolett'
# row: 1549 col: 2 : 'Animation,Comedy,Drama,Sci-Fi' changed to 'AAmmaattonnXooneerrsmmaax--Rii'
# row: 1292 col: 2 : 'Hentai' changed to 'HHeenntt'
# row: 861 col: 2 : 'Romance' changed to 'Flkmv'
# row: 91 col: 2 : 'Hentai' changed to 'Bjttaau'
# row: 1438 col: 2 : 'Animation,Comedy' changed to 'AAiittooid'
# row: 57 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'AAdnnr,,CCimmehqnnttqss'
# row: 1541 col: 2 : 'Comedy' changed to 'CCimmws'
# row: 1216 col: 2 : 'Short' changed to 'hh'
# row: 120 col: 2 : 'Comedy' changed to 'pmmddt'
# row: 839 col: 2 : 'Animation,Action,Adventure,Crime' changed to 'Qnnriiinnccttij,,ddvv,,Xrriiee'
# row: 294 col: 2 : 'Comedy,Ecchi' changed to 'mmyyj'
# row: 627 col: 2 : 'Short,Action,Sport' changed to 'hhifg,,Sccyooonno'
# row: 10 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'mmaariiooj,,ttkoobAAxbnnttfee,,SSii'
# row: 1094 col: 2 : 'Comedy,Historical' changed to 'neefyy,,Jkzrrocco'
# row: 169 col: 2 : 'Animation,Comedy' changed to 'AAjiimmsttoomXeexyy'
# row: 1422 col: 2 : 'Action,Horror,Sci-Fi,Thriller' changed to 'SccttiBfi,,SSii--Cu,,TThhiillllf'
# row: 398 col: 2 : 'Comedy' changed to 'CCpkyy'
# row: 791 col: 2 : 'Hentai,School' changed to 'wbrZvj'
# row: 612 col: 2 : 'Animation' changed to 'AAnnuaaiiib'
# row: 1290 col: 2 : 'Animation' changed to 'AAaattiib'
# row: 1099 col: 2 : 'Hentai' changed to 'HHmttaau'
# row: 1069 col: 2 : 'Action,Psychological,Shounen,Supernatural,Thriller' changed to 'AAiilOccbpggvaall,,hhuujeenniorttuusk,,Gtlllle'
# row: 380 col: 2 : 'Animation,Short,Action,War' changed to 'AAbnaarpb,,Ahhoorrttgprr'
# row: 1040 col: 2 : 'Drama,Mystery,Romance,Thriller' changed to 'DDtmms,,KyyyweyyRReeGrroo'
# row: 201 col: 2 : 'Documentary' changed to 'DDpuummnnyqrryy'
# row: 1317 col: 2 : 'Comedy,Police' changed to 'pmmrhuxd'
# row: 360 col: 2 : 'Fantasy' changed to 'syss'
# row: 1279 col: 2 : 'Animation,Comedy' changed to 'QiiaaiioonnVpnddd'
# row: 172 col: 2 : 'Adventure,Comedy,Fantasy,Shounen' changed to 'AAcmCCpFFaassuSSbjnn'
# row: 167 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Siittinn,,iweyyq'
# row: 119 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'AAbaattupm,,Vooee,,tqmmaaksnnccee'
# row: 327 col: 2 : 'Drama,Romance,Yaoi' changed to 'XtnFlsf,,ql'
# row: 88 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'nnnttiinnxonn,,grbttrrRaattaad'
# row: 1462 col: 2 : 'Drama,Romance' changed to 'tnaalnnccee'
# row: 1119 col: 2 : 'Music' changed to 'uu'
# row: 609 col: 2 : 'Animation,Fantasy,Horror' changed to 'bqttklnnDbywuGft'
# row: 1236 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'VoodddhkFF,,osxee'
# row: 1544 col: 2 : 'Animation,Drama,Music' changed to 'AAnniimmonnDDeaammaaKjiicc'
# row: 349 col: 2 : 'Animation' changed to 'AAmiikaariipj'
# row: 709 col: 2 : 'Comedy,Romance,School,Shounen,Supernatural' changed to 'mmrddh,,TisDhhilliuunnmppennjfsll'
# row: 635 col: 2 : 'Adventure,Animation' changed to 'AAevvwirree,,AAnniiyoonn'
# row: 678 col: 2 : 'Animation' changed to 'mommaaiilj'
# row: 699 col: 2 : 'Animation,Adventure,Crime,Mystery' changed to 'QjiikttbScnngrrr,,FunMMhzdrryy'
# row: 329 col: 2 : 'Animation,Action,Fantasy,Mystery' changed to 'AAonaattoonnSfttFFsbttsssMMyysseeyy'
# row: 895 col: 2 : 'Adventure' changed to 'Qdddnnjw'
# row: 1556 col: 2 : 'Documentary' changed to 'Sooccuunnnttrr'
# row: 1166 col: 2 : 'Documentary' changed to 'lynwnnqyy'
# row: 1593 col: 2 : 'Animation,Comedy' changed to 'nnummqroib,,CClmmwddyy'
# row: 186 col: 2 : 'Comedy' changed to 'CCookddu'
# row: 1067 col: 2 : 'Animation,Comedy' changed to 'Qunsooomiku'
# row: 802 col: 2 : 'Adventure,Kids' changed to 'AAddbdKKos'
# row: 325 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Romance' changed to 'AAopnn,,fiib,,AAsnnttirreeFooeeDDaaaa,,nnaad,,immnn'
# row: 112 col: 2 : 'Hentai' changed to 'ttqo'
# row: 669 col: 2 : 'Fantasy,Kids' changed to 'FFttaawtKKxd'
# row: 1532 col: 2 : 'Harem,Hentai' changed to 'aaeeekGwnnttaaii'
# row: 1228 col: 2 : 'Hentai,School' changed to 'rmttqiiAcchhooo'
# row: 1528 col: 2 : 'Animation,Adventure,Drama,Fantasy,Romance' changed to 'AAnnknaaiiooQddwbgw,,fsmmq,,FFqttaaRRinqnnf'
# row: 749 col: 2 : 'Drama,Music,Thriller' changed to 'DDeaaKuuu,,gelllleet'
# row: 179 col: 2 : 'Comedy,Kids' changed to 'CCmmeeddyyKKx'
# row: 197 col: 2 : 'Animation' changed to 'Smmsttii'
# row: 457 col: 2 : 'Adventure' changed to 'Sddgytee'
# row: 637 col: 2 : 'Hentai' changed to 'Yee'
# row: 415 col: 2 : 'Hentai' changed to 'eett'
# row: 738 col: 2 : 'Animation,Comedy' changed to 'AAbmmaalm,,Vpmmeedd'
# row: 1029 col: 2 : 'Historical,Mystery,Shounen' changed to 'wttrroxll,,yygeerr,,SSgoouumee'
# row: 1328 col: 2 : 'Adventure,Historical,Sci-Fi' changed to 'AAeerrJiissttocc,,cc--FFii'
# row: 289 col: 2 : 'Animation' changed to 'AAnniikqyiiinn'
# row: 485 col: 2 : 'Animation,Adventure,Crime,Mystery' changed to 'nnnsttQddvvdttuuteeVtiinMMrwrrh'
# row: 339 col: 2 : 'Drama,Music' changed to 'DDrraaMMax'
# row: 28 col: 2 : 'Action,Mecha,Sci-Fi,Shounen' changed to 'Qccttklj,,jaaii--FFii,,Dooinneenn'
# row: 1412 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'Qccub,,ddvvnnrrrdCCmmeehFFsaawiiddss'
# row: 852 col: 2 : 'Comedy,Fantasy,Kids' changed to 'CCoondd,,mttaassyy,,Jo'
# row: 282 col: 2 : 'Animation' changed to 'nniimmaaiioo'
# row: 350 col: 2 : 'Comedy,School' changed to 'CCmmDip'
# row: 1327 col: 2 : 'Drama,Family' changed to 'DDrraaGkullt'
# row: 417 col: 2 : 'Animation' changed to 'AAnnuttiioo'
# row: 534 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'QjiiqyoonnZtttVpdyycciiCii'
# row: 613 col: 2 : 'Animation,Family,Fantasy,Music' changed to 'sgiinn,,Gkiiu,,aajgsyy,,Kcc'
# row: 1313 col: 2 : 'Animation,Sci-Fi' changed to 'Sommqttuoo,,SS--FFii'
# row: 866 col: 2 : 'Action,Comedy,Fantasy,Magic,Mecha,Sci-Fi,Shounen' changed to 'rXkFFjaasst,,MMsKrccaa,,SSf--,,pyb'
# row: 693 col: 2 : 'Comedy,Horror' changed to 'FpmmetYel'
# row: 1590 col: 2 : 'Animation' changed to 'Qnnkii'
# row: 681 col: 2 : 'Drama' changed to 'DDrrqq'
# row: 535 col: 2 : 'Animation' changed to 'nngoonn'
# row: 292 col: 2 : 'Adventure,Fantasy,Sci-Fi,Shounen' changed to 'evveejuutFFsmttsDkhhpbeenn'
# row: 343 col: 2 : 'Documentary,Biography,History,News' changed to 'DDxjeennystyy,,BBoovepphh,,Yssoof,,e'
# row: 1487 col: 2 : 'Hentai' changed to 'Yraa'
# row: 262 col: 2 : 'Animation,Adventure,Family,Fantasy,Mystery' changed to 'Ssiioonn,,vvttirrr,,FFaakoyyFFaaydNsstteeh'
# row: 17 col: 2 : 'School,SliceofLife' changed to 'SSjSSkiixdooffOiicee'
# row: 806 col: 2 : 'Action,Drama,Mecha,Military,School,Supernatural' changed to 'Sccyiiinn,,DDmmsKeehhaaiig,,Dool,,SSppeeeqrirrq'
# row: 491 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'SbkmmqkbXmmuEaammaaDaabstTookaaccd'
# row: 324 col: 2 : 'Historical' changed to 'Gdylrrkccll'
# row: 1469 col: 2 : 'Hentai' changed to 'HHttaak'
# row: 1197 col: 2 : 'Short' changed to 'Whhrrtt'
# row: 1470 col: 2 : 'Historical,Kids' changed to 'ktteoccsll,,iidd'
# row: 1148 col: 2 : 'Action,Comedy,Demons,Fantasy,Historical,Shounen,Supernatural' changed to 'QccttonnoonfeennnssFFsjqz,,iittooeuxsllhhoouumdnn,,uuowrrnnqttyll'
# row: 1043 col: 2 : 'Adventure,Drama' changed to 'Qryy,,naa'
# row: 1436 col: 2 : 'Animation' changed to 'AAuqttlb'
# row: 855 col: 2 : 'Animation' changed to 'Qiiqinn'
# row: 305 col: 2 : 'Comedy' changed to 'Voommwf'
# row: 177 col: 2 : 'Animation,Comedy,Romance' changed to 'nniiksttooonn,,CCooee,,Eimmnncc'
# row: 114 col: 2 : 'Drama' changed to 'Srrss'
# row: 1032 col: 2 : 'Musical' changed to 'Niccaa'
# row: 128 col: 2 : 'Action,Horror,Mystery,Seinen,Supernatural' changed to 'SfgubirriMMsseeeyyZkmdm,,SSiwsjtaao'
# row: 110 col: 2 : 'Animation,Comedy' changed to 'qonnoonde'
# row: 1213 col: 2 : 'Animation,Drama,Sport' changed to 'Sjiinaagooonn,,Srrs,,Dppl'
# row: 1421 col: 2 : 'Drama' changed to 'Saaaa'
# row: 905 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'AAnnqgknn,,Drrg,,SccgmAAeeemjrreeFFsttaass'
# row: 67 col: 2 : 'Drama,Romance' changed to 'Faaaa,,RRmmnn'
# row: 774 col: 2 : 'Hentai' changed to 'wnnttsii'
# row: 416 col: 2 : 'Animation,Short,Comedy,Fantasy' changed to 'mujSSgett,,CCookeeddh,,Gttssu'
# row: 1395 col: 2 : 'Comedy' changed to 'Vpf'
# row: 510 col: 2 : 'Animation,Short' changed to 'nnurooo,,oottt'
# row: 149 col: 2 : 'Animation,Comedy,Fantasy' changed to 'mmqppkddyy,,sbaassyy'
# row: 1445 col: 2 : 'Animation,Drama,Romance' changed to 'Qmummaauj,,FrraammqFoommaamv'
# row: 572 col: 2 : 'Fantasy,Mystery' changed to 'bttqsstNhttw'
# row: 19 col: 2 : 'Music' changed to 'MMwucc'
# row: 779 col: 2 : 'Animation,Comedy' changed to 'juksoondddh'
# row: 602 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'svvjyeeVoommdxAvkFFu,,Abljnn'
# row: 864 col: 2 : 'Comedy,Mecha,Police,Sci-Fi' changed to 'Vrddyy,,Nrfgq,,PPkoccw,,R'
# row: 1543 col: 2 : 'Action,Adventure,Historical,Samurai,Seinen' changed to 'Qccttii,,ddrguurree,,iiwttifufSSnuufaaSSkeenn'
# row: 588 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'QxttibCCeyy,,aarrdk,,DcciiFFu,,oomnn,,SSq'
# row: 798 col: 2 : 'Hentai' changed to 'wnnttaao'
# row: 892 col: 2 : 'Comedy,Drama,SliceofLife,Supernatural' changed to 'Vkdd,,rrq,,AkvwoorLLiid,,ppeeeqttiell'
# row: 816 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'AAttuiQcnnyi,,FookeeddhDhhljeenn'
# row: 832 col: 2 : 'Animation,Action,Sport' changed to 'AAnniimmttiinn,,AAcciipmSSolrrr'
# row: 1466 col: 2 : 'Animation,Comedy,Romance' changed to 'nnuaa,,ooeeuToonfw'
# row: 385 col: 2 : 'Animation,Short' changed to 'AAkaayiilnnSSett'
# row: 347 col: 2 : 'Animation,Adventure,Comedy' changed to 'Sjnaagii,,Sxvvmyt,,Fwddh'
# row: 1001 col: 2 : 'Comedy,Fantasy,Kids' changed to 'ddu,,GaagwMuddw'
# row: 838 col: 2 : 'History' changed to 'HHssttoof'
# row: 1127 col: 2 : 'Comedy,Kids' changed to 'XinwKKoddz'
# row: 1181 col: 2 : 'Drama' changed to 'DDk'
# row: 78 col: 2 : 'Drama' changed to 'Saanq'
# row: 39 col: 2 : 'Music' changed to 'yssii'
# row: 1103 col: 2 : 'Animation,Short,Fantasy' changed to 'Sjommruoo,,DhhitttFFmrsyy'
# row: 996 col: 2 : 'Animation,Short,Comedy' changed to 'nnmmttpnnAooenyy'
# row: 1203 col: 2 : 'Action,Mystery,Supernatural,Thriller' changed to 'xyiiimyywdtDoeeaayiohhrrollt'
# row: 1492 col: 2 : 'Action,Demons,Fantasy,Hentai' changed to 'AAcclm,,DDeemmibd,,FFjttdteennttqii'
# row: 544 col: 2 : 'Kids' changed to 'Iiifa'
# row: 1564 col: 2 : 'Sci-Fi,SliceofLife' changed to 'Wccii--FFk,,Allwooriiee'
# row: 620 col: 2 : 'Adventure,Fantasy,Kids,Magic,MartialArts' changed to 'AAnnrj,,CaabysssyyKKuxNaaggu,,Naarrttiiaarr'
# row: 1463 col: 2 : 'Comedy' changed to 'leeyy'
# row: 896 col: 2 : 'Animation,Music' changed to 'AAiiqk,,Niof'
# row: 357 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Magic,SuperPower' changed to 'AAddvveemrrw,,CCpeeyyRsmysshIossNqux,,ioeerrooqee'
# row: 20 col: 2 : 'Action' changed to 'Qccttnn'
# row: 195 col: 2 : 'Animation,Comedy,Drama' changed to 'nniinttuj,,mmyy,,DD'
# row: 1408 col: 2 : 'Action,Comedy,Supernatural' changed to 'SgooomVkee,,SSypprfnnjaa'
# row: 578 col: 2 : 'Short' changed to 'Aboo'
# row: 61 col: 2 : 'Horror' changed to 'irri'
# row: 883 col: 2 : 'Comedy,Ecchi,Romance,School,Seinen,Sports' changed to 'CCoodyycc,,mmsccee,,Zgill,,eeiinnwnnZottss'
# row: 1489 col: 2 : 'Animation,Fantasy' changed to 'Sbiiaattolnnyaadt'
# row: 1049 col: 2 : 'Demons,Hentai' changed to 'DDeenpssYwjttii'
# row: 928 col: 2 : 'Comedy,Kids' changed to 'eedduMiidd'
# row: 1302 col: 2 : 'Comedy' changed to 'oommdd'
# row: 523 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy' changed to 'AAnnmmaaojSttooonn,,AAceennookeeddDDrraammaaaannzh'
# row: 644 col: 2 : 'Short,Comedy' changed to 'DhhiettCCeeh'
# row: 132 col: 2 : 'Animation,Action,Sci-Fi' changed to 'miiqttiinn,,AAccttkoomxii'
# row: 1222 col: 2 : 'Kids' changed to 'KKoddss'
# row: 664 col: 2 : 'Music' changed to 'MMuussux'
# row: 89 col: 2 : 'Short,Drama' changed to 'DgooDDaa'
# row: 503 col: 2 : 'Kids' changed to 'iiddz'
# row: 284 col: 2 : 'Animation' changed to 'AAbkaagoob'
# row: 454 col: 2 : 'Hentai' changed to 'Bdnntt'
# row: 886 col: 2 : 'Animation,Action,Crime,Drama,Thriller' changed to 'AAnnkaayomSoCCtknee,,aa,,Riillllt'
# row: 1027 col: 2 : 'SliceofLife' changed to 'feepo'
# row: 173 col: 2 : 'Animation,Short' changed to 'nniinaakoogie'
# row: 105 col: 2 : 'Short,Adventure,Family' changed to 'Djrrr,,SswuurrFFaammooh'
# row: 222 col: 2 : 'Animation,Action,Sci-Fi' changed to 'AAiimmaaoonnAAttii,,DfR'
# row: 447 col: 2 : 'Fantasy' changed to 'Cswh'
# row: 311 col: 2 : 'Comedy' changed to 'Voommrxh'
# row: 1006 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'AAmmmyAAccttiimSceemiXlhAccii'
# row: 1362 col: 2 : 'Action,Sci-Fi' changed to 'gonnDx--Gii'
# row: 1392 col: 2 : 'Animation,Crime,Horror,Mystery,Thriller' changed to 'naaiioo,,fo,,Gierrooe,,sswyy,,TTbtoee'
# row: 926 col: 2 : 'Kids,Shoujo,Supernatural' changed to 'Joew,,jjjlDoeesyifq'
# row: 166 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Siikqiij,,CCpkdsyySSf--FFii'
# row: 6 col: 2 : 'Action,Comedy,Historical,Samurai,Shounen' changed to 'xttjVpneet,,Yogtiiccsqjrraa,,SShhoonnee'
# row: 621 col: 2 : 'Fantasy,Magic,Shoujo' changed to 'GbttsyyNgguccgpuoo'
# row: 1 col: 2 : 'Action,Sci-Fi' changed to 'QfiiljSScck--o'
# row: 794 col: 2 : 'Animation,Action,Crime,Drama,Horror,Mystery,Thriller' changed to 'Smqyiib,,Qb,,CCrriiee,,DDaammaaooerrsstteefgfeerr'
# row: 566 col: 2 : 'Adventure,Fantasy' changed to 'AAevveennirr,,FFnnttaassu'
# row: 1051 col: 2 : 'Adventure,Comedy,Drama,Mystery,Sci-Fi' changed to 'AAddbmgyXeeyy,,smmaa,,hssttrryySSccRo'
# row: 393 col: 2 : 'Animation,Adventure,Drama,Fantasy' changed to 'AAiisttii,,fgyrreeDDrrqaasttaawyy'
# row: 974 col: 2 : 'Action,Adventure,Fantasy,Game' changed to 'AAccypj,,AAennyrrw,,DqjGGee'
# row: 1206 col: 2 : 'Comedy,Magic,Supernatural' changed to 'XpdddyyMMqggiiippdrrmsguurro'
# row: 1147 col: 2 : 'Hentai' changed to 'rjqo'
# row: 411 col: 2 : 'Talk-Show' changed to 'qoSSgooww'
# row: 677 col: 2 : 'Fantasy,Kids' changed to 'Cqttaayyea'
# row: 1311 col: 2 : 'Action,Comedy,Fantasy,Supernatural' changed to 'AAfjFookddyy,,aajyayy,,Duuobuufll'
# row: 854 col: 2 : 'Animation,Action,Adventure,Fantasy,Horror,Mystery' changed to 'AAkgiij,,Sxttuoonn,,seennyf,,Gnnttaazyy,,JifooeMMhgwt'
# row: 1233 col: 2 : 'Hentai' changed to 'nnaak'
# row: 829 col: 2 : 'Action,Adventure,Mystery,Sci-Fi' changed to 'ccroooj,,AAddwnnttuueeNyyssgeSScc--'
# row: 408 col: 2 : 'Animation,Sci-Fi,Action,Crime,Fantasy,Thriller' changed to 'nnkrub,,cc--FFkQccttpm,,knd,,Daabaadhhtiioorr'
# row: 763 col: 2 : 'Comedy,Fantasy,Kids' changed to 'XoodddhFFsmaass,,Iiif'
# row: 136 col: 2 : 'Fantasy' changed to 'Caabaayy'
# row: 330 col: 2 : 'Hentai' changed to 'baa'
# row: 1167 col: 2 : 'SliceofLife,Space' changed to 'oeeigOiirAqvee'
# row: 64 col: 2 : 'Drama,Comedy' changed to 'XrrsmmaaFoommu'
# row: 978 col: 2 : 'Comedy,Parody' changed to 'oommeeeyyPPddyy'
# row: 63 col: 2 : 'Fantasy,Kids' changed to 'Gsjzt,,Ludd'
# row: 1476 col: 2 : 'Animation,Short' changed to 'AAnniimmsgooomWr'
# row: 26 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'eejjrr,,VoondddFFaabttaaw,,Luss'
# row: 633 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'biimmqttuinn,,AAii,,scwjttrrr,,kfyy,,ttaazu,,SScciiDu'
# row: 70 col: 2 : 'Animation,Comedy,Fantasy' changed to 'AAmiinsyiilnnmmeeeh,,aagqssyy'
# row: 56 col: 2 : 'Horror,Thriller' changed to 'Boorr,,Gyiikoeerr'
# row: 365 col: 2 : 'Documentary' changed to 'DDiccuueenny'
# row: 41 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'AAmiimmaaooob,,viim,,CCleet,,Daattt,,Eoommaaf'
# row: 968 col: 2 : 'Documentary' changed to 'Xvuueenntte'
# row: 143 col: 2 : 'Kids,Music' changed to 'Lkddw,,wkf'
# row: 406 col: 2 : 'Kids,Music' changed to 'KKoaKjssf'
# row: 490 col: 2 : 'Comedy' changed to 'oommwyy'
# row: 950 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'cciinnooxhiooSSgooyjeej'
# row: 1410 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'AAmkaariib,,iinneest,,SSpprry'
# row: 484 col: 2 : 'Action,Mystery,Supernatural' changed to 'ccttknnMMyyeeyySSjowsguurrll'
# row: 574 col: 2 : 'Drama,Romance' changed to 'EmmRRmmaav'
# row: 1512 col: 2 : 'Comedy' changed to 'Vnsu'
# row: 342 col: 2 : 'Animation,Short' changed to 'Sbiimmsttk,,Zlftt'
# row: 1588 col: 2 : 'Action,MartialArts' changed to 'AAccyoooaarryiiqoSftt'
# row: 765 col: 2 : 'Comedy,Horror' changed to 'Foommeeu,,HHeoo'
# row: 650 col: 2 : 'Comedy,Drama' changed to 'CCeesn'
# row: 773 col: 2 : 'Thriller' changed to 'Rjrriilleef'
# row: 1425 col: 2 : 'Drama,SliceofLife' changed to 'Eaammq,,llolLLudee'
# row: 1380 col: 2 : 'Animation,Action,Fantasy' changed to 'usnnxttnn,,FFsnngssyy'
# row: 1240 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'iimmaarkAAccttooom,,CCookeexyyRaajttaadyy'
# row: 1179 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'nnkkaaoonn,,hhgVlwddhvo--Gii'
# row: 1342 col: 2 : 'Animation' changed to 'Qqolnn'
# row: 1332 col: 2 : 'Animation,Action,Sci-Fi' changed to 'nniiqttpAAccunnxk--u'
# row: 1575 col: 2 : 'Drama,Shoujo' changed to 'EqqAoojj'
# row: 196 col: 2 : 'Animation' changed to 'AAnniikaagunn'
# row: 320 col: 2 : 'Kids,Music' changed to 'sss,,uudiicc'
# row: 771 col: 2 : 'Comedy,Drama,Romance' changed to 'ifyy,,rrkaa,,ooaannccw'
# row: 392 col: 2 : 'Hentai' changed to 'Jnnttk'
# row: 1079 col: 2 : 'Animation,Comedy' changed to 'AAiimmttoooCCleeeyy'
# row: 1295 col: 2 : 'Action,Music' changed to 'AAttiil,,iwkcc'
# row: 158 col: 2 : 'Crime,Drama,Thriller' changed to 'Vrriimmrrss,,TTfiiow'
# row: 1381 col: 2 : 'Sci-Fi,Space' changed to 'SSx--FFZppsccee'
# row: 1205 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'AAccttiim,,AAvvdnntt,,MMxhhaa,,DvDii'
# row: 1550 col: 2 : 'Animation,Comedy,Romance,Sci-Fi' changed to 'SbonkpVoommft,,RRoosfSScck--G'
# row: 280 col: 2 : 'Animation,Short,Adventure,Comedy' changed to 'Sbiiyolnn,,Abir,,edrjwCCikee'
# row: 418 col: 2 : 'Animation,Short,Sport' changed to 'QnnummsttiSSgoo,,SSp'
# row: 1322 col: 2 : 'Drama,Sci-Fi,Shounen,Sports' changed to 'DDrrsmm,,Zf--C,,yuumrnnZtd'
# row: 203 col: 2 : 'Action,Adventure,MartialArts,Samurai' changed to 'AAklddcdjyrrrMMsfyoaallrrw,,SSmmrrqu'
# row: 1217 col: 2 : 'Comedy,Sci-Fi,Shounen,Shounen' changed to 'XoommdsD--Cii,,Zhhuujnnyluujee'
# row: 1557 col: 2 : 'Comedy,Magic,Shoujo,SliceofLife' changed to 'CClkxyy,,sggk,,SShhljkp,,DouccdiffKiiee'
# row: 187 col: 2 : 'Adventure,Fantasy,Historical' changed to 'svvttirrCjgwyyHHttrroxk'
# row: 33 col: 2 : 'Animation,Drama,Fantasy,Mystery' changed to 'AAiimmnn,,DDrrsaagqzyyyyaydu'
# row: 1354 col: 2 : 'Comedy,Romance' changed to 'ikwddyyqbr'
# row: 1060 col: 2 : 'Animation,Adventure,Family,Fantasy,Sci-Fi' changed to 'baauoo,,QtteeqllCjssyyZxu--Cu'
# row: 1471 col: 2 : 'Fantasy,Magic,School' changed to 'CssyyoZxbpooll'
# row: 1308 col: 2 : 'Shounen,Sports' changed to 'jiynneennoottz'
# row: 778 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'AAnniimmaagiiij,,AAxgiioom,,DDenqSSx--'
# row: 545 col: 2 : 'Action,Comedy,MartialArts,School,Shounen' changed to 'Sooob,,ikrdd,,NsaaoSfWxooo,,ir'
# row: 652 col: 2 : 'Action,Fantasy,Shounen,Supernatural' changed to 'Qfiib,,aabyqssyySShhooeeuuoeeeaattuueaak'
# row: 1131 col: 2 : 'Animation,Adventure,Fantasy,Sci-Fi' changed to 'nniimmiinn,,AAfceejrrwFFaaaat--Dii'
# row: 49 col: 2 : 'Comedy' changed to 'nddu'
# row: 1109 col: 2 : 'Drama' changed to 'Frr'
# row: 944 col: 2 : 'Animation,Short' changed to 'AAiimmaaiiooSShhoo'
# row: 366 col: 2 : 'Action,Crime,Drama,Sci-Fi' changed to 'QccyiilmCCfkmmee,,rrqSSfk--Dii'
# row: 877 col: 2 : 'Animation,Action,Comedy,Fantasy,Horror' changed to 'nnukgkoonncciiij,,CCeeftFFsraaayy,,HHif'
# row: 276 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Romance' changed to 'iinaattiioom,,AAttkAAddvveegyee,,XpmmeeddyyDDeaa,,aannttdRRlbcc'
# row: 648 col: 2 : 'Harem,Romance,Shoujo' changed to 'HHsfmmlsnnx,,ooh'
# row: 1366 col: 2 : 'Animation,Adventure,Drama,Horror,Romance,Sci-Fi' changed to 'nnaattinn,,QttuueeeXaa,,BoorrrroofTimmqeeZfuo'
# row: 1363 col: 2 : 'Animation,Action,Drama,Romance,Sport' changed to 'AAmmqykAAxttklnn,,DDfaanaa,,mmsnnccee,,Zpprrg'
# row: 208 col: 2 : 'Historical' changed to 'Bossyirriiaak'
# row: 759 col: 2 : 'Animation,Action,Fantasy' changed to 'nniiksiinn,,ttiioonn,,FFsd'
# row: 1592 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'SuttiimCCookdd,,Seaa,,iqfee'
# row: 1440 col: 2 : 'Animation,Short' changed to 'Qottuinnjpfy'
# row: 1281 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'AAsgwirrDDtkaaiiFF'
# row: 1418 col: 2 : 'Comedy,Kids' changed to 'CCoommwfyyiiss'
# row: 546 col: 2 : 'Comedy,Ecchi,School,Shounen' changed to 'nyy,,EEcchh,,Accjiik,,SSyooinneenn'
# row: 750 col: 2 : 'Comedy' changed to 'Xmmx'
# row: 528 col: 2 : 'Action,Comedy,Horror,Shounen,Supernatural' changed to 'Sxpnn,,Xpmmh,,oorrrrprrWbjjSSuuoeefbuurrsll'
# row: 1522 col: 2 : 'Drama,Kids' changed to 'qmmaa,,iidd'
# row: 455 col: 2 : 'Animation,Comedy,Romance' changed to 'Snniimmqyiinn,,Xpeeftlsnncc'
# row: 554 col: 2 : 'Animation,Comedy,Family,Sci-Fi' changed to 'QnnmmnnXmmees,,Raammkt,,AxFFu'
# row: 1377 col: 2 : 'Animation,Short' changed to 'AAunknn,,SSoott'
# row: 632 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Shounen' changed to 'xbttuufd,,Xlmmrddyy,,Cqjqiiss,,hhoonndnn'
# row: 437 col: 2 : 'Animation,Sci-Fi' changed to 'nttoooSScco'
# row: 884 col: 2 : 'Action,Adventure,Fantasy' changed to 'AAcckAAddbnnttrreeDaannttaah'
# row: 1260 col: 2 : 'Animation,Short,Horror' changed to 'AAjummqiiDhhrrttHHoorrfrr'
# row: 587 col: 2 : 'Comedy,Ecchi,Fantasy,Romance,SliceofLife' changed to 'CCmmyyWccfjoGaannaawyy,,aajccw,,Zooiiffd'
# row: 870 col: 2 : 'Short,Comedy' changed to 'hhirrtt,,lmmeexyy'
# row: 467 col: 2 : 'Adventure,Sci-Fi' changed to 'AAbnnuurrwSSccR'
# row: 1509 col: 2 : 'Animation,Short,Action,Adventure,Fantasy,Sci-Fi' changed to 'Siiyulhhrrrxyooob,,ddeeye,,FFnnhAf--ii'
# row: 75 col: 2 : 'Drama,Family' changed to 'aakqkiik'
# row: 1298 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Horror,War' changed to 'QnnkkqttuoojAAfyiinn,,cbreStaamm,,FFaattqss,,oorrf,,WWaa'
# row: 148 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'AAkttkoob,,AAkoonn,,Vneyyaattsu,,Faajcc'
# row: 432 col: 2 : 'Comedy,SliceofLife' changed to 'ookryy,,kiffLLff'
# row: 586 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'QbiimmaattimoonwtDccii--R'
# row: 1309 col: 2 : 'Animation' changed to 'nnkaattiioonn'
# row: 87 col: 2 : 'Animation,Short,Drama,Music' changed to 'AAbmmsyoohhittt,,qq,,Niucc'
# row: 923 col: 2 : 'Animation,Short,Comedy' changed to 'nnmmaattlb,,hhlooddh'
# row: 1553 col: 2 : 'Animation,Short,Comedy' changed to 'AAunqoonnSStt,,immddt'
# row: 1090 col: 2 : 'Animation,Comedy' changed to 'QjopbVyy'
# row: 140 col: 2 : 'Animation,Comedy,Family' changed to 'nnkmmqoooCCikeeyy,,FFmmo'
# row: 38 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'AAfvveejttieeFleedduNryyOooiixSSboojjee'
# row: 646 col: 2 : 'Kids,Sports' changed to 'iiddpppttss'
# row: 116 col: 2 : 'Animation,Comedy,Family,Fantasy' changed to 'AAmiikqttddGaaFFqnng'
# row: 1055 col: 2 : 'Comedy' changed to 'Vmmdu'
# row: 473 col: 2 : 'Animation,Comedy,Family' changed to 'jiimmsoonn,,dd,,aaoyy'
# row: 958 col: 2 : 'Comedy' changed to 'CCoommdddh'
# row: 113 col: 2 : 'Short,Drama,Horror,Mystery,Thriller' changed to 'WpDDaaooi,,Krdtu,,Yuolleerr'
# row: 1356 col: 2 : 'Reality-TV' changed to 'RRwllttTT'
# row: 643 col: 2 : 'Comedy,Parody,School,Sci-Fi,Shounen' changed to 'Xpmmeeddyy,,PPddu,,Wvp,,SSvii--Dooinn'
# row: 547 col: 2 : 'Animation,Comedy' changed to 'SiimmsgiinnCCpdxyy'
# row: 35 col: 2 : 'Adventure,Crime,Drama,History,Mystery,Thriller' changed to 'vvwjgrree,,CCumm,,taaaa,,ssgu,,MMsstteerr,,TTyrroll'
# row: 1250 col: 2 : 'Hentai' changed to 'Yeemttso'
# row: 952 col: 2 : 'Documentary,Short' changed to 'lccuuru,,g'
# row: 213 col: 2 : 'Drama,Thriller' changed to 'DDtnaabelleerr'
# row: 615 col: 2 : 'Hentai' changed to 'wbttk'
# row: 236 col: 2 : 'Animation' changed to 'aattoonn'
# row: 395 col: 2 : 'Animation,Sci-Fi' changed to 'kaayiinn,,Zii--u'
# row: 1573 col: 2 : 'Fantasy,Magic' changed to 'FFsrsh,,MMaat'
# row: 910 col: 2 : 'Comedy' changed to 'oommret'
# row: 663 col: 2 : 'Animation,Comedy,Romance' changed to 'nnmmttooojCCoof,,Tinsnncc'
# row: 1554 col: 2 : 'Animation,Action,Drama,Fantasy,Horror,Thriller' changed to 'aattiinn,,AAfymk,,Cst,,Btrrl,,fiikd'
# row: 92 col: 2 : 'Animation' changed to 'Siinqttnn'
# row: 1009 col: 2 : 'Animation' changed to 'AAmiinqttp'
# row: 1508 col: 2 : 'Comedy,Seinen,Space' changed to 'FoonZdunneenn,,SSppccee'
# row: 965 col: 2 : 'Animation' changed to 'jiimmaa'
# row: 1524 col: 2 : 'Hentai' changed to 'eemgii'
# row: 482 col: 2 : 'Sport' changed to 'Dorrtt'
# row: 1289 col: 2 : 'Romance,Sports' changed to 'RRlmmsnnvwSSoooyss'
# row: 769 col: 2 : 'Kids,Music' changed to 'KKxssNuuziif'
# row: 76 col: 2 : 'Adventure,Kids' changed to 'Svvnnrrrddss'
# row: 354 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Snnnaattub,,nt,,DDfaasaadyyooaabee'
# row: 1455 col: 2 : 'Animation,Family' changed to 'qttonnFFaammll'
# row: 1214 col: 2 : 'Comedy,Short' changed to 'CClnfyy,,SSyprrg'
# row: 614 col: 2 : 'Fantasy,Historical,Kids' changed to 'nnsdyy,,iissypeiiccsoKKiis'
# row: 568 col: 2 : 'Animation,Drama,Fantasy' changed to 'ksyiiooj,,rrqksbgqayy'
# row: 631 col: 2 : 'Comedy' changed to 'ndd'
# row: 370 col: 2 : 'Animation,Comedy' changed to 'kmmyiioo,,lmmeexu'
# row: 1429 col: 2 : 'Animation' changed to 'Qiikyoonn'
# row: 1038 col: 2 : 'Drama,Kids' changed to 'saa,,xa'
# row: 373 col: 2 : 'Short,Sci-Fi,War' changed to 'SShht,,xii--RWWaaf'
# row: 375 col: 2 : 'Short,Drama' changed to 'ootaans'
# row: 801 col: 2 : 'Comedy' changed to 'oommeeft'
# row: 780 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family' changed to 'AAjiigoiboinn,,Qddvvbttyee,,oostDDaammkyy'
# row: 900 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Horror' changed to 'usccttkooddceennttrreeXoowxtskq,,Rsnnyyy,,lrrrr'
# row: 492 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Mystery,Romance' changed to 'SjiinaaoQvveerjw,,tkFFmmiikh,,FFaannssyy,,MMyywreerryyRRnaann'
# row: 1367 col: 2 : 'Comedy,Drama,Romance' changed to 'Vlmmh,,DDrrqnaa,,nsd'
# row: 558 col: 2 : 'Comedy,Parody' changed to 'VoonyyPPaarroodd'
# row: 927 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'QiinaattiAAylegnntteepmmyy'
# row: 934 col: 2 : 'Comedy,Reality-TV' changed to 'pmmeeeTwaaoiittyy--'
# row: 790 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'AAaaooom,,CClntaammqFFaarahmmsb'
# row: 1275 col: 2 : 'Animation,Comedy,Fantasy,Horror,Romance' changed to 'AAmiittnn,,Fpnwfu,,snnss,,ffrraaccr'
# row: 695 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'mmx,,SSk--FFuAppaaf'
# row: 505 col: 2 : 'Comedy,Mecha,Parody' changed to 'iddyy,,eehhs,,PPstldd'
# row: 746 col: 2 : 'Comedy,Talk-Show' changed to 'Flnehkhhww'
# row: 453 col: 2 : 'Hentai' changed to 'Gttaak'
# row: 1065 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'Qnnaattiip,,q,,qmgssu,,vo'
# row: 248 col: 2 : 'Animation,Action' changed to 'Qiinyooo,,inn'
# row: 281 col: 2 : 'Action,Historical,MartialArts,Samurai' changed to 'Sccttkj,,Bosstttiiccaall,,NfyaallSrrtt,,aammaak'
# row: 1283 col: 2 : 'Animation,Short,Music' changed to 'QnniinriibWeguussiix'
# row: 797 col: 2 : 'Animation,Short' changed to 'AAiiaattoomhhe'
# row: 920 col: 2 : 'Comedy' changed to 'oommwddyy'
# row: 316 col: 2 : 'Comedy,Action,Drama,Family' changed to 'Voommw,,SiiibfsmmqDqniiu'
# row: 1558 col: 2 : 'Animation' changed to 'AAjnqttiilj'
# row: 1576 col: 2 : 'Fantasy' changed to 'FFmysayy'
# row: 1337 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'AAkqykoonn,,VndyyFFnnsyyToonnn'
# row: 34 col: 2 : 'Comedy,Ecchi,Mecha,Parody,Sci-Fi,Shounen,SuperPower' changed to 'CCooeeehx,,MMeefhhPPshSScciiFFk,,ZyldoeeOooww'
# row: 1063 col: 2 : 'Action,Sci-Fi,Thriller' changed to 'AAccrul,,SSx--FF,,Gyrrk'
# row: 1350 col: 2 : 'Comedy,Ecchi,Mecha,Romance,Sci-Fi' changed to 'CCoommetEEcchhNeeccgq,,lksm,,SSvR'
# row: 68 col: 2 : 'Action,Drama,Fantasy,Mystery,Sci-Fi' changed to 'AAccm,,DDrrmms,,DzNeet,,k--Ck'
# row: 1196 col: 2 : 'Kids,Sports' changed to 'KKuss,,SSppootta'
# row: 1175 col: 2 : 'Drama' changed to 'DDrraas'
# row: 1479 col: 2 : 'Comedy' changed to 'Voonddyy'
# row: 1056 col: 2 : 'Drama' changed to 'Ftaamm'
# row: 1070 col: 2 : 'Drama' changed to 'rrqk'
# row: 1324 col: 2 : 'Animation,Drama,History,Romance' changed to 'Smokaattulm,,mmq,,Buwpyy,,RRikaannxd'
# row: 1163 col: 2 : 'Animation,Comedy,Sport' changed to 'nnkaaypnnCCnpprrr'
# row: 1411 col: 2 : 'Animation' changed to 'AAoaa'
# row: 675 col: 2 : 'Action,Josei,Supernatural' changed to 'AAttiiiNsseekSSuuppeetnnaattyll'
# row: 913 col: 2 : 'Drama,Historical,Kids' changed to 'k,,HHossirruaallJodd'
# row: 362 col: 2 : 'Animation' changed to 'Qmnsttooj'
# row: 291 col: 2 : 'Animation,Action,Comedy' changed to 'AAnnqii,,ccuoonnCCpnddu'
# row: 212 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'QttiilnnAAfdnnryrr,,CCineeyy,,SSjpuueej'
# row: 47 col: 2 : 'Animation,Comedy,Drama,Music' changed to 'QiiqyVmmwsh,,rrkaa,,ss'
# row: 626 col: 2 : 'Action,Sci-Fi,Space,SuperPower' changed to 'cckoonn,,ii--Ru,,sf,,ZoeerrOprrr'
# row: 1574 col: 2 : 'Drama,Horror,Thriller' changed to 'rrsmmaaerrprr,,TThhrrllllrrr'
# row: 338 col: 2 : 'Hentai' changed to 'Jmttaa'
# row: 1589 col: 2 : 'Mecha,Military,Sci-Fi,Space' changed to 'MMccsllkaatyyAccu--FFooaafee'
# row: 1415 col: 2 : 'Kids' changed to 'osss'
# row: 827 col: 2 : 'Fantasy,Kids' changed to 'FFsnnru,,KKdd'
# row: 808 col: 2 : 'Animation,Biography,Drama,History,Romance,War' changed to 'iiksttiilnnNiioopphht,,FaammBksstttnaavee,,aa'
# row: 583 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'ccttpdjttuueeFFaannttqa,,MMeexys'
# row: 1596 col: 2 : 'Animation,Action,Sci-Fi' changed to 'AAiinttooo,,AAvrj,,WuGii'
# row: 153 col: 2 : 'Action,Adventure,Fantasy,Sci-Fi' changed to 'xttiinnQddbeebyuurrr,,brwhccii--ii'
# row: 536 col: 2 : 'Animation' changed to 'AAiikaarp'
# row: 1200 col: 2 : 'Kids,Music' changed to 'IiifdNuuaiix'
# row: 142 col: 2 : 'Adventure,Drama,Sci-Fi,Space' changed to 'AAcwnnuutr,,Feqaa,,SS--,,ppaacc'
# row: 1106 col: 2 : 'Action,Drama,Horror' changed to 'QfiiDDsmmaaJprroot'
# row: 733 col: 2 : 'Animation,Short,Adventure,Comedy,Family' changed to 'AAmokrooonn,,hhtr,,xvvmttjfw,,CCooddt,,Rmmiiku'
# row: 71 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'AAsnnyrreeCCmmrh,,Daabttd,,xss'
# row: 1270 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'xooonn,,Svvyedoommdd,,nnqyydd'
# row: 515 col: 2 : 'Animation' changed to 'mmaagiinn'
# row: 1432 col: 2 : 'Animation,Comedy' changed to 'nniimmkooj,,Veeyy'
# row: 1142 col: 2 : 'Animation,Sci-Fi' changed to 'AAiimm,,Wii--Dk'
# row: 1585 col: 2 : 'Animation' changed to 'iiaattob'
# row: 867 col: 2 : 'Adventure,Sci-Fi' changed to 'AAjtw,,SSuu'
# row: 463 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,Romance,Thriller' changed to 'Smmttinn,,AAxknnAAermrirrw,,CCrhnq,,FFqbttsh,,HHssttoorrh,,immsnneehhrriilldrr'
# row: 530 col: 2 : 'Comedy' changed to 'CCkee'
# row: 1580 col: 2 : 'Drama,Hentai,Romance,Sci-Fi' changed to 'Eaammaa,,HHnnqkFaameefo--FFii'
# row: 192 col: 2 : 'Comedy,Kids' changed to 'Vpmmwddudd'
# row: 180 col: 2 : 'Animation,Action,Fantasy,Romance' changed to 'AAkguoob,,xriipb,,FFaamzyy,,Emm'
# row: 228 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'AAiinaaynnegeettuurr,,ccFFii'
# row: 931 col: 2 : 'Animation,Comedy,Drama' changed to 'AAjiiaaolm,,CCmmeeFrraammaa'
# row: 1352 col: 2 : 'Animation' changed to 'AAukttii'
# row: 1338 col: 2 : 'Hentai' changed to 'HHdbttaa'
# row: 72 col: 2 : 'Hentai' changed to 'mttaa'
# row: 556 col: 2 : 'Comedy,Parody,SuperPower' changed to 'Vmmeedd,,OqrrAyorOls'
# row: 526 col: 2 : 'Animation,Comedy,Drama' changed to 'AAummqtt,,CCndddyyks'
# row: 500 col: 2 : 'Action,Comedy,Horror' changed to 'AAoonn,,CCoommrfyy,,HHootooe'
# row: 776 col: 2 : 'Drama,Family' changed to 'Fqkaaqii'
# row: 52 col: 2 : 'Animation' changed to 'Sjiisyupm'
# row: 897 col: 2 : 'Animation,Drama,Horror,Mystery' changed to 'AAbkaainn,,DDrrkJrrl,,Nyysstteeft'
# row: 1307 col: 2 : 'SliceofLife' changed to 'SSoiifwooffLLiidd'
# row: 356 col: 2 : 'Animation' changed to 'mommlnn'
# row: 317 col: 2 : 'SliceofLife' changed to 'SSkocceeffOiiw'
# row: 707 col: 2 : 'Historical,Kids' changed to 'HHzooiillMss'
# row: 108 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Qqgkim,,AAruoo,,gyeFFaaqsst'
# row: 332 col: 2 : 'Historical' changed to 'HHwyexqll'
# row: 716 col: 2 : 'Drama,Kids' changed to 'Ftaammaa,,'
# row: 1401 col: 2 : 'Action,Adventure,Mecha,Military,Sci-Fi' changed to 'ljSsvvjttjee,,MMq,,MMiiuaahii'
# row: 874 col: 2 : 'Short' changed to 'Dboorry'
# row: 1229 col: 2 : 'Sci-Fi' changed to 'SSvu--ii'
# row: 1570 col: 2 : 'Action' changed to 'AAfroo'
# row: 1435 col: 2 : 'Hentai' changed to 'HHeeyaaii'
# row: 1188 col: 2 : 'Comedy,School,SliceofLife' changed to 'Vnde,,hhiiidooOoffee'
# row: 244 col: 2 : 'Comedy,Magic,Parody' changed to 'FmmhMMaao,,PPaarroo'
# row: 1012 col: 2 : 'Hentai,Magic,Supernatural' changed to 'HHgii,,Ksgg,,uueetyyrraall'
# row: 1491 col: 2 : 'Animation,Action,Comedy,Crime,Mystery,Sci-Fi' changed to 'jiimmqkoonn,,AAfupnnFooneeshiin,,MMusseeetZcc--FF'
# row: 372 col: 2 : 'Animation,Adventure,Comedy,Fantasy,Romance' changed to 'knaagunnQddvvnnttuurree,,CCooeeeyyGsttsssuEoommsnnccee'
# row: 419 col: 2 : 'Animation,Action,Comedy,Family' changed to 'AAnniioj,,SfkoojCCieeFFaakuu'
# row: 1126 col: 2 : 'Action,Comedy,Mecha,Sci-Fi' changed to 'QrnnXpmmeeddyyNcchh,,DfkFFii'
# row: 1391 col: 2 : 'Action,Comedy,Shounen,Sports' changed to 'AAttuooCCikdxhjjeenn,,SSppoorrttss'
# row: 862 col: 2 : 'Animation,Comedy,Music' changed to 'Qmmqyiij,,VoonMMuuss'
# row: 1577 col: 2 : 'School,Shounen' changed to 'Doolll,,SShhjeem'
# row: 224 col: 2 : 'Animation' changed to 'mmmsttii'
# row: 872 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'AAksb,,AAccrnnqnnttaadt,,Hmmr--Wqcck--ii'
# row: 1513 col: 2 : 'Animation,Family,Comedy,Fantasy' changed to 'iikyuiaammu,,VmmeeFFmttsyy'
# row: 302 col: 2 : 'Animation,Short' changed to 'Qaattooom,,Djrrtt'
# row: 1133 col: 2 : 'Animation,Action,Comedy,Fantasy,Mystery' changed to 'AAbkmml,,QvgooojCCoommeeyyFFgsuMMsseyy'
# row: 1419 col: 2 : 'Hentai' changed to 'daaii'
# row: 845 col: 2 : 'Animation' changed to 'nniittol'
# row: 1190 col: 2 : 'Action,Demons,Fantasy' changed to 'SuoonnEeemmnnssqmttq'
# row: 638 col: 2 : 'Action,Comedy,Kids' changed to 'yiij,,CCprdd,,Lka'
# row: 975 col: 2 : 'Animation,Adventure,Comedy,Drama,Fantasy,Sci-Fi' changed to 'AAkqttlnnAAeennirreeVlkeesyy,,qqDqttSSxii--C'
# row: 1521 col: 2 : 'Comedy' changed to 'CCoodd'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1543, 8576)
# (22, 8576)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1543, 8575)
# (22, 8575)
# (1543, 700)
# (22, 700)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\feature_selection\univariate_selection.py:299: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 2995567.92
# Mean squared error: 42089104248004.58
# Variance score: -28906046014129589512812101632.00

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.03
# Mean squared error: 1.21
# Variance score: -22.81

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.933 0.906 0.907 0.886 1.024]
# Mean: 0.9313401446014206
# Standard deviation: 0.04855663282931703

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                   "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.87

# %% [markdown]
# ### Re-Training

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.03
# Mean squared error: 1.21
# Variance score: -22.81
