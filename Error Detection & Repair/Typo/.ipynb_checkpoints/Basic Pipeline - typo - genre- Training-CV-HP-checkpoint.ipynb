# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Butterfingers(),75, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Butterfingers().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Keyboard().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Butterfingers method ---------------
#
# row: 1454 col: 2 : 'Adventure,Fantasy,Sci-Fi,Shounen' changed to 'Sdcsheurx,Fantasy,Aci-Wj,Xhougqn'
# row: 1014 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'Qbhkaykmn,Wcyjok,Ddvevtuwg,Gaktafy,Xei-Fo,Chruujet'
# row: 240 col: 2 : 'Harem,Hentai' changed to 'Kefvm,Kenvci'
# row: 576 col: 2 : 'Horror,Shounen' changed to 'Hutgug,Vhknkcu'
# row: 924 col: 2 : 'Animation' changed to 'Anlmatjpn'
# row: 1562 col: 2 : 'Drama,Supernatural,Thriller' changed to 'Qrwoe,Xbkerndjirao,Tfrkoler'
# row: 183 col: 2 : 'Comedy,Kids,Parody,Sci-Fi,Space,SuperPower' changed to 'Gomxdy,Kidr,Lxtiay,Sdi-Fi,Wpacd,SjperLosxr'
# row: 180 col: 2 : 'Hentai' changed to 'Nentam'
# row: 453 col: 2 : 'Drama,Romance,Yaoi' changed to 'Dtzic,Comanws,Jaoi'
# row: 818 col: 2 : 'Action,Sci-Fi' changed to 'Sctmmm,Acp-Fi'
# row: 144 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Svimqgpln,Fokxby,Qtcnz,Tomzbce'
# row: 1546 col: 2 : 'Fantasy,Kids,Magic,Romance,Shoujo,SuperPower' changed to 'Hzntadr,Nids,Mqjis,Rokwbxr,Shokki,SukerPifdg'
# row: 398 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Znimwthon,Cojedy,Vfamq,Womakgc'
# row: 739 col: 2 : 'Animation,Action' changed to 'Dkijatioi,Dgnlon'
# row: 985 col: 2 : 'Animation,Adventure,Drama,Fantasy' changed to 'Amhkeejon,Safejtise,Framw,Fxnradu'
# row: 1141 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Romance' changed to 'Xiykagium,Wsfhkn,Cdvwmnure,Cijedy,Ctqmq,Fajtasi,Xomdvce'
# row: 376 col: 2 : 'MartialArts,School,Shounen,Sports' changed to 'KwstiqlAvja,Scmoil,Smiutqn,Spoggd'
# row: 412 col: 2 : 'Animation,Action,Comedy,Romance' changed to 'Animation,Wctipn,Cljxdj,Romahcc'
# row: 1379 col: 2 : 'Action,Horror,Sci-Fi,Thriller' changed to 'Avtion,Iocwlr,Wzm-Dm,Trrnmjer'
# row: 621 col: 2 : 'Short,Drama' changed to 'Whort,Gxaka'
# row: 762 col: 2 : 'Action,Adventure' changed to 'Agtpoh,Advevdltg'
# row: 139 col: 2 : 'Animation,Short' changed to 'Anhlatiot,Ahorg'
# row: 887 col: 2 : 'Music' changed to 'Mhsjw'
# row: 1423 col: 2 : 'Comedy,Drama,Romance' changed to 'Gumqqy,Dsama,Emkande'
# row: 1561 col: 2 : 'Hentai' changed to 'Kentxo'
# row: 1435 col: 2 : 'Comedy' changed to 'Cokrvn'
# row: 387 col: 2 : 'Animation,Short' changed to 'Qbpmatimn,Rhmdf'
# row: 551 col: 2 : 'Action,Adventure,Fantasy,Sci-Fi' changed to 'Acchmn,Cdyqntyrz,Hsntsvn,Sck-Fy'
# row: 123 col: 2 : 'Animation,Action,Comedy,Drama,Romance,Thriller' changed to 'Agomwtioh,Abtipn,Fjmvby,Ersjz,Vimevcv,Vhrillwr'
# row: 58 col: 2 : 'Hentai' changed to 'Hxntan'
# row: 1294 col: 2 : 'Hentai,School' changed to 'Fcitwi,Wcfmon'
# row: 1001 col: 2 : 'Comedy,Drama,Music' changed to 'Fokeer,Dfama,Iosic'
# row: 545 col: 2 : 'Short,Comedy' changed to 'Xnlrt,Volecf'
# row: 500 col: 2 : 'Adventure,Drama,Space' changed to 'Xavrnggfg,Drajs,Siace'
# row: 587 col: 2 : 'Adventure,Comedy,Demons,Historical,Supernatural' changed to 'Qdvfmcoca,Funedh,Drkonr,Vhvtoeneam,Suiegiwtixal'
# row: 618 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy' changed to 'Ajnkwbiok,Ssbikh,Qdvwkugge,Afska,Vdbtaxh'
# row: 1071 col: 2 : 'Comedy,Seinen,Space' changed to 'Coktby,Veiuen,F'acs'
# row: 187 col: 2 : 'Comedy,Drama,Romance' changed to 'Eomzdb,Dvemw,Rooamst'
# row: 443 col: 2 : 'Comedy' changed to 'Colcbv'
# row: 613 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy' changed to 'Animweooj,Acczbtyre,Qgamz,Gakilb,Fagdasy'
# row: 726 col: 2 : 'Animation,Comedy,Drama' changed to 'Aiikweion,Cooasy,Qraja'
# row: 856 col: 2 : 'Comedy' changed to 'Clmray'
# row: 1414 col: 2 : 'Animation,Short,Music' changed to 'Akykaejon,Dhotn,Music'
# row: 272 col: 2 : 'Documentary,Biography,History,News' changed to 'Vodukevewrh,Niogea'ky,Gnxfocy,Usfr'
# row: 588 col: 2 : 'Animation,Drama,Sport' changed to 'Xtymadmln,Dvdmw,Apuvv'
# row: 557 col: 2 : 'Animation,Short,Fantasy' changed to 'Qmjietpon,Fhugj,Fanfaxf'
# row: 774 col: 2 : 'Animation,Romance' changed to 'Cjiiatnoh,Vpkxkde'
# row: 756 col: 2 : 'Action,Fantasy,Magic,Shoujo' changed to 'Zcviuk,Santcsy,Mxtlc,Whouko'
# row: 706 col: 2 : 'Adventure,Kids' changed to 'Advvnuuge,Kodr'
# row: 486 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Aiiietiot,Acflkk,Zvdentnrq,Cokwgh,Wxkjaxg,Scy-Fu'
# row: 401 col: 2 : 'Animation,Drama' changed to 'Qupjecooh,Cgamw'
# row: 826 col: 2 : 'Short' changed to 'Xglwt'
# row: 831 col: 2 : 'Kids' changed to 'Kids'
# row: 1594 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Snojagjog,Axvion,Qrdos,Fey-Di'
# row: 1346 col: 2 : 'Animation,Fantasy,Romance' changed to 'Anikxbmun,Famearg,Gmkanbx'
# row: 518 col: 2 : 'Adventure' changed to 'Asfebguce'
# row: 672 col: 2 : 'Fantasy' changed to 'Fajywsg'
# row: 601 col: 2 : 'Comedy,Ecchi,Romance,School' changed to 'Vuiecn,Zbdhi,Dokqvsd,Vzhpjl'
# row: 1504 col: 2 : 'Fantasy,Horror,Supernatural' changed to 'Fqnvcsh,Hoccor,Aypertwtutal'
# row: 1195 col: 2 : 'Animation' changed to 'Dikoatljk'
# row: 1590 col: 2 : 'Comedy' changed to 'Soiddn'
# row: 1167 col: 2 : 'Animation,Action,Thriller' changed to 'Avumqhykj,Abuiig,Djenlodg'
# row: 1101 col: 2 : 'Animation,Comedy,Romance' changed to 'Qunozjlon,Cojefi,Tomajce'
# row: 1113 col: 2 : 'Romance,Shoujo' changed to 'Vimznca,Sjouop'
# row: 1022 col: 2 : 'Action,Comedy,Shounen,SuperPower' changed to 'Wwdmon,Gojrdy,Snonnej,SoltdKiwdt'
# row: 675 col: 2 : 'Animation' changed to 'Anikachjn'
# row: 1578 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Wnimethpn,Comddn,Sci-Di'
# row: 667 col: 2 : 'Animation,Short,Action,Adventure,Fantasy,Sci-Fi' changed to 'Agomqtnmv,Shuru,Abjpom,Seetihmwv,Faghadi,Xck-Fm'
# row: 1513 col: 2 : 'Action,Adventure,Animation,Comedy' changed to 'Cbtion,Wgetneldv,Avilctuon,Cimtvj'
# row: 1329 col: 2 : 'Short,Comedy' changed to 'Dioge,Bmngdb'
# row: 1026 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Anykatymi,Coiedy,Vdi-Fl'
# row: 900 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Ectiun,Cqrzhturw,Clmtdy,Dhmbnen'
# row: 817 col: 2 : 'Crime,Mystery,Thriller' changed to 'Ctiie,Mywbzrf,Trepller'
# row: 225 col: 2 : 'Animation,Short' changed to 'Ajimwdlkk,Vgore'
# row: 1171 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Romance' changed to 'Animcgjov,Axyloj,Vmosej,Vfpme,Frwmw,Gpmdnce'
# row: 738 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Xvjkanion,Gljedj,Fqntasn,Comahgw'
# row: 768 col: 2 : 'Comedy,Mecha,Police,Sci-Fi' changed to 'Cmkvvy,Kebjq,Pilixd,Sci-Fi'
# row: 766 col: 2 : 'Animation,Action,Fantasy,Romance,Sci-Fi' changed to 'Dnlmdclmn,Qcrkii,Favtzvy,Romdvee,Sci-Fi'
# row: 628 col: 2 : 'Drama' changed to 'Efala'
# row: 690 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'Dtlmctmki,Artlkb,Fchtafn,Gwkq-Fhor,Rbi-Fi'
# row: 929 col: 2 : 'Animation,Biography,Comedy' changed to 'Auonstipn,Viogsw[hy,Comwcv'
# row: 529 col: 2 : 'Action,Fantasy,Supernatural' changed to 'Wwtoov,Fdnfwsj,Supegnztuvqp'
# row: 78 col: 2 : 'Adventure,Historical,Sci-Fi' changed to 'Ddvevtutx,Kjfgorlfap,Xcl-Fk'
# row: 1552 col: 2 : 'Animation,Action,Drama,Romance,Sport' changed to 'Cunozekin,Axuimb,Qdama,Djjagcx,Sport'
# row: 840 col: 2 : 'Drama,Historical' changed to 'Qtsjs,Hkrdkriwal'
# row: 264 col: 2 : 'Romance,School,Shoujo' changed to 'Sondnce,Dvkiul,Sfoujo'
# row: 375 col: 2 : 'Comedy,Magic,Parody' changed to 'Cokgsy,Iwgic,Parodi'
# row: 796 col: 2 : 'Animation' changed to 'Auikajloh'
# row: 895 col: 2 : 'Hentai' changed to 'Hevtwl'
# row: 76 col: 2 : 'Comedy,Kids' changed to 'Gpndby,Hlda'
# row: 458 col: 2 : 'Adventure,Shounen' changed to 'Wdngkekde,Xhounei'
# row: 1333 col: 2 : 'Action,Fantasy,Shounen' changed to 'Awjymn,Fagtcsy,Shouvvn'
# row: 1042 col: 2 : 'Comedy' changed to 'Xunaay'
# row: 1032 col: 2 : 'Animation,Short,Comedy,Romance' changed to 'Akiianiij,Fgore,Cmmebh,Roiancw'
# row: 867 col: 2 : 'Reality-TV' changed to 'Tddpity-TG'
# row: 880 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'Aiindbmmi,Zrtkot,Zoiedg,Vqitarb'
# row: 1547 col: 2 : 'Animation,Short,Comedy' changed to 'Snimatlon,Djlsv,Cmjegu'
# row: 1371 col: 2 : 'Comedy,Ecchi,Fantasy,Harem,Romance,School,Sci-Fi,Supernatural' changed to 'Eokqdg,Ecrhk,Wagbwxy,Ksrqo,Rokahrr,Verjoo,Rgn-Yl,Su[trnabieal'
# row: 261 col: 2 : 'Drama' changed to 'Sraka'
# row: 1045 col: 2 : 'Kids' changed to 'Nida'
# row: 148 col: 2 : 'Comedy' changed to 'Ckiqdi'
# row: 19 col: 2 : 'Hentai' changed to 'Mtbtan'
# row: 1076 col: 2 : 'Animation,Short' changed to 'Xgumdbion,Syorn'
# row: 637 col: 2 : 'Drama' changed to 'Dfenc'
# row: 553 col: 2 : 'Animation,Action,Drama' changed to 'Wnilarupu,Dsuyiu,Braja'
# row: 63 col: 2 : 'Animation,Comedy,Drama' changed to 'Xjukatjuj,Epmcdu,Vgaia'
# row: 167 col: 2 : 'Action,Adventure,Comedy,Fantasy,Shounen,SuperPower' changed to 'Ectikn,Advttuurd,Eumedy,Fsgtasf,Shoukqv,SupatOjscg'
# row: 828 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Cnilcjion,Axbion,Xavqngmre,Sci-Fu'
# row: 1321 col: 2 : 'Comedy,Seinen' changed to 'Coneci,Xwkuqt'
# row: 243 col: 2 : 'SliceofLife' changed to 'DlucvofLige'
# row: 359 col: 2 : 'Sci-Fi' changed to 'Vcu-Fi'
# row: 217 col: 2 : 'Animation,Action,Fantasy,Mystery' changed to 'Dmjmacium,Wctkln,Fanfary,Mgstery'
# row: 1107 col: 2 : 'Shounen' changed to 'Sjptgqn'
# row: 407 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'Afbejruga,Ciiegj,Wci-Xl,Snpunat'
# row: 1443 col: 2 : 'Adventure,Fantasy' changed to 'Advtkvgre,Faggqxu'
# row: 1118 col: 2 : 'Animation,Short' changed to 'Wnknwtnon,Shict'
# row: 1038 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi,Thriller' changed to 'Skimcfimn,Dbypon,Srwjs,Cjmencr,Agi-Fi,Njsllovt'
# row: 199 col: 2 : 'Animation,Drama,Music' changed to 'Enilatyik,Draka,Lusir'
# row: 244 col: 2 : 'Animation,Short,Action,Fantasy' changed to 'Animwtmpn,Xvort,Zcylon,Dattasf'
# row: 712 col: 2 : 'Animation,Short,Drama,Music,Romance' changed to 'Djimxeioh,Shmrt,Awamc,Mlvmr,Tokdnce'
# row: 1122 col: 2 : 'Adventure,Kids' changed to 'Wdcxiulrg,Imda'
# row: 1000 col: 2 : 'SliceofLife' changed to 'VlofgpdJlfw'
# row: 1398 col: 2 : 'Adventure,Drama,Historical,SliceofLife' changed to 'Edyaituxs,Vrajq,Jldtiwicql,SmicejhPjgd'
# row: 570 col: 2 : 'Animation,Short' changed to 'Ahhnxtion,Rroru'
# row: 528 col: 2 : 'Short,Fantasy' changed to 'Shmrt,Hantzsy'
# row: 649 col: 2 : 'Animation,Action,Crime,Sci-Fi' changed to 'Cbjmetimh,Xctujn,Bgjme,Aci-Fn'
# row: 961 col: 2 : 'Short' changed to 'Shorg'
# row: 403 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Aqvejgurv,Vjmrdr,Fqgucsi,Yidr'
# row: 1582 col: 2 : 'Hentai' changed to 'Vebyal'
# row: 1489 col: 2 : 'Animation,Horror,Sci-Fi' changed to 'Cnnkzeilj,Hirtot,Fci-Fk'
# row: 214 col: 2 : 'Animation,Comedy,Romance' changed to 'Enimethit,Fomrdh,Domange'
# row: 869 col: 2 : 'Animation,Comedy' changed to 'Ajkmstuov,Fkmedj'
# row: 1149 col: 2 : 'Animation,Short,Music' changed to 'Snlmqtjln,Shjgt,Musud'
# row: 775 col: 2 : 'Animation,Action,Adventure,Comedy,Crime,Mystery' changed to 'Ahlkduion,Avvylk,Advsvnmre,Rljrcv,Cclme,Kysjegt'
# row: 1268 col: 2 : 'Short,Animation' changed to 'Fiugg,Xnomqtloh'
# row: 514 col: 2 : 'Animation,Comedy' changed to 'Akuixtlon,Clmgqt'
# row: 27 col: 2 : 'Comedy,Drama,Horror,Mystery' changed to 'Wooqdy,Feaja,Hlrrog,Myvtety'
# row: 710 col: 2 : 'Music,School,SliceofLife' changed to 'Murif,Rcrpju,SlosepdMife'
# row: 362 col: 2 : 'Comedy,Harem,Music,Romance,School,Shoujo' changed to 'Eomxvg,Hasam,Mushc,Rokatfe,Fchuoo,Shkuji'
# row: 385 col: 2 : 'Comedy' changed to 'Xomgdn'
# row: 1079 col: 2 : 'Animation,Adventure,Drama,Fantasy,Romance' changed to 'Zuimzyion,Xcfegdkrd,Dsdke,Fanjwfb,Smoehce'
# row: 1081 col: 2 : 'Action,Sci-Fi,Animation,Fantasy,Adventure,Drama' changed to 'Zwtikj,Rci-Di,Wninstnlm,Fcntaay,Adndjtuce,Drxmx'
# row: 1471 col: 2 : 'Comedy,School,SliceofLife' changed to 'Romeay,Xwhoou,WlhcekfLnye'
# row: 724 col: 2 : 'Action,Mystery,Romance,Supernatural,Thriller' changed to 'Wzfiot,Mfdhetj,Tomxbce,Vuprrkafucxm,Tyrilkdr'
# row: 842 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Cniodtiin,Artpuu,Sro-Wl'
# row: 680 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'Aqveufuge,Glmddj,Lgdjeey,Pkjicz,Xfuynvb'
# row: 1202 col: 2 : 'Animation,Fantasy,Romance' changed to 'Wnojwfijb,Hqntasy,Rokansf'
# row: 1312 col: 2 : 'Animation,Short' changed to 'Abmmajlln,Agmsu'
# row: 178 col: 2 : 'Drama,Kids' changed to 'Dwaja,Nics'
# row: 814 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Magic,SuperPower' changed to 'Adgxnturx,Cpoedg,Fsntwsj,Khdv,Kagyc,SlpecPlwxs'
# row: 1430 col: 2 : 'Comedy,School,Sports' changed to 'Cojaeu,Szhojl,Wokvtx'
# row: 849 col: 2 : 'Hentai' changed to 'Vfntei'
# row: 1104 col: 2 : 'Animation,Comedy,Drama,Fantasy,Horror,Mystery' changed to 'Enmkaflin,Cokqdy,Erqka,Ganhaay,Hortpt,Iywdfsy'
# row: 14 col: 2 : 'Animation,Adventure' changed to 'Akumafnkh,Afywnrgre'
# row: 367 col: 2 : 'Short' changed to 'Ahutt'
# row: 584 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Zfyrkture,Coicdf,Santwsy,Kogs'
# row: 852 col: 2 : 'Adventure,Family,Fantasy,Romance' changed to 'Edfebdugd,Ramkki,Faitsdy,Skjancw'
# row: 1063 col: 2 : 'Animation,Action,Adventure,Horror,Mystery,Thriller' changed to 'Wuimsnjjh,Actyon,Wgtvnrura,Ioftog,Kyftxrt,Thryller'
# row: 467 col: 2 : 'Animation,Short' changed to 'Auynztlov,Shkrt'
# row: 1411 col: 2 : 'Adventure,Sci-Fi' changed to 'Agyenguvv,Dci-Fi'
# row: 1436 col: 2 : 'Animation,Short,Comedy' changed to 'Anhoscykn,Rhpet,Sjmcar'
# row: 1363 col: 2 : 'Adventure,Short,Animation,Sci-Fi' changed to 'Wendghmxr,Srkgt,Xnjjqtlkn,Scl-Gl'
# row: 558 col: 2 : 'Animation,Comedy' changed to 'Wnimatiiu,Cuiwvy'
# row: 1449 col: 2 : 'Animation,Romance' changed to 'Ajinenipg,Wojehve'
# row: 4 col: 2 : 'Animation,Fantasy' changed to 'Dnjkatioj,Vwnywdv'
# row: 349 col: 2 : 'Comedy,Music' changed to 'Cjmedg,Iurir'
# row: 161 col: 2 : 'Animation,Adventure,Comedy,Drama,Romance,Sci-Fi' changed to 'Aimoaypjt,Aegvneure,Cjmcdj,Dczmw,Dkmagee,Wrm-Vy'
# row: 468 col: 2 : 'Comedy' changed to 'Eonevt'
# row: 1174 col: 2 : 'Action,Adventure,Crime,Drama,Mystery' changed to 'Abcokn,Cdneutixs,Cxike,Qrsoa,Oysuegv'
# row: 440 col: 2 : 'Animation,Short,Action,Adventure,Sci-Fi' changed to 'Znlmafnmn,Smore,Wctjoj,Advwkeore,Sbi-Fi'
# row: 575 col: 2 : 'Comedy' changed to 'Cokfdv'
# row: 822 col: 2 : 'Action,Comedy' changed to 'Wcelin,Romzqb'
# row: 595 col: 2 : 'Short,Drama' changed to 'Xhmrj,Bgema'
# row: 1190 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Dccpon,Advvnture,Ejiwgy,Rhinnxn'
# row: 374 col: 2 : 'Animation' changed to 'Anokatyuu'
# row: 1019 col: 2 : 'Action,Adventure,Comedy,Drama,Fantasy,Kids' changed to 'Wfriju,Aqysnture,Cjigdj,Drama,Saigasy,Ildd'
# row: 542 col: 2 : 'Animation' changed to 'Atymaeuon'
# row: 333 col: 2 : 'Animation,Short' changed to 'Agikztion,Dhiry'
# row: 156 col: 2 : 'Animation,Drama,Horror' changed to 'Ajkjatkiu,Brwjs,Yoxsox'
# row: 395 col: 2 : 'Comedy,Josei,Romance,SliceofLife' changed to 'Dpncsv,Jkrrp,Domajfa,DlldeofPmne'
# row: 353 col: 2 : 'Adventure,Animation' changed to 'Caventycd,Atyladion'
# row: 858 col: 2 : 'Adventure' changed to 'Zavenrore'
# row: 1263 col: 2 : 'SliceofLife' changed to 'FljweldLifd'
# row: 1027 col: 2 : 'Animation' changed to 'Wmnjzcyon'
# row: 747 col: 2 : 'Mystery' changed to 'Mustrxy'
# row: 1083 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Ciknwniin,Slmedv,Bcame,Fqvtary,Wikanbe'
# row: 930 col: 2 : 'Animation,Sci-Fi' changed to 'Auimaehom,Rck-Xm'
# row: 171 col: 2 : 'Animation,Sport' changed to 'Wkikccimb,R'pre'
# row: 108 col: 2 : 'Ecchi' changed to 'Qcxvl'
# row: 569 col: 2 : 'Ecchi,Music' changed to 'Dwchi,Kusic'
# row: 592 col: 2 : 'Animation,Short,Sci-Fi' changed to 'Ahhmsjnpn,Rhmrt,Sri-Yl'
# row: 517 col: 2 : 'Animation,Comedy,Romance' changed to 'Cnlnatymh,Cjlfcj,Tikwnxa'
# row: 1496 col: 2 : 'Action,Comedy,Fantasy,Magic,Music,Shoujo' changed to 'Cgclli,Ckmddy,Fajdady,Magmc,Nyvis,Vhomop'
# row: 989 col: 2 : 'Comedy,Talk-Show' changed to 'Cijtcu,Tclk-Rfox'
# row: 1420 col: 2 : 'Action' changed to 'Astiun'
# row: 10 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Clkevy,Rwncsst,Nmgx'
# row: 399 col: 2 : 'Action,Historical,MartialArts,Samurai' changed to 'Ecnipt,Imstirisal,MxsticmSgts,Wajmraj'
# row: 953 col: 2 : 'Documentary,Short' changed to 'Gobukqntasy,Rfuve'
# row: 94 col: 2 : 'Drama,Psychological,Seinen,Thriller' changed to 'Drama,Psyvmploglrql,Vspjzn,Tfcilldw'
# row: 221 col: 2 : 'Hentai' changed to 'Gzttal'
# row: 1269 col: 2 : 'Animation,Drama' changed to 'Wkijabion,Drdnz'
# row: 1262 col: 2 : 'Hentai' changed to 'Hfntzp'
# row: 502 col: 2 : 'Adventure,Fantasy' changed to 'Advskgydf,Fautwdu'
# row: 594 col: 2 : 'Animation' changed to 'Eiijavnpn'
# row: 1006 col: 2 : 'Action,School,Shounen' changed to 'Aeuloi,Xzhiil,Sglmnfn'
# row: 722 col: 2 : 'Animation,Action,Sport' changed to 'Ajimayijg,Xcbhjg,W[krr'
# row: 668 col: 2 : 'Drama,Kids' changed to 'Drakq,Kivs'
# row: 1054 col: 2 : 'Short' changed to 'Smprn'
# row: 1338 col: 2 : 'Drama,Romance' changed to 'Frqmd,Gumamge'
# row: 318 col: 2 : 'Action,Crime,Drama,Mystery,Thriller' changed to 'Avtiov,Ccime,Dgxnw,Ijstfry,Tnrkpowr'
# row: 488 col: 2 : 'Kids,Music' changed to 'Iivv,Ousyc'
# row: 933 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Adgfiencg,Cjneah,Denhavy'
# row: 1288 col: 2 : 'Talk-Show' changed to 'Nauh-Wruw'
# row: 765 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Agimweopi,Qgdiok,Advdncuee,Fabuasy'
# row: 1129 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Ailoatjjg,Qcfioj,Dfi-Vj'
# row: 526 col: 2 : 'Comedy' changed to 'Zimedj'
# row: 234 col: 2 : 'Comedy,SliceofLife' changed to 'Cpiwch,SkpzejsLigr'
# row: 1199 col: 2 : 'Historical' changed to 'Vixcodjwql'
# row: 218 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'Eokzci,Womavce,Ssvoop,Skmujo'
# row: 829 col: 2 : 'Comedy,Ecchi,Magic,Parody,Vampire' changed to 'Womagi,Rbeym,Katnc,'wrody,Ncmkude'
# row: 689 col: 2 : 'Comedy,Sci-Fi,Shounen' changed to 'Eomeqy,Rcu-Nh,Xymbnen'
# row: 428 col: 2 : 'Animation' changed to 'Agimwgpkh'
# row: 1172 col: 2 : 'Adventure,Drama,Fantasy,Horror,Shounen,Supernatural,Vampire' changed to 'Avvevttre,Drwmx,Yzhtawt,Mmerot,Skugneh,Shigrnatnrqp,Ewnouge'
# row: 28 col: 2 : 'Harem,Hentai' changed to 'Vxreo,Mentxm'
# row: 1087 col: 2 : 'SliceofLife' changed to 'XnlceodOhfe'
# row: 257 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Mystery' changed to 'Atimwtioh,Aetyiv,Zdvegvgcr,Srwla,Gcntxsh,Ohrgery'
# row: 830 col: 2 : 'Action,Game,Sci-Fi,Shounen' changed to 'Srchjv,Tsme,Svo-Vu,Wkoinen'
# row: 616 col: 2 : 'Adventure,Crime,Drama' changed to 'Sgtdnfuxf,Zcine,Dedmx'
# row: 71 col: 2 : 'Action,Adventure,Comedy,Kids' changed to 'Aetiog,Aavsntuwe,Cjjgfy,Jidd'
# row: 126 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Ankoetkoi,Action,Dedka,Vcp-Vh'
# row: 427 col: 2 : 'Drama,Kids' changed to 'Drama,Yidf'
# row: 688 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,Romance,Thriller' changed to 'Cmimerkmi,Achkog,Aqtentuww,Gpmeqy,Dsqma,Xdmvcsi,Hnftodr,Somanec,Thdkmper'
# row: 691 col: 2 : 'Action,Mecha,Sci-Fi,Space' changed to 'Zctpou,Mecra,Sck-Vi,Fkqwz'
# row: 390 col: 2 : 'Animation' changed to 'Xkimagipt'
# row: 821 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Amikwvhkt,Vimqqy,Sgaka,Rokdjcx'
# row: 941 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'Acvlph,Xcdwnrggw,Wautwfy,Nqzhc'
# row: 504 col: 2 : 'Drama,Sci-Fi' changed to 'Cralc,Sxl-Xo'
# row: 1446 col: 2 : 'Action,Hentai,Supernatural' changed to 'Acfuon,Menhai,Rhpcrnzjurwp'
# row: 1060 col: 2 : 'Comedy' changed to 'Cimxby'
# row: 1280 col: 2 : 'Drama,History,War' changed to 'Vrznz,Givdocy,Qar'
# row: 20 col: 2 : 'Action,Adventure,Mystery,Sci-Fi' changed to 'Wctpon,Wdcdnturv,Mtdtxfy,Rci-Fp'
# row: 335 col: 2 : 'Animation,Short' changed to 'Ajimatyob,Ryoeh'
# row: 189 col: 2 : 'Adventure,Fantasy' changed to 'Adventhse,Swvneab'
# row: 271 col: 2 : 'Animation' changed to 'Dnhjafllj'
# row: 143 col: 2 : 'School,Shoujo' changed to 'Fvioou,Xhouup'
# row: 1486 col: 2 : 'Adventure,Sports' changed to 'Afbdnekrf,S'mrga'
# row: 450 col: 2 : 'Magic' changed to 'Megig'
# row: 104 col: 2 : 'Animation' changed to 'Aniizyupi'
# row: 1399 col: 2 : 'Adventure,Mecha,Sci-Fi,Shounen' changed to 'Aeventure,Oscvs,Xzy-Fi,Siounen'
# row: 1283 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Animebomt,Romeqj,Hsntasj'
# row: 250 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Sdnzjnyfc,Xattwsy,Kiqs'
# row: 947 col: 2 : 'Biography,Drama,Music' changed to 'Himtfwpyb,Sfwka,Jmspx'
# row: 670 col: 2 : 'Animation,Comedy' changed to 'Anjmadhii,Gikeqy'
# row: 1570 col: 2 : 'Animation,Short' changed to 'Zghjahljj,Whote'
# row: 419 col: 2 : 'Comedy,Fantasy' changed to 'Romtdy,Fcbcway'
# row: 744 col: 2 : 'Comedy,Drama,Romance' changed to 'Somdqy,Dgana,Xkmahce'
# row: 1264 col: 2 : 'Animation,Action,Drama,Fantasy' changed to 'Anikqjijh,Wgriiv,Vrzmq,Wwgjcsr'
# row: 1305 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Stjlxtpon,Ectooj,Vcl-Du'
# row: 1410 col: 2 : 'Animation,Drama,Fantasy,Mystery' changed to 'Wbllztiok,Deana,Fxvjway,Lyrtxry'
# row: 1351 col: 2 : 'Animation,Action,Comedy,Sci-Fi' changed to 'Cnikatpon,Acfion,Zomedf,Fgp-Su'
# row: 1281 col: 2 : 'Hentai' changed to 'Hental'
# row: 253 col: 2 : 'Documentary,Short,Biography' changed to 'Ckvmnrjtarj,Amott,Flogcdihy'
# row: 763 col: 2 : 'Horror,Shoujo' changed to 'Horror,Sfohjm'
# row: 1532 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'Dvyfjbyre,Cimfdt,SmpcelwMufe'
# row: 1528 col: 2 : 'Animation,Comedy,Drama,Fantasy,Sci-Fi' changed to 'Cnijauyoj,Comeaj,Crama,Fantavy,Wci-Gl'
# row: 965 col: 2 : 'Short,Action' changed to 'Wijgt,Avtlon'
# row: 348 col: 2 : 'Documentary,Short' changed to 'Gockmwntarf,Sfort'
# row: 360 col: 2 : 'Animation,Fantasy' changed to 'Snikauion,Retcaah'
# row: 948 col: 2 : 'Animation,Comedy,Romance' changed to 'Animetioh,Vpneqy,Vkmancv'
# row: 1229 col: 2 : 'Animation,Crime,Horror,Mystery,Thriller' changed to 'Xiimeulob,Efomw,Viwrir,Mgwtegy,Bjsikmgr'
# row: 511 col: 2 : 'Adventure' changed to 'Aqvcntgrq'
# row: 299 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Cokzvu,Sojabee,SpictorLlfe'
# row: 807 col: 2 : 'Music,Shoujo,SliceofLife,Sports' changed to 'Kuwyc,Shoujo,XlkxeofLhfz,Rplrds'
# row: 310 col: 2 : 'Drama,Historical' changed to 'Qvzmc,Gpsnkvpdzl'
# row: 614 col: 2 : 'Fantasy,Kids' changed to 'Daicash,Yybx'
# row: 857 col: 2 : 'Animation,Short' changed to 'Auikxeilj,Sfjru'
# row: 1173 col: 2 : 'Crime,Drama,Thriller' changed to 'Sgjos,Dtaja,Thrmklrr'
# row: 438 col: 2 : 'Action,Mecha,Sci-Fi' changed to 'Dccymi,Mebiw,Wxl-Xi'
# row: 936 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Wgimzdiou,Acgipb,Dvexjggrf,Wxntdxy'
# row: 24 col: 2 : 'Action,Comedy,Drama,MartialArts,SliceofLife,Sports' changed to 'Dftiln,Clifsy,Dcama,IzddhclAtfs,XmicvifLive,S[pcts'
# row: 725 col: 2 : 'Animation,Short' changed to 'Cnimation,Fhofr'
# row: 1447 col: 2 : 'Adventure,Fantasy,Kids,Magic' changed to 'Ccntnnnre,Hwbrcsr,Hiea,Jegpc'
# row: 319 col: 2 : 'Action,Comedy,Ecchi,Shounen,Sports' changed to 'Schppn,Gokedy,Axcrj,Wfkhnvn,Vpocta'
# row: 377 col: 2 : 'Animation,Action,Comedy,Drama,Sci-Fi,Western' changed to 'Xnmnathok,Aetnik,Xongdy,Gwaka,Sel-Fn,Eevtzgb'
# row: 1125 col: 2 : 'Action' changed to 'Scykjn'
# row: 678 col: 2 : 'Action,Comedy,Kids,Vampire' changed to 'Qctkoh,Spkevy,Nygs,Vamkirx'
# row: 976 col: 2 : 'Comedy,Kids' changed to 'Rkjedy,Juvs'
# row: 655 col: 2 : 'Fantasy,Kids' changed to 'Neutxdy,Klar'
# row: 1376 col: 2 : 'Animation,Short,Action' changed to 'Xnimajyon,Ahoft,Drgion'
# row: 477 col: 2 : 'Kids' changed to 'Yigs'
# row: 719 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Qnomcvmmk,Zijtvv,Drxka,Waibzfy,Rumencd'
# row: 687 col: 2 : 'Comedy,Fantasy' changed to 'Xoneey,Favtwsi'
# row: 1397 col: 2 : 'Comedy' changed to 'Cmmxsb'
# row: 685 col: 2 : 'Comedy' changed to 'Epmqcy'
# row: 1034 col: 2 : 'Drama,SliceofLife' changed to 'Drwkz,DlhdrogMiwe'
# row: 1553 col: 2 : 'Comedy' changed to 'Slmwfu'
# row: 1 col: 2 : 'Hentai' changed to 'Hrnhau'
# row: 643 col: 2 : 'Romance,Sports' changed to 'Sooznxa,Vpiera'
# row: 437 col: 2 : 'Short,Comedy' changed to 'Shkrb,Gukxdv'
# row: 1543 col: 2 : 'Drama,Historical,Military' changed to 'Drama,Mifjkticxl,Jiljjarr'
# row: 781 col: 2 : 'Hentai' changed to 'Mdktai'
# row: 312 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Cninatmot,Sctlln,Wdfenbmrv,Fanfzsg,Sci-Fl'
# row: 12 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'Cokgdy,Ffi-Fi,Skace'
# row: 1008 col: 2 : 'Action,Drama,Seinen' changed to 'Agylmn,Qrala,Sfnmqg'
# row: 1402 col: 2 : 'Action,Psychological,Shounen,Supernatural,Thriller' changed to 'Qwhulm,Prtckopogoran,Svlhnek,Suoeevagurzn,Thrikleg'
# row: 1425 col: 2 : 'Animation,Adventure,Comedy,Family,Fantasy,Sci-Fi' changed to 'Anllatiom,Aetxvtbtw,Womedi,Fdklug,Fzthasb,Szi-Fu'
# row: 59 col: 2 : 'Animation,Drama,Fantasy' changed to 'Sbikenoon,Feckw,Xantasy'
# row: 303 col: 2 : 'Animation,Short' changed to 'Ablmayhon,Skort'
# row: 170 col: 2 : 'Comedy' changed to 'Epnegy'
# row: 1309 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Sci-Fi' changed to 'Emomqdion,Sdysnjkre,Bgdma,Fqlily,Fduuasu,Vdi-Fh'
# row: 274 col: 2 : 'Animation,Action,Fantasy' changed to 'Ajimajuji,Sctlpn,Xwntqfy'
# row: 1020 col: 2 : 'Historical' changed to 'Rkvciruwau'
# row: 113 col: 2 : 'Hentai,Horror' changed to 'Mentai,Nlrrut'
# row: 906 col: 2 : 'Animation,Action,Comedy,Family' changed to 'Zmpmxtklu,Zxfpkn,Rioxdf,Wwiimb'
# row: 1405 col: 2 : 'Comedy,Romance,School,Shoujo,SliceofLife' changed to 'Xomegy,Rlmance,Wchoil,Vhuumk,SpixzifPife'
# row: 732 col: 2 : 'Animation,Action,Fantasy' changed to 'Animxdllj,Sbciin,Dajtast'
# row: 1541 col: 2 : 'Comedy,Ecchi,Fantasy,Romance,SliceofLife' changed to 'Cokqdy,Eezyi,Sqbtasy,Einqgcq,SlicvorJpfe'
# row: 1492 col: 2 : 'Ecchi,Music' changed to 'Erchl,Kosiv'
# row: 1406 col: 2 : 'Animation,Short' changed to 'Aummajiob,Vhorv'
# row: 604 col: 2 : 'Comedy,Demons,Ecchi,Fantasy,Romance,Seinen' changed to 'Fokcby,Dtiomx,Dxchl,Faktzsy,Roiebcd,Sglkdn'
# row: 676 col: 2 : 'Fantasy,Kids' changed to 'Ywkbasu,Ypvs'
# row: 1596 col: 2 : 'Hentai' changed to 'Grntzi'
# row: 972 col: 2 : 'Drama' changed to 'Dfaoa'
# row: 1004 col: 2 : 'Animation,Short,Comedy' changed to 'Wvlmcflon,Shprt,Vomvbv'
# row: 297 col: 2 : 'Animation,Action,Comedy' changed to 'Avimahioi,Xdtion,Comrey'
# row: 465 col: 2 : 'Animation,Comedy' changed to 'Wtimajipu,Comvgj'
# row: 114 col: 2 : 'Drama' changed to 'Dcwna'
# row: 835 col: 2 : 'Animation,Action,Comedy' changed to 'Aghlabioh,Azvokn,Zokefh'
# row: 1403 col: 2 : 'Short,Adventure,Family' changed to 'Shkrt,Wsvenbgtx,Fzmhly'
# row: 235 col: 2 : 'Music' changed to 'Ilxlw'
# row: 968 col: 2 : 'Action,Sci-Fi' changed to 'Aztulk,Sri-Wn'
# row: 1482 col: 2 : 'Animation,Short' changed to 'Amooahooj,Snkrr'
# row: 110 col: 2 : 'Mecha,Sci-Fi' changed to 'Mecja,Swi-Fj'
# row: 470 col: 2 : 'Animation,Comedy,Drama' changed to 'Anilagion,Xolegi,Dtamw'
# row: 291 col: 2 : 'Adventure,Kids' changed to 'Wfgvndurg,Liss'
# row: 1477 col: 2 : 'Comedy,Ecchi,Fantasy,Game' changed to 'Woktdy,Eecri,Ysnjzxy,Fxmr'
# row: 931 col: 2 : 'Drama' changed to 'Erzks'
# row: 1210 col: 2 : 'Comedy' changed to 'Comebu'
# row: 306 col: 2 : 'Mystery' changed to 'Ntstzgy'
# row: 1413 col: 2 : 'Adventure,Family,Fantasy' changed to 'Aqdwgtode,Fqluln,Nantqry'
# row: 1508 col: 2 : 'Adventure,Comedy,Fantasy,Mecha,Shounen' changed to 'Advxbuhea,Dlldcy,Nwitdry,Mwshw,Sfomnen'
# row: 944 col: 2 : 'Animation' changed to 'Wkpnatlin'
# row: 121 col: 2 : 'Animation,Action,Crime,Drama,Horror,Mystery,Thriller' changed to 'Smiostpkn,Scujoh,Wrhje,Drama,Jlcrir,Nysceru,Tmrjloer'
# row: 808 col: 2 : 'Drama,Family' changed to 'Cvqmz,Rqjily'
# row: 1340 col: 2 : 'Animation' changed to 'Ajomation'
# row: 810 col: 2 : 'Comedy' changed to 'Xumegh'
# row: 1548 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Aupmabpli,Avrhob,Wimeey,Waibasb,Rumabcf'
# row: 593 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Wcvfjtuge,Zojtsy,Fakbqsy,Kkss'
# row: 1108 col: 2 : 'School,SliceofLife' changed to 'Swmkil,XuizfpsLifw'
# row: 969 col: 2 : 'Animation' changed to 'Anioejipn'
# row: 1424 col: 2 : 'Adventure,Comedy,Kids' changed to 'Zdvcnture,Conegy,Kocx'
# row: 995 col: 2 : 'Hentai' changed to 'Rgntei'
# row: 175 col: 2 : 'Action,Adventure,Historical,Samurai,Seinen' changed to 'Abgioh,Aedehgitq,Fjduuxkxcn,Damyrzm,Xejhft'
# row: 743 col: 2 : 'Drama,Historical,SliceofLife' changed to 'Vramd,Ruadorhcaj,WomveifLidg'
# row: 1485 col: 2 : 'Kids,Sports' changed to 'Nybw,Spifts'
# row: 237 col: 2 : 'Comedy,Military,Parody,Sci-Fi,Space' changed to 'Xiisdy,Militqfu,Iafmay,Sfi-Fn,Sosce'
# row: 1009 col: 2 : 'Animation,Comedy,Music' changed to 'Qnlmwdlun,Cukefy,Muspc'
# row: 62 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Anikdgjon,Aveimn,Adrcnjuvx,Wantavh'
# row: 418 col: 2 : 'Action,Fantasy,Shounen,SuperPower,Supernatural,Vampire' changed to 'Aetion,Fqbdssr,Vflhmrm,Dm[egPoreg,Vbpvrvatugqn,Fxmpmdt'
# row: 434 col: 2 : 'Action,Adventure,Comedy,Magic,Mecha,Sci-Fi' changed to 'Cctjoh,Abnehcuwq,Cumevy,Oqgjs,Mwchs,Sbn-Fl'
# row: 223 col: 2 : 'Animation,Fantasy,Horror' changed to 'Anumqcpji,Fahtqfy,Hogrkr'
# row: 606 col: 2 : 'Drama,Music,Romance' changed to 'Dfama,Knwic,Tukanre'
# row: 1382 col: 2 : 'Kids,SliceofLife' changed to 'Lpdw,SlndqogLife'
# row: 955 col: 2 : 'Comedy,Magic,Shoujo' changed to 'Domeqb,Magig,Shmyjo'
# row: 373 col: 2 : 'History' changed to 'Hjstory'
# row: 358 col: 2 : 'Comedy,Romance,Seinen,SliceofLife' changed to 'Comesy,Eomznce,Xvjjen,DlkzxofUixg'
# row: 981 col: 2 : 'Animation,Comedy,Music' changed to 'Eiimztpui,Comacj,Mtfur'
# row: 451 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Anilatiok,Cjieay,Awn-Vi'
# row: 1374 col: 2 : 'Comedy,Parody' changed to 'Xukeby,Parogy'
# row: 5 col: 2 : 'Comedy,Romance,School,Seinen,SliceofLife' changed to 'Ckoeah,Wioanse,Sfhlpu,Fcimev,AlifgpfLhfg'
# row: 1422 col: 2 : 'Comedy,Kids,SuperPower' changed to 'Comedy,Khdd,WopdrOmqxr'
# row: 343 col: 2 : 'Hentai' changed to 'Vehvai'
# row: 1272 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy' changed to 'Anokwtlob,Qqvemhirg,Drcls,Dsmnuu,Fevuwsb'
# row: 1273 col: 2 : 'Action,Adventure,Fantasy,Hentai' changed to 'Eebiun,Adnentjwa,Wznvasu,Hcneeh'
# row: 1147 col: 2 : 'Comedy,Kids' changed to 'Sokddj,Kibv'
# row: 347 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Anpmwtplm,Wctijb,Rdm-Fi'
# row: 145 col: 2 : 'Comedy,Fantasy,Shoujo' changed to 'Dunedj,Fanjady,Rfmbjo'
# row: 226 col: 2 : 'Comedy,Parody' changed to 'Comcdn,Pwvkbu'
# row: 600 col: 2 : 'Animation,Sci-Fi' changed to 'Akhmaniin,Xxm-Fi'
# row: 1437 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'Acvipg,Wvvsteore,Mecha,Sxi-Vi'
# row: 1463 col: 2 : 'Animation,Action,Music,Romance,Sci-Fi' changed to 'Annmajpon,Qcblkh,Musis,Gmmdvwt,Acj-Fl'
# row: 431 col: 2 : 'Action,Animation,Sci-Fi' changed to 'Cchiun,Dmmjxhioj,Scn-Yi'
# row: 232 col: 2 : 'Animation,Action' changed to 'Animetkok,Actnmn'
# row: 1232 col: 2 : 'Comedy,Seinen,SliceofLife' changed to 'Comeey,Stltvv,SplczknNife'
# row: 512 col: 2 : 'Action' changed to 'Achlon'
# row: 1259 col: 2 : 'Comedy,Kids' changed to 'Conqdr,Nudf'
# row: 886 col: 2 : 'Comedy,Parody' changed to 'Comeey,Ixwody'
# row: 39 col: 2 : 'Comedy,Crime' changed to 'Romvdy,Ctilq'
# row: 322 col: 2 : 'Hentai' changed to 'Yebuqi'
# row: 885 col: 2 : 'Action,Comedy,Mecha,Sci-Fi' changed to 'Wcgkmn,Cojedy,Mtbhe,Fdi-Fh'
# row: 815 col: 2 : 'Drama' changed to 'Dsemw'
# row: 111 col: 2 : 'Animation,Comedy' changed to 'Enjkadiui,Sklqdy'
# row: 34 col: 2 : 'SliceofLife' changed to 'XulxflfLiys'
# row: 278 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'Cnhoarhon,Agnypm,Acvemyurw,Cmowdv,Wxmily,Nantzsj'
# row: 1367 col: 2 : 'Animation,Short' changed to 'Dniiztmun,Shorc'
# row: 912 col: 2 : 'Animation' changed to 'Wnimaryjn'
# row: 971 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Ethmarylb,Sctopv,Cojady,Faitqry,Rokcgge'
# row: 1564 col: 2 : 'News' changed to 'Nzcv'
# row: 1233 col: 2 : 'Adventure,Comedy,Mystery' changed to 'Zdeqktkxe,Dpnwdg,Lyvtett'
# row: 605 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi,Thriller' changed to 'Ankmxtioi,Wvjipn,Adyentyre,Cimeey,Sci-Fy,Drvlkker'
# row: 383 col: 2 : 'Action,Adventure,Comedy,Fantasy,Magic' changed to 'Qwcoot,Aavenfute,Ckjedy,Rentasy,Ndgic'
# row: 864 col: 2 : 'Comedy' changed to 'Bomedy'
# row: 251 col: 2 : 'Hentai' changed to 'Jahuwi'
# row: 26 col: 2 : 'Comedy' changed to 'Fooagy'
# row: 410 col: 2 : 'Animation,Adventure' changed to 'Euojctnog,Wgvebbutz'
# row: 1591 col: 2 : 'Action,Adventure,Comedy,Fantasy,Shounen,SuperPower' changed to 'Actkjj,Wgcencbeg,Ronsdy,Hwneari,Dhouiej,Sjper'jsar'
# row: 599 col: 2 : 'Drama,Fantasy,Kids' changed to 'Dewix,Fannqsy,Lifd'
# row: 1439 col: 2 : 'Comedy,Parody' changed to 'Roocdj,Pzclqy'
# row: 446 col: 2 : 'Drama,Military,Sci-Fi,Space' changed to 'Grqma,Oilovsdy,Dcu-Fi,Wpxgt'
# row: 61 col: 2 : 'Kids' changed to 'Yiaf'
# row: 1536 col: 2 : 'Adventure,Comedy,Drama' changed to 'Zvxejtute,Zkmesy,Drslw'
# row: 1368 col: 2 : 'Animation,Comedy' changed to 'Anmmacion,Wiieqj'
# row: 881 col: 2 : 'Comedy' changed to 'Comxey'
# row: 197 col: 2 : 'Animation' changed to 'Skimaviln'
# row: 1558 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Sci-Fi' changed to 'Dnjjaujon,Afjion,Wdtqndkrf,Qcxia,Fxhtavg,Vey-Nj'
# row: 932 col: 2 : 'Drama,Hentai,Romance,Sci-Fi' changed to 'Drqma,Gwital,Tpmxjct,Ssi-Dh'
# row: 305 col: 2 : 'Crime' changed to 'Bwiie'
# row: 1265 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance,Sci-Fi' changed to 'Xhhmajmpj,Qetikg,Vomeen,Fcntasy,Rokaier,Dzi-Fi'
# row: 992 col: 2 : 'Historical' changed to 'Hiryjribxj'
# row: 631 col: 2 : 'Animation' changed to 'Znhoatilt'
# row: 533 col: 2 : 'Animation,Short,Action,Drama,Fantasy,Romance' changed to 'Anjlatiog,Sfost,Crtkoj,Dgcmd,Sxgrwsj,Tkosmed'
# row: 742 col: 2 : 'Historical,Romance,Shoujo,Supernatural' changed to 'Hifukrigzo,Rkmamrv,Shoujo,Snoefnwrurwp'
# row: 1441 col: 2 : 'Animation,Sci-Fi' changed to 'Aimkqtmob,Sxk-Yl'
# row: 1501 col: 2 : 'Kids,Shoujo,Supernatural' changed to 'Kudf,Fkokmu,Sipwrnxtntal'
# row: 413 col: 2 : 'Hentai' changed to 'Yzueah'
# row: 1169 col: 2 : 'Short' changed to 'Rkmet'
# row: 1407 col: 2 : 'Animation,Sci-Fi' changed to 'Wiimavijn,Vcm-Fk'
# row: 68 col: 2 : 'Hentai,Magic,Supernatural' changed to 'Hebtsn,Mxglb,Su[crkzyucaj'
# row: 522 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Horror' changed to 'Ajnizyiom,Wvbkun,Qdvemykre,Cjledv,Erama,Dantawv,Joewot'
# row: 559 col: 2 : 'Animation,Action,Comedy' changed to 'Wniisyijg,Aetiuh,Coneqt'
# row: 1116 col: 2 : 'Comedy,Drama,Fantasy,Music' changed to 'Comwqy,Crenw,Vattwry,Ihsmc'
# row: 1098 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'Animxcnmn,Actikv,Adnsnvure,Fokevy,Nammly,Fwtrcsr'
# row: 546 col: 2 : 'Demons,Harem,Hentai,School,Supernatural' changed to 'Sdionv,Haddo,Fcntei,Fcrlol,Dukegnaturql'
# row: 1207 col: 2 : 'Animation,Comedy' changed to 'Qminsnjjg,Cpiabh'
# row: 1372 col: 2 : 'Action,Comedy,Ecchi,Sci-Fi,Shounen,Space,Sports' changed to 'Asfhik,Gmmebu,Archn,Ffi-Yi,Srlgnvk,Skees,Spprff'
# row: 634 col: 2 : 'Animation' changed to 'Amokegiob'
# row: 1585 col: 2 : 'Action,Comedy,Historical,Parody,Samurai,Sci-Fi,Shounen' changed to 'Acbiog,Glkevf,Gkstorkxal,Parucu,Xajoran,Xrn-Fl,Shouten'
# row: 415 col: 2 : 'Comedy,Fantasy,Supernatural' changed to 'Guledj,Rdntasy,Xupetnqtnesm'
# row: 962 col: 2 : 'Documentary,Short' changed to 'Djskjaitagn,Shjft'
# row: 1521 col: 2 : 'Hentai' changed to 'Revtei'
# row: 186 col: 2 : 'Animation,Comedy' changed to 'Cblmdtmkm,Rmnevt'
# row: 1023 col: 2 : 'Comedy,Ecchi,Mecha,Parody,Sci-Fi,Shounen,SuperPower' changed to 'Cmordj,Ercrk,Oecnd,Kzgldg,Sco-Ni,Fhplnen,SupetPuevd'
# row: 254 col: 2 : 'Animation,Comedy,Family' changed to 'Snimxtukh,Rokedj,Fcmimy'
# row: 1592 col: 2 : 'Animation,Short' changed to 'Xukmanipn,Shorg'
# row: 134 col: 2 : 'Fantasy,Magic,Shoujo' changed to 'Fxutqvj,Nanix,Whpujp'
# row: 1484 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'Cdvfttire,Dgaka,Vcj-Fm'
# row: 1507 col: 2 : 'Comedy,Parody' changed to 'Flmrqu,Paridy'
# row: 1373 col: 2 : 'Hentai' changed to 'Hdntay'
# row: 1211 col: 2 : 'Animation,Sci-Fi' changed to 'Stnkdyhiv,Aco-Vu'
# row: 316 col: 2 : 'Animation,Comedy' changed to 'Wmomdfikh,Cjjedg'
# row: 93 col: 2 : 'Comedy,SliceofLife' changed to 'Vjmedy,SjicwlxUlfe'
# row: 1185 col: 2 : 'Hentai' changed to 'Hengai'
# row: 289 col: 2 : 'Kids,Music' changed to 'Lidd,Klvne'
# row: 2 col: 2 : 'Animation' changed to 'Chimxnpon'
# row: 1016 col: 2 : 'Animation' changed to 'Aglmctooj'
# row: 764 col: 2 : 'Animation,Short' changed to 'Aukmacykn,Anott'
# row: 193 col: 2 : 'Action,Adventure,Shounen,SuperPower' changed to 'Qwnooj,Acvemvhev,Rhoyizn,WkperPosff'
# row: 720 col: 2 : 'Horror,Psychological' changed to 'Jkgrlt,Pstehouoeizao'
# row: 219 col: 2 : 'Hentai' changed to 'Nrjbqh'
# row: 1225 col: 2 : 'Drama' changed to 'Dtenc'
# row: 854 col: 2 : 'Animation,Adventure,Comedy,Fantasy' changed to 'Auikcyllh,Avdentute,Goksgy,Gsvjasj'
# row: 1343 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Zomedj,Fanncry,Yudv'
# row: 1132 col: 2 : 'Animation,Comedy,Romance' changed to 'Cnlkzgiog,Comtbh,Solwjed'
# row: 330 col: 2 : 'Action,Fantasy,Shounen,Supernatural' changed to 'Azjnok,Fantqdy,Shpynev,Fbprsuqtbral'
# row: 1342 col: 2 : 'Drama' changed to 'Dtama'
# row: 1204 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Auioxtiub,Acnhon,Dei-Gm'
# row: 630 col: 2 : 'Animation' changed to 'Cmolwyion'
# row: 973 col: 2 : 'Hentai' changed to 'Hqntai'
# row: 480 col: 2 : 'Documentary,Comedy,History,War' changed to 'Dockktntdrj,Cinesj,Nistprh,Cds'
# row: 320 col: 2 : 'Mecha,Parody,Sci-Fi' changed to 'Orgkz,Pasogy,Dfi-Fi'
# row: 1246 col: 2 : 'Animation,Short' changed to 'Cnjmzthom,Short'
# row: 607 col: 2 : 'Animation,Action,Adventure,Crime,Mystery' changed to 'Zninxtiit,Zcrion,Adfsnburq,Cwold,Myfcsry'
# row: 1078 col: 2 : 'Hentai' changed to 'Hwhuzo'
# row: 851 col: 2 : 'Action,Adventure,Demons,Game,Shounen' changed to 'Asgipb,Ddvvntjfw,Sqmonr,Gams,Vhjbnrn'
# row: 1224 col: 2 : 'Action,Sport' changed to 'Agnnmt,Apott'
# row: 277 col: 2 : 'Drama' changed to 'Dralq'
# row: 18 col: 2 : 'Animation' changed to 'Dbykatjoh'
# row: 1529 col: 2 : 'Animation' changed to 'Wbimweoom'
# row: 1241 col: 2 : 'Animation,Short,Comedy' changed to 'Snlmxjkok,Snmsj,Wmmedu'
# row: 409 col: 2 : 'Fantasy,Kids' changed to 'Yanhady,Knvs'
# row: 582 col: 2 : 'Historical,Mystery,Shounen' changed to 'Fistjcicak,Iyanerh,Skmugen'
# row: 1242 col: 2 : 'Animation,Comedy' changed to 'Qvumatloj,Xokqdb'
# row: 1230 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'Advfnvkrt,Afala,Deo-Wl'
# row: 1215 col: 2 : 'Action,Adventure,Demons,Fantasy,Game,Kids,Magic,Sci-Fi,Supernatural' changed to 'Abdion,Advzkrkfe,Swolbs,Ydufafy,Gsmr,Jyva,Oabnb,Sci-Fi,Sulexnzeudqj'
# row: 1409 col: 2 : 'Animation,Action,Comedy,Drama' changed to 'Znikwbimn,Eztmuv,Cjmwdy,Dramc'
# row: 809 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'Akyoebiun,Ccfkon,Ysntash,Yaje-Agpw,Scy-Vi'
# row: 652 col: 2 : 'Animation,Short' changed to 'Agimdcnpj,Xrowt'
# row: 508 col: 2 : 'Supernatural' changed to 'Soozrnatuczp'
# row: 757 col: 2 : 'Sci-Fi,Space' changed to 'Xcm-Si,Rpqce'
# row: 332 col: 2 : 'Comedy,Fantasy' changed to 'Cokeey,Fcgtady'
# row: 571 col: 2 : 'Adventure,Kids' changed to 'Adyzmtuse,Ihqv'
# row: 860 col: 2 : 'Animation' changed to 'Xninathmn'
# row: 1106 col: 2 : 'Animation' changed to 'Dnlmction'
# row: 1579 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Fpmedy,Fwnjarj,Nlvx'
# row: 1031 col: 2 : 'Action,Comedy,Ecchi,Fantasy,Harem,Magic,Romance' changed to 'Actlmn,Comxdi,Qwbno,Fxntesn,Hwrem,Keylc,Rokence'
# row: 1064 col: 2 : 'Comedy,Romance' changed to 'Domedu,Xojatcc'
# row: 550 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Annoqtlpv,Acbiuu,Sbi-Fi'
# row: 184 col: 2 : 'Comedy,SliceofLife' changed to 'Sokefi,SloczufLuff'
# row: 1559 col: 2 : 'Hentai' changed to 'Heuyxu'
# row: 544 col: 2 : 'Animation,Comedy,Romance' changed to 'Anpkatiot,Colfdg,Rpmagcz'
# row: 331 col: 2 : 'Animation,Adventure,Family,Fantasy,Mystery' changed to 'Whilajpig,Adbtntnww,Fannly,Rautaau,Kystewh'
# row: 1285 col: 2 : 'Comedy,Kids,Music' changed to 'Zokegy,Khds,Lhvkg'
# row: 459 col: 2 : 'Fantasy' changed to 'Semvasj'
# row: 105 col: 2 : 'Drama' changed to 'Erzmq'
# row: 1438 col: 2 : 'Comedy,Mecha' changed to 'Colzdg,Oefyc'
# row: 494 col: 2 : 'Family' changed to 'Nsmloy'
# row: 959 col: 2 : 'Action,Mecha,Sci-Fi,Shounen,SuperPower' changed to 'Aeciln,Jewiq,Swm-Wo,Shputgn,SkpzrPowed'
# row: 1468 col: 2 : 'Animation,Action,Drama,Fantasy,Sci-Fi' changed to 'Skijztpot,Aftlkb,Ccdmz,Faitwsj,Aei-Xj'
# row: 338 col: 2 : 'Kids' changed to 'Hhdf'
# row: 442 col: 2 : 'Action,Adventure,Horror,Mystery,Sci-Fi,War' changed to 'Axyiun,Wqeqhdkxe,Kivejs,Mnrgery,Sbh-Fi,Dwr'
# row: 940 col: 2 : 'Animation,Comedy,Drama' changed to 'Anioxgyjg,Eomadu,Eswlw'
# row: 785 col: 2 : 'Animation,Adventure,Drama,Sci-Fi' changed to 'Anomdblui,Xdvxntuvw,Frwme,Aei-Fi'
# row: 1514 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Agytvture,Zuiedj,Ssntefj'
# row: 884 col: 2 : 'Animation' changed to 'Ahimatoon'
# row: 1274 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'Ablkatiun,Rhjdt,Acyhov,Acventmre,Fxbyaff'
# row: 424 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Snimstikb,Qcvnob,Aebentlrz,Fcntcsr,Sci-Fi'
# row: 714 col: 2 : 'Kids,Sci-Fi' changed to 'Kies,Xcl-Fi'
# row: 1092 col: 2 : 'Hentai' changed to 'Grnjdi'
# row: 1320 col: 2 : 'Action,Adventure,Sci-Fi,Sport' changed to 'Wdtupn,Wdnsntuge,Rcu-Wu,Soott'
# row: 1206 col: 2 : 'Drama,Fantasy,Mystery,Romance,School' changed to 'Brela,Gwntdfy,Mjvyefn,Xomcnxv,Srfpul'
# row: 580 col: 2 : 'Animation,Action,Adventure,Comedy,Crime,Fantasy,Mystery,Sci-Fi' changed to 'Xnimzfipj,Ccflog,Wdbenbuft,Bkjqqf,Exhne,Wandafi,Nystery,Dcj-Hi'
# row: 891 col: 2 : 'Comedy,Kids,Shoujo' changed to 'Zomefj,Kjds,Xnouji'
# row: 1231 col: 2 : 'Fantasy,Kids,Magic,Shoujo' changed to 'Gwngswt,Klvs,Kabic,Aimuou'
# row: 497 col: 2 : 'Animation,Fantasy' changed to 'Annkafhmn,Fantast'
# row: 874 col: 2 : 'Comedy' changed to 'Bongqy'
# row: 21 col: 2 : 'Comedy' changed to 'Cljvfy'
# row: 890 col: 2 : 'Animation,Short' changed to 'Xnjowfukn,Xhuee'
# row: 1119 col: 2 : 'Comedy,Fantasy' changed to 'Eimtdi,Dqnjawb'
# row: 827 col: 2 : 'Comedy,Historical' changed to 'Comvby,Rlsvoriwzu'
# row: 281 col: 2 : 'Animation,Short' changed to 'Anijajkmh,Shogt'
# row: 478 col: 2 : 'Animation,Comedy' changed to 'Ckijatyoi,Ckmedt'
# row: 1121 col: 2 : 'Animation' changed to 'Xnnmstlju'
# row: 707 col: 2 : 'Adventure,Kids' changed to 'Aavfntlwz,Hias'
# row: 602 col: 2 : 'Adventure,Comedy,Fantasy,Mystery,Sci-Fi,Shounen' changed to 'Advtncutr,Epoedj,Wqntqsf,Muwhrrr,Dcm-Fk,Wkoujen'
# row: 853 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'Ectijj,Zstegture,Vsttafy,Whonneg'
# row: 640 col: 2 : 'Animation,Sci-Fi' changed to 'Zniiqtkpn,Xfm-Si'
# row: 1354 col: 2 : 'Animation,Drama,Fantasy,Romance' changed to 'Athmaniog,Vsaja,Fwtvaft,Roncnzt'
# row: 1296 col: 2 : 'Animation,Comedy,Drama' changed to 'Xuijahkon,Dkjeqb,Qrwmd'
# row: 905 col: 2 : 'Animation,Drama,Sci-Fi' changed to 'Cnmmatioj,Ataks,Rbi-Fi'
# row: 56 col: 2 : 'Comedy,Ecchi,Mecha,Romance,Sci-Fi' changed to 'Comedy,Wdcji,Kfchw,Xijavce,Sgm-Ri'
# row: 172 col: 2 : 'Comedy' changed to 'Ejkzfy'
# row: 1181 col: 2 : 'Game-Show,Talk-Show' changed to 'Tsox-Dhos,Ealh-Syoc'
# row: 883 col: 2 : 'Action,Romance' changed to 'Actiob,Fomcnrw'
# row: 49 col: 2 : 'Drama,Horror,Mystery' changed to 'Fgwkx,Hprrpx,Mivberb'
# row: 1339 col: 2 : 'Action,MartialArts' changed to 'Acciun,OwrvialDrgv'
# row: 745 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Sci-Fi,Shounen' changed to 'Xdedntngs,Rmmqbh,Yeidsry,Kifs,Dsh-Fl,Svjuten'
# row: 36 col: 2 : 'Action,Drama' changed to 'Wccjog,Dsqoa'
# row: 1386 col: 2 : 'Comedy,Sci-Fi' changed to 'Cojwdn,Xgi-Di'
# row: 639 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Astvjtugf,Wckfasy,Jibv'
# row: 370 col: 2 : 'Animation,Family' changed to 'Anpnetjoj,Fsiyut'
# row: 597 col: 2 : 'Adventure,Comedy,Kids' changed to 'Evvwncurf,Cioeby,Yodf'
# row: 926 col: 2 : 'Adventure' changed to 'Wbvsjrnrz'
# row: 1024 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Snhjseion,Soixsj,Wrl-Vo'
# row: 501 col: 2 : 'Animation,Short,Music' changed to 'Anikatilk,Siuwt,Mudlc'
# row: 1445 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi' changed to 'Dtimwyuon,Eccjon,Dcwka,Tomakdw,Sdh-Si'
# row: 1325 col: 2 : 'Animation' changed to 'Qkloackkn'
# row: 806 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Anmmqviog,Somedy,Nanhasu,Elmancc'
# row: 669 col: 2 : 'Comedy,Ecchi,Kids,Shounen' changed to 'Fokddy,Gzcji,Kjds,Xnounen'
# row: 124 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Atomatujg,Comqdf,Dci-Fi'
# row: 118 col: 2 : 'Kids,Sports' changed to 'Kisw,Apurts'
# row: 838 col: 2 : 'Comedy,Drama' changed to 'Roledv,Dgsla'
# row: 1392 col: 2 : 'Action,Comedy,Historical,Samurai,Shounen' changed to 'Wvnlon,Solsdy,Klstoeical,Dqoutai,Vviimwn'
# row: 554 col: 2 : 'Historical' changed to 'Jistorjcal'
# row: 531 col: 2 : 'Comedy,Police' changed to 'Bumevy,Oikust'
# row: 484 col: 2 : 'Animation,Short,Action,War' changed to 'Dnhmajjun,Dmogt,Xeboug,Far'
# row: 1466 col: 2 : 'Fantasy,Romance,SliceofLife' changed to 'Xajtqxy,Romanww,SnucvknUoda'
# row: 165 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Shhmxtlon,Scfiog,Aavsntuxe,Scm-Fn'
# row: 1196 col: 2 : 'Fantasy' changed to 'Fdntasy'
# row: 770 col: 2 : 'Hentai' changed to 'Kenvai'
# row: 1306 col: 2 : 'Adventure,Kids' changed to 'Zafahtute,Lndv'
# row: 182 col: 2 : 'Action,Adventure,Comedy,Fantasy,Magic,Shounen' changed to 'Wctium,Advtvcute,Wjkedy,Fanfaan,Lacuf,Shkutxn'
# row: 847 col: 2 : 'Comedy,Sports' changed to 'Slmedy,Spkxgv'
# row: 671 col: 2 : 'Animation,Comedy' changed to 'Atumwdioj,Colxdv'
# row: 653 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Snnmxfiln,Cjmedf,Rqgyxfr'
# row: 629 col: 2 : 'Animation,Short' changed to 'Aupmxtioi,Rmlgt'
# row: 1510 col: 2 : 'Adventure,Fantasy,Historical' changed to 'Wseenuure,Nantzsy,Hidtofuxal'
# row: 1348 col: 2 : 'Adventure,Drama,Sci-Fi,Space' changed to 'Advvgfuwz,Dtwid,Fgu-Fi,Rlzce'
# row: 150 col: 2 : 'Adventure,Comedy,Fantasy,Shounen' changed to 'Advamhjfq,Gmmeeb,Fzivswy,Rhkuntj'
# row: 1160 col: 2 : 'Drama,Romance' changed to 'Cwaoa,Gujetze'
# row: 91 col: 2 : 'Fantasy,Mystery' changed to 'Favtesf,Mudbdxy'
# row: 982 col: 2 : 'Adventure,Comedy,Kids,SuperPower' changed to 'Abveiftre,Comfdj,Kigs,SupfxPoeed'
# row: 1481 col: 2 : 'Drama,Fantasy,Kids' changed to 'Drxmw,Xaunzay,Kibs'
# row: 721 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'Adrion,Qdvevture,Cilvdf,Vxttcdh,Kibs'
# row: 624 col: 2 : 'Animation,Romance' changed to 'Agnkwtkok,Rumqnee'
# row: 1540 col: 2 : 'Comedy,Sci-Fi' changed to 'Rimwdy,Sco-Xi'
# row: 636 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'Cwfiuk,Cooeqy,Hxdvm,Svi-Nl,Shomnwn,Soace'
# row: 1472 col: 2 : 'Animation,Short' changed to 'Anoiatiog,Vymgc'
# row: 1328 col: 2 : 'Comedy,Ecchi' changed to 'Cpjrei,Accik'
# row: 577 col: 2 : 'Adventure,Crime,Drama,History,Mystery,Thriller' changed to 'Advwntogd,Cvijs,Vcsna,Rjseory,Nnsnvtj,Rjcijpex'
# row: 352 col: 2 : 'Documentary' changed to 'Dowjkgnczry'
# row: 975 col: 2 : 'Hentai' changed to 'Ndnnel'
# row: 1010 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Mystery,Romance' changed to 'Ciimajnon,Devvttmcr,Vrama,Ywokjf,Fzvtdwj,Mysneey,Gmkanxr'
# row: 1535 col: 2 : 'Mystery,Shounen' changed to 'Ljxtsgy,Whobnvn'
# row: 694 col: 2 : 'Comedy,Police' changed to 'Gojedj,Ljlife'
# row: 1493 col: 2 : 'Animation,Comedy' changed to 'Enimauuon,Cljedf'
# row: 863 col: 2 : 'Action,Adventure,Comedy,Mystery,Shounen' changed to 'Wztimn,Wdvfntufe,Dmkgdg,Myshffn,Vhoutwh'
# row: 73 col: 2 : 'Animation,Fantasy,Music' changed to 'Qmpmqyoov,Fqknesy,Mysof'
# row: 1029 col: 2 : 'Comedy' changed to 'Cpmedy'
# row: 89 col: 2 : 'Comedy,Music,SliceofLife' changed to 'Comesg,Nudic,XlidxkfLyxe'
# row: 1349 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Ahinaniuj,Clmedi,Ddwlw,Rimance'
# row: 1391 col: 2 : 'Comedy,Talk-Show' changed to 'Cokegy,Dwlk-Sior'
# row: 1073 col: 2 : 'Animation,Comedy,Romance' changed to 'Abhmctpin,Ckkesy,Rpmajce'
# row: 345 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Wghkatiou,Acrijn,Xqyentjrw,Zpmwdy,Famtarv'
# row: 190 col: 2 : 'Comedy' changed to 'Xlmrdt'
# row: 344 col: 2 : 'Animation,Biography,Drama,History,Romance,War' changed to 'Anmmaciok,Hhogsaovg,Bwwma,Imsbiwn,Romcmde,Fzt'
# row: 541 col: 2 : 'Comedy,Kids' changed to 'Fooedg,Kids'
# row: 1216 col: 2 : 'Romance,SliceofLife' changed to 'Romatra,SplrxoxKufe'
# row: 733 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'Actikn,Cojesy,'mlicw,Vjpjien'
# row: 942 col: 2 : 'Animation' changed to 'Animxgiot'
# row: 176 col: 2 : 'Animation,Family' changed to 'Wmykzgion,Nalnly'
# row: 779 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'Slmzgy,Qcwnp,Iaren,Gloatbe'
# row: 166 col: 2 : 'Animation' changed to 'Annmavjkn'
# row: 103 col: 2 : 'Hentai,Yaoi' changed to 'Hcutwl,Bcoj'
# row: 163 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Cumeaj,Roiqjgt,FougeirUnse'
# row: 943 col: 2 : 'Comedy,SliceofLife' changed to 'Doidsi,SljcekdMifq'
# row: 1030 col: 2 : 'Animation' changed to 'Wnumztouu'
# row: 1251 col: 2 : 'Action,Drama,MartialArts,Shounen,SuperPower' changed to 'Dwhmjv,Dxalc,MzvbhalSrtw,Ayiuten,VnirdOowvr'
# row: 1453 col: 2 : 'Sci-Fi' changed to 'Ssi-Yl'
# row: 72 col: 2 : 'Fantasy,Kids,Supernatural' changed to 'Fagjwsy,Ylfx,Aupefjdymeaj'
# row: 879 col: 2 : 'Mecha,Military,Sci-Fi,Space' changed to 'Nrcha,Nplltwct,Vxi-Fh,Wkdcs'
# row: 1166 col: 2 : 'Action,War' changed to 'Aedlon,Swr'
# row: 792 col: 2 : 'Comedy,Romance,Seinen,SliceofLife' changed to 'Cimady,Rimqnct,Vrihej,RukftigPife'
# row: 138 col: 2 : 'Adventure,Sci-Fi' changed to 'Wavdnckra,Wbi-Fi'
# row: 46 col: 2 : 'Fantasy,Kids' changed to 'Fwhtxvy,Koqa'
# row: 1053 col: 2 : 'Animation,Drama,Romance' changed to 'Dnkmcciib,Afaoa,Rlowirz'
# row: 524 col: 2 : 'Drama,Fantasy,Harem,Romance,Shoujo' changed to 'Ecckc,Nanfash,Hzdqm,Dioencg,Fhohjo'
# row: 13 col: 2 : 'Adventure,Comedy' changed to 'Zceevjurz,Gmjecb'
# row: 783 col: 2 : 'Action,Drama,Sci-Fi,Space' changed to 'Acjjuh,Agqld,Fxy-Hm,Vpqfe'
# row: 620 col: 2 : 'Animation,Comedy,Fantasy,Horror,Romance' changed to 'Silmwtpov,Cmirdh,Gqntwfg,Nprrpr,Gukamcw'
# row: 177 col: 2 : 'Animation,Adventure,Comedy,Family' changed to 'Wnmlwtuou,Qdvdnturx,Cumtef,Faminj'
# row: 1286 col: 2 : 'Animation,Family,Fantasy' changed to 'Evmkauiou,Vammly,Ywbtcff'
# row: 665 col: 2 : 'SliceofLife,Supernatural' changed to 'XjmceofKhxe,Vbiwegayodal'
# row: 141 col: 2 : 'Documentary' changed to 'Sodumeuuafy'
# row: 845 col: 2 : 'Drama' changed to 'Dramw'
# row: 1267 col: 2 : 'Music' changed to 'Jowic'
# row: 1323 col: 2 : 'Kids,Music' changed to 'Khfs,Mmsic'
# row: 585 col: 2 : 'Adventure,Sci-Fi' changed to 'Wfbdigtrt,Wwy-Dh'
# row: 1282 col: 2 : 'Comedy' changed to 'Domrdy'
# row: 1464 col: 2 : 'Music' changed to 'Kgvis'
# row: 422 col: 2 : 'Comedy,Fantasy,Music' changed to 'Cokedy,Fajtasy,Jmvid'
# row: 984 col: 2 : 'Animation,Comedy,Romance' changed to 'Anindtymk,Wootct,Fonatce'
# row: 1467 col: 2 : 'Adventure,Fantasy' changed to 'Egventutt,Ssmusab'
# row: 301 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'Whimatilu,Acehkk,Adcenture,Zoosqf'
# row: 1277 col: 2 : 'Ecchi' changed to 'Qfcki'
# row: 1347 col: 2 : 'Adventure' changed to 'Aqgeuvbxs'
# row: 1276 col: 2 : 'Adventure,Comedy,Magic' changed to 'Xetejdurs,Spmeqj,Jagic'
# row: 1148 col: 2 : 'Animation,Comedy' changed to 'Xnikdtllv,Xooeey'
# row: 791 col: 2 : 'Animation,Short,Music' changed to 'Aipmejhoi,Skowu,Music'
# row: 737 col: 2 : 'Drama,Kids,Magic' changed to 'Frzkc,Kuds,Manie'
# row: 1235 col: 2 : 'Fantasy,SliceofLife' changed to 'Fdntwsr,SlnccmfLmfq'
# row: 1067 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Fantasy' changed to 'Whimablkn,Acciin,Cjmedb,Crumc,Dreic,Fsubasy'
# row: 1418 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Cbkjetion,Afvejtuff,Family,Wemtasy'
# row: 1256 col: 2 : 'Comedy,Kids' changed to 'Ckkaer,Kjef'
# row: 137 col: 2 : 'Adventure,Comedy,Drama,Fantasy,Historical,Romance' changed to 'Sdczitire,Xumqdh,Bcama,Faitzsu,Ruddjcifan,Rkmcnxd'
# row: 568 col: 2 : 'Comedy' changed to 'Romfdu'
# row: 1261 col: 2 : 'Drama' changed to 'Erqma'
# row: 673 col: 2 : 'Drama,Music,SliceofLife' changed to 'Ecaoa,Mlsic,SpydgogLkve'
# row: 485 col: 2 : 'Comedy' changed to 'Zmmtdy'
# row: 564 col: 2 : 'Drama,Family' changed to 'Arama,Faoojy'
# row: 1526 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Agkmenoon,Romedv,Fwntaxi'
# row: 342 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Ajioctuog,Qxgymn,Sgi-Fj'
# row: 536 col: 2 : 'Hentai' changed to 'Hemtwy'
# row: 1369 col: 2 : 'Ecchi,Seinen' changed to 'Ewchi,Seincn'
# row: 64 col: 2 : 'Animation,Action,Adventure,Crime' changed to 'Ahlladkov,Abbikn,Ascqtdurt,Cvkmz'
# row: 198 col: 2 : 'Fantasy,Kids' changed to 'Fajcssb,Hisf'
# row: 1257 col: 2 : 'Fantasy' changed to 'Fanhaay'
# row: 423 col: 2 : 'Short,Fantasy,Music,Sci-Fi' changed to 'Dfiry,Fzbresy,Mlaie,Sci-Fk'
# row: 1127 col: 2 : 'Comedy,Magic' changed to 'Bomady,Iagix'
# row: 960 col: 2 : 'Action,Comedy,MartialArts,School,Shounen' changed to 'Sghion,Skmeqf,IcrtiskXrjx,Xvhojn,Anoonen'
# row: 471 col: 2 : 'Drama,Family' changed to 'Brwmw,Damlln'
# row: 1051 col: 2 : 'Sci-Fi' changed to 'Sgi-Fi'
# row: 325 col: 2 : 'Action,Comedy,Crime,Drama,Thriller' changed to 'Awtyiu,Cukcvy,Srmje,Dranx,Thwmnleg'
# row: 917 col: 2 : 'Animation,Drama' changed to 'Wgpiztion,Dreme'
# row: 1082 col: 2 : 'Drama,Historical,Samurai,Shounen' changed to 'Dramc,Mysruflecl,Semurqh,Wflknej'
# row: 1109 col: 2 : 'Action,Adventure,Mystery,Police' changed to 'Actkib,Qddcbtnrz,Kystvev,Koolce'
# row: 1293 col: 2 : 'Music' changed to 'Musoc'
# row: 1427 col: 2 : 'Action' changed to 'Schioj'
# row: 334 col: 2 : 'Action,Mecha,Sci-Fi,Shounen' changed to 'Abcuov,Lebhx,Fwi-Vl,Wrounei'
# row: 998 col: 2 : 'Sci-Fi,Action,Animation' changed to 'Sdl-Fi,Aznimm,Wnometmob'
# row: 48 col: 2 : 'Kids' changed to 'Yuds'
# row: 1381 col: 2 : 'Comedy,Music,Shoujo' changed to 'Cumeai,Iuslb,Dfokji'
# row: 967 col: 2 : 'Comedy,Sci-Fi' changed to 'Vpkegy,Sdo-Vj'
# row: 1478 col: 2 : 'Action,Adventure,Mecha,Military,Sci-Fi' changed to 'Xsrilv,Edfenhmrw,Mefic,Mlnutzri,Dsi-Fi'
# row: 642 col: 2 : 'Comedy' changed to 'Cumtdy'
# row: 96 col: 2 : 'Comedy,School,Shounen' changed to 'Comevy,Dwhppl,Xhkynen'
# row: 42 col: 2 : 'Drama,Ecchi' changed to 'Sramc,Aswri'
# row: 510 col: 2 : 'Comedy,Drama,Romance' changed to 'Wkktby,Srqka,Rokagfe'
# row: 1332 col: 2 : 'Action,Adventure,Comedy,Fantasy' changed to 'Zfeuok,Qdgenumrv,Clngsb,Scbtcwu'
# row: 1084 col: 2 : 'Short,Sci-Fi' changed to 'Wilwu,Ssy-Wk'
# row: 206 col: 2 : 'Action,Adventure,Fantasy,Magic,Shounen' changed to 'Agcion,Aavenyute,Rsnvesy,Mwyjs,Rhoonam'
# row: 741 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'Cvomwjion,Xhpcf,Cooedf,Svo-Dm'
# row: 439 col: 2 : 'Comedy,Ecchi,Horror,Romance,Shounen,Supernatural' changed to 'Coiwdt,Dcchi,Hirsow,Rooanva,Fniujen,Xopernqgnrzl'
# row: 566 col: 2 : 'Animation' changed to 'Etmjadiuk'
# row: 304 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Xkijwbiku,Acflli,Cumvqy,Fajuwsy,Toiwudx'
# row: 127 col: 2 : 'Action,Sci-Fi' changed to 'Evdikn,Dgl-Si'
# row: 581 col: 2 : 'Animation,Short,Action,Sci-Fi' changed to 'Anukatpln,Aylrt,Ebfkuh,Vri-Fh'
# row: 1028 col: 2 : 'Hentai,Yuri' changed to 'Kenuai,Iuri'
# row: 619 col: 2 : 'Drama' changed to 'Bwemw'
# row: 1227 col: 2 : 'Animation,Action,Adventure,Fantasy,Mystery,Thriller' changed to 'Wvilsnumh,Qstiok,Wbtrututt,Femvwsn,Myvtzxy,Thriumst'
# row: 1400 col: 2 : 'Drama,Fantasy,Sci-Fi,Thriller' changed to 'Exeoe,Gwntwsy,Xxi-Rl,Dieipmcr'
# row: 1356 col: 2 : 'Animation,Action,Fantasy' changed to 'Anikqbylj,Qftimj,Vxutasy'
# row: 650 col: 2 : 'Comedy,Ecchi,Harem,Romance,School' changed to 'Ximqer,Wecyi,Hagzm,Duncnbe,Azmuop'
# row: 1240 col: 2 : 'Action,Comedy,MartialArts,Shounen,SuperPower' changed to 'Xrynok,Cokrsf,MarclxoAtys,Xhjumei,DlixrImwee'
# row: 1310 col: 2 : 'Comedy,Parody,Romance' changed to 'Coiavt,Padugy,Foiznwe'
# row: 1154 col: 2 : 'Action,Drama,Mecha,Military,Sci-Fi' changed to 'Dcfloj,Erzoz,Kefha,Mllibqej,Sci-Gy'
# row: 1456 col: 2 : 'Animation' changed to 'Xhykebijg'
# row: 32 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Ahijzdjov,Comvvg,Xcp-Xp'
# row: 916 col: 2 : 'Kids' changed to 'Kids'
# row: 1360 col: 2 : 'Comedy' changed to 'Bonedy'
# row: 871 col: 2 : 'Animation,Adventure,Fantasy' changed to 'Anyksbiob,Advdkdoee,Rxttwdt'
# row: 1319 col: 2 : 'Animation,Comedy,Family,Fantasy' changed to 'Znilwtyot,Cokzdr,Vakilr,Fainery'
# row: 1572 col: 2 : 'Animation' changed to 'Anlmaviot'
# row: 1205 col: 2 : 'Magic,Parody' changed to 'Iaylc,Pavofi'
# row: 112 col: 2 : 'Action,Fantasy,Seinen,Supernatural' changed to 'Artpmu,Waktast,Xejnfn,Suidfnznkval'
# row: 1362 col: 2 : 'Comedy' changed to 'Cokeqy'
# row: 208 col: 2 : 'Action,Horror,Mystery,Seinen,Supernatural' changed to 'Wcfilk,Hmtdor,Lyfddcy,Swlnxb,Suktrnxgoxqk'
# row: 1250 col: 2 : 'Animation,Short' changed to 'Enjmzuimn,Rhkvt'
# row: 125 col: 2 : 'Animation' changed to 'Xniiqgiob'
# row: 799 col: 2 : 'Animation,Family,Adventure,Fantasy' changed to 'Ajimztlui,Fcoulh,Asgehnutv,Fxntzsy'
# row: 185 col: 2 : 'Adventure,Comedy,Fantasy,Shoujo' changed to 'Ebvfnehge,Rimrqy,Vcvtcsy,Fnuumk'
# row: 1412 col: 2 : 'Hentai' changed to 'Rtngai'
# row: 151 col: 2 : 'Drama,Kids' changed to 'Swcmz,Kiss'
# row: 1162 col: 2 : 'Action,Sci-Fi,Space' changed to 'Adeioh,Sci-Yi,Sldcc'
# row: 1144 col: 2 : 'Drama,Kids' changed to 'Eecme,Iiqd'
# row: 538 col: 2 : 'Action,Adventure,Comedy,Mecha,Sci-Fi' changed to 'Actiiu,Abvetryse,Wkircv,Itxhd,Xcm-Ni'
# row: 1451 col: 2 : 'Animation' changed to 'Qnujqnilb'
# row: 701 col: 2 : 'Comedy' changed to 'Wmmwdi'
# row: 868 col: 2 : 'Music' changed to 'Muwlz'
# row: 946 col: 2 : 'Animation,Drama' changed to 'Wnimatiot,Qtcma'
# row: 1555 col: 2 : 'Animation,Adventure,Drama' changed to 'Sginxtjoh,Adventkre,Erwma'
# row: 8 col: 2 : 'Drama' changed to 'Grwoz'
# row: 713 col: 2 : 'Animation,Short,Fantasy' changed to 'Animaeplu,Syost,Fahtawy'
# row: 1102 col: 2 : 'Comedy,Harem,Music,Romance,Shoujo' changed to 'Ckmebf,Hwwqm,Nusmd,Gunancf,Sykgjo'
# row: 340 col: 2 : 'Action,Comedy,Fantasy,Shounen,SuperPower' changed to 'Xftilh,Cojedn,Wsuuwxj,Wnoubag,Supft'idzg'
# row: 1021 col: 2 : 'Hentai' changed to 'Jdncwl'
# row: 1480 col: 2 : 'Animation,Short,Fantasy' changed to 'Qgimecikn,Ayjrf,Fabnasy'
# row: 222 col: 2 : 'Comedy,Drama,Fantasy' changed to 'Rjiedv,Srama,Wwkdwsg'
# row: 87 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Aiymarpon,Cplxdu,Btdma,Tokwbxe'
# row: 245 col: 2 : 'Comedy' changed to 'Elixvb'
# row: 1444 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Wjilsgion,Xcbyon,Asvvnturg,Xabtdst'
# row: 832 col: 2 : 'Short' changed to 'Dkprj'
# row: 1018 col: 2 : 'Animation' changed to 'Agylatlok'
# row: 482 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Enimatimn,Sdyklu,Qdeenckgg,Eukrdy,Dautadg'
# row: 793 col: 2 : 'Fantasy,Kids' changed to 'Yeguefy,Kids'
# row: 41 col: 2 : 'Action,Josei,Supernatural' changed to 'Asjooi,Opsem,Rupvrnatgrwn'
# row: 1287 col: 2 : 'Comedy,Parody' changed to 'Colaaf,'acovh'
# row: 997 col: 2 : 'Game,Shounen' changed to 'Gxlf,Svuunen'
# row: 1163 col: 2 : 'Comedy' changed to 'Bjmeat'
# row: 45 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi,Thriller' changed to 'Anhnaelln,Acylov,Eavxiture,Gckpky,Fanvaxy,Scm-Vl,Thrillcg'
# row: 555 col: 2 : 'Comedy' changed to 'Cmnebt'
# row: 1563 col: 2 : 'Animation,Adventure,Family,Fantasy,Sci-Fi' changed to 'Cvloatoim,Cdxcmvutr,Nsnjub,Faieqsy,Sfh-Fi'
# row: 644 col: 2 : 'Action,Fantasy,Mecha,Military,Shounen' changed to 'Zcthmn,Fajtaxh,Kfvjw,Lolltwry,Shiijft'
# row: 1159 col: 2 : 'Animation,Action,Comedy' changed to 'Akikztkmh,Xcejoi,Cokddy'
# row: 1313 col: 2 : 'Animation,Short,Comedy' changed to 'Amilarpon,Rjmvt,Bkkddv'
# row: 1307 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Avimatoog,Agtion,Edeghvlde,Bolvdy,Fenfawj'
# row: 276 col: 2 : 'Animation,Comedy,Drama' changed to 'Akimqthuv,Rlmedy,Dsaia'
# row: 1574 col: 2 : 'Animation,Short,Comedy' changed to 'Sgymaryon,Sgorr,Dmkdcy'
# row: 207 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'Achimn,Cavwuvurs,Favgasy,Shounag'
# row: 194 col: 2 : 'Comedy,Sports' changed to 'Cljrdy,Sootts'
# row: 752 col: 2 : 'Animation,Action,Drama,Sport' changed to 'Xnomxtion,Xrvjoh,Drama,Apiwt'
# row: 877 col: 2 : 'Animation,Action,Comedy,Crime,Mystery' changed to 'Qnimatikn,Wstyob,Voizdh,Cviiw,Lydtsvj'
# row: 462 col: 2 : 'Hentai' changed to 'Menbai'
# row: 397 col: 2 : 'Harem,Hentai' changed to 'Katzm,Mentah'
# row: 285 col: 2 : 'Hentai' changed to 'Rwttqi'
# row: 1152 col: 2 : 'Comedy,Military' changed to 'Comedv,Nmjibxwh'
# row: 1095 col: 2 : 'Adventure,Mecha,Sci-Fi' changed to 'Sdvejtuge,Oswfa,Fzj-Wl'
# row: 978 col: 2 : 'Comedy,Drama' changed to 'Cjlqdh,Gewmz'
# row: 1189 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy' changed to 'Anjjedion,Xxtjon,Comedy,Arwmq,Gandaxy'
# row: 1442 col: 2 : 'Animation' changed to 'Qbpkatkmn'
# row: 1254 col: 2 : 'Action,Drama,Fantasy,Mystery,Sci-Fi' changed to 'Achioj,Brejc,Ranhcsv,Nyvucsy,Sfi-Xk'
# row: 589 col: 2 : 'Hentai' changed to 'Henexi'
# row: 1203 col: 2 : 'Action,Drama,War' changed to 'Axnnon,Vreoa,Wac'
# row: 866 col: 2 : 'Animation,Short' changed to 'Dnimatoon,Xhmru'
# row: 1165 col: 2 : 'Comedy' changed to 'Conedb'
# row: 1326 col: 2 : 'Comedy,SliceofLife' changed to 'Zpiccy,SligelgUixs'
# row: 987 col: 2 : 'Comedy,Drama,SliceofLife' changed to 'Romfqg,Cramw,VkidvohUhst'
# row: 833 col: 2 : 'Animation,Comedy' changed to 'Sginxtuog,Cknddg'
# row: 888 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Wnimadiom,Zliedy,Ffi-Sn'
# row: 540 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Wctipg,Advdntyge,Xomtdy,Sgknnen'
# row: 904 col: 2 : 'Adventure,Comedy,Josei' changed to 'Acvgntkfd,Cilrdi,Jkdwi'
# row: 95 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Smimetipt,Sxtikn,Sci-Fi'
# row: 444 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'Akiiztukb,Dfnyom,Agtsnjhge,Xmkedu'
# row: 1542 col: 2 : 'Animation,Short' changed to 'Avknwuijn,Whigt'
# row: 535 col: 2 : 'Comedy,Samurai,School' changed to 'Ejmfcr,Rqkjvai,Sxhljl'
# row: 1459 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'Wnymatipv,Qxtikg,Rjmedy,Fannzsj'
# row: 307 col: 2 : 'Hentai' changed to 'Hdngal'
# row: 865 col: 2 : 'Hentai' changed to 'Jfbuai'
# row: 1593 col: 2 : 'Hentai' changed to 'Jqvtai'
# row: 98 col: 2 : 'Action,Adventure' changed to 'Astoom,Qdcentkrz'
# row: 1075 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'Xtikaeion,Advencure,Sci-Fu'
# row: 686 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Qvveuture,Xomecy,Fwnddry,Klds'
# row: 408 col: 2 : 'Animation,Comedy,Romance' changed to 'Wnimatimu,Comedy,Vomcgce'
# row: 662 col: 2 : 'Hentai' changed to 'Hfnjau'
# row: 1252 col: 2 : 'Crime,Drama,Mystery' changed to 'Fdiis,Desma,Ojdtzrn'
# row: 1534 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Aiimaciom,Xcthuk,Wvvqntusq,Cokedy,Vqnuasy'
# row: 609 col: 2 : 'Animation,Adventure,Fantasy,Romance' changed to 'Qtulenion,Adxeururx,Rxvtasy,Eokavdf'
# row: 1146 col: 2 : 'Animation,Comedy,Family' changed to 'Anlmatkon,Xoksqt,Vwolli'
# row: 1168 col: 2 : 'Comedy,Drama,Romance' changed to 'Xpnacf,Drajz,Romancc'
# row: 1209 col: 2 : 'Comedy,Drama,SliceofLife,Supernatural' changed to 'Eunedj,Qrwna,RlhbeoxOyfe,Dgpxtnxtuvwl'
# row: 116 col: 2 : 'Crime,Drama,Thriller' changed to 'Cgint,Evamz,Jhriklar'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1543, 7994)
# (26, 7994)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1543, 7993)
# (26, 7993)
# (1543, 700)
# (26, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.07
# Mean squared error: 1.30
# Variance score: -26.56

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.30
# Mean squared error: 1.71
# Variance score: -46.75

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [1.079 1.042 0.943 0.976 0.983]
# Mean: 1.0045339135956586
# Standard deviation: 0.04894864984237875

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.88

# %%
clf = training(model = linear_model.Lasso(alpha = 0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.13
# Mean squared error: 1.39
# Variance score: -30.38
