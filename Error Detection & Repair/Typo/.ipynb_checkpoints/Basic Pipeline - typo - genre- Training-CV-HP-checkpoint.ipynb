# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Keyboard(),75, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Keyboard().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Keyboard().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Keyboard method ---------------
#
# row: 561 col: 2 : 'Animation,Adventure,Drama,Sci-Fi' changed to 'AAnnaattopvvbyrree,,DDtqnaaSScco--FF'
# row: 676 col: 2 : 'Drama,Kids' changed to 'DDaakaaMudd'
# row: 644 col: 2 : 'Mystery,Psychological' changed to 'MMtteetyyssucchhpolxaao'
# row: 1036 col: 2 : 'Animation,Action,Adventure,Crime' changed to 'QiinopnnyQbeettrrr,,Ffee'
# row: 354 col: 2 : 'Drama,Musical' changed to 'DDrraanaaMMuussuccaall'
# row: 530 col: 2 : 'Comedy,Drama,Romance' changed to 'eexDDrrqaa,,RRlkqmxw'
# row: 1581 col: 2 : 'Hentai' changed to 'Graau'
# row: 635 col: 2 : 'Drama,Comedy' changed to 'DDrrqaa,,CCpmmu'
# row: 463 col: 2 : 'Adventure' changed to 'Qsvvdjttjrree'
# row: 1265 col: 2 : 'Animation' changed to 'iiaaiim'
# row: 1002 col: 2 : 'Adventure,Fantasy,Kids' changed to 'AAfbeennuu,,GysztKKf'
# row: 1493 col: 2 : 'Animation,Biography,Comedy' changed to 'biimmqiioobBBoiggfqohhyy,,CCmm'
# row: 113 col: 2 : 'Adventure,Comedy' changed to 'xeemttteeCCkdh'
# row: 912 col: 2 : 'Animation,Short,Horror' changed to 'Qnniimmgoonn,,Wjoogeerr'
# row: 1472 col: 2 : 'Hentai' changed to 'Bms'
# row: 188 col: 2 : 'Animation,Short,Fantasy' changed to 'SnnmmaarooWoorrg,,Caabraassyy'
# row: 1285 col: 2 : 'Documentary' changed to 'DDoouummbyaafyy'
# row: 770 col: 2 : 'Harem,Hentai' changed to 'Jqfrmm,,Ywnnaaii'
# row: 1395 col: 2 : 'Animation,Comedy,Drama,Fantasy,Horror,Mystery' changed to 'Sbiimmsib,,XeuDDenaaRjquHHooet,,zwrr'
# row: 860 col: 2 : 'Animation,Drama,Sport' changed to 'Snnummkoonn,,,,Aop'
# row: 1291 col: 2 : 'Dementia' changed to 'DDdnwnnr'
# row: 597 col: 2 : 'Comedy' changed to 'CCneee'
# row: 847 col: 2 : 'Animation,Short,Fantasy' changed to 'AAjnaattpm,,ZoorrttGaabaass'
# row: 1570 col: 2 : 'Adventure' changed to 'fttuurr'
# row: 566 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'AAddbbttfVlkxaattqssyyKKiiss'
# row: 1318 col: 2 : 'Animation,Sport' changed to 'AAmogunnSSoirrr'
# row: 175 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'AAnnqu,,ddvvwttuurr,,DsnhCbsyy'
# row: 1354 col: 2 : 'Comedy' changed to 'ood'
# row: 14 col: 2 : 'Historical,Romance,Shoujo,Supernatural' changed to 'Gkssrrsk,,Tookaabv,,SShhuujjoo,,Wuuwnnaattjaall'
# row: 56 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'ddeebuur,,oommeeddaannttqssyyMuz'
# row: 662 col: 2 : 'Action,Comedy,Shounen,SuperPower' changed to 'Qxttui,,CCoommeeddyyWuunnuuppwrrPPedf'
# row: 429 col: 2 : 'Kids' changed to 'kss'
# row: 1596 col: 2 : 'Animation' changed to 'krkoonn'
# row: 1115 col: 2 : 'Comedy,Ecchi,Romance,Sci-Fi' changed to 'CClmm,,EEccccyii,,RRpmmaaccee,,SSiiFF'
# row: 1496 col: 2 : 'Comedy,Kids,SuperPower' changed to 'oowxiiddssZuuwtPPle'
# row: 356 col: 2 : 'Animation' changed to 'jknriii'
# row: 740 col: 2 : 'Harem,Hentai' changed to 'HHsfkHHeebgq'
# row: 1042 col: 2 : 'Music,Shoujo,Sports' changed to 'NissuAyoouujjlSSrryss'
# row: 1490 col: 2 : 'Animation,Drama,Family' changed to 'nnkkyupnnDDfaak,,iio'
# row: 1313 col: 2 : 'Hentai' changed to 'dnnttaa'
# row: 1520 col: 2 : 'Comedy,School' changed to 'CCddyy,,Accpk'
# row: 972 col: 2 : 'Hentai' changed to 'HHeennttsii'
# row: 678 col: 2 : 'Action,Comedy' changed to 'AAxttkibookryy'
# row: 1568 col: 2 : 'Biography,Drama' changed to 'hsppb,,Errmmaa'
# row: 200 col: 2 : 'Fantasy' changed to 'jttaau'
# row: 1558 col: 2 : 'Animation,Adventure,Drama,Fantasy' changed to 'ommrij,,vveennee,,FrraanaaRyaass'
# row: 460 col: 2 : 'Comedy,Kids,Parody,Sci-Fi,Space,SuperPower' changed to 'Xpmmeeddh,,ufPPqrrooxAvDppqvee,,yppdePPiwwt'
# row: 1252 col: 2 : 'Comedy,Kids' changed to 'Xooneh,,KKkddw'
# row: 1516 col: 2 : 'Demons,Fantasy,Hentai,Horror,Sci-Fi' changed to 'DDeekooss,,snnttnnaa,,JootooeWcciiii'
# row: 1104 col: 2 : 'Animation,Comedy,Fantasy' changed to 'iimmaarkoob,,CCookdd,,FFqaah'
# row: 743 col: 2 : 'SliceofLife' changed to 'SSuoow'
# row: 645 col: 2 : 'Short' changed to 'yly'
# row: 556 col: 2 : 'Animation,Short' changed to 'AAmmmqlbSShhifr'
# row: 264 col: 2 : 'Animation' changed to 'AAiimmypj'
# row: 1409 col: 2 : 'Animation' changed to 'AAiittiii'
# row: 183 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'iisiiinnVoommweyyDDqmmToommaannee'
# row: 318 col: 2 : 'Animation' changed to 'AAnniikaattoom'
# row: 923 col: 2 : 'Animation,Short,Comedy' changed to 'QnnosttkibDllneeddu'
# row: 1302 col: 2 : 'Comedy,SliceofLife' changed to 'Xkeeokvlii'
# row: 1195 col: 2 : 'Animation,Fantasy' changed to 'miiaaiiijaannttayy'
# row: 534 col: 2 : 'Music' changed to 'uukv'
# row: 959 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'AAsvveebttuuee,,pn,,ZkoocLLiirw'
# row: 388 col: 2 : 'Drama,Historical,SliceofLife' changed to 'Errqkaa,,kwfkqk,,WlluccroodKoffd'
# row: 675 col: 2 : 'Animation,Short,Comedy,Romance' changed to 'nnmmrlnnWoor,,XiddyyTpmmaaccee'
# row: 558 col: 2 : 'Fantasy,Kids,Magic' changed to 'snnttus,,MMsfox'
# row: 857 col: 2 : 'Action,MartialArts,Mecha,SuperPower' changed to 'Qfttj,,qrryoAAttd,,MMeehhaauuppPPiwf'
# row: 656 col: 2 : 'Animation,Short' changed to 'AAummttinn,,ity'
# row: 1522 col: 2 : 'Adventure,Comedy,Kids' changed to 'SddceemttytCCooxyy,,KKss'
# row: 1407 col: 2 : 'Fantasy' changed to 'Rsqssyy'
# row: 1499 col: 2 : 'Drama' changed to 'DDrraammq'
# row: 1120 col: 2 : 'Sci-Fi,Space' changed to 'DfSSaaf'
# row: 919 col: 2 : 'Kids,Magic' changed to 'Moss,,MMaaiicc'
# row: 799 col: 2 : 'Animation,Family,Fantasy' changed to 'Qiikttoonn,,FFqmmll,,FFsnnaass'
# row: 524 col: 2 : 'Action,Demons,Fantasy' changed to 'AAvgoonnwknn,,FFnnttaah'
# row: 1012 col: 2 : 'Animation,Action,Fantasy,Sci-Fi,Thriller' changed to 'AAukaaroobAAxiii,,FFaannttswiioYgrroo'
# row: 592 col: 2 : 'Comedy' changed to 'Xoodf'
# row: 834 col: 2 : 'Animation,Action' changed to 'Sjommrkooccoo'
# row: 109 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'ddgrtteee,,Foommrddyyqnnttdh'
# row: 336 col: 2 : 'Comedy,Ecchi,Mecha,Romance,Sci-Fi' changed to 'mmees,,xii,,MMccbkaajfeeZfoRu'
# row: 157 col: 2 : 'Drama,Romance,SliceofLife' changed to 'rrsn,,Fmmqbccr,,SSoccdoocLLuffw'
# row: 7 col: 2 : 'Drama,Kids' changed to 'taammKKss'
# row: 1477 col: 2 : 'Adventure,Fantasy,Sci-Fi,Shounen' changed to 'AAxnnyuurrd,,jttqsstcco--k,,Dhhooid'
# row: 1561 col: 2 : 'Animation' changed to 'Qiinqynn'
# row: 1276 col: 2 : 'Comedy,Ecchi,Kids,Shounen' changed to 'mmrdduEExbossSSy'
# row: 117 col: 2 : 'Hentai' changed to 'HHeeb'
# row: 11 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'AAjkaayii,,ooonnttsau,,mm--DycciiGii'
# row: 864 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'nniinrb,,ooeedd,,cco--Cii'
# row: 1171 col: 2 : 'Animation' changed to 'AAmkrkl'
# row: 1339 col: 2 : 'Animation,Comedy' changed to 'AAjummyklb,,immt'
# row: 481 col: 2 : 'Action,Comedy,Mystery,SuperPower' changed to 'ttiilnn,,CClrhdgrryySSuueoor'
# row: 876 col: 2 : 'Hentai' changed to 'HHdsii'
# row: 436 col: 2 : 'Comedy,Historical' changed to 'CCmmxt,,urrrccaall'
# row: 1576 col: 2 : 'Action,Adventure,Comedy,Fantasy,Magic' changed to 'AAccttp,,QddvvnnttuurrwneetFFqzyy,,MMaaggv'
# row: 993 col: 2 : 'Comedy,Ecchi' changed to 'Xlmmrdd,,Wfu'
# row: 1113 col: 2 : 'Comedy,Drama,Music' changed to 'CCoodddt,,DDrrqsMMuusscc'
# row: 407 col: 2 : 'Animation,Adventure,Family' changed to 'mmaayiij,,Seeyr,,FFqiikh'
# row: 1387 col: 2 : 'Adventure,Kids' changed to 'Qbuurree,,ddss'
# row: 73 col: 2 : 'Animation,Short,Action,Comedy,Sci-Fi' changed to 'AAbosttnnZhhi,,ccttimmdddh,,Wccuii'
# row: 380 col: 2 : 'Action,Sci-Fi,SuperPower' changed to 'ccupnnDccii--Dii,,ppeerrOoo'
# row: 598 col: 2 : 'Action,Adventure,Fantasy' changed to 'ccrnn,,AAbeemirree,,Gswh'
# row: 821 col: 2 : 'Adventure,Kids' changed to 'QbeemyuurrKKa'
# row: 725 col: 2 : 'Short,Action,Sport' changed to 'SSitg,,Qccttiiib,,Appoorr'
# row: 409 col: 2 : 'Animation,Action,Drama,Fantasy' changed to 'nnaattooo,,AAccriioomeaaaasnngaayy'
# row: 731 col: 2 : 'Animation,Adventure,Comedy,Fantasy,Romance' changed to 'bmmsiioobAAddwy,,CCooeeyy,,qgdt,,'
# row: 1064 col: 2 : 'Mecha,Parody,Sci-Fi' changed to 'whhaa,,rrooSSiiFFu'
# row: 580 col: 2 : 'Action' changed to 'fiipnn'
# row: 757 col: 2 : 'Action,Adventure,MartialArts,Samurai' changed to 'fnn,,xwbjeetuqkAAfywSSstq'
# row: 346 col: 2 : 'Animation' changed to 'Qnnuaattkpb'
# row: 1542 col: 2 : 'Animation' changed to 'Qmmqgiinn'
# row: 1429 col: 2 : 'Animation,Short' changed to 'Sjommaagkoob,,hhoof'
# row: 1389 col: 2 : 'Animation,Drama' changed to 'Smsiiik'
# row: 105 col: 2 : 'Hentai' changed to 'HHdnnaaii'
# row: 287 col: 2 : 'Mystery,Seinen,Supernatural' changed to 'KzyrftiinneeSSppeerrnnaajaa'
# row: 1089 col: 2 : 'Sport' changed to 'Zrr'
# row: 1079 col: 2 : 'Animation,Biography,Drama,History,Romance,War' changed to 'AAnnkgoonnBBuiogyy,,saa,,iioouTookaabccee,,WWst'
# row: 1478 col: 2 : 'SliceofLife' changed to 'Alliiwiffffee'
# row: 669 col: 2 : 'Hentai' changed to 'Yeebttaaii'
# row: 795 col: 2 : 'Comedy,Josei,Romance,SliceofLife' changed to 'ln,,JJsswii,,snnccdAlluccwoogiid'
# row: 186 col: 2 : 'Dementia' changed to 'knnyiiq'
# row: 1177 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'Sjmmttuoom,,AAfumXpkeeeyy,,smttswfuii'
# row: 146 col: 2 : 'Adventure,Comedy,Demons,Fantasy,Magic,Romance,Shounen,Supernatural' changed to 'AAdddjttrreeCCf,,eemmssFFaajttaassuMMqhiix,,lmmf,,SShhoodb,,SSoeerrnnseaall'
# row: 677 col: 2 : 'Adventure,Animation' changed to 'Sdnngeeennkttooob'
# row: 41 col: 2 : 'Animation' changed to 'AAbiim'
# row: 1565 col: 2 : 'Music' changed to 'Kuussiicc'
# row: 89 col: 2 : 'Hentai' changed to 'HHrjsii'
# row: 128 col: 2 : 'Hentai' changed to 'Jeejyii'
# row: 309 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'mmqgiiinnsmmsDsjrssyy,,AFFu'
# row: 1239 col: 2 : 'Animation,Comedy,Fantasy,Horror,Romance' changed to 'nnkmmaakooCCkwf,,aabttaayyBpfoorr,,RRimmbf'
# row: 1486 col: 2 : 'Kids' changed to 'KK'
# row: 273 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'AAiikskoob,,Vmmddd,,Dvii--ii'
# row: 272 col: 2 : 'Animation' changed to 'Sjiiq'
# row: 38 col: 2 : 'Action,Historical,MartialArts,Samurai' changed to 'SttiiiiileccMMsuqoSrrttss,,kii'
# row: 1515 col: 2 : 'Animation' changed to 'AAmnsttnn'
# row: 46 col: 2 : 'Animation,Sci-Fi,Thriller' changed to 'AAnnknnnSSfii--FFGiiot'
# row: 1494 col: 2 : 'Comedy,Ecchi,Fantasy,Harem,Romance,School,Sci-Fi,Supernatural' changed to 'CCoommdsyyxfii,,jttsssyy,,HHaarrw,,TaamccvloAiiCo,,ippdrraarraa'
# row: 1094 col: 2 : 'Drama,Historical' changed to 'DDqmm,,HHiiirriivq'
# row: 1418 col: 2 : 'Comedy,Drama' changed to 'ooxtDDfk'
# row: 862 col: 2 : 'Animation' changed to 'oaattkb'
# row: 1249 col: 2 : 'Animation,Short,Music' changed to 'bunsttonnSSboorr,,MMuuziicc'
# row: 178 col: 2 : 'Action' changed to 'AAccrunn'
# row: 1207 col: 2 : 'Comedy,Sci-Fi' changed to 'CCimmdduCii'
# row: 871 col: 2 : 'Short,Romance' changed to 'hhltg,,Toommaaccee'
# row: 1144 col: 2 : 'Animation,Comedy,Romance' changed to 'QbeeddhEimmnn'
# row: 1331 col: 2 : 'Animation,Horror' changed to 'AAkaagooonnrri'
# row: 930 col: 2 : 'Animation,Action,Fantasy' changed to 'nniiaattb,,Sttb,,jgh'
# row: 1004 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi,Thriller' changed to 'AAkniioonn,,Svii,,DDeaaoommaanncc,,Dviiii,,ulleerr'
# row: 1315 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'iiiijXlmmddyy,,mm,,mmnnxee'
# row: 1560 col: 2 : 'Animation,Comedy,Romance,Sci-Fi' changed to 'mmmoojCCmmee,,oonfSS--Cii'
# row: 705 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'bkmmaattiinnAAiioonnddjee,,bgqt,,SSccu--'
# row: 298 col: 2 : 'Hentai' changed to 'Jeem'
# row: 1351 col: 2 : 'Comedy,Shounen' changed to 'lmmdduWbd'
# row: 824 col: 2 : 'Animation' changed to 'nnunaattuoonn'
# row: 202 col: 2 : 'Drama' changed to 'Etqmms'
# row: 734 col: 2 : 'Animation,Drama,Thriller' changed to 'nnknttiiDD,,Rfklloe'
# row: 1232 col: 2 : 'Animation,Comedy' changed to 'nnkmmaattiiinn,,CCoommdddt'
# row: 1020 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Sjiinaayii,,XddhDDrraakaa,,FFaabttaassyypccd'
# row: 368 col: 2 : 'Adventure,Fantasy' changed to 'ddguufee,,Dqttaazyy'
# row: 1107 col: 2 : 'Mecha,Sci-Fi' changed to 'Nccbaa,,SSRo'
# row: 1091 col: 2 : 'Action,Ecchi,Fantasy' changed to 'Qunn,,vguFFmyaassyy'
# row: 593 col: 2 : 'Animation,Adventure,Comedy,Family,Fantasy,Sci-Fi' changed to 'AAiiksol,,vvwnnjrrd,,CCood,,DaakRqnnrqwyyWo'
# row: 406 col: 2 : 'Kids' changed to 'k'
# row: 1058 col: 2 : 'Horror,Psychological' changed to 'BooeelOsspoucck'
# row: 243 col: 2 : 'Sci-Fi' changed to 'SSu--u'
# row: 1268 col: 2 : 'Horror' changed to 'Joorreoo'
# row: 408 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'QttQddcdjguufd,,FFqmsdt,,MMccq'
# row: 483 col: 2 : 'Comedy' changed to 'lmmeedd'
# row: 973 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Mystery' changed to 'Snnkkaaiil,,Qfkoonn,,ettuurrd,,DDeaaaaFFaannqzt,,eh'
# row: 310 col: 2 : 'Drama' changed to 'DDrrqkq'
# row: 1442 col: 2 : 'School,SliceofLife' changed to 'hhooio,,SSiieeiffk'
# row: 1297 col: 2 : 'Fantasy,Historical,Kids' changed to 'GqryyBokccaak,,M'
# row: 67 col: 2 : 'Animation,Action,Fantasy' changed to 'AAqobAAfttop,,nnttaau'
# row: 60 col: 2 : 'Hentai' changed to 'aak'
# row: 85 col: 2 : 'Comedy,Sports' changed to 'oommeeddu,,ppoorrttz'
# row: 1346 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Smmsttkoom,,AAxceebttjrrrSSvuGii'
# row: 975 col: 2 : 'Documentary' changed to 'DDvynmttth'
# row: 968 col: 2 : 'Adventure,Drama,Historical,SliceofLife' changed to 'vvwnnrrrrsks,,HHkssttoof,,SSowprLLuee'
# row: 1127 col: 2 : 'Short' changed to 'SSbt'
# row: 234 col: 2 : 'Comedy' changed to 'Vleee'
# row: 1292 col: 2 : 'Action,Drama,Mecha,Military,Sci-Fi' changed to 'xiioonn,,taaeefaa,,MMiikiittaarrt,,u--'
# row: 1506 col: 2 : 'Fantasy,Kids' changed to 'aannyq,,ufz'
# row: 594 col: 2 : 'Comedy,Romance,School,Shounen' changed to 'CCookfu,,Tisjccw,,Wccoyijeeb'
# row: 1193 col: 2 : 'Action,Kids,Mecha,Sports' changed to 'AAttiiKKud,,Nrcc,,SSpprrtt'
# row: 946 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'AAkmmaagoo,,AAxiip,,AAevvrnnaagaau'
# row: 1151 col: 2 : 'Action,Comedy,Dementia,Ecchi,Parody,Supernatural' changed to 'Qviioo,,CCookuEnwnnyii,,EEcccchh,,teyy,,SSuupptnnsrq'
# row: 262 col: 2 : 'Fantasy' changed to 'aannaass'
# row: 810 col: 2 : 'Action,Adventure,Horror,Mystery,Sci-Fi,War' changed to 'vttoonn,,ddgrfr,,ooerrirr,,Nyyattcck--FFiiErr'
# row: 500 col: 2 : 'Comedy,Fantasy' changed to 'CCpmmdFFbttsssyy'
# row: 822 col: 2 : 'Comedy,Fantasy,Kids' changed to 'XirFFnnaaayy,,KKkss'
# row: 1325 col: 2 : 'Drama' changed to 'Erraak'
# row: 797 col: 2 : 'Comedy,Fantasy,Romance' changed to 'pmmeexyy,,aajr,,Eimmaajee'
# row: 112 col: 2 : 'Animation,Short' changed to 'SummaaiilmZr'
# row: 1206 col: 2 : 'Animation,Comedy' changed to 'Qoaattiioonn,,pmmddd'
# row: 1244 col: 2 : 'Action,Animation,Sci-Fi' changed to 'fyiip,,Smiimmqttm,,vii--Ck'
# row: 629 col: 2 : 'Adventure,Family,Fantasy' changed to 'Qbtty,,qokDaattssyy'
# row: 62 col: 2 : 'Fantasy,Game' changed to 'qwu,,aammw'
# row: 755 col: 2 : 'Documentary,Short,Biography' changed to 'SlccyeennyyyZhheBBfeaay'
# row: 333 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Mystery,Romance' changed to 'Snnkmmttiinn,,AAsnnyuurr,,qmmaaGqkGqttqyyNyysseeRRismxee'
# row: 475 col: 2 : 'Animation,Comedy,Fantasy,Romance,Sci-Fi' changed to 'juqriiibooneeyy,,sttaaat,,RRookaanndfu--FFii'
# row: 1045 col: 2 : 'Animation,Family,Drama' changed to 'nnmmqtto,,FFaaniiSeqks'
# row: 1489 col: 2 : 'Comedy' changed to 'CCmmxyy'
# row: 839 col: 2 : 'Animation' changed to 'Snnonaariioonn'
# row: 1402 col: 2 : 'Comedy,Sci-Fi' changed to 'VeeAu'
# row: 240 col: 2 : 'Cars,Shounen,Sports' changed to 'FsSSbor'
# row: 790 col: 2 : 'Adventure,Fantasy,Historical' changed to 'eeeuutaannd,,Jzleiill'
# row: 1018 col: 2 : 'Comedy,Mecha' changed to 'Flkyy,,eecchhs'
# row: 583 col: 2 : 'Comedy,Drama,Romance' changed to 'Flkeexyy,,DDrrsnqooqbxr'
# row: 612 col: 2 : 'Animation' changed to 'jiikqii'
# row: 267 col: 2 : 'Short,Comedy' changed to 'hhlt,,CCoommeu'
# row: 491 col: 2 : 'Animation,Comedy,Romance' changed to 'Qmiiaattobmmeefhaacc'
# row: 950 col: 2 : 'Comedy,Fantasy,Kids' changed to 'pkwddh,,GaannyKKii'
# row: 1080 col: 2 : 'Comedy,Seinen,Space' changed to 'Fneeddyy,,deeb,,Woccd'
# row: 242 col: 2 : 'Action,Adventure,Shounen,SuperPower' changed to 'Qob,,ddceennruurree,,SShhluubnn,,uuppeewwee'
# row: 79 col: 2 : 'Drama' changed to 'DDrrmm'
# row: 974 col: 2 : 'Animation,Action,Crime,Drama,Mystery,Thriller' changed to 'AAnnaaginn,,AAfriilnntkmmee,,EtaasMMreetyy,,iill'
# row: 1317 col: 2 : 'Comedy' changed to 'mmeeddu'
# row: 145 col: 2 : 'Historical' changed to 'HHuwookccaall'
# row: 1275 col: 2 : 'Fantasy,Kids' changed to 'FFaaaa,,Mddss'
# row: 84 col: 2 : 'Short,Animation,Sci-Fi' changed to 'boornnkykZiiii'
# row: 424 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Qnniimmaayooo,,Foommeeddyy,,Caabaazt'
# row: 667 col: 2 : 'Animation' changed to 'AAoooonn'
# row: 334 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Thriller' changed to 'SnnukaaiiooAAccttnn,,AAddcwtteeskkoyyaajdyy,,hhtollllwe'
# row: 345 col: 2 : 'Adventure,Comedy,Kids' changed to 'AAddvveennttuuooee,,KKoz'
# row: 1241 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'juksttiipjvttiioonnddgeettieelnwyy'
# row: 518 col: 2 : 'Comedy' changed to 'CCookdd'
# row: 209 col: 2 : 'Action,Mystery' changed to 'ttoonn,,dtyy'
# row: 63 col: 2 : 'Kids' changed to 'Iss'
# row: 622 col: 2 : 'Comedy,Fantasy,Kids' changed to 'oonh,,FFjgstKKkddz'
# row: 870 col: 2 : 'Family' changed to 'FFaammk'
# row: 339 col: 2 : 'Animation' changed to 'Qjnruoom'
# row: 1097 col: 2 : 'Comedy,Romance,Seinen,SliceofLife' changed to 'VshRRmmaamfee,,SSnnwZkiieepffw'
# row: 1063 col: 2 : 'Comedy' changed to 'neet'
# row: 1025 col: 2 : 'Adventure,Comedy,Fantasy,Shoujo' changed to 'Seeejuuw,,CCieesh,,raauSSiuuh'
# row: 979 col: 2 : 'Hentai' changed to 'HHdnnttii'
# row: 210 col: 2 : 'Animation,Short,Action,Fantasy' changed to 'SiiqttopnnDooty,,vyooCttaass'
# row: 846 col: 2 : 'Animation,Short' changed to 'AAbiisuoo,,SShhtt'
# row: 820 col: 2 : 'Comedy,Harem,Music,Romance,School,Shoujo' changed to 'Fs,,wnMMox,,RRpmmaabwSSccoooZhhynoo'
# row: 1046 col: 2 : 'Action,Sci-Fi,Animation,Fantasy,Adventure,Drama' changed to 'QxujDx--DuSnnsttooFFmttsyy,,Sevveebuur,,Xaas'
# row: 564 col: 2 : 'Comedy,Ecchi' changed to 'Foommdevy'
# row: 808 col: 2 : 'Comedy,Drama' changed to 'oommrddt,,rrk'
# row: 924 col: 2 : 'Comedy,Police' changed to 'CCkxOookkccd'
# row: 299 col: 2 : 'Historical' changed to 'Gootccqll'
# row: 1539 col: 2 : 'Fantasy,Kids' changed to 'FFqnnqh,,Lkfw'
# row: 904 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Sjommsgiioonn,,lmmrddcciiFFii'
# row: 1447 col: 2 : 'Animation,Fantasy,Romance' changed to 'AAjmmyiioonnFFmttssyyRRlknnvr'
# row: 430 col: 2 : 'Hentai' changed to 'HHttaa'
# row: 44 col: 2 : 'Action' changed to 'AAfgulnn'
# row: 99 col: 2 : 'Drama,Fantasy,Kids' changed to 'Eaammaa,,nnttaau,,KKiie'
# row: 1118 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'QnnmmaattuoonnFneetuFF'
# row: 53 col: 2 : 'Comedy' changed to 'CCooeeyy'
# row: 990 col: 2 : 'Adventure,Shounen' changed to 'AAxeebttjrrrZlyd'
# row: 533 col: 2 : 'Action,Comedy,MartialArts,School,Shounen' changed to 'ccnn,,,,rrAAeyssSSvhhp,,oonnb'
# row: 1088 col: 2 : 'Drama,Kids' changed to 'DDsnsJuf'
# row: 786 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'nniikaaiilnn,,oommddyy,,DDqmmaa,,SSotr'
# row: 464 col: 2 : 'Comedy,Drama,Romance' changed to 'CCooyyXeaanq,,qccd'
# row: 1130 col: 2 : 'Comedy' changed to 'lneeu'
# row: 1453 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'AAnaar,,oomdddmttrrw,,mmeexhgaazyy'
# row: 1397 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'iiinnpeee,,en,,cciiGiiSSinndnnAqv'
# row: 1377 col: 2 : 'Crime,Drama,Thriller' changed to 't,,FrraaRfiill'
# row: 61 col: 2 : 'Animation,Family,Fantasy,Music' changed to 'AAkmmsiiooDsoaajsyy,,MMiocc'
# row: 192 col: 2 : 'Hentai' changed to 'dnnttso'
# row: 1540 col: 2 : 'Animation,Short' changed to 'bonsyiiij,,SSbity'
# row: 364 col: 2 : 'Comedy,Fantasy' changed to 'Xnrt,,FFaass'
# row: 1159 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'iinaaiioonnoorrtt,,QccgAAbdnnf,,FFnnqdyy'
# row: 701 col: 2 : 'Fantasy,Magic,Shounen' changed to 'aamttqyy,,sv,,uujwnn'
# row: 914 col: 2 : 'Animation,Comedy,Drama' changed to 'Qnnsriiooj,,CCmmeDDrraaaa'
# row: 294 col: 2 : 'Comedy,Parody' changed to 'Xoowh,,st'
# row: 1197 col: 2 : 'Animation' changed to 'Qqoonn'
# row: 1167 col: 2 : 'Action,Mecha,Military,Police,Sci-Fi' changed to 'AAccttnn,,MMxqKooeyy,,PPookkccee,,oDii'
# row: 1463 col: 2 : 'Animation,Adventure' changed to 'biikaaguinn,,Sdj'
# row: 452 col: 2 : 'Documentary' changed to 'oouueesrr'
# row: 3 col: 2 : 'Animation,Fantasy,Romance' changed to 'Siimmsttiil,,RnnyqTkaabee'
# row: 765 col: 2 : 'Adventure,Fantasy' changed to 'AAxbrnnttee,,Gaajttyy'
# row: 985 col: 2 : 'Short,Comedy,Crime,Sci-Fi' changed to 'hhoof,,CCoommeeddhrriimm,,SSccii--ii'
# row: 282 col: 2 : 'Animation,Comedy,Sport' changed to 'QoaaulCClmmtirrtt'
# row: 1509 col: 2 : 'Action,Mecha,Sci-Fi' changed to 'AAvttiinnNeevys,,Zccii--R'
# row: 426 col: 2 : 'Comedy,Kids,Romance' changed to 'mmeeh,,MddTpnnxd'
# row: 489 col: 2 : 'Comedy,Parody' changed to 'ddyy,,Osrryy'
# row: 939 col: 2 : 'SliceofLife' changed to 'DlliicceeicLLiigw'
# row: 1200 col: 2 : 'Fantasy,Kids,Magic,Shoujo' changed to 'qrqw,,KKMMggcc,,Ayijj'
# row: 1393 col: 2 : 'Animation,Adventure,Drama' changed to 'Qjiiaaiioomddeennruufd,,DDrrqmm'
# row: 232 col: 2 : 'Animation,Action,Sci-Fi' changed to 'iiaann,,innWiiFFii'
# row: 1028 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'bkaalAAyknn,,CCoonuFFqjttaasst'
# row: 1226 col: 2 : 'Fantasy,Music' changed to 'Cqssst,,iix'
# row: 543 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'klb,,AAxduudCCmmeeddSSyuumr'
# row: 308 col: 2 : 'Animation,Comedy,Drama' changed to 'nsttoonn,,CClxtSaakaa'
# row: 1286 col: 2 : 'Drama,Music,Romance' changed to 'DDmm,,uuo,,RRnjccee'
# row: 1190 col: 2 : 'Mystery,Police,Supernatural' changed to 'KhssfOiiccr,,Wjrrttrraall'
# row: 97 col: 2 : 'Comedy,Fantasy,Kids' changed to 'FmmeeddyyGaajyt,,ue'
# row: 311 col: 2 : 'Animation,Comedy' changed to 'miingpnn,,oon'
# row: 355 col: 2 : 'Drama,Family' changed to 'taammaaFFnu'
# row: 1122 col: 2 : 'Comedy,Parody' changed to 'Fpdd,,Oaalt'
# row: 1319 col: 2 : 'Drama,Romance' changed to 'Errkaa,,Epsnnee'
# row: 261 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Snnoqttiinn,,QxyooQddcmgirree,,CCkeefuFFqssSSccu--C'
# row: 173 col: 2 : 'Animation,Adventure,Comedy,Drama,Fantasy' changed to 'bnaayiioob,,AAfvvnntttCCoorh,,Ffmmq,,FFqnnttaaah'
# row: 735 col: 2 : 'Kids,Music' changed to 'Jsa,,MMuuzo'
# row: 1464 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'AAmknsyibVkeeeu,,DDaa,,Dptg'
# row: 1579 col: 2 : 'Adventure,Fantasy,Kids' changed to 'AAbeerd,,Caattaass,,Mii'
# row: 1194 col: 2 : 'Animation' changed to 'Qnnnsgkp'
# row: 1034 col: 2 : 'Animation' changed to 'nniinqttoob'
# row: 1076 col: 2 : 'Animation,Comedy,Romance' changed to 'AAmmoojXkwsyy,,RRoons'
# row: 70 col: 2 : 'Animation,Short' changed to 'AAnnkttkib,,ify'
# row: 1333 col: 2 : 'Adventure,Sci-Fi' changed to 'QvveefFFu'
# row: 115 col: 2 : 'Crime' changed to 'Vrrmmw'
# row: 1342 col: 2 : 'Comedy,Drama,Fantasy' changed to 'CCkwfSs,,FFsnnttaass'
# row: 1412 col: 2 : 'Animation' changed to 'Snniimmupm'
# row: 450 col: 2 : 'Animation,Comedy' changed to 'Snnkaattij,,mmdh'
# row: 773 col: 2 : 'Action,Crime,Drama,Mystery,Thriller' changed to 'AAfrupj,,CCrriinee,,DDfaammqNyyztth,,TTtiioowe'
# row: 177 col: 2 : 'Drama' changed to 'nq'
# row: 1068 col: 2 : 'Action,Adventure,Comedy,Drama,Fantasy,Kids' changed to 'AAccoo,,Sbdmfee,,ikdddyy,,EfmmsGjwh,,udd'
# row: 752 col: 2 : 'Comedy,Ecchi,School,Shounen' changed to 'CCoommwdd,,Wccccy,,DvhhiWgpmeeb'
# row: 454 col: 2 : 'Adventure,Fantasy,Kids,Magic' changed to 'AAfdnnuueee,,FFqjttaassh,,Jksshu'
# row: 238 col: 2 : 'School' changed to 'SScchhl'
# row: 855 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'AAnnommttupnnSrnnpmmhApppy'
# row: 1445 col: 2 : 'Adventure,Fantasy' changed to 'ddcwttyrreeFFaaby'
# row: 1211 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'AAnnommaariiinn,,Sddvvrnnyee,,FFqkyyFFaattaassyy'
# row: 281 col: 2 : 'Animation,Action,Comedy,Drama,Sci-Fi,Western' changed to 'AAnnkmmaaykibAAccgiimmdd,,Ftaamm,,Wxu--FFQeessb'
# row: 829 col: 2 : 'Animation' changed to 'AAnniinaann'
# row: 789 col: 2 : 'Action,Adventure' changed to 'vttoooj,,Sddmttuut'
# row: 1289 col: 2 : 'Comedy,Samurai,School' changed to 'CCpkdfu,,Dqmmt,,ccioo'
# row: 1566 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy' changed to 'AAaagijAAfbeemttyer,,Eesmmaanuk,,Cqnnttqssu'
# row: 1188 col: 2 : 'Animation,Short,Music' changed to 'SnnkyiilmAhhrrr,,Kwiicc'
# row: 198 col: 2 : 'Action,Drama' changed to 'Sccooaa'
# row: 606 col: 2 : 'Comedy,School,SliceofLife' changed to 'FlnhhhillZroodiigee'
# row: 237 col: 2 : 'Animation,Adventure,Comedy,Drama,Fantasy,Sci-Fi' changed to 'Qmiimmaaroo,,AAxceenntteee,,CCpddDD,,DqgsSSfii--R'
# row: 486 col: 2 : 'Drama,Historical' changed to 'FsaaHHottfvll'
# row: 600 col: 2 : 'Adventure,Kids' changed to 'Sddeeuufr,,KKiia'
# row: 1530 col: 2 : 'Action,Mecha,Sci-Fi' changed to 'ttulrhhaa,,Wcc--FF'
# row: 1314 col: 2 : 'Action,Fantasy,Supernatural' changed to 'ccttoi,,aannttaadh,,SSeerrnnsrrqo'
# row: 1414 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'CCooneetSSii--SSoee'
# row: 841 col: 2 : 'Comedy,Parody,Sci-Fi' changed to 'pkddyyOsfooxtcck--Co'
# row: 1583 col: 2 : 'Animation,Action,Adventure,Horror,Mystery,Thriller' changed to 'AAbuaaro,,SiibAAddgduue,,HHoorrfoorrattrrryy,,TTfiirr'
# row: 1394 col: 2 : 'Drama,Sci-Fi,Shounen,Sports' changed to 'qmmsDccii--FF,,ZhhoojrWootss'
# row: 1428 col: 2 : 'Short,Drama' changed to 'it,,DDsk'
# row: 1280 col: 2 : 'Comedy,Drama,Romance' changed to 'VpmmuXaammaammaam'
# row: 791 col: 2 : 'Action,Romance' changed to 'AAfttiioo,,RRoommqcc'
# row: 1379 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Fantasy' changed to 'nniioonn,,AAfgiioom,,Foommwyyrriiee,,DDrrsFFyqyy'
# row: 321 col: 2 : 'Action,Adventure,Mecha' changed to 'cciioonn,,Qddbguurree,,MMeevhhq'
# row: 913 col: 2 : 'Fantasy,Kids' changed to 'FFgszyy,,KKuddss'
# row: 179 col: 2 : 'Drama' changed to 'rrmmaa'
# row: 1254 col: 2 : 'Animation,Short' changed to 'Sbiisr,,Dgoofy'
# row: 840 col: 2 : 'Ecchi,Seinen' changed to 'Rccxii,,Dkbeeb'
# row: 1400 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'jknqyiioonnooeeddhGaamttssumr'
# row: 1469 col: 2 : 'Action,Mystery,Romance,Supernatural,Thriller' changed to 'Sxl,,MMyyttrryy,,pqnncc,,ppwmgrr,,yiikee'
# row: 1172 col: 2 : 'Comedy' changed to 'Vooeet'
# row: 1016 col: 2 : 'Comedy' changed to 'Xkrx'
# row: 33 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'CCimmeehoommee,,llkviffiiffee'
# row: 1044 col: 2 : 'Comedy,Kids' changed to 'VoommeexKKodd'
# row: 386 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'ccgiib,,AAegdrreersaayy,,Joddd'
# row: 887 col: 2 : 'Comedy,Ecchi' changed to 'CCmmddyy,,Dcc'
# row: 806 col: 2 : 'Hentai' changed to 'Ywnnraak'
# row: 585 col: 2 : 'Crime' changed to ''
# row: 478 col: 2 : 'Hentai' changed to 'eeb'
# row: 1181 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'jiinqyulb,,Xkft,,DmttqyyToonnnr'
# row: 1358 col: 2 : 'Animation,Drama,Fantasy,Romance' changed to 'AAnnukaaupDDskaa,,raa,,RRmmqnnee'
# row: 304 col: 2 : 'Kids,Supernatural' changed to 'MSSyrfjsaall'
# row: 444 col: 2 : 'Animation,Action,Adventure' changed to 'Qunaaii,,opj,,AAcbuurree'
# row: 190 col: 2 : 'Sci-Fi' changed to 'kR'
# row: 1550 col: 2 : 'Action,Adventure,Sci-Fi' changed to 'Sttiioonn,,Sfvveejttuurree,,Dcc--Cu'
# row: 1271 col: 2 : 'Kids,Music' changed to 'KKiiss,,MMcc'
# row: 1095 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'CCkfyy,,RRpcc,,SSccjooo,,SSgioo'
# row: 340 col: 2 : 'Animation,Short,Action' changed to 'bmmsttiipnnSS,,vtto'
# row: 64 col: 2 : 'Comedy,Magic,Shoujo,SliceofLife' changed to 'FookeeeyysggiiccbpnooSSlliiccwoodLLw'
# row: 322 col: 2 : 'Animation,Adventure,Family,Fantasy,Sci-Fi' changed to 'SnnoaattiipjeennttirrFFkoyy,,FFmttssyySSo--G'
# row: 715 col: 2 : 'Short' changed to 'Ahhrrr'
# row: 504 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Snnksttu,,pkyymyssyy'
# row: 254 col: 2 : 'Hentai' changed to 'wbii'
# row: 1481 col: 2 : 'Drama,School' changed to 'q,,SSxll'
# row: 93 col: 2 : 'Short' changed to 'boofy'
# row: 1110 col: 2 : 'Comedy,Sci-Fi,Shounen,Shounen' changed to 'ookxyy,,iiRZhhooyjhhiuunnee'
# row: 1531 col: 2 : 'Animation,Action,Thriller' changed to 'nnoaayAAccttoomRrrlldrr'
# row: 40 col: 2 : 'Hentai' changed to 'eeii'
# row: 1111 col: 2 : 'Adventure,Kids' changed to 'Qddceemguurree,,KKii'
# row: 590 col: 2 : 'Drama,Kids' changed to 'Ftaammaa,,Miifss'
# row: 448 col: 2 : 'Adventure,Fantasy' changed to 'AAddeeyyrrr,,Gqnnyaadyy'
# row: 379 col: 2 : 'Music' changed to 'MMisscc'
# row: 119 col: 2 : 'Adventure,Fantasy' changed to 'ddcdnnttw,,FFttssyy'
# row: 1299 col: 2 : 'Action' changed to 'ttlb'
# row: 182 col: 2 : 'Adventure,Drama,Mecha,Sci-Fi,Shounen,Space' changed to 'ScryrrrFrraamm,,rv,,SScciiDuDuunnee,,SS'
# row: 57 col: 2 : 'Drama' changed to 'enaa'
# row: 1440 col: 2 : 'Comedy,Fantasy,Kids' changed to 'CCoonwdd,,qjsstMk'
# row: 980 col: 2 : 'Comedy,SliceofLife' changed to 'CClmmeefu,,ZkxdpKkdee'
# row: 1114 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Qmkkaattiioo,,ccm,,AAsvvwnnieeSSii--C'
# row: 1218 col: 2 : 'Comedy,School,Shounen,Supernatural' changed to 'xccbppSSjnnwnn,,uuppeejeqo'
# row: 807 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Shounen' changed to 'Qddvvwjuurrd,,Xooeexh,,FFaanngyyIdddWoojm'
# row: 522 col: 2 : 'Animation' changed to 'Snniimmttuoo'
# row: 1533 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'geettuurrr,,CCookh,,Aok,,goownn'
# row: 1213 col: 2 : 'Animation,Drama,History,Romance' changed to 'nniiniim,,soypeyyRRoommaannee'
# row: 996 col: 2 : 'Kids,Sci-Fi' changed to 'iiw,,SS--k'
# row: 306 col: 2 : 'Action,Sci-Fi,Thriller' changed to 'oobcc--FFiiRgellllee'
# row: 162 col: 2 : 'Animation' changed to 'nnkqyiilnn'
# row: 136 col: 2 : 'Animation,Adventure,Fantasy,Romance' changed to 'AAmmstt,,bttjrr,,FFydyyRRpkaannv'
# row: 21 col: 2 : 'Animation,Action,Comedy,Sci-Fi' changed to 'Qmmaattooo,,Qfnn,,Finwddyy,,W--'
# row: 341 col: 2 : 'Drama' changed to 'Xrrqs'
# row: 27 col: 2 : 'Drama,Mystery' changed to 'DDrraansKyyssryy'
# row: 143 col: 2 : 'Animation' changed to 'AAbuaaiioom'
# row: 978 col: 2 : 'Adventure,Kids' changed to 'AAeuuLiiddd'
# row: 582 col: 2 : 'Adventure,Mystery' changed to 'AAgnnttrree,,yyfyy'
# row: 1027 col: 2 : 'Action,Comedy,Kids' changed to 'AAfttonn,,CCkeeddyyMiiz'
# row: 1117 col: 2 : 'Adventure,Comedy,Magic' changed to 'AAvvnnttrrr,,neeshkcc'
# row: 288 col: 2 : 'Comedy,Parody' changed to 'CCoommdddyyOaarrooddyy'
# row: 947 col: 2 : 'Animation,Comedy,Music' changed to 'QjiirkooXoommwddt,,uucc'
# row: 745 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Horror' changed to 'miikqttinnQxyiim,,fgrnneee,,CClneee,,FFnnraassyy,,Jrreoo'
# row: 1145 col: 2 : 'Drama,Music,Thriller' changed to 'qmmsywoxTThhrriikkdrr'
# row: 1547 col: 2 : 'Comedy' changed to 'oondd'
# row: 624 col: 2 : 'Action,Thriller' changed to 'AAccttiim,,Ghhrriillrr'
# row: 276 col: 2 : 'Drama,Kids' changed to 'faansMusss'
# row: 650 col: 2 : 'Short,Fantasy,Music,Sci-Fi' changed to 'SSyiettbssyyMMaiiccSSxo'
# row: 401 col: 2 : 'Music' changed to 'Kuuu'
# row: 917 col: 2 : 'Drama' changed to 'Xtmmq'
# row: 852 col: 2 : 'Animation,Fantasy' changed to 'Qiiaattiioom,,Raaga'
# row: 422 col: 2 : 'Comedy,Sci-Fi,Shounen' changed to 'Fmmeeyy--G,,SSjpeem'
# row: 1528 col: 2 : 'Kids' changed to 'Mddz'
# row: 779 col: 2 : 'Animation,Action' changed to 'nnttiSkoonn'
# row: 1133 col: 2 : 'Drama,Historical,Kids' changed to 'DDfqmmaa,,Yossttlfiivs,,Mfss'
# row: 468 col: 2 : 'Drama,Historical,SliceofLife' changed to 'f,,ssfiicc,,AuooLLiid'
# row: 1336 col: 2 : 'Comedy,Fantasy' changed to 'ookdfhFFsnnttaayy'
# row: 1001 col: 2 : 'Ecchi,Music' changed to 'Whhu,,yox'
# row: 894 col: 2 : 'Comedy,Ecchi,Harem,Romance,School' changed to 'eeDccyYaadnEpaaccee,,Avooll'
# row: 1202 col: 2 : 'Comedy,Fantasy,Kids' changed to 'FpnehFFaattaass,,uddss'
# row: 986 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'SnniimmsttiinnvjQddmguuCsnn,,DiiD,,rrlleerr'
# row: 371 col: 2 : 'Animation,Comedy,Romance' changed to 'jiinaaiioonnVdd,,RRoonnee'
# row: 342 col: 2 : 'Animation,Action,Fantasy,Romance' changed to 'buguoo,,Sccooonn,,Rjgqdyy,,RRlqfee'
# row: 1274 col: 2 : 'Adventure,Comedy,Fantasy,Mecha,Shounen' changed to 'AAdnnttuurr,,Vlmmdeyy,,FFaannyaauhhaaSSnnb'
# row: 672 col: 2 : 'Action,Mecha,Sci-Fi,Shounen' changed to 'vgoi,,rxWxoFFii,,Doojnn'
# row: 1590 col: 2 : 'Adventure,Fantasy,Kids,Magic,MartialArts' changed to 'Qwyyrree,,FFaattq,,KKddss,,Nqggx,,srrttqQrrttss'
# row: 610 col: 2 : 'Comedy,Military,Parody,Sci-Fi,Space' changed to 'oommu,,KkgtPPaarrddyy,,oRii,,oaavee'
# row: 1156 col: 2 : 'Comedy' changed to 'lrddh'
# row: 719 col: 2 : 'Animation,Action,Sci-Fi' changed to 'AAkmmttooonn,,ccylnn,,ccRii'
# row: 277 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'SccriiijAAdddmrrdCCooeeddyy,,CaazLdd'
# row: 520 col: 2 : 'Animation,Action,Drama,Sport' changed to 'Qjommqttiipnn,,xttjSsaaAolg'
# row: 1014 col: 2 : 'Comedy,SliceofLife' changed to 'mmddyylllKoffd'
# row: 1574 col: 2 : 'Sci-Fi,Action,Animation' changed to 'ccii--FFii,,Qccttknnjiinsykoom'
# row: 784 col: 2 : 'Animation,Action,Comedy,Drama,Mystery,Sci-Fi' changed to 'Siimmsgum,,ccttki,,Voonrddyy,,DDrrmmaa,,Kgeerryy,,Zccii--D'
# row: 485 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'AAbusriiiccttkpnnddceettrrrooeeddqnh,,aannsu'
# row: 738 col: 2 : 'Animation,Adventure,Comedy,Romance' changed to 'Qjkmmqttkpnn,,AAddjrrw,,pmmeeddyyRRooaamccee'
# row: 1134 col: 2 : 'Hentai' changed to 'eettso'
# row: 165 col: 2 : 'Drama' changed to 'DDesnaa'
# row: 544 col: 2 : 'Animation,Comedy,Music' changed to 'AAnnummsttinnmmeeddyy,,ywiicc'
# row: 348 col: 2 : 'Drama,Romance' changed to 'XrrmmaaRRlkqnnccw'
# row: 1041 col: 2 : 'Action,Mecha,Romance' changed to 'Sinn,,Kdlqv'
# row: 935 col: 2 : 'Hentai,School' changed to 'eennsWvgill'
# row: 490 col: 2 : 'Animation,Action,Adventure,Comedy,Horror' changed to 'ttiiib,,QfttunnSfcmirr,,ookeeddyy,,pf'
# row: 221 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'ddbttyrrdoodd,,Cqraass'
# row: 153 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'AAiiuoonnSccgnn,,Qgdttuurr,,Fmmddd,,bttsz'
# row: 1526 col: 2 : 'Action,Adventure,Fantasy,Hentai' changed to 'iioojAAvvnnttj,,myaadyy,,dmqii'
# row: 828 col: 2 : 'Animation,Comedy' changed to 'Snniisyooonnlkeet'
# row: 1500 col: 2 : 'Fantasy,Music' changed to 'Gsttssu,,iocc'
# row: 687 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'AAvyoob,,AArttuurreeCCoonsyySSooyr'
# row: 562 col: 2 : 'Animation,Short,Action,Comedy,Romance' changed to 'jiiaaulSSySvb,,XkdTifee'
# row: 803 col: 2 : 'Cars' changed to 'Xaafw'
# row: 526 col: 2 : 'Animation,Comedy,Drama' changed to 'AAnniikttij,,ooee,,rrqs'
# row: 1135 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'AAnnddeebguuCClkee,,ooidm'
# row: 269 col: 2 : 'Comedy,Sci-Fi' changed to 'CCoodh,,--FF'
# row: 875 col: 2 : 'Action,Comedy,Horror,Shounen,Supernatural' changed to 'AAfttuoomVfJooeoorrDhhooiypptmqttis'
# row: 653 col: 2 : 'Action,Sci-Fi,Thriller' changed to 'AAvolnn,,Accii--FF,,TTjoorr'
# row: 1219 col: 2 : 'Animation,Drama' changed to 'iiaattlFaamm'
# row: 1031 col: 2 : 'Animation,Action,Adventure,Comedy,Crime,Fantasy,Mystery,Sci-Fi' changed to 'Sommaaooo,,SttiAAxwnnttjrr,,VinwVw,,FFaabqwyyKg,,Wccii--Du'
# row: 323 col: 2 : 'Animation,Drama,Romance' changed to 'AAnniimmaattii,,DDrraan,,lmmnnfee'
# row: 206 col: 2 : 'Kids,Music' changed to 'iifss,,jzuf'
# row: 1591 col: 2 : 'Animation' changed to 'mommrooo'
# row: 572 col: 2 : 'Hentai' changed to 'rbttqii'
# row: 782 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'ksttkoonnCCooks,,DDrrqkq,,jcc'
# row: 1423 col: 2 : 'Comedy' changed to 'pkx'
# row: 668 col: 2 : 'School,Shounen' changed to 'SScclijbnn'
# row: 965 col: 2 : 'Comedy,Ecchi,SliceofLife' changed to 'oommdd,,xhhSSoiiccrooffOff'
# row: 751 col: 2 : 'Drama' changed to 'Esaa'
# row: 29 col: 2 : 'Comedy,Drama,Fantasy' changed to 'lkddhrrqmm,,Rnnyaayy'
# row: 1495 col: 2 : 'Drama' changed to 'Srrmmq'
# row: 395 col: 2 : 'Fantasy,Music' changed to 'aabysdtssv'
# row: 222 col: 2 : 'Comedy' changed to 'oommddh'
# row: 723 col: 2 : 'Animation,Comedy,Fantasy,Mystery' changed to 'Qnniittk,,lnrddyyRaannaatKssr'
# row: 1163 col: 2 : 'Animation,Adventure,Crime,Mystery' changed to 'QiiqttooQxgnngjt,,CCtiiee,,MMyysseyy'
# row: 110 col: 2 : 'Short,Comedy' changed to 'Dhhoorr,,oonyy'
# row: 68 col: 2 : 'Animation,Comedy,Romance' changed to 'mmaattnnFeeeyy,,oonaaee'
# row: 1033 col: 2 : 'Horror,Sci-Fi' changed to 'HHprrei,,cciiRii'
# row: 166 col: 2 : 'Comedy' changed to 'ikeeyy'
# row: 1017 col: 2 : 'Kids' changed to 'Ikddss'
# row: 1203 col: 2 : 'Comedy,SliceofLife' changed to 'Xoommdddu,,eeoogLLug'
# row: 295 col: 2 : 'Comedy' changed to 'irdd'
# row: 1230 col: 2 : 'Animation,Drama,Sport' changed to 'AAmmiiirrq,,ppe'
# row: 1253 col: 2 : 'Action,Comedy,Ecchi,Fantasy,Harem,Magic,Romance' changed to 'ScciiipndeyyWii,,FFaanngaahHHqrrwfiicc,,Tinnfee'
# row: 65 col: 2 : 'Animation,Action,Sci-Fi' changed to 'AAiinaattuoonnQxii,,ccii--o'
# row: 952 col: 2 : 'Fantasy,Magic,School' changed to 'FFysd,,Ntcc,,SScciook'
# row: 570 col: 2 : 'Action,Demons,Fantasy,Hentai' changed to 'SgiioojFeeoojw,,Dbraa,,Gwttaao'
# row: 91 col: 2 : 'Hentai' changed to 'Jnnttk'
# row: 1301 col: 2 : 'Animation,Comedy,Drama,Sci-Fi' changed to 'AAbiikqtti,,Xoodft,,aan,,--k'
# row: 1386 col: 2 : 'Animation,Comedy' changed to 'bqroonnXlsu'
# row: 838 col: 2 : 'Comedy' changed to 'CCoowe'
# row: 414 col: 2 : 'Action,Adventure,Mecha,Romance,Sci-Fi,Shounen' changed to 'SpecttjNwhhs,,lmmaaj,,SSFFupjnnr'
# row: 471 col: 2 : 'Action,Fantasy,Shounen,SuperPower,Supernatural,Vampire' changed to 'b,,FFzyyZhhybdjjppwOoowwreSSotmaagrrqGmmppiie'
# row: 133 col: 2 : 'Animation,Comedy' changed to 'AAmiimmkooj,,Xlr'
# row: 927 col: 2 : 'Adventure,Historical,Shounen' changed to 'AAfgeejyeeHHossttptvllZoouunnee'
# row: 312 col: 2 : 'Action,Animation,Sci-Fi' changed to 'vkooAAiimmaattkooZcco--FFii'
# row: 402 col: 2 : 'Animation' changed to 'Snnuaaii'
# row: 775 col: 2 : 'Animation,Romance' changed to 'mummu,,RRaannfd'
# row: 1443 col: 2 : 'Adventure,Family,Fantasy,Romance' changed to 'Qddvveemttyrrd,,CaakktaannsshRRnnccee'
# row: 1586 col: 2 : 'Adventure,Sci-Fi' changed to 'fvvdjrrrAxiiFF'
# row: 1021 col: 2 : 'Action' changed to 'Sfoj'
# row: 704 col: 2 : 'Animation' changed to 'nnusttm'
# row: 1128 col: 2 : 'Action,Adventure,Mecha,Sci-Fi,Shounen' changed to 'AAfolnnAAsgttuurreeKeeSSuGiihhnneeb'
# row: 1383 col: 2 : 'Short,Animation' changed to 'ZhhlerAAommaapnn'
# row: 1059 col: 2 : 'Adventure,Comedy,Historical,Kids' changed to 'svvwttrr,,ooeeu,,ssrrrufskKKkxss'
# row: 892 col: 2 : 'Seinen,SliceofLife' changed to 'ZdiimSSkxeeoor'
# row: 596 col: 2 : 'Demons,Harem,Hentai,School,Supernatural' changed to 'mmmss,,HHsnbyqiiWxookApprrrqyrraa'
# row: 476 col: 2 : 'Animation,Comedy,Drama,Fantasy' changed to 'SmkttlnnmmddDDfaasDnnttsss'
# row: 634 col: 2 : 'Animation,Comedy,Drama,Music' changed to 'ttumktfsaa,,uuii'
# row: 1502 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Qnnosu,,Sccttnn,,sbeegtee,,gaayy'
# row: 156 col: 2 : 'Action,Drama,Fantasy,Historical,MartialArts' changed to 'AAfiinn,,DDrrmmaa,,Dttaa,,HHiizifiiq,,MMaarrttkllQr'
# row: 1136 col: 2 : 'Animation,Action,Comedy,Fantasy,Horror' changed to 'AAbiingkjQkoo,,CCpwddt,,FFsmgaaaoorroo'
# row: 137 col: 2 : 'Hentai' changed to 'Yeettqii'
# row: 456 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'SrmCCoorddhmmaa,,RRnjv'
# row: 696 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Qnnsiipnn,,AAttopnnCCleefh,,aamttaass,,Ecc'
# row: 1460 col: 2 : 'Comedy,Seinen,SliceofLife,SuperPower' changed to 'Fooeeddu,,SSdomWllcceerAyoeeiwrr'
# row: 648 col: 2 : 'Animation,Adventure,Comedy,Fantasy' changed to 'Snnmmaattuoo,,AAvvnngrrwVlmmf,,Csttaa'
# row: 1040 col: 2 : 'Comedy,Fantasy' changed to 'VpmmfhFFsjttaaw'
# row: 400 col: 2 : 'Kids,Music' changed to 'sz,,ydkx'
# row: 58 col: 2 : 'Animation,Short' changed to 'nqgonnSSoo'
# row: 385 col: 2 : 'Animation,Fantasy,Horror,Romance' changed to 'AAmaariipnnFFqssuHHoofrr,,RRimmxee'
# row: 1388 col: 2 : 'Animation' changed to 'Qmiimmrpm'
# row: 761 col: 2 : 'Animation,Action,Drama' changed to 'SiinaayiipnnttXskq'
# row: 1343 col: 2 : 'Drama,Family' changed to 'DDtaammqmmyy'
# row: 1330 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'QjmmsttlnnQddgwbyr,,FFaakoyyaattwyy'
# row: 1410 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Romance' changed to 'SnnknrooAAvttkl,,AAfvvdmttuurrd,,ookddyy,,Ffkaa,,FFaaqdyy,,pnaannfee'
# row: 391 col: 2 : 'Animation,Short' changed to 'AAmmaagiiiSSjoottt'
# row: 95 col: 2 : 'Hentai' changed to 'Bwmaaii'
# row: 181 col: 2 : 'Kids,Sports' changed to 'JSSoooegss'
# row: 1057 col: 2 : 'Comedy' changed to 'leeyy'
# row: 1541 col: 2 : 'Animation,Action,Drama,Fantasy,History,Sci-Fi' changed to 'QbiinqttiibQ,,DDeskaa,,FFsnnraaiiwrrt,,cckDk'
# row: 457 col: 2 : 'Action,Comedy,Historical,Mecha,Parody,Samurai,Sci-Fi,Shounen' changed to 'uijFoommeef,,dpvo,,MMrfsOsfit,,Asuurraako--o,,pdb'
# row: 535 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'unop,,AAcckpnn,,Xkees,,FFbttqssyy'
# row: 1510 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi' changed to 'QnnoaattnnQttinn,,SdddnnruuFFaanukyyqnnttsstccii'
# row: 1147 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy' changed to 'Sommaariioonn,,Scci,,AAddwjttyerDDrraak,,smttqau'
# row: 1320 col: 2 : 'Comedy,Sci-Fi' changed to 'mmeeddSSou'
# row: 514 col: 2 : 'Action,Drama,Fantasy,Mystery,Sci-Fi' changed to 'glj,,DDrrkqaanngaazyy,,yyttrryy,,WccoDo'
# row: 168 col: 2 : 'SliceofLife' changed to 'SSiipffkee'
# row: 1536 col: 2 : 'Comedy' changed to 'ooddd'
# row: 1282 col: 2 : 'Comedy,Kids,Shounen,Space' changed to 'oommxhiidd,,oo,,'
# row: 374 col: 2 : 'Animation' changed to 'AAjummaattoooj'
# row: 1250 col: 2 : 'Animation,Drama' changed to 'AAbiimmkp,,esmmq'
# row: 51 col: 2 : 'Kids' changed to 'Ie'
# row: 819 col: 2 : 'Adventure,Crime,Drama' changed to 'AAxirrd,,iikeeaammq'
# row: 1551 col: 2 : 'Comedy,Kids' changed to 'Xoommwuddw'
# row: 906 col: 2 : 'Comedy,Crime,Drama' changed to 'CCkees,,Frrokw,,Faaks'
# row: 1191 col: 2 : 'Comedy' changed to 'CCoonwddyy'
# row: 1267 col: 2 : 'Hentai' changed to 'HHnnr'
# row: 694 col: 2 : 'Drama' changed to 'saa'
# row: 943 col: 2 : 'Hentai' changed to 'Beenngii'
# row: 1507 col: 2 : 'Animation,Short,Action,Sci-Fi' changed to 'AAoii,,SShhoorrg,,ttoobSSvFF'
# row: 1242 col: 2 : 'Animation,Comedy' changed to 'AAnnkqttkooj,,leesyy'
# row: 1556 col: 2 : 'Animation,Short' changed to 'Qmmmaaiilj,,Dey'
# row: 1324 col: 2 : 'Animation,Adventure,Fantasy' changed to 'AAnnmmsiipnn,,AAvveennuut,,FFsnnttswh'
# row: 1598 col: 2 : 'Action,Comedy,Drama,MartialArts,SliceofLife,Sports' changed to 'ttoobCCnrddyy,,mm,,rrttosllQettz,,llccgKSSppiess'
# row: 1557 col: 2 : 'Comedy,Kids,Music' changed to 'CCinddyy,,Jkss,,uuucc'
# row: 469 col: 2 : 'Action,Horror,Sci-Fi,Thriller' changed to 'AAvuib,,oofrrp,,cc--ii,,hhrriillllt'
# row: 604 col: 2 : 'Hentai' changed to 'HHbttaa'
# row: 1398 col: 2 : 'Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'Sddwttyeee,,Voommru,,DfccjKeeccaa,,SSfiiiiZoaav'
# row: 867 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'iimmttoobQccttoownnjrree,,CCpDskouFFsz'
# row: 963 col: 2 : 'Hentai' changed to 'HHrii'
# row: 774 col: 2 : 'Hentai' changed to 'Grqk'
# row: 730 col: 2 : 'Comedy,Demons,Ecchi,Fantasy,Romance,Seinen' changed to 'mmeeddwmmlzEExcchhiimgszyy,,Ennnrwiinndm'
# row: 1344 col: 2 : 'Animation,Action,Fantasy,Romance,Sci-Fi' changed to 'Snnosooonn,,Sriilm,,Dsyyookaajv,,fii--'
# row: 1492 col: 2 : 'Action,Comedy,Ecchi,Romance,Sci-Fi' changed to 'ccru,,XooddhDccxgii,,ooqjccccii--Do'
# row: 850 col: 2 : 'Kids' changed to 'Mii'
# row: 214 col: 2 : 'Fantasy,Kids' changed to 'FFqjs,,Lod'
# row: 754 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'nnungiioobrlj,,SbttrrdFpee,,ccii--FFo'
# row: 465 col: 2 : 'Animation,Short,Action,Adventure,Drama,Fantasy,Sci-Fi' changed to 'mqgiipbhhxttnn,,QcgirreeSaammaaGh,,SSxiiii'
# row: 1338 col: 2 : 'Drama,Fantasy,Mystery' changed to 'DDqkaa,,nnr,,Kyyattdyy'
# row: 1189 col: 2 : 'Documentary' changed to 'Sknnttaaet'
# row: 631 col: 2 : 'Action,Adventure,Comedy,Mystery,Shounen' changed to 'Sfkoom,,AAbnnjd,,krttteet,,SSluunnb'
# row: 1199 col: 2 : 'Historical' changed to 'HHiittootiixaa'
# row: 1026 col: 2 : 'Animation,Action,Comedy' changed to 'nnnsriipQxkoonnXoommeeu'
# row: 125 col: 2 : 'Animation,Drama,Sport' changed to 'AAnnkmmqujqs,,r'
# row: 897 col: 2 : 'Animation,Action,Adventure,Family,Mystery,Thriller' changed to 'nnkmmaayiinn,,ccgiij,,Sceebryrree,,FFaakiiyyMMayeeuhhrrkllee'
# row: 138 col: 2 : 'Comedy,Drama,Josei,Romance,SliceofLife' changed to 'Xidd,,rrs,,ooziiToonqblluccgee'
# row: 1309 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi,Thriller' changed to 'AAnniiaariil,,fttiipnn,,AAddvveebttfee,,FFaanollDaannysdyy,,SSfii--FF,,Ryrriillt'
# row: 141 col: 2 : 'Animation,Short,Family' changed to 'AAjunaagijWjprrttFFsmmh'
# row: 189 col: 2 : 'Animation,Comedy,Drama' changed to 'Sokqr,,Flmmh,,DDfqkaa'
# row: 1 col: 2 : 'Animation,Short,Comedy' changed to 'SjommaattoiSSprrrFoommddh'
# row: 1307 col: 2 : 'Animation,Short,Comedy,Fantasy,Musical' changed to 'jiikaaruinn,,gg,,CCxyy,,Caattaasst,,uuuccqk'
# row: 330 col: 2 : 'Action,Comedy' changed to 'ccttojoommeeddyy'
# row: 854 col: 2 : 'Kids,Shoujo,Supernatural' changed to 'Mss,,DiAppmaattjtk'
# row: 1378 col: 2 : 'Animation,Short' changed to 'AAmii,,yoot'
# row: 107 col: 2 : 'Adventure,Comedy,Fantasy,Magic' changed to 'svvttuufee,,CCoommrsyyCaajttyy,,fo'
# row: 150 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'Xpmmeeyy,,oommqcceeSSvjllSShhyk'
# row: 812 col: 2 : 'Animation,Comedy' changed to 'kttlnn,,CCooeesyy'
# row: 1365 col: 2 : 'Drama' changed to 'aaaa'
# row: 1137 col: 2 : 'Comedy,Drama,Romance' changed to 'CCooeyy,,rraammaaooqnnccd'
# row: 1439 col: 2 : 'Adventure,Sci-Fi' changed to 'ddgjjrrwxFFo'
# row: 480 col: 2 : 'Animation' changed to 'nnrlnn'
# row: 1140 col: 2 : 'Animation,Short,Adventure,Family' changed to 'kkaattuooWoofg,,bdjttuuw,,Rll'
# row: 814 col: 2 : 'Hentai,Magic,Supernatural' changed to 'HHrq,,Nqvccuuweaayuuf'
# row: 767 col: 2 : 'Adventure,Mecha,Sci-Fi,Shounen' changed to 'vvyrMMccbaaWccu,,SSjiinneem'
# row: 246 col: 2 : 'Action,Adventure,Comedy,Magic,Mecha,Sci-Fi' changed to 'ccooonn,,AAsrbuue,,Veeeaau,,MMeevhhSSii--FFu'
# row: 595 col: 2 : 'Drama,Historical' changed to 'Saan,,sslkccq'
# row: 396 col: 2 : 'Drama,Supernatural,Thriller' changed to 'rrsmmq,,Doeerrnnsgeaall,,Gbellllrrr'
# row: 1312 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'mmsriiSimVinyy,,SSpf'
# row: 1427 col: 2 : 'Action' changed to 'ccooonn'
# row: 1353 col: 2 : 'Comedy,Kids' changed to 'mmeefu,,KKux'
# row: 1205 col: 2 : 'Mystery,Shounen' changed to 'Kyyssrrryy,,gjd'
# row: 445 col: 2 : 'Animation,Drama,Romance,Sci-Fi' changed to 'AAkiioom,,Eqn,,Elaannv,,SSfiiFFk'
# row: 467 col: 2 : 'Drama,Sci-Fi' changed to 'Xmmaa,,SSxFFu'
# row: 643 col: 2 : 'Comedy' changed to 'mmddyy'
# row: 290 col: 2 : 'Short' changed to 'SShhoott'
# row: 1175 col: 2 : 'MartialArts,School,Shounen,Sports' changed to 'MMsukrrttSShhoooo,,SShhijnnnnSSppootta'
# row: 274 col: 2 : 'Animation,Comedy,Drama,Fantasy,Sci-Fi' changed to 'Qjkro,,CClwdd,,DDrrmm,,FFaaqyy,,DccGk'
# ...
# row: 441 col: 2 : 'Animation,Comedy,Fantasy' changed to 'nnkniiCCpmmwddt,,Crqdu'
# row: 256 col: 2 : 'Animation' changed to 'Qiimmaattooj'
# row: 1073 col: 2 : 'Drama,Fantasy,Sci-Fi,Thriller' changed to 'fq,,qnnaayySScciijlleef'
# row: 205 col: 2 : 'Animation,Short' changed to 'Qjiiyknngoott'
# row: 910 col: 2 : 'Drama,Kids,Sports' changed to 'FtmmaaKKoddss,,ess'
# row: 122 col: 2 : 'Action,Family,Adventure,Comedy,Fantasy' changed to 'ttupnn,,CaammiiAAsbmttj,,CCookxuFFsttaaau'
# row: 1588 col: 2 : 'Comedy,Historical' changed to 'CCkHHuzttfxs'
# row: 47 col: 2 : 'Drama,Horror,Thriller' changed to 'DDtsnqHHrrprr,,brroeerr'
# row: 553 col: 2 : 'Romance,Shoujo' changed to 'FooaajvSSooy'
# row: 579 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Sci-Fi' changed to 'QjaannQoonn,,Vieefyy,,DDtaas,,Dsmh,,SSccii'
# row: 1537 col: 2 : 'Animation,Drama,Fantasy,Romance' changed to 'AAnnoqrraanaa,,Dqmttaawt,,Fkaaee'
# row: 1529 col: 2 : 'Comedy' changed to 'Xeu'
# row: 1178 col: 2 : 'Animation,Action,Sport' changed to 'knriinnSoonn,,orrg'
# row: 1287 col: 2 : 'Animation,Action,Horror,Mystery,Sci-Fi' changed to 'AAmmmqimQyYfrroorr,,Nyyat,,SSxk'
# row: 636 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'QiikoooVyySSx--Dii'
# row: 1082 col: 2 : 'Short,Drama' changed to 'SSooDDrraaaa'
# row: 1161 col: 2 : 'Animation,Action,Sci-Fi' changed to 'nniimmsttoonn,,frklm,,oFF'
# row: 926 col: 2 : 'Adventure,Comedy,Drama' changed to 'ddwbgieee,,CCeeddh,,DDtaak'
# row: 1146 col: 2 : 'Comedy' changed to 'dt'
# row: 1544 col: 2 : 'Animation' changed to 'AAiimmttpj'
# row: 1246 col: 2 : 'Animation,Short' changed to 'nnaaoo,,yooey'
# row: 1534 col: 2 : 'Drama,Kids' changed to 'DDrrqkaaMess'
# row: 229 col: 2 : 'Animation' changed to 'nnmmaattoonn'
# row: 1227 col: 2 : 'Comedy,Historical,Sci-Fi' changed to 'lkwddu,,HHodooiivaa,,SSxuFFo'
# row: 1497 col: 2 : 'Animation,Sci-Fi,War' changed to 'nnkaattiiooDviiFFuSaarr'
# row: 942 col: 2 : 'Drama,Hentai,Romance,Sci-Fi' changed to 'DDfaans,,eerqii,,oommccee,,ccii--'
# row: 1176 col: 2 : 'Comedy,Parody' changed to 'aaidd'
# row: 587 col: 2 : 'Talk-Show' changed to '--hhoo'
# row: 184 col: 2 : 'Animation,Short' changed to 'AAmkqkoo,,yooett'
# row: 1305 col: 2 : 'Animation,Short' changed to 'ttkinnSShhg'
# row: 15 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'XlkwxyyEExoHHaafmm,,RRmmaannccee'
# row: 405 col: 2 : 'Animation,Short,Comedy' changed to 'Qnniiiilnn,,SSprry,,CCoommdx'
# row: 100 col: 2 : 'Comedy,SliceofLife' changed to 'XooeeyyDuccoogocw'
# row: 877 col: 2 : 'Drama,Military,Sci-Fi,Space' changed to 'aanaaMMollttaatyySSu,,ppaax'
# row: 652 col: 2 : 'Drama,SliceofLife' changed to 'sqoiicceepKuffr'
# row: 513 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'AAddvvttjerrrqZfii'
# row: 798 col: 2 : 'Action,Comedy,Harem,Mecha,Sci-Fi' changed to 'ccroCCmmeesyyJaarreekMMrgaa,,SSccoFF'
# row: 343 col: 2 : 'Kids' changed to 'KKiiddss'
# row: 215 col: 2 : 'Animation,Romance' changed to 'QknsuoojRRimmnnee'
# row: 1582 col: 2 : 'Adventure,Drama' changed to 'nnyirrd,,Srraanaa'
# row: 1465 col: 2 : 'Animation,Short,Music' changed to 'jnaaoob,,Zhhrrtt,,Niicc'
# row: 956 col: 2 : 'Fantasy,Kids' changed to 'Gqnnttsssyyfss'
# row: 1011 col: 2 : 'Animation' changed to 'AAnniimmqpb'
# row: 966 col: 2 : 'Drama,Kids' changed to 'Srrqnaa,,KKiiddss'
# row: 1488 col: 2 : 'Drama' changed to 'Srrs'
# row: 360 col: 2 : 'Comedy,Ecchi,Fantasy,Romance,SliceofLife' changed to 'Vlmmd,,RjGaajaassyy,,Fimmaamxee,,WkwrLLiir'
# row: 661 col: 2 : 'Animation,Sci-Fi' changed to 'naattiiooSSii--Dii'
# row: 43 col: 2 : 'Comedy' changed to 'CCpkwddu'
# row: 851 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'wnngf,,kstFFsnnraasskess'
# row: 140 col: 2 : 'Animation,Short,Fantasy' changed to 'AAnnaattoobSShhgFFaasayy'
# row: 1349 col: 2 : 'Kids,Sports' changed to 'o,,opw'
# row: 412 col: 2 : 'Adventure,Drama,Fantasy' changed to 'QgeejuuDDeaaaaFFnnrsd'
# row: 525 col: 2 : 'Animation,Family' changed to 'AAnnoiib,,aanuo'
# row: 1485 col: 2 : 'Drama,Sci-Fi,Space' changed to 'Xtaamm,,SSoiiZcc'
# row: 213 col: 2 : 'Animation,Comedy,Drama' changed to 'AAiimmsgiilm,,CCpmmwxh,,rrqaa'
# row: 1261 col: 2 : 'Comedy,Fantasy,Music' changed to 'CCoommddyyFFnnttaa,,Nuuzf'
# row: 1023 col: 2 : 'Fantasy,Kids' changed to 'Raamrah,,KKii'
# row: 352 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'SokqiiiAAfiSxrbttjewCCoommyyiiFF'
# row: 1038 col: 2 : 'Mystery' changed to 'MMhssydrrt'
# row: 353 col: 2 : 'Demons,Fantasy,Hentai,Supernatural' changed to 'Xdkbqaassyy,,Geemaauuofsryrrk'
# row: 1081 col: 2 : 'Comedy,Seinen' changed to 'CCnddyySSeeunneenn'
# row: 505 col: 2 : 'Music' changed to 'Kiicc'
# row: 1075 col: 2 : 'Hentai' changed to 'HHbys'
# row: 87 col: 2 : 'Drama' changed to 'DD'
# row: 1380 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'AAfonn,,AAeceemttjw,,FFnnttqss,,Kccy'
# row: 367 col: 2 : 'Animation' changed to 'Qmiikaatt'
# row: 394 col: 2 : 'Kids,SliceofLife' changed to 'KKiiswZudoogLLkg'
# row: 766 col: 2 : 'Animation,Short,Comedy' changed to 'QnnnrpSSooerCCnfyy'
# row: 297 col: 2 : 'Animation' changed to 'AAbummaattiioo'
# row: 1553 col: 2 : 'Adventure,Shounen' changed to 'AAebrbjeejooidnn'
# row: 418 col: 2 : 'Drama,Kids' changed to 'DDrrnqodda'
# row: 435 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'SvgoonnQxtti,,dxhhaa,,D--FFii'
# row: 698 col: 2 : 'Comedy,Hentai,Yuri' changed to 'XrddHHeettii,,rrii'
# row: 75 col: 2 : 'Fantasy' changed to 'FFaabyqss'
# row: 1396 col: 2 : 'Animation,Adventure,Comedy' changed to 'nniiqlbAAvvdnnuud,,CCooeeddyy'
# row: 1131 col: 2 : 'Comedy,Historical,Parody' changed to 'VoommeeHHiidyltfqll,,Ostlu'
# row: 393 col: 2 : 'Action,Drama,Fantasy,Horror,Mystery,Sci-Fi' changed to 'Sccttiiinnfq,,Caannttqt,,lrrfrr,,zttdthZu'
# row: 437 col: 2 : 'Game,Shounen' changed to 'GGaammee,,SSbiyrj'
# row: 218 col: 2 : 'Animation,Short,Music' changed to 'biimmiiloofy,,MMiss'
# row: 1360 col: 2 : 'Drama,Fantasy,Mystery,Romance,School' changed to 'smms,,RnnraassyyNssgrrr,,EkxrDgooooll'
# row: 1225 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'iiaarkoonn,,CCindddyy,,XfaaaaRRoosmccd'
# row: 976 col: 2 : 'Adventure' changed to 'cmgf'
# row: 1372 col: 2 : 'Action,Adventure,Comedy,Crime,Mystery,Thriller' changed to 'xlnnAAvvwbttteeCCrhCCun,,KtssryyGrriillke'
# row: 131 col: 2 : 'Animation' changed to 'AAnniinaattiip'
# row: 1105 col: 2 : 'Romance,SliceofLife' changed to 'q,,SSlliifeedLLff'
# row: 722 col: 2 : 'Animation,Drama,Family,Fantasy' changed to 'AAjiittoonnSnaa,,slluDgqssyy'
# row: 217 col: 2 : 'Animation,Action,Sci-Fi' changed to 'bommoonnAAtt,,ccii--ii'
# row: 588 col: 2 : 'Animation,Short' changed to 'jkttiilnn,,Zg'
# row: 888 col: 2 : 'Adventure,Drama,MartialArts,Romance,Shounen,Supernatural' changed to 'errw,,DDrraammaa,,aatttkaaofg,,aajwhhmeennSSjpptttuufqll'
# row: 1184 col: 2 : 'Animation,Comedy' changed to 'nnunqgiiooFmmddh'
# row: 1003 col: 2 : 'Action,Drama,War' changed to 'QiiDDeqmm'
# row: 370 col: 2 : 'Comedy,SliceofLife' changed to 'Xkxh,,Wlliixeeoodiid'
# row: 1350 col: 2 : 'Animation' changed to 'AAiikiioonn'
# row: 160 col: 2 : 'Animation,Adventure,Fantasy' changed to 'SnniimmaagiiSbeettfeejyaaa'
# row: 372 col: 2 : 'Hentai,Yuri' changed to 'HHeennttaaiiUtu'
# row: 1258 col: 2 : 'Dementia' changed to 'DDweetto'
# row: 193 col: 2 : 'Hentai' changed to 'HHwtts'
# row: 96 col: 2 : 'Fantasy,Kids' changed to 'Dnnttss,,KKddss'
# row: 954 col: 2 : 'Action,Adventure,Comedy,Fantasy,Shounen,SuperPower' changed to 'SfynnQvvbttyfXoojsshhoonnee,,WuuppfPPeet'
# row: 244 col: 2 : 'Comedy' changed to 'eedd'
# row: 1524 col: 2 : 'Hentai' changed to 'Jii'
# row: 270 col: 2 : 'Short' changed to 'SSirrtt'
# row: 1337 col: 2 : 'Fantasy,Action,Adventure' changed to 'DqaatQcciioonnvvwmuuer'
# row: 88 col: 2 : 'Hentai' changed to 'eeii'
# row: 788 col: 2 : 'Animation' changed to 'AAommqiinn'
# row: 681 col: 2 : 'Drama,Family' changed to 'DDaaDiiku'
# row: 152 col: 2 : 'Action' changed to 'ccgooo'
# row: 949 col: 2 : 'Action,Sci-Fi' changed to 'ccyiib,,vii--C'
# row: 1438 col: 2 : 'Comedy' changed to 'CClnddyy'
# row: 718 col: 2 : 'Drama,Thriller' changed to 'enaaiiot'
# row: 523 col: 2 : 'Documentary,Animation,Short,History' changed to 'DDmmeeraarrSnniiksoob,,Gkssytt'
# row: 1357 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Qmsol,,AAddgrnnr,,FFaaot,,Raattssu'
# row: 80 col: 2 : 'Action,Comedy,Kids,Shounen,SuperPower' changed to 'Sfttiiljidtkessoojnnbuuwfieerr'
# row: 688 col: 2 : 'Action,Comedy,SuperPower' changed to 'AAviiinn,,VpkeeeyyuupprrOsee'
# row: 1098 col: 2 : 'Hentai,School' changed to 'Grttsiigooll'
# row: 328 col: 2 : 'Romance' changed to 'RRlqbr'
# row: 697 col: 2 : 'Animation,Action,Romance,Sci-Fi' changed to 'ukttiioonn,,voljinqnn,,WkFFo'
# row: 474 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family,Fantasy,Sci-Fi,Thriller' changed to 'AAnngum,,b,,Sddvveebryrr,,immeeDDrrsRaankkjaat,,SSfu--u,,iill'
# row: 31 col: 2 : 'Documentary,Music' changed to 'iirrrr,,MMy'
# row: 1310 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'jknaattooQvvnnttrrd,,x--FFo'
# row: 690 col: 2 : 'Mecha,Military' changed to 'MMdhhaaMMllottse'
# row: 233 col: 2 : 'Animation,Action,Fantasy' changed to 'SnnknopnnSccttoob,,Csjttyy'
# row: 1141 col: 2 : 'Animation,Short,Fantasy' changed to 'AAqyolm,,AhhptDqqh'
# row: 1153 col: 2 : 'Mecha,Sci-Fi,Shounen' changed to 'MMcc,,SSxoFF,,SSpuuwb'
# row: 747 col: 2 : 'Short' changed to 'SSj'
# row: 654 col: 2 : 'Hentai' changed to 'eeg'
# row: 325 col: 2 : 'Comedy' changed to 'CCmmrsyy'
# row: 750 col: 2 : 'Animation,Family,Adventure,Fantasy' changed to 'mmgiilb,,Raaddceejrrree,,FFsnnttaassyy'
# row: 649 col: 2 : 'Drama,Kids' changed to 'XfqaaJkxss'
# row: 1368 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'uroiCCieeu,,Sns,,aaaassoonaabfr'
# row: 1179 col: 2 : 'Animation,Short,Drama,Music' changed to 'bnaaiiAjrrttFaaNissv'
# row: 227 col: 2 : 'Comedy' changed to 'ookeeeyy'
# row: 627 col: 2 : 'Hentai' changed to 'HHttaau'
# row: 1030 col: 2 : 'Action,Comedy,Ecchi,Harem,Magic,Supernatural' changed to 'xii,,CCpkdddh,,EEvccj,,qfeensggof,,Duudnnaattsll'
# row: 1347 col: 2 : 'Comedy,Romance,School,Seinen,SliceofLife' changed to 'Vlwet,,oommaanncccchho,,SSeennbSSoxdoouw'
# row: 180 col: 2 : 'Drama,Family' changed to 'qmmaa,,kiillh'
# row: 1000 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'Qnniiqoonn,,jftt,,vrulnn,,AAddvveennttuu,,Rwyy'
# row: 438 col: 2 : 'Animation,Adventure,Fantasy' changed to 'AAommttolj,,fvveennjrreettaayy'
# row: 1467 col: 2 : 'Animation,Comedy,Family,Fantasy,Romance' changed to 'AAommaattoopkyy,,aanoyy,,Djz,,RRooksnnf'
# row: 420 col: 2 : 'Comedy' changed to 'ooddu'
# row: 1035 col: 2 : 'Drama,Kids' changed to 'Frraammaa,,iifss'
# row: 568 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'konnryy,,DDeqmmaa,,oommsxee'
# row: 1221 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'iionnCCeeu,,Zii--'
# row: 1532 col: 2 : 'Comedy,Romance,School' changed to 'Vpmmwdd,,Tkjcc,,SSccli'
# row: 1192 col: 2 : 'Animation' changed to 'AAjqoob'
# row: 1385 col: 2 : 'Short,Sci-Fi,War' changed to 'Doorryrr'
# row: 1212 col: 2 : 'Animation,Comedy,Romance' changed to 'AAjkkaattiooddyy,,RRoommaajd'
# row: 998 col: 2 : 'Music' changed to 'uussii'
# row: 13 col: 2 : 'Drama' changed to 'DDtaamms'
# row: 176 col: 2 : 'Comedy' changed to 'lmmwfh'
# row: 611 col: 2 : 'Animation,Drama,Sport' changed to 'jokaaoo,,SmmaaDirrtt'
# row: 24 col: 2 : 'Comedy,School' changed to 'CCoordd,,ooi'
# row: 363 col: 2 : 'Comedy' changed to 'oommyy'
# row: 66 col: 2 : 'Comedy,School,Supernatural' changed to 'oowDooioAoeefnnsttrraall'
# row: 1054 col: 2 : 'Hentai' changed to 'HHjttu'
# row: 1126 col: 2 : 'Horror,Mystery,Psychological,School,SliceofLife' changed to 'rroo,,KyyzttdrryyOssyyooxsll,,foooollSSkiiccgugee'
# row: 881 col: 2 : 'Animation,Short' changed to 'nniisunn,,Whhftt'
# row: 204 col: 2 : 'Horror,Mystery,Thriller' changed to 'HHoorrfhssyeerr,,TThhoor'
# row: 332 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance,Sci-Fi' changed to 'AAuttonnvyu,,CCneeddGmrsst,,Ekfrcc--FFii'
# row: 362 col: 2 : 'Comedy,Ecchi,Fantasy,Game' changed to 'CCleeRxvkFFaabaassyy,,GGnd'
# row: 462 col: 2 : 'Action,Adventure,Crime,Drama,Mystery' changed to 'AArkooSevveennttCCfmmr,,Xq,,Kayeee'
# row: 921 col: 2 : 'Sci-Fi' changed to 'SSvii--FFo'
# row: 121 col: 2 : 'Action,Adventure,Demons,Fantasy,Game,Kids,Magic,Sci-Fi,Supernatural' changed to 'frkib,,AAvvbuuDDissnngaayy,,Tkd,,uddss,,aaggccSSccRkuuodebttuu'
# row: 1549 col: 2 : 'School,Shounen,Sports' changed to 'Wyook,,Zhhimeenn,,ooss'
# row: 1419 col: 2 : 'Comedy,Magic' changed to 'immwddhMMskx'
# row: 313 col: 2 : 'Documentary' changed to 'DDoovuueemgaaft'
# row: 873 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'AAvveejyrr,,ieeddyyyysseyy,,PPooovdDjoouumnn'
# row: 753 col: 2 : 'Action,Comedy,Sci-Fi,SuperPower' changed to 'AAvttiipm,,oommdhDccii--D,,SSpprtPPwwrrr'
# row: 545 col: 2 : 'Action,Sci-Fi' changed to 'ttiiinn,,AccuD'
# row: 439 col: 2 : 'Reality-TV' changed to 'RReeiigyyY'
# row: 1236 col: 2 : 'Animation,Short,Comedy,Crime,Fantasy' changed to 'Snnttiiinn,,ooer,,CCeeddtknee,,qmsyy'
# row: 647 col: 2 : 'Animation,Action,Fantasy' changed to 'AAummsgkb,,Svkb,,Rsttdyy'
# row: 331 col: 2 : 'Animation' changed to 'munaattoi'
# row: 419 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'AAccttiioo,,AAee,,VooneeddSShhpuunnwnn'
# row: 443 col: 2 : 'Hentai,Yuri' changed to 'tts,,Tuurro'
# row: 1356 col: 2 : 'Mecha,Military,Sci-Fi,Space' changed to 'Kccbaa,,MMhSScco--SSsee'
# row: 1456 col: 2 : 'Animation,Short' changed to 'nnkiiooAhhoog'
# row: 625 col: 2 : 'Hentai' changed to 'Bw'
# row: 1322 col: 2 : 'Music' changed to 'Njziif'
# row: 769 col: 2 : 'Action' changed to 'Qcciip'
# row: 130 col: 2 : 'Horror' changed to 'Birrrrlrr'
# row: 1548 col: 2 : 'Action,Fantasy,Seinen,Supernatural' changed to 'cciiib,,FFjttaakbwnnisjqll'
# row: 1148 col: 2 : 'Historical,Mystery,Shounen' changed to 'YttccMMyyzttAooynneej'
# row: 159 col: 2 : 'Drama' changed to 'fn'
# row: 1233 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'AAnaayooom,,mmw,,Frrmm,,FFjsstEkbcc'
# row: 999 col: 2 : 'Animation,Drama' changed to 'Qbiikrii,,DDqmmq'
# row: 1119 col: 2 : 'Comedy' changed to 'lneet'
# row: 982 col: 2 : 'Animation,Short' changed to 'urujSShhoot'
# row: 1335 col: 2 : 'Animation,Comedy' changed to 'kqttiioonnCCoommeeddyy'
# row: 28 col: 2 : 'Animation,Adventure,Fantasy,Sci-Fi' changed to 'AAiiaatt,,AAfvvrteeFFaannyssyy,,SSxFFii'
# row: 423 col: 2 : 'Comedy' changed to 'oommeeddu'
# row: 1222 col: 2 : 'Drama,Fantasy,Kids' changed to 'DDDsttaasshKKiiw'
# row: 59 col: 2 : 'Adventure,Fantasy,Shounen,Supernatural' changed to 'AAeceettuurrFFqaaupymeeSSuuppeetnnaayuurrk'
# row: 1085 col: 2 : 'Drama,Kids' changed to 'DDsmmsii'
# row: 1269 col: 2 : 'Comedy' changed to 'CCmmeeyy'
# row: 536 col: 2 : 'Sport' changed to 'Wppoof'
# row: 403 col: 2 : 'Comedy' changed to 'CClkeefyy'
# row: 670 col: 2 : 'Fantasy,Kids' changed to 'FFsgssuKKiiss'
# row: 236 col: 2 : 'Action,Adventure,Fantasy' changed to 'AAfkj,,AAeenngjee,,aass'
# row: 1332 col: 2 : 'Adventure,Kids' changed to 'Qgeeryt,,Miidd'
# row: 818 col: 2 : 'Animation,Fantasy,Music' changed to 'Qnniinsgm,,FFaajrdtNi'
# row: 736 col: 2 : 'Action,Comedy,Ecchi,Shounen,Sports' changed to 'Sccttuib,,oommddu,,vxoWooeennrrrss'
# row: 1498 col: 2 : 'Animation,Action,Comedy,Family' changed to 'QmiiaariiooAAfttiioonn,,krDmmollyy'
# row: 1290 col: 2 : 'Animation,Comedy,Romance' changed to 'AAjnqttonnFpmmeexRRmmqjee'
# row: 884 col: 2 : 'Comedy,Action,Drama,Family' changed to 'CCndd,,xyiiDDqkq,,FFsmmullyy'
# row: 1283 col: 2 : 'Fantasy,Kids,Magic,Romance,Shoujo,SuperPower' changed to 'RmttqssKKss,,qggkcc,,RRooaajAjoouuAppflwwdt'
# row: 934 col: 2 : 'Animation,Drama,Horror,Mystery,Thriller' changed to 'AAkaaykmaasooefootNtatteet,,TTbfiikee'
# row: 781 col: 2 : 'Animation,Short,Horror' changed to 'niijSSoottHHoorrrrirr'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1545, 9588)
# (24, 9588)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1545, 9587)
# (24, 9587)
# (1545, 700)
# (24, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1873555.61
# Mean squared error: 17196449792240.95
# Variance score: -7668258932834623667772063744.00

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.14
# Mean squared error: 1.34
# Variance score: -45.77

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.887 0.994 0.853 0.994 0.888]
# Mean: 0.9230153882818865
# Standard deviation: 0.05898809896010753

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 10, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.01}
# The mean squared Error is: 0.82
