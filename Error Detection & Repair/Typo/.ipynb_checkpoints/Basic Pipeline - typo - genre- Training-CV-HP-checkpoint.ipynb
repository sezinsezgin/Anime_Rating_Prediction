# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Butterfingers(),75, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Butterfingers().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Butterfingers().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Butterfingers method ---------------
#
# row: 398 col: 2 : 'Animation' changed to 'Abukctmij'
# row: 360 col: 2 : 'School' changed to 'Rchlmk'
# row: 454 col: 2 : 'Shounen' changed to 'Vrokjtn'
# row: 1178 col: 2 : 'Animation,Comedy' changed to 'Suimatkon,Cumegg'
# row: 688 col: 2 : 'Action,Fantasy,ShounenAi,SuperPower,Supernatural' changed to 'Abflot,Wandwsy,SgjungbCi,SuierPoxer,Au'zrnwtucal'
# row: 1329 col: 2 : 'Drama,Kids' changed to 'Braiz,Kids'
# row: 1358 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Magic' changed to 'Advejttrq,Xokfdi,Hantasj,Kmsx,Nagmc'
# row: 325 col: 2 : 'Animation,Fantasy' changed to 'Amlmseion,Fakgern'
# row: 11 col: 2 : 'Animation,Action,Fantasy' changed to 'Anikerjoj,Acbion,Fabbssy'
# row: 136 col: 2 : 'Action,Comedy,Ecchi,Harem,Romance,Supernatural' changed to 'Wccipk,Comcdb,Gbxfi,Jdfwm,Gumzics,Su'ecnctlrql'
# row: 1579 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'Wgimatijn,Axroob,Foiedr,Vdgtavu,Aci-Hi'
# row: 1476 col: 2 : 'Animation,Comedy,Drama' changed to 'Wnukatiui,Rmmgdv,Atama'
# row: 303 col: 2 : 'Action,Comedy,Fantasy,Magic,Music,Shoujo' changed to 'Cctoon,Cjmedy,Fwtnqfh,Majic,Luwnc,Wjmuji'
# row: 1241 col: 2 : 'Animation,Adventure,Crime,Mystery' changed to 'Avumzroon,Advgndure,Crimr,Myatgrj'
# row: 265 col: 2 : 'Music' changed to 'Mgfic'
# row: 327 col: 2 : 'Animation,Drama,Sport' changed to 'Einmetnon,Brzlc,Skorh'
# row: 1451 col: 2 : 'Drama,Fantasy,Kids' changed to 'Sgsod,Gdjtesy,Ykbf'
# row: 62 col: 2 : 'Adventure,Comedy,Drama,Fantasy,Historical,Romance' changed to 'Zgtchtjww,Coleay,Brqja,Yantaxy,Fnwvidicxj,Domxvcs'
# row: 653 col: 2 : 'Action,Adventure,Drama,Fantasy,Historical,Shounen,Supernatural' changed to 'Awumlt,Scdejfogg,Bramc,Xxutsvy,Hhftorydau,Rhkunej,Rykeskdtkeel'
# row: 339 col: 2 : 'Animation,Action,Sport' changed to 'Annmatpln,Actmmn,Spmft'
# row: 552 col: 2 : 'Drama,Historical' changed to 'Gcaic,Jhstlgifak'
# row: 1122 col: 2 : 'Drama,Romance,Yaoi' changed to 'Vraka,Rimwbwe,Jali'
# row: 615 col: 2 : 'Action,Adventure,Drama,Mystery,Sci-Fi' changed to 'Xxtiiu,Svveuuurx,Deaia,Musterg,Fck-Fi'
# row: 25 col: 2 : 'Kids,Music' changed to 'Hidv,Lusie'
# row: 223 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Atikatjon,Conefn,Fwiuasy,Rmmqgfe'
# row: 301 col: 2 : 'Comedy,Seinen,SliceofLife' changed to 'Xjlebu,Senbgn,AllcepnJise'
# row: 1002 col: 2 : 'School' changed to 'Sbhool'
# row: 244 col: 2 : 'Comedy,Fantasy' changed to 'Emmvei,Gaktasy'
# row: 1133 col: 2 : 'Comedy,Drama,Romance' changed to 'Comgat,Etams,Fomxnge'
# row: 644 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Wnlmaniii,Qcdjmn,Ednentlrt,Rcndawu,Sci-Fi'
# row: 1051 col: 2 : 'Animation' changed to 'Amlmzgikh'
# row: 1115 col: 2 : 'Animation,Short' changed to 'Ailkwdloi,Xyorf'
# row: 93 col: 2 : 'Comedy,Kids,SuperPower' changed to 'Zkjady,Higs,DmpsfPoaar'
# row: 258 col: 2 : 'Animation,Comedy,Drama,Fantasy,Horror,Mystery' changed to 'Atpodjyov,Cuiesn,Edxms,Fwkysfy,Hiwrie,Kgsyexj'
# row: 415 col: 2 : 'Action,Drama,Seinen' changed to 'Zcrikj,Drqma,Dvlneg'
# row: 731 col: 2 : 'Romance,Sports' changed to 'Flkange,Fpotux'
# row: 711 col: 2 : 'Comedy,Police' changed to 'Zukeab,Oookcf'
# row: 544 col: 2 : 'Animation,Sci-Fi' changed to 'Wgkiatpun,Swj-Xl'
# row: 931 col: 2 : 'Animation,Short' changed to 'Ajioselon,Shpry'
# row: 1220 col: 2 : 'Drama,Historical,Military' changed to 'Erxma,Hhatmwhswp,Mmpifery'
# row: 968 col: 2 : 'Kids' changed to 'Llda'
# row: 330 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'Amynatioj,Xction,Aabfntlrz,Fentaay,Wbi-Xk,Theyulet'
# row: 1386 col: 2 : 'Action,Psychological,Shounen,Supernatural,Thriller' changed to 'Wveion,Isyshklidieal,Fmjunxn,Fupacnzturep,Yhrolldr'
# row: 1363 col: 2 : 'Fantasy,Kids,Supernatural' changed to 'Faunavy,Kidw,Wtpcrtatnddl'
# row: 665 col: 2 : 'Crime,Drama' changed to 'Brioe,Qtxmc'
# row: 251 col: 2 : 'Action,Adventure,Mecha' changed to 'Aftiov,Afvantkee,Kxzhx'
# row: 1308 col: 2 : 'Adventure,Drama,Fantasy,Horror,Shounen,Supernatural,Vampire' changed to 'Sgygntorz,Draoa,Xwitssj,Fjrtox,Svouneu,Wt'eghacurzl,Vxmoive'
# row: 734 col: 2 : 'Animation,Short,Action,Comedy,Sci-Fi' changed to 'Akjnzcion,Shkgt,Actiot,Cjmadi,Scm-Fo'
# row: 859 col: 2 : 'Animation' changed to 'Cniladimi'
# row: 513 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'Qjikcuoon,Qramq,Fantwah,Xwi-Fi'
# row: 574 col: 2 : 'Action,Sci-Fi' changed to 'Avhkon,Xcy-Fy'
# row: 127 col: 2 : 'Animation,Adventure,Comedy' changed to 'Dnnmatnon,Avnvthkrs,Cinedi'
# row: 651 col: 2 : 'Short' changed to 'Vvort'
# row: 1219 col: 2 : 'Animation' changed to 'Wnimation'
# row: 280 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi,Thriller' changed to 'Atpkxtiun,Qctukn,Xdrenrure,Suoesy,Acl-Fm,Ejglllee'
# row: 1275 col: 2 : 'Animation' changed to 'Snjmwgiom'
# row: 183 col: 2 : 'Comedy' changed to 'Cimaay'
# row: 253 col: 2 : 'Drama,Fantasy,Kids' changed to 'Drxke,Habcdvh,Kubs'
# row: 1104 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'Axriun,Abvvntbre,Nsbjary,Vmougai'
# row: 687 col: 2 : 'Drama,Romance' changed to 'Vdaoq,Clmancd'
# row: 1061 col: 2 : 'Short' changed to 'Sjosg'
# row: 685 col: 2 : 'Animation' changed to 'Xummayhmn'
# row: 1176 col: 2 : 'Comedy,SliceofLife' changed to 'Cokeey,XjprqmsLjre'
# row: 1205 col: 2 : 'Comedy' changed to 'Ciogbf'
# row: 194 col: 2 : 'Comedy,Parody,Romance' changed to 'Comrvy,Psriqy,Gumanzr'
# row: 833 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Cpmesy,Fannash,Jidv'
# row: 177 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Horror' changed to 'Wnymzcyjn,Actliv,Asvskthde,Cjmsey,Vrsma,Wantwsy,Joddpr'
# row: 1369 col: 2 : 'Animation,Short' changed to 'Wtimqgion,Skort'
# row: 543 col: 2 : 'Action,Adventure,Historical,Samurai,Seinen' changed to 'Sbrijn,Qdventucf,Mustorican,Semnrwi,Xspuen'
# row: 932 col: 2 : 'Comedy,Drama,Seinen' changed to 'Vomegf,Ctamd,Vxiien'
# row: 181 col: 2 : 'Adventure,Comedy,Historical,Kids' changed to 'Wgvxnguse,Suoefn,Hlscirlrxl,Hids'
# row: 278 col: 2 : 'Music,School,SliceofLife' changed to 'Mosud,Swhoou,FojvcoyLiwe'
# row: 1519 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Cnlmafpuu,Dkozbi,Scu-Vh'
# row: 1345 col: 2 : 'Drama,Romance,Yaoi' changed to 'Cewis,Romengw,Yapo'
# row: 249 col: 2 : 'Comedy,Sci-Fi' changed to 'Gjmsdu,Fci-Fo'
# row: 852 col: 2 : 'Music,Shoujo,Sports' changed to 'Oosid,Siomjk,Aports'
# row: 1507 col: 2 : 'Comedy,Parody' changed to 'Bumeqg,Pagovy'
# row: 1081 col: 2 : 'Drama' changed to 'Gxemx'
# row: 75 col: 2 : 'Animation,Adventure,Comedy' changed to 'Wnimegiib,Xcvwjjjrg,Comavy'
# row: 81 col: 2 : 'Animation,Action,Adventure,Sci-Fi,Thriller' changed to 'Wnimznikn,Actpin,Avrenflre,Rcy-Xp,Nhfiuler'
# row: 703 col: 2 : 'Animation,Action,Comedy,Drama,Romance' changed to 'Wtimatjon,Actiuu,Vumddf,Vrciw,Rimdnfe'
# row: 229 col: 2 : 'Animation,Action,Drama,Fantasy,History,Sci-Fi' changed to 'Anymaeiun,Axvlom,Bramw,Nwmtzdy,Kirgoxv,Svi-Fi'
# row: 222 col: 2 : 'Animation,Action,Romance,Sci-Fi' changed to 'Agjoeuoon,Cftlon,Xonzbzs,Wvu-Sl'
# row: 729 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Romance' changed to 'Qnjiatiom,Awtmon,Zomeby,Celke,Drqix,Tumakcf'
# row: 773 col: 2 : 'Comedy' changed to 'Dmmecy'
# row: 1587 col: 2 : 'Comedy,Horror' changed to 'Clntby,Hogdjr'
# row: 1389 col: 2 : 'Comedy' changed to 'Cuofdy'
# row: 1289 col: 2 : 'Hentai' changed to 'Henndi'
# row: 1240 col: 2 : 'Adventure,Sci-Fi' changed to 'Acestvure,Fcn-Fi'
# row: 1003 col: 2 : 'Comedy' changed to 'Vmmeqj'
# row: 947 col: 2 : 'Comedy,School,Shounen,Supernatural' changed to 'Xokeqr,Sbhpoj,Rhkunxb,Supegnwrutwl'
# row: 1127 col: 2 : 'Animation,Short' changed to 'Suikxumpu,Shkgf'
# row: 562 col: 2 : 'Horror,Shounen' changed to 'Kmerpg,Shomhsn'
# row: 40 col: 2 : 'Adventure,Comedy,Kids' changed to 'Aebqngiee,Vkmqqi,Npdd'
# row: 1297 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Atimxjjou,Cojevy,Scj-Vi'
# row: 315 col: 2 : 'Action,Romance' changed to 'Action,Tomanxz'
# row: 1194 col: 2 : 'Historical,Kids' changed to 'Histotyral,Kifr'
# row: 503 col: 2 : 'Reality-TV' changed to 'Ddwnitj-EN'
# row: 20 col: 2 : 'Drama,Family' changed to 'Drsma,Hclmpy'
# row: 982 col: 2 : 'Comedy' changed to 'Cojebv'
# row: 650 col: 2 : 'Comedy' changed to 'Cojdft'
# row: 1465 col: 2 : 'Animation,Adventure,Family' changed to 'Xnimxtijm,Dereudure,Faoyny'
# row: 1557 col: 2 : 'Animation,Drama,Sci-Fi' changed to 'Auimanion,Drzma,Fci-Fy'
# row: 1454 col: 2 : 'Fantasy,Magic' changed to 'Waktqsy,Macic'
# row: 273 col: 2 : 'Animation,Romance' changed to 'Enikwfiim,Romakfe'
# row: 812 col: 2 : 'Comedy,Reality-TV' changed to 'Bkjcdr,Gsxlktv-TV'
# row: 936 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Cbvekture,Saggcfg,Nudd'
# row: 662 col: 2 : 'Animation,Short,Horror' changed to 'Sninatluv,Whodu,Hoxcle'
# row: 814 col: 2 : 'Animation,Comedy' changed to 'Anijaepok,Wjovev'
# row: 1046 col: 2 : 'Hentai' changed to 'Ixntai'
# row: 1348 col: 2 : 'Fantasy,Kids' changed to 'Fqktssy,Hiqv'
# row: 1004 col: 2 : 'Horror,Sci-Fi' changed to 'Yotrpe,Swi-Wl'
# row: 432 col: 2 : 'Drama,Sci-Fi,War' changed to 'Dtana,Sci-Yi,War'
# row: 864 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'Zctimk,Cimevb,Nwrei,Sry-Vo,Shouuvk,Skwgd'
# row: 1067 col: 2 : 'Documentary,Short' changed to 'Vovomejgerj,Svorc'
# row: 1186 col: 2 : 'Action,Crime,Drama,Sci-Fi' changed to 'Actmog,Zcimw,Fxaow,Rgy-Fn'
# row: 73 col: 2 : 'Comedy' changed to 'Rokedr'
# row: 69 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy' changed to 'Anymduiob,Dsnrntkre,Bxana,Famipy,Fahtwsu'
# row: 724 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Xjimatloi,Rimfgy,Ssu-Fi'
# row: 256 col: 2 : 'Animation,Fantasy' changed to 'Cnikwruon,Dajtqsy'
# row: 1147 col: 2 : 'Action' changed to 'Actypn'
# row: 328 col: 2 : 'Action,Horror,Animation,Sci-Fi,Thriller' changed to 'Zcuion,Hkxxkr,Atimatiin,Rei-Hk,Tkgiplec'
# row: 960 col: 2 : 'Drama,Historical,Music,Romance' changed to 'Aseka,Huvboricap,Mbaid,Dokagde'
# row: 424 col: 2 : 'Animation,Comedy' changed to 'Wjkmsjimm,Rimqcy'
# row: 1427 col: 2 : 'Adventure,Kids' changed to 'Aqvebblre,Juca'
# row: 1152 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'Zbrxjngrw,Xlifft,Mjxjety,Pujhce,Xhoimev'
# row: 848 col: 2 : 'Short' changed to 'Aiort'
# row: 66 col: 2 : 'Comedy,Fantasy,Kids,Supernatural,Vampire' changed to 'Cikeby,Ganjafy,Kpdx,Suiegnwuiran,Dao[krt'
# row: 190 col: 2 : 'Animation' changed to 'Emyjsfiom'
# row: 505 col: 2 : 'Adventure,Fantasy,Historical' changed to 'Advrmtire,Fqntxfr,Hhaejfical'
# row: 1325 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Ehjlahipu,Dgventixt,Neiilu,Xwttswj'
# row: 5 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'Wnimaeiik,Wykgy,Adtoih,Asdemfbrt,Xanvawy'
# row: 568 col: 2 : 'Comedy,Crime' changed to 'Ckkfey,Dgike'
# row: 706 col: 2 : 'Hentai' changed to 'Hebvai'
# row: 1478 col: 2 : 'Animation,Adventure,Comedy,Family,Fantasy,Sci-Fi' changed to 'Aiijaglog,Adxenrure,Woirdy,Xqknuy,Wenraaj,Xcl-Fi'
# row: 86 col: 2 : 'Historical' changed to 'Yixtocizwl'
# row: 918 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Animqrmon,Bomefy,Fchuasy,Romekfw'
# row: 1468 col: 2 : 'Adventure,Drama,Fantasy' changed to 'Adxtmtuet,Gtzoc,Yavtasi'
# row: 429 col: 2 : 'Cars' changed to 'Cdrs'
# row: 938 col: 2 : 'Animation,Music' changed to 'Qnimetpou,Llvic'
# row: 304 col: 2 : 'Action,Sports' changed to 'Avnjln,Riocts'
# row: 1239 col: 2 : 'Action,Animation,Sci-Fi' changed to 'Azcljk,Avikdthon,Sbi-Hi'
# row: 195 col: 2 : 'Comedy,Drama' changed to 'Bmieeh,Gramz'
# row: 867 col: 2 : 'Hentai' changed to 'Hdntah'
# row: 442 col: 2 : 'Action,Music' changed to 'Wzyiiu,Music'
# row: 956 col: 2 : 'Hentai' changed to 'Hebtsi'
# row: 364 col: 2 : 'Music' changed to 'Muvnx'
# row: 935 col: 2 : 'Comedy,Drama,Fantasy,Music' changed to 'Ckkfdf,Bgala,Gditasu,Muxhd'
# row: 714 col: 2 : 'Drama' changed to 'Ewamw'
# row: 611 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Dbxentuxa,Cmmedy,Wcntafn'
# row: 322 col: 2 : 'Animation,Action,Adventure,Comedy,Crime' changed to 'Ahkmayuln,Scuion,Cddtmnire,Somgdu,Frilc'
# row: 373 col: 2 : 'SliceofLife' changed to 'DlncemrPixe'
# row: 874 col: 2 : 'Action,Comedy,Ecchi,Fantasy,Harem,Magic,Romance' changed to 'Agtoot,Cmmxqf,Ecbhk,Fxnhzsi,Marfo,Mafiw,Cmmanre'
# row: 1375 col: 2 : 'Comedy' changed to 'Dpkadj'
# row: 1452 col: 2 : 'Drama' changed to 'Dseia'
# row: 1155 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'Advcjdurw,Clkesy,Kiwtwgy,'pmnce,Skpjndn'
# row: 297 col: 2 : 'Drama' changed to 'Vrdia'
# row: 1276 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family' changed to 'Zvymanmki,Actioi,Wavevyute,Cljeqy,Sszks,Fwmlly'
# row: 648 col: 2 : 'Animation,Sci-Fi' changed to 'Shhnwgipm,Sdl-Fi'
# row: 1175 col: 2 : 'Action,Adventure,Mecha,Sci-Fi,Space' changed to 'Aculpu,Cvvqnturt,Mtwha,Xci-Fk,S'aeg'
# row: 535 col: 2 : 'Action,Adventure,Game,Mecha,Sci-Fi,Shounen' changed to 'Artimn,Aavavture,Cdje,Mrrvw,Fcj-Di,Dhountg'
# row: 733 col: 2 : 'Animation,Sci-Fi,War' changed to 'Wnimqviui,Scj-Wy,Rcr'
# row: 141 col: 2 : 'Animation,Comedy,Drama' changed to 'Dnumedion,Volwcg,Drama'
# row: 311 col: 2 : 'Hentai' changed to 'Heifaj'
# row: 1073 col: 2 : 'Action,Comedy,Fantasy,Shounen,SuperPower' changed to 'Agflkn,Vomcdy,Vagtasr,Djobkan,DiozrIortt'
# row: 580 col: 2 : 'Sport' changed to 'Dimre'
# row: 554 col: 2 : 'Comedy' changed to 'Cooedy'
# row: 751 col: 2 : 'Hentai' changed to 'Fettam'
# row: 945 col: 2 : 'Action,Drama,MartialArts,Shounen,SuperPower' changed to 'Awejpb,Qfams,IaxtmdlErvs,Rmojnen,SkkvrPoqed'
# row: 779 col: 2 : 'Animation,Comedy,Romance,Sci-Fi' changed to 'Dvlmagion,Gumzdn,Dumancv,Scn-Fy'
# row: 745 col: 2 : 'Adventure,Shounen' changed to 'Cdtentjvz,Sjuljen'
# row: 800 col: 2 : 'Comedy,Mystery' changed to 'Rukvdi,Lnshrry'
# row: 149 col: 2 : 'Comedy,Ecchi,Horror,Romance,Shounen,Supernatural' changed to 'Dmkedy,Ecfhi,Mjsdor,Romwnfe,Ahjukek,Dupednddursp'
# row: 480 col: 2 : 'Action,Adventure,Sci-Fi,Sport' changed to 'Cwdion,Qvveicute,Vri-Ni,Rpjgn'
# row: 1318 col: 2 : 'Comedy,Police' changed to 'Vojwcy,Pulyze'
# row: 52 col: 2 : 'Action,Drama,Fantasy,Shounen,SuperPower' changed to 'Qznipn,Drama,Fakdcfb,Shunvcn,Anpvr'iqgt'
# row: 1578 col: 2 : 'Drama' changed to 'Draiw'
# row: 879 col: 2 : 'Short' changed to 'Sjlrr'
# row: 548 col: 2 : 'Animation,Action,Fantasy,Sci-Fi' changed to 'Dbilxgiig,Zbyioh,Rctbady,Swi-Gi'
# row: 910 col: 2 : 'Kids,Supernatural' changed to 'Khax,Dkpwrbeturau'
# row: 892 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'Cnijetlin,Ddame,Fzvgasb,Sbk-Fi'
# row: 1184 col: 2 : 'Action,MartialArts' changed to 'Dftmjm,MartkalAxtx'
# row: 742 col: 2 : 'Comedy' changed to 'Wkkeqy'
# row: 354 col: 2 : 'Action,Mecha,Military,Police,Sci-Fi' changed to 'Ecnkoi,Mezka,Mijibady,[omicc,Abl-Wi'
# row: 200 col: 2 : 'Animation,Short,Action' changed to 'Agjodeuon,Sgkrt,Qcgioj'
# row: 1156 col: 2 : 'Action,Historical,Military,SuperPower' changed to 'Wfdnpn,Risymtigwu,Iinldary,SlpztPoxwr'
# row: 1092 col: 2 : 'Drama,Romance' changed to 'Crwje,Somagwq'
# row: 920 col: 2 : 'Comedy,Drama,SliceofLife,Supernatural' changed to 'Sokesy,Drana,FlnbfoyLofx,Shpqxgatuxsn'
# row: 862 col: 2 : 'Animation,Drama,Sci-Fi' changed to 'Ehymaejok,Seamd,Sci-Hi'
# row: 3 col: 2 : 'Hentai' changed to 'Fxntai'
# row: 1048 col: 2 : 'Comedy' changed to 'Cpmvdj'
# row: 173 col: 2 : 'Animation,Adventure,Fantasy' changed to 'Anikatooi,Aavrnborv,Fqmtesy'
# row: 1143 col: 2 : 'Adventure,Crime,Drama,History,Mystery,Thriller' changed to 'Adveunbcq,Cwkma,Vsaiq,Jistoxy,Lhrnegy,Gieillrr'
# row: 1189 col: 2 : 'SliceofLife,Space' changed to 'RoicemfOide,Soace'
# row: 1493 col: 2 : 'Drama,SliceofLife' changed to 'Exwma,WlndxifLjft'
# row: 1509 col: 2 : 'Action,Sci-Fi,Thriller' changed to 'Aetljn,Fco-Fl,Yigilltx'
# row: 897 col: 2 : 'Short,Animation' changed to 'Vhprt,Ajunatpmn'
# row: 1521 col: 2 : 'Crime' changed to 'Evuif'
# row: 1347 col: 2 : 'Animation,Adventure' changed to 'Amkoatimn,Qgxcvvute'
# row: 399 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,Romance,Thriller' changed to 'Znyjetiom,Avciin,Dvvrjrurz,Sokedj,Dtajc,Yxhtadi,Hidtjvu,Roksgeq,Gheiller'
# row: 1362 col: 2 : 'Action,Comedy,Ecchi,Harem,Magic,Supernatural' changed to 'Zction,Cjmect,Vxcgi,Nassm,Icbiw,Vjpcrvavurxm'
# row: 351 col: 2 : 'Animation,Family,Adventure,Comedy,Drama,Musical,Fantasy' changed to 'Enimadmom,Dakiln,Asbcnekrw,Clmrsr,Ardmw,Misjcap,Gwntesj'
# row: 1126 col: 2 : 'Short' changed to 'Sroeb'
# row: 385 col: 2 : 'Animation,Short' changed to 'Wnilctlpk,Shugb'
# row: 804 col: 2 : 'Animation,Short' changed to 'Snimehion,Dmort'
# row: 2 col: 2 : 'Animation' changed to 'Wnjoatikn'
# row: 1100 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Wgfkok,Wgvemcure,Coosdj,Svounen'
# row: 487 col: 2 : 'Kids,Music' changed to 'Nycs,Musyd'
# row: 1164 col: 2 : 'Short,Action' changed to 'Srocf,Acdkok'
# row: 324 col: 2 : 'Drama,Kids' changed to 'Fgxks,Kidv'
# row: 1225 col: 2 : 'Comedy,Fantasy,Shoujo' changed to 'Sojtdy,Fakuzaf,Shjujo'
# row: 405 col: 2 : 'Hentai' changed to 'Heicai'
# row: 1286 col: 2 : 'Ecchi,Music' changed to 'Evdfy,Mbslg'
# row: 36 col: 2 : 'Hentai' changed to 'Hentwo'
# row: 1544 col: 2 : 'Fantasy' changed to 'Fantafy'
# row: 808 col: 2 : 'Animation,Horror,Music,Thriller' changed to 'Avilajiln,Furskr,Khslc,Dhrullet'
# row: 264 col: 2 : 'Kids,Music' changed to 'Kjds,Oispg'
# row: 147 col: 2 : 'Hentai' changed to 'Ktntwp'
# row: 666 col: 2 : 'Action,Mystery,Supernatural' changed to 'Aftiiv,Mrstwsj,Solafhafndqm'
# row: 1217 col: 2 : 'Action,Adventure,Comedy,Fantasy,Magic,Shounen' changed to 'Wcnkok,Aavettlrd,Goledj,Fzmhssy,Lznix,Shotien'
# row: 1124 col: 2 : 'Adventure,Drama,Mecha,Sci-Fi,Shounen,Space' changed to 'Afvenvuwe,Aremd,Mevha,Seo-Fi,Dvmmteh,Spsce'
# row: 1377 col: 2 : 'Animation,Adventure,Comedy,Romance' changed to 'Xhlmatuon,Aqbsneuwe,Gmmedy,Rumance'
# row: 24 col: 2 : 'Animation' changed to 'Dnlianiot'
# row: 488 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Ankjanuon,Dlogvy,Ddaid,Rokqiwe'
# row: 911 col: 2 : 'Comedy' changed to 'Cmiadr'
# row: 1271 col: 2 : 'Drama' changed to 'Erams'
# row: 246 col: 2 : 'Action,Military,Romance' changed to 'Dxgjmb,Oyoitqrv,Rijenwe'
# row: 1408 col: 2 : 'Comedy,Mecha' changed to 'Cjkevy,Mexne'
# row: 718 col: 2 : 'Comedy' changed to 'Fkjedf'
# row: 417 col: 2 : 'Animation,Action,Horror,Mystery,Sci-Fi' changed to 'Cnonwtnoh,Aztimv,Horxpw,Oyshxrv,Fgl-Fu'
# row: 721 col: 2 : 'Animation' changed to 'Agikadiim'
# row: 1180 col: 2 : 'Fantasy,Kids,Magic,Romance,Shoujo,SuperPower' changed to 'Wwgtawj,Kids,Manic,Dlmzncq,Xhoubo,WtlgrKoxrt'
# row: 1044 col: 2 : 'Action,Mystery,Romance,Supernatural,Thriller' changed to 'Ceclig,Luscesj,Comqjxe,Auprrjatyxqn,Fhwinjet'
# row: 599 col: 2 : 'Animation' changed to 'Dgikatjuj'
# row: 1335 col: 2 : 'Drama,Shoujo,Sports' changed to 'Dgand,Shjhbo,Sioryv'
# row: 1471 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Horror' changed to 'Amimariok,Arhlov,Astejbure,Comrqv,Fautaav,Focroc'
# row: 749 col: 2 : 'Kids,Shoujo,Supernatural' changed to 'Koes,Ahobjm,Fupgsistorzl'
# row: 1366 col: 2 : 'Adventure,Comedy,Drama,Mystery,Sci-Fi' changed to 'Cdvejgugz,Eomesu,Dscmw,Mysyfsy,Sci-Xo'
# row: 747 col: 2 : 'Action,Sci-Fi,Space,SuperPower' changed to 'Wdtiog,Xxl-Wi,Rlacc,SykrtOoqet'
# row: 1010 col: 2 : 'Comedy,Drama,Horror,Mystery' changed to 'Coltdy,Crama,Juttlr,Jhsterf'
# row: 840 col: 2 : 'Comedy' changed to 'Ckmedy'
# row: 275 col: 2 : 'Drama' changed to 'Becna'
# row: 673 col: 2 : 'Short,Drama,Thriller' changed to 'Smird,Dcxma,Tjrluoxr'
# row: 514 col: 2 : 'Adventure,Comedy,Fantasy,Magic' changed to 'Acvehuure,Cjmvbi,Fckdcav,Kdgic'
# row: 675 col: 2 : 'Adventure,Sci-Fi,Shounen,Sports' changed to 'Zbvenuure,Sci-Yo,Xvotnek,Aiircs'
# row: 1243 col: 2 : 'Comedy,Drama,Romance' changed to 'Colxdj,Acaja,Fojamcf'
# row: 1058 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family,Fantasy,Sci-Fi,Thriller' changed to 'Culmstmok,Actijg,Adxtnthwe,Ciosgy,Cdaow,Dxkiky,Fantzdt,Sxi-Yl,Uhviller'
# row: 126 col: 2 : 'SliceofLife' changed to 'SklcduwLive'
# row: 1140 col: 2 : 'Action,Mecha,Sci-Fi,Space' changed to 'Scviob,Ierya,Sci-Nn,Flace'
# row: 447 col: 2 : 'Sci-Fi' changed to 'Sci-Fn'
# row: 53 col: 2 : 'Comedy,Seinen,Space' changed to 'Vomedi,Feitqb,Slaev'
# row: 1234 col: 2 : 'Magic' changed to 'Iagir'
# row: 285 col: 2 : 'Hentai' changed to 'Hdgewi'
# row: 112 col: 2 : 'Hentai' changed to 'Hettek'
# row: 483 col: 2 : 'Animation,Comedy' changed to 'Eijmecipn,Wljedj'
# row: 715 col: 2 : 'Comedy,Romance,School,Shoujo,SliceofLife' changed to 'Cumdsb,Gomavcv,Dsfomj,Dhonbj,DopccmfJiye'
# row: 317 col: 2 : 'Animation' changed to 'Snnoaulon'
# row: 1448 col: 2 : 'Game-Show,Reality-TV' changed to 'Ccov-Shjw,Vewpmcy-FT'
# row: 1268 col: 2 : 'Drama' changed to 'Dvamw'
# row: 1170 col: 2 : 'Animation,Short' changed to 'Dhioaeiln,Ahotd'
# row: 1438 col: 2 : 'Action,Sci-Fi' changed to 'Xbjuon,Sci-Gl'
# row: 1069 col: 2 : 'Comedy,Police' changed to 'Comecy,Pmnmrq'
# row: 98 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Wbiichlon,Xseion,Qdyrntufx,Somcsu,Fatdxwh'
# row: 525 col: 2 : 'Animation,Short,Horror' changed to 'Dinmdhnuj,Shogt,Horxof'
# row: 153 col: 2 : 'Hentai' changed to 'Jtgtwi'
# row: 858 col: 2 : 'Ecchi,Seinen' changed to 'Eccii,Ssinen'
# row: 1357 col: 2 : 'Comedy,Parody' changed to 'Sokfsy,Parovy'
# row: 168 col: 2 : 'Documentary,Biography,History,News' changed to 'Cocuoegndrj,Fkmega[hy,Iiabjer,Tedr'
# row: 302 col: 2 : 'Thriller' changed to 'Rhriulvg'
# row: 823 col: 2 : 'Animation,Comedy,Romance' changed to 'Zjmldtkog,Fimeay,Somcbwe'
# row: 1095 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Aftnon,Adxwntugs,Sumavy,Srounwn'
# row: 1380 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Qmnjqgiom,Conegy,Drdma,Domenxe'
# row: 1429 col: 2 : 'Comedy,Military' changed to 'Wumeey,Mlnivqxy'
# row: 462 col: 2 : 'Animation,Comedy,Drama' changed to 'Qunkavjob,Wlmret,Cwana'
# row: 792 col: 2 : 'Hentai' changed to 'Jcnteu'
# row: 1311 col: 2 : 'Kids,SliceofLife' changed to 'Nlef,SplccjfNhfx'
# row: 105 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Aceantbce,Bokecy,Ywntdfy,Hmfs'
# row: 1072 col: 2 : 'Game,Shounen' changed to 'Heme,Afouggn'
# row: 815 col: 2 : 'Music' changed to 'Misic'
# row: 213 col: 2 : 'Shounen,Sports' changed to 'Shibhev,A'lrts'
# row: 1501 col: 2 : 'Drama,Seinen,SliceofLife' changed to 'Dveka,Waiiqn,AligvkgLnhg'
# row: 744 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Cnmkaymin,Adecntnre,Failnn,Xamcwav'
# row: 1344 col: 2 : 'Animation,Action,Adventure,Crime' changed to 'Anjmchiin,Actlon,Qdxwkturg,Ctlmc'
# row: 286 col: 2 : 'Historical' changed to 'Nistogprsm'
# row: 1441 col: 2 : 'Animation,Drama,Fantasy,Mystery' changed to 'Aimnabuon,Grwow,Genhasy,Jhatzrj'
# row: 450 col: 2 : 'Music' changed to 'Musig'
# row: 754 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Horror,Thriller' changed to 'Djimdtkut,Abfhon,Cbveneucg,Cpmefi,Drcna,Hwnjzsn,Hidrpt,Ugrhkosv'
# row: 571 col: 2 : 'Comedy,Music,Shoujo' changed to 'Cpmedi,Ouwps,Xmogno'
# row: 1277 col: 2 : 'Drama,Music,Romance' changed to 'Grcke,Mysnc,Rlnxgce'
# row: 1301 col: 2 : 'Comedy,Drama,Romance' changed to 'Cojcdy,Dtwka,Xomancv'
# row: 1343 col: 2 : 'Comedy,Ecchi,Romance,Sci-Fi' changed to 'Xomacb,Excki,Romegwe,Feh-Fo'
# row: 269 col: 2 : 'Comedy,Josei,Romance,SliceofLife' changed to 'Comccy,Jofxi,Gumauct,SolddixOixe'
# row: 1567 col: 2 : 'Drama,Thriller' changed to 'Grqla,Tkdipjgd'
# row: 1098 col: 2 : 'Animation,Family' changed to 'Ankmqhpkv,Fwlilj'
# row: 533 col: 2 : 'Comedy' changed to 'Cpnxvj'
# row: 500 col: 2 : 'Action,Adventure,Fantasy' changed to 'Wcumun,Aqbeudtxe,Gcivsst'
# row: 1138 col: 2 : 'Animation,Drama,Romance,Sci-Fi' changed to 'Cbimetkjh,Dgalx,Wlmancf,Aci-Fi'
# row: 1436 col: 2 : 'Action,Drama,Shounen' changed to 'Acyiom,Draia,Wmomnan'
# row: 737 col: 2 : 'Horror,Mystery,Thriller' changed to 'Ykrgpr,Mfxgexf,Vfrillef'
# row: 1513 col: 2 : 'Documentary,Mystery,News,Sci-Fi' changed to 'Alcjneurafv,Mustexn,Nerd,Sfi-Du'
# row: 157 col: 2 : 'Animation,Short,Music' changed to 'Snmmsfikg,Sioxt,Mndis'
# row: 171 col: 2 : 'Animation,Short,Family' changed to 'Anijwtion,Djmrt,Haliny'
# row: 365 col: 2 : 'Hentai' changed to 'Rcntql'
# row: 585 col: 2 : 'Comedy' changed to 'Dmkedf'
# row: 478 col: 2 : 'Action' changed to 'Qetkot'
# row: 976 col: 2 : 'Animation,Adventure,Family,Fantasy,Musical,Romance' changed to 'Diimation,Addvntuew,Ndnoki,Dakdaxy,Jusnwdk,Eojanct'
# row: 422 col: 2 : 'Documentary,Comedy,History,War' changed to 'Gpcoktntscy,Fomedy,Hnstuty,Wag'
# row: 697 col: 2 : 'Drama,Family,Romance' changed to 'Grwja,Haolmy,Rpmance'
# row: 919 col: 2 : 'Drama' changed to 'Ddemd'
# row: 266 col: 2 : 'Animation' changed to 'Aninabpkm'
# row: 179 col: 2 : 'Animation' changed to 'Ajklatijm'
# row: 886 col: 2 : 'Fantasy' changed to 'Hdjbaaj'
# row: 1393 col: 2 : 'Drama' changed to 'Brwmz'
# row: 756 col: 2 : 'Drama,Historical,Sports' changed to 'Dfska,Hisbirlsal,Slpetx'
# row: 1571 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'Zvpoackpn,Sctlki,Abvvntugv,Eimqgy,Wxl-Gi'
# row: 643 col: 2 : 'Action' changed to 'Qftuon'
# row: 1534 col: 2 : 'Historical' changed to 'Yixtpricao'
# row: 799 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Zbiictyoh,Agtuon,Sdfenjnve,Foieqf,Faudash'
# row: 314 col: 2 : 'Kids,Music' changed to 'Kkds,Nuxir'
# row: 660 col: 2 : 'Animation,Drama,Romance' changed to 'Avlmxtoln,Dcama,Womancg'
# row: 772 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Anhiqtimn,Volqdr,Nzhgqsj'
# row: 679 col: 2 : 'Comedy,Police' changed to 'Dmmeav,Kunice'
# row: 1040 col: 2 : 'Adventure,Drama,History,Romance' changed to 'Agvrntkvq,Grama,Iixtmcy,Dkmahcg'
# row: 390 col: 2 : 'Animation,Adventure,Fantasy' changed to 'Anhmwjukn,Adfxbfure,Wanydsr'
# row: 164 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Xghmdtkin,Dcuiun,Wdvwjugre,Fsntwsb'
# row: 516 col: 2 : 'Hentai,Yuri' changed to 'Fggtxh,Yuxi'
# row: 657 col: 2 : 'Adventure,Comedy,Horror,Shounen,Supernatural' changed to 'Ddtemnurw,Smmeby,Fmrrot,Shkyiem,Fk[eskafural'
# row: 502 col: 2 : 'Animation,Action,Crime,Mystery' changed to 'Eknoagion,Abglon,Zruie,Lyfverv'
# row: 240 col: 2 : 'Animation,Drama' changed to 'Dnpictikh,Axama'
# row: 231 col: 2 : 'Hentai' changed to 'Hendxi'
# row: 1574 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Eniksguin,Zonedy,Brakd,Fanfwrt,Gjmxjcr'
# row: 428 col: 2 : 'Adventure,Comedy,Fantasy,Shoujo' changed to 'Wgdekture,Xlkgdy,Fcgtdry,Shjytp'
# row: 1577 col: 2 : 'Adventure,Sci-Fi' changed to 'Zgvrntore,Sbi-Fi'
# row: 955 col: 2 : 'Animation,Short' changed to 'Atllqcilm,Shofu'
# row: 205 col: 2 : 'Drama,Supernatural,Thriller' changed to 'Crwkw,Slpgrncebral,Thwollrr'
# row: 1391 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Mystery' changed to 'Snimwrimj,Actiok,Avvebtudc,Ctaks,Fxntawy,Mystexy'
# row: 1306 col: 2 : 'Animation,Action,Comedy' changed to 'Annmctpoi,Wchilu,Comqdn'
# row: 797 col: 2 : 'Adventure,Sci-Fi' changed to 'Xdvangkee,Axi-Fi'
# row: 180 col: 2 : 'Drama' changed to 'Srwna'
# row: 1005 col: 2 : 'Action,Comedy,Horror' changed to 'Wvjlov,Rokeey,Kkxrkv'
# row: 1265 col: 2 : 'Adventure,Comedy' changed to 'Advvkvute,Comebi'
# row: 507 col: 2 : 'Comedy' changed to 'Ckkedj'
# row: 632 col: 2 : 'Comedy,Kids,SliceofLife' changed to 'Fijedu,Nids,SmiceofUlyv'
# row: 371 col: 2 : 'Animation,Comedy,Drama,Music' changed to 'Agimxullm,Cooedy,Dtaja,Nldiw'
# row: 410 col: 2 : 'Animation,Action,Drama,Fantasy' changed to 'Snomatymn,Qcgion,Agwmc,Fanjwrb'
# row: 461 col: 2 : 'Talk-Show' changed to 'Twlk-Srkq'
# row: 717 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Mystery,Romance' changed to 'Animeuyok,Avreuvucw,Arama,Faijly,Hwntawj,Iyfffdy,Eoksmcw'
# row: 1543 col: 2 : 'Animation,Short' changed to 'Anomstijm,Xhort'
# row: 394 col: 2 : 'Comedy,Kids,Shounen,Space' changed to 'Clmecy,Kibv,Xkognet,Soxze'
# row: 233 col: 2 : 'Animation,Short,Comedy' changed to 'Amlmavjog,Dhosu,Comqdy'
# row: 1023 col: 2 : 'Drama,Kids' changed to 'Dvdiw,Knds'
# row: 196 col: 2 : 'Animation,Drama' changed to 'Ctjjsjppu,Breod'
# row: 997 col: 2 : 'Mystery,Police,Supernatural' changed to 'Justesy,Pollee,Xl[wriwvkfdo'
# row: 1305 col: 2 : 'Animation,Short' changed to 'Atpnztion,Shott'
# row: 712 col: 2 : 'Drama' changed to 'Fdcla'
# row: 575 col: 2 : 'Animation,Drama,Thriller' changed to 'Ajimdymon,Agaja,Yhrillev'
# row: 35 col: 2 : 'Drama' changed to 'Qraia'
# row: 617 col: 2 : 'Hentai' changed to 'Ventak'
# row: 555 col: 2 : 'Action,Fantasy,Shounen,Supernatural' changed to 'Acgoot,Fandasy,Shjbnej,Xupetnwturam'
# row: 1248 col: 2 : 'Action,Comedy,Dementia,Ecchi,Parody,Supernatural' changed to 'Axtnon,Cujwdj,Ddnrvtix,Ewchk,Kztovy,Ahoerhqturdk'
# row: 14 col: 2 : 'Comedy,Kids,Romance' changed to 'Gomtdy,Josf,Smmavbv'
# row: 966 col: 2 : 'Comedy' changed to 'Comaqy'
# row: 761 col: 2 : 'Action,MartialArts,Mecha,SuperPower' changed to 'Wwtimn,MzrtjclQrgs,Jegkd,Do[erPoxef'
# row: 1432 col: 2 : 'Animation,Comedy' changed to 'Wbkisjuou,Bomecy'
# row: 511 col: 2 : 'Talk-Show' changed to 'Fwln-Xnor'
# row: 649 col: 2 : 'Romance' changed to 'Romemge'
# row: 1173 col: 2 : 'Hentai' changed to 'Hgmtai'
# row: 591 col: 2 : 'Animation,Adventure' changed to 'Shmmqyion,Agvtitkrq'
# row: 818 col: 2 : 'Animation,Comedy' changed to 'Zknmqtiin,Djmedy'
# row: 1177 col: 2 : 'Demons,Fantasy,Hentai,Supernatural' changed to 'Gdmpns,Hwmgafg,Ientam,Auirvnsbugal'
# row: 1500 col: 2 : 'Adventure,Kids' changed to 'Avyzngjtf,Nods'
# row: 614 col: 2 : 'Animation' changed to 'Cbkmztjon'
# row: 1503 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Sci-Fi' changed to 'Anikaeljn,Zvvenuuvt,Aewja,Faklly,Gcvtcsy,Sdi-Fu'
# row: 1415 col: 2 : 'Animation,Drama,Romance' changed to 'Anmmaeuob,Dgwoa,Fomxubs'
# row: 770 col: 2 : 'Short,Drama,Horror,Mystery,Thriller' changed to 'Dhorb,Vcakw,Howxoc,Kvateri,Bgrinlev'
# row: 1546 col: 2 : 'Fantasy' changed to 'Faiessy'
# row: 539 col: 2 : 'Adventure,Mecha,Sci-Fi' changed to 'Wdvdnture,Mecna,Fci-Fk'
# row: 802 col: 2 : 'Animation,Action,Adventure,Fantasy,Horror' changed to 'Chykayioj,Awtium,Zdgemdowe,Fwutavr,Horsjr'
# row: 1588 col: 2 : 'Action,Comedy,Ecchi,Shounen,Sports' changed to 'Wfuion,Zljvdy,Eccnu,Syonnet,Voortw'
# row: 1563 col: 2 : 'Documentary,Short' changed to 'Qocultnuatf,Shmct'
# row: 954 col: 2 : 'Comedy,Magic' changed to 'Fomedy,Mabic'
# row: 124 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Anyowvnoi,Wefnig,Vvskq,Sdi-Wi'
# row: 530 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Atimduiov,Zcthph,Xcvenrice,Ckleau,Gegvwwt'
# row: 846 col: 2 : 'Comedy' changed to 'Cjmwdf'
# row: 146 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Agukwtion,Axviig,Adtrnetrv,Xomsvf,Fabtwfy'
# row: 835 col: 2 : 'Action,Mecha,Military,Sci-Fi' changed to 'Acfioi,Mecha,Muukgwru,Sck-Fm'
# row: 987 col: 2 : 'Fantasy' changed to 'Rantqst'
# row: 1068 col: 2 : 'Animation,Action,Fantasy' changed to 'Atiksvikt,Aftyoj,Fqktasi'
# row: 404 col: 2 : 'Action' changed to 'Xcvion'
# row: 1580 col: 2 : 'Drama' changed to 'Drama'
# row: 345 col: 2 : 'Animation,Drama,Sport' changed to 'Dkmmejuun,Crdix,F[orb'
# row: 578 col: 2 : 'Animation' changed to 'Znilaflog'
# row: 156 col: 2 : 'News' changed to 'Krww'
# row: 100 col: 2 : 'Adventure,Drama,Shoujo' changed to 'Advantbrc,Dgcoa,Shjhjo'
# row: 1266 col: 2 : 'Animation,Action,Fantasy' changed to 'Wiimauijg,Zcbmji,Rattasi'
# row: 41 col: 2 : 'Animation,Short' changed to 'Siujatikn,Sijtt'
# row: 825 col: 2 : 'Animation,Adventure,Family,Sci-Fi' changed to 'Xnilaepmn,Cdyxnjmce,Fxmjly,Fei-Sk'
# row: 725 col: 2 : 'Kids' changed to 'Kifs'
# row: 1584 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Anlkatmon,Cctiou,Scp-Rh'
# row: 433 col: 2 : 'Fantasy,Kids' changed to 'Fandefj,Knar'
# row: 331 col: 2 : 'Comedy,Sci-Fi' changed to 'Bkmedf,Vco-Fl'
# row: 766 col: 2 : 'Comedy,Kids,Music' changed to 'Zlmadt,Nlcf,Mufpc'
# row: 39 col: 2 : 'Animation,Comedy,Drama' changed to 'Atnkzhhjj,Cimtai,Ardmd'
# row: 619 col: 2 : 'Drama,Mystery' changed to 'Braia,Kjsjery'
# row: 1394 col: 2 : 'Sci-Fi' changed to 'Wbk-Xo'
# row: 1259 col: 2 : 'Drama' changed to 'Crakx'
# row: 56 col: 2 : 'Animation,Short,Action,Adventure,Drama,Fantasy,Sci-Fi' changed to 'Animzfmon,Xhirt,Wcbijj,Zdvtntoeg,Desms,Fwntasu,Xdl-Xy'
# row: 942 col: 2 : 'Historical' changed to 'Hidyognfal'
# row: 557 col: 2 : 'Action,Comedy,Ecchi,Romance,Sci-Fi' changed to 'Acnipi,Cjmedt,Zwchi,Vuianvd,Rci-Fj'
# row: 1425 col: 2 : 'Animation' changed to 'Anmkshlpn'
# row: 263 col: 2 : 'Hentai' changed to 'Hwnfai'
# row: 701 col: 2 : 'Animation,Short' changed to 'Qnkoqdyon,Xvocc'
# row: 868 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Animctioi,Edvennuvg,Vamimi,Fajgesu'
# row: 63 col: 2 : 'Animation,Action,Fantasy' changed to 'Qnukqtlun,Actiot,Fwuuwdy'
# row: 975 col: 2 : 'Comedy' changed to 'Cokgbt'
# row: 1228 col: 2 : 'Drama,Harem,Music,Romance' changed to 'Vraoa,Mqrem,Mufid,Rokahce'
# row: 1296 col: 2 : 'Comedy,Samurai,School' changed to 'Conedn,Szkugai,Sxhoon'
# row: 260 col: 2 : 'Drama,Kids' changed to 'Vwamw,Klds'
# row: 809 col: 2 : 'Action,Sci-Fi' changed to 'Abvipn,Sxp-Si'
# row: 281 col: 2 : 'Animation' changed to 'Avkmwujun'
# row: 999 col: 2 : 'Action' changed to 'Abtkmn'
# row: 94 col: 2 : 'Short' changed to 'Avjtt'
# row: 608 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Avnzntgte,Bomedv,Fdntcfy'
# row: 1489 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Wjhmatpjn,Ssnion,Afetggurx,Dci-Fn'
# row: 1528 col: 2 : 'Comedy,Ecchi,Romance' changed to 'Vooedn,Tfxhn,Woksgce'
# row: 699 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Sjhmagilj,Gplzfy,Ssp-Fo'
# row: 123 col: 2 : 'Comedy' changed to 'Zooxdy'
# row: 1174 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Clmscj,Gsnvdvy,Hoss'
# row: 806 col: 2 : 'Comedy,Fantasy' changed to 'Cumcdh,Rdntesy'
# row: 376 col: 2 : 'Animation' changed to 'Qtimauikn'
# row: 247 col: 2 : 'Kids,Music' changed to 'Nyds,Myfiw'
# row: 1599 col: 2 : 'Hentai' changed to 'Hrjcan'
# row: 972 col: 2 : 'Action,War' changed to 'Acyiln,Aer'
# row: 1231 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Avimweijn,Dvcion,Advrhtyvs,Fanyawi'
# row: 576 col: 2 : 'Comedy,Psychological' changed to 'Cmmvqb,Ovjchmlieidaj'
# row: 1582 col: 2 : 'Action,Adventure' changed to 'Qchoun,Cstqutyxe'
# row: 18 col: 2 : 'Fantasy,Kids' changed to 'Gwntcdf,Nldv'
# row: 193 col: 2 : 'Animation,Drama' changed to 'Wnylajiuk,Qrama'
# row: 74 col: 2 : 'Action,Adventure,Demons,Game,Shounen' changed to 'Actiib,Adgebtucw,Aekpgr,Canf,Shobneg'
# row: 528 col: 2 : 'Animation,Short' changed to 'Cnhmxepom,Xhort'
# row: 1499 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Wnhmatiiv,Dcfyoh,Clmedy,Ydgbcfn,Sikcncs'
# row: 1199 col: 2 : 'Animation,Fantasy,Mystery' changed to 'Xuymxjyoj,Fentwvu,Mjsesry'
# row: 425 col: 2 : 'Animation,Comedy' changed to 'Svomation,Comvdn'
# row: 912 col: 2 : 'Hentai' changed to 'Yvttwi'
# row: 1446 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Amioehlot,Dljedv,Xek-Fp'
# row: 355 col: 2 : 'Comedy,Parody,Sci-Fi' changed to 'Cimedy,Pagody,Scu-Hi'
# row: 612 col: 2 : 'Action,Adventure,MartialArts,Samurai' changed to 'Wdvioi,Scfevtjfe,MarchauArts,Salufao'
# row: 616 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Cjmrgv,Rpmwnct,SnisvofLmxe'
# row: 1420 col: 2 : 'Animation' changed to 'Xjimethin'
# row: 563 col: 2 : 'Comedy' changed to 'Comedt'
# row: 778 col: 2 : 'Adventure,Fantasy' changed to 'Aggzncldt,Scncasy'
# row: 1190 col: 2 : 'Animation,Biography,Comedy' changed to 'Animehuon,Vlotvqlhi,Bjkqey'
# row: 416 col: 2 : 'Fantasy,Kids' changed to 'Haghxsj,Kifs'
# row: 445 col: 2 : 'Animation,Comedy,Family,Fantasy' changed to 'Enimznkoh,Epkqeg,Ywihmj,Fantadg'
# row: 902 col: 2 : 'Comedy,School,SliceofLife' changed to 'Cmmwdy,Rxhuil,SnlcgofLlfe'
# row: 1227 col: 2 : 'Short,Drama' changed to 'Skmrt,Crals'
# row: 1172 col: 2 : 'Hentai' changed to 'Hejvwl'
# row: 174 col: 2 : 'Animation,Short' changed to 'Animauilg,Xgivd'
# row: 1079 col: 2 : 'Fantasy,Kids' changed to 'Fannasy,Kidv'
# row: 1381 col: 2 : 'Kids' changed to 'Ljds'
# row: 1504 col: 2 : 'Animation,Action,Drama,Fantasy,Mystery' changed to 'Dvimatilu,Wxtimv,Dgzma,Faufdwy,Kjdtfsb'
# row: 989 col: 2 : 'Fantasy' changed to 'Hantsvt'
# row: 748 col: 2 : 'Drama,Kids,Sports' changed to 'Drzjc,Lhdv,Akorbs'
# row: 1323 col: 2 : 'Romance' changed to 'Romahxw'
# row: 1360 col: 2 : 'Animation,Family,Fantasy,Music' changed to 'Wnijaykok,Famluy,Namfcdt,Muric'
# row: 696 col: 2 : 'Animation,Short,Comedy,Romance' changed to 'Aklizdnoh,Vhort,Fikedy,Cojanxz'
# row: 22 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Adventurr,Wunedi,Fwttasy,Jpcs'
# row: 497 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Aujjetiln,Wbbijh,Dgtejrkrq,Hwndaxy,Vwj-Nn'
# row: 91 col: 2 : 'Animation,Short,Adventure,Comedy,Family' changed to 'Ahymecomk,Shitt,Agvtvenrg,Gokgdy,Rsliph'
# row: 1520 col: 2 : 'Hentai' changed to 'Yzjtai'
# row: 106 col: 2 : 'Hentai' changed to 'Hwntai'
# row: 1302 col: 2 : 'Adventure,Comedy,Demons,Fantasy,Magic,Romance,Shounen,Supernatural' changed to 'Advegeire,Vomgdy,Seooms,Sanrady,Oahiw,Romxncr,Fhmuken,Rnpexnatucco'
# row: 207 col: 2 : 'Animation,Comedy,Drama' changed to 'Wuomatijg,Dumvdy,Qdamw'
# row: 1374 col: 2 : 'Action' changed to 'Abtmin'
# row: 230 col: 2 : 'Romance,Shoujo' changed to 'Romanze,Vrknuo'
# row: 827 col: 2 : 'Action,Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'Zeuijn,Seventuvz,Comeay,Exchi,Lewfw,Xcl-Fi,Sicce'
# row: 1099 col: 2 : 'Fantasy,Music' changed to 'Gantwsy,Inaic'
# row: 628 col: 2 : 'Comedy,Romance,Seinen,SliceofLife' changed to 'Xomqsy,Fojzuce,Rtongn,SlicwofJpfd'
# row: 343 col: 2 : 'Documentary' changed to 'Sofmksntary'
# row: 248 col: 2 : 'Comedy,Drama,Police,Romance' changed to 'Cumqqy,Qfaic,Pjulve,Gkmahgq'
# row: 767 col: 2 : 'Comedy' changed to 'Clmvfg'
# row: 508 col: 2 : 'Animation,Action,Comedy,Family' changed to 'Wnmkatiom,Acbmoi,Cjmeft,Hajiny'
# row: 1486 col: 2 : 'Short,Comedy,Fantasy,Romance' changed to 'Xhpvy,Blkefy,Fqubasb,Romajcf'
# row: 763 col: 2 : 'Animation,Sci-Fi' changed to 'Wnijavomt,Sdi-Gi'
# row: 1550 col: 2 : 'Adventure,Mystery' changed to 'Wdgsketre,Ktstecj'
# row: 796 col: 2 : 'Drama,Ecchi,Romance,School' changed to 'Gxama,Dxcip,Rlianct,Achljl'
# row: 820 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy' changed to 'Anlmaeikg,Advebttre,Bwdka,Famoly,Wzubevy'
# row: 522 col: 2 : 'Comedy' changed to 'Coiegb'
# row: 97 col: 2 : 'Documentary' changed to 'Gusukentwtt'
# row: 667 col: 2 : 'Comedy,Music,SliceofLife' changed to 'Cpnqan,Mudkc,SjicdmfJige'
# row: 921 col: 2 : 'Animation' changed to 'Amyoauimv'
# row: 1303 col: 2 : 'Hentai' changed to 'Heneso'
# row: 865 col: 2 : 'Adventure,Comedy,Mystery' changed to 'Xvvxnyige,Rkngav,Kgrtqrn'
# row: 96 col: 2 : 'Adventure,Kids' changed to 'Dgtebnuev,Klbs'
# row: 162 col: 2 : 'Hentai' changed to 'Mgntso'
# row: 1163 col: 2 : 'Comedy' changed to 'Coivdy'
# row: 830 col: 2 : 'Animation,Short,Drama,Music,Romance' changed to 'Auimagmou,Rhott,Crakc,Mhxoc,Rumqnre'
# row: 600 col: 2 : 'Animation,Adventure,Drama' changed to 'Anioztlmn,Addehbure,Grxla'
# row: 738 col: 2 : 'Comedy' changed to 'Comedy'
# row: 374 col: 2 : 'Fantasy,Horror,Supernatural' changed to 'Gantaay,Nldror,Anldggeturan'
# row: 55 col: 2 : 'Hentai' changed to 'Fsiyxl'
# row: 1218 col: 2 : 'Animation' changed to 'Ahpoayyon'
# row: 225 col: 2 : 'Hentai,School' changed to 'Hgnhsn,Scyllp'
# row: 1450 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Adventurz,Fukddy,Sdgtdfy,Kjgd'
# row: 459 col: 2 : 'Animation,Short,Action,Drama,Fantasy,Romance' changed to 'Animatlog,Smjgt,Awtiot,Stana,Fzntssy,Rojwmce'
# row: 993 col: 2 : 'Fantasy,Romance,SliceofLife' changed to 'Hwmtwxy,Gjmsncx,SlnczufJpre'
# row: 922 col: 2 : 'Comedy,Kids' changed to 'Dmmcdt,Nics'
# row: 341 col: 2 : 'Animation' changed to 'Wminxgion'
# row: 175 col: 2 : 'Comedy' changed to 'Xkmvgy'
# row: 838 col: 2 : 'Magic' changed to 'Jqgic'
# row: 1255 col: 2 : 'Animation,Action,Drama,Fantasy' changed to 'Djnozhyon,Acckot,Brama,Ragtawu'
# row: 80 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Ahkmatiog,Cimegy,Esakc,Rokauce'
# row: 1028 col: 2 : 'Animation,Action,Drama,Sci-Fi,Thriller' changed to 'Wnmmsgiun,Wbvnku,Crama,Scp-Fi,Cgrylleg'
# row: 486 col: 2 : 'Comedy,Seinen,SliceofLife,SuperPower' changed to 'Gumdey,Rfinwt,AnicfmsLixe,Wnpzx[jwqr'
# row: 176 col: 2 : 'Hentai' changed to 'Yzinah'
# row: 624 col: 2 : 'Action,Josei,Supernatural' changed to 'Qction,Jprvi,Rlpcenztbtdj'
# row: 402 col: 2 : 'Comedy' changed to 'Cjmref'
# row: 403 col: 2 : 'Short,Adventure,Family' changed to 'Amorr,Cfrevvuse,Gaminj'
# row: 1526 col: 2 : 'Action,ShounenAi,Supernatural' changed to 'Actpok,AjmikwnAo,Ruktrveeursk'
# row: 1192 col: 2 : 'Adventure,Kids' changed to 'Wdfthrtre,Kicd'
# row: 1207 col: 2 : 'Animation,Family,Comedy,Fantasy' changed to 'Wtioqtjkm,Familt,Womedi,Fwhfaxi'
# row: 1463 col: 2 : 'Animation,Short' changed to 'Xhomqriin,Dhoft'
# row: 84 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'Wdcfhjutr,Domedy,Sbo-Vi,Sgumjtn'
# row: 832 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Atkkdtion,Womzqy,Draka,Rlnancg'
# row: 652 col: 2 : 'SliceofLife' changed to 'DlkeeowNlnx'
# row: 1328 col: 2 : 'Comedy,Sports' changed to 'Cjmzfn,Fojeyx'
# row: 199 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'Znimwhkon,Whjrt,Gimvby,Sxm-Fl'
# row: 1019 col: 2 : 'Action,Adventure,Shounen,SuperPower' changed to 'Wction,Adntjtugq,Smounen,SopfrPoccr'
# row: 727 col: 2 : 'Animation,Adventure' changed to 'Aniiatnub,Aevfkeixg'
# row: 878 col: 2 : 'Adventure' changed to 'Abdfntuge'
# row: 1062 col: 2 : 'Horror,Mystery,Psychological,School,SliceofLife' changed to 'Kufror,Myrtwry,[xhzhoooglfxl,Xwgooo,VuiweowUpff'
# row: 1027 col: 2 : 'Animation,Comedy,Drama' changed to 'Wnioatkon,Fimedv,Brxia'
# row: 235 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'Advftjust,Ddakq,Dcu-Fk'
# row: 1196 col: 2 : 'Documentary,Short,Biography' changed to 'Focumdgtasy,Rnugf,Uiogwakgy'
# row: 1037 col: 2 : 'Drama,Kids' changed to 'Dgzma,Koda'
# row: 523 col: 2 : 'Drama,Family' changed to 'Qrakz,Najipt'
# row: 849 col: 2 : 'Comedy,Drama,Romance,Sci-Fi,SliceofLife' changed to 'Gokggy,Erela,Tmkahca,Swn-Fi,DkigglfLuxe'
# row: 1238 col: 2 : 'Drama,Kids' changed to 'Drzja,Kivs'
# row: 435 col: 2 : 'Drama,Music,Thriller' changed to 'Brama,Muwle,Tmfnlneg'
# row: 559 col: 2 : 'Action,Horror,Mystery' changed to 'Agdpou,Nurgir,Jyvuffy'
# row: 67 col: 2 : 'Adventure,Family,Fantasy,Romance' changed to 'Afvsnhggg,Feoyny,Nwntxvn,Rojcnvf'
# row: 296 col: 2 : 'School,Shounen' changed to 'Vdhool,Skmunen'
# row: 1167 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Zuilwfion,Eumedi,Crams,Coizmzf'
# row: 899 col: 2 : 'Adventure,Short,Animation,Sci-Fi' changed to 'Asvatdura,Sfort,Qnimajnkn,Rci-Hh'
# row: 1417 col: 2 : 'Action,Adventure,Mystery,Police' changed to 'Axtiog,Qbgethurq,Inddesy,Police'
# row: 1125 col: 2 : 'Comedy,Parody,SuperPower' changed to 'Eonecn,Pstodr,FkpdrPmazs'
# row: 1527 col: 2 : 'Animation,Comedy,Drama,Fantasy' changed to 'Aghmadmmn,Domear,Dtama,Fqntert'
# row: 860 col: 2 : 'Comedy,Drama,Music' changed to 'Gomeay,Drqma,Myrns'
# row: 474 col: 2 : 'Animation,Adventure,Comedy,Fantasy,Romance' changed to 'Wvlixtyon,Cgvekdhrx,Eojeef,Yzncaxy,Vmiagce'
# row: 1258 col: 2 : 'Animation,Action,Drama,Romance,Sport' changed to 'Aiikatlun,Wvroon,Arcma,Gondtze,Fputt'
# row: 709 col: 2 : 'Animation,Drama,History,Romance' changed to 'Animetjon,Dxama,Mjsfowu,Condncv'
# row: 928 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'Ahpmeniub,Wbvtnthxf,Sci-Di'
# row: 125 col: 2 : 'Action,Adventure' changed to 'Drtilm,Wgvcntute'
# row: 1470 col: 2 : 'Hentai' changed to 'Gemtai'
# row: 933 col: 2 : 'Drama,Romance' changed to 'Drama,Rumzvxe'
# row: 572 col: 2 : 'Drama,Kids' changed to 'Axama,Llvw'
# row: 1466 col: 2 : 'Adventure,Comedy,Kids' changed to 'Affevdugq,Zijxdf,Kkdv'
# row: 622 col: 2 : 'Animation,Short' changed to 'Ailmacijn,Fhpdj'
# row: 1050 col: 2 : 'Drama,Fantasy,Mystery,Romance,School' changed to 'Dcwoa,Rzkfasu,Mbsnsxy,Rumanbd,Swhomk'
# row: 26 col: 2 : 'Comedy,School,SliceofLife' changed to 'Conedb,Xvhuol,SukfwifUjfc'
# row: 12 col: 2 : 'Comedy,Music,SliceofLife' changed to 'Eomedy,Juric,SpoexlfLpfe'
# row: 774 col: 2 : 'Animation,Drama' changed to 'Anhmqjloh,Gvwka'
# row: 242 col: 2 : 'Adventure,Fantasy,Historical' changed to 'Ddvenbuve,Faitefh,Mysjorkcsl'
# row: 137 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'Anikatiob,Qvglun,Cavetnutx,Zonevi,Fdmily,Fwgvwxy'
# row: 719 col: 2 : 'Animation,Short' changed to 'Aklkaglln,Avory'
# row: 494 col: 2 : 'Comedy,Parody,School,Sci-Fi,Shounen' changed to 'Cimtft,Oweudb,Sxhool,Dcj-Gi,Fhmgieg'
# row: 1423 col: 2 : 'Hentai' changed to 'Yental'
# row: 887 col: 2 : 'Adventure,Historical,Shounen' changed to 'Qevennust,Hiatorhcwl,Fhounxn'
# row: 1252 col: 2 : 'Animation,Drama' changed to 'Xiioevmon,Srdmc'
# row: 481 col: 2 : 'Kids,Music' changed to 'Kidd,Mbvif'
# row: 1278 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'Aetegtuce,Colefn,VlpswjfMhhe'
# row: 861 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'Colvvb,Aci-Wi,Spzre'
# row: 757 col: 2 : 'Comedy' changed to 'Rlmwdy'
# row: 440 col: 2 : 'Animation,Drama,Family,Romance' changed to 'Anmnwhoun,Ddams,Yaonly,Goiamcz'
# row: 1109 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi,Thriller' changed to 'Avimdtnut,Actlon,Eavvntyrs,Famnly,Fajtcsy,Rci-Gi,Yhrhllev'
# row: 1285 col: 2 : 'Hentai' changed to 'Heuhdi'
# row: 558 col: 2 : 'Drama' changed to 'Draoe'
# row: 185 col: 2 : 'Animation,Comedy,Drama' changed to 'Enimdyiku,Cokgau,Dwame'
# row: 1496 col: 2 : 'Drama,Fantasy,Mystery' changed to 'Grdmc,Fdbtefr,Kyscegy'
# row: 882 col: 2 : 'Short,Animation,Sci-Fi' changed to 'Smjrc,Qnojaejmn,Sfk-Hu'
# row: 1032 col: 2 : 'Animation' changed to 'Xmhldbion'
# row: 191 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'Wccikn,Voiebi,Iolids,Rhulneu'
# row: 1012 col: 2 : 'Animation,Drama,Horror' changed to 'Anhkatkou,Dtaia,Jirrif'
# row: 68 col: 2 : 'Animation,Adventure' changed to 'Anikwvupn,Wavejjnrc'
# row: 60 col: 2 : 'Comedy' changed to 'Gmivdj'
# row: 1473 col: 2 : 'Comedy,Drama,Romance,School' changed to 'Gongfy,Drame,Rokxibc,Schuom'
# row: 412 col: 2 : 'Comedy' changed to 'Cojedy'
# row: 7 col: 2 : 'Animation,Drama,Sport' changed to 'Wkkmctkjt,Graie,Vpuxb'
# row: 384 col: 2 : 'Animation,Drama,Family,Fantasy' changed to 'Anmmdtiom,Dfaks,Fwmppt,Fautafn'
# row: 254 col: 2 : 'Fantasy,Magic,Shoujo' changed to 'Faujary,Iagis,Dhoijo'
# row: 318 col: 2 : 'Animation,Action,Comedy,Drama,Mystery,Sci-Fi' changed to 'Snolztoom,Eftlon,Cimefv,Vsxmz,Misdrcy,Acu-Fl'
# row: 1472 col: 2 : 'Horror,Psychological' changed to 'Roxrlx,Orycyoliyofcp'
# row: 358 col: 2 : 'Animation,Action,Comedy' changed to 'Xnliwgjut,Dctpog,Cjleey'
# row: 944 col: 2 : 'Animation,Comedy' changed to 'Agmkxtlon,Wpkedj'
# row: 916 col: 2 : 'Comedy,Magic,Parody' changed to 'Coiedj,Kxgiv,Parodt'
# row: 1346 col: 2 : 'Animation,Action,Romance,Sci-Fi' changed to 'Abioatlmj,Dbtiou,Romanxe,Scl-Yl'
# row: 479 col: 2 : 'Kids,Sci-Fi' changed to 'Noss,Xzi-Fu'
# row: 1033 col: 2 : 'Action,Adventure,Comedy,Fantasy' changed to 'Acdimi,Sdgdghurz,Cokeqh,Vsjbcsy'
# row: 1223 col: 2 : 'Fantasy,Kids,Magic' changed to 'Nshtafy,Ilva,Lagix'
# row: 310 col: 2 : 'Adventure,Historical,Sci-Fi' changed to 'Xdventuvw,Ikfuocigau,Xgi-Fi'
# row: 760 col: 2 : 'Action,Adventure,Fantasy' changed to 'Actimi,Cdvatture,Wantasg'
# row: 1191 col: 2 : 'Comedy,School,Shounen' changed to 'Zomfsj,Rehpok,Shlunxn'
# row: 839 col: 2 : 'SliceofLife' changed to 'AlizelvKife'
# row: 1407 col: 2 : 'Comedy,SliceofLife' changed to 'Cimegy,SukcgmvJyhe'
# row: 1144 col: 2 : 'Hentai' changed to 'Hdvral'
# row: 640 col: 2 : 'Action,Mystery,Supernatural,Thriller' changed to 'Cctnon,Mysrerb,Supwruqfyral,Rjrinker'
# row: 590 col: 2 : 'Animation,Horror,Sci-Fi' changed to 'Dnylxcklh,Vorgjs,Sci-Vy'
# row: 186 col: 2 : 'Animation' changed to 'Xnikabmon'
# row: 466 col: 2 : 'Animation,Comedy,Drama' changed to 'Ajikxnimg,Domedu,Dramx'
# row: 569 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'Wjlmddomn,Ertikb,Coircj,Yeuczfy,Ari-Gy'
# row: 228 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Wjimadion,Zlmedn,Dgqmw,Ronahdf'
# row: 1148 col: 2 : 'Animation,Action,Comedy,Crime,Fantasy,Horror,Mystery' changed to 'Amioarlpn,Eefpon,Cpiady,Ceils,Gejvxsy,Fkrtor,Ijvtwwy'
# row: 1430 col: 2 : 'Action,Comedy' changed to 'Wstljn,Cjoeej'
# row: 336 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Znhmatkok,Actiii,Scn-Rj'
# row: 1338 col: 2 : 'Animation' changed to 'Dnikatiok'
# row: 836 col: 2 : 'Animation,Action,Fantasy' changed to 'Sgmlatiin,Svtiou,Raitasi'
# row: 252 col: 2 : 'Kids' changed to 'Kisf'
# row: 1229 col: 2 : 'Comedy,Kids' changed to 'Colzdy,Kids'
# row: 1549 col: 2 : 'Short,Comedy' changed to 'Rklrj,Dokeet'
# row: 805 col: 2 : 'Animation,Adventure,Fantasy,Sci-Fi' changed to 'Wnlkwjion,Aavfmunct,Vahcasj,Rdn-Sh'
# row: 1249 col: 2 : 'Action,Sci-Fi' changed to 'Astioh,Fcm-Fi'
# row: 65 col: 2 : 'Mecha,Sports' changed to 'Lecha,Vpkrvs'
# row: 909 col: 2 : 'Fantasy,Kids' changed to 'Dsntxdy,Kidd'
# row: 1589 col: 2 : 'Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'Dgceveurr,Cojqgy,Xcckl,Oedmw,Dwu-Fm,Wiwcg'
# row: 1558 col: 2 : 'Romance,School,Shoujo' changed to 'Romance,Szkokj,Akojju'
# row: 691 col: 2 : 'Comedy,Ecchi' changed to 'Coisdy,Tvchm'
# row: 883 col: 2 : 'Drama,Historical' changed to 'Deama,Fistocyzal'
# row: 845 col: 2 : 'Comedy,Ecchi,Fantasy,Game' changed to 'Cojtet,Ecwho,Fdnywsy,Eake'
# row: 139 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'Cwgyju,Abveuthrx,Fabhwsy,Wyklncn'
# row: 642 col: 2 : 'Comedy' changed to 'Dimtdy'
# row: 1392 col: 2 : 'Action,Ecchi,Fantasy,School,Seinen' changed to 'Ercioh,Dcchl,Hznvzsy,Srhjjm,Samkvu'
# row: 369 col: 2 : 'Animation' changed to 'Ahiketoon'
# row: 1246 col: 2 : 'Action,Adventure,Fantasy,Hentai' changed to 'Szrion,Xevtgyuxa,Fwnjesy,Hamgdm'
# row: 1523 col: 2 : 'Short,Romance' changed to 'Rfucj,Rolahed'
# row: 437 col: 2 : 'Hentai' changed to 'Nebjsl'
# row: 1488 col: 2 : 'Animation' changed to 'Dkyiacpou'
# row: 890 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Xihmeyyut,Cmkedy,Hcntwrv'
# row: 1332 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'Dxtnon,Dvbejvmse,Mccra,Vwy-Du'
# row: 775 col: 2 : 'Comedy' changed to 'Ckjadj'
# row: 108 col: 2 : 'Comedy,Historical,Parody' changed to 'Bmmtst,Histoenczm,Iwdjau'
# row: 941 col: 2 : 'Harem,Hentai' changed to 'Fsrto,Hzbtzi'
# row: 51 col: 2 : 'Romance,School,Shoujo' changed to 'Rkjabez,Xxhmpo,Xfouji'
# row: 145 col: 2 : 'Comedy' changed to 'Dmkevy'
# row: 1477 col: 2 : 'Action,Drama,Western' changed to 'Zetiot,Veajs,Wwwtggj'
# row: 556 col: 2 : 'Animation,Action,Comedy' changed to 'Aiijatiub,Cddipn,Cmledg'
# row: 1055 col: 2 : 'Drama,Family,Romance' changed to 'Drcme,Xxolji,Gmicjcq'
# row: 863 col: 2 : 'School,Shounen,Sports' changed to 'Svipok,Shohmfb,Spoets'
# row: 142 col: 2 : 'Drama' changed to 'Bvaiw'
# row: 1456 col: 2 : 'Comedy,Fantasy' changed to 'Comevv,Nzuvasj'
# row: 1247 col: 2 : 'Drama,Historical,SliceofLife' changed to 'Vrana,Inftkrygdl,SkiweofKirf'
# row: 431 col: 2 : 'Drama,Romance' changed to 'Dddna,Gokdnxc'
# row: 872 col: 2 : 'Fantasy,Music' changed to 'Xagnxry,Misic'
# row: 1475 col: 2 : 'Comedy' changed to 'Comddi'
# row: 1418 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'Actilk,Cjlrdf,Poliee,Svpugfk'
# row: 414 col: 2 : 'Comedy' changed to 'Zomrdj'
# row: 267 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi' changed to 'Zniiceioh,Zdcion,Arwkq,Tjoanwe,Xvj-Fi'
# row: 54 col: 2 : 'Short,Family,Animation,Fantasy' changed to 'Svory,Fqmimt,Dnmjacion,Fantesu'
# row: 1274 col: 2 : 'Music' changed to 'Mbfic'
# row: 1264 col: 2 : 'Short' changed to 'Snjrt'
# row: 1382 col: 2 : 'Animation,Short' changed to 'Eiimation,Shogt'
# row: 492 col: 2 : 'Animation,Drama,Horror,Mystery' changed to 'Snikcgimk,Drdnd,Fjtfpd,Mfwtfsn'
# row: 232 col: 2 : 'Comedy,Kids' changed to 'Bkiedy,Kuva'
# row: 526 col: 2 : 'Action,Magic,Sci-Fi,SuperPower' changed to 'Acfiob,Magic,Xcp-Nn,Wuiqr'owee'
# row: 49 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Acjion,Sdvtjhhre,Comsby,Whojnxb'
# row: 1009 col: 2 : 'Animation' changed to 'Qiymatlom'
# row: 1576 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Comgdr,Fxtrqsy,Kics'
# row: 130 col: 2 : 'Kids,Music' changed to 'Kidv,Musuc'
# row: 1298 col: 2 : 'Animation,Adventure,Fantasy' changed to 'Anmmatkob,Wcvcmyuwa,Habtcsj'
# row: 828 col: 2 : 'Animation,Short,Fantasy' changed to 'Aipkaymjv,Smmgt,Xaufesy'
# row: 1181 col: 2 : 'Animation,Adventure,Comedy,Fantasy' changed to 'Akpmavkob,Adxthuhrq,Womrsn,Fdttast'
# row: 1367 col: 2 : 'Hentai,Yaoi' changed to 'Ksutdh,Yzjn'
# row: 1171 col: 2 : 'Comedy,Historical,Seinen' changed to 'Somzey,Fisboeicau,Awinei'
# row: 1405 col: 2 : 'Animation,Short' changed to 'Amhnajjkv,Sgott'
# row: 959 col: 2 : 'Animation,Drama,Fantasy' changed to 'Qnimatnun,Drsmd,Fajfash'
# row: 6 col: 2 : 'Horror,Thriller' changed to 'Rjewpv,Vfrillgr'
# row: 1566 col: 2 : 'Animation' changed to 'Ailksyiln'
# row: 781 col: 2 : 'Action,Adventure,Comedy,Drama,Romance,Sci-Fi' changed to 'Dzdioj,Adfvntude,Gpmqqi,Efxmc,Wliqncx,Rey-Fl'
# row: 977 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Ajpmajuok,Comref,Vdl-Fi'
# row: 1120 col: 2 : 'Action,Mecha,Sci-Fi' changed to 'Acvipn,Izvra,Xbn-Ni'
# row: 8 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'Actipn,Bumaat,Jareo,Swh-Fl,Ahohnqj,Sleed'
# row: 988 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Romance' changed to 'Akjlaejoj,Dztipu,Cokevy,Atakw,Rebnsxv,Rojwjse'
# row: 482 col: 2 : 'Fantasy' changed to 'Fennavr'
# row: 948 col: 2 : 'Animation,Comedy' changed to 'Atinaciok,Bonedy'
# row: 592 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Wvlmatiig,Awfujk,Dddeiykre,Xikedh,Fwntaay,Sgo-Fu'
# row: 95 col: 2 : 'Comedy,Sports' changed to 'Ckmdcu,Rppfex'
# row: 299 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'Xnymztiun,Flncbi,Vfama,Dpord'
# row: 1029 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi' changed to 'Zhikavion,Acdion,Advevvutw,Fwmjmg,Dwudwxy,Sgo-Fi'
# row: 1406 col: 2 : 'Animation,Crime,Drama,Fantasy,Mystery,Thriller' changed to 'Svykwriun,Grije,Srema,Hanuzay,Oysesrh,Thwmmper'
# row: 1105 col: 2 : 'Animation,Short,Action,Comedy,Romance' changed to 'Anmmehiin,Wmpru,Wruimh,Ejlegy,Rolajev'
# row: 1383 col: 2 : 'SliceofLife' changed to 'FluctpfLifs'
# row: 1431 col: 2 : 'Animation,Short' changed to 'Wnijatloh,Fhjtb'
# row: 151 col: 2 : 'Action,Ecchi,Fantasy' changed to 'Wwtiun,Scwfi,Xxjtwxy'
# row: 1282 col: 2 : 'Comedy,Horror' changed to 'Dlmqey,Korvlr'
# row: 752 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Annmzdnok,Zcvylu,Sbi-Wp'
# row: 741 col: 2 : 'Drama' changed to 'Ddxka'
# row: 1573 col: 2 : 'Animation,Adventure,Drama,Fantasy,Romance' changed to 'Wnimadiln,Wbddktyra,Drana,Nsitwsy,Rpoanwe'
# row: 238 col: 2 : 'Comedy,Crime,Drama' changed to 'Bljefn,Xgimc,Qrwmc'
# row: 85 col: 2 : 'Animation' changed to 'Wiumzthji'
# row: 1410 col: 2 : 'Hentai' changed to 'Hejtzn'
# row: 1581 col: 2 : 'Music' changed to 'Mjsid'
# row: 1518 col: 2 : 'Animation,Sport' changed to 'Silleukon,Souet'
# row: 1455 col: 2 : 'Action,Comedy,MartialArts,School,Shounen' changed to 'Xggiug,Coiqvv,JxrroajArrw,Swjool,Smiuben'
# row: 1070 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'Anumeunji,Agutj,Ckkqdn,Svm-Fi'
# row: 1569 col: 2 : 'Animation,Fantasy' changed to 'Wblmabium,Fxkvadf'
# row: 875 col: 2 : 'Drama,Kids' changed to 'Dwqkw,Nivs'
# row: 1128 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Aniksgkln,Azniuh,Vcy-Wi'
# row: 202 col: 2 : 'Comedy,Seinen' changed to 'Cokedg,Xwigen'
# row: 702 col: 2 : 'Comedy' changed to 'Zmoesy'
# row: 76 col: 2 : 'Kids' changed to 'Kiar'
# row: 1066 col: 2 : 'Animation,Short' changed to 'Dniozhmpn,Xyorj'
# row: 1555 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi' changed to 'Qhimatilm,Czvkjk,Dvvxntytv,Wskumg,Feugaft,Wem-No'
# row: 1299 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Avlmqnipn,Wmjebj,Fgdma,Fomanwe'
# row: 1517 col: 2 : 'Animation,Action,Crime,Sci-Fi' changed to 'Avimatjiv,Actiot,Srlme,Sci-Yo'
# row: 1322 col: 2 : 'Hentai' changed to 'Hdnrwy'
# row: 182 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Dvimatipt,Cjmvdf,Egama,Ronanbe'
# row: 736 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Wvpmatyjg,Awdion,Wevcveurs,Rdk-Fi'
# row: 1 col: 2 : 'Action,Adventure' changed to 'Qctiok,Zdbtnyuts'
# row: 759 col: 2 : 'Family' changed to 'Famylh'
# row: 595 col: 2 : 'Comedy,Action,Drama,Family' changed to 'Ruledy,Adtili,Drwma,Famloj'
# row: 794 col: 2 : 'Animation,Sci-Fi' changed to 'Xjimatikn,Wgn-Hi'
# row: 953 col: 2 : 'Animation' changed to 'Anoksrluj'
# row: 645 col: 2 : 'Action,Adventure,Crime,Drama,Mystery' changed to 'Wwnuon,Agvtkyufw,Cgimt,Qsznd,Myrtwry'
# row: 1395 col: 2 : 'Historical' changed to 'Hiagkgicau'
# row: 1320 col: 2 : 'Kids' changed to 'Nuds'
# row: 1537 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Anikdtlon,Aztyon,Sdveneuvd,Cumwdv,Fcndqfg,Sep-Fy'
# row: 87 col: 2 : 'School' changed to 'Veviol'
# row: 1426 col: 2 : 'SliceofLife' changed to 'SliceonOure'
# row: 1300 col: 2 : 'Adventure,Drama,Historical,Romance' changed to 'Avrwbture,Brqma,Hlsemricak,Wojcife'
# row: 135 col: 2 : 'Hentai' changed to 'Hxvyay'
# row: 967 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'Fokedf,Gfxvy,Hcrem,Romsbce'
# row: 1592 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Wdrentgre,Vauvawt,Kisr'
# row: 1056 col: 2 : 'Sci-Fi,Action,Animation' changed to 'Ssy-Fi,Aceokn,Animwfilm'
# row: 1071 col: 2 : 'Mystery,Psychological' changed to 'Jyxtfxt,Pshchiuiymdal'
# row: 1536 col: 2 : 'Fantasy,SliceofLife' changed to 'Fajtday,RjmwdofLiyt'
# row: 1453 col: 2 : 'Drama,Josei' changed to 'Brakc,Jovel'
# row: 1047 col: 2 : 'Action' changed to 'Agbipm'
# row: 534 col: 2 : 'Animation,Sci-Fi,Thriller' changed to 'Aunkstyjk,Sbi-Go,Nhrlpner'
# row: 940 col: 2 : 'Animation,Short,Drama,Music' changed to 'Abikafioj,Xhort,Vcwmw,Mudic'
# row: 1411 col: 2 : 'Action,Demons,Fantasy' changed to 'Actijn,Bejomr,Favtwsy'
# row: 1139 col: 2 : 'Comedy,Drama' changed to 'Clmedy,Fxsmd'
# row: 803 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Enimatkon,Cooegy,Drsia,Hdjyxxr,Romanfg'
# row: 1053 col: 2 : 'Action,Comedy,Supernatural' changed to 'Asdioj,Comdaj,Supacnahgeso'
# row: 1445 col: 2 : 'Comedy,Ecchi,Fantasy,Romance,SliceofLife' changed to 'Bonedi,Ebdgi,Gxjtaxu,Rjnxncr,SuhcemnMifw'
# row: 241 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Anlmwyiin,Wfukji,Qcdvnjure,Woleci,Sdjtwsi,Sxy-Rl'
# row: 1510 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Akimstnoj,Actnkn,Evsiw,Sxi-Sk'
# row: 1428 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'Zcuioj,Aqnenture,Xomevn,Shounqm'
# row: 1529 col: 2 : 'Drama' changed to 'Drakz'
# row: 1460 col: 2 : 'Hentai' changed to 'Yrvtsu'
# row: 99 col: 2 : 'Comedy,Drama' changed to 'Wjiedy,Ggama'
# row: 1447 col: 2 : 'Animation,Short' changed to 'Snlnarnkn,Sjmvu'
# row: 1524 col: 2 : 'Action,Fantasy,Seinen,Supernatural' changed to 'Acjilb,Namtawy,Sfnueg,Slpxgvacigal'
# row: 1339 col: 2 : 'Adventure,Fantasy' changed to 'Davebdure,Wandqxy'
# row: 1221 col: 2 : 'Animation,Short,Comedy' changed to 'Aniidriik,Sylrt,Comeqy'
# row: 904 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi,Sport' changed to 'Xhjmatmon,Ccfiig,Slmxdy,Fantcsy,Wcm-Fy,Spogb'
# row: 1442 col: 2 : 'Drama,Military,Sci-Fi,Space' changed to 'Drwma,Mmlltqrt,Dci-Hm,Spabe'
# row: 1371 col: 2 : 'Kids,Sports' changed to 'Iisx,Fpoxvs'
# row: 991 col: 2 : 'Comedy,Romance' changed to 'Cuixdy,Roisnst'
# row: 855 col: 2 : 'Animation,Action,Fantasy,Sci-Fi,Thriller' changed to 'Xnklatpon,Ezeiln,Xwntqxb,Scl-Fu,Grwkljzr'
# row: 704 col: 2 : 'SliceofLife' changed to 'SuuweohLlfr'
# row: 1200 col: 2 : 'Drama,Family' changed to 'Vrdia,Swkllh'
# row: 1356 col: 2 : 'Comedy,Game,Space' changed to 'Xkmqdy,Gwiw,W[afd'
# row: 484 col: 2 : 'Animation,Fantasy,Romance' changed to 'Etimwgiot,Fanuxvy,Gomskre'
# row: 898 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Gumabu,Sokeuze,SliczorLifc'
# row: 72 col: 2 : 'Animation,Comedy,Romance' changed to 'Qgiiccoon,Blkefn,Rolqmdd'
# row: 17 col: 2 : 'Animation,Family' changed to 'Akimariit,Falnlj'
# row: 215 col: 2 : 'Action,Adventure,Animation,Sci-Fi,Thriller' changed to 'Cvfiob,Cdrqnbucv,Snimwtiij,Afi-Rn,Tkrnjnrt'
# row: 1091 col: 2 : 'Adventure,Sports' changed to 'Avvsnnurf,R[lets'
# row: 753 col: 2 : 'Comedy' changed to 'Cimggy'
# row: 1237 col: 2 : 'Action,Adventure,Mecha,Military,Sci-Fi' changed to 'Wctymn,Qvvevtogx,Nddra,Mlpitert,Rri-Vi'
# row: 1093 col: 2 : 'Fantasy,Kids,Magic,Shoujo' changed to 'Fzghevj,Ligs,Nxcie,Ahoyoi'
# row: 189 col: 2 : 'Comedy' changed to 'Cliegj'
# row: 1182 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Ahulznmjv,Actmut,Comeqg,Fwjcasy,Roiancq'
# row: 946 col: 2 : 'Documentary' changed to 'Bocunengqrg'
# row: 969 col: 2 : 'Animation,Sci-Fi' changed to 'Qniiqvypu,Sci-Fi'
# row: 366 col: 2 : 'Hentai' changed to 'Kentqk'
# row: 1208 col: 2 : 'Comedy' changed to 'Comfdj'
# row: 891 col: 2 : 'Comedy,Ecchi' changed to 'Zjizdy,Zcwyp'
# row: 816 col: 2 : 'Animation,Comedy' changed to 'Avkmetjin,Cpmtqn'
# row: 542 col: 2 : 'Action,Historical' changed to 'Arynog,Hlshpdmrsl'
# row: 926 col: 2 : 'Animation,Sci-Fi' changed to 'Animwtimn,Xci-Gu'
# row: 271 col: 2 : 'Comedy' changed to 'Cokwvj'
# row: 930 col: 2 : 'Animation' changed to 'Anmlqbukn'
# row: 493 col: 2 : 'Animation,Action,Comedy,Sci-Fi' changed to 'Xiikqhion,Wccion,Cmmeei,Sgi-Ni'
# row: 1233 col: 2 : 'Animation' changed to 'Annmatilv'
# row: 1250 col: 2 : 'Drama,SliceofLife' changed to 'Dralw,SmixeofLlfz'
# row: 1165 col: 2 : 'Hentai' changed to 'Jtifzi'
# row: 983 col: 2 : 'Comedy,SliceofLife' changed to 'Somevr,VpiveowUjfx'
# row: 1538 col: 2 : 'Dementia' changed to 'Famekjpa'
# row: 23 col: 2 : 'Comedy,Ecchi,SliceofLife' changed to 'Cimeby,Eschi,SlmzrlhPmwe'
# row: 347 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'Qnmmarkob,Bkkvdb,Dsama,S'oey'
# row: 1310 col: 2 : 'Adventure,Kids' changed to 'Zdventlrs,Nmed'
# row: 1368 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'Aseyjn,Ddveggnre,Folcdj,Fsitcsu,Iibf'
# row: 925 col: 2 : 'Drama' changed to 'Dgzia'
# row: 203 col: 2 : 'Comedy,Demons,Ecchi,Fantasy,Romance,Seinen' changed to 'Emmscr,Aemokv,Tzcyi,Szvtcsh,Fomqvce,Seinti'
# row: 1185 col: 2 : 'Animation,Action,Comedy' changed to 'Wjkjetion,Wgnioh,Goltvg'
# row: 656 col: 2 : 'Short,Sci-Fi,War' changed to 'Drocu,Svn-Fi,Cwr'
# row: 111 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'Amikation,Sftion,Zbdebtudc,Fqntwsy,Sbi-Fl,Vhwkklqg'
# row: 908 col: 2 : 'Documentary' changed to 'Gocumdhtcti'
# row: 1242 col: 2 : 'Animation,Action,Adventure,Drama' changed to 'Dbuichiov,Ecnkon,Adesnytse,Ctakw'
# row: 722 col: 2 : 'Animation' changed to 'Xhkoxyikm'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1543, 7994)
# (27, 7994)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1543, 7993)
# (27, 7993)
# (1543, 700)
# (27, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.09
# Mean squared error: 1.31
# Variance score: -21.76

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.30
# Mean squared error: 1.72
# Variance score: -38.16

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [1.079 1.042 0.943 0.976 0.983]
# Mean: 1.0045339135956586
# Standard deviation: 0.04894864984237875

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.88

# %%
clf = training(model = linear_model.Lasso(alpha = 0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.05
# Mean squared error: 1.26
# Variance score: -20.09
