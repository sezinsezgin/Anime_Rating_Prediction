# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Keyboard(),50, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Keyboard().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Keyboard().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Keyboard method ---------------
#
# row: 578 col: 2 : 'Animation,Adventure,Comedy,Family' changed to 'nniimmaaroonn,,ddmj,,Vookrsyyaakut'
# row: 554 col: 2 : 'Adventure,Family,Fantasy,Romance' changed to 'Qddeej,,Cqmmiillyy,,tt,,Escc'
# row: 914 col: 2 : 'Animation,Action,Drama,Fantasy,Horror,Thriller' changed to 'AAbnsiioo,,AAyooenaaFFsmttqYee,,Rhhkd'
# row: 893 col: 2 : 'Adventure,Drama,Fantasy' changed to 'AAswttrree,,DDmmGaabsyy'
# row: 194 col: 2 : 'Hentai' changed to 'HHeeii'
# row: 1359 col: 2 : 'Adventure,Kids' changed to 'svveettuurreeKKa'
# row: 429 col: 2 : 'Kids,Supernatural' changed to 'KKdddZipprrbqyjk'
# row: 386 col: 2 : 'Comedy' changed to 'CCddt'
# row: 667 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'nnnttiioo,,QcculnnAAddbeemger,,oonddu'
# row: 720 col: 2 : 'Drama' changed to 'tqn'
# row: 698 col: 2 : 'Drama,Ecchi,Romance,School' changed to 'XfqkaaEEccxgRRimmqbdvioo'
# row: 468 col: 2 : 'Family' changed to 'FFk'
# row: 971 col: 2 : 'Animation' changed to 'nnttki'
# row: 1051 col: 2 : 'Documentary' changed to 'DDfjrttstyy'
# row: 732 col: 2 : 'Comedy' changed to 'CCoodsh'
# row: 94 col: 2 : 'Comedy,Ecchi,Kids,Shounen' changed to 'peeyyDccccykiifss,,hhieenn'
# row: 978 col: 2 : 'Kids,SliceofLife' changed to 'ofSSkkvffii'
# row: 124 col: 2 : 'Action,Comedy,Ecchi,Fantasy,Harem,Magic,Romance' changed to 'Qfyuoonn,,Xru,,EEcchhiiFFnnraadyy,,Yqrrdk,,qggkcc,,Fookaannvr'
# row: 363 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'ttunnsvvttuuee,,lmmrddiuubeenn'
# row: 446 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'Sxgoo,,ookddh,,PPlllkxwWyooeenn'
# row: 11 col: 2 : 'Music' changed to 'Kiv'
# row: 681 col: 2 : 'Dementia,Drama' changed to 'Eeendbttk,,Xtaammaa'
# row: 1482 col: 2 : 'Kids,Music' changed to 'sss,,MMw'
# row: 655 col: 2 : 'Short,Drama,Thriller' changed to 'Ayirrtt,,EqmmaaTThheklleerr'
# row: 145 col: 2 : 'Ecchi,Mystery,Romance,Seinen' changed to 'EEccfiiKtteeyyoonaannccr,,Wweej'
# row: 1177 col: 2 : 'Comedy,Music,Shoujo' changed to 'XkeyyNjf,,oon'
# row: 1342 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'bkkaagiioonn,,QccttpnnCCrddt,,CaamqssuRRpmmaav'
# row: 301 col: 2 : 'Comedy,Ecchi,Mecha,Romance,Sci-Fi' changed to 'wddyy,,fiiNrxhhaaRRoommnnccee,,iiFF'
# row: 1390 col: 2 : 'Drama' changed to 'rrk'
# row: 1563 col: 2 : 'Animation,Short,Comedy' changed to 'AAnnmmaattb,,SSj,,CCeeh'
# row: 430 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Fantasy' changed to 'AAjummgkSxttupnn,,VookddyyFkkwrrs,,qjttaassyy'
# row: 79 col: 2 : 'Comedy' changed to 'oonee'
# row: 281 col: 2 : 'Hentai' changed to 'HHeenntt'
# row: 28 col: 2 : 'Animation,Short,Action,Adventure,Sci-Fi' changed to 'AAnnummWooey,,Qxttnn,,SeeejuueAcc--FFii'
# row: 570 col: 2 : 'Romance,School,Shoujo' changed to 'ikqb,,xyooook,,boouuoo'
# row: 184 col: 2 : 'Animation,Action,Fantasy' changed to 'QokqiilbriiFFaannttaassh'
# row: 1206 col: 2 : 'Drama,Historical,Sports' changed to 'Seqmms,,iidttitiiaa,,Worrtt'
# row: 833 col: 2 : 'Comedy' changed to 'CCoommddyy'
# row: 159 col: 2 : 'Drama' changed to 'DDrraa'
# row: 546 col: 2 : 'Sci-Fi,SliceofLife' changed to 'x--iicceedOiiee'
# row: 602 col: 2 : 'Action,War' changed to 'Qfttklnn,,srr'
# row: 990 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'Qbummaaj,,Qccttij,,Vpkddt,,Zpf'
# row: 993 col: 2 : 'Animation,Short,Music' changed to 'AAnniiql,,Zhhoog,,MMisscc'
# row: 261 col: 2 : 'School,SliceofLife' changed to 'xhhlloSSooccooffiiffee'
# row: 1558 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'bummsttkAAccttnn,,AAfbeeteeeedduRaaoRaannttssu'
# row: 505 col: 2 : 'Adventure,Sci-Fi' changed to 'Scnnttyee,,--C'
# row: 1220 col: 2 : 'Animation,Short' changed to 'iimmaaiij,,Woof'
# row: 1057 col: 2 : 'Documentary,Comedy,History,War' changed to 'SpfieennttaafuFmmddHHiizttooft,,WWrr'
# row: 210 col: 2 : 'Drama,Kids' changed to 'Xfmmaa,,KKii'
# row: 644 col: 2 : 'Comedy,Fantasy' changed to 'CCpnst,,FFnngaassyy'
# row: 1094 col: 2 : 'Adventure,Fantasy' changed to 'ddcdmruurrdRaannr'
# row: 633 col: 2 : 'Comedy,Fantasy' changed to 'pdhbttaassh'
# row: 167 col: 2 : 'Comedy,Drama,Romance' changed to 'pmmeeeyy,,FfaanFoommj'
# row: 1431 col: 2 : 'Horror,Shounen' changed to 'p,,Djnnee'
# row: 1577 col: 2 : 'Drama' changed to 'aakaa'
# row: 754 col: 2 : 'Comedy,Sci-Fi,Space' changed to 'CClketSSii--CAsvee'
# row: 516 col: 2 : 'Fantasy,Kids' changed to 'aattaa,,Mss'
# row: 326 col: 2 : 'SliceofLife' changed to 'kwdurr'
# row: 472 col: 2 : 'Music' changed to 'MMuuiif'
# row: 135 col: 2 : 'Comedy,Samurai,School' changed to 'CCesmmifaa,,Zvhhoo'
# row: 360 col: 2 : 'News' changed to 'q'
# row: 149 col: 2 : 'Comedy,Ecchi,Romance,Shounen,Supernatural,Vampire' changed to 'CCinwddt,,Dfx,,RRmmsjr,,hhoouujnnZuueennttuueVViirrw'
# row: 1073 col: 2 : 'Music' changed to 'Nssuv'
# row: 61 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'Snnoiinnddyy,,fmm,,Zooorrtt'
# row: 973 col: 2 : 'Comedy' changed to 'CClfyy'
# row: 1024 col: 2 : 'Animation,Action,Adventure,Fantasy,Horror,Mystery' changed to 'QmoaaoojQfruim,,fcrirrrFFaannttd,,rrKyysswrrt'
# row: 659 col: 2 : 'Ecchi,Music' changed to 'fxhh,,ssiicc'
# row: 1513 col: 2 : 'Adventure,Comedy,Drama,Fantasy,Historical,Romance' changed to 'AAfmtteee,,F,,DDrraa,,aannttsh,,ssgprrllRRookaannfd'
# row: 668 col: 2 : 'Animation,Short,Fantasy' changed to 'Snsttup,,Der,,Rqaassyy'
# row: 1063 col: 2 : 'Animation,Drama,Romance' changed to 'Qbiimmsttb,,smm,,p'
# row: 535 col: 2 : 'Animation' changed to 'ommqttkinn'
# row: 139 col: 2 : 'Drama' changed to 'Xfq'
# row: 651 col: 2 : 'Hentai' changed to 'eegii'
# row: 745 col: 2 : 'Historical' changed to 'HHozttiekccsll'
# row: 315 col: 2 : 'Animation,Short,Fantasy' changed to 'AAkriioo,,SSooett,,Rnnqyy'
# row: 1182 col: 2 : 'Action,Sci-Fi,SuperPower' changed to 'xinn,,SSuFFk,,ZyorrO'
# row: 1245 col: 2 : 'Animation,Comedy' changed to 'Qnnkqynnoommeeddu'
# row: 128 col: 2 : 'Kids' changed to 'KKxss'
# row: 1049 col: 2 : 'Adventure,Comedy,Fantasy,Magic' changed to 'ddnnttuuee,,pde,,Rsnnyqyyaaggkv'
# row: 1166 col: 2 : 'Short' changed to 'hhfr'
# row: 14 col: 2 : 'Comedy,Kids' changed to 'oommwyyuddss'
# row: 609 col: 2 : 'Hentai' changed to 'Jeettaa'
# row: 709 col: 2 : 'Animation,Drama,Romance,Sci-Fi' changed to 'maattkim,,DDrrsq,,RRmmnnxeeSSiiGk'
# row: 1578 col: 2 : 'Animation,Adventure,Comedy,Fantasy' changed to 'mummiii,,ddbeemfeeimmyy,,aabgaadu'
# row: 1043 col: 2 : 'Comedy' changed to 'CCeedd'
# row: 242 col: 2 : 'Action,Animation,Sci-Fi' changed to 'ccgopbksttoonnccii--o'
# row: 1064 col: 2 : 'Drama' changed to 'Ftqmmaa'
# row: 988 col: 2 : 'Fantasy,Magic,Shounen' changed to 'Csssyyhucc,,SSoobee'
# row: 88 col: 2 : 'Comedy,Drama,Seinen' changed to 'Vmmrsyy,,DDfaaseeiinnwj'
# row: 1282 col: 2 : 'Animation,Sci-Fi' changed to 'nniiaayiioo,,SS--FFii'
# row: 255 col: 2 : 'Short,Sci-Fi' changed to 'SSjoorSSxk--FF'
# row: 637 col: 2 : 'Hentai' changed to 'Jeettsii'
# row: 127 col: 2 : 'Animation,Action,Comedy' changed to 'bmmiioonn,,cci,,CCidfyy'
# row: 1400 col: 2 : 'Animation,Drama,Sport' changed to 'Qbiiqttooonn,,Seqaapptt'
# row: 587 col: 2 : 'School' changed to 'Afjll'
# row: 361 col: 2 : 'Comedy' changed to 'Xkeeeh'
# row: 1277 col: 2 : 'Animation,Comedy' changed to 'AAiimmqylnn,,Xooeeddyy'
# row: 1430 col: 2 : 'Hentai' changed to 'eejtt'
# row: 1080 col: 2 : 'Comedy,Parody,Sci-Fi' changed to 'CCkeeyy,,OaafooddZu--FF'
# row: 1559 col: 2 : 'Drama' changed to 'rraamm'
# row: 930 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Sjiikqgolnn,,XoommweyyrrqGnngaasshToonccee'
# row: 461 col: 2 : 'Action,MartialArts' changed to 'AAfttupnn,,aarrrota'
# row: 961 col: 2 : 'Action,Adventure,Comedy,Shounen' changed to 'ttuib,,Svvuur,,ndfyyuunnwj'
# row: 532 col: 2 : 'Fantasy,Kids' changed to 'FFaabttssyyiiess'
# row: 789 col: 2 : 'Hentai' changed to 'HHeeii'
# row: 615 col: 2 : 'Kids,Music' changed to 'KKiissMMuuii'
# row: 1551 col: 2 : 'Comedy,Romance,School' changed to 'VmmeetnnnccSSxook'
# row: 1264 col: 2 : 'Kids' changed to 'iifss'
# row: 555 col: 2 : 'Animation,Family,Sci-Fi' changed to 'Qbiimmrlb,,DaammktZx--D'
# row: 1464 col: 2 : 'Animation,Adventure,Fantasy' changed to 'QjnsgkoonnQeeuuewDbgssu'
# row: 1175 col: 2 : 'Comedy,Short' changed to 'CCkdt,,SSi'
# row: 848 col: 2 : 'Comedy' changed to 'Vieexyy'
# row: 1467 col: 2 : 'Hentai' changed to 'Beemaao'
# row: 1332 col: 2 : 'Comedy,Historical' changed to 'CClussttliiqk'
# row: 166 col: 2 : 'Animation,Action,Adventure,Family,Mystery,Thriller' changed to 'Siimmrlnn,,Qfu,,Sxgbttee,,FFqllu,,ywthGhhiiokeet'
# row: 1111 col: 2 : 'Comedy,Magic,Parody' changed to 'leyy,,Kqggii,,Oqooddyy'
# row: 1597 col: 2 : 'Comedy,Parody' changed to 'oommwxyyOrr'
# row: 646 col: 2 : 'Historical' changed to 'kpfiifqll'
# row: 272 col: 2 : 'Animation,Crime,Drama,Fantasy,Mystery,Thriller' changed to 'AAummiipw,,DDeaammaaDqjttaawMMussttdeh,,jrrof'
# row: 514 col: 2 : 'Fantasy,Kids' changed to 'FFaanngyyMiidda'
# row: 118 col: 2 : 'Action,Adventure,Drama,Fantasy,Historical,Shounen,Supernatural' changed to 'gii,,AAxeeguueeaammq,,Raattaass,,ossiccaaoZgibSSjowrrnnsttyeaall'
# row: 620 col: 2 : 'Animation,Action,Comedy' changed to 'Snnmmaaiioo,,AAcciij,,ikh'
# row: 928 col: 2 : 'Action' changed to 'Sccttlnn'
# row: 601 col: 2 : 'Hentai' changed to 'btt'
# row: 1124 col: 2 : 'Short,Animation' changed to 'SSlrrAAoaaiib'
# row: 1314 col: 2 : 'Animation,Comedy,Romance' changed to 'AAnniimmiilnnoommookccee'
# row: 856 col: 2 : 'Short' changed to 'SShher'
# row: 723 col: 2 : 'Animation,Adventure,Fantasy,Romance' changed to 'Qiisuoo,,gwuurree,,FFqmqssh,,Tlnaannf'
# row: 964 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'SbmmroiAAccpeemuurrd--Rii'
# row: 413 col: 2 : 'Comedy' changed to 'Fmmyy'
# row: 1279 col: 2 : 'Action,Psychological,Shounen,Supernatural,Thriller' changed to 'Qccl,,ztxoophiixaaojuubdnn,,orrirrqllYjrriiollrf'
# row: 1029 col: 2 : 'Adventure,Family,Fantasy' changed to 'AAddvvwjttrrd,,FFaammiiot,,FFmttaaa'
# row: 524 col: 2 : 'Fantasy,Kids' changed to 'FFsnnttsh,,Iiiez'
# row: 1193 col: 2 : 'Music' changed to 'izo'
# row: 1507 col: 2 : 'Short' changed to 'SSrr'
# row: 1454 col: 2 : 'Animation,Comedy' changed to 'miimmyoF'
# row: 1322 col: 2 : 'Drama,SliceofLife' changed to 'ns,,SSkiiccwgiir'
# row: 72 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Shounen' changed to 'AAvvnnruurrl,,Djttaassyyii,,juumeenn'
# row: 1377 col: 2 : 'Fantasy,Romance,SliceofLife' changed to 'sttaat,,ToommqnnccSSkccffKiiff'
# row: 348 col: 2 : 'Animation' changed to 'Sjiinaaiioob'
# row: 307 col: 2 : 'Comedy' changed to 'CCpmmre'
# row: 494 col: 2 : 'Adventure,Comedy,Kids,Magic' changed to 'SxvvjuuwFnrddkddss,,MMsvkcc'
# row: 1598 col: 2 : 'Comedy,Parody' changed to 'Xookweh,,Oqrrlu'
# row: 634 col: 2 : 'Adventure,Drama,Fantasy,Horror,Shounen,Supernatural,Vampire' changed to 'QfeeifwDDrraa,,FFnnttaass,,rre,,hhoomwbAjwnnqeaallVVaakou'
# row: 1409 col: 2 : 'Comedy,Sci-Fi' changed to 'pmmrddyy,,SSccGu'
# row: 1129 col: 2 : 'Comedy,Mecha,Military,Sci-Fi' changed to 'Vooneedd,,KeehhaaKullttaaetkRii'
# row: 664 col: 2 : 'Drama,Kids' changed to 's,,KKiidd'
# row: 872 col: 2 : 'Kids,Music' changed to 'IeNyiicc'
# row: 1237 col: 2 : 'Action,Adventure,Mystery,Sci-Fi' changed to 'QvttiilbAAddcdmttuurr,,KtyduAcc--ii'
# row: 183 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'AAiikeennyuueeFFqkknngaaz'
# row: 957 col: 2 : 'Romance' changed to 'RRiqmv'
# row: 1132 col: 2 : 'Animation,Comedy' changed to 'Siimmsoi,,oommrxu'
# row: 41 col: 2 : 'Action,Adventure,Horror,Mystery,Sci-Fi,War' changed to 'AAcciioom,,Qevvrnnyyrrwfp,,NhdrwuSScciiFFiiEaa'
# row: 722 col: 2 : 'Animation,Short' changed to 'Qiikaagpnn,,Whhlg'
# row: 592 col: 2 : 'Comedy,Kids' changed to 'ooLudd'
# row: 948 col: 2 : 'Action,Drama,Mecha,Military,School,Supernatural' changed to 'Qttiioonn,,DDnsdccjaa,,oosyy,,vDiowbgaak'
# row: 1191 col: 2 : 'Harem,Romance,Shoujo' changed to 'aafwmmRRnsxeeSSpu'
# row: 1183 col: 2 : 'Action,Comedy,Horror,Shounen,Supernatural' changed to 'Qxyiij,,VuBootl,,SSyy,,Zuuppwrrnnitaak'
# row: 491 col: 2 : 'Comedy,Kids' changed to 'CCookeeddyyoddss'
# row: 265 col: 2 : 'Adventure,Kids' changed to 'fbeebjeeeddw'
# row: 323 col: 2 : 'Animation' changed to 'Qnniiqttulnn'
# row: 557 col: 2 : 'Music' changed to 'MMjsscc'
# row: 847 col: 2 : 'Music' changed to 'uuii'
# row: 1061 col: 2 : 'Sport' changed to 'oler'
# row: 469 col: 2 : 'Animation,Short' changed to 'mkqgiinnirr'
# row: 154 col: 2 : 'Documentary,Short' changed to 'DDuunnraafyy,,SSbly'
# row: 1118 col: 2 : 'Animation' changed to 'bummqttop'
# row: 760 col: 2 : 'Hentai,School' changed to 'Ynntt,,ccoooo'
# row: 1290 col: 2 : 'Adventure,Mystery' changed to 'Qevvmyie,,yyeerru'
# row: 1519 col: 2 : 'Comedy,Drama,Fantasy,Music' changed to 'CCoodeu,,DDaa,,qmttsstuuux'
# row: 1475 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'AAjommsgj,,AAyoom,,pmmee,,Db,,ccii'
# row: 228 col: 2 : 'Historical,Romance,Shoujo,Supernatural' changed to 'agevaaEoommnnee,,SSjooih,,SSuuppdmsrqk'
# row: 979 col: 2 : 'Animation,Action,Fantasy,Sci-Fi' changed to 'SnnmmbAAfgiiooFFaannttsyy,,iiDii'
# row: 625 col: 2 : 'Animation,Biography,Drama,History,Romance,War' changed to 'ksttii,,Huphrraapp,,SqkaaHHozrootuEpaabveeWWs'
# row: 1570 col: 2 : 'Action,Demons,Ecchi,Fantasy,Harem,Romance' changed to 'Qccttoonn,,DDwnpjwEEg,,FFaannyssyyaarree,,RRooqccd'
# row: 1098 col: 2 : 'Fantasy,Kids' changed to 'Gnnsss,,KKw'
# row: 954 col: 2 : 'Adventure,Comedy,Magic' changed to 'AAfeettitee,,CCoommees,,fkcc'
# row: 834 col: 2 : 'Action,Family,Adventure,Comedy,Fantasy' changed to 'SttuDaauAAceejttuud,,Vmmdd,,aattsu'
# row: 657 col: 2 : 'Drama,Music' changed to 'fmm,,Kju'
# row: 734 col: 2 : 'Comedy' changed to 'keeyy'
# row: 810 col: 2 : 'Animation' changed to 'bukttk'
# row: 942 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'nniikylmAAyiinn,,pmmeeeyy,,DnnqzyyRRimmaaccee'
# row: 370 col: 2 : 'Drama,Fantasy,Sci-Fi,Thriller' changed to 'smm,,aagaassyy,,SSxuFFohhtiiolldf'
# row: 940 col: 2 : 'Comedy' changed to 'ooddh'
# row: 390 col: 2 : 'Kids,Music' changed to 'Ikw,,iicc'
# row: 102 col: 2 : 'Comedy,Fantasy,Kids' changed to 'oommdxu,,qt,,Lua'
# row: 419 col: 2 : 'Comedy,Fantasy,Kids' changed to 'CCnwh,,FFaannrssyy,,KKddss'
# row: 78 col: 2 : 'Action,Comedy,Ecchi,Harem,Romance,Supernatural' changed to 'SvooonnCCneeddh,,fhhii,,Gqrree,,FooaarWimsttaall'
# row: 211 col: 2 : 'Animation,Comedy,Fantasy' changed to 'AAnnuaariip,,CCnrdd,,Gaaaad'
# row: 324 col: 2 : 'Adventure,Drama,Sci-Fi' changed to 'Sevveeuufr,,DDqSScc--'
# row: 1125 col: 2 : 'Drama' changed to 'DDaa'
# row: 663 col: 2 : 'Animation,Short' changed to 'AAmkttiinn,,rrtt'
# row: 1287 col: 2 : 'Comedy,Ecchi,SliceofLife' changed to 'Xpneefvjo,,SSllccdlffrd'
# row: 99 col: 2 : 'Hentai' changed to 'HHwnnii'
# row: 1130 col: 2 : 'Comedy,Fantasy,Music' changed to 'lmmeedd,,FFKjwiicc'
# row: 177 col: 2 : 'Mecha,Parody,Sci-Fi' changed to 'MMx,,PPsrrihcciiFFii'
# row: 1026 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'iiqnnQccibSsvvjgjed,,snnaayy,,ii--iitoof'
# row: 1497 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'AAkmmqpnn,,Sxiipnn,,Xrraa,,Ao--FFo'
# row: 1128 col: 2 : 'Animation,Short' changed to 'AAbummqiiSSgooy'
# row: 619 col: 2 : 'Comedy,Drama,Ecchi,Romance,Sci-Fi' changed to 'Vikeeddeqs,,EEvo,,Tmmnnee,,--FF'
# row: 795 col: 2 : 'Comedy,SliceofLife' changed to 'Xmmeeh,,ZlluxdiLLuffr'
# row: 548 col: 2 : 'Animation,Horror' changed to 'AAnniikaarj,,HHrrrr'
# row: 776 col: 2 : 'Animation,Action,Comedy,Crime,Fantasy,Horror,Mystery' changed to 'nnkaattuoonnAAiil,,Fookdddu,,ekmmdaannttsstteoorr,,ussgdyy'
# row: 1256 col: 2 : 'Action,Fantasy,Magic,Shounen' changed to 'ttoj,,yzt,,MMaacc,,hhooynn'
# row: 662 col: 2 : 'Action,Adventure,Seinen' changed to 'Sccttii,,Qddgeennrrr,,ujeem'
# row: 1565 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'nnuriipnnAAfttoonn,,AAxeettuurr,,FFnnysZii--o'
# row: 652 col: 2 : 'Animation,Comedy' changed to 'nniisttoob,,CCidd'
# row: 976 col: 2 : 'Animation,Comedy,Drama,Sport' changed to 'AAommqgjCCrh,,smm,,SSorrr'
# row: 1479 col: 2 : 'Hentai' changed to 'Bbso'
# row: 148 col: 2 : 'Action,Comedy,Ecchi' changed to 'cciinn,,Vddt,,Dfcck'
# row: 144 col: 2 : 'Action,Adventure,Animation,Sci-Fi,Thriller' changed to 'AAxgum,,ddbwttuut,,AAmiimmyooobcckk,,TTfklldt'
# row: 712 col: 2 : 'Hentai' changed to 'eennqii'
# row: 829 col: 2 : 'Action,Crime,Drama,Sci-Fi' changed to 'QccttunnXrro,,tmm,,ccu'
# row: 476 col: 2 : 'Documentary' changed to 'ooccuumttqfu'
# row: 577 col: 2 : 'Animation,Action,Sci-Fi' changed to 'iinqgnn,,oomWfo'
# row: 437 col: 2 : 'Kids' changed to 'KKddss'
# row: 256 col: 2 : 'Animation' changed to 'Qjnsyoi'
# row: 972 col: 2 : 'Drama,Josei,Romance' changed to 'rrnHwwk,,immnnx'
# row: 980 col: 2 : 'Animation,Adventure,Comedy,Drama,Fantasy,Sci-Fi' changed to 'mkmmqyi,,AAeyir,,yy,,DDrraanFFqaawyyDfo--FFii'
# row: 169 col: 2 : 'Animation,Short,Horror' changed to 'AAoaariilnn,,g,,rrfirr'
# row: 801 col: 2 : 'Action,Historical,Military,SuperPower' changed to 'AAiipGoreaaKiilliig,,uuwOiqw'
# row: 885 col: 2 : 'Adventure,Kids' changed to 'svveenniewKKiis'
# row: 47 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'baattooCCmmxyyDfoii'
# row: 626 col: 2 : 'Adventure' changed to 'ddvveennyfw'
# row: 859 col: 2 : 'Animation,Short' changed to 'siiinn,,Zhhoorrr'
# row: 1293 col: 2 : 'Animation,Comedy,Sport' changed to 'AAmmaagoonn,,CCnddd,,Zppp'
# row: 1085 col: 2 : 'Animation' changed to 'AAmmmstt'
# row: 347 col: 2 : 'Hentai' changed to 'mtt'
# row: 1492 col: 2 : 'Animation,Sci-Fi' changed to 'AAkyiiooSSfR'
# row: 1113 col: 2 : 'Animation,Family,Fantasy' changed to 'Snniiqttkpj,,FFmmk,,aabttsw'
# row: 1047 col: 2 : 'Animation,Short,Action,Adventure,Drama,Fantasy,Sci-Fi' changed to 'jiiit,,AAgonnddeet,,SemmRsgqssh,,--Rk'
# row: 1010 col: 2 : 'Animation' changed to 'nnokaattiinn'
# row: 67 col: 2 : 'Drama' changed to 'fk'
# row: 1226 col: 2 : 'Animation,Action,Adventure' changed to 'AAnniiqnnSfttiiinn,,Qsvveennttit'
# row: 1038 col: 2 : 'Adventure,Fantasy' changed to 'Snnuuer,,Caaraazyy'
# row: 1022 col: 2 : 'Hentai' changed to 'HHrrii'
# row: 325 col: 2 : 'Drama,Supernatural,Thriller' changed to 'XqksAuudbgyqll,,TTrrorr'
# row: 925 col: 2 : 'Comedy,Drama,Romance,Shounen' changed to 'ooweyyDDsaaEoommmvSSyooj'
# row: 901 col: 2 : 'Animation' changed to 'jkqiinn'
# row: 558 col: 2 : 'Kids' changed to 'Iddss'
# row: 1413 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'AAnnaaribSvttii,,Sevveegjtee,,FFaayaass'
# row: 208 col: 2 : 'Adventure,Drama,Historical,Romance' changed to 'AAddeeyuueeDDrrmmqJiiitvooommf'
# row: 890 col: 2 : 'Drama' changed to 'Fsmmaa'
# row: 1228 col: 2 : 'Hentai' changed to 'HHeettii'
# row: 653 col: 2 : 'Comedy,Drama,Romance' changed to 'XineeddErrssmmsw'
# row: 1295 col: 2 : 'Animation,Action,Drama' changed to 'AAkksgiiinn,,ccttk,,DDrrsaa'
# row: 21 col: 2 : 'Action,Comedy,SuperPower' changed to 'xyljCCmmeeft,,SSjppeePPlf'
# row: 1443 col: 2 : 'Animation,Short,Fantasy' changed to 'SiimmriilmSSyett,,aabttsw'
# row: 1301 col: 2 : 'Drama' changed to 'Fqmmaa'
# row: 1156 col: 2 : 'Action,Mecha,Sci-Fi,Shounen' changed to 'AAccttiipbeeccyaa,,vu--ginnee'
# row: 486 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'ddcnnuuCCiwdd,,Ziicceeooiigee'
# row: 482 col: 2 : 'Short,Animation,Sci-Fi' changed to 'Whhprr,,Qiimmaarupj,,cc--ii'
# row: 1540 col: 2 : 'Animation,Adventure' changed to 'QiimmqymSddwnnttrr'
# row: 153 col: 2 : 'Crime,Drama,Mystery' changed to 'er,,DDeaasNeyy'
# row: 141 col: 2 : 'Reality-TV' changed to 'Twg'
# row: 579 col: 2 : 'Drama' changed to 'aaaa'
# row: 841 col: 2 : 'Comedy,Parody' changed to 'lnyyPPsrrddh'
# row: 963 col: 2 : 'Comedy' changed to 'oonf'
# row: 515 col: 2 : 'Hentai' changed to 'mttaau'
# row: 1036 col: 2 : 'Animation,Short' changed to 'iiaattiilboorrg'
# row: 132 col: 2 : 'Action,Animation,Sci-Fi' changed to 'AAmAAkmmqgiiiSScck--FFo'
# row: 673 col: 2 : 'Action,Adventure,Game,Mecha,Sci-Fi,Shounen' changed to 'SccoonnQfvvjrfw,,FsneeNeecchhaa,,SScc,,SSbpuunneej'
# row: 406 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'ddvveebyjeeVoondxyy,,vii--Gii,,bluunnwm'
# row: 507 col: 2 : 'Animation,Comedy' changed to 'mummsrnn,,Fpk'
# row: 340 col: 2 : 'Animation,Action,Comedy,Romance,Sci-Fi' changed to 'AAkmmaagii,,Siioopmmeeyy,,pnee,,cciiFF'
# row: 1469 col: 2 : 'Comedy,Sports' changed to 'XeehWooottss'
# row: 716 col: 2 : 'Hentai' changed to 'HHnnaa'
# row: 136 col: 2 : 'Animation,Adventure,Family,Fantasy,Mystery' changed to 'Qkmmqtti,,wyrrw,,FFaakllu,,jqssyyyywydt'
# row: 457 col: 2 : 'Action,Adventure,Comedy,Mecha,Sci-Fi' changed to 'SccttulnnQwrrr,,CCmmrddhKWcciiFF'
# row: 543 col: 2 : 'Hentai' changed to 'eejtto'
# row: 544 col: 2 : 'Drama,Kids' changed to 'DDsmmdd'
# row: 806 col: 2 : 'Comedy' changed to 'Fikeeddyy'
# row: 1267 col: 2 : 'SliceofLife' changed to 'AowlffOiiffd'
# row: 658 col: 2 : 'Animation,Action,Adventure,Comedy,Crime' changed to 'Qiinyk,,Qcck,,Qsgdmyjoonddyyfund'
# row: 1473 col: 2 : 'Comedy,Police' changed to 'CCoonwx,,PPoolloccd'
# row: 1299 col: 2 : 'Animation,Comedy' changed to 'AAnniinaayVmmrddt'
# row: 1251 col: 2 : 'Animation,Comedy,Fantasy' changed to 'yunnlkdyysjraassh'
# row: 1135 col: 2 : 'Comedy' changed to 'Fneeyy'
# row: 1556 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'jiinaatti,,Xee,,CaajraassyyToonsm'
# row: 621 col: 2 : 'Kids,Shoujo,Supernatural' changed to 'LiissDpuuk,,Ayppnnttyeqll'
# row: 1536 col: 2 : 'Adventure' changed to 'wnnyrree'
# row: 1440 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'ddceettif,,CCimmeeddtaattyy,,Iiiss'
# row: 1552 col: 2 : 'Animation,Action,Crime,Sci-Fi' changed to 'kaariioonn,,AAxgooo,,CCk,,SSfu--ii'
# row: 426 col: 2 : 'SliceofLife,Supernatural' changed to 'SSiiccLLw,,SSuufnnf'
# row: 1052 col: 2 : 'Animation,Drama,History,Romance' changed to 'nnummttiiooFaak,,kttrr,,RRoommqjcc'
# row: 1225 col: 2 : 'Animation,Action,Fantasy,Mystery' changed to 'monsiioonn,,AAccrFFmyzyy,,MMr'
# row: 1310 col: 2 : 'Fantasy,Music' changed to 'Cgat,,Nuussiiv'
# row: 1365 col: 2 : 'Animation,Short,Adventure' changed to 'AAonttooAlrr,,AAddeennrytd'
# row: 1260 col: 2 : 'Action,Drama,Mecha,Military,Sci-Fi' changed to ',,XtqmmsNeehh,,Kkuyrryy,,f--Ck'
# row: 1012 col: 2 : 'Comedy,Military' changed to 'kddtkkiiaarrt'
# row: 439 col: 2 : 'Harem,Hentai' changed to 'BaaeemmGeejaak'
# row: 508 col: 2 : 'Adventure,Animation' changed to 'Qxceejyrreeboaariioo'
# row: 1141 col: 2 : 'Hentai' changed to 'dbqu'
# row: 627 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,Romance,Thriller' changed to 'Qbkgkoom,,AAccttk,,AAddmuueeFookuErrqkaamttaadt,,kssttthFoommee,,Yhhollw'
# row: 1441 col: 2 : 'Drama,Fantasy,Harem,Romance,Shoujo' changed to 'Xaa,,FFqnnyaassyysrrrk,,Fookaannhhoouu'
# row: 997 col: 2 : 'Action,Adventure,Fantasy,Game' changed to 'AAcciiij,,gir,,nngs,,ee'
# row: 600 col: 2 : 'Comedy,Seinen,Space' changed to 'CCoommryy,,eeiibeeb,,Dccd'
# row: 1002 col: 2 : 'Animation,Action,Fantasy' changed to 'nnugiiim,,SiiooCaanngaa'
# row: 1487 col: 2 : 'Hentai' changed to 'wttaao'
# row: 929 col: 2 : 'Animation,Adventure,Fantasy' changed to 'nniittooob,,Sevvwnnuurree,,snnyqssyy'
# row: 1319 col: 2 : 'Animation,Action,Fantasy' changed to 'jkmmsykoonnAAccii,,FFaannaadh'
# row: 401 col: 2 : 'Music' changed to 'Nyk'
# row: 496 col: 2 : 'Action,Fantasy,ShounenAi,SuperPower,Supernatural' changed to 'ttoonn,,FFaassyy,,DhhoouunneennQkAOpwweerrSSuuwfnntteqll'
# row: 412 col: 2 : 'Drama,Shounen,Sports' changed to 'esZhhi,,ooofrss'
# row: 781 col: 2 : 'Animation' changed to 'AAnnogiinn'
# row: 16 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Horror,War' changed to 'AAmmaattinn,,AAxyuoojSvvwttuurrdDDq,,CaadtrrfirrQaaf'
# row: 793 col: 2 : 'Animation' changed to 'nnkmmttiilb'
# row: 575 col: 2 : 'Animation,Comedy,Drama' changed to 'bgooCClkuFenaa'
# row: 477 col: 2 : 'Demons,Fantasy,Hentai,Supernatural' changed to 'DDeebw,,FFaabgsyy,,HHeejgs,,iorebqyk'
# row: 95 col: 2 : 'Animation,Short,Comedy' changed to 'jaattunnSSett,,CClmmeeyy'
# row: 409 col: 2 : 'Fantasy,Action,Adventure' changed to 'bttaawh,,Sccgiioonn,,AAsnnrj'
# row: 1276 col: 2 : 'Hentai' changed to 'Brnnttaak'
# row: 1162 col: 2 : 'Action,Comedy,MartialArts,School,Shounen' changed to 'Sccttj,,FoommddyyqrrllQtta,,hhoollhhinnr'
# row: 452 col: 2 : 'Animation,Family,Fantasy' changed to 'jiimmaattiioob,,FFsiiDaamysyy'
# row: 1421 col: 2 : 'Magic' changed to 'qox'
# row: 364 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy' changed to 'AAjunaagooQxriioomVoodd,,Xfaan,,Gm'
# row: 603 col: 2 : 'Adventure' changed to 'Svvrttfr'
# row: 1435 col: 2 : 'Music' changed to 'Ksskcc'
# row: 1438 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Sbommqttlnn,,CCooeeddyy,,qmmsRRnaab'
# row: 730 col: 2 : 'Action,Military,Romance' changed to 'vgookkrqrr,,Tikaannf'
# row: 702 col: 2 : 'Short,Comedy' changed to 'ZoottCCoorddyy'
# row: 204 col: 2 : 'Action,Adventure,Comedy,Kids' changed to 'AAxttoonn,,Qddbdjyrrw,,CCoommshKKkdda'
# row: 951 col: 2 : 'Action,Adventure,Crime,Drama,Mystery' changed to 'ttuoo,,AAddvveemjrr,,X,,DDfaaNyytt'
# row: 960 col: 2 : 'Music' changed to 'uussiicc'
# row: 1254 col: 2 : 'Animation,Short,Music' changed to 'bokaannSShhpfyKak'
# row: 596 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'nttkoo,,Errqk,,FFnnttsayyWo--FF'
# row: 428 col: 2 : 'Comedy,Historical' changed to 'ooeeddukssttooeccaa'
# row: 282 col: 2 : 'Action,Fantasy,Shounen,SuperPower,Supernatural,Vampire' changed to 'AAyb,,aagswyy,,SSoouunn,,ZjoeePPooeee,,SSuuppdfnnuuesaanfee'
# row: 396 col: 2 : 'Animation,Action,Adventure' changed to 'iimmriioottuoonn,,ddtteee'
# row: 1247 col: 2 : 'Drama' changed to 'Xtmmq'
# row: 1488 col: 2 : 'Animation,Action,Drama' changed to 'ukttiioonn,,yu,,DDrrqmms'
# row: 911 col: 2 : 'Romance' changed to 'RRookqbw'
# row: 755 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'AAnniioo,,rrmmaaqss,,SSccii--FF'
# row: 854 col: 2 : 'Adventure' changed to 'Sddcdnnyuufd'
# row: 1420 col: 2 : 'Action,Comedy,Fantasy,Magic,Mecha,Sci-Fi,Shounen' changed to 'AAklmVpnrddRaamysss,,Nqgg,,MMeehh,,SSxkFFk,,SShhljb'
# row: 54 col: 2 : 'Action' changed to 'AAyoj'
# row: 285 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'nnommsyiioonnddrnnttirreeFFaammiiqss'
# row: 959 col: 2 : 'Crime' changed to 'Frrkee'
# row: 1229 col: 2 : 'Animation,Short,Comedy,Crime,Fantasy' changed to 'Sknsrj,,SSlfVdddhCCrrmmr,,jssyy'
# row: 522 col: 2 : 'Animation,Short' changed to 'iinyhhoof'
# row: 926 col: 2 : 'Comedy,Drama,Romance' changed to 'CCooneexyy,,DDrraas,,aamccw'
# row: 30 col: 2 : 'Comedy,Ecchi,Magic,Parody,Vampire' changed to 'FneetDxyoMMaav,,PPqooh,,Cskfw'
# row: 676 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'AAnnoaariibQfiioonn,,XqZDii'
# row: 1522 col: 2 : 'Drama,Romance,Yaoi' changed to 'DDkFpqccee,,k'
# row: 780 col: 2 : 'Action,Sci-Fi' changed to 'AAccoooccu--'
# row: 273 col: 2 : 'Hentai' changed to 'aaii'
# row: 253 col: 2 : 'Animation,Short' changed to 'SnnoaattnnSSyoorry'
# row: 654 col: 2 : 'Animation' changed to 'nnommgnn'
# row: 197 col: 2 : 'Action,Fantasy,Mecha,Sci-Fi' changed to 'AAvtto,,saayyNvcc--Gii'
# row: 1553 col: 2 : 'Animation,Adventure,Family,Fantasy,Sci-Fi' changed to 'QkaattunnAAeerreesniiou,,ttaaSSccuRii'
# row: 85 col: 2 : 'Hentai' changed to 'HHdnnyqii'
# row: 143 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'evveemyuuCCmmfyyZo--FFiiDhhooj'
# row: 60 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Qddggjrr,,qnnq,,iisd'
# row: 1477 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'iimmqriijAAvveejtttd,,FFyyDbsu'
# row: 695 col: 2 : 'Drama' changed to 'rrs'
# row: 708 col: 2 : 'Action,Drama,Fantasy,Mystery,Sci-Fi' changed to 'AAyiioojFrrmmqFFaabttaawMMdeerruSSxuRk'
# row: 531 col: 2 : 'Documentary,Animation,Short,History' changed to 'Foocceettt,,mksttkpnn,,WhhpttHHgptyy'
# row: 157 col: 2 : 'Animation,Comedy' changed to 'QbiittooVookrdd'
# row: 314 col: 2 : 'Adventure,Sci-Fi' changed to 'snnguurree,,Afu--FFk'
# row: 1496 col: 2 : 'Short' changed to 'Dhh'
# row: 1504 col: 2 : 'Drama' changed to 'Fsmmaa'
# row: 802 col: 2 : 'Documentary' changed to 'ccwttaae'
# row: 239 col: 2 : 'Hentai' changed to 'Ywbyqk'
# row: 475 col: 2 : 'Short' changed to 'bltt'
# row: 133 col: 2 : 'Animation,Action,Drama,Fantasy,Mystery' changed to 'nnknqnnAAttnn,,DDfmmCsbttaasst,,yyssttrryy'
# row: 1481 col: 2 : 'Hentai' changed to 'eennyaa'
# row: 766 col: 2 : 'Comedy,Military' changed to 'ooneeyy,,MMklliiysrrt'
# row: 898 col: 2 : 'SliceofLife' changed to 'Aoflr'
# row: 1546 col: 2 : 'Ecchi,Music' changed to 'EEccyk,,j'
# row: 1534 col: 2 : 'Drama' changed to 'e'
# row: 276 col: 2 : 'Drama,Military,Sci-Fi,Space' changed to 'eqmmqMMkrq,,iiRAr'
# row: 1262 col: 2 : 'Comedy,Drama,Josei,Romance,SliceofLife' changed to 'ooeexfnaaHoossRRmmsccrocceeooKree'
# row: 432 col: 2 : 'Animation,Action,Adventure,Drama,Fantasy,Mystery' changed to 'SbaattmQxttoonnddvvnnr,,rrmm,,FFqttaassh,,MMssyrrh'
# row: 677 col: 2 : 'Animation,Short' changed to 'AAmqgp,,SSb'
# row: 1160 col: 2 : 'Animation,Adventure,Family,Sci-Fi' changed to 'nnmmqypbQddbryeee,,DmmiiotcckCii'
# row: 1491 col: 2 : 'Sci-Fi' changed to 'Zfii--ii'
# row: 187 col: 2 : 'Drama' changed to 'DDrraak'
# row: 686 col: 2 : 'Comedy,Drama' changed to 'ookxyyDDtqmms'
# row: 1266 col: 2 : 'Action,Adventure,Sci-Fi' changed to 'roonnAAgdmrtrDkG'
# row: 863 col: 2 : 'Animation,Short,Comedy' changed to 'mmmsttiip,,pgCClmmddyy'
# row: 952 col: 2 : 'Harem,Hentai' changed to 'HHsrreemmJd'
# row: 1471 col: 2 : 'Comedy,Drama,SliceofLife,Supernatural' changed to 'nryy,,rraakaaxcLLiiw,,uueetnnqttuuaao'
# row: 1249 col: 2 : 'Reality-TV' changed to 'RReeotttTTG'
# row: 372 col: 2 : 'Adventure,Sci-Fi,Sport' changed to 'AAvvrbreeeZu--FF,,SSppp'
# row: 342 col: 2 : 'Action,Adventure,Comedy,Fantasy,Shounen,SuperPower' changed to 'AAyii,,Qscwjttoommrftqbttaayy,,gjdnnieerrPPprrr'
# row: 941 col: 2 : 'Comedy,Parody,School' changed to 'eedd,,Osels,,Dhhooll'
# row: 811 col: 2 : 'Animation,Fantasy' changed to 'Qommqoo,,Cgqzyy'
# row: 1323 col: 2 : 'Animation' changed to 'ub'
# row: 1168 col: 2 : 'Drama,Family,Romance' changed to 'DDrrmmqkoyy,,Eoosnncc'
# row: 675 col: 2 : 'Sci-Fi' changed to 'ii--FF'
# row: 1294 col: 2 : 'Animation,Action,Fantasy' changed to 'jkmmqiiinnSiilmGaannttzyy'
# row: 1214 col: 2 : 'Short,Music,Sci-Fi' changed to 'SShhirrKiwuxSSccuFFo'
# row: 269 col: 2 : 'Action,Mecha,Sci-Fi,Space' changed to 'Qccoo,,MMeecchhcc,,ppaax'
# row: 1192 col: 2 : 'Action,Comedy,Ecchi,Romance,Sci-Fi' changed to 'Scciioom,,FookfyyDcciiooaannccr,,ii--'
# row: 1203 col: 2 : 'Action,Adventure' changed to 'AAcciim,,AAdddnnrfee'
# row: 499 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'cciioomAAvvnnrw,,aannyy,,Zhhuumd'
# row: 867 col: 2 : 'Animation' changed to 'nniimmiilnn'
# row: 550 col: 2 : 'Animation,Short,Drama,Music' changed to 'Qnnmmkyrrsmmaa,,MMuuof'
# row: 113 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'Qokaaroonnbeetttee,,Ax--Dii'
# row: 1020 col: 2 : 'Short,Drama' changed to 'rr,,n'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1545, 8025)
# (30, 8025)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\feature_selection\univariate_selection.py:299: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# (1545, 8024)
# (30, 8024)
# (1545, 700)
# (30, 700)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.07
# Mean squared error: 1.35
# Variance score: -17.89

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.10
# Mean squared error: 1.30
# Variance score: -16.62

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.9   0.931 0.981 0.952 0.862]
# Mean: 0.9251883382969499
# Standard deviation: 0.04093362419140034

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                   "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\pattern-3.6-py3.7.egg\pattern\text\en\..\..\..\..\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# best parameters are:  {'alpha': 0.01}
# The mean squared Error is: 0.84
