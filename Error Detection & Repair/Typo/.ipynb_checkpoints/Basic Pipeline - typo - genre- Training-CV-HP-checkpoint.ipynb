# %% [markdown]
# ## Import Data

# %%
import numpy as np
import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []


anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        item = np.nan
    else:    
        if "movie" in item:
            item = "movie"
        else:
            item = "tv series"
    l3.append(item)

    
    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Typo_Butterfingers(),75, ignored_columns = [0,1,3,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Typo_Butterfingers().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Typo_Butterfingers().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to Typo_Butterfingers method ---------------
#
# row: 1019 col: 2 : 'Animation' changed to 'Ahimaelln'
# row: 1505 col: 2 : 'Drama' changed to 'Gsxmx'
# row: 509 col: 2 : 'Animation' changed to 'Cnimatioh'
# row: 1200 col: 2 : 'Music' changed to 'Kuslc'
# row: 288 col: 2 : 'Historical' changed to 'Hnsfpvicwl'
# row: 454 col: 2 : 'Drama' changed to 'Drans'
# row: 1557 col: 2 : 'Animation,Action,Comedy,Drama,Sci-Fi' changed to 'Aiojqbjon,Zceimn,Eknedf,Sdaja,Aci-Gy'
# row: 649 col: 2 : 'Animation,Comedy,Drama' changed to 'Wgonajijt,Rimfdj,Aranq'
# row: 600 col: 2 : 'Animation,Drama' changed to 'Qhilwtjkn,Dxema'
# row: 1017 col: 2 : 'Drama,Historical,Music,Romance' changed to 'Drqms,Historizdp,Mksuc,Rknanba'
# row: 242 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Ahikztiun,Acguon,Sfi-Nu'
# row: 1514 col: 2 : 'Animation,Adventure,Action,Comedy,Sci-Fi' changed to 'Whmkatlun,Wdcznvyxa,Xeeiob,Somzdv,Sck-Dl'
# row: 1160 col: 2 : 'Action' changed to 'Zcgnoj'
# row: 1318 col: 2 : 'Crime,Mystery,Romance,Thriller' changed to 'Rrkmg,Mystefy,Rjleice,Gyrillxt'
# row: 403 col: 2 : 'Animation' changed to 'Ekjlcdilj'
# row: 1315 col: 2 : 'Hentai' changed to 'Hvhtam'
# row: 779 col: 2 : 'Animation,Sci-Fi' changed to 'Enimetipn,Xvp-Dl'
# row: 483 col: 2 : 'Action,Adventure,Comedy,Fantasy,Kids' changed to 'Wgbioj,Wbydiynwe,Cljeqy,Fanuawy,Npgs'
# row: 419 col: 2 : 'Kids,Music' changed to 'Kmga,Mhvlf'
# row: 873 col: 2 : 'Comedy,Parody' changed to 'Vlmefh,[wrmby'
# row: 405 col: 2 : 'Comedy,Kids,SliceofLife' changed to 'Comedj,Kmgr,SplzsmdOufc'
# row: 1234 col: 2 : 'Animation,Drama,Horror' changed to 'Anhlzthon,Dgana,Hpfxor'
# row: 310 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Whimatpoi,Cokedu,Fzubxrh'
# row: 731 col: 2 : 'Drama,Kids' changed to 'Dezlz,Kkef'
# row: 396 col: 2 : 'Animation,Short' changed to 'Annmaguon,Xgorb'
# row: 418 col: 2 : 'Animation,Action,Crime,Sci-Fi' changed to 'Aninaeiiv,Eftiln,Cvime,Scu-Fi'
# row: 1343 col: 2 : 'Comedy,Ecchi,Fantasy,Harem,Romance,School,Sci-Fi,Supernatural' changed to 'Ciigag,Wbwji,Gziuwvn,Kwdgm,Rmkzufe,Scyoou,Axi-Fn,Rulefnayugdp'
# row: 87 col: 2 : 'Hentai' changed to 'Rwbhzi'
# row: 219 col: 2 : 'Animation,Short' changed to 'Abklatiln,Dhort'
# row: 740 col: 2 : 'Hentai' changed to 'Hfvtsi'
# row: 920 col: 2 : 'Hentai' changed to 'Hevtai'
# row: 1049 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Anplavooj,Ccfiig,Esccitugs,Fauuqry'
# row: 1395 col: 2 : 'Documentary' changed to 'Dlfumzhdarj'
# row: 167 col: 2 : 'Animation,Drama,Romance' changed to 'Anuiztnon,Ccaoa,Donancv'
# row: 491 col: 2 : 'Comedy,Drama' changed to 'Cojddy,Egwna'
# row: 924 col: 2 : 'Comedy,Ecchi,Romance,Shounen,Supernatural,Vampire' changed to 'Goltdr,Fcbmi,Rloqjct,Srojnen,Suiesnctjvcj,Dckpoge'
# row: 158 col: 2 : 'Mystery,Shounen' changed to 'Igstffj,Vymunft'
# row: 547 col: 2 : 'Comedy' changed to 'Comeei'
# row: 1174 col: 2 : 'Drama,Sci-Fi,Space' changed to 'Dgdia,Sbl-Fm,R[zze'
# row: 1280 col: 2 : 'Comedy,Kids' changed to 'Colebi,Ilav'
# row: 1511 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Svkmqtiou,Comadb,Scj-Fo'
# row: 834 col: 2 : 'Action,Crime,Drama,Sci-Fi' changed to 'Acfion,Xrlmt,Dramw,Vcu-Fi'
# row: 582 col: 2 : 'Animation' changed to 'Wtinajmkh'
# row: 1230 col: 2 : 'Adventure,Comedy,Ecchi,Fantasy,Magic,School' changed to 'Aqvemfjre,Dokecy,Tcvhi,Hcntasy,Mzgic,Rvykou'
# row: 526 col: 2 : 'Comedy,Romance,School' changed to 'Vuiefj,Eolanbx,Xcjoml'
# row: 258 col: 2 : 'Comedy' changed to 'Cimcvg'
# row: 546 col: 2 : 'Animation,Short,Music' changed to 'Snjmaeilb,Xkort,Mhwlc'
# row: 1527 col: 2 : 'Animation,Short,Action,Comedy,Sci-Fi' changed to 'Cjmmsvlov,Shirg,Czfimh,Gomedh,Scj-Vu'
# row: 818 col: 2 : 'Animation,Sci-Fi' changed to 'Zkpkadkou,Del-Fn'
# row: 1522 col: 2 : 'Comedy' changed to 'Cokrfb'
# row: 558 col: 2 : 'Animation,Action,Drama' changed to 'Cnimafioh,Actuoj,Dgama'
# row: 140 col: 2 : 'Animation,Comedy,Romance' changed to 'Qbmowtion,Dmmadb,Glizkcc'
# row: 1587 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Abloxtuok,Dulvdy,Vwncasv,Goienxe'
# row: 1309 col: 2 : 'Documentary,Mystery,News,Sci-Fi' changed to 'Vjzkozbeqxg,Kidjeri,Tewa,Afn-Fk'
# row: 468 col: 2 : 'Drama,Fantasy,Kids' changed to 'Cramq,Wabbary,Kyqd'
# row: 1314 col: 2 : 'Documentary,Short,Biography' changed to 'Dockmeigasy,Shidt,Bolgta[hy'
# row: 1093 col: 2 : 'Animation,Comedy,Drama' changed to 'Snoiajhmi,Gomsar,Scaka'
# row: 66 col: 2 : 'Animation,Family,Sci-Fi' changed to 'Xnikwfiun,Hdjimy,Xbi-Fi'
# row: 1249 col: 2 : 'Fantasy,Kids' changed to 'Favredn,Ljgs'
# row: 1327 col: 2 : 'Action,Comedy,Ecchi,Romance,Sci-Fi' changed to 'Qceipn,Colfdu,Ezchl,Diiqhfc,Sci-Fi'
# row: 1490 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'Ebikxcyig,Wetnpk,Domebn,Swnywxy,Rvk-Si'
# row: 1103 col: 2 : 'Comedy,Parody,School' changed to 'Zjmqdb,Pweody,Sfhion'
# row: 37 col: 2 : 'Adventure,Drama,Space' changed to 'Advaktkrt,Etwla,Spsce'
# row: 537 col: 2 : 'Fantasy,Action,Adventure' changed to 'Dajtasj,Qbtkoj,Acrentmxc'
# row: 224 col: 2 : 'Fantasy,Music' changed to 'Dentqsh,Oixne'
# row: 986 col: 2 : 'Action,Drama,Horror' changed to 'Zgchov,Qrakc,Nlrfov'
# row: 36 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Anpjation,Asvanfurc,Family,Vwvtwsh'
# row: 1468 col: 2 : 'Short,Action,Sport' changed to 'Shldt,Actiou,Spptc'
# row: 529 col: 2 : 'Comedy,Fantasy' changed to 'Colrdy,Fentzsh'
# row: 1034 col: 2 : 'Kids,Music' changed to 'Ilgv,Kusjc'
# row: 171 col: 2 : 'Comedy,Parody' changed to 'Cokedj,Psrofy'
# row: 1565 col: 2 : 'Drama,Family,Romance' changed to 'Frema,Dcmimb,Wonamce'
# row: 1453 col: 2 : 'Comedy,School' changed to 'Romxvy,Fbhool'
# row: 1247 col: 2 : 'Animation,Action,Comedy,Crime,Drama' changed to 'Abimatlon,Acvimk,Cokgdy,Cclme,Dxzka'
# row: 259 col: 2 : 'Hentai' changed to 'Hebexu'
# row: 437 col: 2 : 'Animation,Comedy' changed to 'Euooafuob,Wmiedy'
# row: 294 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Dbpmzdluv,Xokedt,Fwana,Tomancz'
# row: 1164 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Womeej,Fxntaxy,Kida'
# row: 601 col: 2 : 'Drama,Shoujo,Sports' changed to 'Deama,Djoubm,D[jdrx'
# row: 1336 col: 2 : 'Animation,Short' changed to 'Xthlatipi,Short'
# row: 742 col: 2 : 'Animation,Short,Music' changed to 'Aniksbkki,Srmrv,Jusie'
# row: 572 col: 2 : 'Hentai' changed to 'Itttap'
# row: 1498 col: 2 : 'Animation' changed to 'Anikwhjmg'
# row: 1358 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Asvznfurg,Sainasy,Kicw'
# row: 368 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Cinfsj,Hentash,Kidf'
# row: 1588 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi,Thriller' changed to 'Enmmation,Scvili,Adtevnuwc,Comvey,Svo-Fl,Thtmlmet'
# row: 484 col: 2 : 'Animation,Action,Adventure,Comedy,Horror' changed to 'Anyjafiou,Wcvyon,Wdnettbrt,Ckkedr,Hirtjw'
# row: 245 col: 2 : 'Hentai' changed to 'Hwutwi'
# row: 888 col: 2 : 'Historical' changed to 'Hlsdpcibsl'
# row: 210 col: 2 : 'Action,Comedy,Horror,Shounen,Supernatural' changed to 'Actlon,Fmktab,Yjrdms,Vfobnsb,Vkpcguabyxzm'
# row: 798 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Aqnemturf,Xjmggy,Dcntasy'
# row: 320 col: 2 : 'Comedy' changed to 'Cimqby'
# row: 827 col: 2 : 'Drama,Fantasy,Kids' changed to 'Drwma,Fanvwwy,Kndd'
# row: 645 col: 2 : 'Animation,Action,Comedy,Drama,Sci-Fi,Western' changed to 'Anjnsbhon,Scjyki,Cjmedt,Drcmq,Vdi-Fm,Wcstvgn'
# row: 227 col: 2 : 'Animation,Action,Adventure,Romance,Sci-Fi' changed to 'Avimavoov,Axtion,Advwnttwf,Vomavcq,Sdp-No'
# row: 1351 col: 2 : 'Comedy,Talk-Show' changed to 'Xmlegj,Exlk-Show'
# row: 132 col: 2 : 'Kids,SliceofLife' changed to 'Kpax,SjorekhOife'
# row: 860 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Mystery,Romance' changed to 'Wnijwtion,Wsdehthcx,Dgamw,Fakllh,Rwneadt,Mjsgzrb,Soicnfe'
# row: 927 col: 2 : 'Comedy,Drama' changed to 'Zomfgy,Fecoa'
# row: 637 col: 2 : 'Hentai' changed to 'Hzkcak'
# row: 221 col: 2 : 'Dementia' changed to 'Aenfbgha'
# row: 839 col: 2 : 'Animation' changed to 'Qniisthpn'
# row: 343 col: 2 : 'Adventure,Kids' changed to 'Abbwgygrs,Kmav'
# row: 1494 col: 2 : 'Hentai' changed to 'Hendai'
# row: 59 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Ahimxeipn,Comedy,Fettzsf'
# row: 430 col: 2 : 'Comedy' changed to 'Dlmesv'
# row: 452 col: 2 : 'Animation' changed to 'Auijabuon'
# row: 745 col: 2 : 'Adventure,Drama,Shoujo' changed to 'Wdvetyife,Bswmz,Xjuumo'
# row: 1221 col: 2 : 'Comedy,Crime' changed to 'Cumefy,Cfimc'
# row: 544 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Svumwthku,Cpkedy,Drcma,Sokanwe'
# row: 441 col: 2 : 'Comedy' changed to 'Zomesy'
# row: 1089 col: 2 : 'Documentary,Short' changed to 'Dpcioentary,Sijft'
# row: 1312 col: 2 : 'Kids,Music' changed to 'Nkqw,Ludix'
# row: 317 col: 2 : 'Horror,Thriller' changed to 'Hisgur,Thvilmet'
# row: 620 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Dnioatuok,Avnlji,Eegenrurt,Srl-Fi'
# row: 1450 col: 2 : 'Biography,Drama,Music' changed to 'Bijftephy,Deeoa,Ljxod'
# row: 809 col: 2 : 'Comedy' changed to 'Elnedy'
# row: 788 col: 2 : 'Mecha,Sci-Fi' changed to 'Mrcfw,Vgn-Si'
# row: 1245 col: 2 : 'Adventure,Historical,Shounen' changed to 'Ebcfnfude,Kofcogiccm,Dhmjudn'
# row: 337 col: 2 : 'Romance' changed to 'Rkmcnct'
# row: 1414 col: 2 : 'Kids,SliceofLife' changed to 'Jidw,VliceofLnve'
# row: 344 col: 2 : 'Drama,Mystery' changed to 'Deaka,Nystety'
# row: 636 col: 2 : 'Short,Fantasy,Music,Sci-Fi' changed to 'Sjorn,Dcnysvy,Kmsyc,Vcy-Ri'
# row: 39 col: 2 : 'Action,Comedy,Ecchi,Harem,Magic,Supernatural' changed to 'Sxbmpm,Xontdt,Ezcji,Faxek,Mablb,Sukxrnatnral'
# row: 1231 col: 2 : 'Hentai,Magic,Supernatural' changed to 'Ifnhap,Mafic,Sn[eenqduval'
# row: 899 col: 2 : 'Hentai,Yuri' changed to 'Hrjtqi,Ulry'
# row: 903 col: 2 : 'Animation' changed to 'Smjjdtiom'
# row: 974 col: 2 : 'Action,Animation,Sci-Fi' changed to 'Xcbion,Aglmauioh,Scy-Fi'
# row: 557 col: 2 : 'Animation,Adventure,Family,Sci-Fi' changed to 'Anioatlln,Ddvenuutr,Gdkukg,Scm-Fi'
# row: 1081 col: 2 : 'Animation,Adventure,Comedy,Fantasy,Romance' changed to 'Dbyksylom,Edvenrurg,Gujwdy,Fwvydxh,Romwicg'
# row: 363 col: 2 : 'Animation,Drama,Sport' changed to 'Anhlaghmn,Bwclc,Spotu'
# row: 1534 col: 2 : 'Animation' changed to 'Abjmstuon'
# row: 32 col: 2 : 'Documentary' changed to 'Gochnegbarb'
# row: 1156 col: 2 : 'Short,Comedy' changed to 'Shjrt,Gjjasy'
# row: 461 col: 2 : 'Comedy,Kids,Shoujo' changed to 'Domtdy,Liad,Wvobjo'
# row: 1475 col: 2 : 'Hentai,School' changed to 'Hwntxl,Srylkl'
# row: 640 col: 2 : 'Comedy,Drama,Horror,Mystery' changed to 'Xumedf,Qraja,Hovror,Mystxrf'
# row: 395 col: 2 : 'Animation,Short' changed to 'Dgimcthpt,Rhmfd'
# row: 508 col: 2 : 'Animation,Short' changed to 'Xiimwnimi,Srprr'
# row: 102 col: 2 : 'Comedy' changed to 'Ckoggf'
# row: 494 col: 2 : 'Animation,Fantasy' changed to 'Suimsvion,Fwttadr'
# row: 511 col: 2 : 'Action,Adventure,Mecha' changed to 'Zctioh,Cffekbjre,Kechx'
# row: 54 col: 2 : 'Fantasy' changed to 'Fqgvzxi'
# row: 1313 col: 2 : 'Hentai' changed to 'Hzvjai'
# row: 717 col: 2 : 'Comedy,Romance,Seinen,SliceofLife' changed to 'Eomtsy,Gpmahce,Sviign,SonzalxLyfe'
# row: 472 col: 2 : 'Comedy,Josei,Romance,SliceofLife' changed to 'Cpmrdr,Mjddn,Rumxngs,VlizeowUjfa'
# row: 1566 col: 2 : 'Romance,SliceofLife' changed to 'Glmakfe,WlicsodOife'
# row: 1487 col: 2 : 'Drama,Fantasy,Harem,Romance,Shoujo' changed to 'Dvsmz,Fahtway,Hzteo,Rolzice,Wmotkm'
# row: 1384 col: 2 : 'Adventure,Fantasy' changed to 'Adnwjtuvz,Fwivasr'
# row: 1423 col: 2 : 'Animation,Short,Fantasy' changed to 'Avumajiun,Xjlre,Faidqdf'
# row: 998 col: 2 : 'Drama,Kids,Sports' changed to 'Vcckd,Iifv,Rkowua'
# row: 913 col: 2 : 'Hentai' changed to 'Ktngai'
# row: 825 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Cnhmztiou,Smmsdu,Deqla,Nwktasy,Domsvct'
# row: 1261 col: 2 : 'Music' changed to 'Kuslg'
# row: 970 col: 2 : 'Animation,Drama,Family,Romance' changed to 'Aupjwniom,Gtama,Valuli,Tonebcz'
# row: 1368 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Wbfwntudx,Coledy,Daghewy,Kmcx'
# row: 1448 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Djyketipb,Cmiedn,Asama,Rjmzmfg'
# row: 844 col: 2 : 'Historical,Mystery,Shounen' changed to 'Hmvtorncal,Lyduwey,Snimuen'
# row: 1088 col: 2 : 'Adventure' changed to 'Wdcxmturr'
# row: 423 col: 2 : 'Action,Comedy,Mystery,SuperPower' changed to 'Aethmn,Comcfy,Mystcry,SuperPoafc'
# row: 1556 col: 2 : 'Action,Adventure,Comedy,Kids' changed to 'Cctokn,Advqncnte,Vimsfy,Hidv'
# row: 831 col: 2 : 'Action,Drama,Fantasy,Mystery,Sci-Fi' changed to 'Drtiln,Drdmz,Hanvwfy,Ktwyery,Sbi-Ni'
# row: 822 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'Wvimebppj,Qcujon,Zkmedj,Spogt'
# row: 958 col: 2 : 'Historical,Romance,Shoujo,Supernatural' changed to 'Iystociveu,Comctze,Svoljk,Fuiectajhgap'
# row: 1135 col: 2 : 'Hentai' changed to 'Mevnan'
# row: 1237 col: 2 : 'Animation,Comedy,Family,Sci-Fi' changed to 'Wbilsdion,Somedt,Rwiopj,Rcy-Yi'
# row: 138 col: 2 : 'Comedy,Magic,Parody' changed to 'Bumecv,Laghs,Pqgjdu'
# row: 766 col: 2 : 'Animation,Drama,History,Romance' changed to 'Ehinxvmon,Ersma,Fpvviry,Rpmance'
# row: 1533 col: 2 : 'Animation,Comedy,Drama' changed to 'Agijdtipn,Cukxci,Fxams'
# row: 135 col: 2 : 'Drama,Music,Thriller' changed to 'Dwwka,Luwic,Uvtkller'
# row: 500 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'Suymznmuk,Awtnin,Fxjndwb,Yxle-Ayid,Dvl-Hi'
# row: 791 col: 2 : 'Comedy,Ecchi' changed to 'Xoiefg,Edcip'
# row: 1441 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Wnyledpoh,Actimn,Geqkd,Swi-Sk'
# row: 422 col: 2 : 'Animation,Action,Drama' changed to 'Wgjmqtjjn,Agdoon,Erwkd'
# row: 1097 col: 2 : 'Comedy,Parody' changed to 'Bomdfy,Ozrogv'
# row: 1161 col: 2 : 'Animation,Short' changed to 'Amyowyupn,Skmrt'
# row: 1154 col: 2 : 'Animation,Action,Adventure,Comedy,Crime,Fantasy,Mystery,Sci-Fi' changed to 'Dhomstpon,Xstipn,Scvevtmee,Cumecy,Crmie,Ndntaxy,Mfwtert,Vck-Fh'
# row: 1196 col: 2 : 'Historical' changed to 'Risforlvcl'
# row: 1127 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Dnimatiim,Clmasn,Hwbtwwt,Epkeize'
# row: 356 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Sci-Fi' changed to 'Animxtpon,Wctiub,Adbenhgee,Fenily,Fqnvafj,Ssl-Yi'
# row: 322 col: 2 : 'Animation,Short' changed to 'Znijatiun,Wjogt'
# row: 273 col: 2 : 'Action,Magic,Sci-Fi,SuperPower' changed to 'Wvjnok,Ozyib,Xgu-Wj,Snpte'matw'
# row: 684 col: 2 : 'Comedy,Military' changed to 'Coktdy,Mjlicary'
# row: 685 col: 2 : 'Hentai' changed to 'Vgnrau'
# row: 871 col: 2 : 'Drama,Thriller' changed to 'Deala,Nheylnrr'
# row: 670 col: 2 : 'Drama,Music,Romance' changed to 'Dfanc,Lkfic,Rilcibr'
# row: 712 col: 2 : 'Hentai,Yaoi' changed to 'Kgjtap,Ywoy'
# row: 1033 col: 2 : 'Drama,Psychological' changed to 'Dtwna,Osbchupojisaj'
# row: 711 col: 2 : 'Action,Kids' changed to 'Dcfiin,Kldf'
# row: 86 col: 2 : 'Comedy' changed to 'Wljtdn'
# row: 383 col: 2 : 'School,Shounen,Sports' changed to 'Sxhook,Shokbtv,Sporgs'
# row: 936 col: 2 : 'Drama,Historical,Samurai,Shounen' changed to 'Crwlq,Hirtisyczn,Dwmieaj,Wruhhsv'
# row: 943 col: 2 : 'Animation,Short,Comedy' changed to 'Enkjctlon,Xhory,Vpirey'
# row: 362 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'Wnjmwrilh,Wwtmpn,Qdvekuuwv,Eokevb,Fco-Ym'
# row: 1086 col: 2 : 'Game,Psychological,Seinen,Thriller' changed to 'Gaje,Pfyzvokogibal,Sennen,Ggrilncc'
# row: 749 col: 2 : 'Hentai' changed to 'Mwgjao'
# row: 1569 col: 2 : 'Short,Comedy,Fantasy,Romance' changed to 'Shoru,Cjmedv,Fauuasy,Gomznvr'
# row: 193 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Animatioj,Comeqy,Vcmteag'
# row: 893 col: 2 : 'Comedy,School,SliceofLife' changed to 'Comwdu,Scvilo,SjibfonLirr'
# row: 333 col: 2 : 'Action,Comedy,Sci-Fi,SuperPower' changed to 'Esupon,Zujegg,Wzo-Fi,Auier[jwwr'
# row: 1013 col: 2 : 'Hentai,Horror' changed to 'Hditsm,Yjgcur'
# row: 1299 col: 2 : 'SliceofLife' changed to 'SpieqovLlxg'
# row: 1069 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'Qiloetmli,Zctijn,Rcngary,Txmf-Fhod,Sci-Fn'
# row: 792 col: 2 : 'Comedy' changed to 'Foktvr'
# row: 241 col: 2 : 'Animation,Short' changed to 'Enomxejon,Rhost'
# row: 743 col: 2 : 'Animation,Short,Sci-Fi' changed to 'Enklatiot,Short,Sci-Fi'
# row: 681 col: 2 : 'Kids,Sports' changed to 'Kidf,Skkwts'
# row: 522 col: 2 : 'Hentai' changed to 'Yfnyzh'
# row: 460 col: 2 : 'Animation,Action,Adventure,Comedy,Sci-Fi' changed to 'Sbllatnoh,Artiin,Xqgvnfore,Womwdu,Szi-Fl'
# row: 358 col: 2 : 'Comedy,Drama,Romance' changed to 'Bomesy,Draja,Rjmxncg'
# row: 1578 col: 2 : 'Action,Comedy,Shounen,Sports' changed to 'Qcdiln,Wojssh,Rhlbjqn,Apoghs'
# row: 1129 col: 2 : 'Animation,Action,Comedy,Sport' changed to 'Aiimzgjon,Acbimn,Cjnefu,Sljer'
# row: 10 col: 2 : 'Animation' changed to 'Znkmaduok'
# row: 1073 col: 2 : 'Animation,Action,Adventure,Drama' changed to 'Znikwcjpt,Sxtikn,Acvebttgw,Qeams'
# row: 142 col: 2 : 'Adventure,Sci-Fi' changed to 'Sddentuge,Dfi-Fl'
# row: 1201 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'Wceikn,Rokzdj,Iarsm,Frn-Fk,Shouvat,Spccw'
# row: 301 col: 2 : 'Comedy' changed to 'Rukeau'
# row: 1517 col: 2 : 'Drama,Mystery,Romance,Thriller' changed to 'Stalq,Myxefgr,Tojcncd,Crriljet'
# row: 621 col: 2 : 'Animation,Action,Comedy,Drama,Romance,Thriller' changed to 'Zjiiavnog,Acrmok,Bimeey,Bdqma,Guoqnfe,Thtlluvd'
# row: 1328 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Cnjmcjoob,Cpmedi,Rri-Fi'
# row: 1002 col: 2 : 'Comedy' changed to 'Xumabg'
# row: 1373 col: 2 : 'Drama' changed to 'Dwxiw'
# row: 619 col: 2 : 'Hentai' changed to 'Hektsi'
# row: 121 col: 2 : 'Adventure,Sports' changed to 'Qdvetnhfe,Spowns'
# row: 797 col: 2 : 'Adventure,Comedy,Kids,SuperPower' changed to 'Advetuuxx,Eimedh,Kncr,Diper'oxwt'
# row: 324 col: 2 : 'Hentai' changed to 'Yxttwl'
# row: 336 col: 2 : 'Animation,Short' changed to 'Xmilatioj,Ahlty'
# row: 1552 col: 2 : 'Drama' changed to 'Arzka'
# row: 427 col: 2 : 'Action,Comedy,Ecchi' changed to 'Actilk,Vimtbj,Ewchp'
# row: 644 col: 2 : 'Comedy,Drama,Romance' changed to 'Coocdf,Dtama,Rojcnce'
# row: 673 col: 2 : 'Music' changed to 'Mmshx'
# row: 730 col: 2 : 'Comedy,Sci-Fi' changed to 'Zijrdy,Rcl-Hi'
# row: 243 col: 2 : 'Animation,Short,Adventure,Comedy' changed to 'Wnimqbojn,Shprd,Wevdhhmde,Rliedn'
# row: 129 col: 2 : 'Action,Animation,Sci-Fi' changed to 'Swjipn,Eniozhupj,Aem-Fj'
# row: 890 col: 2 : 'Short,Drama,Horror,Mystery,Thriller' changed to 'Sgort,Dgsmq,Hkdrlt,Igfvzry,Hmriklzr'
# row: 847 col: 2 : 'Animation,Adventure,Comedy' changed to 'Snikaelmk,Wvvcngurv,Cijtsn'
# row: 234 col: 2 : 'Animation,Action,Fantasy' changed to 'Snymqfiun,Acthov,Rxitday'
# row: 553 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'Anymqeuou,Xcflob,Zqyzituwe,Rojxdu'
# row: 1592 col: 2 : 'Short,Drama,Thriller' changed to 'Vforh,Dfaiw,Vhgjmjec'
# row: 147 col: 2 : 'Adventure,Comedy,Magic,Romance,Shoujo' changed to 'Scdzndutv,Zinedh,Icbmz,Eumance,Shulgm'
# row: 1502 col: 2 : 'Short' changed to 'Skogn'
# row: 157 col: 2 : 'Animation' changed to 'Anpmxguon'
# row: 1199 col: 2 : 'Animation,Fantasy' changed to 'Wninatijn,Xamnzsr'
# row: 1228 col: 2 : 'Comedy,Parody,School,Seinen' changed to 'Cllegy,Pagudy,Dchoul,Szlvxn'
# row: 701 col: 2 : 'Animation,Adventure,Family,Fantasy,Sci-Fi' changed to 'Ebkmsgimu,Abvqncuec,Fzmioy,Famgdxy,Sci-Sj'
# row: 1520 col: 2 : 'Comedy,Historical' changed to 'Zmmaqh,Hivemwicxl'
# row: 929 col: 2 : 'Animation,Comedy,Romance' changed to 'Znhoabpon,Cjoecu,Rlmanwe'
# row: 776 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Wnimztilm,Aceiut,Sci-Fj'
# row: 1567 col: 2 : 'Action,Comedy,Mecha' changed to 'Xctnon,Vkmqdy,Jcche'
# row: 407 col: 2 : 'Animation,Short' changed to 'Zhljabpob,Vhofe'
# row: 1544 col: 2 : 'Animation,Action,Drama' changed to 'Anioaeikk,Qctluv,Drwoe'
# row: 514 col: 2 : 'Action,Mecha,Military,Shounen' changed to 'Scgiin,Mrcvd,Mnlnyasy,Amohnek'
# row: 1219 col: 2 : 'Short' changed to 'Vrort'
# row: 401 col: 2 : 'Animation,Drama,Romance,Sci-Fi' changed to 'Xhilzhion,Drenc,Xloance,Sri-Xl'
# row: 1236 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Wbikwtipn,Scyimi,Webekcusd,Vci-Fp'
# row: 325 col: 2 : 'Adventure,Comedy,Drama' changed to 'Wfventurr,Foiedy,Vraia'
# row: 953 col: 2 : 'Action' changed to 'Sreion'
# row: 497 col: 2 : 'Comedy,Kids' changed to 'Comddj,Yjqs'
# row: 305 col: 2 : 'Comedy,Parody,Sci-Fi' changed to 'Cmmeah,Patodn,Seh-Rm'
# row: 548 col: 2 : 'Animation,Drama' changed to 'Wnpjaniin,Dremq'
# row: 531 col: 2 : 'Animation,Comedy' changed to 'Animabnon,Zomedy'
# row: 119 col: 2 : 'Animation,Action,Comedy' changed to 'Avimatpon,Aggion,Comesy'
# row: 1300 col: 2 : 'Harem,Hentai' changed to 'Ravem,Menfej'
# row: 1288 col: 2 : 'Fantasy,Kids' changed to 'Fziczsj,Ipbx'
# row: 1114 col: 2 : 'Talk-Show' changed to 'Uwly-Sfiw'
# row: 1232 col: 2 : 'Animation,Comedy,Romance' changed to 'Znmmzbkob,Comqqy,Wonsncf'
# row: 898 col: 2 : 'Action,Adventure,Fantasy,Game' changed to 'Acthin,Cfvemhuge,Xwgtasy,Ccie'
# row: 113 col: 2 : 'Comedy,Ecchi,Kids,School,Shounen,SliceofLife' changed to 'Comcdy,Tcdhi,Kids,Svjook,Wvlunrj,FlmcrofLjys'
# row: 1353 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Enioatkkm,Actijn,Wdvxitufc,Nwktcsn'
# row: 1593 col: 2 : 'Animation,Short,Comedy' changed to 'Anukabljn,Sjjfc,Cijeaf'
# row: 1293 col: 2 : 'Hentai' changed to 'Henvxi'
# row: 361 col: 2 : 'Animation,Drama,History,Romance' changed to 'Avkkabujn,Gtziw,Mpfgpfr,Rolavfe'
# row: 398 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Ckmeat,Voiagcd,SjyxsmyLjye'
# row: 197 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Agyiqyimv,Wctjon,Adxxitoge,Handasf'
# row: 728 col: 2 : 'Ecchi' changed to 'Tfrhi'
# row: 741 col: 2 : 'Animation' changed to 'Atioxtion'
# row: 1391 col: 2 : 'Hentai' changed to 'Hrjtwi'
# row: 1122 col: 2 : 'Comedy' changed to 'Cpmxsy'
# row: 979 col: 2 : 'Action,Sci-Fi' changed to 'Wcenub,Abn-Fi'
# row: 647 col: 2 : 'Animation' changed to 'Enjmagpjv'
# row: 518 col: 2 : 'Documentary,Short' changed to 'Documdnyxtb,Sjott'
# row: 1342 col: 2 : 'Action,Historical' changed to 'Wstopj,Miatorlcqm'
# row: 180 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Abhmqvjov,Xonscy,Sck-Ry'
# row: 532 col: 2 : 'Animation,Action,Romance,Sci-Fi' changed to 'Egimagijv,Ecenmn,Rumxncs,Sgm-Hl'
# row: 750 col: 2 : 'Drama' changed to 'Dfsme'
# row: 26 col: 2 : 'Comedy,Ecchi,Romance,Sci-Fi' changed to 'Goitsb,Edevi,Romagex,Wrp-Xi'
# row: 910 col: 2 : 'Comedy' changed to 'Bomwej'
# row: 173 col: 2 : 'Adventure,Fantasy,Romance' changed to 'Cavrmtuge,Fanbcxg,Duiahcd'
# row: 467 col: 2 : 'Adventure,Comedy,Magic' changed to 'Agvxntyre,Rmmedn,Mzclc'
# row: 1120 col: 2 : 'Comedy,Historical,Sci-Fi' changed to 'Spmedu,Kiavirival,Svj-Fn'
# row: 1168 col: 2 : 'Comedy,Crime,Drama' changed to 'Gkkcdn,Cfine,Braiw'
# row: 726 col: 2 : 'Sci-Fi,Space' changed to 'Xci-Fi,S[ace'
# row: 515 col: 2 : 'Kids' changed to 'Kibd'
# row: 1459 col: 2 : 'Animation,Adventure' changed to 'Ahulxhoog,Adxeibjre'
# row: 1362 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Advehvlvg,Eokrdy,Yektaay,Nlqx'
# row: 1194 col: 2 : 'Action,Adventure,Mecha,Sci-Fi' changed to 'Wctnln,Adgenfure,Jwrha,Rcj-Fi'
# row: 15 col: 2 : 'Animation,Action,Comedy,Fantasy,Sci-Fi' changed to 'Enjmxullg,Actiut,Cokeqy,Fabtwwv,Sci-Fi'
# row: 753 col: 2 : 'Comedy,Drama,Romance' changed to 'Rlmesy,Grema,Eikansv'
# row: 882 col: 2 : 'Drama,Sci-Fi,Shounen,Sports' changed to 'Dxamq,Acm-Np,Vfokbei,Slorrd'
# row: 975 col: 2 : 'Drama' changed to 'Csaka'
# row: 1278 col: 2 : 'Fantasy,Magic' changed to 'Vantevy,Mcfiv'
# row: 1096 col: 2 : 'Animation,Comedy' changed to 'Aiimatomk,Vkkgdy'
# row: 487 col: 2 : 'Animation' changed to 'Aninanlkn'
# row: 1271 col: 2 : 'Animation,Fantasy' changed to 'Wnijwtioh,Sqheqsf'
# row: 21 col: 2 : 'Comedy,Police' changed to 'Cplzfy,Pulkcq'
# row: 1388 col: 2 : 'Animation,Action,Drama,Sci-Fi' changed to 'Dniiahikn,Acgiij,Dramx,Fcj-Yi'
# row: 1392 col: 2 : 'Hentai' changed to 'Femtai'
# row: 223 col: 2 : 'Comedy,Ecchi,SliceofLife' changed to 'Elmedn,Rcckl,RkivrkfLlsw'
# row: 93 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Cbimduipn,Ccbuom,Ack-Fi'
# row: 80 col: 2 : 'Action,Adventure,Comedy,Fantasy,Shounen,SuperPower' changed to 'Cztioi,Qdvevcire,Cukedt,Ywntasy,Sgkuten,SuiwwPufqt'
# row: 1186 col: 2 : 'Adventure,Shounen' changed to 'Adnrunkte,Vypnten'
# row: 625 col: 2 : 'Comedy' changed to 'Womedi'
# row: 291 col: 2 : 'Comedy' changed to 'Cokqdn'
# row: 724 col: 2 : 'Animation' changed to 'Zvimqdion'
# row: 359 col: 2 : 'Animation' changed to 'Eniiatmkn'
# row: 812 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Ajimsuyon,Vomsvg,Dvsos,Rloamsz'
# row: 435 col: 2 : 'Short,Adventure,Family' changed to 'Sjjrt,Aqdqnturr,Fwminr'
# row: 43 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Amimation,Coksdi,Drwia,Romcnrs'
# row: 1325 col: 2 : 'Drama,Romance' changed to 'Vrsia,Rljatbf'
# row: 1485 col: 2 : 'Kids,Music' changed to 'Kibv,Music'
# row: 1513 col: 2 : 'Animation,Action,Fantasy,Sci-Fi' changed to 'Cnloquiln,Wchyot,Fxjedrj,Scp-Wi'
# row: 1465 col: 2 : 'Adventure,Comedy,Mystery' changed to 'Afvevjueg,Somzat,Iystsry'
# row: 768 col: 2 : 'Drama,Sports' changed to 'Etxke,Aoltur'
# row: 1134 col: 2 : 'Animation,Adventure,Comedy' changed to 'Atilaniou,Zdfegruts,Comesy'
# row: 390 col: 2 : 'Action,Ecchi,Fantasy,School,Seinen' changed to 'Avbiln,Eccri,Fsbbwsj,Sxrool,Dziiev'
# row: 118 col: 2 : 'Animation,Action,Comedy,Fantasy' changed to 'Djimdtkkk,Acbiln,Dmoqdj,Fahtwsf'
# row: 567 col: 2 : 'Drama,Josei,Romance' changed to 'Dcamq,Uosei,Roiqngw'
# row: 864 col: 2 : 'Drama' changed to 'Dxakz'
# row: 1438 col: 2 : 'Adventure,Kids' changed to 'Cdventuge,Npds'
# row: 1379 col: 2 : 'Comedy' changed to 'Fokedy'
# row: 693 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Romance' changed to 'Sbimwtijn,Aftpoi,Advqnuusz,Fikfdb,Afama,Gantcsy,Foldmfs'
# row: 819 col: 2 : 'Animation' changed to 'Anpmctjpn'
# row: 388 col: 2 : 'Comedy,Police' changed to 'Rpmcdy,Pullda'
# row: 627 col: 2 : 'Animation,Adventure,Drama,Family,Fantasy,Sci-Fi' changed to 'Quimatuon,Afveudlrv,Vvama,Vqnilg,Fsntaxj,Sbm-No'
# row: 1568 col: 2 : 'Adventure,Fantasy,Kids,Magic,MartialArts' changed to 'Aevrneurx,Rzmfast,Khds,Magix,MqsfjalCcba'
# row: 35 col: 2 : 'Animation,Short' changed to 'Dnimdnuon,Vhmtt'
# row: 1427 col: 2 : 'Crime' changed to 'Crlmd'
# row: 204 col: 2 : 'Fantasy' changed to 'Febhevy'
# row: 1202 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,Horror,Thriller' changed to 'Anikqtmoj,Zctkog,Dervjbhwe,Cimedy,Brdia,Szjtarg,Hovxow,Gkriousw'
# row: 1483 col: 2 : 'Animation,Adventure,Sci-Fi' changed to 'Whpkqtium,Advennurs,Rco-Rh'
# row: 732 col: 2 : 'Animation,Action,Adventure,Family,Fantasy,Thriller' changed to 'Chimatikg,Zwvioi,Abdxvturt,Sxmnou,Ssmnast,Uhvillwr'
# row: 1433 col: 2 : 'News' changed to 'Nsws'
# row: 576 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Aiijwyjmn,Solwby,Drzos,Waguadb,Vomwica'
# row: 1507 col: 2 : 'Drama,Sci-Fi' changed to 'Dvakx,Xci-Wi'
# row: 784 col: 2 : 'Comedy' changed to 'Zimfdy'
# row: 1104 col: 2 : 'Hentai' changed to 'Vcknqh'
# row: 704 col: 2 : 'Short' changed to 'Sgmgt'
# row: 251 col: 2 : 'Kids,Sports' changed to 'Kisx,Spmrex'
# row: 201 col: 2 : 'Animation,Action,Romance,Sci-Fi' changed to 'Zilmatmkh,Wryioi,Romqnbr,Wsy-Fy'
# row: 941 col: 2 : 'Animation,Short' changed to 'Cnhkdglpn,Dvksr'
# row: 897 col: 2 : 'Adventure,Comedy,Fantasy,Parody' changed to 'Xgvfntuwd,Colecy,Swbtaxi,Pwtoaj'
# row: 1549 col: 2 : 'Hentai' changed to 'Hcnhdi'
# row: 1059 col: 2 : 'Music' changed to 'Kuvhc'
# row: 1102 col: 2 : 'Sports' changed to 'Sporns'
# row: 52 col: 2 : 'Drama,Historical' changed to 'Greka,Mistpdicau'
# row: 196 col: 2 : 'Animation,Action,Adventure,Comedy,Crime' changed to 'Djimetpoj,Xcnpiu,Xqvemdkre,Rjkvfr,Crkmd'
# row: 545 col: 2 : 'Animation,Short,Adventure,Family' changed to 'Dnimatjoj,Xhitt,Adbfgtlrw,Yaminn'
# row: 182 col: 2 : 'Animation,Short' changed to 'Qnoiwuiin,Diigt'
# row: 962 col: 2 : 'Reality-TV' changed to 'Tealmty-HV'
# row: 1598 col: 2 : 'Hentai' changed to 'Hwggch'
# row: 1499 col: 2 : 'Action,Drama,Fantasy,Historical,MartialArts' changed to 'Ebvijg,Drxla,Vavrady,Mksjorpcwm,NadtialAgcs'
# row: 268 col: 2 : 'Action' changed to 'Acromm'
# row: 1175 col: 2 : 'Action,Comedy' changed to 'Ccunlh,Clmedj'
# row: 314 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance,Sci-Fi' changed to 'Akijatoin,Wctiov,Sukebu,Femtaxy,Eonwnce,Rxj-Xi'
# row: 53 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'Zolzgu,Rokdncv,Wxhool,Sjobgu'
# row: 1100 col: 2 : 'Action,Comedy,Crime,Drama,Thriller' changed to 'Acyokn,Conevy,Crmme,Dvwia,Dnrilpre'
# row: 902 col: 2 : 'Animation,Comedy,Drama' changed to 'Wnimxhipn,Comvdi,Cwwiz'
# row: 867 col: 2 : 'Comedy,Sports' changed to 'Soledu,Slmwbx'
# row: 78 col: 2 : 'Animation,Short,Comedy,Romance' changed to 'Qnimatiok,Xhivh,Bomedy,Wpoajcg'
# row: 1375 col: 2 : 'Adventure' changed to 'Edbznjoga'
# row: 263 col: 2 : 'Animation,Comedy,Drama' changed to 'Ajimqnion,Wojesy,Dvwia'
# row: 1529 col: 2 : 'Animation,Family,Fantasy' changed to 'Anijwtilh,Xcjimy,Vsnvwwj'
# row: 1389 col: 2 : 'Short,Comedy' changed to 'Sypxv,Bomgdf'
# row: 1582 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Ahimatijh,Sxvmon,Rpmqsy,Yantasy,Rokwtve'
# row: 984 col: 2 : 'Action,Sci-Fi,Animation,Fantasy,Adventure,Drama' changed to 'Ceciii,Wcy-Fl,Aiimatpkt,Fcngzfg,Advxneuxe,Frais'
# row: 983 col: 2 : 'Short,Fantasy' changed to 'Shptr,Fanusai'
# row: 907 col: 2 : 'Comedy' changed to 'Comegj'
# row: 22 col: 2 : 'SliceofLife,Supernatural' changed to 'SklgekfJmfe,Skpernatkwsl'
# row: 817 col: 2 : 'Action,Adventure,Comedy,Ecchi,Fantasy,Romance,Sci-Fi,Space' changed to 'Zchikt,Wffsktote,Cokacy,Qrcjj,Sabtwsy,Ejianxv,Xci-Sy,Wpece'
# row: 858 col: 2 : 'Animation,Action,Adventure,Sci-Fi' changed to 'Xtlmatimn,Ceenkn,Advenykee,Vci-Hi'
# row: 225 col: 2 : 'Fantasy,Magic' changed to 'Fantafy,Lagjd'
# row: 323 col: 2 : 'Animation' changed to 'Dkynajiin'
# row: 1555 col: 2 : 'Animation,Comedy,Drama' changed to 'Qupjavhkn,Comedb,Drsmd'
# row: 886 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Avrvnrndq,Fdntasy,Kpvv'
# row: 513 col: 2 : 'Comedy' changed to 'Clmqvy'
# row: 1551 col: 2 : 'Adventure,Sci-Fi,Shounen,Sports' changed to 'Adcwbtodv,Svi-Yi,Drouuei,S[odes'
# row: 1481 col: 2 : 'School' changed to 'Dvmoom'
# row: 1519 col: 2 : 'Short,Drama' changed to 'Shmrv,Bccms'
# row: 253 col: 2 : 'Animation,Short' changed to 'Cnimzcpoj,Fmmdh'
# row: 853 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'Eipmatujn,Acrimg,Edvenfude,Coidei,Fsniuy,Gevtavy'
# row: 384 col: 2 : 'Action,Comedy,Ecchi,Sci-Fi,Shounen,Space,Sports' changed to 'Wctyov,Zjmvvi,Ecchi,Acn-Yl,Aklunek,Aiacd,Aporba'
# row: 763 col: 2 : 'Animation,Short' changed to 'Ahimztion,Xmogt'
# row: 315 col: 2 : 'Action,Historical,MartialArts,Samurai' changed to 'Axumon,Historibdp,JwgbiwlAfer,Xaktrxk'
# row: 835 col: 2 : 'Drama' changed to 'Atekc'
# row: 4 col: 2 : 'Comedy' changed to 'Coozfg'
# row: 424 col: 2 : 'Music' changed to 'Okskc'
# row: 1050 col: 2 : 'School,Shounen' changed to 'Vcnipo,Vyjumxg'
# row: 1112 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Ahimedioj,Zwtyun,Qfegnture,Xajuwsf,Sco-Wi'
# row: 606 col: 2 : 'Comedy,Kids' changed to 'Ckkgdv,Kodf'
# row: 1531 col: 2 : 'School,Sports' changed to 'Dghooj,Splrcv'
# row: 143 col: 2 : 'Comedy,Ecchi,Kids,Shounen' changed to 'Cimecg,Egvki,Ljas,Fhiumgv'
# row: 495 col: 2 : 'Comedy,Magic' changed to 'Vukedy,Mwnux'
# row: 765 col: 2 : 'Action,Fantasy,Supernatural' changed to 'Abniln,Nantxsn,Sbiernaugraj'
# row: 177 col: 2 : 'Ecchi' changed to 'Escfi'
# row: 859 col: 2 : 'Action,Adventure,Horror,Shounen,Vampire' changed to 'Astiok,Aaveiturx,Hogrig,Smklbeh,Nakpowe'
# row: 345 col: 2 : 'Hentai' changed to 'Kditak'
# row: 38 col: 2 : 'Comedy,Kids,Romance' changed to 'Zpmvby,Ylbs,Fomwnce'
# row: 997 col: 2 : 'Animation,Action,Comedy,Romance' changed to 'Auijxcimh,Abrnkn,Cioedy,Tlkaker'
# row: 127 col: 2 : 'Music,Shoujo,Sports' changed to 'Mmakz,Smoibk,Aports'
# row: 928 col: 2 : 'Talk-Show' changed to 'Tslk-Sviw'
# row: 1000 col: 2 : 'Adventure,Comedy,Fantasy,Shounen' changed to 'Adbgjtusc,Vkngqn,Xwnfasj,Smounei'
# row: 95 col: 2 : 'Hentai' changed to 'Gemhai'
# row: 367 col: 2 : 'Animation,Action,Drama,Sci-Fi,Thriller,War' changed to 'Znhmedijk,Zctipu,Draiz,Wzy-Wl,Thtinlwg,Wwc'
# row: 439 col: 2 : 'Drama,Kids' changed to 'Drciz,Jiss'
# row: 417 col: 2 : 'Action,Fantasy,Mecha,Sci-Fi' changed to 'Acgion,Fqngavi,Kzzhx,Sci-Si'
# row: 346 col: 2 : 'Animation,Comedy,Sci-Fi' changed to 'Anynztiok,Gjnady,Fsu-Fl'
# row: 937 col: 2 : 'Kids' changed to 'Ynda'
# row: 642 col: 2 : 'Adventure,Family,Fantasy,Romance' changed to 'Zdventure,Fzjjlr,Vcnfqvy,Cplznff'
# row: 1340 col: 2 : 'Comedy,Mecha' changed to 'Cimeag,Kecha'
# row: 217 col: 2 : 'Action,Sci-Fi,Space,SuperPower' changed to 'Qbeukv,Szi-Fk,F'qge,SupedPofdr'
# row: 594 col: 2 : 'Comedy' changed to 'Cokedy'
# row: 1535 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi,Thriller' changed to 'Wkpmqcijn,Ectiln,Aaveujuts,Yannesy,Vcm-Yi,Fyrmlnrd'
# row: 145 col: 2 : 'Hentai' changed to 'Hvkcwi'
# row: 1307 col: 2 : 'Action,Drama,Mecha,Military,Sci-Fi' changed to 'Wdtpom,Fcxma,Nexha,Jyoieqvn,Vby-Fi'
# row: 774 col: 2 : 'Drama,Fantasy,Sci-Fi,Thriller' changed to 'Grams,Nancash,Vck-Wi,Thvpolex'
# row: 216 col: 2 : 'Comedy,Ecchi,Fantasy,Game' changed to 'Gomecr,Eeehj,Fwktcsu,Gwoz'
# row: 1326 col: 2 : 'Ecchi,Seinen' changed to 'Fgchi,Dcpbej'
# row: 61 col: 2 : 'Action,Comedy,Police,Shounen' changed to 'Eccjpn,Comxef,Lplivx,Rhmundn'
# row: 470 col: 2 : 'Animation' changed to 'Xtilwfion'
# row: 1599 col: 2 : 'Action,Adventure,Sci-Fi,Sport' changed to 'Wdtion,Ddxevbtrf,Sfi-Fi,Sllvc'
# row: 229 col: 2 : 'Comedy,Drama' changed to 'Gomxdn,Drcma'
# row: 718 col: 2 : 'Action,Adventure' changed to 'Dftioh,Qdvthgmre'
# row: 1205 col: 2 : 'Adventure,Comedy,Sci-Fi,Shounen' changed to 'Advdjtgge,Ejoedr,Swi-Fm,Whmtnen'
# row: 274 col: 2 : 'Animation,Action,Drama,Fantasy,Mystery' changed to 'Qnimadhoi,Dcykom,Dcajc,Hzjnaay,Mnxtstj'
# row: 879 col: 2 : 'Action,Comedy,Demons,Fantasy,Historical,Shounen,Supernatural' changed to 'Aveiki,Cmmadt,Croona,Xahvssy,Hlsgowiwaj,Wgpnnqg,Sy'tgbetuswj'
# row: 519 col: 2 : 'Magic' changed to 'Maeid'
# row: 178 col: 2 : 'Comedy' changed to 'Cmneqg'
# row: 428 col: 2 : 'Animation,Comedy,Romance' changed to 'Ajmnwvpun,Cmmegj,Romwncs'
# row: 165 col: 2 : 'Adventure,Fantasy' changed to 'Advruttrg,Sanncst'
# row: 111 col: 2 : 'Comedy,Parody,SuperPower' changed to 'Wlmadj,Iaroay,XuoetPmfqx'
# row: 1285 col: 2 : 'Drama,Mecha,Sci-Fi,Space' changed to 'Qrama,Lecha,Sco-Yk,A[wcf'
# row: 1172 col: 2 : 'Shounen' changed to 'Xhounzm'
# row: 235 col: 2 : 'Action' changed to 'Wzvion'
# row: 816 col: 2 : 'Animation,Short' changed to 'Xnilweiok,Svofh'
# row: 609 col: 2 : 'Comedy' changed to 'Bomsdy'
# row: 1454 col: 2 : 'Animation,Short,Comedy,Crime,Fantasy' changed to 'Anmmatmom,Whmrh,Gomeey,Crumv,Fwnjady'
# row: 442 col: 2 : 'Animation,Adventure,Comedy,Drama,Romance,Sci-Fi' changed to 'Animathok,Advfnttdr,Colcdy,Qwald,Romwnve,Ari-Fh'
# row: 691 col: 2 : 'Drama' changed to 'Qxqlz'
# row: 440 col: 2 : 'Comedy,Kids,Parody,Sci-Fi,Space,SuperPower' changed to 'Conesn,Hlea,Kwtkdy,Fei-Hi,Spqzf,DopevPmwwv'
# row: 1138 col: 2 : 'Demons,Harem,Hentai,School,Supernatural' changed to 'Gaiijr,Vectm,Mqntei,Schkkk,Si[drnqjjrap'
# row: 633 col: 2 : 'Animation,Drama' changed to 'Snikxgkok,Drcix'
# row: 610 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Romance' changed to 'Avjlwhlln,Wetion,Vokddg,Vseme,Wsktasu,Gooends'
# row: 1363 col: 2 : 'Comedy' changed to 'Cjmwff'
# row: 1266 col: 2 : 'Animation' changed to 'Wnikannmi'
# row: 466 col: 2 : 'Animation,Action,Drama,Romance,Sci-Fi' changed to 'Wupiatipn,Sgrjpn,Qrcow,Tllqksd,Wci-Fy'
# row: 1066 col: 2 : 'Animation,Adventure,Comedy,Romance' changed to 'Xnijwtiot,Wbtetture,Sonefr,Rukznbe'
# row: 360 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Adcdneure,Xomtdy,Rdmnesy,Kodv'
# row: 1229 col: 2 : 'Short,Animation,Sci-Fi' changed to 'Xhowt,Aumkanuih,Szl-Hh'
# row: 506 col: 2 : 'Comedy' changed to 'Xomedj'
# row: 503 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,War' changed to 'Anlmayikn,Evnmpn,Xegektudc,Romedy,Dgamd,Fwntdst,Histoct,Sqd'
# row: 449 col: 2 : 'Animation,Comedy,Romance' changed to 'Snkkxtijk,Cknggy,Gloeubz'
# row: 48 col: 2 : 'Animation,Sci-Fi' changed to 'Ztimation,Sch-Si'
# row: 455 col: 2 : 'Comedy,Sci-Fi,Shounen,Shounen' changed to 'Comedi,Wwi-Fi,Fjpimcm,Xvptmem'
# row: 446 col: 2 : 'Animation,Action,Drama' changed to 'Cipmatlkm,Arvnok,Frana'
# row: 174 col: 2 : 'Animation,Adventure' changed to 'Avikahlov,Zcvebtuwe'
# row: 1224 col: 2 : 'Romance,School,Shoujo' changed to 'Eunabse,Rwfomu,Dhoojo'
# row: 1054 col: 2 : 'Animation' changed to 'Wtimatnjt'
# row: 665 col: 2 : 'Action' changed to 'Acjioi'
# row: 267 col: 2 : 'Animation,Comedy,Family' changed to 'Xkomaeypu,Djmeaj,Daoult'
# row: 842 col: 2 : 'Action,Historical,Military,SuperPower' changed to 'Actuok,Mixtowhcaj,Mikitary,Sm'ggPorer'
# row: 473 col: 2 : 'Comedy,Historical,Shounen' changed to 'Cojtfv,Hpwyuxiven,Dhltnen'
# row: 269 col: 2 : 'Animation,Adventure,Family,Fantasy' changed to 'Animatiog,Adrdmturc,Gqnily,Hahdsdy'
# row: 237 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'Emknsyipk,Shmrf,Zlmgdn,Fzi-Sl'
# row: 769 col: 2 : 'Animation,Short' changed to 'Akymauljn,Sfogt'
# row: 1087 col: 2 : 'Comedy' changed to 'Skixdy'
# row: 1420 col: 2 : 'Comedy,Samurai,School' changed to 'Domedy,Aamotsi,Wdhomk'
# row: 900 col: 2 : 'Animation,Comedy,Drama' changed to 'Zjmiatkot,Cojeey,Fdzjw'
# row: 556 col: 2 : 'Comedy' changed to 'Colevy'
# row: 622 col: 2 : 'Adventure,Sci-Fi' changed to 'Evdvnturv,Sci-Nm'
# row: 103 col: 2 : 'Animation,Adventure,Comedy' changed to 'Wtokahion,Adtvntlgg,Cooeqj'
# row: 1347 col: 2 : 'Shounen' changed to 'Avognen'
# row: 1239 col: 2 : 'Drama,Fantasy,Kids' changed to 'Bramc,Xantzsy,Kuvs'
# row: 1504 col: 2 : 'Animation,Comedy' changed to 'Anikwdymn,Gpmrcy'
# row: 1443 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Xnlkxtiiv,Eimebu,Bramd,Rimance'
# row: 50 col: 2 : 'Comedy' changed to 'Biicdf'
# row: 854 col: 2 : 'Adventure,Comedy,Drama,Mystery,Sci-Fi' changed to 'Zvvtneurr,Bjmwsy,Avzma,Mystwry,Sxl-Wk'
# row: 447 col: 2 : 'Animation,Comedy,Fantasy,Mystery' changed to 'Athlatomn,Eomwcj,Fannxvf,Mysddwy'
# row: 1270 col: 2 : 'Adventure,Sci-Fi,Sport' changed to 'Asxvtturq,Vch-Xk,Sport'
# row: 993 col: 2 : 'Kids,Music' changed to 'Kidr,Murjs'
# row: 450 col: 2 : 'Hentai' changed to 'Heutwi'
# row: 65 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'Dcjlki,Svvrntlrq,Vatnwwh,Neeha'
# row: 1155 col: 2 : 'Animation,Short,Sport' changed to 'Znikzjioj,Amogy,Spocb'
# row: 1218 col: 2 : 'Comedy' changed to 'Comech'
# row: 911 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Qtlmxtlon,Evtloi,Fplfgy,Gautary,Xomause'
# row: 1478 col: 2 : 'Hentai,School' changed to 'Jejdai,Vcrmjo'
# row: 162 col: 2 : 'Fantasy,Music' changed to 'Fabtexy,Kusic'
# row: 477 col: 2 : 'Adventure,Fantasy,Kids' changed to 'Wcbetrugv,Fanrwsr,Niaa'
# row: 378 col: 2 : 'Comedy,Romance,SliceofLife' changed to 'Cpmecb,Djjajcg,VklceoyLifw'
# row: 1166 col: 2 : 'Action,Psychological,Shounen,Supernatural,Thriller' changed to 'Acyilg,Pshcmopiglfxl,Dvobken,Syitebstltel,Rjtiluxs'
# row: 747 col: 2 : 'Fantasy' changed to 'Rantqsn'
# row: 1532 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Znyiwtloh,Ejmest,Qtqka,Rokauwe'
# row: 566 col: 2 : 'Action,Comedy,Fantasy,Magic,Music,Shoujo' changed to 'Awnmjn,Cumxdy,Waitasy,Mweid,Nhric,Rhihlo'
# row: 365 col: 2 : 'Action,Comedy,Harem,Sci-Fi,Shounen,Space' changed to 'Aghlin,Clmedv,Harfm,Sdi-Wy,Xrlkben,Dpwce'
# row: 465 col: 2 : 'Animation,Comedy,Romance' changed to 'Znioathkn,Eoicby,Rpmznge'
# row: 1257 col: 2 : 'Kids' changed to 'Kids'
# row: 1040 col: 2 : 'Animation,Drama,Romance' changed to 'Xnimdcili,Ccame,Rimenxq'
# row: 866 col: 2 : 'Action,Adventure,Comedy,Mecha,Sci-Fi' changed to 'Zcjlun,Qbevntuxf,Booesg,Oechz,Sxi-Sh'
# row: 1337 col: 2 : 'Animation,Comedy' changed to 'Wmonctjok,Eokffy'
# row: 1371 col: 2 : 'Comedy,School,Shounen' changed to 'Xjmedt,Wchkou,Rhiumek'
# row: 436 col: 2 : 'Animation,Drama,Family,Music,Romance' changed to 'Akhjwtomb,Drqna,Vqknlf,Mufmc,Xomagcw'
# row: 955 col: 2 : 'Comedy' changed to 'Vojeey'
# row: 772 col: 2 : 'Sci-Fi,SliceofLife' changed to 'Sei-Yi,SoicdofNift'
# row: 456 col: 2 : 'Comedy,Kids,Mystery' changed to 'Bmjfer,Nhgd,Kfsttsf'
# row: 1304 col: 2 : 'Animation,Drama,Sport' changed to 'Cjiowtjon,Sraka,Vpkgv'
# row: 1367 col: 2 : 'Action,Drama,Shounen' changed to 'Agtlov,Ccakw,Ahoynth'
# row: 501 col: 2 : 'Action,Sci-Fi,SuperPower' changed to 'Aftimh,Sco-Fl,SuierPower'
# row: 837 col: 2 : 'Comedy,Romance' changed to 'Rllech,Rmidnce'
# row: 372 col: 2 : 'Kids,Music' changed to 'Nids,Mkwic'
# row: 829 col: 2 : 'Horror' changed to 'Vucrir'
# row: 800 col: 2 : 'Comedy,Action,Drama,Family' changed to 'Colzsy,Xxemon,Fcxma,Yemllj'
# row: 1165 col: 2 : 'Sci-Fi' changed to 'Sei-Fy'
# row: 1153 col: 2 : 'Comedy,Demons,Ecchi,Fantasy,Romance,Seinen' changed to 'Cokevv,Dfimux,Tgchn,Fenraxj,Slmwvvg,Wekndj'
# row: 641 col: 2 : 'Animation,Short' changed to 'Diikatiki,Symrc'
# row: 82 col: 2 : 'Animation' changed to 'Eghmayuot'
# row: 34 col: 2 : 'Adventure,Comedy,SliceofLife' changed to 'Advsttore,Roneet,SmhedofLkhe'
# row: 94 col: 2 : 'Drama' changed to 'Agsmw'
# row: 1204 col: 2 : 'Adventure,Comedy,Fantasy,Mystery,Sci-Fi,Shounen' changed to 'Acxemturg,Cojxdf,Hantwwh,Mywtzxy,Sru-Ni,Shounen'
# row: 1003 col: 2 : 'Drama,Family,Romance' changed to 'Crxoa,Ramimy,Romauce'
# row: 1412 col: 2 : 'Adventure,Comedy,Fantasy,Shounen' changed to 'Advakvire,Sknedt,Xakuadh,Sfunien'
# row: 1585 col: 2 : 'Hentai' changed to 'Gtktdn'
# row: 561 col: 2 : 'Comedy,Horror' changed to 'Zimedf,Howror'
# row: 651 col: 2 : 'Animation,Action,Adventure,Comedy' changed to 'Cvinqhikn,Wvvimn,Acvgnybra,Zlmddi'
# row: 1131 col: 2 : 'Action,Thriller' changed to 'Axdnkk,Trryllxr'
# row: 233 col: 2 : 'Animation,Comedy,Fantasy,Horror,Romance' changed to 'Animahnut,Womqdy,Fantaxy,Gjxror,Wjjwtxe'
# row: 560 col: 2 : 'Action' changed to 'Achion'
# row: 826 col: 2 : 'Adventure,Comedy,Fantasy,Kids,Magic' changed to 'Zdventjdd,Dmmedt,Gatjasy,Kies,Maykc'
# row: 1032 col: 2 : 'Animation,Short,Comedy,Sci-Fi' changed to 'Zvhkatykn,Snuxg,Vumadg,Aco-Dl'
# row: 1246 col: 2 : 'Animation' changed to 'Agilqfiln'
# row: 351 col: 2 : 'Animation,Short,Fantasy' changed to 'Anpmcvion,Wvoxt,Fattavy'
# row: 255 col: 2 : 'Comedy,Kids,Shounen,Space' changed to 'Comedy,Kkbs,Shjmneh,Vkage'
# row: 110 col: 2 : 'Action,Adventure,Game,Mecha,Sci-Fi,Shounen' changed to 'Csrimn,Adeejyusc,Gejr,Ischa,Adp-Fk,Sguumrn'
# row: 713 col: 2 : 'Animation,Short' changed to 'Smmmegnlk,Shoeu'
# row: 1095 col: 2 : 'Animation,Short' changed to 'Ammkatoon,Sgogt'
# row: 256 col: 2 : 'Drama,Family' changed to 'Qxama,Hdnylg'
# row: 1064 col: 2 : 'Kids' changed to 'Kida'
# row: 559 col: 2 : 'Short,Action' changed to 'Ahlvt,Accnim'
# row: 332 col: 2 : 'Hentai' changed to 'Renbdl'
# row: 1015 col: 2 : 'Animation,Drama,Fantasy,Sci-Fi' changed to 'Anynatijv,Frama,Wattaay,Swo-Xi'
# row: 1488 col: 2 : 'Animation,Short,Mystery' changed to 'Dnomcfhoj,Shpgh,Mywbcty'
# row: 1256 col: 2 : 'Action,Adventure,Samurai,Shounen' changed to 'Zbtooi,Asdagturf,Dxmurwi,Shlgngn'
# row: 1380 col: 2 : 'Animation,Action,Adventure,Family,Mystery,Thriller' changed to 'Enimetikt,Dznijg,Xqnengire,Fxmhln,Kysgrvr,Rktilleg'
# row: 277 col: 2 : 'Short' changed to 'Shoft'
# row: 1137 col: 2 : 'Drama' changed to 'Deama'
# row: 83 col: 2 : 'Comedy,Historical,Parody' changed to 'Cukvbj,Ylsturnewo,[xroqy'
# row: 810 col: 2 : 'Documentary' changed to 'Dpcblqneary'
# row: 1037 col: 2 : 'Hentai,Psychological' changed to 'Hgntan,Osnshmlohkfap'
# row: 716 col: 2 : 'Animation,Action,Adventure,Fantasy' changed to 'Zmykdyilk,Sfyljv,Cdnsjnura,Favvwsy'
# row: 1382 col: 2 : 'Adventure,Mecha,Sci-Fi,Shounen' changed to 'Sdvejfyfe,Negna,Swl-Hj,Xjjuiwg'
# row: 122 col: 2 : 'Comedy,SliceofLife' changed to 'Dimggy,SlixakxLlde'
# row: 8 col: 2 : 'Historical' changed to 'Hjdtjdlral'
# row: 425 col: 2 : 'Drama' changed to 'Deqna'
# row: 1584 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Boktsj,Favtasy,Hhdf'
# row: 1581 col: 2 : 'Comedy' changed to 'Sokedy'
# row: 1062 col: 2 : 'Animation,Drama,Family,Fantasy,Romance' changed to 'Anikqtmon,Drqmw,Hannlh,Hqngxav,Rpmaicw'
# row: 42 col: 2 : 'Documentary' changed to 'Dosumcnyctg'
# row: 232 col: 2 : 'Romance' changed to 'Romancg'
# row: 476 col: 2 : 'Animation,Short,Music' changed to 'Amimadimt,Dvkrd,Mushg'
# row: 964 col: 2 : 'Animation,Action,Comedy,Crime,Fantasy,Horror,Mystery' changed to 'Wuoiwtkjn,Asyion,Confvy,Gghma,Fegeash,Votrix,Mysgetr'
# row: 662 col: 2 : 'Animation,Comedy,Sport' changed to 'Avhiqtlpm,Coirdy,Sporg'
# row: 124 col: 2 : 'Dementia' changed to 'Dtmxnjia'
# row: 260 col: 2 : 'Hentai' changed to 'Rtjtap'
# row: 1324 col: 2 : 'Mecha,Military' changed to 'Kezhq,Jlllhavv'
# row: 1492 col: 2 : 'Hentai' changed to 'Itnuai'
# row: 1523 col: 2 : 'Action,Adventure,Fantasy,Mecha' changed to 'Wetpkt,Acvfnvute,Fanbsdf,Nrgha'
# row: 275 col: 2 : 'Animation,Short' changed to 'Zjikatooi,Shprj'
# row: 304 col: 2 : 'Comedy' changed to 'Cmkddy'
# row: 823 col: 2 : 'Animation,Action,Fantasy,Game-Show,Sci-Fi' changed to 'Wnmkadion,Wcvmon,Fqmcwdn,Dsie-Srja,Svi-Fo'
# row: 1242 col: 2 : 'Hentai' changed to 'Havuai'
# row: 1009 col: 2 : 'Animation,Short,Action' changed to 'Animation,Shutt,Awfokv'
# row: 1377 col: 2 : 'Comedy,Ecchi,Fantasy,Romance,SliceofLife' changed to 'Vomcby,Qcdhj,Rdngady,Tpjevgf,RpocsofKifr'
# row: 915 col: 2 : 'Drama' changed to 'Drwme'
# row: 411 col: 2 : 'Short,Drama' changed to 'Fhord,Drama'
# row: 183 col: 2 : 'Animation' changed to 'Zblkatiij'
# row: 565 col: 2 : 'Animation,Comedy' changed to 'Xnymatikn,Domeay'
# row: 380 col: 2 : 'Comedy,Sports' changed to 'Romevn,Xpogjs'
# row: 517 col: 2 : 'Animation,Action,Adventure,Sci-Fi,Thriller' changed to 'Znpmxeiug,Dxbkjv,Safennure,Xcm-Wi,Jhfiolcw'
# row: 1083 col: 2 : 'Ecchi,Music' changed to 'Wcdhi,Igsic'
# row: 1303 col: 2 : 'Animation' changed to 'Enoownppg'
# row: 803 col: 2 : 'Animation,Comedy,Drama,Fantasy,Horror,Mystery' changed to 'Anlmejimj,Comsbr,Cgajx,Datjwab,Imtrlg,Inatefb'
# row: 963 col: 2 : 'Action,Adventure' changed to 'Ewrokn,Ebfxnnhde'
# row: 538 col: 2 : 'Comedy,Ecchi' changed to 'Cmjeay,Dechj'
# row: 139 col: 2 : 'Short' changed to 'Xforv'
# row: 1435 col: 2 : 'Animation,Sci-Fi' changed to 'Qnikahiob,Xri-Fi'
# row: 1452 col: 2 : 'Animation,Action,Adventure,Fantasy,Sci-Fi' changed to 'Atlmayhpk,Wrtlon,Advekguwe,Fandaxv,Sci-Fo'
# row: 159 col: 2 : 'Animation,Comedy,Fantasy,Romance' changed to 'Cmpketimu,Coirfy,Fzmtwdy,Rpmzkef'
# row: 1469 col: 2 : 'Hentai' changed to 'Keutep'
# row: 290 col: 2 : 'Hentai' changed to 'Veitao'
# row: 41 col: 2 : 'Animation,Short,Comedy' changed to 'Whomatojv,Vvort,Cmmvsy'
# row: 536 col: 2 : 'Animation,Short' changed to 'Cnomddlog,Shkgb'
# row: 13 col: 2 : 'Action,Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'Esgiin,Evnenbufr,Rokedf,Ewbji,Mzchx,Rfj-Si,Spqcw'
# row: 628 col: 2 : 'Comedy,Mecha,Parody' changed to 'Comedr,Mzcrw,Oarlay'
# row: 1422 col: 2 : 'Action,Music' changed to 'Zwtiuh,Mmshc'
# row: 661 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Cnimatkon,Actlon,Sbm-Hi'
# row: 942 col: 2 : 'Comedy,Sci-Fi' changed to 'Cmieby,Szu-Wi'
# row: 630 col: 2 : 'Comedy,Demons,Horror,Mystery,Supernatural,Vampire' changed to 'Clkefg,Agkons,Rpsrpg,Lyftzey,Flpdrnathrql,Gsipjrw'
# row: 603 col: 2 : 'Short,Drama,Sci-Fi' changed to 'Wnptt,Ctwka,Rco-Gi'
# row: 1250 col: 2 : 'Animation,Action,Comedy' changed to 'Anjiqthjn,Cejipn,Eolcgj'
# row: 410 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Fantasy,History,Romance,Thriller' changed to 'Euliwtiin,Xftykn,Cgyrnvyre,Comfdt,Crsma,Fcttxwy,Hiwtkey,Rilcgce,Chtpnler'
# row: 1352 col: 2 : 'Hentai' changed to 'Ienyai'
# ...
# row: 1344 col: 2 : 'Hentai' changed to 'Yvktam'
# row: 238 col: 2 : 'Animation' changed to 'Wnkoxypkn'
# row: 248 col: 2 : 'Music' changed to 'Iuviw'
# row: 1029 col: 2 : 'Animation,Short,Action,Sci-Fi' changed to 'Cbimatiov,Siort,Wxbiom,Sci-Wi'
# row: 199 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family,Fantasy,Sci-Fi,Thriller' changed to 'Anpmatijn,Axtuog,Wgvwmtbte,Clmagy,Drznw,Xdmioy,Fwnvadg,Sci-Fu,Tkgkmler'
# row: 1553 col: 2 : 'Drama,Fantasy,Mystery,Romance,School' changed to 'Qrana,Fautwsi,Mgftary,Cijsnxv,Swjpol'
# row: 168 col: 2 : 'Drama' changed to 'Dxeka'
# row: 1329 col: 2 : 'Animation' changed to 'Wnlkxruin'
# row: 1142 col: 2 : 'Animation,Comedy,Drama,Fantasy,Romance' changed to 'Wkimwtkok,Voicdy,Bgwkq,Fsntasy,Roictbq'
# row: 413 col: 2 : 'Drama,Fantasy,Mystery' changed to 'Vgaix,Ncgbzxu,Mjftxrv'
# row: 1428 col: 2 : 'Animation,Short' changed to 'Wtniayiin,Shkgt'
# row: 496 col: 2 : 'Animation,Drama,Music' changed to 'Aummabiuh,Arsma,Mydie'
# row: 482 col: 2 : 'Comedy' changed to 'Womeai'
# row: 249 col: 2 : 'Action,MartialArts' changed to 'Drvipm,MaerkwnArta'
# row: 737 col: 2 : 'Comedy,Harem,Music,Romance,Shoujo' changed to 'Elmtvv,Hwvrl,Iisle,Xknandw,Vhokhl'
# row: 1215 col: 2 : 'Animation,Short' changed to 'Avioafpln,Shoxb'
# row: 968 col: 2 : 'Comedy,School,Shounen,Supernatural' changed to 'Vjjvay,Szilol,Dhotnfb,Wypsruadtrel'
# row: 869 col: 2 : 'Sport' changed to 'Spmeh'
# row: 757 col: 2 : 'Documentary' changed to 'Eorulentzfj'
# row: 382 col: 2 : 'Action,Adventure,Demons,Fantasy,Game,Kids,Magic,Sci-Fi,Supernatural' changed to 'Asjjon,Adcqjtuft,Bdkona,Fakyaay,Game,Hhsf,Oacpb,Ssl-Xi,Agpdgkwtidqm'
# row: 951 col: 2 : 'Hentai' changed to 'Hegtaj'
# row: 1364 col: 2 : 'Action,Comedy,Ecchi,Shounen,Sports' changed to 'Zrnjin,Somedy,Ecehm,Vnounet,Fpkdvr'
# row: 282 col: 2 : 'Action,Mecha,Romance' changed to 'Ectjkt,Kecha,Gomenwe'
# row: 27 col: 2 : 'Adventure,Comedy,Mystery,Police,Shounen' changed to 'Wdvrtftcc,Xporgy,Mbfterb,Polixe,Shookdn'
# row: 1477 col: 2 : 'Kids' changed to 'Njds'
# row: 733 col: 2 : 'Adventure,Historical,Sci-Fi' changed to 'Ddfsutofe,Fiaturiwcp,Sfy-Fo'
# row: 789 col: 2 : 'Comedy' changed to 'Dikedn'
# row: 1331 col: 2 : 'Comedy,Drama,Romance,Sci-Fi,SliceofLife' changed to 'Comfvy,Drzma,Ronxnce,Sxm-Gi,RljeeinLinr'
# row: 1101 col: 2 : 'Animation,Family,Drama' changed to 'Wgimxgiog,Sskoly,Grama'
# row: 1446 col: 2 : 'Action,Comedy,Fantasy,Shounen,SuperPower' changed to 'Zcuiun,Coieey,Fznvadb,Shotnxn,Stpzd[oxsr'
# row: 295 col: 2 : 'Hentai' changed to 'Hengdm'
# row: 613 col: 2 : 'Animation,Short,Music' changed to 'Abjoadupn,Rhort,Lnruv'
# row: 189 col: 2 : 'Animation,Short' changed to 'Agikatmph,Xikft'
# row: 719 col: 2 : 'Adventure,Comedy,Ecchi,Mecha,Sci-Fi,Space' changed to 'Qseektyca,Zonedy,Ecrmy,Jfcne,Scm-Fi,Rpcsd'
# row: 583 col: 2 : 'Comedy,Kids' changed to 'Comedh,Kids'
# row: 91 col: 2 : 'Drama,Historical,SliceofLife' changed to 'Dtsmq,Hldfmdicxm,WjirtovLiht'
# row: 656 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'Dnumsvipv,Skigt,Actiun,Wfxentugf,Dantssf'
# row: 1501 col: 2 : 'Comedy,SliceofLife' changed to 'Zoixdy,SlierpxLjwe'
# row: 1393 col: 2 : 'Comedy,Parody' changed to 'Zomegg,[drldg'
# row: 1005 col: 2 : 'Comedy' changed to 'Comggy'
# row: 815 col: 2 : 'Animation,Short,Action,Adventure,Fantasy' changed to 'Qhiiaripv,Showj,Czhlmn,Wdtsnuurs,Fantasy'
# row: 302 col: 2 : 'Crime,Mystery,Thriller' changed to 'Crlme,Iyftwgt,Thsmlkwr'
# row: 778 col: 2 : 'Horror' changed to 'Norrjd'
# row: 16 col: 2 : 'Action,Adventure,Comedy,Magic,Mecha,Sci-Fi' changed to 'Azvkik,Xvvenhlcw,Cpmedg,Kahif,Mtcha,Wcu-Ri'
# row: 1333 col: 2 : 'Short,Sci-Fi' changed to 'Rhort,Azi-Di'
# row: 852 col: 2 : 'Comedy,School' changed to 'Cokzqv,Xdmllk'
# row: 371 col: 2 : 'Romance,Sports' changed to 'Xpkahwx,D[pgfs'
# row: 1021 col: 2 : 'Hentai' changed to 'Makfqi'
# row: 1211 col: 2 : 'Adventure,Comedy,Fantasy,Magic' changed to 'Adgsnfbrt,Cjnfdi,Namtwsy,Mcgyg'
# row: 1071 col: 2 : 'Fantasy' changed to 'Fatgssi'
# row: 841 col: 2 : 'Hentai' changed to 'Gehbao'
# row: 552 col: 2 : 'Animation' changed to 'Akikatnog'
# row: 612 col: 2 : 'Adventure,Drama,Fantasy' changed to 'Abbentutr,Dwamc,Fzibasy'
# row: 851 col: 2 : 'Comedy,Fantasy' changed to 'Cokeqi,Hztfqvj'
# row: 1124 col: 2 : 'Animation,Family' changed to 'Anukagikn,Fdomnn'
# row: 577 col: 2 : 'Drama' changed to 'Drdow'
# row: 1374 col: 2 : 'Hentai' changed to 'Fendau'
# row: 1429 col: 2 : 'Hentai' changed to 'Kfntai'
# row: 463 col: 2 : 'Comedy,Drama,Romance' changed to 'Bpkedu,Cdzma,Xomcmca'
# row: 1039 col: 2 : 'Comedy,Romance' changed to 'Zpnrby,Romsucg'
# row: 1458 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy' changed to 'Anikatmov,Acriji,Wdbenebse,Fjiedy,Fxgdqfy'
# row: 1298 col: 2 : 'Music' changed to 'Muvpc'
# row: 857 col: 2 : 'Action,Sci-Fi' changed to 'Xwtjob,Ack-Fi'
# row: 654 col: 2 : 'Action,Fantasy,Magic,Shounen' changed to 'Action,Fstyzvy,Oacub,Shjlbqn'
# row: 28 col: 2 : 'Comedy,Ecchi,School' changed to 'Cokeei,Vcvhj,Sbhumk'
# row: 587 col: 2 : 'Animation,Action,Horror,Romance' changed to 'Cknmayiku,Acjhob,Hpgrot,Rkmemrs'
# row: 1260 col: 2 : 'Comedy' changed to 'Xkjecj'
# row: 821 col: 2 : 'Action,Drama,Seinen' changed to 'Xcjijj,Dralz,Swinev'
# row: 987 col: 2 : 'Animation,Music' changed to 'Snlmqhion,Jisox'
# row: 584 col: 2 : 'Hentai' changed to 'Jejdai'
# row: 478 col: 2 : 'Comedy,SliceofLife' changed to 'Comddn,AokcgovMife'
# row: 457 col: 2 : 'Drama,Family' changed to 'Dramc,Fammly'
# row: 309 col: 2 : 'Comedy' changed to 'Ekmeer'
# row: 507 col: 2 : 'Comedy,Romance' changed to 'Culegn,Rolancg'
# row: 498 col: 2 : 'Drama' changed to 'Dtaka'
# row: 181 col: 2 : 'Animation,Family,Comedy,Fantasy' changed to 'Stlkxtilb,Faminf,Conecg,Nxnnwsy'
# row: 126 col: 2 : 'Comedy,Magic,Supernatural' changed to 'Ciovdb,Ladhc,Fy'efnxgmrcn'
# row: 1284 col: 2 : 'Hentai' changed to 'Hagtai'
# row: 90 col: 2 : 'Action,Drama' changed to 'Zcuiib,Deame'
# row: 1462 col: 2 : 'Hentai' changed to 'Memfay'
# row: 952 col: 2 : 'Crime,Drama,Thriller' changed to 'Cfije,Bgame,Tvrllmcr'
# row: 992 col: 2 : 'Animation,Comedy,Romance' changed to 'Wnmmation,Eomedy,Romdbce'
# row: 218 col: 2 : 'Comedy,Ecchi,Kids,School,Shounen,SliceofLife' changed to 'Conesy,Ecchi,Nkfs,Rvnjpl,Dmounwj,AlmceoyLufe'
# row: 45 col: 2 : 'Documentary,Short' changed to 'Dmcjmevuery,Dklrt'
# row: 775 col: 2 : 'Adventure,Comedy,Demons,Fantasy,Magic,Romance,Shounen,Supernatural' changed to 'Evrfntltw,Sokfdy,Demojx,Datgadr,Madpc,Fomwnvg,Riubgwj,Supetnauutam'
# row: 884 col: 2 : 'Adventure' changed to 'Cbvwnuuwa'
# row: 602 col: 2 : 'Animation,Short' changed to 'Xnomwhiov,Sfort'
# row: 1192 col: 2 : 'Music,Space' changed to 'Iuxic,Apcce'
# row: 657 col: 2 : 'Kids,Music' changed to 'Hndw,Kuskb'
# row: 293 col: 2 : 'Kids' changed to 'Kids'
# row: 674 col: 2 : 'Comedy,Ecchi,Romance' changed to 'Cmledi,Tccfi,Rpoxnde'
# row: 919 col: 2 : 'Romance,Shoujo' changed to 'Roiahce,Dviubo'
# row: 152 col: 2 : 'Adventure,Sci-Fi' changed to 'Zvvahgmee,Xrk-Du'
# row: 1528 col: 2 : 'Drama,Shounen,Sports' changed to 'Dtaoa,Sronnvi,Vpofns'
# row: 1143 col: 2 : 'Comedy,Short' changed to 'Fpmeey,Xhoru'
# row: 1276 col: 2 : 'Animation,Comedy,Romance' changed to 'Eiikahhkn,Comfgy,Gjmwncx'
# row: 1405 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Ajimwcyon,Wvtkov,Sco-Yi'
# row: 908 col: 2 : 'Adventure,Comedy,Fantasy,Kids' changed to 'Wqventjvt,Cimeff,Ysncasg,Nogs'
# row: 666 col: 2 : 'Thriller' changed to 'Ykrknmqs'
# row: 57 col: 2 : 'Drama,Romance,Yaoi' changed to 'Fgxmw,Domajvf,Ysml'
# row: 972 col: 2 : 'Animation' changed to 'Zbnmeujoj'
# row: 574 col: 2 : 'Action,Adventure,Sci-Fi' changed to 'Xvhiun,Adnwneudt,Wbi-Gi'
# row: 421 col: 2 : 'Hentai' changed to 'Hzgfay'
# row: 1264 col: 2 : 'Hentai' changed to 'Jvneci'
# row: 391 col: 2 : 'Comedy,SliceofLife' changed to 'Clmddy,AlkgcmfLlfe'
# row: 504 col: 2 : 'Comedy' changed to 'Ckmgdn'
# row: 1148 col: 2 : 'Animation,Drama,Sport' changed to 'Animqtuoi,Eramc,Rposc'
# row: 991 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Anometjoi,Cpmwdy,Fagczsu'
# row: 271 col: 2 : 'Kids,Sci-Fi' changed to 'Lhca,Wdi-Xk'
# row: 1183 col: 2 : 'Hentai' changed to 'Hwngzi'
# row: 1321 col: 2 : 'Animation,Adventure,Comedy,Sci-Fi' changed to 'Whuowdiot,Advenftfx,Ckotdf,Wwl-Dy'
# row: 585 col: 2 : 'Animation,Action,Adventure,Comedy,Family,Fantasy' changed to 'Dnikavhon,Xdtoon,Qsvejbucx,Cjmwqy,Nznimj,Fannwsy'
# row: 1560 col: 2 : 'Sci-Fi' changed to 'Rri-Fm'
# row: 1268 col: 2 : 'Comedy,Game,Space' changed to 'Cukfcy,Gane,X'abx'
# row: 967 col: 2 : 'Short' changed to 'Snktt'
# row: 1171 col: 2 : 'Animation,Sci-Fi' changed to 'Znijauikb,Scu-Yi'
# row: 98 col: 2 : 'Game-Show,Talk-Show' changed to 'Gake-Sioq,Tapy-Fviw'
# row: 1434 col: 2 : 'Animation,Short' changed to 'Abiiwuikb,Sfift'
# row: 534 col: 2 : 'Comedy,Hentai,Yuri' changed to 'Conxdr,Hqmtai,Ulfi'
# row: 985 col: 2 : 'Animation' changed to 'Wkilatikn'
# row: 1209 col: 2 : 'Action,Adventure,Fantasy,Shounen' changed to 'Avhiot,Avneghmwe,Fqncadr,Ahokuen'
# row: 1442 col: 2 : 'Animation,Action,Comedy,Crime,Drama,Romance' changed to 'Xbimatiph,Agbhpi,Cklegy,Csime,Srcls,Cjmwnxv'
# row: 1162 col: 2 : 'Animation' changed to 'Dninaflin'
# row: 1267 col: 2 : 'Action,Sci-Fi' changed to 'Aetikn,Wcp-Ym'
# row: 725 col: 2 : 'Action,Josei,Supernatural' changed to 'Dctmmn,Npfqi,Stpetnatuswl'
# row: 739 col: 2 : 'Animation,Drama,Family' changed to 'Agymahjjt,Dramz,Vamimy'
# row: 1075 col: 2 : 'Animation,Action,Adventure,Comedy,Drama,Family' changed to 'Wkjkatkon,Xrnion,Avedifyre,Ckjfdt,Gdamw,Xwiikr'
# row: 347 col: 2 : 'Comedy' changed to 'Zoieqn'
# row: 1136 col: 2 : 'School' changed to 'Rchlpn'
# row: 944 col: 2 : 'Animation' changed to 'Wtimqvion'
# row: 593 col: 2 : 'Action,Drama,Fantasy,Horror,Mystery,Sci-Fi' changed to 'Xcthmn,Etakz,Fwkraaf,Hlrcms,Kyrtdfy,Scm-Fi'
# row: 149 col: 2 : 'Documentary,Music' changed to 'Eobumvmnaru,Mgrmd'
# row: 746 col: 2 : 'Animation' changed to 'Abykwbkon'
# row: 608 col: 2 : 'Adventure' changed to 'Avrdvtutf'
# row: 925 col: 2 : 'Animation,Action,Crime,Drama,Horror,Mystery,Thriller' changed to 'Ahimatiuk,Action,Criie,Dfaow,Hodxor,Kisceey,Tkrilmer'
# row: 397 col: 2 : 'Kids' changed to 'Knda'
# row: 170 col: 2 : 'Adventure,Crime,Drama' changed to 'Wbvcntlre,Ffima,Dvsna'
# row: 459 col: 2 : 'Short,Sci-Fi,War' changed to 'Dnkct,Sci-Fl,Xdf'
# row: 1053 col: 2 : 'Comedy,Drama,Police,Romance' changed to 'Zojfdy,Drama,Punnde,Tojetcg'
# row: 349 col: 2 : 'Adventure,Comedy,Drama,Fantasy,Historical,Romance' changed to 'Wdvencurq,Comesu,Draia,Favyefh,Kisylrixak,Cinshfe'
# row: 385 col: 2 : 'Animation,Action,Sci-Fi' changed to 'Avhodtiov,Actmov,Vci-Sm'
# row: 128 col: 2 : 'Animation,Action,Comedy,Fantasy,Romance' changed to 'Cnunatmoh,Avdylt,Cimfby,Gantasy,Sooskcr'
# row: 191 col: 2 : 'Comedy,Parody' changed to 'Vjlgvy,Ixdoci'
# row: 212 col: 2 : 'Comedy,Ecchi,Harem,Romance' changed to 'Gomeci,Gcdnl,Mzrvj,Rujanvv'
# row: 1210 col: 2 : 'Adventure,Fantasy,Sci-Fi,Shounen' changed to 'Abvfnvuez,Gattasy,Fci-Yj,Snonieh'
# row: 1586 col: 2 : 'Animation,Horror' changed to 'Cnlmshhib,Hovror'
# row: 250 col: 2 : 'Comedy,Parody' changed to 'Djjqgf,Pwgjby'
# row: 176 col: 2 : 'Animation,Comedy' changed to 'Wnljxtlkn,Fumeag'
# row: 1580 col: 2 : 'Hentai' changed to 'Heitci'
# row: 541 col: 2 : 'Animation,Sci-Fi' changed to 'Enioztooh,Dxl-Fo'
# row: 720 col: 2 : 'Fantasy,Magic,Shoujo' changed to 'Vwntway,Msdic,Dnobno'
# row: 1241 col: 2 : 'Animation,Short,Comedy,Romance' changed to 'Avoistopk,Whoet,Vmkedy,Sjksnce'
# row: 1187 col: 2 : 'Mecha,Sports' changed to 'Kggnd,Rpurff'
# row: 1383 col: 2 : 'Horror,Sci-Fi' changed to 'Rorrut,Wci-Fu'
# row: 328 col: 2 : 'Animation,Comedy' changed to 'Zglmahiin,Gokedy'
# row: 686 col: 2 : 'Short' changed to 'Drjct'
# row: 1082 col: 2 : 'Fantasy,Kids' changed to 'Fenudvh,Nids'
# row: 400 col: 2 : 'Adventure,Comedy,Fantasy' changed to 'Advzjgkrv,Rpkzqj,Wabjsay'
# row: 1350 col: 2 : 'Comedy,Seinen,SliceofLife' changed to 'Coiesb,Remmcn,SmidelgLkne'
# row: 1365 col: 2 : 'Animation,Comedy' changed to 'Qghmatikt,Ckmacy'
# row: 1497 col: 2 : 'Action,Adventure,Demons,Game,Shounen' changed to 'Ashnku,Acyzvttre,Bqmiiw,Gama,Shojggg'
# row: 47 col: 2 : 'Action,Adventure,Comedy,Drama,Fantasy,Kids' changed to 'Sxjion,Zdvwinufq,Cpmedt,Dvama,Xdnyavi,Imdx'
# row: 605 col: 2 : 'Comedy,Romance,School,Shoujo' changed to 'Comqfy,Romxvxe,Sdjuom,Skouto'
# row: 1240 col: 2 : 'Hentai' changed to 'Jcntzl'
# row: 1449 col: 2 : 'Animation,Short,Adventure,Fantasy' changed to 'Anikqgyjn,Short,Adxendbrt,Davtqvy'
# row: 1269 col: 2 : 'Comedy,Fantasy,Kids' changed to 'Glifvg,Hamfwfy,Klgf'
# row: 1035 col: 2 : 'Animation,Adventure,Drama,Fantasy' changed to 'Abikefjoi,Qgvsgfyde,Frzmw,Fdttwsn'
# row: 1292 col: 2 : 'Adventure,Comedy,Fantasy,Mecha,Shounen' changed to 'Advztvhte,Gojadj,Faktarv,Ierra,Skolnen'
# row: 1094 col: 2 : 'Animation,Sci-Fi' changed to 'Anpnwtlln,Sgp-Fi'
# row: 1152 col: 2 : 'Comedy,SliceofLife' changed to 'Comcbj,SuldxodLiff'
# row: 554 col: 2 : 'Adventure,Fantasy' changed to 'Addsnturs,Fajtavu'
# row: 807 col: 2 : 'Animation,Comedy,Drama,Romance' changed to 'Anjiatlon,Cuicej,Draie,Gknamce'
# row: 889 col: 2 : 'Action,Hentai,Supernatural' changed to 'Awtikk,Hqnhqi,Siicrnattrwu'
# row: 677 col: 2 : 'Drama,Romance' changed to 'Edwmx,Glnabcz'
# row: 629 col: 2 : 'Adventure,Comedy,Horror,Shounen,Supernatural' changed to 'Wagcnvuxs,Eokedy,Vocdpt,Dnotmsi,Suocfndtutal'
# row: 542 col: 2 : 'Animation,Short' changed to 'Ciimagimn,Srlet'
# row: 894 col: 2 : 'Comedy' changed to 'Clmgfj'
# row: 845 col: 2 : 'Music' changed to 'Muslz'
# row: 444 col: 2 : 'Animation,Short,Fantasy' changed to 'Euimatiin,Shovn,Rshtssy'
# row: 914 col: 2 : 'Comedy,SliceofLife' changed to 'Ckovdn,DlibvodLife'
# row: 597 col: 2 : 'Animation,Family' changed to 'Wnimctoin,Gqlimh'
# row: 100 col: 2 : 'Action,Family,Adventure,Comedy,Fantasy' changed to 'Zetiuu,Fwoily,Esvsmtuge,Eomvej,Fwngaay'
# row: 270 col: 2 : 'Comedy' changed to 'Comvdu'
# row: 375 col: 2 : 'Animation' changed to 'Anlnavumm'
# row: 29 col: 2 : 'Hentai' changed to 'Ygnrai'
# row: 1052 col: 2 : 'Comedy,School,Shounen' changed to 'Fomgdy,Sdhooo,Fkpmnen'
# row: 932 col: 2 : 'Action,ShounenAi,Supernatural' changed to 'Acfyon,WhoknqkAi,Sypsrtarural'
# row: 285 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Sci-Fi' changed to 'Qnimaviln,Avrkon,Addeknhrx,Glledi,Vanrwsr,Wru-Fk'
# row: 1289 col: 2 : 'Animation,Short' changed to 'Zvlmqfikn,Vhigr'
# row: 70 col: 2 : 'Comedy,Ecchi,Romance,School,Seinen,Sports' changed to 'Dpmsgt,Xzrni,Roiauce,Rcrooj,Xepheb,Vpovtf'
# row: 631 col: 2 : 'Fantasy' changed to 'Wantdsu'
# row: 755 col: 2 : 'Animation,Action,Adventure,Comedy,Fantasy,Romance' changed to 'Dnnjwtiju,Cenipv,Evvegfjeq,Cojxdy,Fqhewsf,Rlksbcf'
# row: 1385 col: 2 : 'Animation,Action,Comedy,Drama,Fantasy,Romance,Thriller' changed to 'Znplatlln,Actlot,Zojeqy,Dgqjx,Febtasy,Foiande,Ghtmuntr'
# row: 415 col: 2 : 'SliceofLife' changed to 'SkldvufMifz'
# row: 1416 col: 2 : 'Animation,Sci-Fi,Action,Crime,Fantasy,Thriller' changed to 'Wnnmzryin,Scl-Fk,Dccloh,Grnoe,Fwmbasy,Dvrkjkxr'
# row: 933 col: 2 : 'Animation' changed to 'Enikatyog'
# row: 758 col: 2 : 'Mecha,Military,Sci-Fi,Space' changed to 'Mcbre,Lijpudsf,Scl-Fy,Vlacx'
# row: 702 col: 2 : 'Demons,Fantasy,Hentai,Horror,Sci-Fi' changed to 'Dejigs,Sabtwsu,Hekrxj,Ipcgod,Wgh-Dn'
# row: 194 col: 2 : 'Animation,Action,Fantasy,Sci-Fi' changed to 'Abjnahyjv,Cwfioj,Xdngasy,Scl-Fo'
# row: 1189 col: 2 : 'Animation,Action,Drama,Fantasy,Horror,Thriller' changed to 'Animxdikb,Aehioi,Dramc,Fzhhaaj,Yicrox,Tiryller'
# row: 1561 col: 2 : 'Music' changed to 'Mmsnf'
# row: 1099 col: 2 : 'Animation,Short,Action,Adventure,Sci-Fi' changed to 'Dmuianipn,Shjxh,Ccciou,Adnvkclre,Fci-Fk'
# row: 571 col: 2 : 'Hentai' changed to 'Henveo'
# row: 312 col: 2 : 'Animation,Comedy,Fantasy' changed to 'Wnimqvojm,Vokfdt,Yamtawg'
# row: 153 col: 2 : 'Animation,Comedy,Drama' changed to 'Evijxtuot,Rumrdy,Dvamz'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1548, 10527)
# (23, 10527)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1548, 10526)
# (23, 10526)
# (1548, 700)
# (23, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.11
# Mean squared error: 1.37
# Variance score: -15.04

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.31
# Mean squared error: 1.75
# Variance score: -24.99

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.982 1.038 1.042 0.903 1.117]
# Mean: 1.0163364571857305
# Standard deviation: 0.07105670183925278

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.01}
# The mean squared Error is: 0.89

# %%
clf = training(model = linear_model.Lasso(alpha = 0.01), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.10
# Mean squared error: 1.36
# Variance score: -14.71

# %% [markdown]
# ### Evaluation the repairing of different methods on different amount of error in the data

# %% [markdown]
# ### Replace with the most frequented Word

# %%
plt.xlabel('Error Ratio in the Data (%)')
plt.ylabel('MSE')

plt.ylim(0.80, 0.90)
plt.bar([5, 10, 30, 50, 75], [0.85, 0.85, 0.84, 0.84, 0.83])
plt.yticks([0.85, 0.84, 0.83])
plt.show()

# %% [markdown]
# ### Drop

# %%
plt.xlabel('Error Ratio in the Data (%)')
plt.ylabel('MSE')

plt.ylim(0.80, 1)
plt.bar([5, 10, 30, 50, 75], [0.85, 0.85,0.88,0.90,0.95 ])
plt.yticks([0.85,0.88,0.90,0.95])
plt.show()

# %% [markdown]
# ### Use Dict

# %%
plt.xlabel('Error Ratio in the Data (%)')
plt.ylabel('MSE')

plt.ylim(0.80, 1)
plt.bar([5, 10, 30, 50, 75], [0.87, 0.91, 0.94, 1.02,1.04])
plt.yticks([0.87,0.91,0.94,1.02,1.04])
plt.show()

# %% [markdown]
# ### Use pattern library

# %%
plt.xlabel('Error Ratio in the Data (%)')
plt.ylabel('MSE')

plt.ylim(0.90, 1)
plt.bar([5, 10, 30, 50, 75], [0.91,0.95, 1.01, 1.02,1.02])
plt.yticks([0.91,1.02, 0.95, 1.01])
plt.show()
