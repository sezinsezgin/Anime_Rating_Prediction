# %% [markdown]
# ## Import Data

# %%
import numpy as np
#import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# /Users/sezin/.local/share/virtualenvs/dsa-DC4ML-_HMLejDF/lib/python3.7/site-packages/chainer-6.0.0a1-py3.7.egg/chainer/_environment_check.py:41: UserWarning: Accelerate has been detected as a NumPy backend library.
# vecLib, which is a part of Accelerate, is known not to work correctly with Chainer.
# We recommend using other BLAS libraries such as OpenBLAS.
# For details of the issue, please see
# https://docs.chainer.org/en/stable/tips.html#mnist-example-does-not-converge-in-cpu-mode-on-mac-os-x.
#
# Also note that Chainer does not officially support Mac OS X.
# Please use it at your own risk.
#
#   ''')  # NOQA

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []



anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        row['type'] = np.nan
    elif float(row['episodes']) != 1:
            row['type'] = "tv series"
    else:
            row['type'] = "movie"
    l3.append(row['type'])   

    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("TrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Random_Active_Domain(),50, ignored_columns = [0,1,2,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Random_Active_Domain().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Random_Active_Domain().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to random_active_domain method ---------------
#
# row: 1487 col: 3 : 'movie' changed to 'movie'
# row: 877 col: 3 : 'movie' changed to 'tv series'
# row: 1568 col: 3 : 'movie' changed to 'tv series'
# row: 1245 col: 3 : 'tv series' changed to 'tv series'
# row: 728 col: 3 : 'movie' changed to 'movie'
# row: 207 col: 3 : 'tv series' changed to 'tv series'
# row: 990 col: 3 : 'tv series' changed to 'tv series'
# row: 190 col: 3 : 'movie' changed to 'movie'
# row: 175 col: 3 : 'movie' changed to 'tv series'
# row: 1123 col: 3 : 'movie' changed to 'tv series'
# row: 505 col: 3 : 'movie' changed to 'movie'
# row: 1491 col: 3 : 'movie' changed to 'movie'
# row: 824 col: 3 : 'movie' changed to 'tv series'
# row: 1286 col: 3 : 'tv series' changed to 'tv series'
# row: 898 col: 3 : 'tv series' changed to 'tv series'
# row: 850 col: 3 : 'movie' changed to 'movie'
# row: 295 col: 3 : 'movie' changed to 'tv series'
# row: 311 col: 3 : 'tv series' changed to 'movie'
# row: 368 col: 3 : 'movie' changed to 'tv series'
# row: 1416 col: 3 : 'movie' changed to 'movie'
# row: 874 col: 3 : 'tv series' changed to 'movie'
# row: 1553 col: 3 : 'tv series' changed to 'tv series'
# row: 121 col: 3 : 'movie' changed to 'tv series'
# row: 479 col: 3 : 'movie' changed to 'movie'
# row: 1276 col: 3 : 'tv series' changed to 'movie'
# row: 307 col: 3 : 'tv series' changed to 'tv series'
# row: 1535 col: 3 : 'movie' changed to 'movie'
# row: 652 col: 3 : 'movie' changed to 'tv series'
# row: 463 col: 3 : 'tv series' changed to 'movie'
# row: 1571 col: 3 : 'tv series' changed to 'tv series'
# row: 128 col: 3 : 'movie' changed to 'movie'
# row: 1373 col: 3 : 'movie' changed to 'tv series'
# row: 1031 col: 3 : 'movie' changed to 'tv series'
# row: 1063 col: 3 : 'tv series' changed to 'tv series'
# row: 78 col: 3 : 'movie' changed to 'tv series'
# row: 829 col: 3 : 'movie' changed to 'tv series'
# row: 769 col: 3 : 'movie' changed to 'tv series'
# row: 25 col: 3 : 'movie' changed to 'movie'
# row: 1586 col: 3 : 'movie' changed to 'tv series'
# row: 768 col: 3 : 'movie' changed to 'tv series'
# row: 661 col: 3 : 'tv series' changed to 'movie'
# row: 1348 col: 3 : 'movie' changed to 'movie'
# row: 122 col: 3 : 'movie' changed to 'movie'
# row: 61 col: 3 : 'tv series' changed to 'movie'
# row: 936 col: 3 : 'movie' changed to 'tv series'
# row: 1060 col: 3 : 'movie' changed to 'tv series'
# row: 890 col: 3 : 'tv series' changed to 'tv series'
# row: 932 col: 3 : 'movie' changed to 'movie'
# row: 545 col: 3 : 'tv series' changed to 'tv series'
# row: 382 col: 3 : 'movie' changed to 'tv series'
# row: 642 col: 3 : 'tv series' changed to 'movie'
# row: 412 col: 3 : 'movie' changed to 'tv series'
# row: 1144 col: 3 : 'tv series' changed to 'tv series'
# row: 881 col: 3 : 'tv series' changed to 'tv series'
# row: 210 col: 3 : 'movie' changed to 'movie'
# row: 739 col: 3 : 'movie' changed to 'movie'
# row: 293 col: 3 : 'tv series' changed to 'tv series'
# row: 72 col: 3 : 'tv series' changed to 'movie'
# row: 1591 col: 3 : 'tv series' changed to 'movie'
# row: 1402 col: 3 : 'tv series' changed to 'tv series'
# row: 812 col: 3 : 'movie' changed to 'movie'
# row: 79 col: 3 : 'tv series' changed to 'movie'
# row: 50 col: 3 : 'tv series' changed to 'movie'
# row: 491 col: 3 : 'tv series' changed to 'tv series'
# row: 306 col: 3 : 'movie' changed to 'tv series'
# row: 1569 col: 3 : 'tv series' changed to 'tv series'
# row: 837 col: 3 : 'tv series' changed to 'movie'
# row: 956 col: 3 : 'tv series' changed to 'movie'
# row: 1395 col: 3 : 'tv series' changed to 'movie'
# row: 370 col: 3 : 'movie' changed to 'movie'
# row: 456 col: 3 : 'movie' changed to 'movie'
# row: 426 col: 3 : 'movie' changed to 'tv series'
# row: 477 col: 3 : 'tv series' changed to 'tv series'
# row: 755 col: 3 : 'movie' changed to 'tv series'
# row: 939 col: 3 : 'tv series' changed to 'tv series'
# row: 304 col: 3 : 'movie' changed to 'tv series'
# row: 1222 col: 3 : 'movie' changed to 'movie'
# row: 844 col: 3 : 'tv series' changed to 'movie'
# row: 508 col: 3 : 'tv series' changed to 'tv series'
# row: 328 col: 3 : 'movie' changed to 'tv series'
# row: 448 col: 3 : 'movie' changed to 'movie'
# row: 1526 col: 3 : 'tv series' changed to 'movie'
# row: 1044 col: 3 : 'tv series' changed to 'tv series'
# row: 647 col: 3 : 'tv series' changed to 'tv series'
# row: 1357 col: 3 : 'tv series' changed to 'movie'
# row: 1325 col: 3 : 'movie' changed to 'tv series'
# row: 1281 col: 3 : 'tv series' changed to 'tv series'
# row: 191 col: 3 : 'tv series' changed to 'movie'
# row: 1566 col: 3 : 'movie' changed to 'movie'
# row: 841 col: 3 : 'tv series' changed to 'tv series'
# row: 1253 col: 3 : 'tv series' changed to 'tv series'
# row: 1143 col: 3 : 'tv series' changed to 'tv series'
# row: 1518 col: 3 : 'tv series' changed to 'tv series'
# row: 216 col: 3 : 'tv series' changed to 'movie'
# row: 275 col: 3 : 'tv series' changed to 'movie'
# row: 2 col: 3 : 'movie' changed to 'tv series'
# row: 297 col: 3 : 'movie' changed to 'tv series'
# row: 1021 col: 3 : 'tv series' changed to 'tv series'
# row: 705 col: 3 : 'movie' changed to 'tv series'
# row: 1500 col: 3 : 'tv series' changed to 'tv series'
# row: 1367 col: 3 : 'tv series' changed to 'tv series'
# row: 864 col: 3 : 'tv series' changed to 'tv series'
# row: 1580 col: 3 : 'tv series' changed to 'tv series'
# row: 203 col: 3 : 'tv series' changed to 'tv series'
# row: 1189 col: 3 : 'tv series' changed to 'tv series'
# row: 1510 col: 3 : 'tv series' changed to 'movie'
# row: 329 col: 3 : 'movie' changed to 'movie'
# row: 908 col: 3 : 'tv series' changed to 'movie'
# row: 522 col: 3 : 'tv series' changed to 'tv series'
# row: 18 col: 3 : 'tv series' changed to 'tv series'
# row: 919 col: 3 : 'tv series' changed to 'movie'
# row: 593 col: 3 : 'tv series' changed to 'movie'
# row: 564 col: 3 : 'movie' changed to 'movie'
# row: 1465 col: 3 : 'movie' changed to 'tv series'
# row: 309 col: 3 : 'tv series' changed to 'tv series'
# row: 366 col: 3 : 'tv series' changed to 'movie'
# row: 944 col: 3 : 'movie' changed to 'tv series'
# row: 1270 col: 3 : 'movie' changed to 'movie'
# row: 1444 col: 3 : 'tv series' changed to 'movie'
# row: 1238 col: 3 : 'movie' changed to 'movie'
# row: 1572 col: 3 : 'movie' changed to 'movie'
# row: 945 col: 3 : 'tv series' changed to 'movie'
# row: 594 col: 3 : 'movie' changed to 'movie'
# row: 776 col: 3 : 'tv series' changed to 'tv series'
# row: 688 col: 3 : 'tv series' changed to 'movie'
# row: 704 col: 3 : 'tv series' changed to 'tv series'
# row: 1364 col: 3 : 'movie' changed to 'tv series'
# row: 1424 col: 3 : 'movie' changed to 'movie'
# row: 746 col: 3 : 'tv series' changed to 'movie'
# row: 756 col: 3 : 'movie' changed to 'movie'
# row: 903 col: 3 : 'tv series' changed to 'tv series'
# row: 41 col: 3 : 'movie' changed to 'movie'
# row: 999 col: 3 : 'movie' changed to 'tv series'
# row: 628 col: 3 : 'movie' changed to 'movie'
# row: 73 col: 3 : 'tv series' changed to 'movie'
# row: 1315 col: 3 : 'tv series' changed to 'tv series'
# row: 602 col: 3 : 'tv series' changed to 'tv series'
# row: 699 col: 3 : 'movie' changed to 'movie'
# row: 953 col: 3 : 'tv series' changed to 'movie'
# row: 1555 col: 3 : 'tv series' changed to 'movie'
# row: 1365 col: 3 : 'movie' changed to 'movie'
# row: 455 col: 3 : 'tv series' changed to 'movie'
# row: 623 col: 3 : 'movie' changed to 'tv series'
# row: 411 col: 3 : 'movie' changed to 'movie'
# row: 534 col: 3 : 'movie' changed to 'movie'
# row: 1160 col: 3 : 'tv series' changed to 'tv series'
# row: 14 col: 3 : 'tv series' changed to 'tv series'
# row: 1454 col: 3 : 'movie' changed to 'tv series'
# row: 291 col: 3 : 'tv series' changed to 'movie'
# row: 1466 col: 3 : 'movie' changed to 'tv series'
# row: 1310 col: 3 : 'tv series' changed to 'tv series'
# row: 1338 col: 3 : 'movie' changed to 'movie'
# row: 662 col: 3 : 'movie' changed to 'tv series'
# row: 1480 col: 3 : 'movie' changed to 'tv series'
# row: 916 col: 3 : 'tv series' changed to 'tv series'
# row: 269 col: 3 : 'movie' changed to 'tv series'
# row: 996 col: 3 : 'movie' changed to 'movie'
# row: 424 col: 3 : 'tv series' changed to 'tv series'
# row: 1043 col: 3 : 'tv series' changed to 'movie'
# row: 1468 col: 3 : 'movie' changed to 'movie'
# row: 1384 col: 3 : 'tv series' changed to 'tv series'
# row: 1559 col: 3 : 'movie' changed to 'tv series'
# row: 1594 col: 3 : 'tv series' changed to 'tv series'
# row: 947 col: 3 : 'movie' changed to 'tv series'
# row: 1081 col: 3 : 'tv series' changed to 'movie'
# row: 350 col: 3 : 'tv series' changed to 'movie'
# row: 715 col: 3 : 'movie' changed to 'movie'
# row: 625 col: 3 : 'tv series' changed to 'movie'
# row: 496 col: 3 : 'movie' changed to 'tv series'
# row: 1543 col: 3 : 'movie' changed to 'tv series'
# row: 1086 col: 3 : 'tv series' changed to 'movie'
# row: 1488 col: 3 : 'movie' changed to 'movie'
# row: 1241 col: 3 : 'tv series' changed to 'movie'
# row: 416 col: 3 : 'tv series' changed to 'tv series'
# row: 414 col: 3 : 'movie' changed to 'tv series'
# row: 748 col: 3 : 'movie' changed to 'movie'
# row: 1584 col: 3 : 'movie' changed to 'movie'
# row: 968 col: 3 : 'tv series' changed to 'movie'
# row: 383 col: 3 : 'movie' changed to 'tv series'
# row: 1531 col: 3 : 'tv series' changed to 'tv series'
# row: 664 col: 3 : 'movie' changed to 'tv series'
# row: 100 col: 3 : 'movie' changed to 'movie'
# row: 1588 col: 3 : 'movie' changed to 'movie'
# row: 548 col: 3 : 'movie' changed to 'movie'
# row: 868 col: 3 : 'tv series' changed to 'tv series'
# row: 897 col: 3 : 'movie' changed to 'tv series'
# row: 136 col: 3 : 'movie' changed to 'movie'
# row: 643 col: 3 : 'movie' changed to 'movie'
# row: 665 col: 3 : 'tv series' changed to 'tv series'
# row: 152 col: 3 : 'movie' changed to 'movie'
# row: 832 col: 3 : 'tv series' changed to 'tv series'
# row: 975 col: 3 : 'movie' changed to 'tv series'
# row: 1263 col: 3 : 'movie' changed to 'movie'
# row: 47 col: 3 : 'tv series' changed to 'tv series'
# row: 1421 col: 3 : 'tv series' changed to 'movie'
# row: 1046 col: 3 : 'tv series' changed to 'tv series'
# row: 185 col: 3 : 'tv series' changed to 'movie'
# row: 1324 col: 3 : 'tv series' changed to 'tv series'
# row: 689 col: 3 : 'movie' changed to 'tv series'
# row: 1191 col: 3 : 'movie' changed to 'tv series'
# row: 1104 col: 3 : 'tv series' changed to 'movie'
# row: 1345 col: 3 : 'tv series' changed to 'tv series'
# row: 1426 col: 3 : 'movie' changed to 'tv series'
# row: 1126 col: 3 : 'movie' changed to 'movie'
# row: 308 col: 3 : 'movie' changed to 'movie'
# row: 989 col: 3 : 'tv series' changed to 'movie'
# row: 1121 col: 3 : 'movie' changed to 'movie'
# row: 973 col: 3 : 'movie' changed to 'tv series'
# row: 1001 col: 3 : 'tv series' changed to 'movie'
# row: 1102 col: 3 : 'movie' changed to 'movie'
# row: 1010 col: 3 : 'movie' changed to 'tv series'
# row: 927 col: 3 : 'tv series' changed to 'tv series'
# row: 15 col: 3 : 'tv series' changed to 'movie'
# row: 964 col: 3 : 'tv series' changed to 'movie'
# row: 1067 col: 3 : 'tv series' changed to 'movie'
# row: 1498 col: 3 : 'tv series' changed to 'tv series'
# row: 866 col: 3 : 'tv series' changed to 'tv series'
# row: 1355 col: 3 : 'tv series' changed to 'tv series'
# row: 1303 col: 3 : 'movie' changed to 'tv series'
# row: 267 col: 3 : 'tv series' changed to 'movie'
# row: 413 col: 3 : 'movie' changed to 'movie'
# row: 356 col: 3 : 'tv series' changed to 'tv series'
# row: 138 col: 3 : 'movie' changed to 'movie'
# row: 696 col: 3 : 'tv series' changed to 'movie'
# row: 1242 col: 3 : 'tv series' changed to 'tv series'
# row: 1168 col: 3 : 'tv series' changed to 'movie'
# row: 117 col: 3 : 'movie' changed to 'movie'
# row: 985 col: 3 : 'tv series' changed to 'tv series'
# row: 1179 col: 3 : 'tv series' changed to 'movie'
# row: 305 col: 3 : 'tv series' changed to 'movie'
# row: 826 col: 3 : 'tv series' changed to 'movie'
# row: 134 col: 3 : 'movie' changed to 'movie'
# row: 1228 col: 3 : 'tv series' changed to 'movie'
# row: 1330 col: 3 : 'tv series' changed to 'tv series'
# row: 686 col: 3 : 'tv series' changed to 'tv series'
# row: 974 col: 3 : 'tv series' changed to 'tv series'
# row: 1187 col: 3 : 'movie' changed to 'movie'
# row: 1573 col: 3 : 'tv series' changed to 'movie'
# row: 535 col: 3 : 'tv series' changed to 'movie'
# row: 1163 col: 3 : 'movie' changed to 'tv series'
# row: 88 col: 3 : 'tv series' changed to 'movie'
# row: 449 col: 3 : 'movie' changed to 'movie'
# row: 1135 col: 3 : 'movie' changed to 'tv series'
# row: 59 col: 3 : 'movie' changed to 'movie'
# row: 373 col: 3 : 'tv series' changed to 'movie'
# row: 1507 col: 3 : 'tv series' changed to 'tv series'
# row: 298 col: 3 : 'movie' changed to 'tv series'
# row: 1312 col: 3 : 'movie' changed to 'movie'
# row: 1317 col: 3 : 'tv series' changed to 'movie'
# row: 231 col: 3 : 'movie' changed to 'tv series'
# row: 30 col: 3 : 'movie' changed to 'movie'
# row: 1546 col: 3 : 'movie' changed to 'movie'
# row: 1202 col: 3 : 'movie' changed to 'movie'
# row: 690 col: 3 : 'movie' changed to 'tv series'
# row: 1469 col: 3 : 'movie' changed to 'movie'
# row: 1473 col: 3 : 'movie' changed to 'movie'
# row: 1511 col: 3 : 'movie' changed to 'movie'
# row: 481 col: 3 : 'tv series' changed to 'tv series'
# row: 679 col: 3 : 'movie' changed to 'tv series'
# row: 971 col: 3 : 'movie' changed to 'movie'
# row: 926 col: 3 : 'tv series' changed to 'movie'
# row: 384 col: 3 : 'movie' changed to 'tv series'
# row: 668 col: 3 : 'tv series' changed to 'tv series'
# row: 1415 col: 3 : 'tv series' changed to 'movie'
# row: 5 col: 3 : 'movie' changed to 'movie'
# row: 209 col: 3 : 'movie' changed to 'tv series'
# row: 556 col: 3 : 'movie' changed to 'tv series'
# row: 640 col: 3 : 'movie' changed to 'tv series'
# row: 1041 col: 3 : 'movie' changed to 'tv series'
# row: 1030 col: 3 : 'movie' changed to 'movie'
# row: 67 col: 3 : 'tv series' changed to 'movie'
# row: 852 col: 3 : 'tv series' changed to 'movie'
# row: 1560 col: 3 : 'tv series' changed to 'tv series'
# row: 1268 col: 3 : 'tv series' changed to 'tv series'
# row: 31 col: 3 : 'movie' changed to 'movie'
# row: 1294 col: 3 : 'tv series' changed to 'tv series'
# row: 1054 col: 3 : 'movie' changed to 'tv series'
# row: 1186 col: 3 : 'tv series' changed to 'tv series'
# row: 669 col: 3 : 'movie' changed to 'movie'
# row: 1322 col: 3 : 'movie' changed to 'movie'
# row: 1148 col: 3 : 'tv series' changed to 'tv series'
# row: 1117 col: 3 : 'movie' changed to 'movie'
# row: 302 col: 3 : 'movie' changed to 'tv series'
# row: 681 col: 3 : 'movie' changed to 'tv series'
# row: 758 col: 3 : 'movie' changed to 'tv series'
# row: 1266 col: 3 : 'movie' changed to 'movie'
# row: 1068 col: 3 : 'tv series' changed to 'tv series'
# row: 497 col: 3 : 'tv series' changed to 'movie'
# row: 1418 col: 3 : 'movie' changed to 'movie'
# row: 862 col: 3 : 'movie' changed to 'movie'
# row: 1417 col: 3 : 'movie' changed to 'movie'
# row: 650 col: 3 : 'movie' changed to 'tv series'
# row: 1065 col: 3 : 'movie' changed to 'tv series'
# row: 334 col: 3 : 'movie' changed to 'movie'
# row: 1223 col: 3 : 'tv series' changed to 'movie'
# row: 986 col: 3 : 'tv series' changed to 'tv series'
# row: 344 col: 3 : 'movie' changed to 'movie'
# row: 396 col: 3 : 'tv series' changed to 'tv series'
# row: 200 col: 3 : 'tv series' changed to 'movie'
# row: 892 col: 3 : 'movie' changed to 'movie'
# row: 1428 col: 3 : 'tv series' changed to 'tv series'
# row: 1091 col: 3 : 'movie' changed to 'tv series'
# row: 764 col: 3 : 'tv series' changed to 'movie'
# row: 778 col: 3 : 'tv series' changed to 'movie'
# row: 1256 col: 3 : 'tv series' changed to 'movie'
# row: 1547 col: 3 : 'movie' changed to 'tv series'
# row: 691 col: 3 : 'tv series' changed to 'tv series'
# row: 420 col: 3 : 'tv series' changed to 'movie'
# row: 993 col: 3 : 'tv series' changed to 'movie'
# row: 151 col: 3 : 'tv series' changed to 'tv series'
# row: 1536 col: 3 : 'tv series' changed to 'movie'
# row: 1176 col: 3 : 'tv series' changed to 'movie'
# row: 1304 col: 3 : 'movie' changed to 'tv series'
# row: 799 col: 3 : 'tv series' changed to 'movie'
# row: 1403 col: 3 : 'tv series' changed to 'tv series'
# row: 1453 col: 3 : 'movie' changed to 'tv series'
# row: 143 col: 3 : 'movie' changed to 'tv series'
# row: 1280 col: 3 : 'movie' changed to 'tv series'
# row: 1237 col: 3 : 'tv series' changed to 'movie'
# row: 91 col: 3 : 'tv series' changed to 'movie'
# row: 976 col: 3 : 'movie' changed to 'tv series'
# row: 188 col: 3 : 'movie' changed to 'movie'
# row: 744 col: 3 : 'movie' changed to 'tv series'
# row: 1539 col: 3 : 'tv series' changed to 'tv series'
# row: 69 col: 3 : 'tv series' changed to 'movie'
# row: 1400 col: 3 : 'tv series' changed to 'tv series'
# row: 1251 col: 3 : 'movie' changed to 'movie'
# row: 1020 col: 3 : 'tv series' changed to 'movie'
# row: 430 col: 3 : 'movie' changed to 'tv series'
# row: 1297 col: 3 : 'movie' changed to 'movie'
# row: 714 col: 3 : 'tv series' changed to 'tv series'
# row: 1332 col: 3 : 'tv series' changed to 'movie'
# row: 772 col: 3 : 'movie' changed to 'tv series'
# row: 1229 col: 3 : 'tv series' changed to 'tv series'
# row: 766 col: 3 : 'movie' changed to 'tv series'
# row: 846 col: 3 : 'tv series' changed to 'movie'
# row: 1410 col: 3 : 'tv series' changed to 'tv series'
# row: 332 col: 3 : 'tv series' changed to 'tv series'
# row: 246 col: 3 : 'tv series' changed to 'tv series'
# row: 638 col: 3 : 'tv series' changed to 'tv series'
# row: 833 col: 3 : 'tv series' changed to 'movie'
# row: 553 col: 3 : 'tv series' changed to 'movie'
# row: 240 col: 3 : 'movie' changed to 'movie'
# row: 114 col: 3 : 'tv series' changed to 'tv series'
# row: 1116 col: 3 : 'tv series' changed to 'tv series'
# row: 1501 col: 3 : 'movie' changed to 'movie'
# row: 133 col: 3 : 'tv series' changed to 'movie'
# row: 1300 col: 3 : 'tv series' changed to 'movie'
# row: 1499 col: 3 : 'movie' changed to 'tv series'
# row: 1109 col: 3 : 'movie' changed to 'tv series'
# row: 709 col: 3 : 'movie' changed to 'tv series'
# row: 218 col: 3 : 'tv series' changed to 'movie'
# row: 95 col: 3 : 'tv series' changed to 'movie'
# row: 252 col: 3 : 'movie' changed to 'movie'
# row: 23 col: 3 : 'movie' changed to 'movie'
# row: 55 col: 3 : 'movie' changed to 'tv series'
# row: 900 col: 3 : 'tv series' changed to 'movie'
# row: 56 col: 3 : 'movie' changed to 'tv series'
# row: 569 col: 3 : 'tv series' changed to 'movie'
# row: 198 col: 3 : 'tv series' changed to 'tv series'
# row: 232 col: 3 : 'tv series' changed to 'tv series'
# row: 1111 col: 3 : 'movie' changed to 'tv series'
# row: 434 col: 3 : 'tv series' changed to 'tv series'
# row: 1190 col: 3 : 'movie' changed to 'movie'
# row: 1034 col: 3 : 'tv series' changed to 'movie'
# row: 577 col: 3 : 'movie' changed to 'movie'
# row: 1130 col: 3 : 'movie' changed to 'tv series'
# row: 1000 col: 3 : 'movie' changed to 'tv series'
# row: 1246 col: 3 : 'movie' changed to 'tv series'
# row: 1327 col: 3 : 'tv series' changed to 'movie'
# row: 918 col: 3 : 'tv series' changed to 'tv series'
# row: 119 col: 3 : 'tv series' changed to 'movie'
# row: 523 col: 3 : 'tv series' changed to 'movie'
# row: 1595 col: 3 : 'tv series' changed to 'tv series'
# row: 1434 col: 3 : 'tv series' changed to 'tv series'
# row: 687 col: 3 : 'movie' changed to 'movie'
# row: 283 col: 3 : 'tv series' changed to 'tv series'
# row: 1047 col: 3 : 'tv series' changed to 'tv series'
# row: 595 col: 3 : 'movie' changed to 'movie'
# row: 282 col: 3 : 'movie' changed to 'movie'
# row: 13 col: 3 : 'movie' changed to 'tv series'
# row: 959 col: 3 : 'tv series' changed to 'movie'
# row: 1284 col: 3 : 'tv series' changed to 'movie'
# row: 238 col: 3 : 'tv series' changed to 'movie'
# row: 1080 col: 3 : 'tv series' changed to 'movie'
# row: 70 col: 3 : 'tv series' changed to 'movie'
# row: 673 col: 3 : 'movie' changed to 'tv series'
# row: 123 col: 3 : 'movie' changed to 'movie'
# row: 747 col: 3 : 'movie' changed to 'movie'
# row: 626 col: 3 : 'movie' changed to 'tv series'
# row: 1173 col: 3 : 'movie' changed to 'movie'
# row: 1538 col: 3 : 'tv series' changed to 'movie'
# row: 865 col: 3 : 'movie' changed to 'movie'
# row: 1409 col: 3 : 'movie' changed to 'tv series'
# row: 421 col: 3 : 'tv series' changed to 'tv series'
# row: 1390 col: 3 : 'tv series' changed to 'tv series'
# row: 1262 col: 3 : 'movie' changed to 'tv series'
# row: 982 col: 3 : 'movie' changed to 'tv series'
# row: 872 col: 3 : 'movie' changed to 'tv series'
# row: 931 col: 3 : 'tv series' changed to 'movie'
# row: 1504 col: 3 : 'movie' changed to 'tv series'
# row: 318 col: 3 : 'movie' changed to 'tv series'
# row: 62 col: 3 : 'movie' changed to 'tv series'
# row: 1414 col: 3 : 'tv series' changed to 'movie'
# row: 1496 col: 3 : 'tv series' changed to 'tv series'
# row: 1221 col: 3 : 'movie' changed to 'tv series'
# row: 319 col: 3 : 'movie' changed to 'tv series'
# row: 1592 col: 3 : 'tv series' changed to 'tv series'
# row: 148 col: 3 : 'tv series' changed to 'movie'
# row: 1038 col: 3 : 'movie' changed to 'movie'
# row: 1278 col: 3 : 'tv series' changed to 'tv series'
# row: 634 col: 3 : 'tv series' changed to 'movie'
# row: 402 col: 3 : 'tv series' changed to 'tv series'
# row: 326 col: 3 : 'movie' changed to 'tv series'
# row: 1195 col: 3 : 'tv series' changed to 'tv series'
# row: 1006 col: 3 : 'movie' changed to 'tv series'
# row: 1115 col: 3 : 'movie' changed to 'movie'
# row: 913 col: 3 : 'tv series' changed to 'movie'
# row: 51 col: 3 : 'tv series' changed to 'tv series'
# row: 451 col: 3 : 'tv series' changed to 'movie'
# row: 558 col: 3 : 'tv series' changed to 'movie'
# row: 651 col: 3 : 'movie' changed to 'movie'
# row: 403 col: 3 : 'movie' changed to 'tv series'
# row: 787 col: 3 : 'tv series' changed to 'movie'
# row: 92 col: 3 : 'tv series' changed to 'tv series'
# row: 666 col: 3 : 'tv series' changed to 'tv series'
# row: 241 col: 3 : 'tv series' changed to 'tv series'
# row: 32 col: 3 : 'tv series' changed to 'tv series'
# row: 323 col: 3 : 'movie' changed to 'tv series'
# row: 300 col: 3 : 'movie' changed to 'movie'
# row: 57 col: 3 : 'tv series' changed to 'tv series'
# row: 374 col: 3 : 'movie' changed to 'tv series'
# row: 1093 col: 3 : 'tv series' changed to 'tv series'
# row: 581 col: 3 : 'movie' changed to 'movie'
# row: 1509 col: 3 : 'movie' changed to 'movie'
# row: 527 col: 3 : 'movie' changed to 'tv series'
# row: 1433 col: 3 : 'movie' changed to 'movie'
# row: 1593 col: 3 : 'tv series' changed to 'movie'
# row: 1533 col: 3 : 'movie' changed to 'tv series'
# row: 526 col: 3 : 'movie' changed to 'movie'
# row: 538 col: 3 : 'movie' changed to 'tv series'
# row: 631 col: 3 : 'tv series' changed to 'movie'
# row: 1550 col: 3 : 'tv series' changed to 'tv series'
# row: 391 col: 3 : 'tv series' changed to 'movie'
# row: 606 col: 3 : 'tv series' changed to 'movie'
# row: 1387 col: 3 : 'movie' changed to 'movie'
# row: 1161 col: 3 : 'tv series' changed to 'movie'
# row: 1233 col: 3 : 'movie' changed to 'movie'
# row: 1431 col: 3 : 'movie' changed to 'tv series'
# row: 1517 col: 3 : 'tv series' changed to 'tv series'
# row: 675 col: 3 : 'tv series' changed to 'movie'
# row: 958 col: 3 : 'movie' changed to 'movie'
# row: 6 col: 3 : 'movie' changed to 'tv series'
# row: 998 col: 3 : 'tv series' changed to 'tv series'
# row: 1551 col: 3 : 'tv series' changed to 'tv series'
# row: 627 col: 3 : 'movie' changed to 'movie'
# row: 48 col: 3 : 'tv series' changed to 'tv series'
# row: 962 col: 3 : 'tv series' changed to 'tv series'
# row: 1436 col: 3 : 'movie' changed to 'tv series'
# row: 760 col: 3 : 'tv series' changed to 'tv series'
# row: 588 col: 3 : 'movie' changed to 'movie'
# row: 1505 col: 3 : 'movie' changed to 'tv series'
# row: 310 col: 3 : 'movie' changed to 'tv series'
# row: 678 col: 3 : 'movie' changed to 'movie'
# row: 889 col: 3 : 'tv series' changed to 'movie'
# row: 570 col: 3 : 'movie' changed to 'tv series'
# row: 860 col: 3 : 'tv series' changed to 'tv series'
# row: 1218 col: 3 : 'movie' changed to 'movie'
# row: 1137 col: 3 : 'movie' changed to 'movie'
# row: 1582 col: 3 : 'tv series' changed to 'tv series'
# row: 76 col: 3 : 'movie' changed to 'movie'
# row: 296 col: 3 : 'tv series' changed to 'movie'
# row: 392 col: 3 : 'tv series' changed to 'tv series'
# row: 1236 col: 3 : 'movie' changed to 'movie'
# row: 997 col: 3 : 'movie' changed to 'movie'
# row: 234 col: 3 : 'movie' changed to 'movie'
# row: 1425 col: 3 : 'tv series' changed to 'tv series'
# row: 86 col: 3 : 'tv series' changed to 'movie'
# row: 1215 col: 3 : 'tv series' changed to 'tv series'
# row: 1 col: 3 : 'tv series' changed to 'tv series'
# row: 814 col: 3 : 'movie' changed to 'tv series'
# row: 256 col: 3 : 'tv series' changed to 'movie'
# row: 698 col: 3 : 'tv series' changed to 'movie'
# row: 867 col: 3 : 'tv series' changed to 'movie'
# row: 287 col: 3 : 'tv series' changed to 'movie'
# row: 1358 col: 3 : 'tv series' changed to 'tv series'
# row: 1066 col: 3 : 'tv series' changed to 'tv series'
# row: 37 col: 3 : 'movie' changed to 'tv series'
# row: 828 col: 3 : 'movie' changed to 'tv series'
# row: 337 col: 3 : 'tv series' changed to 'movie'
# row: 632 col: 3 : 'movie' changed to 'tv series'
# row: 314 col: 3 : 'tv series' changed to 'tv series'
# row: 620 col: 3 : 'movie' changed to 'tv series'
# row: 943 col: 3 : 'tv series' changed to 'movie'
# row: 1101 col: 3 : 'movie' changed to 'movie'
# row: 711 col: 3 : 'movie' changed to 'movie'
# row: 1152 col: 3 : 'tv series' changed to 'movie'
# row: 1558 col: 3 : 'tv series' changed to 'movie'
# row: 1441 col: 3 : 'tv series' changed to 'tv series'
# row: 784 col: 3 : 'tv series' changed to 'tv series'
# row: 775 col: 3 : 'movie' changed to 'tv series'
# row: 629 col: 3 : 'movie' changed to 'movie'
# row: 619 col: 3 : 'tv series' changed to 'tv series'
# row: 1240 col: 3 : 'movie' changed to 'movie'
# row: 253 col: 3 : 'tv series' changed to 'tv series'
# row: 717 col: 3 : 'tv series' changed to 'tv series'
# row: 36 col: 3 : 'tv series' changed to 'tv series'
# row: 1127 col: 3 : 'movie' changed to 'movie'
# row: 431 col: 3 : 'tv series' changed to 'tv series'
# row: 785 col: 3 : 'tv series' changed to 'movie'
# row: 830 col: 3 : 'tv series' changed to 'tv series'
# row: 1197 col: 3 : 'tv series' changed to 'movie'
# row: 1178 col: 3 : 'tv series' changed to 'tv series'
# row: 1203 col: 3 : 'movie' changed to 'tv series'
# row: 1474 col: 3 : 'tv series' changed to 'movie'
# row: 658 col: 3 : 'tv series' changed to 'tv series'
# row: 502 col: 3 : 'tv series' changed to 'movie'
# row: 83 col: 3 : 'tv series' changed to 'tv series'
# row: 1274 col: 3 : 'tv series' changed to 'tv series'
# row: 425 col: 3 : 'tv series' changed to 'tv series'
# row: 1309 col: 3 : 'movie' changed to 'movie'
# row: 357 col: 3 : 'tv series' changed to 'tv series'
# row: 834 col: 3 : 'tv series' changed to 'movie'
# row: 730 col: 3 : 'tv series' changed to 'movie'
# row: 1219 col: 3 : 'movie' changed to 'movie'
# row: 984 col: 3 : 'tv series' changed to 'tv series'
# row: 1508 col: 3 : 'tv series' changed to 'movie'
# row: 694 col: 3 : 'tv series' changed to 'movie'
# row: 202 col: 3 : 'tv series' changed to 'tv series'
# row: 1448 col: 3 : 'tv series' changed to 'movie'
# row: 265 col: 3 : 'movie' changed to 'tv series'
# row: 1394 col: 3 : 'tv series' changed to 'movie'
# row: 208 col: 3 : 'tv series' changed to 'tv series'
# row: 751 col: 3 : 'movie' changed to 'tv series'
# row: 1318 col: 3 : 'movie' changed to 'tv series'
# row: 1313 col: 3 : 'tv series' changed to 'movie'
# row: 40 col: 3 : 'movie' changed to 'tv series'
# row: 884 col: 3 : 'movie' changed to 'movie'
# row: 656 col: 3 : 'tv series' changed to 'movie'
# row: 1321 col: 3 : 'movie' changed to 'tv series'
# row: 155 col: 3 : 'movie' changed to 'tv series'
# row: 376 col: 3 : 'tv series' changed to 'tv series'
# row: 433 col: 3 : 'tv series' changed to 'tv series'
# row: 467 col: 3 : 'movie' changed to 'tv series'
# row: 697 col: 3 : 'tv series' changed to 'movie'
# row: 279 col: 3 : 'movie' changed to 'tv series'
# row: 1230 col: 3 : 'tv series' changed to 'tv series'
# row: 1427 col: 3 : 'tv series' changed to 'movie'
# row: 495 col: 3 : 'tv series' changed to 'tv series'
# row: 630 col: 3 : 'tv series' changed to 'tv series'
# row: 407 col: 3 : 'tv series' changed to 'movie'
# row: 618 col: 3 : 'tv series' changed to 'tv series'
# row: 1370 col: 3 : 'tv series' changed to 'tv series'
# row: 1359 col: 3 : 'tv series' changed to 'tv series'
# row: 1171 col: 3 : 'tv series' changed to 'movie'
# row: 159 col: 3 : 'tv series' changed to 'movie'
# row: 1285 col: 3 : 'movie' changed to 'movie'
# row: 786 col: 3 : 'movie' changed to 'movie'
# row: 613 col: 3 : 'movie' changed to 'movie'
# row: 1452 col: 3 : 'tv series' changed to 'movie'
# row: 1120 col: 3 : 'movie' changed to 'movie'
# row: 63 col: 3 : 'movie' changed to 'movie'
# row: 1036 col: 3 : 'tv series' changed to 'tv series'
# row: 856 col: 3 : 'tv series' changed to 'movie'
# row: 929 col: 3 : 'tv series' changed to 'tv series'
# row: 435 col: 3 : 'movie' changed to 'tv series'
# row: 773 col: 3 : 'tv series' changed to 'movie'
# row: 369 col: 3 : 'movie' changed to 'tv series'
# row: 873 col: 3 : 'tv series' changed to 'movie'
# row: 499 col: 3 : 'tv series' changed to 'movie'
# row: 262 col: 3 : 'movie' changed to 'tv series'
# row: 519 col: 3 : 'movie' changed to 'movie'
# row: 1032 col: 3 : 'tv series' changed to 'tv series'
# row: 1052 col: 3 : 'movie' changed to 'movie'
# row: 578 col: 3 : 'tv series' changed to 'tv series'
# row: 1545 col: 3 : 'tv series' changed to 'movie'
# row: 1574 col: 3 : 'tv series' changed to 'movie'
# row: 52 col: 3 : 'movie' changed to 'movie'
# row: 1026 col: 3 : 'tv series' changed to 'movie'
# row: 255 col: 3 : 'tv series' changed to 'tv series'
# row: 894 col: 3 : 'tv series' changed to 'tv series'
# row: 1244 col: 3 : 'movie' changed to 'movie'
# row: 1432 col: 3 : 'tv series' changed to 'tv series'
# row: 1353 col: 3 : 'movie' changed to 'tv series'
# row: 109 col: 3 : 'tv series' changed to 'tv series'
# row: 935 col: 3 : 'movie' changed to 'tv series'
# row: 289 col: 3 : 'tv series' changed to 'tv series'
# row: 113 col: 3 : 'movie' changed to 'movie'
# row: 465 col: 3 : 'tv series' changed to 'movie'
# row: 528 col: 3 : 'tv series' changed to 'tv series'
# row: 1025 col: 3 : 'tv series' changed to 'movie'
# row: 393 col: 3 : 'tv series' changed to 'movie'
# row: 969 col: 3 : 'movie' changed to 'movie'
# row: 476 col: 3 : 'tv series' changed to 'tv series'
# row: 521 col: 3 : 'tv series' changed to 'tv series'
# row: 560 col: 3 : 'tv series' changed to 'tv series'
# row: 979 col: 3 : 'tv series' changed to 'tv series'
# row: 1335 col: 3 : 'movie' changed to 'tv series'
# row: 980 col: 3 : 'tv series' changed to 'movie'
# row: 1083 col: 3 : 'tv series' changed to 'tv series'
# row: 861 col: 3 : 'movie' changed to 'tv series'
# row: 469 col: 3 : 'tv series' changed to 'tv series'
# row: 896 col: 3 : 'movie' changed to 'tv series'
# row: 82 col: 3 : 'tv series' changed to 'tv series'
# row: 10 col: 3 : 'tv series' changed to 'tv series'
# row: 539 col: 3 : 'tv series' changed to 'tv series'
# row: 616 col: 3 : 'tv series' changed to 'movie'
# row: 181 col: 3 : 'movie' changed to 'tv series'
# row: 42 col: 3 : 'movie' changed to 'tv series'
# row: 1597 col: 3 : 'movie' changed to 'movie'
# row: 1214 col: 3 : 'tv series' changed to 'movie'
# row: 1249 col: 3 : 'tv series' changed to 'tv series'
# row: 446 col: 3 : 'tv series' changed to 'movie'
# row: 87 col: 3 : 'tv series' changed to 'movie'
# row: 1443 col: 3 : 'tv series' changed to 'tv series'
# row: 608 col: 3 : 'tv series' changed to 'tv series'
# row: 127 col: 3 : 'tv series' changed to 'movie'
# row: 336 col: 3 : 'movie' changed to 'tv series'
# row: 157 col: 3 : 'tv series' changed to 'movie'
# row: 1007 col: 3 : 'movie' changed to 'tv series'
# row: 1018 col: 3 : 'tv series' changed to 'tv series'
# row: 1391 col: 3 : 'tv series' changed to 'tv series'
# row: 223 col: 3 : 'tv series' changed to 'tv series'
# row: 1371 col: 3 : 'tv series' changed to 'tv series'
# row: 49 col: 3 : 'movie' changed to 'movie'
# row: 378 col: 3 : 'tv series' changed to 'tv series'
# row: 1599 col: 3 : 'tv series' changed to 'tv series'
# row: 1556 col: 3 : 'tv series' changed to 'movie'
# row: 635 col: 3 : 'tv series' changed to 'movie'
# row: 1140 col: 3 : 'tv series' changed to 'movie'
# row: 1347 col: 3 : 'tv series' changed to 'movie'
# row: 905 col: 3 : 'movie' changed to 'movie'
# row: 529 col: 3 : 'tv series' changed to 'tv series'
# row: 1040 col: 3 : 'movie' changed to 'tv series'
# row: 1069 col: 3 : 'movie' changed to 'tv series'
# row: 592 col: 3 : 'movie' changed to 'tv series'
# row: 1113 col: 3 : 'movie' changed to 'movie'
# row: 809 col: 3 : 'tv series' changed to 'movie'
# row: 1525 col: 3 : 'tv series' changed to 'movie'
# row: 105 col: 3 : 'tv series' changed to 'tv series'
# row: 500 col: 3 : 'movie' changed to 'tv series'
# row: 340 col: 3 : 'tv series' changed to 'movie'
# row: 928 col: 3 : 'movie' changed to 'movie'
# row: 515 col: 3 : 'tv series' changed to 'tv series'
# row: 752 col: 3 : 'tv series' changed to 'movie'
# row: 360 col: 3 : 'movie' changed to 'tv series'
# row: 428 col: 3 : 'tv series' changed to 'tv series'
# row: 102 col: 3 : 'tv series' changed to 'movie'
# row: 915 col: 3 : 'tv series' changed to 'movie'
# row: 1147 col: 3 : 'movie' changed to 'tv series'
# row: 498 col: 3 : 'tv series' changed to 'movie'
# row: 1207 col: 3 : 'tv series' changed to 'movie'
# row: 1273 col: 3 : 'tv series' changed to 'tv series'
# row: 790 col: 3 : 'tv series' changed to 'tv series'
# row: 1331 col: 3 : 'movie' changed to 'tv series'
# row: 330 col: 3 : 'tv series' changed to 'movie'
# row: 271 col: 3 : 'movie' changed to 'tv series'
# row: 800 col: 3 : 'tv series' changed to 'tv series'
# row: 352 col: 3 : 'tv series' changed to 'movie'
# row: 179 col: 3 : 'movie' changed to 'tv series'
# row: 763 col: 3 : 'tv series' changed to 'tv series'
# row: 359 col: 3 : 'tv series' changed to 'tv series'
# row: 516 col: 3 : 'tv series' changed to 'tv series'
# row: 858 col: 3 : 'movie' changed to 'tv series'
# row: 84 col: 3 : 'movie' changed to 'tv series'
# row: 399 col: 3 : 'tv series' changed to 'tv series'
# row: 415 col: 3 : 'tv series' changed to 'movie'
# row: 875 col: 3 : 'movie' changed to 'movie'
# row: 1074 col: 3 : 'movie' changed to 'tv series'
# row: 531 col: 3 : 'tv series' changed to 'tv series'
# row: 99 col: 3 : 'movie' changed to 'tv series'
# row: 906 col: 3 : 'tv series' changed to 'tv series'
# row: 742 col: 3 : 'tv series' changed to 'tv series'
# row: 1059 col: 3 : 'movie' changed to 'movie'
# row: 164 col: 3 : 'movie' changed to 'movie'
# row: 1589 col: 3 : 'movie' changed to 'movie'
# row: 667 col: 3 : 'tv series' changed to 'tv series'
# row: 899 col: 3 : 'movie' changed to 'movie'
# row: 633 col: 3 : 'tv series' changed to 'movie'
# row: 163 col: 3 : 'tv series' changed to 'tv series'
# row: 1095 col: 3 : 'movie' changed to 'movie'
# row: 107 col: 3 : 'tv series' changed to 'tv series'
# row: 1129 col: 3 : 'tv series' changed to 'movie'
# row: 1336 col: 3 : 'movie' changed to 'movie'
# row: 39 col: 3 : 'movie' changed to 'tv series'
# row: 161 col: 3 : 'tv series' changed to 'tv series'
# row: 205 col: 3 : 'movie' changed to 'tv series'
# row: 244 col: 3 : 'movie' changed to 'tv series'
# row: 542 col: 3 : 'tv series' changed to 'tv series'
# row: 888 col: 3 : 'tv series' changed to 'tv series'
# row: 727 col: 3 : 'tv series' changed to 'tv series'
# row: 1329 col: 3 : 'movie' changed to 'tv series'
# row: 1541 col: 3 : 'tv series' changed to 'tv series'
# row: 682 col: 3 : 'tv series' changed to 'tv series'
# row: 1552 col: 3 : 'movie' changed to 'movie'
# row: 797 col: 3 : 'movie' changed to 'tv series'
# row: 372 col: 3 : 'movie' changed to 'tv series'
# row: 563 col: 3 : 'tv series' changed to 'movie'
# row: 1522 col: 3 : 'movie' changed to 'movie'
# row: 1239 col: 3 : 'movie' changed to 'tv series'
# row: 409 col: 3 : 'movie' changed to 'movie'
# row: 327 col: 3 : 'movie' changed to 'movie'
# row: 1159 col: 3 : 'movie' changed to 'movie'
# row: 3 col: 3 : 'movie' changed to 'movie'
# row: 1183 col: 3 : 'tv series' changed to 'movie'
# row: 987 col: 3 : 'movie' changed to 'movie'
# row: 1002 col: 3 : 'movie' changed to 'movie'
# row: 1472 col: 3 : 'movie' changed to 'movie'
# row: 389 col: 3 : 'tv series' changed to 'movie'
# row: 777 col: 3 : 'tv series' changed to 'movie'
# row: 648 col: 3 : 'tv series' changed to 'tv series'
# row: 1439 col: 3 : 'tv series' changed to 'tv series'
# row: 1447 col: 3 : 'tv series' changed to 'movie'
# row: 390 col: 3 : 'tv series' changed to 'tv series'
# row: 1062 col: 3 : 'tv series' changed to 'movie'
# row: 822 col: 3 : 'tv series' changed to 'movie'
# row: 741 col: 3 : 'movie' changed to 'tv series'
# row: 612 col: 3 : 'tv series' changed to 'movie'
# row: 1089 col: 3 : 'movie' changed to 'tv series'
# row: 90 col: 3 : 'movie' changed to 'movie'
# row: 486 col: 3 : 'tv series' changed to 'tv series'
# row: 839 col: 3 : 'tv series' changed to 'tv series'
# row: 615 col: 3 : 'tv series' changed to 'movie'
# row: 268 col: 3 : 'movie' changed to 'movie'
# row: 8 col: 3 : 'tv series' changed to 'tv series'
# row: 510 col: 3 : 'tv series' changed to 'tv series'
# row: 101 col: 3 : 'movie' changed to 'movie'
# row: 226 col: 3 : 'tv series' changed to 'movie'
# row: 454 col: 3 : 'movie' changed to 'tv series'
# row: 604 col: 3 : 'movie' changed to 'movie'
# row: 909 col: 3 : 'tv series' changed to 'tv series'
# row: 1537 col: 3 : 'tv series' changed to 'tv series'
# row: 670 col: 3 : 'movie' changed to 'movie'
# row: 1220 col: 3 : 'movie' changed to 'tv series'
# row: 466 col: 3 : 'tv series' changed to 'movie'
# row: 1087 col: 3 : 'movie' changed to 'tv series'
# row: 568 col: 3 : 'tv series' changed to 'tv series'
# row: 840 col: 3 : 'tv series' changed to 'movie'
# row: 901 col: 3 : 'tv series' changed to 'tv series'
# row: 695 col: 3 : 'tv series' changed to 'movie'
# row: 168 col: 3 : 'tv series' changed to 'tv series'
# row: 16 col: 3 : 'tv series' changed to 'tv series'
# row: 248 col: 3 : 'tv series' changed to 'movie'
# row: 239 col: 3 : 'tv series' changed to 'movie'
# row: 1301 col: 3 : 'tv series' changed to 'movie'
# row: 710 col: 3 : 'movie' changed to 'tv series'
# row: 146 col: 3 : 'movie' changed to 'tv series'
# row: 1435 col: 3 : 'tv series' changed to 'tv series'
# row: 1375 col: 3 : 'movie' changed to 'movie'
# row: 1194 col: 3 : 'tv series' changed to 'tv series'
# row: 104 col: 3 : 'tv series' changed to 'movie'
# row: 847 col: 3 : 'movie' changed to 'tv series'
# row: 532 col: 3 : 'movie' changed to 'movie'
# row: 819 col: 3 : 'movie' changed to 'movie'
# row: 1138 col: 3 : 'tv series' changed to 'movie'
# row: 243 col: 3 : 'tv series' changed to 'tv series'
# row: 1484 col: 3 : 'tv series' changed to 'movie'
# row: 1366 col: 3 : 'tv series' changed to 'movie'
# row: 573 col: 3 : 'tv series' changed to 'tv series'
# row: 312 col: 3 : 'tv series' changed to 'tv series'
# row: 938 col: 3 : 'tv series' changed to 'movie'
# row: 1119 col: 3 : 'tv series' changed to 'tv series'
# row: 354 col: 3 : 'movie' changed to 'tv series'
# row: 624 col: 3 : 'tv series' changed to 'movie'
# row: 335 col: 3 : 'tv series' changed to 'movie'
# row: 1056 col: 3 : 'movie' changed to 'movie'
# row: 1076 col: 3 : 'movie' changed to 'movie'
# row: 1548 col: 3 : 'tv series' changed to 'tv series'
# row: 460 col: 3 : 'movie' changed to 'movie'
# row: 11 col: 3 : 'tv series' changed to 'tv series'
# row: 957 col: 3 : 'tv series' changed to 'tv series'
# row: 530 col: 3 : 'movie' changed to 'movie'
# row: 116 col: 3 : 'movie' changed to 'tv series'
# row: 26 col: 3 : 'movie' changed to 'movie'
# row: 1167 col: 3 : 'movie' changed to 'tv series'
# row: 644 col: 3 : 'movie' changed to 'tv series'
# row: 1576 col: 3 : 'movie' changed to 'tv series'
# row: 1149 col: 3 : 'movie' changed to 'tv series'
# row: 1142 col: 3 : 'tv series' changed to 'movie'
# row: 1206 col: 3 : 'tv series' changed to 'tv series'
# row: 355 col: 3 : 'movie' changed to 'movie'
# row: 1351 col: 3 : 'tv series' changed to 'movie'
# row: 1247 col: 3 : 'tv series' changed to 'tv series'
# row: 1243 col: 3 : 'movie' changed to 'tv series'
# row: 1570 col: 3 : 'tv series' changed to 'tv series'
# row: 1128 col: 3 : 'tv series' changed to 'tv series'
# row: 493 col: 3 : 'tv series' changed to 'tv series'
# row: 1048 col: 3 : 'tv series' changed to 'tv series'
# row: 17 col: 3 : 'movie' changed to 'movie'
# row: 315 col: 3 : 'tv series' changed to 'tv series'
# row: 559 col: 3 : 'tv series' changed to 'movie'
# row: 970 col: 3 : 'tv series' changed to 'movie'
# row: 1070 col: 3 : 'movie' changed to 'tv series'
# row: 726 col: 3 : 'movie' changed to 'movie'
# row: 572 col: 3 : 'tv series' changed to 'movie'
# row: 140 col: 3 : 'tv series' changed to 'tv series'
# row: 1398 col: 3 : 'tv series' changed to 'movie'
# row: 278 col: 3 : 'tv series' changed to 'tv series'
# row: 1182 col: 3 : 'movie' changed to 'tv series'
# row: 432 col: 3 : 'tv series' changed to 'tv series'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
     # Reset index to enable concat
    train_data_set.reset_index(inplace=True)
    dfOneHot_train.reset_index(inplace=True)
    train_dummies.reset_index(inplace=True)
    
    test_data_set.reset_index(inplace=True)
    dfOneHot_test.reset_index(inplace=True)
    test_dummies.reset_index(inplace=True)
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1542, 7177)
# (389, 7177)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1542, 7176)
# (389, 7176)
# (1542, 700)
# (389, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1622624.84
# Mean squared error: 18591659420198.09
# Variance score: -421831976421074309006491648.00

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 0.82
# Mean squared error: 0.85
# Variance score: 0.11

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.925 0.999 0.982 0.907 0.939]
# Mean: 0.9503012189084418
# Standard deviation: 0.034892564702928175

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 10, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.91
