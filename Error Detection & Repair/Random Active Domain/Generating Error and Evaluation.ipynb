# %% [markdown]
# ## Import Data

# %%
import numpy as np
#import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []



anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        row['type'] = np.nan
    elif float(row['episodes']) != 1:
            row['type'] = "tv series"
    else:
            row['type'] = "movie"
    l3.append(row['type'])   

    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Random_Active_Domain(),50, ignored_columns = [0,1,2,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Random_Active_Domain().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Random_Active_Domain().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to random_active_domain method ---------------
#
# row: 604 col: 3 : 'tv series' changed to 'movie'
# row: 1174 col: 3 : 'tv series' changed to 'tv series'
# row: 532 col: 3 : 'tv series' changed to 'movie'
# row: 1474 col: 3 : 'movie' changed to 'movie'
# row: 589 col: 3 : 'movie' changed to 'movie'
# row: 943 col: 3 : 'tv series' changed to 'tv series'
# row: 99 col: 3 : 'tv series' changed to 'tv series'
# row: 1104 col: 3 : 'movie' changed to 'tv series'
# row: 676 col: 3 : 'movie' changed to 'tv series'
# row: 1448 col: 3 : 'tv series' changed to 'movie'
# row: 1061 col: 3 : 'tv series' changed to 'tv series'
# row: 489 col: 3 : 'movie' changed to 'tv series'
# row: 1149 col: 3 : 'movie' changed to 'movie'
# row: 856 col: 3 : 'tv series' changed to 'movie'
# row: 1079 col: 3 : 'movie' changed to 'movie'
# row: 1239 col: 3 : 'movie' changed to 'tv series'
# row: 71 col: 3 : 'tv series' changed to 'movie'
# row: 1030 col: 3 : 'tv series' changed to 'tv series'
# row: 1235 col: 3 : 'tv series' changed to 'movie'
# row: 553 col: 3 : 'movie' changed to 'tv series'
# row: 764 col: 3 : 'movie' changed to 'tv series'
# row: 502 col: 3 : 'tv series' changed to 'tv series'
# row: 469 col: 3 : 'movie' changed to 'tv series'
# row: 536 col: 3 : 'movie' changed to 'movie'
# row: 1579 col: 3 : 'tv series' changed to 'tv series'
# row: 1407 col: 3 : 'movie' changed to 'tv series'
# row: 381 col: 3 : 'movie' changed to 'movie'
# row: 1451 col: 3 : 'tv series' changed to 'tv series'
# row: 581 col: 3 : 'tv series' changed to 'tv series'
# row: 1240 col: 3 : 'movie' changed to 'movie'
# row: 1582 col: 3 : 'tv series' changed to 'tv series'
# row: 396 col: 3 : 'movie' changed to 'tv series'
# row: 1073 col: 3 : 'movie' changed to 'movie'
# row: 724 col: 3 : 'tv series' changed to 'tv series'
# row: 1441 col: 3 : 'tv series' changed to 'movie'
# row: 70 col: 3 : 'movie' changed to 'tv series'
# row: 687 col: 3 : 'tv series' changed to 'tv series'
# row: 1295 col: 3 : 'movie' changed to 'tv series'
# row: 1068 col: 3 : 'tv series' changed to 'tv series'
# row: 717 col: 3 : 'movie' changed to 'movie'
# row: 411 col: 3 : 'tv series' changed to 'tv series'
# row: 1560 col: 3 : 'tv series' changed to 'movie'
# row: 114 col: 3 : 'tv series' changed to 'movie'
# row: 852 col: 3 : 'tv series' changed to 'movie'
# row: 675 col: 3 : 'tv series' changed to 'movie'
# row: 122 col: 3 : 'movie' changed to 'tv series'
# row: 1596 col: 3 : 'movie' changed to 'movie'
# row: 742 col: 3 : 'tv series' changed to 'tv series'
# row: 1598 col: 3 : 'tv series' changed to 'tv series'
# row: 950 col: 3 : 'movie' changed to 'tv series'
# row: 547 col: 3 : 'tv series' changed to 'tv series'
# row: 1 col: 3 : 'tv series' changed to 'movie'
# row: 677 col: 3 : 'movie' changed to 'movie'
# row: 765 col: 3 : 'tv series' changed to 'tv series'
# row: 1306 col: 3 : 'tv series' changed to 'movie'
# row: 1332 col: 3 : 'tv series' changed to 'movie'
# row: 408 col: 3 : 'movie' changed to 'tv series'
# row: 1470 col: 3 : 'movie' changed to 'tv series'
# row: 1518 col: 3 : 'tv series' changed to 'movie'
# row: 68 col: 3 : 'movie' changed to 'movie'
# row: 792 col: 3 : 'movie' changed to 'tv series'
# row: 842 col: 3 : 'movie' changed to 'movie'
# row: 140 col: 3 : 'movie' changed to 'tv series'
# row: 1176 col: 3 : 'movie' changed to 'movie'
# row: 248 col: 3 : 'movie' changed to 'movie'
# row: 443 col: 3 : 'movie' changed to 'tv series'
# row: 265 col: 3 : 'movie' changed to 'tv series'
# row: 201 col: 3 : 'tv series' changed to 'tv series'
# row: 92 col: 3 : 'movie' changed to 'tv series'
# row: 339 col: 3 : 'movie' changed to 'movie'
# row: 1046 col: 3 : 'tv series' changed to 'movie'
# row: 1435 col: 3 : 'movie' changed to 'tv series'
# row: 1089 col: 3 : 'tv series' changed to 'tv series'
# row: 1336 col: 3 : 'tv series' changed to 'movie'
# row: 977 col: 3 : 'tv series' changed to 'movie'
# row: 1512 col: 3 : 'tv series' changed to 'movie'
# row: 740 col: 3 : 'movie' changed to 'tv series'
# row: 570 col: 3 : 'tv series' changed to 'tv series'
# row: 1403 col: 3 : 'movie' changed to 'tv series'
# row: 861 col: 3 : 'tv series' changed to 'tv series'
# row: 1161 col: 3 : 'movie' changed to 'tv series'
# row: 1123 col: 3 : 'tv series' changed to 'movie'
# row: 1255 col: 3 : 'tv series' changed to 'tv series'
# row: 1467 col: 3 : 'movie' changed to 'movie'
# row: 186 col: 3 : 'tv series' changed to 'tv series'
# row: 356 col: 3 : 'tv series' changed to 'tv series'
# row: 312 col: 3 : 'tv series' changed to 'tv series'
# row: 484 col: 3 : 'tv series' changed to 'movie'
# row: 224 col: 3 : 'movie' changed to 'movie'
# row: 1181 col: 3 : 'tv series' changed to 'movie'
# row: 979 col: 3 : 'movie' changed to 'tv series'
# row: 712 col: 3 : 'tv series' changed to 'tv series'
# row: 14 col: 3 : 'movie' changed to 'tv series'
# row: 1360 col: 3 : 'movie' changed to 'movie'
# row: 857 col: 3 : 'movie' changed to 'movie'
# row: 235 col: 3 : 'tv series' changed to 'movie'
# row: 678 col: 3 : 'movie' changed to 'tv series'
# row: 460 col: 3 : 'movie' changed to 'movie'
# row: 1573 col: 3 : 'movie' changed to 'movie'
# row: 1299 col: 3 : 'movie' changed to 'movie'
# row: 1231 col: 3 : 'tv series' changed to 'tv series'
# row: 1082 col: 3 : 'movie' changed to 'movie'
# row: 198 col: 3 : 'movie' changed to 'movie'
# row: 1064 col: 3 : 'movie' changed to 'movie'
# row: 72 col: 3 : 'tv series' changed to 'movie'
# row: 805 col: 3 : 'movie' changed to 'tv series'
# row: 1112 col: 3 : 'movie' changed to 'movie'
# row: 575 col: 3 : 'tv series' changed to 'movie'
# row: 123 col: 3 : 'tv series' changed to 'tv series'
# row: 1207 col: 3 : 'tv series' changed to 'tv series'
# row: 847 col: 3 : 'movie' changed to 'movie'
# row: 534 col: 3 : 'tv series' changed to 'tv series'
# row: 374 col: 3 : 'movie' changed to 'movie'
# row: 1528 col: 3 : 'movie' changed to 'tv series'
# row: 652 col: 3 : 'movie' changed to 'movie'
# row: 290 col: 3 : 'movie' changed to 'movie'
# row: 897 col: 3 : 'tv series' changed to 'tv series'
# row: 13 col: 3 : 'tv series' changed to 'tv series'
# row: 667 col: 3 : 'tv series' changed to 'tv series'
# row: 26 col: 3 : 'movie' changed to 'tv series'
# row: 203 col: 3 : 'movie' changed to 'tv series'
# row: 213 col: 3 : 'movie' changed to 'tv series'
# row: 920 col: 3 : 'movie' changed to 'movie'
# row: 1453 col: 3 : 'movie' changed to 'tv series'
# row: 58 col: 3 : 'movie' changed to 'tv series'
# row: 357 col: 3 : 'tv series' changed to 'movie'
# row: 1599 col: 3 : 'tv series' changed to 'tv series'
# row: 1571 col: 3 : 'tv series' changed to 'movie'
# row: 69 col: 3 : 'tv series' changed to 'movie'
# row: 1109 col: 3 : 'movie' changed to 'tv series'
# row: 407 col: 3 : 'tv series' changed to 'tv series'
# row: 1060 col: 3 : 'tv series' changed to 'movie'
# row: 322 col: 3 : 'tv series' changed to 'tv series'
# row: 1544 col: 3 : 'movie' changed to 'tv series'
# row: 775 col: 3 : 'movie' changed to 'movie'
# row: 1025 col: 3 : 'tv series' changed to 'movie'
# row: 597 col: 3 : 'movie' changed to 'movie'
# row: 1057 col: 3 : 'tv series' changed to 'movie'
# row: 1455 col: 3 : 'tv series' changed to 'tv series'
# row: 442 col: 3 : 'tv series' changed to 'movie'
# row: 910 col: 3 : 'movie' changed to 'tv series'
# row: 1198 col: 3 : 'movie' changed to 'movie'
# row: 108 col: 3 : 'movie' changed to 'movie'
# row: 769 col: 3 : 'movie' changed to 'movie'
# row: 1039 col: 3 : 'movie' changed to 'movie'
# row: 78 col: 3 : 'tv series' changed to 'tv series'
# row: 817 col: 3 : 'movie' changed to 'movie'
# row: 1549 col: 3 : 'tv series' changed to 'tv series'
# row: 36 col: 3 : 'movie' changed to 'tv series'
# row: 40 col: 3 : 'tv series' changed to 'tv series'
# row: 600 col: 3 : 'tv series' changed to 'movie'
# row: 592 col: 3 : 'movie' changed to 'tv series'
# row: 1049 col: 3 : 'tv series' changed to 'movie'
# row: 282 col: 3 : 'movie' changed to 'tv series'
# row: 197 col: 3 : 'tv series' changed to 'tv series'
# row: 51 col: 3 : 'tv series' changed to 'movie'
# row: 733 col: 3 : 'movie' changed to 'movie'
# row: 1053 col: 3 : 'tv series' changed to 'tv series'
# row: 63 col: 3 : 'tv series' changed to 'movie'
# row: 300 col: 3 : 'movie' changed to 'movie'
# row: 642 col: 3 : 'tv series' changed to 'tv series'
# row: 1193 col: 3 : 'movie' changed to 'tv series'
# row: 802 col: 3 : 'movie' changed to 'tv series'
# row: 199 col: 3 : 'tv series' changed to 'tv series'
# row: 1378 col: 3 : 'tv series' changed to 'movie'
# row: 142 col: 3 : 'tv series' changed to 'movie'
# row: 561 col: 3 : 'tv series' changed to 'tv series'
# row: 182 col: 3 : 'movie' changed to 'movie'
# row: 529 col: 3 : 'tv series' changed to 'tv series'
# row: 707 col: 3 : 'movie' changed to 'movie'
# row: 876 col: 3 : 'tv series' changed to 'movie'
# row: 705 col: 3 : 'tv series' changed to 'movie'
# row: 945 col: 3 : 'tv series' changed to 'movie'
# row: 1308 col: 3 : 'tv series' changed to 'movie'
# row: 289 col: 3 : 'movie' changed to 'movie'
# row: 808 col: 3 : 'tv series' changed to 'tv series'
# row: 41 col: 3 : 'movie' changed to 'movie'
# row: 1288 col: 3 : 'movie' changed to 'movie'
# row: 651 col: 3 : 'tv series' changed to 'movie'
# row: 825 col: 3 : 'tv series' changed to 'tv series'
# row: 372 col: 3 : 'tv series' changed to 'tv series'
# row: 326 col: 3 : 'movie' changed to 'tv series'
# row: 1313 col: 3 : 'movie' changed to 'tv series'
# row: 774 col: 3 : 'tv series' changed to 'tv series'
# row: 250 col: 3 : 'movie' changed to 'tv series'
# row: 594 col: 3 : 'movie' changed to 'tv series'
# row: 345 col: 3 : 'movie' changed to 'movie'
# row: 1545 col: 3 : 'tv series' changed to 'movie'
# row: 1375 col: 3 : 'movie' changed to 'tv series'
# row: 1587 col: 3 : 'movie' changed to 'tv series'
# row: 220 col: 3 : 'tv series' changed to 'movie'
# row: 905 col: 3 : 'movie' changed to 'movie'
# row: 222 col: 3 : 'tv series' changed to 'tv series'
# row: 15 col: 3 : 'movie' changed to 'tv series'
# row: 1241 col: 3 : 'tv series' changed to 'tv series'
# row: 1243 col: 3 : 'movie' changed to 'tv series'
# row: 1553 col: 3 : 'tv series' changed to 'tv series'
# row: 506 col: 3 : 'tv series' changed to 'tv series'
# row: 603 col: 3 : 'tv series' changed to 'tv series'
# row: 549 col: 3 : 'tv series' changed to 'movie'
# row: 840 col: 3 : 'movie' changed to 'tv series'
# row: 1485 col: 3 : 'movie' changed to 'tv series'
# row: 478 col: 3 : 'movie' changed to 'movie'
# row: 1128 col: 3 : 'movie' changed to 'tv series'
# row: 568 col: 3 : 'movie' changed to 'movie'
# row: 1282 col: 3 : 'tv series' changed to 'movie'
# row: 1177 col: 3 : 'movie' changed to 'tv series'
# row: 1248 col: 3 : 'movie' changed to 'tv series'
# row: 226 col: 3 : 'tv series' changed to 'tv series'
# row: 444 col: 3 : 'movie' changed to 'tv series'
# row: 1328 col: 3 : 'movie' changed to 'movie'
# row: 455 col: 3 : 'movie' changed to 'tv series'
# row: 1120 col: 3 : 'movie' changed to 'movie'
# row: 1012 col: 3 : 'movie' changed to 'tv series'
# row: 190 col: 3 : 'tv series' changed to 'movie'
# row: 1087 col: 3 : 'movie' changed to 'movie'
# row: 1476 col: 3 : 'tv series' changed to 'movie'
# row: 259 col: 3 : 'tv series' changed to 'tv series'
# row: 1429 col: 3 : 'tv series' changed to 'movie'
# row: 1521 col: 3 : 'movie' changed to 'movie'
# row: 1506 col: 3 : 'tv series' changed to 'movie'
# row: 1504 col: 3 : 'movie' changed to 'movie'
# row: 113 col: 3 : 'tv series' changed to 'movie'
# row: 1305 col: 3 : 'tv series' changed to 'tv series'
# row: 400 col: 3 : 'movie' changed to 'tv series'
# row: 1280 col: 3 : 'tv series' changed to 'tv series'
# row: 800 col: 3 : 'tv series' changed to 'tv series'
# row: 477 col: 3 : 'tv series' changed to 'tv series'
# row: 719 col: 3 : 'tv series' changed to 'movie'
# row: 983 col: 3 : 'tv series' changed to 'tv series'
# row: 939 col: 3 : 'movie' changed to 'movie'
# row: 607 col: 3 : 'movie' changed to 'movie'
# row: 270 col: 3 : 'tv series' changed to 'tv series'
# row: 1333 col: 3 : 'movie' changed to 'tv series'
# row: 1337 col: 3 : 'movie' changed to 'movie'
# row: 1267 col: 3 : 'movie' changed to 'movie'
# row: 144 col: 3 : 'tv series' changed to 'tv series'
# row: 1301 col: 3 : 'movie' changed to 'movie'
# row: 1499 col: 3 : 'tv series' changed to 'movie'
# row: 471 col: 3 : 'tv series' changed to 'movie'
# row: 1150 col: 3 : 'movie' changed to 'tv series'
# row: 416 col: 3 : 'tv series' changed to 'tv series'
# row: 366 col: 3 : 'movie' changed to 'movie'
# row: 1588 col: 3 : 'tv series' changed to 'movie'
# row: 1069 col: 3 : 'movie' changed to 'tv series'
# row: 1312 col: 3 : 'movie' changed to 'movie'
# row: 1586 col: 3 : 'tv series' changed to 'movie'
# row: 947 col: 3 : 'tv series' changed to 'tv series'
# row: 310 col: 3 : 'tv series' changed to 'tv series'
# row: 1287 col: 3 : 'movie' changed to 'movie'
# row: 1568 col: 3 : 'movie' changed to 'movie'
# row: 118 col: 3 : 'movie' changed to 'tv series'
# row: 512 col: 3 : 'movie' changed to 'tv series'
# row: 303 col: 3 : 'tv series' changed to 'movie'
# row: 1088 col: 3 : 'tv series' changed to 'movie'
# row: 481 col: 3 : 'tv series' changed to 'tv series'
# row: 1348 col: 3 : 'tv series' changed to 'movie'
# row: 810 col: 3 : 'tv series' changed to 'movie'
# row: 1472 col: 3 : 'movie' changed to 'movie'
# row: 1007 col: 3 : 'tv series' changed to 'movie'
# row: 636 col: 3 : 'movie' changed to 'tv series'
# row: 1048 col: 3 : 'tv series' changed to 'movie'
# row: 35 col: 3 : 'tv series' changed to 'tv series'
# row: 351 col: 3 : 'movie' changed to 'tv series'
# row: 942 col: 3 : 'movie' changed to 'movie'
# row: 941 col: 3 : 'movie' changed to 'movie'
# row: 1444 col: 3 : 'tv series' changed to 'movie'
# row: 25 col: 3 : 'movie' changed to 'tv series'
# row: 761 col: 3 : 'tv series' changed to 'movie'
# row: 1121 col: 3 : 'tv series' changed to 'movie'
# row: 242 col: 3 : 'movie' changed to 'movie'
# row: 1252 col: 3 : 'tv series' changed to 'tv series'
# row: 1437 col: 3 : 'tv series' changed to 'movie'
# row: 908 col: 3 : 'movie' changed to 'movie'
# row: 96 col: 3 : 'tv series' changed to 'tv series'
# row: 1147 col: 3 : 'tv series' changed to 'tv series'
# row: 1294 col: 3 : 'tv series' changed to 'movie'
# row: 82 col: 3 : 'tv series' changed to 'tv series'
# row: 1507 col: 3 : 'movie' changed to 'movie'
# row: 627 col: 3 : 'movie' changed to 'tv series'
# row: 1473 col: 3 : 'tv series' changed to 'tv series'
# row: 204 col: 3 : 'movie' changed to 'tv series'
# row: 280 col: 3 : 'tv series' changed to 'movie'
# row: 1574 col: 3 : 'tv series' changed to 'movie'
# row: 1272 col: 3 : 'tv series' changed to 'movie'
# row: 134 col: 3 : 'movie' changed to 'tv series'
# row: 1178 col: 3 : 'tv series' changed to 'movie'
# row: 67 col: 3 : 'movie' changed to 'movie'
# row: 544 col: 3 : 'tv series' changed to 'tv series'
# row: 465 col: 3 : 'tv series' changed to 'tv series'
# row: 628 col: 3 : 'tv series' changed to 'tv series'
# row: 1546 col: 3 : 'movie' changed to 'movie'
# row: 172 col: 3 : 'tv series' changed to 'tv series'
# row: 923 col: 3 : 'movie' changed to 'tv series'
# row: 393 col: 3 : 'tv series' changed to 'movie'
# row: 318 col: 3 : 'tv series' changed to 'movie'
# row: 899 col: 3 : 'tv series' changed to 'tv series'
# row: 773 col: 3 : 'tv series' changed to 'movie'
# row: 286 col: 3 : 'tv series' changed to 'tv series'
# row: 746 col: 3 : 'movie' changed to 'movie'
# row: 1398 col: 3 : 'movie' changed to 'movie'
# row: 1251 col: 3 : 'tv series' changed to 'movie'
# row: 1406 col: 3 : 'movie' changed to 'tv series'
# row: 232 col: 3 : 'movie' changed to 'tv series'
# row: 1186 col: 3 : 'tv series' changed to 'movie'
# row: 95 col: 3 : 'movie' changed to 'tv series'
# row: 1043 col: 3 : 'tv series' changed to 'movie'
# row: 1490 col: 3 : 'tv series' changed to 'movie'
# row: 1160 col: 3 : 'movie' changed to 'tv series'
# row: 417 col: 3 : 'movie' changed to 'movie'
# row: 1427 col: 3 : 'tv series' changed to 'movie'
# row: 1183 col: 3 : 'tv series' changed to 'movie'
# row: 268 col: 3 : 'tv series' changed to 'tv series'
# row: 686 col: 3 : 'tv series' changed to 'movie'
# row: 533 col: 3 : 'tv series' changed to 'movie'
# row: 1540 col: 3 : 'tv series' changed to 'movie'
# row: 227 col: 3 : 'tv series' changed to 'tv series'
# row: 191 col: 3 : 'tv series' changed to 'tv series'
# row: 1032 col: 3 : 'tv series' changed to 'tv series'
# row: 830 col: 3 : 'movie' changed to 'movie'
# row: 1209 col: 3 : 'movie' changed to 'tv series'
# row: 267 col: 3 : 'movie' changed to 'tv series'
# row: 1126 col: 3 : 'movie' changed to 'tv series'
# row: 211 col: 3 : 'movie' changed to 'tv series'
# row: 1238 col: 3 : 'tv series' changed to 'tv series'
# row: 128 col: 3 : 'movie' changed to 'movie'
# row: 807 col: 3 : 'tv series' changed to 'movie'
# row: 743 col: 3 : 'tv series' changed to 'movie'
# row: 385 col: 3 : 'tv series' changed to 'tv series'
# row: 111 col: 3 : 'movie' changed to 'tv series'
# row: 1508 col: 3 : 'movie' changed to 'tv series'
# row: 327 col: 3 : 'movie' changed to 'tv series'
# row: 1200 col: 3 : 'movie' changed to 'tv series'
# row: 971 col: 3 : 'tv series' changed to 'movie'
# row: 334 col: 3 : 'tv series' changed to 'movie'
# row: 1417 col: 3 : 'movie' changed to 'tv series'
# row: 737 col: 3 : 'movie' changed to 'movie'
# row: 1536 col: 3 : 'tv series' changed to 'tv series'
# row: 1066 col: 3 : 'movie' changed to 'movie'
# row: 223 col: 3 : 'movie' changed to 'movie'
# row: 1426 col: 3 : 'tv series' changed to 'tv series'
# row: 911 col: 3 : 'movie' changed to 'movie'
# row: 1151 col: 3 : 'movie' changed to 'movie'
# row: 1502 col: 3 : 'tv series' changed to 'tv series'
# row: 1392 col: 3 : 'tv series' changed to 'tv series'
# row: 925 col: 3 : 'movie' changed to 'movie'
# row: 155 col: 3 : 'tv series' changed to 'movie'
# row: 778 col: 3 : 'movie' changed to 'tv series'
# row: 498 col: 3 : 'movie' changed to 'movie'
# row: 238 col: 3 : 'tv series' changed to 'tv series'
# row: 1297 col: 3 : 'tv series' changed to 'movie'
# row: 1095 col: 3 : 'tv series' changed to 'tv series'
# row: 1027 col: 3 : 'tv series' changed to 'movie'
# row: 814 col: 3 : 'movie' changed to 'tv series'
# row: 812 col: 3 : 'tv series' changed to 'movie'
# row: 60 col: 3 : 'movie' changed to 'tv series'
# row: 832 col: 3 : 'tv series' changed to 'movie'
# row: 162 col: 3 : 'movie' changed to 'tv series'
# row: 97 col: 3 : 'movie' changed to 'tv series'
# row: 274 col: 3 : 'movie' changed to 'tv series'
# row: 698 col: 3 : 'tv series' changed to 'movie'
# row: 1459 col: 3 : 'movie' changed to 'tv series'
# row: 829 col: 3 : 'movie' changed to 'tv series'
# row: 1156 col: 3 : 'tv series' changed to 'movie'
# row: 871 col: 3 : 'movie' changed to 'movie'
# row: 124 col: 3 : 'movie' changed to 'movie'
# row: 1077 col: 3 : 'movie' changed to 'movie'
# row: 217 col: 3 : 'movie' changed to 'movie'
# row: 364 col: 3 : 'tv series' changed to 'movie'
# row: 1439 col: 3 : 'tv series' changed to 'tv series'
# row: 1033 col: 3 : 'movie' changed to 'movie'
# row: 324 col: 3 : 'tv series' changed to 'movie'
# row: 1532 col: 3 : 'movie' changed to 'tv series'
# row: 548 col: 3 : 'movie' changed to 'tv series'
# row: 609 col: 3 : 'movie' changed to 'tv series'
# row: 929 col: 3 : 'tv series' changed to 'tv series'
# row: 1581 col: 3 : 'movie' changed to 'tv series'
# row: 1566 col: 3 : 'movie' changed to 'tv series'
# row: 967 col: 3 : 'movie' changed to 'movie'
# row: 454 col: 3 : 'movie' changed to 'tv series'
# row: 735 col: 3 : 'movie' changed to 'movie'
# row: 301 col: 3 : 'movie' changed to 'tv series'
# row: 1005 col: 3 : 'movie' changed to 'movie'
# row: 434 col: 3 : 'tv series' changed to 'movie'
# row: 645 col: 3 : 'tv series' changed to 'movie'
# row: 837 col: 3 : 'tv series' changed to 'movie'
# row: 1416 col: 3 : 'tv series' changed to 'tv series'
# row: 337 col: 3 : 'tv series' changed to 'movie'
# row: 461 col: 3 : 'tv series' changed to 'movie'
# row: 283 col: 3 : 'tv series' changed to 'movie'
# row: 1022 col: 3 : 'movie' changed to 'movie'
# row: 1356 col: 3 : 'tv series' changed to 'tv series'
# row: 382 col: 3 : 'tv series' changed to 'tv series'
# row: 468 col: 3 : 'movie' changed to 'tv series'
# row: 781 col: 3 : 'movie' changed to 'movie'
# row: 1228 col: 3 : 'movie' changed to 'tv series'
# row: 1452 col: 3 : 'movie' changed to 'movie'
# row: 1058 col: 3 : 'tv series' changed to 'tv series'
# row: 1059 col: 3 : 'tv series' changed to 'movie'
# row: 161 col: 3 : 'tv series' changed to 'tv series'
# row: 1318 col: 3 : 'tv series' changed to 'movie'
# row: 112 col: 3 : 'movie' changed to 'tv series'
# row: 555 col: 3 : 'tv series' changed to 'tv series'
# row: 405 col: 3 : 'movie' changed to 'movie'
# row: 1303 col: 3 : 'movie' changed to 'tv series'
# row: 890 col: 3 : 'tv series' changed to 'movie'
# row: 1044 col: 3 : 'movie' changed to 'tv series'
# row: 1175 col: 3 : 'movie' changed to 'tv series'
# row: 1219 col: 3 : 'movie' changed to 'tv series'
# row: 715 col: 3 : 'movie' changed to 'tv series'
# row: 229 col: 3 : 'movie' changed to 'movie'
# row: 1382 col: 3 : 'tv series' changed to 'tv series'
# row: 482 col: 3 : 'movie' changed to 'tv series'
# row: 1580 col: 3 : 'tv series' changed to 'movie'
# row: 88 col: 3 : 'movie' changed to 'movie'
# row: 845 col: 3 : 'movie' changed to 'tv series'
# row: 368 col: 3 : 'movie' changed to 'tv series'
# row: 892 col: 3 : 'tv series' changed to 'tv series'
# row: 292 col: 3 : 'tv series' changed to 'tv series'
# row: 261 col: 3 : 'tv series' changed to 'movie'
# row: 399 col: 3 : 'movie' changed to 'movie'
# row: 1024 col: 3 : 'movie' changed to 'tv series'
# row: 930 col: 3 : 'movie' changed to 'tv series'
# row: 1461 col: 3 : 'movie' changed to 'movie'
# row: 1433 col: 3 : 'tv series' changed to 'movie'
# row: 684 col: 3 : 'tv series' changed to 'movie'
# row: 834 col: 3 : 'tv series' changed to 'tv series'
# row: 998 col: 3 : 'tv series' changed to 'movie'
# row: 815 col: 3 : 'tv series' changed to 'movie'
# row: 30 col: 3 : 'tv series' changed to 'movie'
# row: 212 col: 3 : 'movie' changed to 'movie'
# row: 1420 col: 3 : 'movie' changed to 'tv series'
# row: 424 col: 3 : 'movie' changed to 'tv series'
# row: 1072 col: 3 : 'tv series' changed to 'tv series'
# row: 328 col: 3 : 'movie' changed to 'movie'
# row: 1199 col: 3 : 'movie' changed to 'movie'
# row: 1221 col: 3 : 'tv series' changed to 'movie'
# row: 77 col: 3 : 'tv series' changed to 'movie'
# row: 816 col: 3 : 'tv series' changed to 'movie'
# row: 685 col: 3 : 'movie' changed to 'tv series'
# row: 1163 col: 3 : 'tv series' changed to 'tv series'
# row: 504 col: 3 : 'movie' changed to 'tv series'
# row: 760 col: 3 : 'tv series' changed to 'tv series'
# row: 605 col: 3 : 'tv series' changed to 'movie'
# row: 1271 col: 3 : 'movie' changed to 'tv series'
# row: 1081 col: 3 : 'movie' changed to 'movie'
# row: 1113 col: 3 : 'movie' changed to 'movie'
# row: 595 col: 3 : 'tv series' changed to 'tv series'
# row: 630 col: 3 : 'movie' changed to 'tv series'
# row: 472 col: 3 : 'tv series' changed to 'tv series'
# row: 344 col: 3 : 'tv series' changed to 'movie'
# row: 1594 col: 3 : 'movie' changed to 'tv series'
# row: 342 col: 3 : 'tv series' changed to 'tv series'
# row: 164 col: 3 : 'movie' changed to 'movie'
# row: 1466 col: 3 : 'movie' changed to 'tv series'
# row: 586 col: 3 : 'movie' changed to 'tv series'
# row: 880 col: 3 : 'tv series' changed to 'tv series'
# row: 1127 col: 3 : 'tv series' changed to 'tv series'
# row: 451 col: 3 : 'movie' changed to 'tv series'
# row: 177 col: 3 : 'tv series' changed to 'tv series'
# row: 1377 col: 3 : 'movie' changed to 'tv series'
# row: 758 col: 3 : 'tv series' changed to 'movie'
# row: 1371 col: 3 : 'tv series' changed to 'movie'
# row: 1434 col: 3 : 'tv series' changed to 'movie'
# row: 931 col: 3 : 'tv series' changed to 'tv series'
# row: 1208 col: 3 : 'movie' changed to 'movie'
# row: 395 col: 3 : 'movie' changed to 'movie'
# row: 275 col: 3 : 'movie' changed to 'tv series'
# row: 864 col: 3 : 'tv series' changed to 'tv series'
# row: 704 col: 3 : 'movie' changed to 'tv series'
# row: 358 col: 3 : 'tv series' changed to 'tv series'
# row: 1055 col: 3 : 'tv series' changed to 'tv series'
# row: 1364 col: 3 : 'movie' changed to 'movie'
# row: 1517 col: 3 : 'tv series' changed to 'tv series'
# row: 369 col: 3 : 'tv series' changed to 'movie'
# row: 1585 col: 3 : 'movie' changed to 'tv series'
# row: 934 col: 3 : 'tv series' changed to 'tv series'
# row: 672 col: 3 : 'movie' changed to 'movie'
# row: 753 col: 3 : 'movie' changed to 'tv series'
# row: 1116 col: 3 : 'movie' changed to 'movie'
# row: 74 col: 3 : 'movie' changed to 'movie'
# row: 693 col: 3 : 'tv series' changed to 'tv series'
# row: 926 col: 3 : 'tv series' changed to 'movie'
# row: 1347 col: 3 : 'tv series' changed to 'tv series'
# row: 1054 col: 3 : 'tv series' changed to 'tv series'
# row: 688 col: 3 : 'tv series' changed to 'tv series'
# row: 990 col: 3 : 'tv series' changed to 'movie'
# row: 1519 col: 3 : 'tv series' changed to 'tv series'
# row: 919 col: 3 : 'movie' changed to 'movie'
# row: 1552 col: 3 : 'movie' changed to 'movie'
# row: 964 col: 3 : 'tv series' changed to 'movie'
# row: 585 col: 3 : 'movie' changed to 'tv series'
# row: 648 col: 3 : 'movie' changed to 'movie'
# row: 302 col: 3 : 'movie' changed to 'tv series'
# row: 189 col: 3 : 'movie' changed to 'movie'
# row: 754 col: 3 : 'tv series' changed to 'movie'
# row: 720 col: 3 : 'tv series' changed to 'movie'
# row: 1094 col: 3 : 'movie' changed to 'movie'
# row: 546 col: 3 : 'tv series' changed to 'tv series'
# row: 136 col: 3 : 'tv series' changed to 'tv series'
# row: 1278 col: 3 : 'movie' changed to 'tv series'
# row: 525 col: 3 : 'movie' changed to 'movie'
# row: 904 col: 3 : 'movie' changed to 'movie'
# row: 1304 col: 3 : 'tv series' changed to 'tv series'
# row: 700 col: 3 : 'movie' changed to 'tv series'
# row: 956 col: 3 : 'movie' changed to 'movie'
# row: 1124 col: 3 : 'tv series' changed to 'tv series'
# row: 195 col: 3 : 'movie' changed to 'movie'
# row: 1096 col: 3 : 'tv series' changed to 'movie'
# row: 557 col: 3 : 'movie' changed to 'tv series'
# row: 673 col: 3 : 'movie' changed to 'tv series'
# row: 1422 col: 3 : 'tv series' changed to 'tv series'
# row: 151 col: 3 : 'movie' changed to 'tv series'
# row: 475 col: 3 : 'movie' changed to 'movie'
# row: 1092 col: 3 : 'movie' changed to 'tv series'
# row: 1478 col: 3 : 'movie' changed to 'movie'
# row: 827 col: 3 : 'movie' changed to 'movie'
# row: 522 col: 3 : 'movie' changed to 'tv series'
# row: 1191 col: 3 : 'tv series' changed to 'movie'
# row: 888 col: 3 : 'tv series' changed to 'tv series'
# row: 1253 col: 3 : 'tv series' changed to 'tv series'
# row: 851 col: 3 : 'tv series' changed to 'movie'
# row: 432 col: 3 : 'movie' changed to 'movie'
# row: 1557 col: 3 : 'tv series' changed to 'tv series'
# row: 1275 col: 3 : 'movie' changed to 'tv series'
# row: 240 col: 3 : 'tv series' changed to 'tv series'
# row: 790 col: 3 : 'movie' changed to 'movie'
# row: 1230 col: 3 : 'tv series' changed to 'tv series'
# row: 1036 col: 3 : 'tv series' changed to 'tv series'
# row: 580 col: 3 : 'tv series' changed to 'tv series'
# row: 927 col: 3 : 'tv series' changed to 'tv series'
# row: 1393 col: 3 : 'movie' changed to 'tv series'
# row: 1569 col: 3 : 'tv series' changed to 'tv series'
# row: 1227 col: 3 : 'tv series' changed to 'movie'
# row: 1076 col: 3 : 'movie' changed to 'tv series'
# row: 9 col: 3 : 'tv series' changed to 'tv series'
# row: 801 col: 3 : 'tv series' changed to 'movie'
# row: 935 col: 3 : 'movie' changed to 'tv series'
# row: 414 col: 3 : 'movie' changed to 'tv series'
# row: 505 col: 3 : 'tv series' changed to 'tv series'
# row: 629 col: 3 : 'tv series' changed to 'movie'
# row: 898 col: 3 : 'movie' changed to 'movie'
# row: 1410 col: 3 : 'movie' changed to 'movie'
# row: 1319 col: 3 : 'tv series' changed to 'tv series'
# row: 137 col: 3 : 'movie' changed to 'tv series'
# row: 1136 col: 3 : 'tv series' changed to 'movie'
# row: 692 col: 3 : 'movie' changed to 'movie'
# row: 1154 col: 3 : 'tv series' changed to 'movie'
# row: 37 col: 3 : 'movie' changed to 'tv series'
# row: 48 col: 3 : 'tv series' changed to 'movie'
# row: 1372 col: 3 : 'tv series' changed to 'movie'
# row: 288 col: 3 : 'movie' changed to 'tv series'
# row: 1578 col: 3 : 'tv series' changed to 'tv series'
# row: 1535 col: 3 : 'movie' changed to 'tv series'
# row: 236 col: 3 : 'movie' changed to 'tv series'
# row: 462 col: 3 : 'tv series' changed to 'movie'
# row: 1035 col: 3 : 'tv series' changed to 'movie'
# row: 143 col: 3 : 'movie' changed to 'tv series'
# row: 29 col: 3 : 'tv series' changed to 'tv series'
# row: 749 col: 3 : 'tv series' changed to 'tv series'
# row: 1020 col: 3 : 'movie' changed to 'tv series'
# row: 1542 col: 3 : 'tv series' changed to 'tv series'
# row: 1285 col: 3 : 'movie' changed to 'movie'
# row: 885 col: 3 : 'movie' changed to 'tv series'
# row: 995 col: 3 : 'movie' changed to 'movie'
# row: 615 col: 3 : 'movie' changed to 'tv series'
# row: 1325 col: 3 : 'tv series' changed to 'tv series'
# row: 511 col: 3 : 'movie' changed to 'movie'
# row: 963 col: 3 : 'tv series' changed to 'tv series'
# row: 467 col: 3 : 'tv series' changed to 'movie'
# row: 766 col: 3 : 'movie' changed to 'movie'
# row: 1184 col: 3 : 'tv series' changed to 'tv series'
# row: 281 col: 3 : 'tv series' changed to 'movie'
# row: 1273 col: 3 : 'tv series' changed to 'tv series'
# row: 1102 col: 3 : 'tv series' changed to 'tv series'
# row: 257 col: 3 : 'movie' changed to 'movie'
# row: 823 col: 3 : 'tv series' changed to 'movie'
# row: 129 col: 3 : 'tv series' changed to 'tv series'
# row: 1514 col: 3 : 'movie' changed to 'movie'
# row: 353 col: 3 : 'movie' changed to 'movie'
# row: 519 col: 3 : 'movie' changed to 'movie'
# row: 1153 col: 3 : 'tv series' changed to 'movie'
# row: 5 col: 3 : 'tv series' changed to 'tv series'
# row: 1391 col: 3 : 'tv series' changed to 'movie'
# row: 422 col: 3 : 'tv series' changed to 'tv series'
# row: 655 col: 3 : 'movie' changed to 'tv series'
# row: 409 col: 3 : 'tv series' changed to 'tv series'
# row: 863 col: 3 : 'tv series' changed to 'tv series'
# row: 1031 col: 3 : 'tv series' changed to 'movie'
# row: 360 col: 3 : 'movie' changed to 'movie'
# row: 1268 col: 3 : 'movie' changed to 'tv series'
# row: 1152 col: 3 : 'tv series' changed to 'movie'
# row: 120 col: 3 : 'movie' changed to 'tv series'
# row: 1242 col: 3 : 'tv series' changed to 'tv series'
# row: 392 col: 3 : 'tv series' changed to 'tv series'
# row: 91 col: 3 : 'movie' changed to 'movie'
# row: 1538 col: 3 : 'tv series' changed to 'movie'
# row: 954 col: 3 : 'movie' changed to 'tv series'
# row: 813 col: 3 : 'movie' changed to 'movie'
# row: 1256 col: 3 : 'tv series' changed to 'movie'
# row: 1492 col: 3 : 'tv series' changed to 'movie'
# row: 1425 col: 3 : 'tv series' changed to 'tv series'
# row: 488 col: 3 : 'movie' changed to 'tv series'
# row: 588 col: 3 : 'movie' changed to 'tv series'
# row: 279 col: 3 : 'tv series' changed to 'tv series'
# row: 501 col: 3 : 'tv series' changed to 'movie'
# row: 394 col: 3 : 'tv series' changed to 'tv series'
# row: 776 col: 3 : 'movie' changed to 'movie'
# row: 200 col: 3 : 'tv series' changed to 'tv series'
# row: 646 col: 3 : 'tv series' changed to 'tv series'
# row: 523 col: 3 : 'movie' changed to 'tv series'
# row: 1257 col: 3 : 'movie' changed to 'movie'
# row: 665 col: 3 : 'tv series' changed to 'tv series'
# row: 803 col: 3 : 'tv series' changed to 'movie'
# row: 1383 col: 3 : 'tv series' changed to 'tv series'
# row: 1284 col: 3 : 'tv series' changed to 'tv series'
# row: 610 col: 3 : 'movie' changed to 'movie'
# row: 277 col: 3 : 'tv series' changed to 'movie'
# row: 663 col: 3 : 'tv series' changed to 'movie'
# row: 694 col: 3 : 'movie' changed to 'tv series'
# row: 895 col: 3 : 'tv series' changed to 'movie'
# row: 952 col: 3 : 'movie' changed to 'tv series'
# row: 241 col: 3 : 'movie' changed to 'movie'
# row: 147 col: 3 : 'tv series' changed to 'movie'
# row: 1555 col: 3 : 'movie' changed to 'movie'
# row: 466 col: 3 : 'tv series' changed to 'tv series'
# row: 1051 col: 3 : 'tv series' changed to 'tv series'
# row: 1423 col: 3 : 'tv series' changed to 'tv series'
# row: 1431 col: 3 : 'tv series' changed to 'movie'
# row: 751 col: 3 : 'tv series' changed to 'movie'
# row: 865 col: 3 : 'movie' changed to 'movie'
# row: 1171 col: 3 : 'movie' changed to 'movie'
# row: 233 col: 3 : 'movie' changed to 'movie'
# row: 50 col: 3 : 'movie' changed to 'movie'
# row: 959 col: 3 : 'movie' changed to 'movie'
# row: 535 col: 3 : 'tv series' changed to 'tv series'
# row: 1015 col: 3 : 'tv series' changed to 'movie'
# row: 859 col: 3 : 'movie' changed to 'movie'
# row: 1397 col: 3 : 'tv series' changed to 'tv series'
# row: 1563 col: 3 : 'tv series' changed to 'tv series'
# row: 398 col: 3 : 'tv series' changed to 'movie'
# row: 210 col: 3 : 'movie' changed to 'tv series'
# row: 2 col: 3 : 'tv series' changed to 'movie'
# row: 1559 col: 3 : 'tv series' changed to 'movie'
# row: 1436 col: 3 : 'tv series' changed to 'movie'
# row: 691 col: 3 : 'tv series' changed to 'tv series'
# row: 867 col: 3 : 'tv series' changed to 'movie'
# row: 1362 col: 3 : 'tv series' changed to 'movie'
# row: 1279 col: 3 : 'tv series' changed to 'tv series'
# row: 1400 col: 3 : 'movie' changed to 'tv series'
# row: 1541 col: 3 : 'movie' changed to 'tv series'
# row: 714 col: 3 : 'tv series' changed to 'movie'
# row: 1498 col: 3 : 'movie' changed to 'movie'
# row: 946 col: 3 : 'movie' changed to 'movie'
# row: 1052 col: 3 : 'tv series' changed to 'movie'
# row: 598 col: 3 : 'movie' changed to 'movie'
# row: 572 col: 3 : 'movie' changed to 'tv series'
# row: 887 col: 3 : 'tv series' changed to 'movie'
# row: 1162 col: 3 : 'tv series' changed to 'tv series'
# row: 736 col: 3 : 'tv series' changed to 'movie'
# row: 1224 col: 3 : 'movie' changed to 'tv series'
# row: 1438 col: 3 : 'movie' changed to 'movie'
# row: 738 col: 3 : 'tv series' changed to 'movie'
# row: 1323 col: 3 : 'movie' changed to 'tv series'
# row: 528 col: 3 : 'tv series' changed to 'tv series'
# row: 1038 col: 3 : 'tv series' changed to 'movie'
# row: 896 col: 3 : 'movie' changed to 'tv series'
# row: 883 col: 3 : 'movie' changed to 'movie'
# row: 1084 col: 3 : 'movie' changed to 'movie'
# row: 294 col: 3 : 'movie' changed to 'tv series'
# row: 582 col: 3 : 'tv series' changed to 'tv series'
# row: 1537 col: 3 : 'tv series' changed to 'movie'
# row: 1572 col: 3 : 'tv series' changed to 'tv series'
# row: 18 col: 3 : 'tv series' changed to 'tv series'
# row: 1454 col: 3 : 'movie' changed to 'tv series'
# row: 1093 col: 3 : 'movie' changed to 'tv series'
# row: 973 col: 3 : 'tv series' changed to 'tv series'
# row: 578 col: 3 : 'tv series' changed to 'tv series'
# row: 744 col: 3 : 'movie' changed to 'tv series'
# row: 93 col: 3 : 'tv series' changed to 'movie'
# row: 463 col: 3 : 'tv series' changed to 'movie'
# row: 566 col: 3 : 'tv series' changed to 'tv series'
# row: 560 col: 3 : 'movie' changed to 'movie'
# row: 567 col: 3 : 'tv series' changed to 'tv series'
# row: 1511 col: 3 : 'movie' changed to 'movie'
# row: 1480 col: 3 : 'tv series' changed to 'tv series'
# row: 1576 col: 3 : 'movie' changed to 'movie'
# row: 437 col: 3 : 'tv series' changed to 'movie'
# row: 413 col: 3 : 'tv series' changed to 'movie'
# row: 632 col: 3 : 'tv series' changed to 'movie'
# row: 171 col: 3 : 'movie' changed to 'tv series'
# row: 1062 col: 3 : 'movie' changed to 'tv series'
# row: 1329 col: 3 : 'tv series' changed to 'tv series'
# row: 419 col: 3 : 'movie' changed to 'movie'
# row: 335 col: 3 : 'movie' changed to 'movie'
# row: 52 col: 3 : 'movie' changed to 'movie'
# row: 121 col: 3 : 'movie' changed to 'movie'
# row: 415 col: 3 : 'movie' changed to 'tv series'
# row: 759 col: 3 : 'tv series' changed to 'tv series'
# row: 878 col: 3 : 'movie' changed to 'tv series'
# row: 323 col: 3 : 'tv series' changed to 'tv series'
# row: 378 col: 3 : 'movie' changed to 'movie'
# row: 377 col: 3 : 'tv series' changed to 'movie'
# row: 798 col: 3 : 'tv series' changed to 'tv series'
# row: 1344 col: 3 : 'movie' changed to 'movie'
# row: 1142 col: 3 : 'tv series' changed to 'movie'
# row: 1137 col: 3 : 'tv series' changed to 'movie'
# row: 1550 col: 3 : 'tv series' changed to 'tv series'
# row: 1399 col: 3 : 'tv series' changed to 'movie'
# row: 1424 col: 3 : 'tv series' changed to 'tv series'
# row: 27 col: 3 : 'tv series' changed to 'tv series'
# row: 1510 col: 3 : 'movie' changed to 'movie'
# row: 906 col: 3 : 'tv series' changed to 'tv series'
# row: 181 col: 3 : 'movie' changed to 'tv series'
# row: 542 col: 3 : 'movie' changed to 'movie'
# row: 1217 col: 3 : 'tv series' changed to 'tv series'
# row: 346 col: 3 : 'movie' changed to 'movie'
# row: 748 col: 3 : 'tv series' changed to 'tv series'
# row: 799 col: 3 : 'movie' changed to 'movie'
# row: 299 col: 3 : 'movie' changed to 'tv series'
# row: 441 col: 3 : 'movie' changed to 'movie'
# row: 84 col: 3 : 'movie' changed to 'tv series'
# row: 500 col: 3 : 'movie' changed to 'tv series'
# row: 1106 col: 3 : 'tv series' changed to 'movie'
# row: 559 col: 3 : 'movie' changed to 'movie'
# row: 1182 col: 3 : 'tv series' changed to 'tv series'
# row: 839 col: 3 : 'movie' changed to 'movie'
# row: 340 col: 3 : 'movie' changed to 'tv series'
# row: 1190 col: 3 : 'movie' changed to 'tv series'
# row: 635 col: 3 : 'movie' changed to 'movie'
# row: 539 col: 3 : 'tv series' changed to 'tv series'
# row: 54 col: 3 : 'tv series' changed to 'movie'
# row: 1016 col: 3 : 'movie' changed to 'movie'
# row: 1034 col: 3 : 'tv series' changed to 'tv series'
# row: 1125 col: 3 : 'movie' changed to 'movie'
# row: 380 col: 3 : 'movie' changed to 'movie'
# row: 846 col: 3 : 'movie' changed to 'tv series'
# row: 836 col: 3 : 'tv series' changed to 'tv series'
# row: 1300 col: 3 : 'tv series' changed to 'tv series'
# row: 244 col: 3 : 'movie' changed to 'movie'
# row: 12 col: 3 : 'tv series' changed to 'movie'
# row: 841 col: 3 : 'movie' changed to 'movie'
# row: 215 col: 3 : 'movie' changed to 'tv series'
# row: 1543 col: 3 : 'movie' changed to 'movie'
# row: 1331 col: 3 : 'movie' changed to 'tv series'
# row: 833 col: 3 : 'tv series' changed to 'tv series'
# row: 1135 col: 3 : 'movie' changed to 'movie'
# row: 1172 col: 3 : 'tv series' changed to 'tv series'
# row: 640 col: 3 : 'tv series' changed to 'movie'
# row: 231 col: 3 : 'movie' changed to 'tv series'
# row: 221 col: 3 : 'tv series' changed to 'tv series'
# row: 718 col: 3 : 'movie' changed to 'tv series'
# row: 1281 col: 3 : 'movie' changed to 'tv series'
# row: 1414 col: 3 : 'movie' changed to 'tv series'
# row: 1134 col: 3 : 'movie' changed to 'tv series'
# row: 1028 col: 3 : 'movie' changed to 'tv series'
# row: 427 col: 3 : 'movie' changed to 'tv series'
# row: 913 col: 3 : 'movie' changed to 'movie'
# row: 1220 col: 3 : 'movie' changed to 'movie'
# row: 1139 col: 3 : 'tv series' changed to 'movie'
# row: 1158 col: 3 : 'tv series' changed to 'tv series'
# row: 1180 col: 3 : 'tv series' changed to 'movie'
# row: 543 col: 3 : 'tv series' changed to 'movie'
# row: 951 col: 3 : 'tv series' changed to 'tv series'
# row: 882 col: 3 : 'movie' changed to 'movie'
# row: 756 col: 3 : 'tv series' changed to 'tv series'
# row: 218 col: 3 : 'movie' changed to 'tv series'
# row: 660 col: 3 : 'movie' changed to 'movie'
# row: 272 col: 3 : 'tv series' changed to 'tv series'
# row: 343 col: 3 : 'tv series' changed to 'movie'
# row: 1409 col: 3 : 'tv series' changed to 'movie'
# row: 789 col: 3 : 'movie' changed to 'tv series'
# row: 877 col: 3 : 'movie' changed to 'movie'
# row: 658 col: 3 : 'movie' changed to 'movie'
# row: 156 col: 3 : 'movie' changed to 'movie'
# row: 485 col: 3 : 'tv series' changed to 'movie'
# row: 821 col: 3 : 'movie' changed to 'movie'
# row: 618 col: 3 : 'tv series' changed to 'movie'
# row: 388 col: 3 : 'movie' changed to 'movie'
# row: 404 col: 3 : 'tv series' changed to 'tv series'
# row: 1380 col: 3 : 'tv series' changed to 'movie'
# row: 1006 col: 3 : 'tv series' changed to 'tv series'
# row: 914 col: 3 : 'tv series' changed to 'movie'
# row: 787 col: 3 : 'movie' changed to 'tv series'
# row: 1179 col: 3 : 'tv series' changed to 'tv series'
# row: 1442 col: 3 : 'tv series' changed to 'movie'
# row: 386 col: 3 : 'tv series' changed to 'movie'
# row: 997 col: 3 : 'movie' changed to 'movie'
# row: 938 col: 3 : 'movie' changed to 'movie'
# row: 1262 col: 3 : 'tv series' changed to 'tv series'
# row: 716 col: 3 : 'movie' changed to 'tv series'
# row: 757 col: 3 : 'tv series' changed to 'tv series'
# row: 1155 col: 3 : 'tv series' changed to 'tv series'
# row: 1225 col: 3 : 'movie' changed to 'movie'
# row: 243 col: 3 : 'movie' changed to 'movie'
# row: 527 col: 3 : 'tv series' changed to 'tv series'
# row: 538 col: 3 : 'tv series' changed to 'tv series'
# row: 937 col: 3 : 'movie' changed to 'movie'
# row: 20 col: 3 : 'tv series' changed to 'movie'
# row: 85 col: 3 : 'movie' changed to 'movie'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1541, 7178)
# (23, 7178)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1541, 7177)
# (23, 7177)
# (1541, 700)
# (23, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 910397.07
# Mean squared error: 3974894645372.38
# Variance score: -254599296850211886623358976.00

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 1.12
# Mean squared error: 1.34
# Variance score: -27.98

# %% [markdown]
# ### LassoCV

# %%
'''
# Create a list of alphas to cross-validate against
alphas = np.logspace(-10, 1, 100)

# Instantiate the linear model and visualizer
model = LassoCV(alphas=alphas, cv = 5)
visualizer = AlphaSelection(model)

visualizer.fit(anime_X_train, anime_y_train)
g = visualizer.poof()
'''
# Out:
# '\n# Create a list of alphas to cross-validate against\nalphas = np.logspace(-10, 1, 100)\n\n# Instantiate the linear model and visualizer\nmodel = LassoCV(alphas=alphas, cv = 5)\nvisualizer = AlphaSelection(model)\n\nvisualizer.fit(anime_X_train, anime_y_train)\ng = visualizer.poof()\n'

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.916 1.018 0.891 0.93  0.897]
# Mean: 0.9303915105041698
# Standard deviation: 0.04583954633690569

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 10, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.87
