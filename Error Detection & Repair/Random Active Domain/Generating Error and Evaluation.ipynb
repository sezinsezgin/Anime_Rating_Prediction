# %% [markdown]
# ## Import Data

# %%
import numpy as np
#import imdb 
import pandas as pd
#from error_generator import Explicit_Missing_Value
#from error_generator import Implicit_Missing_Value
#from error_generator import White_Noise
#from error_generator import Gaussian_Noise
from error_generator import Random_Active_Domain
from error_generator import Similar_Based_Active_Domain
from error_generator import Typo_Keyboard
from error_generator import Typo_Butterfingers
from error_generator import Word2vec_Nearest_Neighbor
from error_generator import Value_Selector
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

anime_data = pd.read_csv("../../new_anime_data1.csv", index_col=0)

anime_data['episodes'] = anime_data['episodes'].replace('Unknown', np.nan)
# Out:
# c:\users\larat\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Cleaning

# %%
l1 = []
l2 = []
l3 = []



anime_data['genre'].fillna('',  inplace=True)
anime_data['overview'].fillna('',  inplace=True)
anime_data['type'].fillna('',  inplace=True)
for index, row in anime_data.iterrows():
    item = row['genre']
    if(pd.isnull(item)):
            item =""
    else:
        if isinstance(item, (list, tuple)):
            item = ','.join(item)
        else:
            item = item.replace(" ","")
            item = item.replace("[","")
            item = item.replace("]","")
            item = item.replace("'","")
    l1.append(item) 
      

for index, row in anime_data.iterrows():
    item = row['overview']
    if(pd.isnull(row['overview'])):
            item = ""
    else:
       # for item in anime_data['overview']:
            if isinstance(item, (list, tuple)):
                item = ','.join(item)
            else:
                item = item.replace("[","")
                item = item.replace("]","")
    l2.append(item) 

for index, row in anime_data.iterrows():
    item = row['type']
    if(pd.isnull(row['type'])):
        row['type'] = np.nan
    elif float(row['episodes']) != 1:
            row['type'] = "tv series"
    else:
            row['type'] = "movie"
    l3.append(row['type'])   

    
anime_data['genre'] = l1   
anime_data['overview'] = l2
anime_data['type'] = l3

#drop dublicate
anime_data.drop_duplicates(inplace = True)

# %% [markdown]
# ## Sampling

# %%
anime_train, anime_test = train_test_split(anime_data, test_size=0.2)
anime_test.to_csv("testDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("TrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Random_Active_Domain(),75, ignored_columns = [0,1,2,4,5,6,7])
Read_Write.write_csv_dataset("./{}.csv".format(Random_Active_Domain().name), new_dataset)
anime_train = pd.read_csv("./{}.csv".format(Random_Active_Domain().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to random_active_domain method ---------------
#
# row: 1510 col: 3 : 'movie' changed to 'tv series'
# row: 142 col: 3 : 'movie' changed to 'tv series'
# row: 1075 col: 3 : 'movie' changed to 'movie'
# row: 953 col: 3 : 'movie' changed to 'tv series'
# row: 1441 col: 3 : 'movie' changed to 'movie'
# row: 311 col: 3 : 'tv series' changed to 'tv series'
# row: 270 col: 3 : 'tv series' changed to 'tv series'
# row: 1417 col: 3 : 'movie' changed to 'tv series'
# row: 357 col: 3 : 'movie' changed to 'tv series'
# row: 834 col: 3 : 'tv series' changed to 'tv series'
# row: 26 col: 3 : 'tv series' changed to 'movie'
# row: 327 col: 3 : 'movie' changed to 'movie'
# row: 1570 col: 3 : 'tv series' changed to 'tv series'
# row: 1518 col: 3 : 'tv series' changed to 'movie'
# row: 856 col: 3 : 'movie' changed to 'tv series'
# row: 654 col: 3 : 'tv series' changed to 'tv series'
# row: 410 col: 3 : 'tv series' changed to 'tv series'
# row: 156 col: 3 : 'tv series' changed to 'tv series'
# row: 1109 col: 3 : 'tv series' changed to 'movie'
# row: 943 col: 3 : 'tv series' changed to 'movie'
# row: 19 col: 3 : 'movie' changed to 'movie'
# row: 545 col: 3 : 'movie' changed to 'tv series'
# row: 390 col: 3 : 'movie' changed to 'movie'
# row: 942 col: 3 : 'tv series' changed to 'movie'
# row: 509 col: 3 : 'tv series' changed to 'tv series'
# row: 307 col: 3 : 'movie' changed to 'movie'
# row: 1452 col: 3 : 'movie' changed to 'tv series'
# row: 31 col: 3 : 'tv series' changed to 'movie'
# row: 1402 col: 3 : 'movie' changed to 'tv series'
# row: 86 col: 3 : 'movie' changed to 'movie'
# row: 1495 col: 3 : 'movie' changed to 'movie'
# row: 1270 col: 3 : 'movie' changed to 'movie'
# row: 116 col: 3 : 'tv series' changed to 'tv series'
# row: 1209 col: 3 : 'movie' changed to 'movie'
# row: 988 col: 3 : 'tv series' changed to 'movie'
# row: 1285 col: 3 : 'tv series' changed to 'tv series'
# row: 813 col: 3 : 'tv series' changed to 'tv series'
# row: 1506 col: 3 : 'movie' changed to 'tv series'
# row: 1358 col: 3 : 'tv series' changed to 'tv series'
# row: 314 col: 3 : 'tv series' changed to 'movie'
# row: 145 col: 3 : 'movie' changed to 'tv series'
# row: 403 col: 3 : 'tv series' changed to 'movie'
# row: 198 col: 3 : 'movie' changed to 'movie'
# row: 420 col: 3 : 'movie' changed to 'tv series'
# row: 120 col: 3 : 'movie' changed to 'tv series'
# row: 1025 col: 3 : 'movie' changed to 'movie'
# row: 501 col: 3 : 'movie' changed to 'tv series'
# row: 799 col: 3 : 'tv series' changed to 'movie'
# row: 432 col: 3 : 'movie' changed to 'tv series'
# row: 391 col: 3 : 'tv series' changed to 'movie'
# row: 927 col: 3 : 'movie' changed to 'tv series'
# row: 415 col: 3 : 'movie' changed to 'movie'
# row: 1508 col: 3 : 'movie' changed to 'movie'
# row: 1033 col: 3 : 'tv series' changed to 'movie'
# row: 57 col: 3 : 'tv series' changed to 'tv series'
# row: 1409 col: 3 : 'movie' changed to 'tv series'
# row: 941 col: 3 : 'movie' changed to 'tv series'
# row: 441 col: 3 : 'tv series' changed to 'tv series'
# row: 840 col: 3 : 'tv series' changed to 'tv series'
# row: 193 col: 3 : 'movie' changed to 'tv series'
# row: 189 col: 3 : 'movie' changed to 'tv series'
# row: 305 col: 3 : 'movie' changed to 'movie'
# row: 887 col: 3 : 'movie' changed to 'tv series'
# row: 346 col: 3 : 'movie' changed to 'tv series'
# row: 558 col: 3 : 'movie' changed to 'movie'
# row: 994 col: 3 : 'tv series' changed to 'movie'
# row: 1116 col: 3 : 'tv series' changed to 'movie'
# row: 683 col: 3 : 'tv series' changed to 'movie'
# row: 547 col: 3 : 'tv series' changed to 'movie'
# row: 1211 col: 3 : 'tv series' changed to 'movie'
# row: 1302 col: 3 : 'tv series' changed to 'tv series'
# row: 1171 col: 3 : 'movie' changed to 'movie'
# row: 895 col: 3 : 'tv series' changed to 'tv series'
# row: 1156 col: 3 : 'tv series' changed to 'movie'
# row: 122 col: 3 : 'movie' changed to 'tv series'
# row: 717 col: 3 : 'tv series' changed to 'tv series'
# row: 719 col: 3 : 'movie' changed to 'tv series'
# row: 1530 col: 3 : 'tv series' changed to 'movie'
# row: 1240 col: 3 : 'movie' changed to 'tv series'
# row: 1120 col: 3 : 'movie' changed to 'movie'
# row: 1435 col: 3 : 'movie' changed to 'tv series'
# row: 1220 col: 3 : 'tv series' changed to 'tv series'
# row: 1319 col: 3 : 'movie' changed to 'movie'
# row: 1237 col: 3 : 'tv series' changed to 'movie'
# row: 224 col: 3 : 'tv series' changed to 'movie'
# row: 1044 col: 3 : 'movie' changed to 'tv series'
# row: 1054 col: 3 : 'tv series' changed to 'tv series'
# row: 1112 col: 3 : 'movie' changed to 'tv series'
# row: 190 col: 3 : 'tv series' changed to 'movie'
# row: 1385 col: 3 : 'tv series' changed to 'movie'
# row: 1158 col: 3 : 'tv series' changed to 'movie'
# row: 1035 col: 3 : 'movie' changed to 'tv series'
# row: 730 col: 3 : 'movie' changed to 'tv series'
# row: 800 col: 3 : 'movie' changed to 'tv series'
# row: 1323 col: 3 : 'tv series' changed to 'movie'
# row: 608 col: 3 : 'tv series' changed to 'tv series'
# row: 1330 col: 3 : 'movie' changed to 'movie'
# row: 1152 col: 3 : 'movie' changed to 'movie'
# row: 599 col: 3 : 'tv series' changed to 'movie'
# row: 563 col: 3 : 'movie' changed to 'tv series'
# row: 1524 col: 3 : 'movie' changed to 'movie'
# row: 1046 col: 3 : 'movie' changed to 'tv series'
# row: 612 col: 3 : 'movie' changed to 'tv series'
# row: 154 col: 3 : 'tv series' changed to 'movie'
# row: 303 col: 3 : 'tv series' changed to 'movie'
# row: 1122 col: 3 : 'movie' changed to 'tv series'
# row: 698 col: 3 : 'movie' changed to 'movie'
# row: 1062 col: 3 : 'tv series' changed to 'movie'
# row: 328 col: 3 : 'tv series' changed to 'movie'
# row: 1057 col: 3 : 'movie' changed to 'movie'
# row: 1551 col: 3 : 'movie' changed to 'tv series'
# row: 570 col: 3 : 'tv series' changed to 'tv series'
# row: 326 col: 3 : 'tv series' changed to 'movie'
# row: 301 col: 3 : 'tv series' changed to 'tv series'
# row: 275 col: 3 : 'tv series' changed to 'movie'
# row: 349 col: 3 : 'movie' changed to 'tv series'
# row: 1103 col: 3 : 'movie' changed to 'movie'
# row: 144 col: 3 : 'movie' changed to 'tv series'
# row: 87 col: 3 : 'tv series' changed to 'tv series'
# row: 22 col: 3 : 'tv series' changed to 'movie'
# row: 412 col: 3 : 'tv series' changed to 'tv series'
# row: 331 col: 3 : 'tv series' changed to 'movie'
# row: 176 col: 3 : 'tv series' changed to 'tv series'
# row: 454 col: 3 : 'tv series' changed to 'movie'
# row: 893 col: 3 : 'movie' changed to 'movie'
# row: 348 col: 3 : 'tv series' changed to 'tv series'
# row: 360 col: 3 : 'tv series' changed to 'movie'
# row: 614 col: 3 : 'tv series' changed to 'movie'
# row: 1234 col: 3 : 'tv series' changed to 'tv series'
# row: 720 col: 3 : 'movie' changed to 'tv series'
# row: 43 col: 3 : 'tv series' changed to 'movie'
# row: 1278 col: 3 : 'movie' changed to 'tv series'
# row: 1042 col: 3 : 'tv series' changed to 'movie'
# row: 963 col: 3 : 'movie' changed to 'tv series'
# row: 199 col: 3 : 'movie' changed to 'tv series'
# row: 1168 col: 3 : 'movie' changed to 'movie'
# row: 177 col: 3 : 'tv series' changed to 'tv series'
# row: 634 col: 3 : 'tv series' changed to 'movie'
# row: 894 col: 3 : 'movie' changed to 'tv series'
# row: 912 col: 3 : 'tv series' changed to 'movie'
# row: 1154 col: 3 : 'tv series' changed to 'tv series'
# row: 638 col: 3 : 'movie' changed to 'movie'
# row: 474 col: 3 : 'movie' changed to 'tv series'
# row: 1322 col: 3 : 'movie' changed to 'movie'
# row: 214 col: 3 : 'tv series' changed to 'tv series'
# row: 131 col: 3 : 'movie' changed to 'movie'
# row: 1486 col: 3 : 'tv series' changed to 'movie'
# row: 666 col: 3 : 'tv series' changed to 'tv series'
# row: 767 col: 3 : 'movie' changed to 'movie'
# row: 714 col: 3 : 'movie' changed to 'tv series'
# row: 485 col: 3 : 'movie' changed to 'tv series'
# row: 1517 col: 3 : 'movie' changed to 'tv series'
# row: 1351 col: 3 : 'tv series' changed to 'movie'
# row: 315 col: 3 : 'tv series' changed to 'tv series'
# row: 1367 col: 3 : 'tv series' changed to 'movie'
# row: 859 col: 3 : 'tv series' changed to 'movie'
# row: 1194 col: 3 : 'tv series' changed to 'movie'
# row: 1006 col: 3 : 'movie' changed to 'movie'
# row: 565 col: 3 : 'movie' changed to 'tv series'
# row: 8 col: 3 : 'tv series' changed to 'movie'
# row: 309 col: 3 : 'movie' changed to 'tv series'
# row: 899 col: 3 : 'movie' changed to 'movie'
# row: 705 col: 3 : 'tv series' changed to 'tv series'
# row: 924 col: 3 : 'movie' changed to 'movie'
# row: 926 col: 3 : 'movie' changed to 'tv series'
# row: 220 col: 3 : 'tv series' changed to 'tv series'
# row: 700 col: 3 : 'movie' changed to 'tv series'
# row: 47 col: 3 : 'tv series' changed to 'movie'
# row: 811 col: 3 : 'tv series' changed to 'movie'
# row: 968 col: 3 : 'movie' changed to 'tv series'
# row: 873 col: 3 : 'tv series' changed to 'tv series'
# row: 1088 col: 3 : 'tv series' changed to 'tv series'
# row: 300 col: 3 : 'tv series' changed to 'movie'
# row: 872 col: 3 : 'tv series' changed to 'movie'
# row: 253 col: 3 : 'movie' changed to 'tv series'
# row: 779 col: 3 : 'movie' changed to 'movie'
# row: 1001 col: 3 : 'tv series' changed to 'tv series'
# row: 673 col: 3 : 'tv series' changed to 'tv series'
# row: 1232 col: 3 : 'movie' changed to 'movie'
# row: 202 col: 3 : 'tv series' changed to 'tv series'
# row: 1276 col: 3 : 'movie' changed to 'movie'
# row: 1024 col: 3 : 'movie' changed to 'movie'
# row: 1182 col: 3 : 'movie' changed to 'tv series'
# row: 978 col: 3 : 'movie' changed to 'tv series'
# row: 1578 col: 3 : 'tv series' changed to 'movie'
# row: 345 col: 3 : 'movie' changed to 'tv series'
# row: 933 col: 3 : 'movie' changed to 'tv series'
# row: 880 col: 3 : 'movie' changed to 'tv series'
# row: 1239 col: 3 : 'movie' changed to 'movie'
# row: 754 col: 3 : 'tv series' changed to 'tv series'
# row: 1266 col: 3 : 'movie' changed to 'movie'
# row: 954 col: 3 : 'movie' changed to 'tv series'
# row: 668 col: 3 : 'tv series' changed to 'movie'
# row: 1555 col: 3 : 'tv series' changed to 'movie'
# row: 845 col: 3 : 'movie' changed to 'tv series'
# row: 961 col: 3 : 'tv series' changed to 'movie'
# row: 936 col: 3 : 'tv series' changed to 'tv series'
# row: 1193 col: 3 : 'tv series' changed to 'movie'
# row: 1312 col: 3 : 'tv series' changed to 'movie'
# row: 388 col: 3 : 'movie' changed to 'tv series'
# row: 237 col: 3 : 'tv series' changed to 'tv series'
# row: 351 col: 3 : 'tv series' changed to 'tv series'
# row: 1145 col: 3 : 'tv series' changed to 'tv series'
# row: 102 col: 3 : 'tv series' changed to 'movie'
# row: 235 col: 3 : 'movie' changed to 'tv series'
# row: 409 col: 3 : 'tv series' changed to 'tv series'
# row: 564 col: 3 : 'tv series' changed to 'movie'
# row: 477 col: 3 : 'movie' changed to 'tv series'
# row: 149 col: 3 : 'movie' changed to 'movie'
# row: 362 col: 3 : 'tv series' changed to 'tv series'
# row: 966 col: 3 : 'tv series' changed to 'movie'
# row: 1207 col: 3 : 'movie' changed to 'movie'
# row: 639 col: 3 : 'movie' changed to 'tv series'
# row: 572 col: 3 : 'movie' changed to 'movie'
# row: 385 col: 3 : 'tv series' changed to 'tv series'
# row: 1041 col: 3 : 'movie' changed to 'tv series'
# row: 285 col: 3 : 'tv series' changed to 'movie'
# row: 879 col: 3 : 'tv series' changed to 'movie'
# row: 340 col: 3 : 'tv series' changed to 'movie'
# row: 1387 col: 3 : 'tv series' changed to 'tv series'
# row: 889 col: 3 : 'tv series' changed to 'tv series'
# row: 21 col: 3 : 'movie' changed to 'movie'
# row: 4 col: 3 : 'movie' changed to 'tv series'
# row: 1043 col: 3 : 'movie' changed to 'movie'
# row: 500 col: 3 : 'tv series' changed to 'tv series'
# row: 512 col: 3 : 'movie' changed to 'tv series'
# row: 234 col: 3 : 'tv series' changed to 'tv series'
# row: 1115 col: 3 : 'movie' changed to 'movie'
# row: 1136 col: 3 : 'movie' changed to 'movie'
# row: 61 col: 3 : 'movie' changed to 'tv series'
# row: 832 col: 3 : 'tv series' changed to 'tv series'
# row: 1310 col: 3 : 'tv series' changed to 'movie'
# row: 920 col: 3 : 'movie' changed to 'movie'
# row: 1480 col: 3 : 'tv series' changed to 'tv series'
# row: 1572 col: 3 : 'movie' changed to 'movie'
# row: 1352 col: 3 : 'movie' changed to 'tv series'
# row: 593 col: 3 : 'tv series' changed to 'movie'
# row: 435 col: 3 : 'movie' changed to 'tv series'
# row: 1079 col: 3 : 'movie' changed to 'tv series'
# row: 993 col: 3 : 'tv series' changed to 'tv series'
# row: 1127 col: 3 : 'tv series' changed to 'movie'
# row: 1105 col: 3 : 'tv series' changed to 'tv series'
# row: 627 col: 3 : 'movie' changed to 'tv series'
# row: 221 col: 3 : 'tv series' changed to 'tv series'
# row: 1125 col: 3 : 'movie' changed to 'tv series'
# row: 466 col: 3 : 'movie' changed to 'tv series'
# row: 1589 col: 3 : 'movie' changed to 'movie'
# row: 397 col: 3 : 'movie' changed to 'tv series'
# row: 1229 col: 3 : 'movie' changed to 'movie'
# row: 1496 col: 3 : 'movie' changed to 'tv series'
# row: 1492 col: 3 : 'movie' changed to 'movie'
# row: 1453 col: 3 : 'tv series' changed to 'tv series'
# row: 1241 col: 3 : 'tv series' changed to 'movie'
# row: 1005 col: 3 : 'tv series' changed to 'tv series'
# row: 1346 col: 3 : 'tv series' changed to 'movie'
# row: 1597 col: 3 : 'tv series' changed to 'movie'
# row: 748 col: 3 : 'tv series' changed to 'tv series'
# row: 59 col: 3 : 'tv series' changed to 'movie'
# row: 891 col: 3 : 'movie' changed to 'tv series'
# row: 975 col: 3 : 'movie' changed to 'movie'
# row: 219 col: 3 : 'movie' changed to 'movie'
# row: 271 col: 3 : 'movie' changed to 'tv series'
# row: 426 col: 3 : 'tv series' changed to 'movie'
# row: 637 col: 3 : 'tv series' changed to 'movie'
# row: 277 col: 3 : 'tv series' changed to 'tv series'
# row: 790 col: 3 : 'tv series' changed to 'tv series'
# row: 201 col: 3 : 'movie' changed to 'movie'
# row: 282 col: 3 : 'tv series' changed to 'tv series'
# row: 223 col: 3 : 'tv series' changed to 'tv series'
# row: 1493 col: 3 : 'movie' changed to 'movie'
# row: 1244 col: 3 : 'movie' changed to 'tv series'
# row: 1314 col: 3 : 'movie' changed to 'movie'
# row: 973 col: 3 : 'tv series' changed to 'tv series'
# row: 1260 col: 3 : 'movie' changed to 'tv series'
# row: 1066 col: 3 : 'tv series' changed to 'tv series'
# row: 1485 col: 3 : 'movie' changed to 'movie'
# row: 777 col: 3 : 'movie' changed to 'tv series'
# row: 906 col: 3 : 'tv series' changed to 'movie'
# row: 1252 col: 3 : 'tv series' changed to 'movie'
# row: 1327 col: 3 : 'tv series' changed to 'movie'
# row: 143 col: 3 : 'tv series' changed to 'tv series'
# row: 1599 col: 3 : 'tv series' changed to 'tv series'
# row: 1167 col: 3 : 'tv series' changed to 'movie'
# row: 138 col: 3 : 'tv series' changed to 'tv series'
# row: 1595 col: 3 : 'tv series' changed to 'movie'
# row: 476 col: 3 : 'tv series' changed to 'tv series'
# row: 740 col: 3 : 'movie' changed to 'tv series'
# row: 944 col: 3 : 'movie' changed to 'movie'
# row: 1279 col: 3 : 'tv series' changed to 'tv series'
# row: 1256 col: 3 : 'tv series' changed to 'tv series'
# row: 883 col: 3 : 'movie' changed to 'tv series'
# row: 29 col: 3 : 'tv series' changed to 'movie'
# row: 1222 col: 3 : 'tv series' changed to 'tv series'
# row: 5 col: 3 : 'tv series' changed to 'movie'
# row: 1446 col: 3 : 'movie' changed to 'tv series'
# row: 619 col: 3 : 'movie' changed to 'tv series'
# row: 1281 col: 3 : 'tv series' changed to 'movie'
# row: 495 col: 3 : 'movie' changed to 'tv series'
# row: 18 col: 3 : 'tv series' changed to 'movie'
# row: 531 col: 3 : 'movie' changed to 'movie'
# row: 623 col: 3 : 'tv series' changed to 'tv series'
# row: 35 col: 3 : 'tv series' changed to 'tv series'
# row: 1077 col: 3 : 'tv series' changed to 'movie'
# row: 1353 col: 3 : 'tv series' changed to 'tv series'
# row: 1134 col: 3 : 'movie' changed to 'tv series'
# row: 1009 col: 3 : 'tv series' changed to 'tv series'
# row: 1456 col: 3 : 'tv series' changed to 'tv series'
# row: 947 col: 3 : 'movie' changed to 'tv series'
# row: 1316 col: 3 : 'tv series' changed to 'tv series'
# row: 853 col: 3 : 'movie' changed to 'tv series'
# row: 1176 col: 3 : 'tv series' changed to 'movie'
# row: 1284 col: 3 : 'movie' changed to 'tv series'
# row: 1427 col: 3 : 'movie' changed to 'movie'
# row: 1585 col: 3 : 'movie' changed to 'tv series'
# row: 283 col: 3 : 'movie' changed to 'movie'
# row: 1472 col: 3 : 'movie' changed to 'tv series'
# row: 904 col: 3 : 'tv series' changed to 'movie'
# row: 907 col: 3 : 'movie' changed to 'tv series'
# row: 146 col: 3 : 'movie' changed to 'movie'
# row: 1354 col: 3 : 'tv series' changed to 'tv series'
# row: 1562 col: 3 : 'movie' changed to 'movie'
# row: 54 col: 3 : 'movie' changed to 'tv series'
# row: 1095 col: 3 : 'movie' changed to 'tv series'
# row: 1061 col: 3 : 'tv series' changed to 'tv series'
# row: 516 col: 3 : 'movie' changed to 'movie'
# row: 344 col: 3 : 'tv series' changed to 'tv series'
# row: 365 col: 3 : 'movie' changed to 'tv series'
# row: 273 col: 3 : 'tv series' changed to 'movie'
# row: 562 col: 3 : 'movie' changed to 'tv series'
# row: 976 col: 3 : 'tv series' changed to 'movie'
# row: 243 col: 3 : 'tv series' changed to 'tv series'
# row: 1133 col: 3 : 'tv series' changed to 'tv series'
# row: 604 col: 3 : 'tv series' changed to 'tv series'
# row: 606 col: 3 : 'movie' changed to 'movie'
# row: 482 col: 3 : 'tv series' changed to 'movie'
# row: 646 col: 3 : 'movie' changed to 'tv series'
# row: 1264 col: 3 : 'movie' changed to 'movie'
# row: 446 col: 3 : 'movie' changed to 'tv series'
# row: 1096 col: 3 : 'tv series' changed to 'tv series'
# row: 245 col: 3 : 'tv series' changed to 'tv series'
# row: 837 col: 3 : 'movie' changed to 'tv series'
# row: 1519 col: 3 : 'movie' changed to 'tv series'
# row: 658 col: 3 : 'movie' changed to 'movie'
# row: 1569 col: 3 : 'movie' changed to 'movie'
# row: 106 col: 3 : 'tv series' changed to 'movie'
# row: 1423 col: 3 : 'tv series' changed to 'movie'
# row: 1164 col: 3 : 'tv series' changed to 'movie'
# row: 631 col: 3 : 'movie' changed to 'tv series'
# row: 392 col: 3 : 'movie' changed to 'tv series'
# row: 1013 col: 3 : 'tv series' changed to 'tv series'
# row: 1268 col: 3 : 'tv series' changed to 'movie'
# row: 1460 col: 3 : 'movie' changed to 'movie'
# row: 444 col: 3 : 'movie' changed to 'tv series'
# row: 225 col: 3 : 'movie' changed to 'tv series'
# row: 610 col: 3 : 'movie' changed to 'tv series'
# row: 1395 col: 3 : 'tv series' changed to 'movie'
# row: 732 col: 3 : 'movie' changed to 'tv series'
# row: 607 col: 3 : 'tv series' changed to 'movie'
# row: 890 col: 3 : 'movie' changed to 'tv series'
# row: 676 col: 3 : 'tv series' changed to 'movie'
# row: 888 col: 3 : 'tv series' changed to 'movie'
# row: 1416 col: 3 : 'tv series' changed to 'movie'
# row: 803 col: 3 : 'movie' changed to 'movie'
# row: 56 col: 3 : 'tv series' changed to 'tv series'
# row: 150 col: 3 : 'tv series' changed to 'tv series'
# row: 324 col: 3 : 'tv series' changed to 'tv series'
# row: 929 col: 3 : 'tv series' changed to 'movie'
# row: 1190 col: 3 : 'movie' changed to 'movie'
# row: 449 col: 3 : 'movie' changed to 'movie'
# row: 594 col: 3 : 'tv series' changed to 'tv series'
# row: 6 col: 3 : 'tv series' changed to 'tv series'
# row: 366 col: 3 : 'tv series' changed to 'movie'
# row: 1464 col: 3 : 'movie' changed to 'tv series'
# row: 552 col: 3 : 'movie' changed to 'movie'
# row: 734 col: 3 : 'movie' changed to 'tv series'
# row: 1292 col: 3 : 'tv series' changed to 'movie'
# row: 1236 col: 3 : 'tv series' changed to 'movie'
# row: 1187 col: 3 : 'movie' changed to 'tv series'
# row: 1469 col: 3 : 'tv series' changed to 'movie'
# row: 1503 col: 3 : 'tv series' changed to 'tv series'
# row: 707 col: 3 : 'tv series' changed to 'tv series'
# row: 1431 col: 3 : 'tv series' changed to 'movie'
# row: 517 col: 3 : 'tv series' changed to 'tv series'
# row: 1333 col: 3 : 'tv series' changed to 'movie'
# row: 1265 col: 3 : 'movie' changed to 'tv series'
# row: 489 col: 3 : 'tv series' changed to 'movie'
# row: 491 col: 3 : 'tv series' changed to 'tv series'
# row: 640 col: 3 : 'tv series' changed to 'tv series'
# row: 1295 col: 3 : 'movie' changed to 'movie'
# row: 333 col: 3 : 'tv series' changed to 'tv series'
# row: 108 col: 3 : 'tv series' changed to 'movie'
# row: 774 col: 3 : 'tv series' changed to 'movie'
# row: 1397 col: 3 : 'tv series' changed to 'movie'
# row: 758 col: 3 : 'tv series' changed to 'tv series'
# row: 1583 col: 3 : 'movie' changed to 'movie'
# row: 1076 col: 3 : 'tv series' changed to 'movie'
# row: 1475 col: 3 : 'tv series' changed to 'movie'
# row: 1180 col: 3 : 'tv series' changed to 'tv series'
# row: 1541 col: 3 : 'tv series' changed to 'movie'
# row: 617 col: 3 : 'tv series' changed to 'movie'
# row: 1049 col: 3 : 'tv series' changed to 'movie'
# row: 1380 col: 3 : 'tv series' changed to 'movie'
# row: 1212 col: 3 : 'movie' changed to 'movie'
# row: 990 col: 3 : 'tv series' changed to 'tv series'
# row: 1573 col: 3 : 'tv series' changed to 'tv series'
# row: 660 col: 3 : 'tv series' changed to 'tv series'
# row: 1210 col: 3 : 'tv series' changed to 'tv series'
# row: 81 col: 3 : 'movie' changed to 'tv series'
# row: 1593 col: 3 : 'tv series' changed to 'movie'
# row: 433 col: 3 : 'movie' changed to 'movie'
# row: 670 col: 3 : 'movie' changed to 'movie'
# row: 630 col: 3 : 'movie' changed to 'tv series'
# row: 1462 col: 3 : 'movie' changed to 'movie'
# row: 858 col: 3 : 'tv series' changed to 'tv series'
# row: 1414 col: 3 : 'tv series' changed to 'tv series'
# row: 974 col: 3 : 'tv series' changed to 'tv series'
# row: 802 col: 3 : 'tv series' changed to 'movie'
# row: 979 col: 3 : 'tv series' changed to 'movie'
# row: 407 col: 3 : 'tv series' changed to 'tv series'
# row: 709 col: 3 : 'tv series' changed to 'tv series'
# row: 139 col: 3 : 'movie' changed to 'movie'
# row: 513 col: 3 : 'movie' changed to 'tv series'
# row: 456 col: 3 : 'movie' changed to 'movie'
# row: 722 col: 3 : 'movie' changed to 'tv series'
# row: 765 col: 3 : 'tv series' changed to 'movie'
# row: 625 col: 3 : 'movie' changed to 'movie'
# row: 1436 col: 3 : 'tv series' changed to 'tv series'
# row: 361 col: 3 : 'movie' changed to 'tv series'
# row: 731 col: 3 : 'movie' changed to 'tv series'
# row: 998 col: 3 : 'tv series' changed to 'movie'
# row: 1315 col: 3 : 'movie' changed to 'tv series'
# row: 206 col: 3 : 'movie' changed to 'tv series'
# row: 945 col: 3 : 'movie' changed to 'tv series'
# row: 473 col: 3 : 'tv series' changed to 'tv series'
# row: 793 col: 3 : 'tv series' changed to 'tv series'
# row: 37 col: 3 : 'tv series' changed to 'tv series'
# row: 123 col: 3 : 'movie' changed to 'tv series'
# row: 1034 col: 3 : 'tv series' changed to 'tv series'
# row: 48 col: 3 : 'tv series' changed to 'tv series'
# row: 960 col: 3 : 'tv series' changed to 'movie'
# row: 772 col: 3 : 'movie' changed to 'movie'
# row: 786 col: 3 : 'movie' changed to 'movie'
# row: 922 col: 3 : 'tv series' changed to 'movie'
# row: 1394 col: 3 : 'tv series' changed to 'movie'
# row: 1208 col: 3 : 'tv series' changed to 'tv series'
# row: 685 col: 3 : 'tv series' changed to 'tv series'
# row: 806 col: 3 : 'tv series' changed to 'tv series'
# row: 1173 col: 3 : 'tv series' changed to 'tv series'
# row: 1509 col: 3 : 'movie' changed to 'tv series'
# row: 95 col: 3 : 'tv series' changed to 'tv series'
# row: 641 col: 3 : 'tv series' changed to 'movie'
# row: 169 col: 3 : 'movie' changed to 'tv series'
# row: 1324 col: 3 : 'movie' changed to 'movie'
# row: 438 col: 3 : 'movie' changed to 'tv series'
# row: 1332 col: 3 : 'tv series' changed to 'tv series'
# row: 163 col: 3 : 'tv series' changed to 'tv series'
# row: 1184 col: 3 : 'tv series' changed to 'movie'
# row: 712 col: 3 : 'tv series' changed to 'tv series'
# row: 1326 col: 3 : 'movie' changed to 'movie'
# row: 986 col: 3 : 'tv series' changed to 'movie'
# row: 939 col: 3 : 'tv series' changed to 'movie'
# row: 588 col: 3 : 'tv series' changed to 'tv series'
# row: 483 col: 3 : 'tv series' changed to 'movie'
# row: 1048 col: 3 : 'tv series' changed to 'tv series'
# row: 1201 col: 3 : 'tv series' changed to 'tv series'
# row: 1428 col: 3 : 'tv series' changed to 'tv series'
# row: 320 col: 3 : 'tv series' changed to 'movie'
# row: 1056 col: 3 : 'movie' changed to 'tv series'
# row: 1050 col: 3 : 'tv series' changed to 'tv series'
# row: 761 col: 3 : 'movie' changed to 'tv series'
# row: 368 col: 3 : 'tv series' changed to 'tv series'
# row: 959 col: 3 : 'tv series' changed to 'movie'
# row: 222 col: 3 : 'tv series' changed to 'tv series'
# row: 93 col: 3 : 'movie' changed to 'tv series'
# row: 1341 col: 3 : 'tv series' changed to 'movie'
# row: 780 col: 3 : 'tv series' changed to 'tv series'
# row: 411 col: 3 : 'movie' changed to 'movie'
# row: 921 col: 3 : 'movie' changed to 'tv series'
# row: 659 col: 3 : 'movie' changed to 'movie'
# row: 1068 col: 3 : 'movie' changed to 'movie'
# row: 1163 col: 3 : 'tv series' changed to 'movie'
# row: 398 col: 3 : 'tv series' changed to 'movie'
# row: 969 col: 3 : 'movie' changed to 'movie'
# row: 1340 col: 3 : 'tv series' changed to 'movie'
# row: 1197 col: 3 : 'movie' changed to 'movie'
# row: 423 col: 3 : 'tv series' changed to 'movie'
# row: 2 col: 3 : 'movie' changed to 'tv series'
# row: 1012 col: 3 : 'movie' changed to 'tv series'
# row: 335 col: 3 : 'tv series' changed to 'movie'
# row: 25 col: 3 : 'movie' changed to 'tv series'
# row: 256 col: 3 : 'tv series' changed to 'tv series'
# row: 747 col: 3 : 'tv series' changed to 'tv series'
# row: 866 col: 3 : 'movie' changed to 'movie'
# row: 160 col: 3 : 'movie' changed to 'tv series'
# row: 727 col: 3 : 'tv series' changed to 'tv series'
# row: 135 col: 3 : 'tv series' changed to 'movie'
# row: 818 col: 3 : 'tv series' changed to 'tv series'
# row: 103 col: 3 : 'movie' changed to 'tv series'
# row: 1336 col: 3 : 'movie' changed to 'tv series'
# row: 783 col: 3 : 'movie' changed to 'movie'
# row: 1563 col: 3 : 'tv series' changed to 'tv series'
# row: 164 col: 3 : 'tv series' changed to 'movie'
# row: 72 col: 3 : 'movie' changed to 'tv series'
# row: 908 col: 3 : 'movie' changed to 'tv series'
# row: 1379 col: 3 : 'movie' changed to 'tv series'
# row: 956 col: 3 : 'tv series' changed to 'movie'
# row: 136 col: 3 : 'movie' changed to 'movie'
# row: 768 col: 3 : 'movie' changed to 'movie'
# row: 291 col: 3 : 'tv series' changed to 'tv series'
# row: 1137 col: 3 : 'tv series' changed to 'tv series'
# row: 424 col: 3 : 'tv series' changed to 'movie'
# row: 814 col: 3 : 'tv series' changed to 'movie'
# row: 1022 col: 3 : 'tv series' changed to 'movie'
# row: 560 col: 3 : 'tv series' changed to 'movie'
# row: 759 col: 3 : 'tv series' changed to 'movie'
# row: 781 col: 3 : 'movie' changed to 'movie'
# row: 1007 col: 3 : 'movie' changed to 'tv series'
# row: 1140 col: 3 : 'tv series' changed to 'movie'
# row: 484 col: 3 : 'tv series' changed to 'movie'
# row: 650 col: 3 : 'tv series' changed to 'tv series'
# row: 1213 col: 3 : 'tv series' changed to 'movie'
# row: 522 col: 3 : 'tv series' changed to 'tv series'
# row: 1293 col: 3 : 'tv series' changed to 'tv series'
# row: 910 col: 3 : 'movie' changed to 'movie'
# row: 1313 col: 3 : 'tv series' changed to 'tv series'
# row: 1008 col: 3 : 'movie' changed to 'tv series'
# row: 1277 col: 3 : 'movie' changed to 'movie'
# row: 861 col: 3 : 'tv series' changed to 'tv series'
# row: 573 col: 3 : 'movie' changed to 'movie'
# row: 83 col: 3 : 'tv series' changed to 'tv series'
# row: 230 col: 3 : 'movie' changed to 'movie'
# row: 602 col: 3 : 'tv series' changed to 'movie'
# row: 649 col: 3 : 'movie' changed to 'tv series'
# row: 236 col: 3 : 'movie' changed to 'movie'
# row: 1113 col: 3 : 'movie' changed to 'tv series'
# row: 1235 col: 3 : 'movie' changed to 'movie'
# row: 458 col: 3 : 'movie' changed to 'tv series'
# row: 1457 col: 3 : 'movie' changed to 'tv series'
# row: 626 col: 3 : 'movie' changed to 'movie'
# row: 652 col: 3 : 'movie' changed to 'movie'
# row: 1545 col: 3 : 'tv series' changed to 'tv series'
# row: 384 col: 3 : 'movie' changed to 'movie'
# row: 1253 col: 3 : 'movie' changed to 'tv series'
# row: 1415 col: 3 : 'tv series' changed to 'movie'
# row: 1287 col: 3 : 'movie' changed to 'tv series'
# row: 1591 col: 3 : 'movie' changed to 'tv series'
# row: 559 col: 3 : 'tv series' changed to 'movie'
# row: 999 col: 3 : 'tv series' changed to 'tv series'
# row: 1155 col: 3 : 'tv series' changed to 'tv series'
# row: 713 col: 3 : 'tv series' changed to 'tv series'
# row: 682 col: 3 : 'movie' changed to 'tv series'
# row: 674 col: 3 : 'movie' changed to 'movie'
# row: 1289 col: 3 : 'movie' changed to 'movie'
# row: 1045 col: 3 : 'movie' changed to 'movie'
# row: 1 col: 3 : 'tv series' changed to 'movie'
# row: 1553 col: 3 : 'movie' changed to 'movie'
# row: 1023 col: 3 : 'tv series' changed to 'tv series'
# row: 1514 col: 3 : 'movie' changed to 'movie'
# row: 17 col: 3 : 'tv series' changed to 'tv series'
# row: 1304 col: 3 : 'movie' changed to 'tv series'
# row: 816 col: 3 : 'tv series' changed to 'tv series'
# row: 1251 col: 3 : 'movie' changed to 'movie'
# row: 502 col: 3 : 'tv series' changed to 'movie'
# row: 452 col: 3 : 'tv series' changed to 'movie'
# row: 735 col: 3 : 'tv series' changed to 'tv series'
# row: 1299 col: 3 : 'tv series' changed to 'tv series'
# row: 1359 col: 3 : 'movie' changed to 'tv series'
# row: 951 col: 3 : 'tv series' changed to 'tv series'
# row: 524 col: 3 : 'movie' changed to 'movie'
# row: 192 col: 3 : 'tv series' changed to 'movie'
# row: 1139 col: 3 : 'movie' changed to 'tv series'
# row: 1523 col: 3 : 'movie' changed to 'tv series'
# row: 860 col: 3 : 'tv series' changed to 'tv series'
# row: 521 col: 3 : 'tv series' changed to 'tv series'
# row: 535 col: 3 : 'movie' changed to 'movie'
# row: 1581 col: 3 : 'tv series' changed to 'movie'
# row: 949 col: 3 : 'movie' changed to 'movie'
# row: 1060 col: 3 : 'tv series' changed to 'movie'
# row: 14 col: 3 : 'movie' changed to 'tv series'
# row: 1301 col: 3 : 'tv series' changed to 'movie'
# row: 568 col: 3 : 'tv series' changed to 'tv series'
# row: 1451 col: 3 : 'tv series' changed to 'movie'
# row: 80 col: 3 : 'movie' changed to 'tv series'
# row: 468 col: 3 : 'tv series' changed to 'tv series'
# row: 207 col: 3 : 'tv series' changed to 'movie'
# row: 494 col: 3 : 'tv series' changed to 'movie'
# row: 380 col: 3 : 'movie' changed to 'movie'
# row: 184 col: 3 : 'tv series' changed to 'tv series'
# row: 1308 col: 3 : 'tv series' changed to 'tv series'
# row: 996 col: 3 : 'movie' changed to 'tv series'
# row: 715 col: 3 : 'tv series' changed to 'tv series'
# row: 656 col: 3 : 'movie' changed to 'movie'
# row: 141 col: 3 : 'movie' changed to 'tv series'
# row: 582 col: 3 : 'tv series' changed to 'movie'
# row: 1100 col: 3 : 'tv series' changed to 'movie'
# row: 881 col: 3 : 'movie' changed to 'movie'
# row: 1204 col: 3 : 'movie' changed to 'movie'
# row: 264 col: 3 : 'movie' changed to 'tv series'
# row: 1311 col: 3 : 'tv series' changed to 'movie'
# row: 809 col: 3 : 'movie' changed to 'tv series'
# row: 114 col: 3 : 'movie' changed to 'tv series'
# row: 389 col: 3 : 'movie' changed to 'movie'
# row: 44 col: 3 : 'movie' changed to 'tv series'
# row: 914 col: 3 : 'movie' changed to 'tv series'
# row: 1370 col: 3 : 'tv series' changed to 'tv series'
# row: 1185 col: 3 : 'movie' changed to 'movie'
# row: 1378 col: 3 : 'tv series' changed to 'tv series'
# row: 557 col: 3 : 'movie' changed to 'movie'
# row: 1525 col: 3 : 'movie' changed to 'movie'
# row: 1374 col: 3 : 'tv series' changed to 'movie'
# row: 1245 col: 3 : 'movie' changed to 'tv series'
# row: 248 col: 3 : 'tv series' changed to 'tv series'
# row: 251 col: 3 : 'tv series' changed to 'tv series'
# row: 819 col: 3 : 'tv series' changed to 'tv series'
# row: 977 col: 3 : 'movie' changed to 'tv series'
# row: 151 col: 3 : 'tv series' changed to 'tv series'
# row: 13 col: 3 : 'movie' changed to 'movie'
# row: 480 col: 3 : 'tv series' changed to 'tv series'
# row: 1505 col: 3 : 'tv series' changed to 'movie'
# row: 124 col: 3 : 'movie' changed to 'tv series'
# row: 1444 col: 3 : 'movie' changed to 'movie'
# row: 1169 col: 3 : 'movie' changed to 'movie'
# row: 1539 col: 3 : 'tv series' changed to 'tv series'
# row: 98 col: 3 : 'tv series' changed to 'tv series'
# row: 287 col: 3 : 'tv series' changed to 'movie'
# row: 1365 col: 3 : 'tv series' changed to 'tv series'
# row: 1135 col: 3 : 'movie' changed to 'movie'
# row: 828 col: 3 : 'movie' changed to 'movie'
# row: 1085 col: 3 : 'movie' changed to 'movie'
# row: 540 col: 3 : 'movie' changed to 'tv series'
# row: 323 col: 3 : 'movie' changed to 'tv series'
# row: 771 col: 3 : 'tv series' changed to 'tv series'
# row: 370 col: 3 : 'movie' changed to 'movie'
# row: 355 col: 3 : 'movie' changed to 'tv series'
# row: 746 col: 3 : 'tv series' changed to 'movie'
# row: 1228 col: 3 : 'movie' changed to 'movie'
# row: 694 col: 3 : 'movie' changed to 'tv series'
# row: 1010 col: 3 : 'tv series' changed to 'movie'
# row: 601 col: 3 : 'tv series' changed to 'tv series'
# row: 463 col: 3 : 'movie' changed to 'movie'
# row: 1067 col: 3 : 'movie' changed to 'movie'
# row: 1490 col: 3 : 'movie' changed to 'movie'
# row: 589 col: 3 : 'movie' changed to 'movie'
# row: 693 col: 3 : 'tv series' changed to 'tv series'
# row: 541 col: 3 : 'movie' changed to 'movie'
# row: 418 col: 3 : 'tv series' changed to 'tv series'
# row: 260 col: 3 : 'movie' changed to 'movie'
# row: 1467 col: 3 : 'movie' changed to 'movie'
# row: 1216 col: 3 : 'tv series' changed to 'movie'
# row: 429 col: 3 : 'tv series' changed to 'tv series'
# row: 598 col: 3 : 'tv series' changed to 'tv series'
# row: 1410 col: 3 : 'movie' changed to 'tv series'
# row: 971 col: 3 : 'tv series' changed to 'movie'
# row: 38 col: 3 : 'tv series' changed to 'tv series'
# row: 374 col: 3 : 'tv series' changed to 'movie'
# row: 364 col: 3 : 'movie' changed to 'tv series'
# row: 1282 col: 3 : 'movie' changed to 'tv series'
# row: 1438 col: 3 : 'movie' changed to 'movie'
# row: 1454 col: 3 : 'tv series' changed to 'movie'
# row: 1306 col: 3 : 'movie' changed to 'tv series'
# row: 478 col: 3 : 'tv series' changed to 'tv series'
# row: 137 col: 3 : 'tv series' changed to 'movie'
# row: 645 col: 3 : 'tv series' changed to 'movie'
# row: 414 col: 3 : 'tv series' changed to 'movie'
# row: 284 col: 3 : 'movie' changed to 'movie'
# row: 417 col: 3 : 'tv series' changed to 'tv series'
# row: 1468 col: 3 : 'movie' changed to 'tv series'
# row: 155 col: 3 : 'tv series' changed to 'tv series'
# row: 313 col: 3 : 'tv series' changed to 'tv series'
# row: 288 col: 3 : 'movie' changed to 'tv series'
# row: 955 col: 3 : 'tv series' changed to 'tv series'
# row: 550 col: 3 : 'tv series' changed to 'movie'
# row: 240 col: 3 : 'tv series' changed to 'tv series'
# row: 865 col: 3 : 'movie' changed to 'movie'
# row: 259 col: 3 : 'tv series' changed to 'tv series'
# row: 1172 col: 3 : 'tv series' changed to 'tv series'
# row: 1248 col: 3 : 'tv series' changed to 'movie'
# row: 611 col: 3 : 'tv series' changed to 'tv series'
# row: 1360 col: 3 : 'tv series' changed to 'tv series'
# row: 680 col: 3 : 'movie' changed to 'tv series'
# row: 486 col: 3 : 'tv series' changed to 'tv series'
# row: 67 col: 3 : 'movie' changed to 'tv series'
# row: 92 col: 3 : 'movie' changed to 'tv series'
# row: 1218 col: 3 : 'movie' changed to 'tv series'
# row: 510 col: 3 : 'movie' changed to 'tv series'
# row: 1038 col: 3 : 'tv series' changed to 'tv series'
# row: 852 col: 3 : 'movie' changed to 'movie'
# row: 1520 col: 3 : 'tv series' changed to 'tv series'
# row: 316 col: 3 : 'tv series' changed to 'movie'
# row: 1274 col: 3 : 'tv series' changed to 'movie'
# row: 950 col: 3 : 'tv series' changed to 'tv series'
# row: 396 col: 3 : 'tv series' changed to 'tv series'
# row: 1347 col: 3 : 'tv series' changed to 'movie'
# row: 134 col: 3 : 'tv series' changed to 'movie'
# row: 1055 col: 3 : 'tv series' changed to 'movie'
# row: 1224 col: 3 : 'tv series' changed to 'movie'
# row: 254 col: 3 : 'tv series' changed to 'movie'
# row: 697 col: 3 : 'movie' changed to 'tv series'
# row: 738 col: 3 : 'movie' changed to 'tv series'
# row: 274 col: 3 : 'tv series' changed to 'tv series'
# row: 1267 col: 3 : 'movie' changed to 'movie'
# row: 1447 col: 3 : 'movie' changed to 'tv series'
# row: 46 col: 3 : 'movie' changed to 'movie'
# row: 186 col: 3 : 'tv series' changed to 'movie'
# row: 33 col: 3 : 'tv series' changed to 'movie'
# row: 1536 col: 3 : 'tv series' changed to 'movie'
# row: 1206 col: 3 : 'tv series' changed to 'tv series'
# row: 750 col: 3 : 'movie' changed to 'movie'
# row: 575 col: 3 : 'tv series' changed to 'movie'
# row: 490 col: 3 : 'movie' changed to 'tv series'
# row: 854 col: 3 : 'movie' changed to 'tv series'
# row: 113 col: 3 : 'movie' changed to 'tv series'
# row: 551 col: 3 : 'movie' changed to 'movie'
# row: 1200 col: 3 : 'tv series' changed to 'tv series'
# row: 1286 col: 3 : 'movie' changed to 'tv series'
# row: 352 col: 3 : 'movie' changed to 'tv series'
# row: 302 col: 3 : 'movie' changed to 'tv series'
# row: 566 col: 3 : 'movie' changed to 'movie'
# row: 1058 col: 3 : 'movie' changed to 'tv series'
# row: 903 col: 3 : 'movie' changed to 'movie'
# row: 1119 col: 3 : 'tv series' changed to 'movie'
# row: 1143 col: 3 : 'movie' changed to 'movie'
# row: 1504 col: 3 : 'tv series' changed to 'tv series'
# row: 1550 col: 3 : 'tv series' changed to 'movie'
# row: 73 col: 3 : 'tv series' changed to 'movie'
# row: 629 col: 3 : 'movie' changed to 'movie'
# row: 55 col: 3 : 'movie' changed to 'tv series'
# row: 703 col: 3 : 'movie' changed to 'tv series'
# row: 635 col: 3 : 'tv series' changed to 'movie'
# row: 147 col: 3 : 'tv series' changed to 'tv series'
# row: 1219 col: 3 : 'movie' changed to 'movie'
# row: 1533 col: 3 : 'tv series' changed to 'movie'
# row: 869 col: 3 : 'movie' changed to 'movie'
# row: 1111 col: 3 : 'movie' changed to 'tv series'
# row: 1381 col: 3 : 'tv series' changed to 'tv series'
# row: 900 col: 3 : 'tv series' changed to 'tv series'
# row: 679 col: 3 : 'tv series' changed to 'movie'
# row: 77 col: 3 : 'tv series' changed to 'movie'
# row: 269 col: 3 : 'tv series' changed to 'movie'
# row: 1390 col: 3 : 'movie' changed to 'tv series'
# row: 787 col: 3 : 'tv series' changed to 'movie'
# row: 119 col: 3 : 'tv series' changed to 'tv series'
# row: 376 col: 3 : 'movie' changed to 'tv series'
# row: 823 col: 3 : 'movie' changed to 'movie'
# row: 373 col: 3 : 'movie' changed to 'movie'
# row: 1592 col: 3 : 'tv series' changed to 'tv series'
# row: 1258 col: 3 : 'tv series' changed to 'tv series'
# row: 399 col: 3 : 'movie' changed to 'movie'
# row: 826 col: 3 : 'movie' changed to 'movie'
# row: 723 col: 3 : 'movie' changed to 'tv series'
# row: 909 col: 3 : 'tv series' changed to 'movie'
# row: 1309 col: 3 : 'tv series' changed to 'tv series'
# row: 319 col: 3 : 'tv series' changed to 'tv series'
# row: 855 col: 3 : 'movie' changed to 'tv series'
# row: 99 col: 3 : 'tv series' changed to 'movie'
# row: 701 col: 3 : 'movie' changed to 'movie'
# row: 20 col: 3 : 'tv series' changed to 'movie'
# row: 304 col: 3 : 'tv series' changed to 'movie'
# row: 182 col: 3 : 'movie' changed to 'tv series'
# row: 657 col: 3 : 'movie' changed to 'tv series'
# row: 864 col: 3 : 'tv series' changed to 'movie'
# row: 1526 col: 3 : 'movie' changed to 'movie'
# row: 334 col: 3 : 'movie' changed to 'tv series'
# row: 1082 col: 3 : 'movie' changed to 'tv series'
# row: 257 col: 3 : 'tv series' changed to 'tv series'
# row: 227 col: 3 : 'movie' changed to 'tv series'
# row: 742 col: 3 : 'movie' changed to 'tv series'
# row: 1031 col: 3 : 'tv series' changed to 'tv series'
# row: 445 col: 3 : 'movie' changed to 'tv series'
# row: 493 col: 3 : 'tv series' changed to 'movie'
# row: 1298 col: 3 : 'tv series' changed to 'tv series'
# row: 406 col: 3 : 'movie' changed to 'movie'
# row: 824 col: 3 : 'tv series' changed to 'movie'
# row: 796 col: 3 : 'tv series' changed to 'tv series'
# row: 393 col: 3 : 'tv series' changed to 'movie'
# row: 1532 col: 3 : 'movie' changed to 'movie'
# row: 10 col: 3 : 'movie' changed to 'movie'
# row: 375 col: 3 : 'tv series' changed to 'tv series'
# row: 1032 col: 3 : 'tv series' changed to 'tv series'
# row: 462 col: 3 : 'movie' changed to 'tv series'
# row: 1549 col: 3 : 'movie' changed to 'tv series'
# row: 1521 col: 3 : 'tv series' changed to 'movie'
# row: 90 col: 3 : 'movie' changed to 'movie'
# row: 574 col: 3 : 'movie' changed to 'movie'
# row: 297 col: 3 : 'movie' changed to 'tv series'
# row: 200 col: 3 : 'movie' changed to 'movie'
# row: 353 col: 3 : 'movie' changed to 'tv series'
# row: 1590 col: 3 : 'movie' changed to 'tv series'
# row: 721 col: 3 : 'movie' changed to 'tv series'
# row: 1129 col: 3 : 'movie' changed to 'movie'
# row: 1051 col: 3 : 'movie' changed to 'movie'
# row: 615 col: 3 : 'tv series' changed to 'tv series'
# row: 310 col: 3 : 'tv series' changed to 'tv series'
# row: 827 col: 3 : 'tv series' changed to 'tv series'
# row: 7 col: 3 : 'tv series' changed to 'movie'
# row: 886 col: 3 : 'movie' changed to 'tv series'
# row: 985 col: 3 : 'tv series' changed to 'movie'
# row: 817 col: 3 : 'movie' changed to 'movie'
# row: 188 col: 3 : 'movie' changed to 'tv series'
# row: 1246 col: 3 : 'tv series' changed to 'movie'
# row: 1432 col: 3 : 'movie' changed to 'movie'
# row: 1000 col: 3 : 'tv series' changed to 'tv series'
# row: 1026 col: 3 : 'tv series' changed to 'movie'
# row: 1040 col: 3 : 'movie' changed to 'tv series'
# row: 455 col: 3 : 'tv series' changed to 'movie'
# row: 618 col: 3 : 'tv series' changed to 'tv series'
# row: 596 col: 3 : 'movie' changed to 'movie'
# row: 1461 col: 3 : 'tv series' changed to 'movie'
# row: 1124 col: 3 : 'tv series' changed to 'movie'
# row: 180 col: 3 : 'tv series' changed to 'movie'
# row: 1389 col: 3 : 'movie' changed to 'movie'
# row: 851 col: 3 : 'tv series' changed to 'movie'
# row: 1420 col: 3 : 'movie' changed to 'tv series'
# row: 1196 col: 3 : 'tv series' changed to 'tv series'
# row: 1412 col: 3 : 'tv series' changed to 'movie'
# row: 548 col: 3 : 'movie' changed to 'movie'
# row: 431 col: 3 : 'tv series' changed to 'tv series'
# row: 896 col: 3 : 'movie' changed to 'tv series'
# row: 843 col: 3 : 'tv series' changed to 'tv series'
# row: 578 col: 3 : 'tv series' changed to 'movie'
# row: 1364 col: 3 : 'movie' changed to 'tv series'
# row: 916 col: 3 : 'tv series' changed to 'tv series'
# row: 325 col: 3 : 'tv series' changed to 'movie'
# row: 689 col: 3 : 'tv series' changed to 'movie'
# row: 427 col: 3 : 'movie' changed to 'tv series'
# row: 196 col: 3 : 'movie' changed to 'movie'
# row: 1342 col: 3 : 'movie' changed to 'movie'
# row: 928 col: 3 : 'tv series' changed to 'tv series'
# row: 905 col: 3 : 'movie' changed to 'tv series'
# row: 1106 col: 3 : 'tv series' changed to 'movie'
# row: 267 col: 3 : 'tv series' changed to 'tv series'
# row: 212 col: 3 : 'movie' changed to 'tv series'
# row: 1433 col: 3 : 'tv series' changed to 'tv series'
# row: 1162 col: 3 : 'tv series' changed to 'tv series'
# row: 379 col: 3 : 'movie' changed to 'tv series'
# row: 255 col: 3 : 'tv series' changed to 'tv series'
# row: 808 col: 3 : 'tv series' changed to 'movie'
# row: 1018 col: 3 : 'movie' changed to 'movie'
# row: 63 col: 3 : 'movie' changed to 'movie'
# row: 195 col: 3 : 'tv series' changed to 'movie'
# row: 1554 col: 3 : 'tv series' changed to 'tv series'
# row: 1418 col: 3 : 'tv series' changed to 'movie'
# row: 1512 col: 3 : 'movie' changed to 'movie'
# row: 1198 col: 3 : 'tv series' changed to 'movie'
# row: 1146 col: 3 : 'movie' changed to 'movie'
# row: 587 col: 3 : 'tv series' changed to 'movie'
# row: 736 col: 3 : 'movie' changed to 'tv series'
# row: 443 col: 3 : 'movie' changed to 'movie'
# row: 208 col: 3 : 'tv series' changed to 'movie'
# row: 1002 col: 3 : 'tv series' changed to 'tv series'
# row: 341 col: 3 : 'movie' changed to 'tv series'
# row: 252 col: 3 : 'movie' changed to 'tv series'
# row: 231 col: 3 : 'movie' changed to 'movie'
# row: 1502 col: 3 : 'tv series' changed to 'movie'
# row: 554 col: 3 : 'movie' changed to 'tv series'
# row: 871 col: 3 : 'tv series' changed to 'tv series'
# row: 1144 col: 3 : 'tv series' changed to 'tv series'
# row: 1458 col: 3 : 'tv series' changed to 'movie'
# row: 534 col: 3 : 'tv series' changed to 'movie'
# row: 1499 col: 3 : 'tv series' changed to 'movie'
# row: 651 col: 3 : 'movie' changed to 'movie'
# row: 272 col: 3 : 'movie' changed to 'movie'
# row: 400 col: 3 : 'tv series' changed to 'movie'
# row: 129 col: 3 : 'movie' changed to 'tv series'
# row: 583 col: 3 : 'movie' changed to 'movie'
# row: 850 col: 3 : 'movie' changed to 'tv series'
# row: 211 col: 3 : 'tv series' changed to 'tv series'
# row: 695 col: 3 : 'movie' changed to 'tv series'
# row: 459 col: 3 : 'movie' changed to 'tv series'
# row: 215 col: 3 : 'tv series' changed to 'tv series'
# row: 1189 col: 3 : 'tv series' changed to 'movie'
# row: 987 col: 3 : 'tv series' changed to 'movie'
# row: 934 col: 3 : 'tv series' changed to 'movie'
# row: 620 col: 3 : 'tv series' changed to 'tv series'
# row: 109 col: 3 : 'tv series' changed to 'tv series'
# row: 757 col: 3 : 'tv series' changed to 'tv series'
# row: 940 col: 3 : 'tv series' changed to 'movie'
# row: 1371 col: 3 : 'tv series' changed to 'movie'
# row: 725 col: 3 : 'tv series' changed to 'tv series'
# row: 1092 col: 3 : 'tv series' changed to 'tv series'
# row: 408 col: 3 : 'movie' changed to 'tv series'
# row: 289 col: 3 : 'tv series' changed to 'movie'
# row: 161 col: 3 : 'movie' changed to 'tv series'
# row: 1422 col: 3 : 'movie' changed to 'movie'
# row: 1543 col: 3 : 'tv series' changed to 'tv series'
# row: 1407 col: 3 : 'tv series' changed to 'tv series'
# row: 447 col: 3 : 'movie' changed to 'movie'
# row: 1331 col: 3 : 'tv series' changed to 'tv series'
# row: 1513 col: 3 : 'movie' changed to 'tv series'
# row: 338 col: 3 : 'movie' changed to 'movie'
# row: 830 col: 3 : 'movie' changed to 'tv series'
# row: 1434 col: 3 : 'movie' changed to 'movie'
# row: 1391 col: 3 : 'tv series' changed to 'movie'
# row: 127 col: 3 : 'tv series' changed to 'tv series'
# row: 609 col: 3 : 'tv series' changed to 'movie'
# row: 846 col: 3 : 'tv series' changed to 'tv series'
# row: 1160 col: 3 : 'movie' changed to 'tv series'
# row: 84 col: 3 : 'tv series' changed to 'tv series'
# row: 475 col: 3 : 'tv series' changed to 'tv series'
# row: 89 col: 3 : 'movie' changed to 'movie'
# row: 863 col: 3 : 'movie' changed to 'movie'
# row: 1179 col: 3 : 'tv series' changed to 'tv series'
# row: 911 col: 3 : 'movie' changed to 'tv series'
# row: 187 col: 3 : 'movie' changed to 'tv series'
# row: 805 col: 3 : 'movie' changed to 'movie'
# row: 1511 col: 3 : 'movie' changed to 'tv series'
# row: 665 col: 3 : 'movie' changed to 'movie'
# row: 1430 col: 3 : 'movie' changed to 'tv series'
# row: 381 col: 3 : 'tv series' changed to 'tv series'
# row: 258 col: 3 : 'movie' changed to 'movie'
# row: 413 col: 3 : 'movie' changed to 'tv series'
# row: 667 col: 3 : 'movie' changed to 'tv series'
# row: 932 col: 3 : 'tv series' changed to 'movie'
# row: 669 col: 3 : 'tv series' changed to 'tv series'
# row: 70 col: 3 : 'movie' changed to 'tv series'
# row: 356 col: 3 : 'movie' changed to 'movie'
# row: 1455 col: 3 : 'tv series' changed to 'tv series'
# row: 726 col: 3 : 'tv series' changed to 'tv series'
# row: 776 col: 3 : 'movie' changed to 'movie'
# row: 810 col: 3 : 'tv series' changed to 'tv series'
# row: 1476 col: 3 : 'movie' changed to 'tv series'
# row: 857 col: 3 : 'movie' changed to 'tv series'
# row: 995 col: 3 : 'movie' changed to 'movie'
# row: 1148 col: 3 : 'movie' changed to 'movie'
# row: 175 col: 3 : 'movie' changed to 'movie'
# row: 1588 col: 3 : 'tv series' changed to 'tv series'
# row: 603 col: 3 : 'movie' changed to 'tv series'
# row: 244 col: 3 : 'tv series' changed to 'movie'
# row: 1535 col: 3 : 'movie' changed to 'tv series'
# row: 354 col: 3 : 'tv series' changed to 'tv series'
# row: 1361 col: 3 : 'movie' changed to 'tv series'
# row: 556 col: 3 : 'tv series' changed to 'movie'
# row: 1086 col: 3 : 'tv series' changed to 'movie'
# row: 592 col: 3 : 'movie' changed to 'movie'
# row: 34 col: 3 : 'movie' changed to 'movie'
# row: 590 col: 3 : 'tv series' changed to 'tv series'
# row: 170 col: 3 : 'movie' changed to 'movie'
# row: 469 col: 3 : 'tv series' changed to 'tv series'
# row: 519 col: 3 : 'tv series' changed to 'movie'
# row: 1449 col: 3 : 'tv series' changed to 'tv series'
# row: 75 col: 3 : 'tv series' changed to 'movie'
# row: 616 col: 3 : 'tv series' changed to 'tv series'
# row: 1195 col: 3 : 'movie' changed to 'movie'
# row: 1548 col: 3 : 'movie' changed to 'movie'
# row: 923 col: 3 : 'movie' changed to 'movie'
# row: 1366 col: 3 : 'movie' changed to 'movie'
# row: 439 col: 3 : 'movie' changed to 'tv series'
# row: 1349 col: 3 : 'movie' changed to 'tv series'
# row: 1507 col: 3 : 'tv series' changed to 'movie'
# row: 1567 col: 3 : 'movie' changed to 'movie'
# row: 597 col: 3 : 'movie' changed to 'tv series'
# row: 492 col: 3 : 'tv series' changed to 'tv series'
# row: 217 col: 3 : 'movie' changed to 'tv series'
# row: 436 col: 3 : 'tv series' changed to 'tv series'
# row: 1355 col: 3 : 'tv series' changed to 'movie'
# row: 266 col: 3 : 'movie' changed to 'movie'
# row: 526 col: 3 : 'movie' changed to 'movie'
# row: 11 col: 3 : 'tv series' changed to 'movie'
# row: 1117 col: 3 : 'tv series' changed to 'tv series'
# row: 68 col: 3 : 'movie' changed to 'movie'
# row: 276 col: 3 : 'movie' changed to 'tv series'
# row: 1384 col: 3 : 'movie' changed to 'movie'
# row: 844 col: 3 : 'movie' changed to 'movie'
# row: 539 col: 3 : 'tv series' changed to 'movie'
# row: 741 col: 3 : 'tv series' changed to 'tv series'
# row: 293 col: 3 : 'movie' changed to 'tv series'
# row: 23 col: 3 : 'movie' changed to 'tv series'
# row: 1174 col: 3 : 'tv series' changed to 'movie'
# row: 1482 col: 3 : 'tv series' changed to 'movie'
# row: 1501 col: 3 : 'tv series' changed to 'movie'
# row: 706 col: 3 : 'movie' changed to 'tv series'
# row: 1558 col: 3 : 'movie' changed to 'movie'
# row: 172 col: 3 : 'movie' changed to 'movie'
# row: 600 col: 3 : 'movie' changed to 'tv series'
# row: 1388 col: 3 : 'movie' changed to 'movie'
# row: 841 col: 3 : 'movie' changed to 'movie'
# row: 133 col: 3 : 'tv series' changed to 'tv series'
# row: 104 col: 3 : 'tv series' changed to 'movie'
# row: 1405 col: 3 : 'tv series' changed to 'movie'
# row: 32 col: 3 : 'movie' changed to 'tv series'
# row: 306 col: 3 : 'movie' changed to 'tv series'
# row: 430 col: 3 : 'movie' changed to 'movie'
# row: 1294 col: 3 : 'tv series' changed to 'movie'
# row: 130 col: 3 : 'tv series' changed to 'movie'
# row: 1529 col: 3 : 'movie' changed to 'tv series'
# row: 561 col: 3 : 'movie' changed to 'movie'
# row: 121 col: 3 : 'tv series' changed to 'movie'
# row: 1413 col: 3 : 'movie' changed to 'movie'
# row: 1247 col: 3 : 'movie' changed to 'tv series'
# row: 1227 col: 3 : 'movie' changed to 'tv series'
# row: 518 col: 3 : 'movie' changed to 'tv series'
# row: 584 col: 3 : 'movie' changed to 'tv series'
# row: 52 col: 3 : 'tv series' changed to 'tv series'
# row: 992 col: 3 : 'movie' changed to 'movie'
# row: 1003 col: 3 : 'tv series' changed to 'movie'
# row: 1142 col: 3 : 'movie' changed to 'movie'
# row: 1411 col: 3 : 'tv series' changed to 'tv series'
# row: 1203 col: 3 : 'tv series' changed to 'movie'
# row: 27 col: 3 : 'tv series' changed to 'tv series'
# row: 292 col: 3 : 'tv series' changed to 'movie'
# row: 1376 col: 3 : 'tv series' changed to 'tv series'
# row: 1243 col: 3 : 'tv series' changed to 'movie'
# row: 1074 col: 3 : 'tv series' changed to 'movie'
# row: 440 col: 3 : 'movie' changed to 'tv series'
# row: 110 col: 3 : 'tv series' changed to 'movie'
# row: 497 col: 3 : 'tv series' changed to 'tv series'
# row: 1273 col: 3 : 'tv series' changed to 'tv series'
# row: 218 col: 3 : 'tv series' changed to 'movie'
# row: 171 col: 3 : 'tv series' changed to 'tv series'
# row: 1081 col: 3 : 'movie' changed to 'movie'
# row: 1072 col: 3 : 'movie' changed to 'movie'
# row: 937 col: 3 : 'movie' changed to 'tv series'
# row: 930 col: 3 : 'movie' changed to 'movie'
# row: 402 col: 3 : 'tv series' changed to 'movie'
# row: 332 col: 3 : 'movie' changed to 'movie'
# row: 710 col: 3 : 'movie' changed to 'tv series'
# row: 205 col: 3 : 'movie' changed to 'movie'
# row: 962 col: 3 : 'tv series' changed to 'tv series'
# row: 1566 col: 3 : 'tv series' changed to 'tv series'
# row: 997 col: 3 : 'movie' changed to 'tv series'
# row: 935 col: 3 : 'tv series' changed to 'movie'
# row: 1582 col: 3 : 'movie' changed to 'tv series'
# row: 1199 col: 3 : 'tv series' changed to 'tv series'
# row: 983 col: 3 : 'tv series' changed to 'movie'
# row: 801 col: 3 : 'tv series' changed to 'tv series'
# row: 1157 col: 3 : 'tv series' changed to 'movie'
# row: 247 col: 3 : 'movie' changed to 'tv series'
# row: 528 col: 3 : 'movie' changed to 'tv series'
# row: 318 col: 3 : 'tv series' changed to 'tv series'
# row: 111 col: 3 : 'tv series' changed to 'tv series'
# row: 1305 col: 3 : 'tv series' changed to 'tv series'
# row: 1016 col: 3 : 'tv series' changed to 'tv series'
# row: 632 col: 3 : 'tv series' changed to 'movie'
# row: 367 col: 3 : 'movie' changed to 'movie'
# row: 461 col: 3 : 'movie' changed to 'movie'
# row: 1083 col: 3 : 'tv series' changed to 'movie'
# row: 1515 col: 3 : 'tv series' changed to 'movie'
# row: 1261 col: 3 : 'tv series' changed to 'tv series'
# row: 118 col: 3 : 'movie' changed to 'movie'
# row: 242 col: 3 : 'tv series' changed to 'tv series'
# row: 749 col: 3 : 'movie' changed to 'tv series'
# row: 126 col: 3 : 'movie' changed to 'movie'
# row: 702 col: 3 : 'movie' changed to 'movie'
# row: 1123 col: 3 : 'tv series' changed to 'tv series'
# row: 982 col: 3 : 'tv series' changed to 'tv series'
# row: 744 col: 3 : 'tv series' changed to 'tv series'
# row: 1021 col: 3 : 'movie' changed to 'tv series'
# row: 3 col: 3 : 'movie' changed to 'tv series'
# row: 263 col: 3 : 'tv series' changed to 'tv series'
# row: 28 col: 3 : 'tv series' changed to 'tv series'
# row: 343 col: 3 : 'movie' changed to 'tv series'
# row: 174 col: 3 : 'tv series' changed to 'tv series'
# row: 479 col: 3 : 'tv series' changed to 'movie'
# row: 675 col: 3 : 'tv series' changed to 'tv series'
# row: 1471 col: 3 : 'tv series' changed to 'movie'
# row: 655 col: 3 : 'tv series' changed to 'movie'
# row: 1559 col: 3 : 'tv series' changed to 'tv series'
# row: 1181 col: 3 : 'tv series' changed to 'movie'
# row: 1089 col: 3 : 'tv series' changed to 'tv series'
# row: 496 col: 3 : 'movie' changed to 'movie'
# row: 1165 col: 3 : 'tv series' changed to 'movie'
# row: 1338 col: 3 : 'tv series' changed to 'movie'
# row: 591 col: 3 : 'movie' changed to 'movie'
# row: 179 col: 3 : 'movie' changed to 'movie'
# row: 1029 col: 3 : 'movie' changed to 'tv series'
# row: 628 col: 3 : 'movie' changed to 'movie'
# row: 989 col: 3 : 'tv series' changed to 'movie'
# row: 165 col: 3 : 'movie' changed to 'tv series'
# row: 1516 col: 3 : 'movie' changed to 'tv series'
# row: 448 col: 3 : 'movie' changed to 'tv series'
# row: 711 col: 3 : 'tv series' changed to 'movie'
# row: 538 col: 3 : 'movie' changed to 'movie'
# row: 153 col: 3 : 'movie' changed to 'tv series'
# row: 1192 col: 3 : 'movie' changed to 'tv series'
# row: 232 col: 3 : 'tv series' changed to 'tv series'
# row: 1335 col: 3 : 'tv series' changed to 'tv series'
# row: 1036 col: 3 : 'tv series' changed to 'movie'
# row: 877 col: 3 : 'tv series' changed to 'tv series'
# row: 525 col: 3 : 'tv series' changed to 'tv series'
# row: 1439 col: 3 : 'tv series' changed to 'tv series'
# row: 868 col: 3 : 'tv series' changed to 'tv series'
# row: 579 col: 3 : 'movie' changed to 'movie'
# row: 1557 col: 3 : 'tv series' changed to 'movie'
# row: 1375 col: 3 : 'tv series' changed to 'tv series'
# row: 875 col: 3 : 'tv series' changed to 'movie'
# row: 265 col: 3 : 'movie' changed to 'movie'
# row: 1337 col: 3 : 'tv series' changed to 'tv series'
# row: 775 col: 3 : 'tv series' changed to 'movie'
# row: 1275 col: 3 : 'tv series' changed to 'tv series'
# row: 1078 col: 3 : 'tv series' changed to 'movie'
# row: 1443 col: 3 : 'tv series' changed to 'movie'
# row: 1575 col: 3 : 'movie' changed to 'movie'
# row: 553 col: 3 : 'tv series' changed to 'movie'
# row: 1448 col: 3 : 'movie' changed to 'tv series'
# row: 773 col: 3 : 'movie' changed to 'tv series'
# row: 1473 col: 3 : 'tv series' changed to 'tv series'
# row: 898 col: 3 : 'tv series' changed to 'movie'
# row: 692 col: 3 : 'movie' changed to 'tv series'
# row: 970 col: 3 : 'movie' changed to 'movie'
# row: 1028 col: 3 : 'tv series' changed to 'movie'
# row: 1343 col: 3 : 'movie' changed to 'tv series'
# row: 678 col: 3 : 'movie' changed to 'movie'
# row: 839 col: 3 : 'movie' changed to 'tv series'
# row: 387 col: 3 : 'tv series' changed to 'tv series'
# row: 261 col: 3 : 'tv series' changed to 'tv series'
# row: 1214 col: 3 : 'tv series' changed to 'tv series'
# row: 166 col: 3 : 'movie' changed to 'movie'
# row: 1393 col: 3 : 'tv series' changed to 'tv series'
# row: 181 col: 3 : 'tv series' changed to 'movie'
# row: 672 col: 3 : 'movie' changed to 'tv series'
# row: 1098 col: 3 : 'tv series' changed to 'tv series'
# row: 1147 col: 3 : 'tv series' changed to 'movie'
# row: 94 col: 3 : 'tv series' changed to 'movie'
# row: 1064 col: 3 : 'movie' changed to 'tv series'
# row: 520 col: 3 : 'tv series' changed to 'movie'
# row: 688 col: 3 : 'movie' changed to 'movie'
# row: 892 col: 3 : 'movie' changed to 'movie'
# row: 1598 col: 3 : 'tv series' changed to 'movie'
# row: 1445 col: 3 : 'movie' changed to 'movie'
# row: 642 col: 3 : 'movie' changed to 'movie'
# row: 342 col: 3 : 'tv series' changed to 'tv series'
# row: 1186 col: 3 : 'tv series' changed to 'tv series'
# row: 733 col: 3 : 'movie' changed to 'tv series'
# row: 204 col: 3 : 'tv series' changed to 'movie'
# row: 812 col: 3 : 'movie' changed to 'tv series'
# row: 45 col: 3 : 'tv series' changed to 'tv series'
# row: 1487 col: 3 : 'tv series' changed to 'movie'
# row: 1386 col: 3 : 'tv series' changed to 'movie'
# row: 577 col: 3 : 'tv series' changed to 'movie'
# row: 40 col: 3 : 'tv series' changed to 'tv series'
# row: 1398 col: 3 : 'movie' changed to 'tv series'
# row: 581 col: 3 : 'movie' changed to 'tv series'
# row: 506 col: 3 : 'movie' changed to 'tv series'
# row: 586 col: 3 : 'movie' changed to 'tv series'
# row: 543 col: 3 : 'movie' changed to 'tv series'
# row: 148 col: 3 : 'tv series' changed to 'movie'
# row: 1383 col: 3 : 'movie' changed to 'tv series'
# row: 948 col: 3 : 'movie' changed to 'movie'
# row: 1104 col: 3 : 'tv series' changed to 'movie'
# row: 917 col: 3 : 'movie' changed to 'tv series'
# row: 1255 col: 3 : 'tv series' changed to 'movie'
# row: 964 col: 3 : 'tv series' changed to 'movie'
# row: 1356 col: 3 : 'tv series' changed to 'movie'
# row: 1307 col: 3 : 'movie' changed to 'tv series'
# row: 1069 col: 3 : 'movie' changed to 'tv series'
# row: 298 col: 3 : 'tv series' changed to 'movie'
# row: 804 col: 3 : 'tv series' changed to 'movie'
# row: 684 col: 3 : 'movie' changed to 'movie'
# row: 1188 col: 3 : 'tv series' changed to 'tv series'
# row: 1459 col: 3 : 'tv series' changed to 'tv series'
# row: 442 col: 3 : 'movie' changed to 'movie'
# row: 64 col: 3 : 'movie' changed to 'tv series'
# row: 42 col: 3 : 'movie' changed to 'tv series'
# row: 1500 col: 3 : 'tv series' changed to 'tv series'
# row: 228 col: 3 : 'tv series' changed to 'tv series'
# row: 1087 col: 3 : 'movie' changed to 'movie'
# row: 1047 col: 3 : 'tv series' changed to 'tv series'
# row: 1223 col: 3 : 'tv series' changed to 'movie'
# row: 789 col: 3 : 'tv series' changed to 'movie'
# row: 1534 col: 3 : 'movie' changed to 'movie'
# row: 728 col: 3 : 'tv series' changed to 'movie'
# row: 437 col: 3 : 'movie' changed to 'tv series'
# row: 487 col: 3 : 'movie' changed to 'tv series'
# row: 60 col: 3 : 'movie' changed to 'tv series'
# row: 764 col: 3 : 'tv series' changed to 'tv series'
# row: 312 col: 3 : 'tv series' changed to 'tv series'
# row: 105 col: 3 : 'movie' changed to 'movie'
# row: 1497 col: 3 : 'movie' changed to 'tv series'
# row: 416 col: 3 : 'tv series' changed to 'tv series'
# row: 453 col: 3 : 'tv series' changed to 'tv series'
# row: 1052 col: 3 : 'tv series' changed to 'tv series'
# row: 1020 col: 3 : 'tv series' changed to 'movie'
# row: 1594 col: 3 : 'movie' changed to 'movie'
# row: 815 col: 3 : 'tv series' changed to 'tv series'
# row: 1404 col: 3 : 'movie' changed to 'movie'
# row: 849 col: 3 : 'tv series' changed to 'tv series'
# row: 1537 col: 3 : 'tv series' changed to 'tv series'
# row: 1561 col: 3 : 'tv series' changed to 'tv series'
# row: 1170 col: 3 : 'tv series' changed to 'tv series'
# row: 279 col: 3 : 'tv series' changed to 'movie'
# row: 503 col: 3 : 'movie' changed to 'movie'
# row: 1421 col: 3 : 'movie' changed to 'movie'
# row: 653 col: 3 : 'movie' changed to 'tv series'
# row: 58 col: 3 : 'tv series' changed to 'movie'
# row: 1108 col: 3 : 'movie' changed to 'movie'
# row: 1280 col: 3 : 'tv series' changed to 'tv series'
# row: 1382 col: 3 : 'tv series' changed to 'movie'
# row: 1084 col: 3 : 'tv series' changed to 'movie'
# row: 428 col: 3 : 'tv series' changed to 'tv series'
# row: 677 col: 3 : 'tv series' changed to 'movie'
# row: 1481 col: 3 : 'movie' changed to 'tv series'
# row: 1317 col: 3 : 'tv series' changed to 'movie'
# row: 1303 col: 3 : 'tv series' changed to 'movie'
# row: 467 col: 3 : 'tv series' changed to 'movie'
# row: 51 col: 3 : 'movie' changed to 'tv series'
# row: 9 col: 3 : 'movie' changed to 'tv series'
# row: 69 col: 3 : 'tv series' changed to 'movie'
# row: 1071 col: 3 : 'tv series' changed to 'tv series'
# row: 36 col: 3 : 'movie' changed to 'movie'
# row: 241 col: 3 : 'tv series' changed to 'tv series'

# %% [markdown]
# ## Transformation

# %%
import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
     # Reset index to enable concat
    train_data_set.reset_index(inplace=True)
    dfOneHot_train.reset_index(inplace=True)
    train_dummies.reset_index(inplace=True)
    
    test_data_set.reset_index(inplace=True)
    dfOneHot_test.reset_index(inplace=True)
    test_dummies.reset_index(inplace=True)
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

'''
anime_train = feature_transformation(anime_train)
anime_test = feature_transformation(anime_test)
'''
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

# %%
#anime_train = anime_train.dropna()
print(anime_train.shape)
print(anime_test.shape)
# Out:
# (1542, 7212)
# (389, 7212)

# %%
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1542, 7211)
# (389, 7211)
# (1542, 700)
# (389, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)

    # The mean absolute error
    print("Mean absolute error: %.2f" % np.sqrt(mean_absolute_error(anime_y_test, anime_y_pred)))

    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(anime_y_test, anime_y_pred))

# %% [markdown]
# ### Linear Regression

# %%
clf = training(model = linear_model.LinearRegression(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 2880538.37
# Mean squared error: 75195465219893.78
# Variance score: -6198913740194380226305720320.00

# %% [markdown]
# ### Lesso Regression

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 0.87
# Mean squared error: 0.96
# Variance score: -0.00

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(anime_X_train, anime_y_train);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(anime_X_test)
# Calculate the absolute errors
errors = abs(predictions - anime_y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / anime_y_test)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 0.58 degrees.
# Accuracy: 90.33 %.

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.932 1.083 1.052 1.038 0.988]
# Mean: 1.018530526694531
# Standard deviation: 0.05312560861594834

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.1}
# The mean squared Error is: 0.90

# %% [markdown]
# ### Retraining

# %%
clf = training(model = linear_model.Lasso(alpha=0.1), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean absolute error: 0.82
# Mean squared error: 0.87
# Variance score: 0.18
