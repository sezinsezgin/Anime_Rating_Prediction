# %% [markdown]
# ## Import Data

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from error_generator import Random_Active_Domain
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# ## Train-test dataset

# %%
anime_train = pd.read_csv("data/trainDataset.csv")
anime_test = pd.read_csv("data/testDataset.csv")

# %% [markdown]
# ## Generating Errors

# %%
def error_generater(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generater(anime_train.values.tolist(), Random_Active_Domain(),75, ignored_columns = [0,1,2,4,5,6,7])
Read_Write.write_csv_dataset("data/{}.csv".format(Random_Active_Domain().name), new_dataset)
anime_train = pd.read_csv("data/{}.csv".format(Random_Active_Domain().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("data/dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to random_active_domain method ---------------
#
# row: 1429 col: 3 : 'movie' changed to 'tv series'
# row: 165 col: 3 : 'movie' changed to 'movie'
# row: 138 col: 3 : 'tv series' changed to 'tv series'
# row: 92 col: 3 : 'tv series' changed to 'movie'
# row: 687 col: 3 : 'tv series' changed to 'tv series'
# row: 903 col: 3 : 'movie' changed to 'movie'
# row: 492 col: 3 : 'tv series' changed to 'tv series'
# row: 875 col: 3 : 'movie' changed to 'movie'
# row: 1416 col: 3 : 'tv series' changed to 'tv series'
# row: 1437 col: 3 : 'tv series' changed to 'tv series'
# row: 614 col: 3 : 'tv series' changed to 'movie'
# row: 1013 col: 3 : 'movie' changed to 'tv series'
# row: 818 col: 3 : 'movie' changed to 'tv series'
# row: 1454 col: 3 : 'movie' changed to 'tv series'
# row: 1151 col: 3 : 'tv series' changed to 'movie'
# row: 452 col: 3 : 'tv series' changed to 'movie'
# row: 1066 col: 3 : 'movie' changed to 'movie'
# row: 342 col: 3 : 'tv series' changed to 'movie'
# row: 1081 col: 3 : 'tv series' changed to 'movie'
# row: 767 col: 3 : 'tv series' changed to 'movie'
# row: 976 col: 3 : 'movie' changed to 'movie'
# row: 1552 col: 3 : 'movie' changed to 'tv series'
# row: 1441 col: 3 : 'tv series' changed to 'tv series'
# row: 1599 col: 3 : 'tv series' changed to 'tv series'
# row: 473 col: 3 : 'tv series' changed to 'movie'
# row: 80 col: 3 : 'tv series' changed to 'tv series'
# row: 213 col: 3 : 'tv series' changed to 'movie'
# row: 1273 col: 3 : 'tv series' changed to 'movie'
# row: 1388 col: 3 : 'tv series' changed to 'movie'
# row: 1431 col: 3 : 'movie' changed to 'tv series'
# row: 271 col: 3 : 'movie' changed to 'tv series'
# row: 61 col: 3 : 'movie' changed to 'movie'
# row: 681 col: 3 : 'tv series' changed to 'tv series'
# row: 1091 col: 3 : 'movie' changed to 'tv series'
# row: 1310 col: 3 : 'tv series' changed to 'movie'
# row: 1511 col: 3 : 'tv series' changed to 'movie'
# row: 643 col: 3 : 'tv series' changed to 'movie'
# row: 1023 col: 3 : 'tv series' changed to 'tv series'
# row: 1231 col: 3 : 'tv series' changed to 'tv series'
# row: 1241 col: 3 : 'tv series' changed to 'tv series'
# row: 496 col: 3 : 'tv series' changed to 'tv series'
# row: 127 col: 3 : 'movie' changed to 'tv series'
# row: 1347 col: 3 : 'movie' changed to 'movie'
# row: 1119 col: 3 : 'movie' changed to 'tv series'
# row: 1440 col: 3 : 'movie' changed to 'movie'
# row: 789 col: 3 : 'movie' changed to 'movie'
# row: 1473 col: 3 : 'tv series' changed to 'tv series'
# row: 136 col: 3 : 'tv series' changed to 'tv series'
# row: 1234 col: 3 : 'movie' changed to 'movie'
# row: 365 col: 3 : 'tv series' changed to 'movie'
# row: 1489 col: 3 : 'tv series' changed to 'movie'
# row: 468 col: 3 : 'tv series' changed to 'movie'
# row: 794 col: 3 : 'tv series' changed to 'movie'
# row: 1532 col: 3 : 'movie' changed to 'tv series'
# row: 1392 col: 3 : 'movie' changed to 'tv series'
# row: 707 col: 3 : 'movie' changed to 'movie'
# row: 744 col: 3 : 'tv series' changed to 'movie'
# row: 434 col: 3 : 'movie' changed to 'movie'
# row: 498 col: 3 : 'movie' changed to 'tv series'
# row: 640 col: 3 : 'movie' changed to 'movie'
# row: 870 col: 3 : 'tv series' changed to 'tv series'
# row: 688 col: 3 : 'tv series' changed to 'movie'
# row: 70 col: 3 : 'tv series' changed to 'tv series'
# row: 785 col: 3 : 'movie' changed to 'movie'
# row: 1098 col: 3 : 'movie' changed to 'movie'
# row: 290 col: 3 : 'tv series' changed to 'tv series'
# row: 615 col: 3 : 'movie' changed to 'movie'
# row: 1573 col: 3 : 'tv series' changed to 'movie'
# row: 475 col: 3 : 'tv series' changed to 'tv series'
# row: 96 col: 3 : 'movie' changed to 'tv series'
# row: 756 col: 3 : 'tv series' changed to 'movie'
# row: 133 col: 3 : 'tv series' changed to 'movie'
# row: 1265 col: 3 : 'tv series' changed to 'tv series'
# row: 764 col: 3 : 'tv series' changed to 'tv series'
# row: 276 col: 3 : 'movie' changed to 'tv series'
# row: 1225 col: 3 : 'tv series' changed to 'tv series'
# row: 831 col: 3 : 'tv series' changed to 'tv series'
# row: 885 col: 3 : 'movie' changed to 'movie'
# row: 1514 col: 3 : 'tv series' changed to 'tv series'
# row: 1228 col: 3 : 'movie' changed to 'movie'
# row: 1262 col: 3 : 'tv series' changed to 'tv series'
# row: 830 col: 3 : 'movie' changed to 'tv series'
# row: 545 col: 3 : 'tv series' changed to 'movie'
# row: 1367 col: 3 : 'movie' changed to 'movie'
# row: 862 col: 3 : 'tv series' changed to 'tv series'
# row: 335 col: 3 : 'movie' changed to 'movie'
# row: 716 col: 3 : 'movie' changed to 'movie'
# row: 324 col: 3 : 'movie' changed to 'movie'
# row: 1223 col: 3 : 'tv series' changed to 'tv series'
# row: 536 col: 3 : 'movie' changed to 'tv series'
# row: 863 col: 3 : 'movie' changed to 'tv series'
# row: 1475 col: 3 : 'movie' changed to 'tv series'
# row: 1318 col: 3 : 'tv series' changed to 'movie'
# row: 1432 col: 3 : 'movie' changed to 'tv series'
# row: 168 col: 3 : 'tv series' changed to 'tv series'
# row: 1263 col: 3 : 'movie' changed to 'movie'
# row: 678 col: 3 : 'movie' changed to 'movie'
# row: 1212 col: 3 : 'movie' changed to 'tv series'
# row: 1588 col: 3 : 'movie' changed to 'movie'
# row: 1312 col: 3 : 'movie' changed to 'movie'
# row: 928 col: 3 : 'tv series' changed to 'movie'
# row: 306 col: 3 : 'movie' changed to 'tv series'
# row: 895 col: 3 : 'movie' changed to 'tv series'
# row: 1508 col: 3 : 'movie' changed to 'tv series'
# row: 52 col: 3 : 'movie' changed to 'movie'
# row: 723 col: 3 : 'movie' changed to 'movie'
# row: 693 col: 3 : 'tv series' changed to 'movie'
# row: 994 col: 3 : 'movie' changed to 'movie'
# row: 1017 col: 3 : 'movie' changed to 'movie'
# row: 157 col: 3 : 'tv series' changed to 'movie'
# row: 409 col: 3 : 'tv series' changed to 'movie'
# row: 841 col: 3 : 'tv series' changed to 'movie'
# row: 595 col: 3 : 'tv series' changed to 'tv series'
# row: 947 col: 3 : 'tv series' changed to 'movie'
# row: 1339 col: 3 : 'tv series' changed to 'movie'
# row: 130 col: 3 : 'tv series' changed to 'movie'
# row: 302 col: 3 : 'movie' changed to 'tv series'
# row: 2 col: 3 : 'movie' changed to 'movie'
# row: 1221 col: 3 : 'movie' changed to 'tv series'
# row: 1574 col: 3 : 'tv series' changed to 'tv series'
# row: 161 col: 3 : 'movie' changed to 'movie'
# row: 1439 col: 3 : 'movie' changed to 'movie'
# row: 181 col: 3 : 'tv series' changed to 'movie'
# row: 49 col: 3 : 'tv series' changed to 'tv series'
# row: 1513 col: 3 : 'tv series' changed to 'tv series'
# row: 262 col: 3 : 'tv series' changed to 'tv series'
# row: 586 col: 3 : 'movie' changed to 'tv series'
# row: 1123 col: 3 : 'movie' changed to 'movie'
# row: 1143 col: 3 : 'tv series' changed to 'movie'
# row: 437 col: 3 : 'movie' changed to 'tv series'
# row: 1275 col: 3 : 'movie' changed to 'tv series'
# row: 774 col: 3 : 'tv series' changed to 'tv series'
# row: 128 col: 3 : 'tv series' changed to 'tv series'
# row: 839 col: 3 : 'movie' changed to 'movie'
# row: 1328 col: 3 : 'movie' changed to 'movie'
# row: 231 col: 3 : 'tv series' changed to 'tv series'
# row: 997 col: 3 : 'movie' changed to 'tv series'
# row: 12 col: 3 : 'movie' changed to 'movie'
# row: 1183 col: 3 : 'tv series' changed to 'movie'
# row: 527 col: 3 : 'movie' changed to 'movie'
# row: 1422 col: 3 : 'tv series' changed to 'tv series'
# row: 29 col: 3 : 'tv series' changed to 'tv series'
# row: 1243 col: 3 : 'tv series' changed to 'tv series'
# row: 7 col: 3 : 'movie' changed to 'tv series'
# row: 193 col: 3 : 'tv series' changed to 'movie'
# row: 674 col: 3 : 'movie' changed to 'movie'
# row: 244 col: 3 : 'movie' changed to 'tv series'
# row: 378 col: 3 : 'movie' changed to 'movie'
# row: 721 col: 3 : 'movie' changed to 'tv series'
# row: 701 col: 3 : 'movie' changed to 'tv series'
# row: 44 col: 3 : 'movie' changed to 'movie'
# row: 1385 col: 3 : 'movie' changed to 'movie'
# row: 246 col: 3 : 'movie' changed to 'movie'
# row: 456 col: 3 : 'movie' changed to 'tv series'
# row: 1120 col: 3 : 'movie' changed to 'tv series'
# row: 1227 col: 3 : 'movie' changed to 'tv series'
# row: 131 col: 3 : 'movie' changed to 'tv series'
# row: 1492 col: 3 : 'tv series' changed to 'movie'
# row: 1325 col: 3 : 'tv series' changed to 'tv series'
# row: 1259 col: 3 : 'movie' changed to 'movie'
# row: 1079 col: 3 : 'tv series' changed to 'movie'
# row: 254 col: 3 : 'tv series' changed to 'movie'
# row: 879 col: 3 : 'tv series' changed to 'movie'
# row: 1280 col: 3 : 'tv series' changed to 'tv series'
# row: 985 col: 3 : 'movie' changed to 'movie'
# row: 150 col: 3 : 'movie' changed to 'tv series'
# row: 953 col: 3 : 'movie' changed to 'movie'
# row: 1519 col: 3 : 'tv series' changed to 'movie'
# row: 391 col: 3 : 'tv series' changed to 'tv series'
# row: 322 col: 3 : 'tv series' changed to 'tv series'
# row: 1525 col: 3 : 'tv series' changed to 'tv series'
# row: 43 col: 3 : 'movie' changed to 'movie'
# row: 929 col: 3 : 'movie' changed to 'tv series'
# row: 422 col: 3 : 'movie' changed to 'movie'
# row: 1099 col: 3 : 'tv series' changed to 'movie'
# row: 104 col: 3 : 'movie' changed to 'movie'
# row: 406 col: 3 : 'movie' changed to 'tv series'
# row: 385 col: 3 : 'tv series' changed to 'movie'
# row: 1293 col: 3 : 'movie' changed to 'tv series'
# row: 277 col: 3 : 'tv series' changed to 'tv series'
# row: 1164 col: 3 : 'tv series' changed to 'movie'
# row: 57 col: 3 : 'tv series' changed to 'movie'
# row: 1343 col: 3 : 'movie' changed to 'tv series'
# row: 125 col: 3 : 'tv series' changed to 'tv series'
# row: 380 col: 3 : 'tv series' changed to 'tv series'
# row: 346 col: 3 : 'tv series' changed to 'movie'
# row: 1236 col: 3 : 'movie' changed to 'tv series'
# row: 1443 col: 3 : 'movie' changed to 'movie'
# row: 778 col: 3 : 'tv series' changed to 'movie'
# row: 591 col: 3 : 'tv series' changed to 'tv series'
# row: 722 col: 3 : 'movie' changed to 'tv series'
# row: 229 col: 3 : 'movie' changed to 'tv series'
# row: 524 col: 3 : 'tv series' changed to 'tv series'
# row: 653 col: 3 : 'tv series' changed to 'movie'
# row: 692 col: 3 : 'movie' changed to 'movie'
# row: 1425 col: 3 : 'tv series' changed to 'movie'
# row: 1051 col: 3 : 'tv series' changed to 'tv series'
# row: 1481 col: 3 : 'tv series' changed to 'tv series'
# row: 1076 col: 3 : 'tv series' changed to 'tv series'
# row: 54 col: 3 : 'movie' changed to 'tv series'
# row: 1404 col: 3 : 'tv series' changed to 'movie'
# row: 1199 col: 3 : 'tv series' changed to 'tv series'
# row: 934 col: 3 : 'movie' changed to 'movie'
# row: 1524 col: 3 : 'movie' changed to 'movie'
# row: 194 col: 3 : 'movie' changed to 'movie'
# row: 461 col: 3 : 'tv series' changed to 'movie'
# row: 40 col: 3 : 'tv series' changed to 'tv series'
# row: 730 col: 3 : 'tv series' changed to 'tv series'
# row: 201 col: 3 : 'movie' changed to 'movie'
# row: 1239 col: 3 : 'tv series' changed to 'tv series'
# row: 981 col: 3 : 'tv series' changed to 'tv series'
# row: 1242 col: 3 : 'movie' changed to 'tv series'
# row: 970 col: 3 : 'tv series' changed to 'tv series'
# row: 821 col: 3 : 'movie' changed to 'movie'
# row: 717 col: 3 : 'tv series' changed to 'movie'
# row: 1122 col: 3 : 'tv series' changed to 'movie'
# row: 746 col: 3 : 'tv series' changed to 'tv series'
# row: 60 col: 3 : 'tv series' changed to 'tv series'
# row: 48 col: 3 : 'tv series' changed to 'movie'
# row: 804 col: 3 : 'tv series' changed to 'movie'
# row: 834 col: 3 : 'movie' changed to 'movie'
# row: 248 col: 3 : 'tv series' changed to 'movie'
# row: 1014 col: 3 : 'tv series' changed to 'movie'
# row: 1397 col: 3 : 'movie' changed to 'movie'
# row: 1520 col: 3 : 'tv series' changed to 'movie'
# row: 1278 col: 3 : 'tv series' changed to 'movie'
# row: 1074 col: 3 : 'movie' changed to 'tv series'
# row: 1591 col: 3 : 'tv series' changed to 'tv series'
# row: 1316 col: 3 : 'tv series' changed to 'tv series'
# row: 580 col: 3 : 'tv series' changed to 'tv series'
# row: 1341 col: 3 : 'movie' changed to 'movie'
# row: 1563 col: 3 : 'movie' changed to 'movie'
# row: 1324 col: 3 : 'movie' changed to 'movie'
# row: 890 col: 3 : 'movie' changed to 'movie'
# row: 1369 col: 3 : 'tv series' changed to 'movie'
# row: 123 col: 3 : 'tv series' changed to 'tv series'
# row: 949 col: 3 : 'tv series' changed to 'tv series'
# row: 1296 col: 3 : 'movie' changed to 'movie'
# row: 1194 col: 3 : 'movie' changed to 'tv series'
# row: 122 col: 3 : 'tv series' changed to 'movie'
# row: 850 col: 3 : 'tv series' changed to 'tv series'
# row: 1052 col: 3 : 'movie' changed to 'tv series'
# row: 771 col: 3 : 'tv series' changed to 'movie'
# row: 781 col: 3 : 'movie' changed to 'tv series'
# row: 72 col: 3 : 'tv series' changed to 'tv series'
# row: 702 col: 3 : 'movie' changed to 'movie'
# row: 1116 col: 3 : 'tv series' changed to 'tv series'
# row: 1213 col: 3 : 'movie' changed to 'movie'
# row: 632 col: 3 : 'movie' changed to 'tv series'
# row: 648 col: 3 : 'tv series' changed to 'tv series'
# row: 682 col: 3 : 'movie' changed to 'movie'
# row: 354 col: 3 : 'tv series' changed to 'movie'
# row: 9 col: 3 : 'tv series' changed to 'movie'
# row: 223 col: 3 : 'tv series' changed to 'movie'
# row: 1471 col: 3 : 'movie' changed to 'movie'
# row: 1302 col: 3 : 'movie' changed to 'movie'
# row: 655 col: 3 : 'tv series' changed to 'tv series'
# row: 1580 col: 3 : 'movie' changed to 'tv series'
# row: 348 col: 3 : 'movie' changed to 'tv series'
# row: 1350 col: 3 : 'tv series' changed to 'movie'
# row: 183 col: 3 : 'tv series' changed to 'tv series'
# row: 1005 col: 3 : 'tv series' changed to 'tv series'
# row: 956 col: 3 : 'tv series' changed to 'movie'
# row: 1408 col: 3 : 'movie' changed to 'tv series'
# row: 946 col: 3 : 'tv series' changed to 'movie'
# row: 152 col: 3 : 'tv series' changed to 'movie'
# row: 1587 col: 3 : 'movie' changed to 'movie'
# row: 777 col: 3 : 'tv series' changed to 'tv series'
# row: 562 col: 3 : 'tv series' changed to 'tv series'
# row: 1272 col: 3 : 'movie' changed to 'movie'
# row: 1186 col: 3 : 'tv series' changed to 'tv series'
# row: 1373 col: 3 : 'movie' changed to 'movie'
# row: 1374 col: 3 : 'movie' changed to 'movie'
# row: 979 col: 3 : 'tv series' changed to 'tv series'
# row: 1026 col: 3 : 'tv series' changed to 'tv series'
# row: 1442 col: 3 : 'movie' changed to 'tv series'
# row: 1192 col: 3 : 'tv series' changed to 'movie'
# row: 1384 col: 3 : 'movie' changed to 'movie'
# row: 1247 col: 3 : 'movie' changed to 'tv series'
# row: 178 col: 3 : 'movie' changed to 'tv series'
# row: 23 col: 3 : 'tv series' changed to 'tv series'
# row: 353 col: 3 : 'tv series' changed to 'movie'
# row: 1434 col: 3 : 'movie' changed to 'tv series'
# row: 63 col: 3 : 'movie' changed to 'movie'
# row: 113 col: 3 : 'movie' changed to 'movie'
# row: 748 col: 3 : 'movie' changed to 'movie'
# row: 1291 col: 3 : 'movie' changed to 'movie'
# row: 743 col: 3 : 'movie' changed to 'tv series'
# row: 89 col: 3 : 'tv series' changed to 'movie'
# row: 1371 col: 3 : 'tv series' changed to 'movie'
# row: 329 col: 3 : 'tv series' changed to 'movie'
# row: 933 col: 3 : 'movie' changed to 'tv series'
# row: 431 col: 3 : 'tv series' changed to 'movie'
# row: 507 col: 3 : 'movie' changed to 'movie'
# row: 1274 col: 3 : 'movie' changed to 'movie'
# row: 1567 col: 3 : 'movie' changed to 'movie'
# row: 489 col: 3 : 'movie' changed to 'tv series'
# row: 671 col: 3 : 'tv series' changed to 'movie'
# row: 315 col: 3 : 'tv series' changed to 'tv series'
# row: 565 col: 3 : 'tv series' changed to 'movie'
# row: 800 col: 3 : 'movie' changed to 'movie'
# row: 1154 col: 3 : 'movie' changed to 'tv series'
# row: 1479 col: 3 : 'movie' changed to 'movie'
# row: 1421 col: 3 : 'tv series' changed to 'tv series'
# row: 218 col: 3 : 'movie' changed to 'tv series'
# row: 857 col: 3 : 'movie' changed to 'tv series'
# row: 465 col: 3 : 'tv series' changed to 'tv series'
# row: 782 col: 3 : 'movie' changed to 'movie'
# row: 1197 col: 3 : 'tv series' changed to 'tv series'
# row: 1500 col: 3 : 'movie' changed to 'tv series'
# row: 69 col: 3 : 'movie' changed to 'movie'
# row: 62 col: 3 : 'tv series' changed to 'movie'
# row: 1268 col: 3 : 'tv series' changed to 'tv series'
# row: 509 col: 3 : 'movie' changed to 'movie'
# row: 505 col: 3 : 'movie' changed to 'movie'
# row: 238 col: 3 : 'tv series' changed to 'tv series'
# row: 142 col: 3 : 'movie' changed to 'movie'
# row: 314 col: 3 : 'tv series' changed to 'tv series'
# row: 571 col: 3 : 'tv series' changed to 'tv series'
# row: 1082 col: 3 : 'tv series' changed to 'movie'
# row: 22 col: 3 : 'tv series' changed to 'tv series'
# row: 1556 col: 3 : 'movie' changed to 'tv series'
# row: 986 col: 3 : 'tv series' changed to 'tv series'
# row: 813 col: 3 : 'movie' changed to 'tv series'
# row: 234 col: 3 : 'movie' changed to 'movie'
# row: 840 col: 3 : 'movie' changed to 'movie'
# row: 1167 col: 3 : 'movie' changed to 'movie'
# row: 411 col: 3 : 'tv series' changed to 'movie'
# row: 31 col: 3 : 'tv series' changed to 'movie'
# row: 1585 col: 3 : 'tv series' changed to 'tv series'
# row: 916 col: 3 : 'movie' changed to 'movie'
# row: 1254 col: 3 : 'tv series' changed to 'movie'
# row: 126 col: 3 : 'tv series' changed to 'tv series'
# row: 1333 col: 3 : 'tv series' changed to 'tv series'
# row: 403 col: 3 : 'tv series' changed to 'movie'
# row: 1527 col: 3 : 'movie' changed to 'tv series'
# row: 807 col: 3 : 'tv series' changed to 'movie'
# row: 657 col: 3 : 'movie' changed to 'tv series'
# row: 1530 col: 3 : 'movie' changed to 'movie'
# row: 1046 col: 3 : 'tv series' changed to 'movie'
# row: 914 col: 3 : 'tv series' changed to 'movie'
# row: 968 col: 3 : 'tv series' changed to 'movie'
# row: 619 col: 3 : 'tv series' changed to 'movie'
# row: 636 col: 3 : 'tv series' changed to 'tv series'
# row: 751 col: 3 : 'movie' changed to 'movie'
# row: 1528 col: 3 : 'tv series' changed to 'tv series'
# row: 1147 col: 3 : 'movie' changed to 'movie'
# row: 583 col: 3 : 'movie' changed to 'tv series'
# row: 1387 col: 3 : 'movie' changed to 'tv series'
# row: 388 col: 3 : 'movie' changed to 'movie'
# row: 835 col: 3 : 'tv series' changed to 'movie'
# row: 686 col: 3 : 'tv series' changed to 'tv series'
# row: 357 col: 3 : 'movie' changed to 'tv series'
# row: 1559 col: 3 : 'movie' changed to 'movie'
# row: 145 col: 3 : 'tv series' changed to 'tv series'
# row: 1001 col: 3 : 'tv series' changed to 'movie'
# row: 1021 col: 3 : 'tv series' changed to 'tv series'
# row: 845 col: 3 : 'movie' changed to 'tv series'
# row: 514 col: 3 : 'movie' changed to 'movie'
# row: 1379 col: 3 : 'movie' changed to 'tv series'
# row: 1401 col: 3 : 'tv series' changed to 'movie'
# row: 432 col: 3 : 'movie' changed to 'tv series'
# row: 1546 col: 3 : 'movie' changed to 'movie'
# row: 1334 col: 3 : 'tv series' changed to 'movie'
# row: 623 col: 3 : 'tv series' changed to 'movie'
# row: 750 col: 3 : 'movie' changed to 'movie'
# row: 318 col: 3 : 'movie' changed to 'tv series'
# row: 1448 col: 3 : 'tv series' changed to 'movie'
# row: 371 col: 3 : 'tv series' changed to 'movie'
# row: 1053 col: 3 : 'tv series' changed to 'movie'
# row: 944 col: 3 : 'tv series' changed to 'movie'
# row: 919 col: 3 : 'tv series' changed to 'tv series'
# row: 1457 col: 3 : 'movie' changed to 'movie'
# row: 50 col: 3 : 'tv series' changed to 'tv series'
# row: 27 col: 3 : 'tv series' changed to 'tv series'
# row: 1592 col: 3 : 'movie' changed to 'tv series'
# row: 1311 col: 3 : 'movie' changed to 'movie'
# row: 195 col: 3 : 'tv series' changed to 'movie'
# row: 685 col: 3 : 'tv series' changed to 'movie'
# row: 154 col: 3 : 'tv series' changed to 'tv series'
# row: 878 col: 3 : 'tv series' changed to 'tv series'
# row: 1077 col: 3 : 'tv series' changed to 'movie'
# row: 1019 col: 3 : 'tv series' changed to 'movie'
# row: 1549 col: 3 : 'movie' changed to 'movie'
# row: 235 col: 3 : 'movie' changed to 'tv series'
# row: 1412 col: 3 : 'movie' changed to 'movie'
# row: 449 col: 3 : 'tv series' changed to 'tv series'
# row: 1396 col: 3 : 'tv series' changed to 'movie'
# row: 809 col: 3 : 'tv series' changed to 'movie'
# row: 192 col: 3 : 'movie' changed to 'movie'
# row: 278 col: 3 : 'movie' changed to 'movie'
# row: 612 col: 3 : 'tv series' changed to 'movie'
# row: 26 col: 3 : 'movie' changed to 'movie'
# row: 993 col: 3 : 'tv series' changed to 'movie'
# row: 1497 col: 3 : 'movie' changed to 'tv series'
# row: 541 col: 3 : 'movie' changed to 'movie'
# row: 1049 col: 3 : 'tv series' changed to 'tv series'
# row: 725 col: 3 : 'tv series' changed to 'tv series'
# row: 1594 col: 3 : 'movie' changed to 'movie'
# row: 568 col: 3 : 'tv series' changed to 'movie'
# row: 1395 col: 3 : 'movie' changed to 'movie'
# row: 82 col: 3 : 'tv series' changed to 'tv series'
# row: 1427 col: 3 : 'movie' changed to 'tv series'
# row: 487 col: 3 : 'tv series' changed to 'movie'
# row: 1007 col: 3 : 'movie' changed to 'tv series'
# row: 517 col: 3 : 'movie' changed to 'tv series'
# row: 1389 col: 3 : 'tv series' changed to 'tv series'
# row: 656 col: 3 : 'tv series' changed to 'movie'
# row: 332 col: 3 : 'tv series' changed to 'movie'
# row: 410 col: 3 : 'movie' changed to 'movie'
# row: 167 col: 3 : 'movie' changed to 'tv series'
# row: 366 col: 3 : 'movie' changed to 'movie'
# row: 1299 col: 3 : 'tv series' changed to 'tv series'
# row: 557 col: 3 : 'tv series' changed to 'tv series'
# row: 454 col: 3 : 'movie' changed to 'tv series'
# row: 676 col: 3 : 'movie' changed to 'tv series'
# row: 1038 col: 3 : 'movie' changed to 'tv series'
# row: 820 col: 3 : 'movie' changed to 'tv series'
# row: 341 col: 3 : 'tv series' changed to 'movie'
# row: 1327 col: 3 : 'tv series' changed to 'tv series'
# row: 1073 col: 3 : 'movie' changed to 'tv series'
# row: 198 col: 3 : 'tv series' changed to 'movie'
# row: 221 col: 3 : 'tv series' changed to 'movie'
# row: 347 col: 3 : 'tv series' changed to 'tv series'
# row: 1163 col: 3 : 'tv series' changed to 'tv series'
# row: 1535 col: 3 : 'tv series' changed to 'movie'
# row: 1301 col: 3 : 'movie' changed to 'tv series'
# row: 696 col: 3 : 'tv series' changed to 'movie'
# row: 500 col: 3 : 'tv series' changed to 'movie'
# row: 765 col: 3 : 'tv series' changed to 'tv series'
# row: 675 col: 3 : 'tv series' changed to 'movie'
# row: 1547 col: 3 : 'tv series' changed to 'movie'
# row: 1224 col: 3 : 'movie' changed to 'movie'
# row: 1112 col: 3 : 'tv series' changed to 'movie'
# row: 1453 col: 3 : 'movie' changed to 'movie'
# row: 728 col: 3 : 'tv series' changed to 'movie'
# row: 882 col: 3 : 'tv series' changed to 'movie'
# row: 1153 col: 3 : 'movie' changed to 'movie'
# row: 1377 col: 3 : 'movie' changed to 'movie'
# row: 1159 col: 3 : 'movie' changed to 'movie'
# row: 1096 col: 3 : 'movie' changed to 'tv series'
# row: 414 col: 3 : 'movie' changed to 'tv series'
# row: 677 col: 3 : 'tv series' changed to 'movie'
# row: 100 col: 3 : 'tv series' changed to 'tv series'
# row: 255 col: 3 : 'tv series' changed to 'movie'
# row: 749 col: 3 : 'tv series' changed to 'movie'
# row: 1542 col: 3 : 'tv series' changed to 'movie'
# row: 330 col: 3 : 'tv series' changed to 'tv series'
# row: 1294 col: 3 : 'tv series' changed to 'tv series'
# row: 488 col: 3 : 'movie' changed to 'tv series'
# row: 1402 col: 3 : 'movie' changed to 'movie'
# row: 374 col: 3 : 'tv series' changed to 'movie'
# row: 512 col: 3 : 'tv series' changed to 'movie'
# row: 1253 col: 3 : 'movie' changed to 'tv series'
# row: 85 col: 3 : 'movie' changed to 'movie'
# row: 1080 col: 3 : 'tv series' changed to 'tv series'
# row: 1307 col: 3 : 'tv series' changed to 'tv series'
# row: 339 col: 3 : 'movie' changed to 'tv series'
# row: 502 col: 3 : 'tv series' changed to 'movie'
# row: 969 col: 3 : 'movie' changed to 'movie'
# row: 936 col: 3 : 'movie' changed to 'movie'
# row: 1355 col: 3 : 'movie' changed to 'tv series'
# row: 1411 col: 3 : 'tv series' changed to 'movie'
# row: 561 col: 3 : 'movie' changed to 'movie'
# row: 301 col: 3 : 'movie' changed to 'tv series'
# row: 886 col: 3 : 'tv series' changed to 'movie'
# row: 1108 col: 3 : 'movie' changed to 'movie'
# row: 55 col: 3 : 'movie' changed to 'movie'
# row: 888 col: 3 : 'movie' changed to 'movie'
# row: 1045 col: 3 : 'tv series' changed to 'tv series'
# row: 336 col: 3 : 'movie' changed to 'tv series'
# row: 780 col: 3 : 'tv series' changed to 'tv series'
# row: 108 col: 3 : 'movie' changed to 'movie'
# row: 1438 col: 3 : 'tv series' changed to 'tv series'
# row: 36 col: 3 : 'movie' changed to 'movie'
# row: 428 col: 3 : 'movie' changed to 'tv series'
# row: 58 col: 3 : 'movie' changed to 'movie'
# row: 1562 col: 3 : 'tv series' changed to 'movie'
# row: 1258 col: 3 : 'movie' changed to 'tv series'
# row: 585 col: 3 : 'tv series' changed to 'tv series'
# row: 626 col: 3 : 'tv series' changed to 'movie'
# row: 419 col: 3 : 'movie' changed to 'tv series'
# row: 731 col: 3 : 'movie' changed to 'tv series'
# row: 269 col: 3 : 'movie' changed to 'movie'
# row: 752 col: 3 : 'movie' changed to 'movie'
# row: 871 col: 3 : 'tv series' changed to 'movie'
# row: 1135 col: 3 : 'tv series' changed to 'movie'
# row: 1581 col: 3 : 'movie' changed to 'tv series'
# row: 922 col: 3 : 'movie' changed to 'movie'
# row: 808 col: 3 : 'tv series' changed to 'tv series'
# row: 1364 col: 3 : 'movie' changed to 'tv series'
# row: 948 col: 3 : 'movie' changed to 'movie'
# row: 844 col: 3 : 'tv series' changed to 'movie'
# row: 1042 col: 3 : 'tv series' changed to 'tv series'
# row: 1361 col: 3 : 'movie' changed to 'tv series'
# row: 24 col: 3 : 'movie' changed to 'tv series'
# row: 1321 col: 3 : 'movie' changed to 'tv series'
# row: 566 col: 3 : 'movie' changed to 'movie'
# row: 1109 col: 3 : 'tv series' changed to 'tv series'
# row: 911 col: 3 : 'tv series' changed to 'movie'
# row: 773 col: 3 : 'movie' changed to 'tv series'
# row: 691 col: 3 : 'movie' changed to 'movie'
# row: 1103 col: 3 : 'tv series' changed to 'movie'
# row: 249 col: 3 : 'movie' changed to 'tv series'
# row: 1570 col: 3 : 'tv series' changed to 'tv series'
# row: 303 col: 3 : 'movie' changed to 'tv series'
# row: 299 col: 3 : 'tv series' changed to 'movie'
# row: 1127 col: 3 : 'movie' changed to 'tv series'
# row: 1210 col: 3 : 'movie' changed to 'movie'
# row: 628 col: 3 : 'movie' changed to 'movie'
# row: 1101 col: 3 : 'tv series' changed to 'movie'
# row: 1175 col: 3 : 'tv series' changed to 'tv series'
# row: 978 col: 3 : 'movie' changed to 'tv series'
# row: 407 col: 3 : 'tv series' changed to 'movie'
# row: 596 col: 3 : 'tv series' changed to 'movie'
# row: 904 col: 3 : 'movie' changed to 'movie'
# row: 426 col: 3 : 'tv series' changed to 'movie'
# row: 261 col: 3 : 'movie' changed to 'tv series'
# row: 1248 col: 3 : 'tv series' changed to 'movie'
# row: 1531 col: 3 : 'movie' changed to 'tv series'
# row: 1414 col: 3 : 'movie' changed to 'tv series'
# row: 1004 col: 3 : 'movie' changed to 'movie'
# row: 893 col: 3 : 'movie' changed to 'movie'
# row: 252 col: 3 : 'tv series' changed to 'movie'
# row: 4 col: 3 : 'movie' changed to 'movie'
# row: 604 col: 3 : 'tv series' changed to 'tv series'
# row: 68 col: 3 : 'movie' changed to 'movie'
# row: 51 col: 3 : 'movie' changed to 'movie'
# row: 832 col: 3 : 'tv series' changed to 'movie'
# row: 766 col: 3 : 'tv series' changed to 'movie'
# row: 494 col: 3 : 'tv series' changed to 'tv series'
# row: 1235 col: 3 : 'movie' changed to 'tv series'
# row: 1517 col: 3 : 'movie' changed to 'tv series'
# row: 121 col: 3 : 'movie' changed to 'movie'
# row: 156 col: 3 : 'movie' changed to 'tv series'
# row: 272 col: 3 : 'movie' changed to 'movie'
# row: 1504 col: 3 : 'movie' changed to 'tv series'
# row: 898 col: 3 : 'movie' changed to 'movie'
# row: 1474 col: 3 : 'tv series' changed to 'tv series'
# row: 158 col: 3 : 'movie' changed to 'movie'
# row: 317 col: 3 : 'tv series' changed to 'tv series'
# row: 683 col: 3 : 'tv series' changed to 'movie'
# row: 1465 col: 3 : 'movie' changed to 'tv series'
# row: 858 col: 3 : 'tv series' changed to 'tv series'
# row: 331 col: 3 : 'tv series' changed to 'tv series'
# row: 28 col: 3 : 'tv series' changed to 'movie'
# row: 119 col: 3 : 'movie' changed to 'movie'
# row: 662 col: 3 : 'movie' changed to 'tv series'
# row: 724 col: 3 : 'movie' changed to 'movie'
# row: 340 col: 3 : 'tv series' changed to 'movie'
# row: 1024 col: 3 : 'movie' changed to 'movie'
# row: 896 col: 3 : 'movie' changed to 'movie'
# row: 579 col: 3 : 'movie' changed to 'movie'
# row: 1141 col: 3 : 'tv series' changed to 'movie'
# row: 241 col: 3 : 'movie' changed to 'movie'
# row: 1232 col: 3 : 'movie' changed to 'movie'
# row: 738 col: 3 : 'tv series' changed to 'tv series'
# row: 190 col: 3 : 'movie' changed to 'movie'
# row: 639 col: 3 : 'tv series' changed to 'tv series'
# row: 1536 col: 3 : 'tv series' changed to 'tv series'
# row: 1597 col: 3 : 'movie' changed to 'tv series'
# row: 1168 col: 3 : 'movie' changed to 'tv series'
# row: 320 col: 3 : 'tv series' changed to 'tv series'
# row: 1410 col: 3 : 'tv series' changed to 'tv series'
# row: 1137 col: 3 : 'tv series' changed to 'tv series'
# row: 236 col: 3 : 'movie' changed to 'movie'
# row: 140 col: 3 : 'tv series' changed to 'tv series'
# row: 1100 col: 3 : 'movie' changed to 'movie'
# row: 359 col: 3 : 'movie' changed to 'movie'
# row: 143 col: 3 : 'movie' changed to 'movie'
# row: 1061 col: 3 : 'tv series' changed to 'movie'
# row: 884 col: 3 : 'movie' changed to 'tv series'
# row: 1445 col: 3 : 'movie' changed to 'tv series'
# row: 1202 col: 3 : 'movie' changed to 'tv series'
# row: 523 col: 3 : 'tv series' changed to 'tv series'
# row: 102 col: 3 : 'tv series' changed to 'tv series'
# row: 825 col: 3 : 'movie' changed to 'movie'
# row: 1288 col: 3 : 'tv series' changed to 'tv series'
# row: 333 col: 3 : 'tv series' changed to 'tv series'
# row: 602 col: 3 : 'movie' changed to 'movie'
# row: 417 col: 3 : 'tv series' changed to 'movie'
# row: 1068 col: 3 : 'tv series' changed to 'movie'
# row: 823 col: 3 : 'movie' changed to 'tv series'
# row: 1331 col: 3 : 'tv series' changed to 'movie'
# row: 260 col: 3 : 'tv series' changed to 'movie'
# row: 337 col: 3 : 'tv series' changed to 'movie'
# row: 1063 col: 3 : 'tv series' changed to 'movie'
# row: 1487 col: 3 : 'movie' changed to 'movie'
# row: 1503 col: 3 : 'tv series' changed to 'movie'
# row: 1176 col: 3 : 'movie' changed to 'tv series'
# row: 425 col: 3 : 'tv series' changed to 'tv series'
# row: 1419 col: 3 : 'movie' changed to 'movie'
# row: 462 col: 3 : 'movie' changed to 'movie'
# row: 1037 col: 3 : 'tv series' changed to 'tv series'
# row: 795 col: 3 : 'tv series' changed to 'movie'
# row: 572 col: 3 : 'tv series' changed to 'movie'
# row: 608 col: 3 : 'movie' changed to 'tv series'
# row: 710 col: 3 : 'tv series' changed to 'movie'
# row: 1195 col: 3 : 'tv series' changed to 'tv series'
# row: 1148 col: 3 : 'tv series' changed to 'movie'
# row: 554 col: 3 : 'tv series' changed to 'tv series'
# row: 16 col: 3 : 'movie' changed to 'movie'
# row: 1569 col: 3 : 'tv series' changed to 'movie'
# row: 564 col: 3 : 'movie' changed to 'movie'
# row: 1 col: 3 : 'movie' changed to 'tv series'
# row: 737 col: 3 : 'movie' changed to 'tv series'
# row: 1501 col: 3 : 'movie' changed to 'movie'
# row: 435 col: 3 : 'movie' changed to 'tv series'
# row: 836 col: 3 : 'movie' changed to 'movie'
# row: 446 col: 3 : 'tv series' changed to 'movie'
# row: 1357 col: 3 : 'tv series' changed to 'tv series'
# row: 1358 col: 3 : 'movie' changed to 'movie'
# row: 1554 col: 3 : 'movie' changed to 'tv series'
# row: 1340 col: 3 : 'tv series' changed to 'movie'
# row: 433 col: 3 : 'movie' changed to 'tv series'
# row: 295 col: 3 : 'movie' changed to 'movie'
# row: 225 col: 3 : 'movie' changed to 'tv series'
# row: 1152 col: 3 : 'tv series' changed to 'tv series'
# row: 328 col: 3 : 'tv series' changed to 'tv series'
# row: 1033 col: 3 : 'movie' changed to 'tv series'
# row: 1117 col: 3 : 'tv series' changed to 'movie'
# row: 983 col: 3 : 'tv series' changed to 'movie'
# row: 1028 col: 3 : 'tv series' changed to 'movie'
# row: 1246 col: 3 : 'tv series' changed to 'tv series'
# row: 416 col: 3 : 'movie' changed to 'movie'
# row: 786 col: 3 : 'tv series' changed to 'tv series'
# row: 1363 col: 3 : 'movie' changed to 'movie'
# row: 421 col: 3 : 'movie' changed to 'movie'
# row: 1002 col: 3 : 'movie' changed to 'movie'
# row: 3 col: 3 : 'movie' changed to 'movie'
# row: 609 col: 3 : 'tv series' changed to 'movie'
# row: 837 col: 3 : 'tv series' changed to 'tv series'
# row: 912 col: 3 : 'movie' changed to 'tv series'
# row: 613 col: 3 : 'movie' changed to 'movie'
# row: 1478 col: 3 : 'tv series' changed to 'movie'
# row: 1149 col: 3 : 'movie' changed to 'movie'
# row: 1238 col: 3 : 'movie' changed to 'tv series'
# row: 384 col: 3 : 'movie' changed to 'tv series'
# row: 296 col: 3 : 'movie' changed to 'movie'
# row: 316 col: 3 : 'tv series' changed to 'tv series'
# row: 1436 col: 3 : 'tv series' changed to 'movie'
# row: 1452 col: 3 : 'tv series' changed to 'tv series'
# row: 1257 col: 3 : 'movie' changed to 'tv series'
# row: 83 col: 3 : 'tv series' changed to 'movie'
# row: 493 col: 3 : 'movie' changed to 'tv series'
# row: 1548 col: 3 : 'movie' changed to 'movie'
# row: 129 col: 3 : 'movie' changed to 'tv series'
# row: 1424 col: 3 : 'movie' changed to 'movie'
# row: 700 col: 3 : 'movie' changed to 'tv series'
# row: 959 col: 3 : 'tv series' changed to 'movie'
# row: 394 col: 3 : 'movie' changed to 'tv series'
# row: 967 col: 3 : 'movie' changed to 'movie'
# row: 1521 col: 3 : 'tv series' changed to 'movie'
# row: 1491 col: 3 : 'tv series' changed to 'tv series'
# row: 1070 col: 3 : 'movie' changed to 'tv series'
# row: 14 col: 3 : 'tv series' changed to 'tv series'
# row: 226 col: 3 : 'movie' changed to 'tv series'
# row: 88 col: 3 : 'tv series' changed to 'movie'
# row: 1027 col: 3 : 'tv series' changed to 'tv series'
# row: 1128 col: 3 : 'tv series' changed to 'tv series'
# row: 641 col: 3 : 'movie' changed to 'movie'
# row: 1222 col: 3 : 'movie' changed to 'movie'
# row: 616 col: 3 : 'tv series' changed to 'movie'
# row: 1139 col: 3 : 'movie' changed to 'movie'
# row: 1406 col: 3 : 'movie' changed to 'movie'
# row: 1555 col: 3 : 'tv series' changed to 'tv series'
# row: 1166 col: 3 : 'tv series' changed to 'movie'
# row: 501 col: 3 : 'movie' changed to 'movie'
# row: 105 col: 3 : 'movie' changed to 'movie'
# row: 577 col: 3 : 'movie' changed to 'movie'
# row: 867 col: 3 : 'tv series' changed to 'tv series'
# row: 375 col: 3 : 'movie' changed to 'tv series'
# row: 865 col: 3 : 'movie' changed to 'tv series'
# row: 345 col: 3 : 'movie' changed to 'tv series'
# row: 1470 col: 3 : 'tv series' changed to 'movie'
# row: 1216 col: 3 : 'tv series' changed to 'movie'
# row: 945 col: 3 : 'tv series' changed to 'movie'
# row: 441 col: 3 : 'movie' changed to 'tv series'
# row: 1305 col: 3 : 'tv series' changed to 'movie'
# row: 652 col: 3 : 'movie' changed to 'movie'
# row: 222 col: 3 : 'tv series' changed to 'movie'
# row: 160 col: 3 : 'movie' changed to 'movie'
# row: 642 col: 3 : 'tv series' changed to 'tv series'
# row: 1446 col: 3 : 'movie' changed to 'tv series'
# row: 719 col: 3 : 'tv series' changed to 'movie'
# row: 1003 col: 3 : 'tv series' changed to 'movie'
# row: 1399 col: 3 : 'movie' changed to 'movie'
# row: 1575 col: 3 : 'tv series' changed to 'tv series'
# row: 504 col: 3 : 'tv series' changed to 'movie'
# row: 563 col: 3 : 'movie' changed to 'tv series'
# row: 323 col: 3 : 'tv series' changed to 'movie'
# row: 660 col: 3 : 'movie' changed to 'movie'
# row: 921 col: 3 : 'movie' changed to 'tv series'
# row: 876 col: 3 : 'tv series' changed to 'tv series'
# row: 1219 col: 3 : 'tv series' changed to 'movie'
# row: 973 col: 3 : 'movie' changed to 'movie'
# row: 569 col: 3 : 'tv series' changed to 'tv series'
# row: 1330 col: 3 : 'movie' changed to 'movie'
# row: 1499 col: 3 : 'tv series' changed to 'movie'
# row: 253 col: 3 : 'movie' changed to 'tv series'
# row: 1200 col: 3 : 'movie' changed to 'tv series'
# row: 263 col: 3 : 'movie' changed to 'tv series'
# row: 1351 col: 3 : 'movie' changed to 'movie'
# row: 1172 col: 3 : 'tv series' changed to 'movie'
# row: 1455 col: 3 : 'tv series' changed to 'movie'
# row: 555 col: 3 : 'movie' changed to 'tv series'
# row: 1018 col: 3 : 'movie' changed to 'tv series'
# row: 787 col: 3 : 'tv series' changed to 'movie'
# row: 1298 col: 3 : 'movie' changed to 'movie'
# row: 436 col: 3 : 'movie' changed to 'tv series'
# row: 897 col: 3 : 'tv series' changed to 'movie'
# row: 792 col: 3 : 'movie' changed to 'tv series'
# row: 901 col: 3 : 'tv series' changed to 'movie'
# row: 1008 col: 3 : 'tv series' changed to 'movie'
# row: 305 col: 3 : 'movie' changed to 'tv series'
# row: 1245 col: 3 : 'movie' changed to 'movie'
# row: 146 col: 3 : 'movie' changed to 'movie'
# row: 288 col: 3 : 'tv series' changed to 'movie'
# row: 1449 col: 3 : 'movie' changed to 'movie'
# row: 481 col: 3 : 'tv series' changed to 'movie'
# row: 651 col: 3 : 'tv series' changed to 'tv series'
# row: 1083 col: 3 : 'tv series' changed to 'tv series'
# row: 77 col: 3 : 'tv series' changed to 'movie'
# row: 1543 col: 3 : 'movie' changed to 'tv series'
# row: 1382 col: 3 : 'tv series' changed to 'movie'
# row: 1064 col: 3 : 'tv series' changed to 'tv series'
# row: 1593 col: 3 : 'movie' changed to 'movie'
# row: 389 col: 3 : 'tv series' changed to 'tv series'
# row: 1394 col: 3 : 'movie' changed to 'movie'
# row: 1456 col: 3 : 'tv series' changed to 'movie'
# row: 1138 col: 3 : 'movie' changed to 'tv series'
# row: 184 col: 3 : 'movie' changed to 'tv series'
# row: 188 col: 3 : 'movie' changed to 'tv series'
# row: 76 col: 3 : 'tv series' changed to 'movie'
# row: 297 col: 3 : 'tv series' changed to 'tv series'
# row: 230 col: 3 : 'tv series' changed to 'tv series'
# row: 1336 col: 3 : 'tv series' changed to 'movie'
# row: 747 col: 3 : 'movie' changed to 'tv series'
# row: 1372 col: 3 : 'tv series' changed to 'movie'
# row: 1097 col: 3 : 'movie' changed to 'movie'
# row: 1237 col: 3 : 'movie' changed to 'movie'
# row: 59 col: 3 : 'movie' changed to 'tv series'
# row: 1423 col: 3 : 'movie' changed to 'movie'
# row: 806 col: 3 : 'movie' changed to 'tv series'
# row: 101 col: 3 : 'movie' changed to 'movie'
# row: 869 col: 3 : 'tv series' changed to 'tv series'
# row: 708 col: 3 : 'movie' changed to 'movie'
# row: 900 col: 3 : 'movie' changed to 'tv series'
# row: 854 col: 3 : 'movie' changed to 'movie'
# row: 1545 col: 3 : 'movie' changed to 'movie'
# row: 202 col: 3 : 'tv series' changed to 'movie'
# row: 99 col: 3 : 'tv series' changed to 'movie'
# row: 1025 col: 3 : 'tv series' changed to 'movie'
# row: 622 col: 3 : 'movie' changed to 'tv series'
# row: 1284 col: 3 : 'tv series' changed to 'movie'
# row: 567 col: 3 : 'movie' changed to 'tv series'
# row: 1506 col: 3 : 'movie' changed to 'tv series'
# row: 1179 col: 3 : 'movie' changed to 'tv series'
# row: 1490 col: 3 : 'movie' changed to 'movie'
# row: 1198 col: 3 : 'movie' changed to 'tv series'
# row: 718 col: 3 : 'movie' changed to 'tv series'
# row: 1279 col: 3 : 'tv series' changed to 'movie'
# row: 107 col: 3 : 'movie' changed to 'tv series'
# row: 1036 col: 3 : 'tv series' changed to 'movie'
# row: 939 col: 3 : 'movie' changed to 'movie'
# row: 352 col: 3 : 'tv series' changed to 'tv series'
# row: 1407 col: 3 : 'tv series' changed to 'tv series'
# row: 1326 col: 3 : 'movie' changed to 'movie'
# row: 906 col: 3 : 'tv series' changed to 'movie'
# row: 1516 col: 3 : 'movie' changed to 'movie'
# row: 1266 col: 3 : 'movie' changed to 'tv series'
# row: 964 col: 3 : 'tv series' changed to 'tv series'
# row: 745 col: 3 : 'tv series' changed to 'movie'
# row: 770 col: 3 : 'movie' changed to 'tv series'
# row: 400 col: 3 : 'tv series' changed to 'tv series'
# row: 455 col: 3 : 'tv series' changed to 'tv series'
# row: 937 col: 3 : 'movie' changed to 'movie'
# row: 670 col: 3 : 'movie' changed to 'tv series'
# row: 891 col: 3 : 'tv series' changed to 'movie'
# row: 282 col: 3 : 'movie' changed to 'tv series'
# row: 680 col: 3 : 'tv series' changed to 'movie'
# row: 1540 col: 3 : 'movie' changed to 'tv series'
# row: 1386 col: 3 : 'tv series' changed to 'movie'
# row: 1467 col: 3 : 'tv series' changed to 'movie'
# row: 860 col: 3 : 'movie' changed to 'tv series'
# row: 1012 col: 3 : 'tv series' changed to 'tv series'
# row: 308 col: 3 : 'movie' changed to 'movie'
# row: 709 col: 3 : 'tv series' changed to 'tv series'
# row: 644 col: 3 : 'tv series' changed to 'movie'
# row: 759 col: 3 : 'tv series' changed to 'movie'
# row: 1565 col: 3 : 'tv series' changed to 'movie'
# row: 530 col: 3 : 'tv series' changed to 'movie'
# row: 943 col: 3 : 'movie' changed to 'tv series'
# row: 1144 col: 3 : 'movie' changed to 'movie'
# row: 1306 col: 3 : 'movie' changed to 'movie'
# row: 1048 col: 3 : 'tv series' changed to 'tv series'
# row: 1142 col: 3 : 'tv series' changed to 'tv series'
# row: 395 col: 3 : 'movie' changed to 'tv series'
# row: 30 col: 3 : 'tv series' changed to 'tv series'
# row: 1006 col: 3 : 'movie' changed to 'movie'
# row: 1589 col: 3 : 'tv series' changed to 'tv series'
# row: 1383 col: 3 : 'movie' changed to 'movie'
# row: 960 col: 3 : 'tv series' changed to 'movie'
# row: 961 col: 3 : 'tv series' changed to 'tv series'
# row: 420 col: 3 : 'tv series' changed to 'movie'
# row: 923 col: 3 : 'tv series' changed to 'tv series'
# row: 570 col: 3 : 'tv series' changed to 'tv series'
# row: 1322 col: 3 : 'tv series' changed to 'movie'
# row: 1059 col: 3 : 'tv series' changed to 'movie'
# row: 91 col: 3 : 'tv series' changed to 'movie'
# row: 1078 col: 3 : 'movie' changed to 'tv series'
# row: 610 col: 3 : 'movie' changed to 'tv series'
# row: 1260 col: 3 : 'tv series' changed to 'movie'
# row: 1483 col: 3 : 'movie' changed to 'tv series'
# row: 1131 col: 3 : 'movie' changed to 'movie'
# row: 170 col: 3 : 'tv series' changed to 'tv series'
# row: 538 col: 3 : 'tv series' changed to 'tv series'
# row: 350 col: 3 : 'movie' changed to 'movie'
# row: 838 col: 3 : 'tv series' changed to 'tv series'
# row: 559 col: 3 : 'movie' changed to 'tv series'
# row: 1409 col: 3 : 'movie' changed to 'tv series'
# row: 182 col: 3 : 'movie' changed to 'movie'
# row: 755 col: 3 : 'movie' changed to 'tv series'
# row: 180 col: 3 : 'tv series' changed to 'tv series'
# row: 1276 col: 3 : 'tv series' changed to 'tv series'
# row: 1249 col: 3 : 'tv series' changed to 'movie'
# row: 521 col: 3 : 'tv series' changed to 'tv series'
# row: 243 col: 3 : 'tv series' changed to 'movie'
# row: 1553 col: 3 : 'movie' changed to 'tv series'
# row: 742 col: 3 : 'movie' changed to 'tv series'
# row: 987 col: 3 : 'tv series' changed to 'tv series'
# row: 1485 col: 3 : 'movie' changed to 'movie'
# row: 763 col: 3 : 'tv series' changed to 'movie'
# row: 45 col: 3 : 'tv series' changed to 'movie'
# row: 215 col: 3 : 'movie' changed to 'tv series'
# row: 1551 col: 3 : 'movie' changed to 'tv series'
# row: 1126 col: 3 : 'tv series' changed to 'movie'
# row: 1295 col: 3 : 'movie' changed to 'tv series'
# row: 1287 col: 3 : 'movie' changed to 'movie'
# row: 1130 col: 3 : 'tv series' changed to 'movie'
# row: 1577 col: 3 : 'tv series' changed to 'tv series'
# row: 576 col: 3 : 'tv series' changed to 'tv series'
# row: 932 col: 3 : 'tv series' changed to 'movie'
# row: 393 col: 3 : 'tv series' changed to 'tv series'
# row: 396 col: 3 : 'movie' changed to 'movie'
# row: 1433 col: 3 : 'tv series' changed to 'tv series'
# row: 458 col: 3 : 'movie' changed to 'tv series'
# row: 268 col: 3 : 'tv series' changed to 'movie'
# row: 1590 col: 3 : 'movie' changed to 'movie'
# row: 343 col: 3 : 'movie' changed to 'movie'
# row: 543 col: 3 : 'tv series' changed to 'movie'
# row: 1522 col: 3 : 'tv series' changed to 'movie'
# row: 991 col: 3 : 'movie' changed to 'tv series'
# row: 200 col: 3 : 'movie' changed to 'movie'
# row: 1133 col: 3 : 'tv series' changed to 'tv series'
# row: 172 col: 3 : 'tv series' changed to 'movie'
# row: 1428 col: 3 : 'movie' changed to 'movie'
# row: 214 col: 3 : 'tv series' changed to 'movie'
# row: 666 col: 3 : 'movie' changed to 'tv series'
# row: 599 col: 3 : 'tv series' changed to 'tv series'
# row: 1578 col: 3 : 'tv series' changed to 'movie'
# row: 783 col: 3 : 'tv series' changed to 'tv series'
# row: 185 col: 3 : 'movie' changed to 'movie'
# row: 284 col: 3 : 'movie' changed to 'movie'
# row: 1561 col: 3 : 'tv series' changed to 'tv series'
# row: 918 col: 3 : 'tv series' changed to 'movie'
# row: 1539 col: 3 : 'tv series' changed to 'movie'
# row: 1349 col: 3 : 'tv series' changed to 'movie'
# row: 1043 col: 3 : 'movie' changed to 'movie'
# row: 703 col: 3 : 'tv series' changed to 'tv series'
# row: 300 col: 3 : 'tv series' changed to 'movie'
# row: 995 col: 3 : 'movie' changed to 'movie'
# row: 1466 col: 3 : 'tv series' changed to 'movie'
# row: 827 col: 3 : 'movie' changed to 'tv series'
# row: 293 col: 3 : 'movie' changed to 'tv series'
# row: 522 col: 3 : 'tv series' changed to 'tv series'
# row: 197 col: 3 : 'tv series' changed to 'tv series'
# row: 980 col: 3 : 'movie' changed to 'movie'
# row: 990 col: 3 : 'movie' changed to 'tv series'
# row: 1009 col: 3 : 'movie' changed to 'tv series'
# row: 758 col: 3 : 'movie' changed to 'movie'
# row: 399 col: 3 : 'movie' changed to 'movie'
# row: 779 col: 3 : 'movie' changed to 'tv series'
# row: 415 col: 3 : 'tv series' changed to 'movie'
# row: 1140 col: 3 : 'movie' changed to 'tv series'
# row: 310 col: 3 : 'tv series' changed to 'movie'
# row: 327 col: 3 : 'movie' changed to 'movie'
# row: 447 col: 3 : 'tv series' changed to 'movie'
# row: 1320 col: 3 : 'movie' changed to 'movie'
# row: 1169 col: 3 : 'movie' changed to 'tv series'
# row: 232 col: 3 : 'movie' changed to 'movie'
# row: 853 col: 3 : 'movie' changed to 'movie'
# row: 672 col: 3 : 'tv series' changed to 'movie'
# row: 1022 col: 3 : 'movie' changed to 'tv series'
# row: 1162 col: 3 : 'movie' changed to 'movie'
# row: 294 col: 3 : 'tv series' changed to 'movie'
# row: 1188 col: 3 : 'movie' changed to 'movie'
# row: 141 col: 3 : 'tv series' changed to 'tv series'
# row: 629 col: 3 : 'tv series' changed to 'tv series'
# row: 1447 col: 3 : 'tv series' changed to 'tv series'
# row: 575 col: 3 : 'movie' changed to 'movie'
# row: 1155 col: 3 : 'movie' changed to 'movie'
# row: 1459 col: 3 : 'tv series' changed to 'movie'
# row: 573 col: 3 : 'movie' changed to 'tv series'
# row: 812 col: 3 : 'movie' changed to 'movie'
# row: 822 col: 3 : 'movie' changed to 'movie'
# row: 163 col: 3 : 'tv series' changed to 'movie'
# row: 954 col: 3 : 'movie' changed to 'tv series'
# row: 485 col: 3 : 'movie' changed to 'tv series'
# row: 93 col: 3 : 'tv series' changed to 'movie'
# row: 46 col: 3 : 'tv series' changed to 'movie'
# row: 1056 col: 3 : 'tv series' changed to 'movie'
# row: 1354 col: 3 : 'movie' changed to 'tv series'
# row: 309 col: 3 : 'tv series' changed to 'tv series'
# row: 833 col: 3 : 'movie' changed to 'movie'
# row: 791 col: 3 : 'tv series' changed to 'tv series'
# row: 503 col: 3 : 'tv series' changed to 'movie'
# row: 661 col: 3 : 'movie' changed to 'tv series'
# row: 1304 col: 3 : 'movie' changed to 'tv series'
# row: 1564 col: 3 : 'movie' changed to 'movie'
# row: 1538 col: 3 : 'movie' changed to 'movie'
# row: 1191 col: 3 : 'movie' changed to 'tv series'
# row: 237 col: 3 : 'movie' changed to 'movie'
# row: 1558 col: 3 : 'tv series' changed to 'tv series'
# row: 477 col: 3 : 'movie' changed to 'movie'
# row: 358 col: 3 : 'movie' changed to 'movie'
# row: 90 col: 3 : 'movie' changed to 'movie'
# row: 1566 col: 3 : 'tv series' changed to 'tv series'
# row: 887 col: 3 : 'movie' changed to 'tv series'
# row: 996 col: 3 : 'tv series' changed to 'movie'
# row: 369 col: 3 : 'tv series' changed to 'tv series'
# row: 203 col: 3 : 'movie' changed to 'movie'
# row: 155 col: 3 : 'movie' changed to 'movie'
# row: 112 col: 3 : 'tv series' changed to 'movie'
# row: 1315 col: 3 : 'movie' changed to 'movie'
# row: 1568 col: 3 : 'movie' changed to 'tv series'
# row: 868 col: 3 : 'tv series' changed to 'tv series'
# row: 1435 col: 3 : 'movie' changed to 'movie'
# row: 463 col: 3 : 'movie' changed to 'movie'
# row: 665 col: 3 : 'movie' changed to 'tv series'
# row: 589 col: 3 : 'tv series' changed to 'tv series'
# row: 1229 col: 3 : 'tv series' changed to 'tv series'
# row: 989 col: 3 : 'movie' changed to 'tv series'
# row: 856 col: 3 : 'movie' changed to 'movie'
# row: 905 col: 3 : 'movie' changed to 'movie'
# row: 1584 col: 3 : 'movie' changed to 'tv series'
# row: 1087 col: 3 : 'tv series' changed to 'tv series'
# row: 117 col: 3 : 'movie' changed to 'tv series'
# row: 65 col: 3 : 'movie' changed to 'tv series'
# row: 34 col: 3 : 'tv series' changed to 'movie'
# row: 598 col: 3 : 'movie' changed to 'movie'
# row: 1496 col: 3 : 'movie' changed to 'tv series'
# row: 695 col: 3 : 'tv series' changed to 'movie'
# row: 574 col: 3 : 'movie' changed to 'movie'
# row: 1165 col: 3 : 'tv series' changed to 'movie'
# row: 169 col: 3 : 'tv series' changed to 'movie'
# row: 1283 col: 3 : 'tv series' changed to 'movie'
# row: 793 col: 3 : 'tv series' changed to 'tv series'
# row: 1344 col: 3 : 'tv series' changed to 'tv series'
# row: 915 col: 3 : 'movie' changed to 'movie'
# row: 842 col: 3 : 'movie' changed to 'movie'
# row: 769 col: 3 : 'movie' changed to 'movie'
# row: 1093 col: 3 : 'movie' changed to 'movie'
# row: 1032 col: 3 : 'movie' changed to 'tv series'
# row: 1493 col: 3 : 'movie' changed to 'movie'
# row: 264 col: 3 : 'movie' changed to 'movie'
# row: 592 col: 3 : 'movie' changed to 'movie'
# row: 1161 col: 3 : 'tv series' changed to 'tv series'
# row: 558 col: 3 : 'tv series' changed to 'tv series'
# row: 1145 col: 3 : 'movie' changed to 'tv series'
# row: 401 col: 3 : 'movie' changed to 'movie'
# row: 450 col: 3 : 'movie' changed to 'movie'
# row: 1286 col: 3 : 'tv series' changed to 'movie'
# row: 1129 col: 3 : 'tv series' changed to 'movie'
# row: 925 col: 3 : 'tv series' changed to 'movie'
# row: 587 col: 3 : 'tv series' changed to 'movie'
# row: 927 col: 3 : 'movie' changed to 'movie'
# row: 444 col: 3 : 'movie' changed to 'tv series'
# row: 848 col: 3 : 'movie' changed to 'tv series'
# row: 1308 col: 3 : 'movie' changed to 'movie'
# row: 713 col: 3 : 'movie' changed to 'tv series'
# row: 114 col: 3 : 'tv series' changed to 'tv series'
# row: 1040 col: 3 : 'tv series' changed to 'movie'
# row: 611 col: 3 : 'tv series' changed to 'tv series'
# row: 977 col: 3 : 'tv series' changed to 'tv series'
# row: 67 col: 3 : 'tv series' changed to 'movie'
# row: 673 col: 3 : 'tv series' changed to 'tv series'
# row: 274 col: 3 : 'tv series' changed to 'movie'
# row: 647 col: 3 : 'tv series' changed to 'tv series'
# row: 483 col: 3 : 'tv series' changed to 'movie'
# row: 963 col: 3 : 'tv series' changed to 'tv series'
# row: 1469 col: 3 : 'tv series' changed to 'tv series'
# row: 1292 col: 3 : 'tv series' changed to 'movie'
# row: 537 col: 3 : 'tv series' changed to 'movie'
# row: 1125 col: 3 : 'tv series' changed to 'movie'
# row: 518 col: 3 : 'movie' changed to 'tv series'
# row: 1134 col: 3 : 'movie' changed to 'movie'
# row: 204 col: 3 : 'tv series' changed to 'movie'
# row: 219 col: 3 : 'movie' changed to 'movie'
# row: 211 col: 3 : 'tv series' changed to 'movie'
# row: 373 col: 3 : 'movie' changed to 'tv series'
# row: 18 col: 3 : 'movie' changed to 'tv series'
# row: 1208 col: 3 : 'movie' changed to 'movie'
# row: 917 col: 3 : 'tv series' changed to 'tv series'
# row: 805 col: 3 : 'tv series' changed to 'movie'
# row: 1095 col: 3 : 'tv series' changed to 'movie'
# row: 1444 col: 3 : 'tv series' changed to 'movie'
# row: 762 col: 3 : 'tv series' changed to 'movie'
# row: 81 col: 3 : 'movie' changed to 'tv series'
# row: 1468 col: 3 : 'movie' changed to 'tv series'
# row: 1094 col: 3 : 'tv series' changed to 'tv series'
# row: 801 col: 3 : 'tv series' changed to 'movie'
# row: 635 col: 3 : 'movie' changed to 'tv series'
# row: 734 col: 3 : 'movie' changed to 'tv series'
# row: 1365 col: 3 : 'movie' changed to 'movie'
# row: 56 col: 3 : 'movie' changed to 'tv series'
# row: 529 col: 3 : 'tv series' changed to 'tv series'
# row: 1105 col: 3 : 'tv series' changed to 'movie'
# row: 757 col: 3 : 'movie' changed to 'tv series'
# row: 654 col: 3 : 'movie' changed to 'tv series'
# row: 377 col: 3 : 'tv series' changed to 'movie'
# row: 1256 col: 3 : 'movie' changed to 'movie'
# row: 753 col: 3 : 'tv series' changed to 'tv series'
# row: 1190 col: 3 : 'tv series' changed to 'movie'
# row: 97 col: 3 : 'movie' changed to 'movie'
# row: 551 col: 3 : 'tv series' changed to 'tv series'
# row: 729 col: 3 : 'movie' changed to 'tv series'
# row: 265 col: 3 : 'movie' changed to 'movie'
# row: 908 col: 3 : 'tv series' changed to 'movie'
# row: 1360 col: 3 : 'movie' changed to 'movie'
# row: 625 col: 3 : 'movie' changed to 'movie'
# row: 166 col: 3 : 'movie' changed to 'movie'
# row: 304 col: 3 : 'movie' changed to 'movie'
# row: 705 col: 3 : 'tv series' changed to 'movie'
# row: 508 col: 3 : 'tv series' changed to 'movie'
# row: 1261 col: 3 : 'movie' changed to 'tv series'
# row: 94 col: 3 : 'tv series' changed to 'movie'
# row: 1381 col: 3 : 'movie' changed to 'tv series'
# row: 10 col: 3 : 'tv series' changed to 'movie'
# row: 53 col: 3 : 'tv series' changed to 'movie'
# row: 207 col: 3 : 'tv series' changed to 'tv series'
# row: 618 col: 3 : 'movie' changed to 'tv series'
# row: 1477 col: 3 : 'movie' changed to 'tv series'
# row: 1071 col: 3 : 'movie' changed to 'tv series'
# row: 8 col: 3 : 'movie' changed to 'tv series'
# row: 1173 col: 3 : 'movie' changed to 'tv series'
# row: 1583 col: 3 : 'movie' changed to 'movie'
# row: 843 col: 3 : 'movie' changed to 'movie'
# row: 383 col: 3 : 'tv series' changed to 'movie'
# row: 134 col: 3 : 'tv series' changed to 'tv series'
# row: 478 col: 3 : 'movie' changed to 'tv series'
# row: 760 col: 3 : 'tv series' changed to 'movie'
# row: 846 col: 3 : 'tv series' changed to 'movie'
# row: 1264 col: 3 : 'tv series' changed to 'tv series'
# row: 1502 col: 3 : 'tv series' changed to 'tv series'
# row: 1303 col: 3 : 'tv series' changed to 'movie'
# row: 940 col: 3 : 'tv series' changed to 'tv series'
# row: 73 col: 3 : 'tv series' changed to 'tv series'
# row: 1380 col: 3 : 'movie' changed to 'tv series'
# row: 78 col: 3 : 'movie' changed to 'movie'
# row: 1011 col: 3 : 'tv series' changed to 'movie'
# row: 799 col: 3 : 'tv series' changed to 'tv series'
# row: 1058 col: 3 : 'tv series' changed to 'movie'
# row: 247 col: 3 : 'tv series' changed to 'movie'
# row: 829 col: 3 : 'tv series' changed to 'movie'
# row: 1346 col: 3 : 'movie' changed to 'movie'
# row: 453 col: 3 : 'tv series' changed to 'movie'
# row: 982 col: 3 : 'movie' changed to 'tv series'
# row: 1482 col: 3 : 'movie' changed to 'tv series'
# row: 811 col: 3 : 'tv series' changed to 'movie'
# row: 233 col: 3 : 'movie' changed to 'movie'
# row: 910 col: 3 : 'movie' changed to 'tv series'
# row: 1461 col: 3 : 'movie' changed to 'tv series'
# row: 1072 col: 3 : 'tv series' changed to 'movie'
# row: 736 col: 3 : 'tv series' changed to 'tv series'
# row: 1271 col: 3 : 'movie' changed to 'tv series'
# row: 39 col: 3 : 'tv series' changed to 'tv series'
# row: 445 col: 3 : 'tv series' changed to 'movie'
# row: 1180 col: 3 : 'movie' changed to 'movie'
# row: 588 col: 3 : 'movie' changed to 'tv series'
# row: 1171 col: 3 : 'tv series' changed to 'movie'
# row: 962 col: 3 : 'tv series' changed to 'movie'
# row: 459 col: 3 : 'tv series' changed to 'tv series'
# row: 511 col: 3 : 'tv series' changed to 'tv series'
# row: 499 col: 3 : 'movie' changed to 'movie'
# row: 620 col: 3 : 'movie' changed to 'movie'
# row: 139 col: 3 : 'movie' changed to 'tv series'
# row: 735 col: 3 : 'tv series' changed to 'tv series'
# row: 535 col: 3 : 'movie' changed to 'movie'
# row: 1464 col: 3 : 'movie' changed to 'tv series'
# row: 398 col: 3 : 'movie' changed to 'tv series'
# row: 438 col: 3 : 'movie' changed to 'tv series'
# row: 1550 col: 3 : 'movie' changed to 'movie'
# row: 1057 col: 3 : 'movie' changed to 'movie'
# row: 1203 col: 3 : 'movie' changed to 'movie'
# row: 212 col: 3 : 'movie' changed to 'tv series'
# row: 988 col: 3 : 'tv series' changed to 'movie'
# row: 1107 col: 3 : 'tv series' changed to 'tv series'
# row: 560 col: 3 : 'tv series' changed to 'movie'
# row: 217 col: 3 : 'tv series' changed to 'movie'
# row: 427 col: 3 : 'tv series' changed to 'tv series'
# row: 814 col: 3 : 'movie' changed to 'movie'
# row: 659 col: 3 : 'movie' changed to 'movie'
# row: 1523 col: 3 : 'movie' changed to 'tv series'
# row: 368 col: 3 : 'movie' changed to 'tv series'
# row: 699 col: 3 : 'movie' changed to 'movie'
# row: 1187 col: 3 : 'tv series' changed to 'tv series'
# row: 387 col: 3 : 'movie' changed to 'tv series'
# row: 1184 col: 3 : 'tv series' changed to 'tv series'
# row: 739 col: 3 : 'tv series' changed to 'tv series'
# row: 826 col: 3 : 'movie' changed to 'tv series'
# row: 79 col: 3 : 'movie' changed to 'tv series'
# row: 754 col: 3 : 'tv series' changed to 'movie'
# row: 103 col: 3 : 'movie' changed to 'movie'
# row: 1255 col: 3 : 'movie' changed to 'movie'
# row: 467 col: 3 : 'tv series' changed to 'movie'
# row: 815 col: 3 : 'movie' changed to 'tv series'
# row: 606 col: 3 : 'tv series' changed to 'tv series'
# row: 439 col: 3 : 'tv series' changed to 'movie'
# row: 199 col: 3 : 'movie' changed to 'tv series'
# row: 1285 col: 3 : 'movie' changed to 'movie'
# row: 250 col: 3 : 'movie' changed to 'movie'
# row: 312 col: 3 : 'movie' changed to 'movie'
# row: 64 col: 3 : 'tv series' changed to 'tv series'
# row: 689 col: 3 : 'movie' changed to 'movie'
# row: 1193 col: 3 : 'tv series' changed to 'movie'
# row: 720 col: 3 : 'movie' changed to 'tv series'
# row: 224 col: 3 : 'tv series' changed to 'tv series'
# row: 526 col: 3 : 'tv series' changed to 'tv series'
# row: 894 col: 3 : 'movie' changed to 'tv series'
# row: 824 col: 3 : 'movie' changed to 'movie'
# row: 1335 col: 3 : 'tv series' changed to 'movie'
# row: 1085 col: 3 : 'movie' changed to 'movie'
# row: 1451 col: 3 : 'movie' changed to 'tv series'
# row: 11 col: 3 : 'tv series' changed to 'movie'
# row: 549 col: 3 : 'tv series' changed to 'tv series'
# row: 1102 col: 3 : 'tv series' changed to 'movie'
# row: 1113 col: 3 : 'movie' changed to 'movie'
# row: 257 col: 3 : 'tv series' changed to 'tv series'
# row: 460 col: 3 : 'tv series' changed to 'tv series'
# row: 1029 col: 3 : 'movie' changed to 'movie'
# row: 1309 col: 3 : 'movie' changed to 'tv series'
# row: 1362 col: 3 : 'tv series' changed to 'movie'
# row: 228 col: 3 : 'tv series' changed to 'tv series'
# row: 1571 col: 3 : 'movie' changed to 'movie'
# row: 1267 col: 3 : 'tv series' changed to 'tv series'
# row: 95 col: 3 : 'movie' changed to 'movie'
# row: 544 col: 3 : 'movie' changed to 'movie'
# row: 630 col: 3 : 'tv series' changed to 'movie'
# row: 13 col: 3 : 'movie' changed to 'movie'
# row: 866 col: 3 : 'tv series' changed to 'movie'
# row: 151 col: 3 : 'movie' changed to 'tv series'
# row: 418 col: 3 : 'tv series' changed to 'tv series'
# row: 872 col: 3 : 'tv series' changed to 'movie'
# row: 275 col: 3 : 'movie' changed to 'tv series'
# row: 326 col: 3 : 'tv series' changed to 'movie'
# row: 1067 col: 3 : 'tv series' changed to 'tv series'
# row: 497 col: 3 : 'tv series' changed to 'tv series'
# row: 1000 col: 3 : 'tv series' changed to 'movie'
# row: 924 col: 3 : 'movie' changed to 'movie'
# row: 972 col: 3 : 'tv series' changed to 'tv series'
# row: 1118 col: 3 : 'tv series' changed to 'movie'
# row: 1420 col: 3 : 'tv series' changed to 'tv series'
# row: 379 col: 3 : 'tv series' changed to 'tv series'
# row: 402 col: 3 : 'tv series' changed to 'movie'
# row: 21 col: 3 : 'movie' changed to 'tv series'
# row: 147 col: 3 : 'movie' changed to 'tv series'
# row: 965 col: 3 : 'movie' changed to 'tv series'
# row: 663 col: 3 : 'movie' changed to 'movie'
# row: 424 col: 3 : 'movie' changed to 'movie'
# row: 1055 col: 3 : 'movie' changed to 'tv series'
# row: 186 col: 3 : 'tv series' changed to 'movie'
# row: 553 col: 3 : 'tv series' changed to 'tv series'
# row: 177 col: 3 : 'movie' changed to 'tv series'
# row: 1572 col: 3 : 'movie' changed to 'tv series'
# row: 1089 col: 3 : 'tv series' changed to 'movie'
# row: 775 col: 3 : 'movie' changed to 'tv series'
# row: 1121 col: 3 : 'tv series' changed to 'tv series'
# row: 273 col: 3 : 'tv series' changed to 'movie'
# row: 258 col: 3 : 'tv series' changed to 'tv series'
# row: 205 col: 3 : 'tv series' changed to 'tv series'
# row: 148 col: 3 : 'tv series' changed to 'movie'
# row: 519 col: 3 : 'tv series' changed to 'movie'
# row: 1375 col: 3 : 'movie' changed to 'movie'
# row: 189 col: 3 : 'movie' changed to 'movie'
# row: 1277 col: 3 : 'movie' changed to 'tv series'
# row: 270 col: 3 : 'tv series' changed to 'tv series'
# row: 1596 col: 3 : 'tv series' changed to 'tv series'
# row: 118 col: 3 : 'tv series' changed to 'movie'
# row: 19 col: 3 : 'tv series' changed to 'tv series'
# row: 162 col: 3 : 'movie' changed to 'tv series'
# row: 649 col: 3 : 'tv series' changed to 'tv series'
# row: 1030 col: 3 : 'movie' changed to 'tv series'
# row: 1417 col: 3 : 'movie' changed to 'movie'
# row: 1297 col: 3 : 'movie' changed to 'tv series'
# row: 208 col: 3 : 'tv series' changed to 'movie'
# row: 1582 col: 3 : 'tv series' changed to 'tv series'
# row: 941 col: 3 : 'movie' changed to 'tv series'
# row: 1160 col: 3 : 'tv series' changed to 'movie'
# row: 1342 col: 3 : 'movie' changed to 'tv series'

# %% [markdown]
# ## Transformation

# %%
import nltk
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    #print("Train Dummies",train_dummies.shape)    
    #print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# features vector
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

print(anime_train.shape)
print(anime_test.shape)

# split train test
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])
# Out:
# (1541, 7163)
# (390, 7163)

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)
# Out:
# (1541, 7162)
# (390, 7162)
# (1541, 700)
# (390, 700)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)
    
    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

# %% [markdown]
# ### Training

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean squared error: 1.05

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)
# Out:
# Scores: [0.986 0.986 1.078 0.975 0.954]
# Mean: 0.9959716665162077
# Standard deviation: 0.042662998376204936

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 5, anime_X_train, anime_y_train)
# Out:
# best parameters are:  {'alpha': 0.01}
# The mean squared Error is: 0.86

# %%
clf = training(model = linear_model.Lasso(alpha = 0.01), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
# Out:
# Mean squared error: 1.04
