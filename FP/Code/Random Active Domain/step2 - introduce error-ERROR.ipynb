# %% [markdown]
# ## Import Data

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from error_generator import Random_Active_Domain
from error_generator import List_selected
from error_generator import Read_Write
from error_generator import Error_Generator
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LassoCV
from yellowbrick.regressor import AlphaSelection
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from yellowbrick.regressor import PredictionError

# %% [markdown]
# ## Train-test dataset

# %%
anime_train = pd.read_csv("data/trainDataset.csv")
anime_test = pd.read_csv("data/testDataset.csv")

# %%
anime_train['genre'].fillna('',  inplace=True)
anime_train['overview'].fillna('',  inplace=True)
anime_train['type'].fillna('',  inplace=True)

anime_test['genre'].fillna('',  inplace=True)
anime_test['overview'].fillna('',  inplace=True)
anime_test['type'].fillna('',  inplace=True)

print("Anime train:", anime_train.shape)
print(anime_train.type.value_counts())

print("Anime test:", anime_test.shape)
print(anime_test.type.value_counts())
# Out:
# Anime train: (1600, 8)
# movie        800
# tv series    793
#                7
# Name: type, dtype: int64
# Anime test: (400, 8)
# movie        202
# tv series    197
#                1
# Name: type, dtype: int64

# %%
#anime_train['type'].fillna('',  inplace=True)
print("Type",anime_train['type'].isnull().any())
# Out:
# Type False

# %%
for feature in list(anime_train):
    print(feature+":", anime_train[feature].isna().sum())
# Out:
# anime_id: 0
# name: 0
# genre: 0
# type: 0
# episodes: 50
# rating: 36
# members: 0
# overview: 0

# %% [markdown]
# ## Generating Errors

# %%
def error_generator(dataset, method, n, ignored_columns):

    myselector=List_selected()

    mygen=Error_Generator()

    new_dataset=mygen.error_generator(method_gen=method,selector=myselector,percentage=n,dataset=dataset,mute_column = ignored_columns)
    
    return new_dataset

# %%
# generate error in the training set
new_dataset = error_generator(anime_train.values.tolist(), Random_Active_Domain(),75, ignored_columns = [0,1,2,4,5,6,7])
Read_Write.write_csv_dataset("data/{}.csv".format(Random_Active_Domain().name), new_dataset)
anime_train = pd.read_csv("data/{}.csv".format(Random_Active_Domain().name), 
                            names = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
anime_train.to_csv("data/dirtyTrainDataset.csv", index = False,
                  columns = ['anime_id', 'name','genre','type', 'episodes','rating', 'members', 'overview'])
# Out:
# ---------Change according to random_active_domain method ---------------
#
# row: 913 col: 3 : 'movie' changed to 'tv series'
# row: 1274 col: 3 : 'movie' changed to 'tv series'
# row: 1346 col: 3 : 'movie' changed to 'movie'
# row: 917 col: 3 : 'tv series' changed to 'tv series'
# row: 1532 col: 3 : 'movie' changed to 'tv series'
# row: 1472 col: 3 : 'movie' changed to 'movie'
# row: 1290 col: 3 : 'tv series' changed to 'movie'
# row: 459 col: 3 : 'tv series' changed to 'tv series'
# row: 254 col: 3 : 'tv series' changed to 'tv series'
# row: 237 col: 3 : 'movie' changed to 'tv series'
# row: 1436 col: 3 : 'tv series' changed to 'movie'
# row: 1171 col: 3 : 'tv series' changed to 'tv series'
# row: 1199 col: 3 : 'tv series' changed to 'tv series'
# row: 270 col: 3 : 'tv series' changed to 'movie'
# row: 1328 col: 3 : 'movie' changed to 'movie'
# row: 1032 col: 3 : 'movie' changed to 'tv series'
# row: 614 col: 3 : 'tv series' changed to 'movie'
# row: 1568 col: 3 : 'movie' changed to 'tv series'
# row: 670 col: 3 : 'movie' changed to 'tv series'
# row: 1466 col: 3 : 'tv series' changed to 'movie'
# row: 1069 col: 3 : 'tv series' changed to 'tv series'
# row: 403 col: 3 : 'tv series' changed to 'movie'
# row: 1252 col: 3 : 'movie' changed to 'tv series'
# row: 176 col: 3 : 'movie' changed to 'movie'
# row: 1281 col: 3 : 'tv series' changed to 'tv series'
# row: 612 col: 3 : 'tv series' changed to 'tv series'
# row: 366 col: 3 : 'movie' changed to 'tv series'
# row: 1061 col: 3 : 'tv series' changed to 'tv series'
# row: 724 col: 3 : 'movie' changed to 'movie'
# row: 1362 col: 3 : 'tv series' changed to 'movie'
# row: 1381 col: 3 : 'movie' changed to 'tv series'
# row: 1389 col: 3 : 'tv series' changed to 'movie'
# row: 1105 col: 3 : 'tv series' changed to 'tv series'
# row: 1354 col: 3 : 'movie' changed to 'tv series'
# row: 110 col: 3 : 'tv series' changed to 'movie'
# row: 1415 col: 3 : 'movie' changed to 'movie'
# row: 427 col: 3 : 'tv series' changed to 'movie'
# row: 453 col: 3 : 'tv series' changed to 'tv series'
# row: 358 col: 3 : 'movie' changed to 'tv series'
# row: 1327 col: 3 : 'tv series' changed to 'tv series'
# row: 680 col: 3 : 'tv series' changed to 'tv series'
# row: 1453 col: 3 : 'movie' changed to 'movie'
# row: 38 col: 3 : 'tv series' changed to 'tv series'
# row: 1547 col: 3 : 'tv series' changed to 'tv series'
# row: 1253 col: 3 : 'movie' changed to 'tv series'
# row: 819 col: 3 : 'movie' changed to 'tv series'
# row: 115 col: 3 : 'movie' changed to 'movie'
# row: 209 col: 3 : 'tv series' changed to 'movie'
# row: 718 col: 3 : 'movie' changed to 'movie'
# row: 999 col: 3 : 'tv series' changed to 'movie'
# row: 1593 col: 3 : 'movie' changed to 'tv series'
# row: 1210 col: 3 : 'movie' changed to 'movie'
# row: 1001 col: 3 : 'tv series' changed to 'movie'
# row: 657 col: 3 : 'movie' changed to 'tv series'
# row: 1363 col: 3 : 'movie' changed to 'tv series'
# row: 516 col: 3 : 'tv series' changed to 'movie'
# row: 311 col: 3 : 'movie' changed to 'movie'
# row: 375 col: 3 : 'movie' changed to 'tv series'
# row: 1085 col: 3 : 'movie' changed to 'movie'
# row: 1257 col: 3 : 'movie' changed to 'movie'
# row: 678 col: 3 : 'movie' changed to 'tv series'
# row: 893 col: 3 : 'movie' changed to 'tv series'
# row: 736 col: 3 : 'tv series' changed to 'tv series'
# row: 381 col: 3 : 'movie' changed to 'tv series'
# row: 422 col: 3 : 'movie' changed to 'movie'
# row: 541 col: 3 : 'movie' changed to 'movie'
# row: 1383 col: 3 : 'movie' changed to 'tv series'
# row: 994 col: 3 : 'movie' changed to 'tv series'
# row: 828 col: 3 : 'tv series' changed to 'movie'
# row: 1205 col: 3 : 'movie' changed to 'movie'
# row: 592 col: 3 : 'movie' changed to 'movie'
# row: 1206 col: 3 : 'tv series' changed to 'movie'
# row: 182 col: 3 : 'movie' changed to 'tv series'
# row: 1217 col: 3 : 'movie' changed to 'tv series'
# row: 1220 col: 3 : 'tv series' changed to 'movie'
# row: 475 col: 3 : 'tv series' changed to 'tv series'
# row: 815 col: 3 : 'movie' changed to 'movie'
# row: 987 col: 3 : 'tv series' changed to 'movie'
# row: 333 col: 3 : 'tv series' changed to ''
# row: 684 col: 3 : 'movie' changed to 'tv series'
# row: 1523 col: 3 : 'movie' changed to 'movie'
# row: 930 col: 3 : 'tv series' changed to 'movie'
# row: 749 col: 3 : 'tv series' changed to 'movie'
# row: 796 col: 3 : 'tv series' changed to 'tv series'
# row: 1356 col: 3 : 'tv series' changed to 'movie'
# row: 562 col: 3 : 'tv series' changed to 'tv series'
# row: 316 col: 3 : 'tv series' changed to 'movie'
# row: 20 col: 3 : 'movie' changed to 'movie'
# row: 1031 col: 3 : 'tv series' changed to 'movie'
# row: 1126 col: 3 : 'tv series' changed to 'movie'
# row: 1524 col: 3 : 'movie' changed to 'movie'
# row: 477 col: 3 : 'movie' changed to 'tv series'
# row: 546 col: 3 : 'tv series' changed to 'tv series'
# row: 507 col: 3 : 'movie' changed to 'tv series'
# row: 337 col: 3 : 'tv series' changed to 'movie'
# row: 889 col: 3 : 'movie' changed to 'movie'
# row: 259 col: 3 : 'tv series' changed to 'tv series'
# row: 573 col: 3 : 'movie' changed to 'movie'
# row: 335 col: 3 : 'movie' changed to 'tv series'
# row: 1063 col: 3 : 'tv series' changed to 'tv series'
# row: 278 col: 3 : 'movie' changed to 'movie'
# row: 34 col: 3 : 'tv series' changed to 'movie'
# row: 1404 col: 3 : 'tv series' changed to 'movie'
# row: 949 col: 3 : 'tv series' changed to 'movie'
# row: 1575 col: 3 : 'tv series' changed to ''
# row: 526 col: 3 : 'tv series' changed to 'movie'
# row: 530 col: 3 : 'tv series' changed to 'tv series'
# row: 124 col: 3 : 'movie' changed to 'tv series'
# row: 421 col: 3 : 'movie' changed to 'movie'
# row: 659 col: 3 : 'movie' changed to 'tv series'
# row: 965 col: 3 : 'movie' changed to 'movie'
# row: 241 col: 3 : 'movie' changed to 'tv series'
# row: 1310 col: 3 : 'tv series' changed to 'movie'
# row: 667 col: 3 : 'movie' changed to 'tv series'
# row: 1084 col: 3 : 'movie' changed to 'movie'
# row: 14 col: 3 : 'tv series' changed to 'tv series'
# row: 846 col: 3 : 'tv series' changed to 'movie'
# row: 107 col: 3 : 'movie' changed to 'tv series'
# row: 1151 col: 3 : 'tv series' changed to 'movie'
# row: 591 col: 3 : 'tv series' changed to 'movie'
# row: 933 col: 3 : 'movie' changed to 'movie'
# row: 1360 col: 3 : 'movie' changed to 'movie'
# row: 698 col: 3 : 'tv series' changed to 'tv series'
# row: 984 col: 3 : 'movie' changed to 'movie'
# row: 1250 col: 3 : 'movie' changed to 'tv series'
# row: 1301 col: 3 : 'movie' changed to 'tv series'
# row: 898 col: 3 : 'movie' changed to 'movie'
# row: 956 col: 3 : 'tv series' changed to 'movie'
# row: 64 col: 3 : 'tv series' changed to 'tv series'
# row: 896 col: 3 : 'movie' changed to ''
# row: 1142 col: 3 : 'tv series' changed to 'tv series'
# row: 460 col: 3 : 'tv series' changed to 'tv series'
# row: 1567 col: 3 : 'movie' changed to 'movie'
# row: 434 col: 3 : 'movie' changed to 'movie'
# row: 1039 col: 3 : 'movie' changed to 'movie'
# row: 33 col: 3 : 'tv series' changed to 'tv series'
# row: 766 col: 3 : 'tv series' changed to 'movie'
# row: 1152 col: 3 : 'tv series' changed to 'movie'
# row: 396 col: 3 : 'movie' changed to 'movie'
# row: 299 col: 3 : 'tv series' changed to 'tv series'
# row: 199 col: 3 : 'movie' changed to 'tv series'
# row: 438 col: 3 : 'movie' changed to 'movie'
# row: 140 col: 3 : 'tv series' changed to 'movie'
# row: 699 col: 3 : 'movie' changed to 'movie'
# row: 1541 col: 3 : 'movie' changed to 'tv series'
# row: 589 col: 3 : 'tv series' changed to 'tv series'
# row: 731 col: 3 : 'movie' changed to 'movie'
# row: 1496 col: 3 : 'movie' changed to 'movie'
# row: 1045 col: 3 : 'tv series' changed to 'tv series'
# row: 1143 col: 3 : 'tv series' changed to 'movie'
# row: 1271 col: 3 : 'movie' changed to 'movie'
# row: 649 col: 3 : 'tv series' changed to 'tv series'
# row: 1459 col: 3 : 'tv series' changed to 'tv series'
# row: 1097 col: 3 : 'movie' changed to 'movie'
# row: 172 col: 3 : 'tv series' changed to 'movie'
# row: 1095 col: 3 : 'tv series' changed to 'tv series'
# row: 1592 col: 3 : 'movie' changed to 'tv series'
# row: 1049 col: 3 : 'tv series' changed to 'tv series'
# row: 90 col: 3 : 'movie' changed to 'tv series'
# row: 1073 col: 3 : 'movie' changed to 'movie'
# row: 275 col: 3 : 'movie' changed to 'movie'
# row: 689 col: 3 : 'movie' changed to 'tv series'
# row: 1269 col: 3 : 'movie' changed to 'movie'
# row: 1417 col: 3 : 'movie' changed to 'tv series'
# row: 104 col: 3 : 'movie' changed to 'tv series'
# row: 744 col: 3 : 'tv series' changed to 'tv series'
# row: 676 col: 3 : 'movie' changed to 'movie'
# row: 955 col: 3 : 'movie' changed to 'movie'
# row: 57 col: 3 : 'tv series' changed to 'movie'
# row: 1030 col: 3 : 'movie' changed to 'tv series'
# row: 1562 col: 3 : 'tv series' changed to 'tv series'
# row: 818 col: 3 : 'movie' changed to 'movie'
# row: 503 col: 3 : 'tv series' changed to 'tv series'
# row: 1245 col: 3 : 'movie' changed to 'tv series'
# row: 1464 col: 3 : 'movie' changed to 'tv series'
# row: 1047 col: 3 : 'tv series' changed to 'movie'
# row: 1484 col: 3 : 'tv series' changed to 'tv series'
# row: 958 col: 3 : 'tv series' changed to 'tv series'
# row: 611 col: 3 : 'tv series' changed to 'movie'
# row: 1185 col: 3 : 'tv series' changed to 'movie'
# row: 284 col: 3 : 'movie' changed to 'tv series'
# row: 443 col: 3 : 'tv series' changed to 'tv series'
# row: 1056 col: 3 : 'tv series' changed to 'movie'
# row: 1347 col: 3 : 'movie' changed to 'movie'
# row: 725 col: 3 : 'tv series' changed to 'tv series'
# row: 83 col: 3 : 'tv series' changed to 'tv series'
# row: 1288 col: 3 : 'tv series' changed to 'movie'
# row: 1203 col: 3 : 'movie' changed to 'movie'
# row: 1092 col: 3 : 'tv series' changed to 'tv series'
# row: 539 col: 3 : 'movie' changed to 'movie'
# row: 374 col: 3 : 'tv series' changed to 'tv series'
# row: 809 col: 3 : 'tv series' changed to 'tv series'
# row: 175 col: 3 : 'tv series' changed to 'tv series'
# row: 364 col: 3 : 'tv series' changed to 'movie'
# row: 740 col: 3 : 'tv series' changed to 'tv series'
# row: 97 col: 3 : 'movie' changed to 'movie'
# row: 1129 col: 3 : 'tv series' changed to 'movie'
# row: 394 col: 3 : 'movie' changed to 'tv series'
# row: 388 col: 3 : 'movie' changed to 'movie'
# row: 623 col: 3 : 'tv series' changed to 'tv series'
# row: 1266 col: 3 : 'movie' changed to 'tv series'
# row: 674 col: 3 : 'movie' changed to 'movie'
# row: 841 col: 3 : 'tv series' changed to 'tv series'
# row: 492 col: 3 : 'tv series' changed to 'tv series'
# row: 1398 col: 3 : 'tv series' changed to 'tv series'
# row: 212 col: 3 : 'movie' changed to 'tv series'
# row: 1448 col: 3 : 'tv series' changed to 'movie'
# row: 291 col: 3 : 'movie' changed to 'movie'
# row: 1518 col: 3 : 'tv series' changed to 'movie'
# row: 481 col: 3 : 'tv series' changed to 'tv series'
# row: 1195 col: 3 : 'tv series' changed to 'movie'
# row: 12 col: 3 : 'movie' changed to 'movie'
# row: 1557 col: 3 : 'movie' changed to 'tv series'
# row: 582 col: 3 : 'movie' changed to 'tv series'
# row: 28 col: 3 : 'tv series' changed to 'movie'
# row: 513 col: 3 : 'movie' changed to 'tv series'
# row: 763 col: 3 : 'tv series' changed to 'tv series'
# row: 105 col: 3 : 'movie' changed to 'movie'
# row: 489 col: 3 : 'movie' changed to 'tv series'
# row: 1565 col: 3 : 'tv series' changed to 'movie'
# row: 971 col: 3 : 'tv series' changed to 'movie'
# row: 1175 col: 3 : 'tv series' changed to 'tv series'
# row: 193 col: 3 : 'tv series' changed to 'movie'
# row: 1176 col: 3 : 'movie' changed to 'movie'
# row: 1024 col: 3 : 'movie' changed to 'tv series'
# row: 1599 col: 3 : 'tv series' changed to 'movie'
# row: 888 col: 3 : 'movie' changed to 'tv series'
# row: 863 col: 3 : 'movie' changed to 'movie'
# row: 821 col: 3 : 'movie' changed to 'tv series'
# row: 579 col: 3 : 'movie' changed to 'tv series'
# row: 1162 col: 3 : 'movie' changed to 'tv series'
# row: 706 col: 3 : 'tv series' changed to 'movie'
# row: 1332 col: 3 : 'movie' changed to 'tv series'
# row: 1570 col: 3 : 'tv series' changed to 'movie'
# row: 1359 col: 3 : 'tv series' changed to 'movie'
# row: 350 col: 3 : 'movie' changed to 'movie'
# row: 637 col: 3 : 'tv series' changed to 'tv series'
# row: 138 col: 3 : 'tv series' changed to 'tv series'
# row: 1153 col: 3 : 'movie' changed to 'tv series'
# row: 1421 col: 3 : 'tv series' changed to 'tv series'
# row: 672 col: 3 : 'tv series' changed to 'movie'
# row: 774 col: 3 : 'tv series' changed to 'movie'
# row: 325 col: 3 : 'tv series' changed to 'tv series'
# row: 508 col: 3 : 'tv series' changed to 'tv series'
# row: 1240 col: 3 : 'tv series' changed to 'tv series'
# row: 198 col: 3 : 'tv series' changed to 'movie'
# row: 1156 col: 3 : 'tv series' changed to 'tv series'
# row: 1591 col: 3 : 'tv series' changed to 'tv series'
# row: 578 col: 3 : 'tv series' changed to 'movie'
# row: 781 col: 3 : 'movie' changed to 'tv series'
# row: 458 col: 3 : 'movie' changed to 'tv series'
# row: 675 col: 3 : 'tv series' changed to 'movie'
# row: 117 col: 3 : 'movie' changed to 'movie'
# row: 79 col: 3 : 'movie' changed to 'tv series'
# row: 1144 col: 3 : 'movie' changed to 'movie'
# row: 25 col: 3 : 'movie' changed to 'tv series'
# row: 439 col: 3 : 'tv series' changed to 'tv series'
# row: 1054 col: 3 : 'tv series' changed to 'tv series'
# row: 1499 col: 3 : 'tv series' changed to 'movie'
# row: 847 col: 3 : 'movie' changed to 'movie'
# row: 856 col: 3 : 'movie' changed to 'movie'
# row: 759 col: 3 : 'tv series' changed to 'movie'
# row: 875 col: 3 : 'movie' changed to 'tv series'
# row: 1519 col: 3 : 'tv series' changed to 'movie'
# row: 379 col: 3 : 'tv series' changed to 'tv series'
# row: 587 col: 3 : 'tv series' changed to 'tv series'
# row: 1106 col: 3 : 'tv series' changed to 'movie'
# row: 909 col: 3 : 'tv series' changed to 'tv series'
# row: 1058 col: 3 : 'tv series' changed to 'tv series'
# row: 82 col: 3 : 'tv series' changed to 'tv series'
# row: 351 col: 3 : 'movie' changed to 'movie'
# row: 180 col: 3 : 'tv series' changed to 'tv series'
# row: 1178 col: 3 : 'movie' changed to 'movie'
# row: 990 col: 3 : 'movie' changed to 'movie'
# row: 1109 col: 3 : 'tv series' changed to 'tv series'
# row: 168 col: 3 : 'tv series' changed to 'movie'
# row: 1135 col: 3 : 'tv series' changed to 'movie'
# row: 1022 col: 3 : 'movie' changed to 'tv series'
# row: 501 col: 3 : 'movie' changed to 'movie'
# row: 1502 col: 3 : 'tv series' changed to 'tv series'
# row: 1516 col: 3 : 'movie' changed to 'tv series'
# row: 245 col: 3 : 'tv series' changed to 'tv series'
# row: 1434 col: 3 : 'movie' changed to 'tv series'
# row: 1211 col: 3 : 'movie' changed to 'tv series'
# row: 524 col: 3 : 'tv series' changed to 'movie'
# row: 1324 col: 3 : 'movie' changed to 'movie'
# row: 295 col: 3 : 'movie' changed to 'tv series'
# row: 655 col: 3 : 'tv series' changed to 'movie'
# row: 1365 col: 3 : 'movie' changed to 'movie'
# row: 895 col: 3 : 'movie' changed to 'tv series'
# row: 780 col: 3 : 'tv series' changed to 'movie'
# row: 1265 col: 3 : 'tv series' changed to 'movie'
# row: 230 col: 3 : 'tv series' changed to 'movie'
# row: 693 col: 3 : 'tv series' changed to 'movie'
# row: 570 col: 3 : 'tv series' changed to 'movie'
# row: 313 col: 3 : 'tv series' changed to 'movie'
# row: 831 col: 3 : 'tv series' changed to 'movie'
# row: 1526 col: 3 : 'tv series' changed to 'tv series'
# row: 1475 col: 3 : 'movie' changed to 'movie'
# row: 685 col: 3 : 'tv series' changed to 'movie'
# row: 461 col: 3 : 'tv series' changed to 'movie'
# row: 993 col: 3 : 'tv series' changed to 'tv series'
# row: 1479 col: 3 : 'movie' changed to 'tv series'
# row: 1405 col: 3 : 'movie' changed to 'tv series'
# row: 1198 col: 3 : 'movie' changed to 'movie'
# row: 919 col: 3 : 'tv series' changed to 'movie'
# row: 43 col: 3 : 'movie' changed to 'movie'
# row: 286 col: 3 : 'tv series' changed to 'tv series'
# row: 1077 col: 3 : 'tv series' changed to 'movie'
# row: 451 col: 3 : 'movie' changed to 'tv series'
# row: 8 col: 3 : 'movie' changed to 'movie'
# row: 735 col: 3 : 'tv series' changed to 'movie'
# row: 271 col: 3 : 'movie' changed to 'movie'
# row: 345 col: 3 : 'movie' changed to 'movie'
# row: 219 col: 3 : 'movie' changed to 'tv series'
# row: 413 col: 3 : 'tv series' changed to 'movie'
# row: 189 col: 3 : 'movie' changed to 'movie'
# row: 1488 col: 3 : 'movie' changed to 'tv series'
# row: 440 col: 3 : 'tv series' changed to 'movie'
# row: 789 col: 3 : 'movie' changed to 'movie'
# row: 1094 col: 3 : 'tv series' changed to 'tv series'
# row: 764 col: 3 : 'tv series' changed to 'movie'
# row: 1510 col: 3 : 'movie' changed to 'tv series'
# row: 9 col: 3 : 'tv series' changed to 'movie'
# row: 1081 col: 3 : 'tv series' changed to 'tv series'
# row: 1560 col: 3 : 'tv series' changed to 'tv series'
# row: 874 col: 3 : 'movie' changed to 'tv series'
# row: 1598 col: 3 : 'tv series' changed to 'tv series'
# row: 1377 col: 3 : 'movie' changed to 'movie'
# row: 1408 col: 3 : 'movie' changed to 'movie'
# row: 1469 col: 3 : 'tv series' changed to 'tv series'
# row: 1108 col: 3 : 'movie' changed to 'movie'
# row: 832 col: 3 : 'tv series' changed to 'movie'
# row: 692 col: 3 : 'movie' changed to 'tv series'
# row: 547 col: 3 : 'tv series' changed to 'movie'
# row: 1361 col: 3 : 'movie' changed to 'movie'
# row: 925 col: 3 : 'tv series' changed to 'movie'
# row: 1522 col: 3 : 'tv series' changed to 'movie'
# row: 705 col: 3 : 'tv series' changed to 'tv series'
# row: 1165 col: 3 : 'tv series' changed to 'movie'
# row: 854 col: 3 : 'movie' changed to 'tv series'
# row: 1561 col: 3 : 'tv series' changed to 'movie'
# row: 1122 col: 3 : 'tv series' changed to 'tv series'
# row: 1034 col: 3 : 'tv series' changed to 'tv series'
# row: 810 col: 3 : 'tv series' changed to 'tv series'
# row: 1259 col: 3 : 'movie' changed to 'movie'
# row: 964 col: 3 : 'tv series' changed to 'movie'
# row: 509 col: 3 : 'movie' changed to 'tv series'
# row: 417 col: 3 : 'tv series' changed to 'tv series'
# row: 65 col: 3 : 'movie' changed to 'tv series'
# row: 1025 col: 3 : 'tv series' changed to 'tv series'
# row: 1320 col: 3 : 'movie' changed to 'movie'
# row: 54 col: 3 : 'movie' changed to 'movie'
# row: 1212 col: 3 : 'movie' changed to 'movie'
# row: 966 col: 3 : 'tv series' changed to 'movie'
# row: 1527 col: 3 : 'movie' changed to 'tv series'
# row: 834 col: 3 : 'movie' changed to ''
# row: 1540 col: 3 : 'movie' changed to 'tv series'
# row: 739 col: 3 : 'tv series' changed to 'tv series'
# row: 371 col: 3 : 'tv series' changed to 'movie'
# row: 565 col: 3 : 'tv series' changed to 'tv series'
# row: 150 col: 3 : 'movie' changed to 'movie'
# row: 488 col: 3 : 'movie' changed to 'movie'
# row: 1192 col: 3 : 'tv series' changed to 'movie'
# row: 454 col: 3 : 'movie' changed to 'tv series'
# row: 264 col: 3 : 'movie' changed to 'tv series'
# row: 1258 col: 3 : 'movie' changed to 'tv series'
# row: 512 col: 3 : 'tv series' changed to 'tv series'
# row: 887 col: 3 : 'movie' changed to 'movie'
# row: 435 col: 3 : 'movie' changed to 'movie'
# row: 624 col: 3 : 'tv series' changed to 'movie'
# row: 1456 col: 3 : 'tv series' changed to 'tv series'
# row: 339 col: 3 : 'movie' changed to 'movie'
# row: 682 col: 3 : 'movie' changed to 'tv series'
# row: 482 col: 3 : 'movie' changed to 'movie'
# row: 463 col: 3 : 'movie' changed to 'tv series'
# row: 517 col: 3 : 'movie' changed to 'movie'
# row: 272 col: 3 : 'movie' changed to 'movie'
# row: 1348 col: 3 : 'tv series' changed to 'tv series'
# row: 626 col: 3 : 'tv series' changed to 'movie'
# row: 748 col: 3 : 'movie' changed to 'movie'
# row: 865 col: 3 : 'movie' changed to 'tv series'
# row: 1145 col: 3 : 'movie' changed to 'tv series'
# row: 265 col: 3 : 'movie' changed to 'tv series'
# row: 1229 col: 3 : 'tv series' changed to 'tv series'
# row: 355 col: 3 : 'movie' changed to 'movie'
# row: 927 col: 3 : 'movie' changed to 'tv series'
# row: 988 col: 3 : 'tv series' changed to 'tv series'
# row: 372 col: 3 : 'tv series' changed to 'movie'
# row: 349 col: 3 : 'movie' changed to 'tv series'
# row: 431 col: 3 : 'tv series' changed to 'tv series'
# row: 137 col: 3 : 'movie' changed to 'movie'
# row: 1416 col: 3 : 'tv series' changed to 'tv series'
# row: 677 col: 3 : 'tv series' changed to 'tv series'
# row: 504 col: 3 : 'tv series' changed to 'movie'
# row: 540 col: 3 : 'movie' changed to 'movie'
# row: 1179 col: 3 : 'movie' changed to 'movie'
# row: 157 col: 3 : 'tv series' changed to 'tv series'
# row: 647 col: 3 : 'tv series' changed to 'movie'
# row: 1411 col: 3 : 'tv series' changed to 'tv series'
# row: 1196 col: 3 : 'tv series' changed to 'movie'
# row: 1177 col: 3 : 'movie' changed to 'tv series'
# row: 214 col: 3 : 'tv series' changed to 'tv series'
# row: 226 col: 3 : 'movie' changed to 'tv series'
# row: 691 col: 3 : 'movie' changed to 'tv series'
# row: 362 col: 3 : 'movie' changed to 'tv series'
# row: 1429 col: 3 : 'movie' changed to 'movie'
# row: 1249 col: 3 : 'tv series' changed to 'tv series'
# row: 41 col: 3 : 'tv series' changed to 'movie'
# row: 16 col: 3 : 'movie' changed to 'tv series'
# row: 765 col: 3 : 'tv series' changed to 'tv series'
# row: 982 col: 3 : 'movie' changed to 'movie'
# row: 1088 col: 3 : 'tv series' changed to 'movie'
# row: 1248 col: 3 : 'tv series' changed to 'movie'
# row: 194 col: 3 : 'movie' changed to 'movie'
# row: 127 col: 3 : 'movie' changed to 'tv series'
# row: 324 col: 3 : 'movie' changed to 'tv series'
# row: 884 col: 3 : 'movie' changed to ''
# row: 1380 col: 3 : 'movie' changed to 'tv series'
# row: 1221 col: 3 : 'movie' changed to 'tv series'
# row: 1371 col: 3 : 'tv series' changed to 'movie'
# row: 27 col: 3 : 'tv series' changed to 'movie'
# row: 1529 col: 3 : 'movie' changed to 'movie'
# row: 1040 col: 3 : 'tv series' changed to 'movie'
# row: 1123 col: 3 : 'movie' changed to 'tv series'
# row: 1566 col: 3 : 'tv series' changed to 'movie'
# row: 548 col: 3 : 'movie' changed to 'movie'
# row: 549 col: 3 : 'tv series' changed to 'movie'
# row: 498 col: 3 : 'movie' changed to 'movie'
# row: 470 col: 3 : 'tv series' changed to 'tv series'
# row: 1141 col: 3 : 'tv series' changed to 'tv series'
# row: 1159 col: 3 : 'movie' changed to 'tv series'
# row: 1233 col: 3 : 'tv series' changed to 'tv series'
# row: 916 col: 3 : 'movie' changed to 'movie'
# row: 179 col: 3 : 'movie' changed to 'tv series'
# row: 385 col: 3 : 'tv series' changed to 'movie'
# row: 946 col: 3 : 'tv series' changed to 'movie'
# row: 1586 col: 3 : 'tv series' changed to 'movie'
# row: 1443 col: 3 : 'movie' changed to 'movie'
# row: 45 col: 3 : 'tv series' changed to 'movie'
# row: 178 col: 3 : 'movie' changed to 'tv series'
# row: 704 col: 3 : 'tv series' changed to 'tv series'
# row: 1201 col: 3 : 'tv series' changed to 'movie'
# row: 707 col: 3 : 'movie' changed to 'tv series'
# row: 1010 col: 3 : 'tv series' changed to 'movie'
# row: 804 col: 3 : 'tv series' changed to 'movie'
# row: 390 col: 3 : 'tv series' changed to 'tv series'
# row: 266 col: 3 : 'movie' changed to 'movie'
# row: 1481 col: 3 : 'tv series' changed to 'movie'
# row: 1355 col: 3 : 'movie' changed to 'movie'
# row: 1322 col: 3 : 'tv series' changed to 'movie'
# row: 977 col: 3 : 'tv series' changed to 'movie'
# row: 833 col: 3 : 'movie' changed to 'tv series'
# row: 148 col: 3 : 'tv series' changed to 'movie'
# row: 1452 col: 3 : 'tv series' changed to 'movie'
# row: 567 col: 3 : 'movie' changed to 'movie'
# row: 1118 col: 3 : 'tv series' changed to 'tv series'
# row: 1366 col: 3 : 'tv series' changed to 'tv series'
# row: 1101 col: 3 : 'tv series' changed to 'movie'
# row: 131 col: 3 : 'movie' changed to 'tv series'
# row: 1093 col: 3 : 'movie' changed to 'tv series'
# row: 688 col: 3 : 'tv series' changed to 'movie'
# row: 1193 col: 3 : 'tv series' changed to 'movie'
# row: 281 col: 3 : 'movie' changed to 'tv series'
# row: 315 col: 3 : 'tv series' changed to 'tv series'
# row: 979 col: 3 : 'tv series' changed to 'tv series'
# row: 1367 col: 3 : 'movie' changed to 'tv series'
# row: 872 col: 3 : 'tv series' changed to 'tv series'
# row: 363 col: 3 : 'movie' changed to 'movie'
# row: 968 col: 3 : 'tv series' changed to 'movie'
# row: 437 col: 3 : 'movie' changed to 'tv series'
# row: 1002 col: 3 : 'movie' changed to 'movie'
# row: 605 col: 3 : 'tv series' changed to 'movie'
# row: 645 col: 3 : 'movie' changed to 'movie'
# row: 1395 col: 3 : 'movie' changed to 'tv series'
# row: 1382 col: 3 : 'tv series' changed to 'tv series'
# row: 1012 col: 3 : 'tv series' changed to 'tv series'
# row: 1295 col: 3 : 'movie' changed to 'tv series'
# row: 128 col: 3 : 'tv series' changed to 'tv series'
# row: 1489 col: 3 : 'tv series' changed to ''
# row: 1468 col: 3 : 'movie' changed to 'movie'
# row: 1044 col: 3 : 'movie' changed to 'tv series'
# row: 1275 col: 3 : 'movie' changed to 'tv series'
# row: 253 col: 3 : 'movie' changed to 'movie'
# row: 94 col: 3 : 'tv series' changed to 'movie'
# row: 754 col: 3 : 'tv series' changed to 'tv series'
# row: 156 col: 3 : 'movie' changed to 'movie'
# row: 1111 col: 3 : 'tv series' changed to 'movie'
# row: 864 col: 3 : 'tv series' changed to 'tv series'
# row: 1579 col: 3 : 'movie' changed to 'movie'
# row: 824 col: 3 : 'movie' changed to 'movie'
# row: 1403 col: 3 : 'tv series' changed to 'movie'
# row: 108 col: 3 : 'movie' changed to 'movie'
# row: 377 col: 3 : 'tv series' changed to 'movie'
# row: 486 col: 3 : 'movie' changed to 'tv series'
# row: 1406 col: 3 : 'movie' changed to 'movie'
# row: 848 col: 3 : 'movie' changed to 'movie'
# row: 1521 col: 3 : 'tv series' changed to 'tv series'
# row: 975 col: 3 : 'movie' changed to 'tv series'
# row: 720 col: 3 : 'movie' changed to 'movie'
# row: 505 col: 3 : 'movie' changed to ''
# row: 398 col: 3 : 'movie' changed to 'tv series'
# row: 123 col: 3 : 'tv series' changed to 'tv series'
# row: 1190 col: 3 : 'tv series' changed to 'movie'
# row: 73 col: 3 : 'tv series' changed to 'tv series'
# row: 285 col: 3 : 'movie' changed to 'movie'
# row: 1478 col: 3 : 'tv series' changed to 'movie'
# row: 696 col: 3 : 'tv series' changed to 'movie'
# row: 643 col: 3 : 'tv series' changed to 'tv series'
# row: 400 col: 3 : 'tv series' changed to 'movie'
# row: 1490 col: 3 : 'movie' changed to 'movie'
# row: 42 col: 3 : 'tv series' changed to 'tv series'
# row: 450 col: 3 : 'movie' changed to 'movie'
# row: 1052 col: 3 : 'movie' changed to ''
# row: 456 col: 3 : 'movie' changed to 'movie'
# row: 1038 col: 3 : 'movie' changed to 'tv series'
# row: 651 col: 3 : 'tv series' changed to 'movie'
# row: 244 col: 3 : 'movie' changed to 'tv series'
# row: 1273 col: 3 : 'tv series' changed to 'movie'
# row: 1393 col: 3 : 'tv series' changed to 'tv series'
# row: 6 col: 3 : 'movie' changed to 'movie'
# row: 1336 col: 3 : 'tv series' changed to 'tv series'
# row: 412 col: 3 : 'movie' changed to 'tv series'
# row: 84 col: 3 : 'movie' changed to 'tv series'
# row: 1276 col: 3 : 'tv series' changed to 'tv series'
# row: 1556 col: 3 : 'movie' changed to 'tv series'
# row: 886 col: 3 : 'tv series' changed to 'tv series'
# row: 1498 col: 3 : 'movie' changed to 'movie'
# row: 1315 col: 3 : 'movie' changed to 'tv series'
# row: 1072 col: 3 : 'tv series' changed to 'movie'
# row: 21 col: 3 : 'movie' changed to ''
# row: 408 col: 3 : 'movie' changed to 'movie'
# row: 1076 col: 3 : 'tv series' changed to 'movie'
# row: 1219 col: 3 : 'tv series' changed to 'tv series'
# row: 944 col: 3 : 'tv series' changed to 'tv series'
# row: 554 col: 3 : 'tv series' changed to 'movie'
# row: 972 col: 3 : 'tv series' changed to 'movie'
# row: 373 col: 3 : 'movie' changed to 'tv series'
# row: 801 col: 3 : 'tv series' changed to 'movie'
# row: 1353 col: 3 : 'movie' changed to 'movie'
# row: 465 col: 3 : 'tv series' changed to 'tv series'
# row: 634 col: 3 : 'movie' changed to 'movie'
# row: 478 col: 3 : 'movie' changed to 'tv series'
# row: 778 col: 3 : 'tv series' changed to 'movie'
# row: 900 col: 3 : 'movie' changed to 'movie'
# row: 1169 col: 3 : 'movie' changed to 'tv series'
# row: 903 col: 3 : 'movie' changed to 'tv series'
# row: 263 col: 3 : 'movie' changed to 'tv series'
# row: 1236 col: 3 : 'movie' changed to 'tv series'
# row: 308 col: 3 : 'movie' changed to 'movie'
# row: 288 col: 3 : 'tv series' changed to 'tv series'
# row: 633 col: 3 : 'movie' changed to 'movie'
# row: 1048 col: 3 : 'tv series' changed to 'movie'
# row: 957 col: 3 : 'movie' changed to 'tv series'
# row: 855 col: 3 : 'tv series' changed to 'movie'
# row: 702 col: 3 : 'movie' changed to 'movie'
# row: 1224 col: 3 : 'movie' changed to 'movie'
# row: 433 col: 3 : 'movie' changed to 'movie'
# row: 1447 col: 3 : 'tv series' changed to 'movie'
# row: 386 col: 3 : 'tv series' changed to 'tv series'
# row: 135 col: 3 : 'movie' changed to 'movie'
# row: 223 col: 3 : 'tv series' changed to 'movie'
# row: 1043 col: 3 : 'movie' changed to 'tv series'
# row: 727 col: 3 : 'tv series' changed to 'tv series'
# row: 118 col: 3 : 'tv series' changed to 'tv series'
# row: 464 col: 3 : 'tv series' changed to 'movie'
# row: 50 col: 3 : 'tv series' changed to 'tv series'
# row: 155 col: 3 : 'movie' changed to 'tv series'
# row: 1172 col: 3 : 'tv series' changed to 'tv series'
# row: 1392 col: 3 : 'movie' changed to 'movie'
# row: 415 col: 3 : 'tv series' changed to 'movie'
# row: 1455 col: 3 : 'tv series' changed to 'tv series'
# row: 609 col: 3 : 'tv series' changed to 'movie'
# row: 39 col: 3 : 'tv series' changed to 'tv series'
# row: 307 col: 3 : 'movie' changed to 'tv series'
# row: 85 col: 3 : 'movie' changed to 'tv series'
# row: 1418 col: 3 : 'movie' changed to 'tv series'
# row: 1150 col: 3 : 'movie' changed to 'tv series'
# row: 845 col: 3 : 'movie' changed to 'tv series'
# row: 1509 col: 3 : 'tv series' changed to 'tv series'
# row: 1384 col: 3 : 'movie' changed to 'movie'
# row: 1401 col: 3 : 'tv series' changed to 'tv series'
# row: 569 col: 3 : 'tv series' changed to ''
# row: 695 col: 3 : 'tv series' changed to 'tv series'
# row: 204 col: 3 : 'tv series' changed to 'movie'
# row: 1037 col: 3 : 'tv series' changed to 'movie'
# row: 1296 col: 3 : 'movie' changed to 'tv series'
# row: 610 col: 3 : 'movie' changed to 'movie'
# row: 733 col: 3 : 'tv series' changed to 'tv series'
# row: 1340 col: 3 : 'tv series' changed to 'tv series'
# row: 830 col: 3 : 'movie' changed to 'tv series'
# row: 1342 col: 3 : 'movie' changed to 'tv series'
# row: 712 col: 3 : 'movie' changed to 'movie'
# row: 446 col: 3 : 'tv series' changed to 'movie'
# row: 74 col: 3 : 'tv series' changed to 'tv series'
# row: 544 col: 3 : 'movie' changed to 'movie'
# row: 26 col: 3 : 'movie' changed to ''
# row: 770 col: 3 : 'movie' changed to 'tv series'
# row: 1494 col: 3 : 'tv series' changed to 'tv series'
# row: 383 col: 3 : 'tv series' changed to 'movie'
# row: 162 col: 3 : 'movie' changed to 'tv series'
# row: 53 col: 3 : 'tv series' changed to 'movie'
# row: 280 col: 3 : 'tv series' changed to 'tv series'
# row: 177 col: 3 : 'movie' changed to 'movie'
# row: 1139 col: 3 : 'movie' changed to 'movie'
# row: 939 col: 3 : 'movie' changed to 'movie'
# row: 648 col: 3 : 'tv series' changed to 'movie'
# row: 666 col: 3 : 'movie' changed to 'movie'
# row: 227 col: 3 : 'movie' changed to 'movie'
# row: 642 col: 3 : 'tv series' changed to 'movie'
# row: 1020 col: 3 : 'movie' changed to 'tv series'
# row: 410 col: 3 : 'movie' changed to 'tv series'
# row: 535 col: 3 : 'movie' changed to 'movie'
# row: 1500 col: 3 : 'movie' changed to 'tv series'
# row: 1387 col: 3 : 'movie' changed to 'tv series'
# row: 93 col: 3 : 'tv series' changed to 'tv series'
# row: 694 col: 3 : 'tv series' changed to 'tv series'
# row: 873 col: 3 : 'movie' changed to 'movie'
# row: 973 col: 3 : 'movie' changed to 'tv series'
# row: 166 col: 3 : 'movie' changed to 'tv series'
# row: 268 col: 3 : 'tv series' changed to 'tv series'
# row: 625 col: 3 : 'movie' changed to 'movie'
# row: 401 col: 3 : 'movie' changed to 'movie'
# row: 641 col: 3 : 'movie' changed to 'movie'
# row: 289 col: 3 : 'movie' changed to 'tv series'
# row: 312 col: 3 : 'movie' changed to 'tv series'
# row: 755 col: 3 : 'movie' changed to 'movie'
# row: 1474 col: 3 : 'tv series' changed to 'movie'
# row: 294 col: 3 : 'tv series' changed to 'tv series'
# row: 132 col: 3 : 'tv series' changed to 'movie'
# row: 243 col: 3 : 'tv series' changed to 'tv series'
# row: 986 col: 3 : 'tv series' changed to 'tv series'
# row: 1291 col: 3 : 'movie' changed to 'tv series'
# row: 597 col: 3 : 'tv series' changed to 'movie'
# row: 187 col: 3 : 'movie' changed to 'tv series'
# row: 238 col: 3 : 'tv series' changed to 'tv series'
# row: 734 col: 3 : 'movie' changed to 'movie'
# row: 1373 col: 3 : 'movie' changed to 'tv series'
# row: 321 col: 3 : 'tv series' changed to 'movie'
# row: 382 col: 3 : 'movie' changed to 'movie'
# row: 1074 col: 3 : 'movie' changed to 'movie'
# row: 341 col: 3 : 'tv series' changed to 'tv series'
# row: 557 col: 3 : 'tv series' changed to 'tv series'
# row: 599 col: 3 : 'tv series' changed to 'movie'
# row: 1517 col: 3 : 'movie' changed to 'tv series'
# row: 1033 col: 3 : 'movie' changed to 'movie'
# row: 196 col: 3 : 'movie' changed to 'movie'
# row: 857 col: 3 : 'movie' changed to 'tv series'
# row: 10 col: 3 : 'tv series' changed to 'movie'
# row: 1595 col: 3 : 'movie' changed to 'tv series'
# row: 163 col: 3 : 'tv series' changed to 'tv series'
# row: 332 col: 3 : 'tv series' changed to 'tv series'
# row: 1563 col: 3 : 'movie' changed to 'movie'
# row: 322 col: 3 : 'tv series' changed to 'movie'
# row: 621 col: 3 : 'movie' changed to 'tv series'
# row: 55 col: 3 : 'movie' changed to 'movie'
# row: 627 col: 3 : 'tv series' changed to 'tv series'
# row: 1125 col: 3 : 'tv series' changed to 'tv series'
# row: 296 col: 3 : 'movie' changed to 'movie'
# row: 1430 col: 3 : 'tv series' changed to 'tv series'
# row: 1104 col: 3 : 'movie' changed to 'tv series'
# row: 240 col: 3 : 'tv series' changed to 'tv series'
# row: 269 col: 3 : 'movie' changed to 'movie'
# row: 141 col: 3 : 'tv series' changed to 'tv series'
# row: 257 col: 3 : 'tv series' changed to 'movie'
# row: 1227 col: 3 : 'movie' changed to 'tv series'
# row: 1559 col: 3 : 'movie' changed to 'tv series'
# row: 300 col: 3 : 'tv series' changed to 'tv series'
# row: 1492 col: 3 : 'tv series' changed to 'tv series'
# row: 1243 col: 3 : 'tv series' changed to 'tv series'
# row: 671 col: 3 : 'tv series' changed to 'movie'
# row: 1251 col: 3 : 'movie' changed to 'movie'
# row: 590 col: 3 : 'movie' changed to 'movie'
# row: 1501 col: 3 : 'movie' changed to 'tv series'
# row: 1078 col: 3 : 'movie' changed to 'tv series'
# row: 1304 col: 3 : 'movie' changed to 'tv series'
# row: 529 col: 3 : 'tv series' changed to 'movie'
# row: 870 col: 3 : 'tv series' changed to 'movie'
# row: 445 col: 3 : 'tv series' changed to 'tv series'
# row: 947 col: 3 : 'tv series' changed to 'tv series'
# row: 1279 col: 3 : 'tv series' changed to 'movie'
# row: 18 col: 3 : 'movie' changed to 'tv series'
# row: 885 col: 3 : 'movie' changed to 'movie'
# row: 1114 col: 3 : 'tv series' changed to 'tv series'
# row: 1483 col: 3 : 'movie' changed to 'movie'
# row: 1379 col: 3 : 'movie' changed to 'tv series'
# row: 533 col: 3 : 'tv series' changed to 'tv series'
# row: 249 col: 3 : 'movie' changed to 'tv series'
# row: 378 col: 3 : 'movie' changed to 'tv series'
# row: 997 col: 3 : 'movie' changed to 'tv series'
# row: 220 col: 3 : 'tv series' changed to 'tv series'
# row: 103 col: 3 : 'movie' changed to 'tv series'
# row: 1285 col: 3 : 'movie' changed to 'tv series'
# row: 1306 col: 3 : 'movie' changed to 'movie'
# row: 1574 col: 3 : 'tv series' changed to 'tv series'
# row: 769 col: 3 : 'movie' changed to 'tv series'
# row: 967 col: 3 : 'movie' changed to 'tv series'
# row: 232 col: 3 : 'movie' changed to 'tv series'
# row: 902 col: 3 : 'tv series' changed to 'movie'
# row: 632 col: 3 : 'movie' changed to 'tv series'
# row: 251 col: 3 : 'movie' changed to 'movie'
# row: 1471 col: 3 : 'movie' changed to 'tv series'
# row: 883 col: 3 : 'movie' changed to 'movie'
# row: 161 col: 3 : 'movie' changed to 'tv series'
# row: 395 col: 3 : 'movie' changed to 'tv series'
# row: 310 col: 3 : 'tv series' changed to 'tv series'
# row: 1035 col: 3 : 'tv series' changed to 'tv series'
# row: 1399 col: 3 : 'movie' changed to 'movie'
# row: 192 col: 3 : 'movie' changed to 'tv series'
# row: 1163 col: 3 : 'tv series' changed to 'tv series'
# row: 121 col: 3 : 'movie' changed to 'tv series'
# row: 703 col: 3 : 'tv series' changed to 'movie'
# row: 1497 col: 3 : 'movie' changed to 'movie'
# row: 233 col: 3 : 'movie' changed to 'movie'
# row: 282 col: 3 : 'movie' changed to 'tv series'
# row: 1189 col: 3 : 'movie' changed to 'movie'
# row: 476 col: 3 : 'movie' changed to 'tv series'
# row: 1021 col: 3 : 'tv series' changed to 'tv series'
# row: 721 col: 3 : 'movie' changed to 'movie'
# row: 365 col: 3 : 'tv series' changed to 'movie'
# row: 75 col: 3 : 'tv series' changed to 'movie'
# row: 606 col: 3 : 'tv series' changed to 'tv series'
# row: 1590 col: 3 : 'movie' changed to 'movie'
# row: 792 col: 3 : 'movie' changed to 'movie'
# row: 798 col: 3 : 'movie' changed to 'movie'
# row: 190 col: 3 : 'movie' changed to 'tv series'
# row: 800 col: 3 : 'movie' changed to 'tv series'
# row: 1573 col: 3 : 'tv series' changed to 'tv series'
# row: 1260 col: 3 : 'tv series' changed to 'tv series'
# row: 991 col: 3 : 'movie' changed to 'tv series'
# row: 1345 col: 3 : 'movie' changed to ''
# row: 1528 col: 3 : 'tv series' changed to 'tv series'
# row: 215 col: 3 : 'movie' changed to 'tv series'
# row: 1003 col: 3 : 'tv series' changed to 'tv series'
# row: 340 col: 3 : 'tv series' changed to 'movie'
# row: 1232 col: 3 : 'movie' changed to 'movie'
# row: 1426 col: 3 : 'movie' changed to 'movie'
# row: 58 col: 3 : 'movie' changed to 'tv series'
# row: 256 col: 3 : 'movie' changed to 'movie'
# row: 487 col: 3 : 'tv series' changed to 'movie'
# row: 876 col: 3 : 'tv series' changed to 'movie'
# row: 1372 col: 3 : 'tv series' changed to 'tv series'
# row: 716 col: 3 : 'movie' changed to 'tv series'
# row: 126 col: 3 : 'tv series' changed to 'tv series'
# row: 319 col: 3 : 'movie' changed to 'movie'
# row: 1597 col: 3 : 'movie' changed to 'movie'
# row: 1358 col: 3 : 'movie' changed to 'tv series'
# row: 1571 col: 3 : 'movie' changed to 'movie'
# row: 491 col: 3 : 'tv series' changed to ''
# row: 1533 col: 3 : 'tv series' changed to 'movie'
# row: 1280 col: 3 : 'tv series' changed to 'tv series'
# row: 940 col: 3 : 'tv series' changed to 'tv series'
# row: 1261 col: 3 : 'movie' changed to 'movie'
# row: 15 col: 3 : 'tv series' changed to 'tv series'
# row: 35 col: 3 : 'movie' changed to 'tv series'
# row: 231 col: 3 : 'tv series' changed to 'tv series'
# row: 1538 col: 3 : 'movie' changed to 'movie'
# row: 61 col: 3 : 'movie' changed to 'tv series'
# row: 1046 col: 3 : 'tv series' changed to 'movie'
# row: 616 col: 3 : 'tv series' changed to 'movie'
# row: 998 col: 3 : 'movie' changed to 'movie'
# row: 580 col: 3 : 'tv series' changed to 'movie'
# row: 538 col: 3 : 'tv series' changed to 'movie'
# row: 36 col: 3 : 'movie' changed to 'tv series'
# row: 1451 col: 3 : 'movie' changed to 'movie'
# row: 922 col: 3 : 'movie' changed to 'movie'
# row: 239 col: 3 : 'movie' changed to 'movie'
# row: 722 col: 3 : 'movie' changed to 'tv series'
# row: 1070 col: 3 : 'movie' changed to 'movie'
# row: 835 col: 3 : 'tv series' changed to 'tv series'
# row: 468 col: 3 : 'tv series' changed to 'movie'
# row: 111 col: 3 : 'tv series' changed to 'movie'
# row: 1318 col: 3 : 'tv series' changed to 'movie'
# row: 152 col: 3 : 'tv series' changed to 'tv series'
# row: 1188 col: 3 : 'movie' changed to 'movie'
# row: 1013 col: 3 : 'movie' changed to 'movie'
# row: 728 col: 3 : 'tv series' changed to 'tv series'
# row: 767 col: 3 : 'tv series' changed to 'tv series'
# row: 575 col: 3 : 'movie' changed to 'movie'
# row: 1023 col: 3 : 'tv series' changed to 'tv series'
# row: 91 col: 3 : 'tv series' changed to 'tv series'
# row: 452 col: 3 : 'tv series' changed to 'movie'
# row: 1419 col: 3 : 'movie' changed to 'movie'
# row: 159 col: 3 : 'tv series' changed to 'movie'
# row: 1493 col: 3 : 'movie' changed to 'tv series'
# row: 534 col: 3 : 'tv series' changed to 'movie'
# row: 1558 col: 3 : 'tv series' changed to 'tv series'
# row: 1278 col: 3 : 'tv series' changed to 'tv series'
# row: 1293 col: 3 : 'movie' changed to 'tv series'
# row: 1170 col: 3 : 'movie' changed to 'movie'
# row: 510 col: 3 : 'movie' changed to 'tv series'
# row: 120 col: 3 : 'tv series' changed to 'movie'
# row: 1059 col: 3 : 'tv series' changed to 'movie'
# row: 301 col: 3 : 'movie' changed to 'tv series'
# row: 248 col: 3 : 'tv series' changed to 'tv series'
# row: 574 col: 3 : 'movie' changed to 'movie'
# row: 1388 col: 3 : 'tv series' changed to 'movie'
# row: 202 col: 3 : 'tv series' changed to 'tv series'
# row: 136 col: 3 : 'tv series' changed to 'tv series'
# row: 663 col: 3 : 'movie' changed to 'tv series'
# row: 1254 col: 3 : 'tv series' changed to 'tv series'
# row: 1231 col: 3 : 'tv series' changed to 'tv series'
# row: 356 col: 3 : 'tv series' changed to 'movie'
# row: 1504 col: 3 : 'movie' changed to 'movie'
# row: 1317 col: 3 : 'movie' changed to 'tv series'
# row: 72 col: 3 : 'tv series' changed to 'tv series'
# row: 970 col: 3 : 'tv series' changed to 'movie'
# row: 225 col: 3 : 'movie' changed to 'movie'
# row: 1578 col: 3 : 'tv series' changed to 'tv series'
# row: 255 col: 3 : 'tv series' changed to 'movie'
# row: 1576 col: 3 : 'tv series' changed to 'tv series'
# row: 330 col: 3 : 'tv series' changed to 'movie'
# row: 336 col: 3 : 'movie' changed to 'movie'
# row: 1530 col: 3 : 'movie' changed to 'tv series'
# row: 221 col: 3 : 'tv series' changed to 'tv series'
# row: 1209 col: 3 : 'movie' changed to 'tv series'
# row: 602 col: 3 : 'movie' changed to 'movie'
# row: 906 col: 3 : 'tv series' changed to 'tv series'
# row: 783 col: 3 : 'tv series' changed to 'movie'
# row: 402 col: 3 : 'tv series' changed to 'movie'
# row: 444 col: 3 : 'movie' changed to 'tv series'
# row: 639 col: 3 : 'tv series' changed to 'tv series'
# row: 51 col: 3 : 'movie' changed to 'movie'
# row: 664 col: 3 : 'tv series' changed to 'movie'
# row: 653 col: 3 : 'tv series' changed to 'tv series'
# row: 1458 col: 3 : 'movie' changed to 'movie'
# row: 1439 col: 3 : 'movie' changed to 'tv series'
# row: 1202 col: 3 : 'movie' changed to 'movie'
# row: 558 col: 3 : 'tv series' changed to 'movie'
# row: 326 col: 3 : 'tv series' changed to 'movie'
# row: 823 col: 3 : 'movie' changed to 'movie'
# row: 787 col: 3 : 'tv series' changed to 'tv series'
# row: 1299 col: 3 : 'tv series' changed to 'movie'
# row: 1180 col: 3 : 'movie' changed to 'tv series'
# row: 387 col: 3 : 'movie' changed to 'movie'
# row: 1437 col: 3 : 'tv series' changed to 'tv series'
# row: 1215 col: 3 : 'tv series' changed to 'movie'
# row: 1375 col: 3 : 'movie' changed to 'tv series'
# row: 1238 col: 3 : 'movie' changed to 'tv series'
# row: 1132 col: 3 : 'movie' changed to 'movie'
# row: 92 col: 3 : 'tv series' changed to 'movie'
# row: 1055 col: 3 : 'movie' changed to 'movie'
# row: 880 col: 3 : 'tv series' changed to 'movie'
# row: 70 col: 3 : 'tv series' changed to 'tv series'
# row: 473 col: 3 : 'tv series' changed to 'tv series'
# row: 1463 col: 3 : 'movie' changed to 'movie'
# row: 953 col: 3 : 'movie' changed to 'tv series'
# row: 838 col: 3 : 'tv series' changed to 'tv series'
# row: 449 col: 3 : 'tv series' changed to 'movie'
# row: 184 col: 3 : 'movie' changed to 'movie'
# row: 455 col: 3 : 'tv series' changed to 'movie'
# row: 430 col: 3 : 'tv series' changed to 'tv series'
# row: 1247 col: 3 : 'movie' changed to 'tv series'
# row: 951 col: 3 : 'tv series' changed to 'tv series'
# row: 812 col: 3 : 'movie' changed to 'tv series'
# row: 119 col: 3 : 'movie' changed to 'movie'
# row: 737 col: 3 : 'movie' changed to 'tv series'
# row: 768 col: 3 : 'tv series' changed to 'movie'
# row: 1160 col: 3 : 'tv series' changed to 'movie'
# row: 277 col: 3 : 'tv series' changed to 'tv series'
# row: 585 col: 3 : 'tv series' changed to 'tv series'
# row: 608 col: 3 : 'movie' changed to 'tv series'
# row: 462 col: 3 : 'movie' changed to 'tv series'
# row: 1283 col: 3 : 'tv series' changed to 'tv series'
# row: 466 col: 3 : 'movie' changed to 'tv series'
# row: 1550 col: 3 : 'movie' changed to 'movie'
# row: 806 col: 3 : 'movie' changed to 'tv series'
# row: 1423 col: 3 : 'movie' changed to 'tv series'
# row: 551 col: 3 : 'tv series' changed to 'tv series'
# row: 1433 col: 3 : 'tv series' changed to 'movie'
# row: 1057 col: 3 : 'movie' changed to 'movie'
# row: 1385 col: 3 : 'movie' changed to 'tv series'
# row: 974 col: 3 : 'movie' changed to 'tv series'
# row: 1338 col: 3 : 'movie' changed to 'tv series'
# row: 1370 col: 3 : 'movie' changed to 'movie'
# row: 406 col: 3 : 'movie' changed to 'movie'
# row: 314 col: 3 : 'tv series' changed to 'tv series'
# row: 1235 col: 3 : 'movie' changed to 'movie'
# row: 1552 col: 3 : 'movie' changed to 'movie'
# row: 1204 col: 3 : 'movie' changed to 'movie'
# row: 1067 col: 3 : 'tv series' changed to 'movie'
# row: 1167 col: 3 : 'movie' changed to 'movie'
# row: 1234 col: 3 : 'movie' changed to 'movie'
# row: 791 col: 3 : 'tv series' changed to 'movie'
# row: 19 col: 3 : 'tv series' changed to 'tv series'
# row: 1341 col: 3 : 'movie' changed to 'movie'
# row: 711 col: 3 : 'tv series' changed to 'movie'
# row: 581 col: 3 : 'tv series' changed to 'movie'
# row: 519 col: 3 : 'tv series' changed to 'movie'
# row: 1309 col: 3 : 'movie' changed to 'movie'
# row: 978 col: 3 : 'movie' changed to 'movie'
# row: 309 col: 3 : 'tv series' changed to 'movie'
# row: 550 col: 3 : 'tv series' changed to 'tv series'
# row: 1191 col: 3 : 'movie' changed to 'tv series'
# row: 133 col: 3 : 'tv series' changed to 'movie'
# row: 1286 col: 3 : 'tv series' changed to 'movie'
# row: 1386 col: 3 : 'tv series' changed to 'tv series'
# row: 962 col: 3 : 'tv series' changed to 'movie'
# row: 1594 col: 3 : 'movie' changed to 'tv series'
# row: 1508 col: 3 : 'movie' changed to 'movie'
# row: 1086 col: 3 : 'tv series' changed to 'movie'
# row: 1103 col: 3 : 'tv series' changed to 'tv series'
# row: 1331 col: 3 : 'tv series' changed to 'tv series'
# row: 98 col: 3 : 'tv series' changed to 'movie'
# row: 1585 col: 3 : 'tv series' changed to 'tv series'
# row: 777 col: 3 : 'tv series' changed to 'tv series'
# row: 328 col: 3 : 'tv series' changed to 'tv series'
# row: 346 col: 3 : 'tv series' changed to 'tv series'
# row: 1173 col: 3 : 'movie' changed to 'tv series'
# row: 784 col: 3 : 'movie' changed to 'movie'
# row: 950 col: 3 : 'tv series' changed to 'tv series'
# row: 479 col: 3 : 'tv series' changed to 'movie'
# row: 1007 col: 3 : 'movie' changed to 'tv series'
# row: 1120 col: 3 : 'movie' changed to 'movie'
# row: 907 col: 3 : 'tv series' changed to 'movie'
# row: 825 col: 3 : 'movie' changed to 'tv series'
# row: 1477 col: 3 : 'movie' changed to 'movie'
# row: 1531 col: 3 : 'movie' changed to 'tv series'
# row: 320 col: 3 : 'tv series' changed to 'tv series'
# row: 996 col: 3 : 'tv series' changed to 'movie'
# row: 164 col: 3 : 'movie' changed to 'movie'
# row: 1110 col: 3 : 'movie' changed to 'tv series'
# row: 31 col: 3 : 'tv series' changed to 'movie'
# row: 1298 col: 3 : 'movie' changed to 'movie'
# row: 1400 col: 3 : 'movie' changed to 'movie'
# row: 329 col: 3 : 'tv series' changed to 'tv series'
# row: 1168 col: 3 : 'movie' changed to 'movie'
# row: 1584 col: 3 : 'movie' changed to 'movie'
# row: 210 col: 3 : 'movie' changed to 'movie'
# row: 1580 col: 3 : 'movie' changed to 'movie'
# row: 730 col: 3 : 'tv series' changed to 'tv series'
# row: 78 col: 3 : 'movie' changed to 'tv series'
# row: 1577 col: 3 : 'tv series' changed to 'tv series'
# row: 1147 col: 3 : 'movie' changed to 'tv series'
# row: 1391 col: 3 : 'movie' changed to 'movie'
# row: 826 col: 3 : 'movie' changed to 'tv series'
# row: 143 col: 3 : 'movie' changed to 'movie'
# row: 432 col: 3 : 'movie' changed to 'tv series'
# row: 1446 col: 3 : 'movie' changed to 'movie'
# row: 1136 col: 3 : 'tv series' changed to 'tv series'
# row: 1026 col: 3 : 'tv series' changed to 'movie'
# row: 1374 col: 3 : 'movie' changed to 'tv series'
# row: 646 col: 3 : 'movie' changed to 'tv series'
# row: 630 col: 3 : 'tv series' changed to 'movie'
# row: 600 col: 3 : 'movie' changed to 'movie'
# row: 607 col: 3 : 'movie' changed to 'movie'
# row: 158 col: 3 : 'movie' changed to 'movie'
# row: 205 col: 3 : 'tv series' changed to 'movie'
# row: 1050 col: 3 : 'movie' changed to 'movie'
# row: 1187 col: 3 : 'tv series' changed to 'movie'
# row: 207 col: 3 : 'tv series' changed to 'tv series'
# row: 1335 col: 3 : 'tv series' changed to 'tv series'
# row: 1053 col: 3 : 'tv series' changed to 'tv series'
# row: 1164 col: 3 : 'tv series' changed to 'tv series'
# row: 1480 col: 3 : 'tv series' changed to 'tv series'
# row: 1438 col: 3 : 'tv series' changed to 'tv series'
# row: 963 col: 3 : 'tv series' changed to 'movie'
# row: 981 col: 3 : 'tv series' changed to 'movie'
# row: 216 col: 3 : 'movie' changed to 'tv series'
# row: 76 col: 3 : 'tv series' changed to 'movie'
# row: 399 col: 3 : 'movie' changed to 'tv series'
# row: 472 col: 3 : 'movie' changed to 'movie'
# row: 134 col: 3 : 'tv series' changed to 'movie'
# row: 302 col: 3 : 'movie' changed to 'tv series'
# row: 242 col: 3 : 'tv series' changed to 'tv series'
# row: 743 col: 3 : 'movie' changed to 'tv series'
# row: 1495 col: 3 : 'tv series' changed to 'movie'
# row: 247 col: 3 : 'tv series' changed to 'movie'
# row: 1263 col: 3 : 'movie' changed to 'movie'
# row: 1454 col: 3 : 'movie' changed to 'movie'
# row: 515 col: 3 : 'movie' changed to 'movie'
# row: 877 col: 3 : 'tv series' changed to 'movie'
# row: 1268 col: 3 : 'tv series' changed to 'tv series'
# row: 49 col: 3 : 'tv series' changed to 'movie'
# row: 969 col: 3 : 'movie' changed to ''
# row: 1323 col: 3 : 'tv series' changed to 'tv series'
# row: 448 col: 3 : 'movie' changed to 'tv series'
# row: 1364 col: 3 : 'movie' changed to 'movie'
# row: 794 col: 3 : 'tv series' changed to 'movie'
# row: 595 col: 3 : 'tv series' changed to 'tv series'
# row: 145 col: 3 : 'tv series' changed to 'movie'
# row: 752 col: 3 : 'movie' changed to 'tv series'
# row: 1041 col: 3 : 'movie' changed to 'movie'
# row: 1174 col: 3 : 'movie' changed to 'tv series'
# row: 113 col: 3 : 'movie' changed to 'movie'
# row: 790 col: 3 : 'movie' changed to 'movie'
# row: 1222 col: 3 : 'movie' changed to 'tv series'
# row: 822 col: 3 : 'movie' changed to 'movie'
# row: 1183 col: 3 : 'tv series' changed to 'movie'
# row: 1062 col: 3 : 'movie' changed to 'tv series'
# row: 506 col: 3 : 'tv series' changed to 'movie'
# row: 1402 col: 3 : 'movie' changed to 'tv series'
# row: 1450 col: 3 : 'tv series' changed to 'tv series'
# row: 1244 col: 3 : 'movie' changed to 'movie'
# row: 805 col: 3 : 'tv series' changed to 'tv series'
# row: 228 col: 3 : 'tv series' changed to 'tv series'
# row: 331 col: 3 : 'tv series' changed to 'movie'
# row: 1237 col: 3 : 'movie' changed to 'tv series'
# row: 1270 col: 3 : 'movie' changed to 'movie'
# row: 935 col: 3 : 'movie' changed to 'tv series'
# row: 803 col: 3 : 'tv series' changed to 'movie'
# row: 1028 col: 3 : 'tv series' changed to 'movie'
# row: 1140 col: 3 : 'movie' changed to 'tv series'
# row: 879 col: 3 : 'tv series' changed to 'movie'
# row: 782 col: 3 : 'movie' changed to 'movie'
# row: 99 col: 3 : 'tv series' changed to 'tv series'
# row: 323 col: 3 : 'tv series' changed to 'movie'
# row: 1445 col: 3 : 'movie' changed to 'movie'
# row: 1534 col: 3 : 'movie' changed to 'movie'
# row: 926 col: 3 : 'movie' changed to 'tv series'
# row: 983 col: 3 : 'tv series' changed to 'movie'
# row: 1277 col: 3 : 'movie' changed to 'movie'
# row: 109 col: 3 : 'movie' changed to 'movie'
# row: 1004 col: 3 : 'movie' changed to 'tv series'
# row: 457 col: 3 : 'tv series' changed to 'movie'
# row: 1537 col: 3 : 'tv series' changed to 'movie'
# row: 1302 col: 3 : 'movie' changed to 'tv series'
# row: 1186 col: 3 : 'tv series' changed to 'tv series'
# row: 742 col: 3 : 'movie' changed to 'movie'
# row: 669 col: 3 : 'tv series' changed to 'tv series'
# row: 568 col: 3 : 'tv series' changed to 'tv series'
# row: 1352 col: 3 : 'tv series' changed to 'movie'
# row: 1307 col: 3 : 'tv series' changed to 'movie'
# row: 1137 col: 3 : 'tv series' changed to 'movie'
# row: 393 col: 3 : 'tv series' changed to 'movie'
# row: 354 col: 3 : 'tv series' changed to 'movie'
# row: 1513 col: 3 : 'tv series' changed to 'movie'
# row: 426 col: 3 : 'tv series' changed to 'movie'
# row: 122 col: 3 : 'tv series' changed to 'tv series'
# row: 146 col: 3 : 'movie' changed to 'movie'
# row: 1545 col: 3 : 'movie' changed to 'tv series'
# row: 899 col: 3 : 'tv series' changed to 'tv series'
# row: 100 col: 3 : 'tv series' changed to 'movie'
# row: 869 col: 3 : 'tv series' changed to 'tv series'
# row: 679 col: 3 : 'movie' changed to 'movie'
# row: 1435 col: 3 : 'movie' changed to 'movie'
# row: 1305 col: 3 : 'tv series' changed to 'movie'
# row: 48 col: 3 : 'tv series' changed to 'movie'
# row: 1064 col: 3 : 'tv series' changed to 'tv series'
# row: 1378 col: 3 : 'movie' changed to 'tv series'
# row: 1596 col: 3 : 'tv series' changed to 'movie'
# row: 1476 col: 3 : 'movie' changed to 'tv series'
# row: 1589 col: 3 : 'tv series' changed to 'tv series'
# row: 89 col: 3 : 'tv series' changed to 'movie'
# row: 71 col: 3 : 'tv series' changed to 'tv series'
# row: 836 col: 3 : 'movie' changed to 'movie'
# row: 1011 col: 3 : 'tv series' changed to 'tv series'
# row: 80 col: 3 : 'tv series' changed to 'tv series'
# row: 1449 col: 3 : 'movie' changed to 'movie'
# row: 283 col: 3 : 'movie' changed to 'movie'
# row: 827 col: 3 : 'movie' changed to 'tv series'
# row: 392 col: 3 : 'tv series' changed to 'tv series'
# row: 1413 col: 3 : 'tv series' changed to 'tv series'
# row: 1154 col: 3 : 'movie' changed to 'movie'
# row: 867 col: 3 : 'tv series' changed to 'tv series'
# row: 62 col: 3 : 'tv series' changed to 'tv series'
# row: 144 col: 3 : 'tv series' changed to 'movie'
# row: 1068 col: 3 : 'tv series' changed to 'tv series'
# row: 995 col: 3 : 'movie' changed to 'movie'
# row: 425 col: 3 : 'tv series' changed to 'tv series'
# row: 527 col: 3 : 'movie' changed to 'movie'
# row: 761 col: 3 : 'movie' changed to 'tv series'
# row: 923 col: 3 : 'tv series' changed to 'movie'
# row: 360 col: 3 : 'movie' changed to 'movie'
# row: 1420 col: 3 : 'tv series' changed to 'tv series'
# row: 497 col: 3 : 'tv series' changed to 'tv series'
# row: 1166 col: 3 : 'tv series' changed to 'tv series'
# row: 921 col: 3 : 'movie' changed to 'movie'
# row: 839 col: 3 : 'movie' changed to 'movie'
# row: 170 col: 3 : 'tv series' changed to 'movie'
# row: 758 col: 3 : 'movie' changed to 'movie'
# row: 1119 col: 3 : 'movie' changed to 'movie'
# row: 1182 col: 3 : 'tv series' changed to 'tv series'
# row: 1016 col: 3 : 'tv series' changed to 'movie'
# row: 1583 col: 3 : 'movie' changed to 'tv series'
# row: 1256 col: 3 : 'movie' changed to 'movie'
# row: 1131 col: 3 : 'movie' changed to 'tv series'
# row: 213 col: 3 : 'tv series' changed to 'tv series'
# row: 469 col: 3 : 'tv series' changed to 'movie'
# row: 853 col: 3 : 'movie' changed to 'movie'
# row: 1107 col: 3 : 'tv series' changed to 'tv series'
# row: 1130 col: 3 : 'tv series' changed to 'movie'
# row: 710 col: 3 : 'tv series' changed to 'tv series'
# row: 416 col: 3 : 'movie' changed to 'tv series'
# row: 878 col: 3 : 'tv series' changed to 'movie'
# row: 1525 col: 3 : 'tv series' changed to 'movie'
# row: 652 col: 3 : 'movie' changed to 'movie'
# row: 640 col: 3 : 'movie' changed to 'movie'
# row: 686 col: 3 : 'tv series' changed to 'movie'
# row: 1407 col: 3 : 'tv series' changed to 'tv series'
# row: 287 col: 3 : 'tv series' changed to 'tv series'
# row: 985 col: 3 : 'movie' changed to 'tv series'
# row: 723 col: 3 : 'movie' changed to 'movie'
# row: 343 col: 3 : 'movie' changed to 'movie'
# row: 1272 col: 3 : 'movie' changed to 'movie'
# row: 106 col: 3 : 'tv series' changed to 'tv series'
# row: 44 col: 3 : 'movie' changed to 'tv series'
# row: 60 col: 3 : 'tv series' changed to 'tv series'
# row: 1017 col: 3 : 'movie' changed to 'tv series'
# row: 1282 col: 3 : 'movie' changed to 'tv series'
# row: 1316 col: 3 : 'tv series' changed to 'tv series'
# row: 594 col: 3 : 'tv series' changed to 'tv series'
# row: 11 col: 3 : 'tv series' changed to 'movie'
# row: 125 col: 3 : 'tv series' changed to 'movie'
# row: 1473 col: 3 : 'tv series' changed to 'tv series'
# row: 1553 col: 3 : 'movie' changed to 'tv series'
# row: 1008 col: 3 : 'tv series' changed to 'tv series'
# row: 904 col: 3 : 'movie' changed to 'movie'
# row: 563 col: 3 : 'movie' changed to 'tv series'
# row: 1060 col: 3 : 'tv series' changed to 'movie'
# row: 808 col: 3 : 'tv series' changed to 'tv series'
# row: 861 col: 3 : 'tv series' changed to 'movie'
# row: 52 col: 3 : 'movie' changed to ''
# row: 1014 col: 3 : 'tv series' changed to 'movie'
# row: 211 col: 3 : 'tv series' changed to ''
# row: 185 col: 3 : 'movie' changed to 'tv series'
# row: 1071 col: 3 : 'movie' changed to 'tv series'
# row: 945 col: 3 : 'tv series' changed to 'movie'
# row: 756 col: 3 : 'tv series' changed to 'tv series'
# row: 604 col: 3 : 'tv series' changed to 'tv series'
# row: 553 col: 3 : 'tv series' changed to 'movie'
# row: 521 col: 3 : 'tv series' changed to 'tv series'
# row: 95 col: 3 : 'movie' changed to 'movie'
# row: 1287 col: 3 : 'movie' changed to 'tv series'
# row: 959 col: 3 : 'tv series' changed to 'movie'
# row: 882 col: 3 : 'tv series' changed to 'movie'
# row: 1089 col: 3 : 'tv series' changed to 'tv series'
# row: 1289 col: 3 : 'movie' changed to 'tv series'
# row: 586 col: 3 : 'movie' changed to 'movie'
# row: 931 col: 3 : 'tv series' changed to 'movie'
# row: 786 col: 3 : 'tv series' changed to 'movie'
# row: 344 col: 3 : 'tv series' changed to 'movie'
# row: 615 col: 3 : 'movie' changed to 'movie'
# row: 1505 col: 3 : 'tv series' changed to 'tv series'
# row: 293 col: 3 : 'movie' changed to 'tv series'
# row: 1461 col: 3 : 'movie' changed to 'movie'
# row: 1431 col: 3 : 'movie' changed to 'movie'
# row: 690 col: 3 : 'movie' changed to 'tv series'
# row: 63 col: 3 : 'movie' changed to 'tv series'
# row: 405 col: 3 : 'movie' changed to 'tv series'
# row: 1264 col: 3 : 'tv series' changed to 'movie'
# row: 348 col: 3 : 'movie' changed to 'tv series'
# row: 741 col: 3 : 'tv series' changed to 'tv series'
# row: 745 col: 3 : 'tv series' changed to 'tv series'
# row: 635 col: 3 : 'movie' changed to 'tv series'
# row: 561 col: 3 : 'movie' changed to 'tv series'
# row: 1208 col: 3 : 'movie' changed to 'tv series'
# row: 1051 col: 3 : 'tv series' changed to 'tv series'
# row: 936 col: 3 : 'movie' changed to 'movie'
# row: 813 col: 3 : 'movie' changed to 'movie'
# row: 1005 col: 3 : 'tv series' changed to 'movie'
# row: 153 col: 3 : 'movie' changed to 'movie'
# row: 1444 col: 3 : 'tv series' changed to 'movie'
# row: 1427 col: 3 : 'movie' changed to 'movie'
# row: 234 col: 3 : 'movie' changed to 'tv series'
# row: 370 col: 3 : 'movie' changed to 'tv series'
# row: 1344 col: 3 : 'tv series' changed to 'movie'
# row: 520 col: 3 : 'movie' changed to 'movie'
# row: 224 col: 3 : 'tv series' changed to 'tv series'
# row: 773 col: 3 : 'movie' changed to 'tv series'
# row: 1409 col: 3 : 'movie' changed to 'movie'
# row: 1015 col: 3 : 'movie' changed to 'tv series'
# row: 1148 col: 3 : 'tv series' changed to 'movie'
# row: 1535 col: 3 : 'tv series' changed to 'movie'
# row: 1255 col: 3 : 'movie' changed to 'movie'
# row: 1027 col: 3 : 'tv series' changed to 'tv series'
# row: 905 col: 3 : 'movie' changed to 'movie'
# row: 195 col: 3 : 'tv series' changed to 'tv series'
# row: 502 col: 3 : 'tv series' changed to 'movie'
# row: 1555 col: 3 : 'tv series' changed to 'tv series'
# row: 359 col: 3 : 'movie' changed to 'tv series'
# row: 397 col: 3 : 'tv series' changed to 'tv series'
# row: 852 col: 3 : 'tv series' changed to 'movie'
# row: 523 col: 3 : 'tv series' changed to 'tv series'
# row: 858 col: 3 : 'tv series' changed to 'movie'
# row: 46 col: 3 : 'tv series' changed to 'movie'
# row: 4 col: 3 : 'movie' changed to 'tv series'
# row: 114 col: 3 : 'tv series' changed to 'movie'
# row: 536 col: 3 : 'movie' changed to 'tv series'
# row: 342 col: 3 : 'tv series' changed to 'movie'
# row: 171 col: 3 : 'movie' changed to 'tv series'
# row: 859 col: 3 : 'movie' changed to 'tv series'
# row: 1506 col: 3 : 'movie' changed to 'movie'
# row: 1357 col: 3 : 'tv series' changed to 'tv series'
# row: 1218 col: 3 : 'tv series' changed to 'movie'
# row: 1146 col: 3 : 'movie' changed to 'movie'
# row: 1412 col: 3 : 'movie' changed to 'movie'
# row: 522 col: 3 : 'tv series' changed to 'tv series'
# row: 77 col: 3 : 'tv series' changed to 'movie'
# row: 1425 col: 3 : 'tv series' changed to 'movie'
# row: 596 col: 3 : 'tv series' changed to 'tv series'
# row: 992 col: 3 : 'movie' changed to 'tv series'
# row: 788 col: 3 : 'tv series' changed to 'tv series'
# row: 1544 col: 3 : 'movie' changed to 'movie'
# row: 1100 col: 3 : 'movie' changed to 'tv series'
# row: 543 col: 3 : 'tv series' changed to 'movie'
# row: 908 col: 3 : 'tv series' changed to 'tv series'
# row: 1133 col: 3 : 'tv series' changed to 'tv series'
# row: 139 col: 3 : 'movie' changed to 'tv series'
# row: 545 col: 3 : 'tv series' changed to 'tv series'

# %% [markdown]
# ## Transformation

# %%
import nltk
def get_words(x):
    bagofwords=[]
    for i in x:
        if i[1]=='NN':
            bagofwords.append(i[0])
        elif i[1]=='NNS':
            bagofwords.append(i[0])
        elif i[1]=='NNP':
            bagofwords.append(i[0])
        elif i[1]=='NNPS':
            bagofwords.append(i[0])
        elif i[1]=='JJ':
            bagofwords.append(i[0])
        elif i[1]=='JJR':
            bagofwords.append(i[0])
        elif i[1]=='JJS':
            bagofwords.append(i[0])
        elif i[1]=='RB':
            bagofwords.append(i[0])
        elif i[1]=='RBR':
            bagofwords.append(i[0])
        elif i[1]=='RBS':
            bagofwords.append(i[0])
    return bagofwords

def clean_words(x):
    b=nltk.pos_tag(nltk.word_tokenize(x))
    result=get_words(b)
    return result

# %%
def get_dummies(train_data_set, test_data_set):
    train_dummies = train_data_set.genre.str.get_dummies(',')
    test_dummies = test_data_set.genre.str.get_dummies(',')
    
    print("Train Dummies",train_dummies.shape)    
    print("Test Dummies",test_dummies.shape)
    
    #### ALİGN
    train_dummies, test_dummies = train_dummies.align(test_dummies, axis=1, join='left')
    
    test_dummies.fillna(0, inplace=True)
    
    type_lb = LabelBinarizer()
    fitted_type_lb = type_lb.fit(train_data_set.type.values)
    X_train = type_lb.transform(train_data_set.type.values)
    X_test  = type_lb.transform(test_data_set.type.values)
    
    dfOneHot_train = pd.DataFrame(X_train, columns = ["movie/TVseries" for i in range(X_train.shape[1])])
    dfOneHot_test  = pd.DataFrame(X_test,  columns = ["movie/TVseries" for i in range(X_test.shape[1])])
    
    
    train_data_set = pd.concat([train_data_set, dfOneHot_train], axis=1, join="inner")
    train_data_set = pd.concat([train_data_set, train_dummies ], axis=1, join="inner")

    test_data_set = pd.concat([test_data_set, dfOneHot_test], axis=1)
    test_data_set = pd.concat([test_data_set, test_dummies],  axis=1)
    
    test_data_set['movie/TVseries'].fillna(0, inplace=True)
    train_data_set['movie/TVseries'].fillna(0, inplace=True)

    return ([train_data_set, test_data_set])

def feature_transformation(train_data_set, test_data_set):
    
    dummieset = get_dummies(train_data_set, test_data_set)
    train_data_set = dummieset[0]
    test_data_set = dummieset[1]
        
    #Bag of Words
    summary_doc_train = train_data_set['overview'].fillna("").map(clean_words)
    summary_doc_train =summary_doc_train.apply(','.join)
    
    summary_doc_test = test_data_set['overview'].fillna("").map(clean_words)
    summary_doc_test =summary_doc_test.apply(','.join)
 
    vectorizer = TfidfVectorizer()
    fitted_vectorizer = vectorizer.fit(summary_doc_train)
    overview_feature_train = fitted_vectorizer.transform(summary_doc_train).toarray()
    overview_feature_test = fitted_vectorizer.transform(summary_doc_test).toarray()

    df_train = pd.DataFrame(overview_feature_train, columns = ["word"+ str(int(i)) for i in range(overview_feature_train.shape[1])])
    train_data_set = pd.concat([train_data_set, df_train], axis=1)
    
    df_test = pd.DataFrame(overview_feature_test, columns = ["word"+ str(int(i)) for i in range(overview_feature_test.shape[1])])
    test_data_set = pd.concat([test_data_set, df_test], axis=1)
    
    train_data_set = train_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    test_data_set = test_data_set.drop(columns=['anime_id', 'name', 'genre', 'overview', 'type'])
    
    #drop NaN values
    train_data_set.dropna(inplace=True)
    test_data_set.dropna(inplace=True)
    
    train_data_set.fillna(0, inplace=True)
    test_data_set.fillna(0, inplace=True)
    
    return ([train_data_set, test_data_set])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# features vector
transformed_features = feature_transformation(anime_train, anime_test)

anime_train = transformed_features[0]
anime_test = transformed_features[1]

print(anime_train.shape)
print(anime_test.shape)

# split train test
anime_y_train = anime_train['rating']
anime_X_train = anime_train.drop(columns=['rating'])

anime_y_test = anime_test['rating']
anime_X_test = anime_test.drop(columns=['rating'])
# Out:
# Train Dummies (1600, 57)
# Test Dummies (400, 49)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-688999c262f3> in <module>
#       2
#       3 # features vector
# ----> 4 transformed_features = feature_transformation(anime_train, anime_test)
#       5
#       6 anime_train = transformed_features[0]
#
# <ipython-input-14-04dfa65526d4> in feature_transformation(train_data_set, test_data_set)
#      33 def feature_transformation(train_data_set, test_data_set):
#      34
# ---> 35     dummieset = get_dummies(train_data_set, test_data_set)
#      36     train_data_set = dummieset[0]
#      37     test_data_set = dummieset[1]
#
# <ipython-input-14-04dfa65526d4> in get_dummies(train_data_set, test_data_set)
#      12
#      13     type_lb = LabelBinarizer()
# ---> 14     fitted_type_lb = type_lb.fit(train_data_set.type.values)
#      15     X_train = type_lb.transform(train_data_set.type.values)
#      16     X_test  = type_lb.transform(test_data_set.type.values)
#
# ~/.local/share/virtualenvs/dsa-DC4ML-_HMLejDF/lib/python3.7/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     403         self : returns an instance of self.
#     404         """
# --> 405         self.y_type_ = type_of_target(y)
#     406         if 'multioutput' in self.y_type_:
#     407             raise ValueError("Multioutput target data is not supported with "
#
# ~/.local/share/virtualenvs/dsa-DC4ML-_HMLejDF/lib/python3.7/site-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~/.local/share/virtualenvs/dsa-DC4ML-_HMLejDF/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~/.local/share/virtualenvs/dsa-DC4ML-_HMLejDF/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     279         aux = ar[perm]
#     280     else:
# --> 281         ar.sort()
#     282         aux = ar
#     283     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler

selector = SelectKBest(score_func=f_regression,k=700)#anime_X_test.shape[1]-1)
features = selector.fit(anime_X_train, anime_y_train)

# summarize scores
np.set_printoptions(precision=3)
#print(fit.scores_)

print(anime_X_train.shape)
print(anime_X_test.shape)
anime_X_train = features.transform(anime_X_train)
anime_X_test = features.transform(anime_X_test)
print(anime_X_train.shape)
print(anime_X_test.shape)

scaler = StandardScaler() 

# Apply transform to both the training set and the test set.
anime_X_train = scaler.fit_transform(anime_X_train)  
anime_X_test = scaler.transform(anime_X_test)

# %% [markdown]
# ## Training - Testing - Evaluation

# %%
def training(model, dataset, label):
    clf = model
    clf.fit(dataset, label)
    return clf

def testing_evaluation(model, testset):
    # Make predictions using the testing set
    anime_y_pred = model.predict(testset)
    
    # The mean squared error
    print("Mean squared error: %.2f" % np.sqrt(mean_squared_error(anime_y_test, anime_y_pred)))

    
    visualizer = PredictionError(model)
    visualizer.fit(anime_X_train, anime_y_train)  # Fit the training data to the visualizer
    visualizer.score(anime_X_test, anime_y_test)  # Evaluate the model on the test data
    g = visualizer.poof() 
    
    
    plt.plot(anime_y_test, '--g', anime_y_pred, '--b')

# %% [markdown]
# ### Training

# %%
clf = training(model = linear_model.Lasso(), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)

# %% [markdown]
# ### Cross Validation

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
scores = cross_val_score(clf, anime_X_train, anime_y_train, scoring="neg_mean_squared_error", cv=5) 
rmse_scores = np.sqrt(-scores)
display_scores(rmse_scores)

# %% [markdown]
# ### Grid Search For Hyper Parameter Selection

# %%
def checkHP(model, folds, dataset, label):
    parameters = {
                    "alpha" : [1,0.1,0.01,0.001,0.0001,0]
                  }

    gd_sr = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring="neg_mean_squared_error",
                         cv=folds)

    gd_sr.fit(dataset, label)  
    
    best_parameters = gd_sr.best_params_  
    print("best parameters are: ", best_parameters)

    best_result = gd_sr.best_score_  
    print("The mean squared Error is: %.2f" % -best_result) 
    
checkHP(clf, 10, anime_X_train, anime_y_train)

# %%
clf = training(model = linear_model.Lasso(alpha = 0.01), dataset = anime_X_train, label= anime_y_train)
testing_evaluation(clf, anime_X_test)
